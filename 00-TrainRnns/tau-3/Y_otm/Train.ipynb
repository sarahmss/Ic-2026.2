# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm", "cos(theta_pred)"
# - Saida: X
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = [
    "ZZx1",  # Train
    "ZZx2",  # Val
    "ZZxReto", # Test
    "ZZy1", # Test
    "ZZy2", # Test
    "LSG-1", # Test
    "LSG-2", # Test
    "ZZx1-inv", # Test
    "zzx2-inv2", # Test
    "semiCirc", # Test
]
PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a", "sintheta"]   
TARGET_INT = ["y"]  
TARGET = ["dy"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
PLOT = False
TIME_STEPS = 3
TS = 0.07

# %%
Datasets = []
NormDatasets = []

for title in TITLES:
    df = pd.read_excel("./../Theta/Data/Datasets.xlsx", sheet_name=title)
    df_theta = pd.read_excel("./../Theta/resultados_comparacao.xlsx", sheet_name=title)

    df["theta_pred"] = df_theta["theta_pred_model_arch69_r0.9_Ld0.7_Lp0.3_seed1706"]
    df["sintheta"] = np.sin(df["theta_pred"])
    df = df.dropna().reset_index(drop=True)

    Datasets.append(df)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train = Train1

for i in range(len(Datasets) - 1):
    CurrentTestDataset = Datasets[i + 1].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = NormDatasets[1]

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1030, 3, 5)
# Dimensão da saida: (1030, 1)
# Dimensão da entrada: (1388, 3, 5)
# Dimensão da saida: (1388, 1)

# %%
phi_d_train =  Train["phi_d"].values[:len(x_train)]
phi_e_train =  Train["phi_e"].values[:len(x_train)]
theta_train = Train["theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(phi_d_train)}")
print(f"Dimensão da entrada fisica: {np.shape(phi_e_train)}")
# Out:
# Dimensão da entrada: (1030, 3, 5)
# Dimensão da saida: (1030, 1)
# Dimensão da entrada fisica : (1030,)
# Dimensão da entrada fisica: (1030,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):
    dx_cin = (R / 2) * tf.sin(theta) * (phi_d + phi_e)
    return [dx_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(dq).T, np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, phi_d, phi_e, theta, Ld, Lp):
    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(phi_d, phi_e, theta), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
phi_d_train = tf.convert_to_tensor(phi_d_train, dtype=tf.float32)
phi_e_train = tf.convert_to_tensor(phi_e_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          phi_d_train, phi_e_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_mse = f"MSE_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_mse, []).append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {mse:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"MSE_{safe_title}_{name}"] = to_scalar(metrics[name][f"MSE_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    #os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    model_path = f"models/{model_name}.keras"

    #model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}")

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import initializers
from itertools import product
import numpy as np
import tensorflow as tf

N_MODELS = 5

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[n] for n in range(81, 101)]


# FirstLayers = [
#     [27], [30], [32], [35], [36], [37], [40],
#     [42], [44], [46], [49], [50], [52], [75],
# ]

# architectures = [
#     [fl[0], sl]
#     for fl in FirstLayers
#     for sl in range(
#         max(1, int(0.3 * fl[0])),
#         int(0.7 * fl[0])
#     )
# ]

# 🔹 retomar a partir do último modelo salvo
# last_saved = [27, 12]

# if last_saved in architectures:
#     idx = architectures.index(last_saved)
#     architectures = architectures[idx + 1:]  # começa DEPOIS do último salvo
#     print(f"Retomando a partir de {last_saved} (índice {idx}). Restam {len(architectures)} arquiteturas.")
# else:
#     print(f"⚠️ {last_saved} não encontrado na lista — rodando tudo do zero.")

print(len(architectures))
print(architectures)

Ld_Lp = [[0.5, 0.5], [0.3, 0.7], [0.7, 0.3]]
r_values = [0.01, 0.9]

results = {}

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados-1l-v2.xlsx")
# Out:
# 20
# [[81], [82], [83], [84], [85], [86], [87], [88], [89], [90], [91], [92], [93], [94], [95], [96], [97], [98], [99], [100]]
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 0.987786 | Val Loss 3.448539
# Epoch 100 | Train Loss 0.071409 | Val Loss 0.495340
# Epoch 200 | Train Loss 0.044525 | Val Loss 0.510525
# Epoch 300 | Train Loss 0.035571 | Val Loss 0.518601
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9808, R² diff = 0.9416
# y | ZZx2 -> R² = 0.9701, R² diff = 0.8773
# y | ZZxReto -> R² = -3.1765, R² diff = 0.2815
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 0.944401 | Val Loss 3.122526
# Epoch 100 | Train Loss 0.070548 | Val Loss 0.511034
# Epoch 200 | Train Loss 0.045469 | Val Loss 0.499993
# Epoch 300 | Train Loss 0.037020 | Val Loss 0.555224
# Early stopping at epoch 356
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9831, R² diff = 0.9440
# y | ZZx2 -> R² = 0.9588, R² diff = 0.8742
# y | ZZxReto -> R² = -2.9095, R² diff = 0.2949
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.132855 | Val Loss 3.988703
# Epoch 100 | Train Loss 0.070682 | Val Loss 0.486002
# Epoch 200 | Train Loss 0.044685 | Val Loss 0.469358
# Epoch 300 | Train Loss 0.036761 | Val Loss 0.500453
# Early stopping at epoch 358
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9843, R² diff = 0.9471
# y | ZZx2 -> R² = 0.9519, R² diff = 0.8833
# y | ZZxReto -> R² = -2.6170, R² diff = 0.3406
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.054994 | Val Loss 3.724480
# Epoch 100 | Train Loss 0.071067 | Val Loss 0.490237
# Epoch 200 | Train Loss 0.046314 | Val Loss 0.455782
# Epoch 300 | Train Loss 0.036401 | Val Loss 0.478701
# Early stopping at epoch 373
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed4434.keras
# y | ZZx1 -> R² = 0.9833, R² diff = 0.9475
# y | ZZx2 -> R² = 0.9421, R² diff = 0.8821
# y | ZZxReto -> R² = -2.6862, R² diff = 0.3421
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.085584 | Val Loss 3.826173
# Epoch 100 | Train Loss 0.071029 | Val Loss 0.501359
# Epoch 200 | Train Loss 0.045628 | Val Loss 0.481884
# Epoch 300 | Train Loss 0.035437 | Val Loss 0.542975
# Early stopping at epoch 361
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed2243.keras
# y | ZZx1 -> R² = 0.9833, R² diff = 0.9447
# y | ZZx2 -> R² = 0.9602, R² diff = 0.8785
# y | ZZxReto -> R² = -2.8977, R² diff = 0.3010
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.076001 | Val Loss 3.813116
# Epoch 100 | Train Loss 0.071457 | Val Loss 0.493256
# Epoch 200 | Train Loss 0.046159 | Val Loss 0.455694
# Epoch 300 | Train Loss 0.036133 | Val Loss 0.523749
# Early stopping at epoch 373
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9841, R² diff = 0.9469
# y | ZZx2 -> R² = 0.9450, R² diff = 0.8823
# y | ZZxReto -> R² = -2.6984, R² diff = 0.3319
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 0.868479 | Val Loss 2.879914
# Epoch 100 | Train Loss 0.069566 | Val Loss 0.494752
# Epoch 200 | Train Loss 0.043842 | Val Loss 0.509465
# Epoch 300 | Train Loss 0.035788 | Val Loss 0.496954
# Early stopping at epoch 333
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9790, R² diff = 0.9399
# y | ZZx2 -> R² = 0.9699, R² diff = 0.8750
# y | ZZxReto -> R² = -3.3489, R² diff = 0.2607
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.088417 | Val Loss 3.930939
# Epoch 100 | Train Loss 0.067438 | Val Loss 0.486593
# Epoch 200 | Train Loss 0.042822 | Val Loss 0.487766
# Epoch 300 | Train Loss 0.034914 | Val Loss 0.500892
# Early stopping at epoch 350
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9839, R² diff = 0.9469
# y | ZZx2 -> R² = 0.9435, R² diff = 0.8794
# y | ZZxReto -> R² = -2.6308, R² diff = 0.3373
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.093795 | Val Loss 3.857026
# Epoch 100 | Train Loss 0.069019 | Val Loss 0.488667
# Epoch 200 | Train Loss 0.044883 | Val Loss 0.476564
# Epoch 300 | Train Loss 0.035621 | Val Loss 0.512996
# Early stopping at epoch 365
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed4434.keras
# y | ZZx1 -> R² = 0.9828, R² diff = 0.9469
# y | ZZx2 -> R² = 0.9358, R² diff = 0.8781
# y | ZZxReto -> R² = -2.7260, R² diff = 0.3369
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 1.038219 | Val Loss 3.670316
# Epoch 100 | Train Loss 0.070304 | Val Loss 0.472711
# Epoch 200 | Train Loss 0.045796 | Val Loss 0.488170
# Epoch 300 | Train Loss 0.037098 | Val Loss 0.562130
# Early stopping at epoch 343
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed2243.keras
# y | ZZx1 -> R² = 0.9781, R² diff = 0.9408
# y | ZZx2 -> R² = 0.9696, R² diff = 0.8812
# y | ZZxReto -> R² = -3.3193, R² diff = 0.2694
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 1.140837 | Val Loss 3.981351
# Epoch 100 | Train Loss 0.069946 | Val Loss 0.481567
# Epoch 200 | Train Loss 0.043544 | Val Loss 0.479457
# Epoch 300 | Train Loss 0.035252 | Val Loss 0.513871
# Early stopping at epoch 355
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed5613.keras
# y | ZZx1 -> R² = 0.9837, R² diff = 0.9455
# y | ZZx2 -> R² = 0.9540, R² diff = 0.8823
# y | ZZxReto -> R² = -2.7641, R² diff = 0.3251
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 0.985731 | Val Loss 3.343422
# Epoch 100 | Train Loss 0.071847 | Val Loss 0.515502
# Epoch 200 | Train Loss 0.044216 | Val Loss 0.503082
# Epoch 300 | Train Loss 0.034787 | Val Loss 0.527481
# Early stopping at epoch 349
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed7093.keras
# y | ZZx1 -> R² = 0.9787, R² diff = 0.9409
# y | ZZx2 -> R² = 0.9541, R² diff = 0.8728
# y | ZZxReto -> R² = -3.3192, R² diff = 0.2792
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.127274 | Val Loss 4.009808
# Epoch 100 | Train Loss 0.063985 | Val Loss 0.480065
# Epoch 200 | Train Loss 0.042603 | Val Loss 0.543823
# Epoch 300 | Train Loss 0.036024 | Val Loss 0.551562
# Early stopping at epoch 328
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed5756.keras
# y | ZZx1 -> R² = 0.9820, R² diff = 0.9437
# y | ZZx2 -> R² = 0.9505, R² diff = 0.8756
# y | ZZxReto -> R² = -2.8124, R² diff = 0.3187
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.067157 | Val Loss 3.823541
# Epoch 100 | Train Loss 0.065195 | Val Loss 0.445736
# Epoch 200 | Train Loss 0.044258 | Val Loss 0.465043
# Epoch 300 | Train Loss 0.036998 | Val Loss 0.522513
# Early stopping at epoch 347
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed4434.keras
# y | ZZx1 -> R² = 0.9810, R² diff = 0.9458
# y | ZZx2 -> R² = 0.9455, R² diff = 0.8869
# y | ZZxReto -> R² = -2.8334, R² diff = 0.3296
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.124663 | Val Loss 3.974740
# Epoch 100 | Train Loss 0.073667 | Val Loss 0.491388
# Epoch 200 | Train Loss 0.048564 | Val Loss 0.431256
# Epoch 300 | Train Loss 0.036794 | Val Loss 0.499934
# Early stopping at epoch 385
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed2243.keras
# y | ZZx1 -> R² = 0.9827, R² diff = 0.9462
# y | ZZx2 -> R² = 0.9539, R² diff = 0.8874
# y | ZZxReto -> R² = -2.7313, R² diff = 0.3362
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.180467 | Val Loss 3.983367
# Epoch 100 | Train Loss 0.074110 | Val Loss 0.524871
# Epoch 200 | Train Loss 0.047481 | Val Loss 0.513291
# Epoch 300 | Train Loss 0.037958 | Val Loss 0.574339
# Early stopping at epoch 357
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed5613.keras
# y | ZZx1 -> R² = 0.9785, R² diff = 0.9385
# y | ZZx2 -> R² = 0.9682, R² diff = 0.8712
# y | ZZxReto -> R² = -3.4495, R² diff = 0.2498
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.038033 | Val Loss 3.429674
# Epoch 100 | Train Loss 0.071323 | Val Loss 0.499432
# Epoch 200 | Train Loss 0.045741 | Val Loss 0.489112
# Epoch 300 | Train Loss 0.037434 | Val Loss 0.515908
# Early stopping at epoch 353
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed7093.keras
# y | ZZx1 -> R² = 0.9806, R² diff = 0.9412
# y | ZZx2 -> R² = 0.9693, R² diff = 0.8785
# y | ZZxReto -> R² = -3.2284, R² diff = 0.2701
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.112115 | Val Loss 3.970162
# Epoch 100 | Train Loss 0.069590 | Val Loss 0.493554
# Epoch 200 | Train Loss 0.043717 | Val Loss 0.500651
# Epoch 300 | Train Loss 0.035173 | Val Loss 0.528640
# Early stopping at epoch 351
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed5756.keras
# y | ZZx1 -> R² = 0.9827, R² diff = 0.9443
# y | ZZx2 -> R² = 0.9427, R² diff = 0.8768
# y | ZZxReto -> R² = -2.8559, R² diff = 0.3186
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.055909 | Val Loss 3.655693
# Epoch 100 | Train Loss 0.071509 | Val Loss 0.495782
# Epoch 200 | Train Loss 0.047243 | Val Loss 0.475415
# Epoch 300 | Train Loss 0.038222 | Val Loss 0.532065
# Early stopping at epoch 352
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed4434.keras
# y | ZZx1 -> R² = 0.9781, R² diff = 0.9399
# y | ZZx2 -> R² = 0.9660, R² diff = 0.8776
# y | ZZxReto -> R² = -3.2986, R² diff = 0.2655
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 1.069444 | Val Loss 3.811600
# Epoch 100 | Train Loss 0.069486 | Val Loss 0.474621
# Epoch 200 | Train Loss 0.043071 | Val Loss 0.446156
# Epoch 300 | Train Loss 0.033887 | Val Loss 0.485153
# Early stopping at epoch 362
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed2243.keras
# y | ZZx1 -> R² = 0.9844, R² diff = 0.9480
# y | ZZx2 -> R² = 0.9412, R² diff = 0.8880
# y | ZZxReto -> R² = -2.6163, R² diff = 0.3429
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 1.182692 | Val Loss 4.168243
# Epoch 100 | Train Loss 0.072273 | Val Loss 0.497249
# Epoch 200 | Train Loss 0.048683 | Val Loss 0.437299
# Epoch 300 | Train Loss 0.038571 | Val Loss 0.512165
# Early stopping at epoch 377
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed5613.keras
# y | ZZx1 -> R² = 0.9835, R² diff = 0.9468
# y | ZZx2 -> R² = 0.9572, R² diff = 0.8861
# y | ZZxReto -> R² = -2.7549, R² diff = 0.3210
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 0.853170 | Val Loss 2.943581
# Epoch 100 | Train Loss 0.069845 | Val Loss 0.487623
# Epoch 200 | Train Loss 0.045437 | Val Loss 0.482937
# Epoch 300 | Train Loss 0.038020 | Val Loss 0.532080
# Early stopping at epoch 350
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed7093.keras
# y | ZZx1 -> R² = 0.9815, R² diff = 0.9444
# y | ZZx2 -> R² = 0.9662, R² diff = 0.8823
# y | ZZxReto -> R² = -3.0274, R² diff = 0.2887
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.049689 | Val Loss 3.766899
# Epoch 100 | Train Loss 0.069832 | Val Loss 0.501989
# Epoch 200 | Train Loss 0.044797 | Val Loss 0.469294
# Epoch 300 | Train Loss 0.036370 | Val Loss 0.519835
# Early stopping at epoch 365
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed5756.keras
# y | ZZx1 -> R² = 0.9844, R² diff = 0.9488
# y | ZZx2 -> R² = 0.9385, R² diff = 0.8812
# y | ZZxReto -> R² = -2.5038, R² diff = 0.3495
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.063386 | Val Loss 3.750967
# Epoch 100 | Train Loss 0.068711 | Val Loss 0.490102
# Epoch 200 | Train Loss 0.045060 | Val Loss 0.481008
# Epoch 300 | Train Loss 0.037564 | Val Loss 0.525542
# Early stopping at epoch 360
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed4434.keras
# y | ZZx1 -> R² = 0.9829, R² diff = 0.9475
# y | ZZx2 -> R² = 0.9495, R² diff = 0.8804
# y | ZZxReto -> R² = -2.6515, R² diff = 0.3296
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.137086 | Val Loss 4.087623
# Epoch 100 | Train Loss 0.072013 | Val Loss 0.491621
# Epoch 200 | Train Loss 0.049644 | Val Loss 0.431843
# Epoch 300 | Train Loss 0.038649 | Val Loss 0.479819
# Early stopping at epoch 397
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed2243.keras
# y | ZZx1 -> R² = 0.9840, R² diff = 0.9494
# y | ZZx2 -> R² = 0.9427, R² diff = 0.8865
# y | ZZxReto -> R² = -2.5343, R² diff = 0.3541
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.125019 | Val Loss 3.887577
# Epoch 100 | Train Loss 0.072995 | Val Loss 0.513545
# Epoch 200 | Train Loss 0.053598 | Val Loss 0.459214
# Epoch 300 | Train Loss 0.039332 | Val Loss 0.486030
# Epoch 400 | Train Loss 0.032510 | Val Loss 0.464923
# Early stopping at epoch 405
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed5613.keras
# y | ZZx1 -> R² = 0.9834, R² diff = 0.9474
# y | ZZx2 -> R² = 0.9511, R² diff = 0.8797
# y | ZZxReto -> R² = -2.6786, R² diff = 0.3313
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.014574 | Val Loss 3.496918
# Epoch 100 | Train Loss 0.071145 | Val Loss 0.481572
# Epoch 200 | Train Loss 0.047381 | Val Loss 0.504485
# Epoch 300 | Train Loss 0.038223 | Val Loss 0.554859
# Early stopping at epoch 341
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed7093.keras
# y | ZZx1 -> R² = 0.9784, R² diff = 0.9387
# y | ZZx2 -> R² = 0.9751, R² diff = 0.8785
# y | ZZxReto -> R² = -3.4074, R² diff = 0.2546
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.014104 | Val Loss 3.645518
# Epoch 100 | Train Loss 0.066238 | Val Loss 0.476099
# Epoch 200 | Train Loss 0.044879 | Val Loss 0.482126
# Epoch 300 | Train Loss 0.036708 | Val Loss 0.509665
# Early stopping at epoch 347
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed5756.keras
# y | ZZx1 -> R² = 0.9835, R² diff = 0.9466
# y | ZZx2 -> R² = 0.9477, R² diff = 0.8800
# y | ZZxReto -> R² = -2.6739, R² diff = 0.3283
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.053585 | Val Loss 3.744351
# Epoch 100 | Train Loss 0.070967 | Val Loss 0.490231
# Epoch 200 | Train Loss 0.046366 | Val Loss 0.460493
# Epoch 300 | Train Loss 0.036932 | Val Loss 0.503055
# Early stopping at epoch 373
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed4434.keras
# y | ZZx1 -> R² = 0.9835, R² diff = 0.9480
# y | ZZx2 -> R² = 0.9408, R² diff = 0.8814
# y | ZZxReto -> R² = -2.5905, R² diff = 0.3469
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 1.106291 | Val Loss 3.971202
# Epoch 100 | Train Loss 0.071132 | Val Loss 0.475997
# Epoch 200 | Train Loss 0.046253 | Val Loss 0.461959
# Epoch 300 | Train Loss 0.037286 | Val Loss 0.507295
# Early stopping at epoch 356
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed2243.keras
# y | ZZx1 -> R² = 0.9821, R² diff = 0.9445
# y | ZZx2 -> R² = 0.9679, R² diff = 0.8851
# y | ZZxReto -> R² = -2.9372, R² diff = 0.3033
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 1.042873 | Val Loss 3.456677
# Epoch 100 | Train Loss 0.073167 | Val Loss 0.497906
# Epoch 200 | Train Loss 0.051319 | Val Loss 0.449847
# Epoch 300 | Train Loss 0.039470 | Val Loss 0.514841
# Early stopping at epoch 380
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9801, R² diff = 0.9429
# y | ZZx2 -> R² = 0.9624, R² diff = 0.8824
# y | ZZxReto -> R² = -3.1543, R² diff = 0.2834
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 1.103455 | Val Loss 3.912372
# Epoch 100 | Train Loss 0.072581 | Val Loss 0.477550
# Epoch 200 | Train Loss 0.047973 | Val Loss 0.419442
# Epoch 300 | Train Loss 0.034660 | Val Loss 0.455681
# Early stopping at epoch 389
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9812, R² diff = 0.9482
# y | ZZx2 -> R² = 0.9445, R² diff = 0.8898
# y | ZZxReto -> R² = -2.9342, R² diff = 0.3306
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.142322 | Val Loss 4.098717
# Epoch 100 | Train Loss 0.065104 | Val Loss 0.473505
# Epoch 200 | Train Loss 0.042391 | Val Loss 0.502182
# Epoch 300 | Train Loss 0.034690 | Val Loss 0.499990
# Early stopping at epoch 328
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9803, R² diff = 0.9432
# y | ZZx2 -> R² = 0.9542, R² diff = 0.8781
# y | ZZxReto -> R² = -3.0786, R² diff = 0.3002
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.089452 | Val Loss 3.832721
# Epoch 100 | Train Loss 0.065319 | Val Loss 0.469128
# Epoch 200 | Train Loss 0.043506 | Val Loss 0.481892
# Epoch 300 | Train Loss 0.037073 | Val Loss 0.526129
# Early stopping at epoch 349
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed4434.keras
# y | ZZx1 -> R² = 0.9834, R² diff = 0.9473
# y | ZZx2 -> R² = 0.9431, R² diff = 0.8809
# y | ZZxReto -> R² = -2.6943, R² diff = 0.3298
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.103464 | Val Loss 3.819961
# Epoch 100 | Train Loss 0.072964 | Val Loss 0.502004
# Epoch 200 | Train Loss 0.049183 | Val Loss 0.471181
# Epoch 300 | Train Loss 0.037538 | Val Loss 0.548397
# Early stopping at epoch 370
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed2243.keras
# y | ZZx1 -> R² = 0.9813, R² diff = 0.9430
# y | ZZx2 -> R² = 0.9631, R² diff = 0.8782
# y | ZZxReto -> R² = -3.1233, R² diff = 0.2814
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.131336 | Val Loss 3.994506
# Epoch 100 | Train Loss 0.070224 | Val Loss 0.450784
# Epoch 200 | Train Loss 0.046511 | Val Loss 0.428499
# Epoch 300 | Train Loss 0.037329 | Val Loss 0.509852
# Early stopping at epoch 361
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9830, R² diff = 0.9463
# y | ZZx2 -> R² = 0.9592, R² diff = 0.8927
# y | ZZxReto -> R² = -2.8165, R² diff = 0.3266
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.049105 | Val Loss 3.739079
# Epoch 100 | Train Loss 0.071206 | Val Loss 0.479107
# Epoch 200 | Train Loss 0.045643 | Val Loss 0.466536
# Epoch 300 | Train Loss 0.035874 | Val Loss 0.520235
# Early stopping at epoch 350
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9809, R² diff = 0.9432
# y | ZZx2 -> R² = 0.9655, R² diff = 0.8833
# y | ZZxReto -> R² = -3.0545, R² diff = 0.2986
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.143924 | Val Loss 4.139348
# Epoch 100 | Train Loss 0.068360 | Val Loss 0.482696
# Epoch 200 | Train Loss 0.043976 | Val Loss 0.480753
# Epoch 300 | Train Loss 0.036527 | Val Loss 0.519178
# Early stopping at epoch 350
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9836, R² diff = 0.9460
# y | ZZx2 -> R² = 0.9537, R² diff = 0.8811
# y | ZZxReto -> R² = -2.7291, R² diff = 0.3221
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.046587 | Val Loss 3.677611
# Epoch 100 | Train Loss 0.069265 | Val Loss 0.500048
# Epoch 200 | Train Loss 0.043492 | Val Loss 0.511492
# Epoch 300 | Train Loss 0.036405 | Val Loss 0.513050
# Early stopping at epoch 329
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed4434.keras
# y | ZZx1 -> R² = 0.9791, R² diff = 0.9396
# y | ZZx2 -> R² = 0.9656, R² diff = 0.8730
# y | ZZxReto -> R² = -3.3221, R² diff = 0.2646
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 1.109738 | Val Loss 3.876458
# Epoch 100 | Train Loss 0.072168 | Val Loss 0.507613
# Epoch 200 | Train Loss 0.046524 | Val Loss 0.456048
# Epoch 300 | Train Loss 0.036648 | Val Loss 0.528884
# Early stopping at epoch 379
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed2243.keras
# y | ZZx1 -> R² = 0.9853, R² diff = 0.9487
# y | ZZx2 -> R² = 0.9508, R² diff = 0.8827
# y | ZZxReto -> R² = -2.5210, R² diff = 0.3401
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 1.015093 | Val Loss 3.457075
# Epoch 100 | Train Loss 0.072746 | Val Loss 0.489769
# Epoch 200 | Train Loss 0.047439 | Val Loss 0.457920
# Epoch 300 | Train Loss 0.035671 | Val Loss 0.485119
# Early stopping at epoch 364
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed5613.keras
# y | ZZx1 -> R² = 0.9816, R² diff = 0.9428
# y | ZZx2 -> R² = 0.9662, R² diff = 0.8829
# y | ZZxReto -> R² = -3.1131, R² diff = 0.2926
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 1.084593 | Val Loss 3.813395
# Epoch 100 | Train Loss 0.071978 | Val Loss 0.481363
# Epoch 200 | Train Loss 0.045426 | Val Loss 0.408746
# Epoch 300 | Train Loss 0.031613 | Val Loss 0.442749
# Early stopping at epoch 398
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed7093.keras
# y | ZZx1 -> R² = 0.9860, R² diff = 0.9511
# y | ZZx2 -> R² = 0.9447, R² diff = 0.8926
# y | ZZxReto -> R² = -2.4051, R² diff = 0.3723
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.101105 | Val Loss 3.889865
# Epoch 100 | Train Loss 0.074932 | Val Loss 0.504975
# Epoch 200 | Train Loss 0.048218 | Val Loss 0.474175
# Epoch 300 | Train Loss 0.037526 | Val Loss 0.578244
# Early stopping at epoch 366
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed5756.keras
# y | ZZx1 -> R² = 0.9799, R² diff = 0.9410
# y | ZZx2 -> R² = 0.9666, R² diff = 0.8797
# y | ZZxReto -> R² = -3.1522, R² diff = 0.2808
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.060931 | Val Loss 3.757207
# Epoch 100 | Train Loss 0.063486 | Val Loss 0.471423
# Epoch 200 | Train Loss 0.040962 | Val Loss 0.499136
# Epoch 300 | Train Loss 0.034288 | Val Loss 0.524126
# Early stopping at epoch 343
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed4434.keras
# y | ZZx1 -> R² = 0.9826, R² diff = 0.9470
# y | ZZx2 -> R² = 0.9410, R² diff = 0.8802
# y | ZZxReto -> R² = -2.6232, R² diff = 0.3440
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.178701 | Val Loss 4.100404
# Epoch 100 | Train Loss 0.072908 | Val Loss 0.490051
# Epoch 200 | Train Loss 0.048594 | Val Loss 0.417604
# Epoch 300 | Train Loss 0.035866 | Val Loss 0.462911
# Early stopping at epoch 391
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed2243.keras
# y | ZZx1 -> R² = 0.9836, R² diff = 0.9474
# y | ZZx2 -> R² = 0.9575, R² diff = 0.8901
# y | ZZxReto -> R² = -2.7123, R² diff = 0.3414
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.134877 | Val Loss 3.872157
# Epoch 100 | Train Loss 0.071775 | Val Loss 0.505718
# Epoch 200 | Train Loss 0.047228 | Val Loss 0.452787
# Epoch 300 | Train Loss 0.037049 | Val Loss 0.505209
# Early stopping at epoch 377
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed5613.keras
# y | ZZx1 -> R² = 0.9831, R² diff = 0.9453
# y | ZZx2 -> R² = 0.9500, R² diff = 0.8813
# y | ZZxReto -> R² = -2.8717, R² diff = 0.3115
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.093012 | Val Loss 3.773489
# Epoch 100 | Train Loss 0.073263 | Val Loss 0.498624
# Epoch 200 | Train Loss 0.048460 | Val Loss 0.460605
# Epoch 300 | Train Loss 0.035187 | Val Loss 0.532049
# Early stopping at epoch 374
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed7093.keras
# y | ZZx1 -> R² = 0.9780, R² diff = 0.9427
# y | ZZx2 -> R² = 0.9531, R² diff = 0.8795
# y | ZZxReto -> R² = -3.2908, R² diff = 0.2878
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.076918 | Val Loss 3.896261
# Epoch 100 | Train Loss 0.071469 | Val Loss 0.467473
# Epoch 200 | Train Loss 0.045905 | Val Loss 0.451602
# Epoch 300 | Train Loss 0.036161 | Val Loss 0.536566
# Early stopping at epoch 358
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed5756.keras
# y | ZZx1 -> R² = 0.9805, R² diff = 0.9446
# y | ZZx2 -> R² = 0.9610, R² diff = 0.8882
# y | ZZxReto -> R² = -2.9478, R² diff = 0.3168
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.085196 | Val Loss 3.827281
# Epoch 100 | Train Loss 0.067696 | Val Loss 0.469897
# Epoch 200 | Train Loss 0.042902 | Val Loss 0.487062
# Epoch 300 | Train Loss 0.034868 | Val Loss 0.519546
# Early stopping at epoch 345
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed4434.keras
# y | ZZx1 -> R² = 0.9811, R² diff = 0.9440
# y | ZZx2 -> R² = 0.9506, R² diff = 0.8816
# y | ZZxReto -> R² = -2.9926, R² diff = 0.3044
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 1.047799 | Val Loss 3.727180
# Epoch 100 | Train Loss 0.067397 | Val Loss 0.463769
# Epoch 200 | Train Loss 0.043898 | Val Loss 0.459157
# Epoch 300 | Train Loss 0.035589 | Val Loss 0.506608
# Early stopping at epoch 354
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed2243.keras
# y | ZZx1 -> R² = 0.9828, R² diff = 0.9458
# y | ZZx2 -> R² = 0.9554, R² diff = 0.8857
# y | ZZxReto -> R² = -2.7518, R² diff = 0.3302
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 1.133359 | Val Loss 3.964367
# Epoch 100 | Train Loss 0.071623 | Val Loss 0.484441
# Epoch 200 | Train Loss 0.049713 | Val Loss 0.422937
# Epoch 300 | Train Loss 0.039159 | Val Loss 0.493610
# Early stopping at epoch 390
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed5613.keras
# y | ZZx1 -> R² = 0.9847, R² diff = 0.9484
# y | ZZx2 -> R² = 0.9516, R² diff = 0.8891
# y | ZZxReto -> R² = -2.5382, R² diff = 0.3471
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 1.071258 | Val Loss 3.812231
# Epoch 100 | Train Loss 0.071393 | Val Loss 0.499917
# Epoch 200 | Train Loss 0.046479 | Val Loss 0.460227
# Epoch 300 | Train Loss 0.035957 | Val Loss 0.521245
# Early stopping at epoch 375
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed7093.keras
# y | ZZx1 -> R² = 0.9825, R² diff = 0.9481
# y | ZZx2 -> R² = 0.9427, R² diff = 0.8805
# y | ZZxReto -> R² = -2.6533, R² diff = 0.3392
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.043280 | Val Loss 3.777399
# Epoch 100 | Train Loss 0.069394 | Val Loss 0.497619
# Epoch 200 | Train Loss 0.044237 | Val Loss 0.460331
# Epoch 300 | Train Loss 0.034114 | Val Loss 0.470185
# Early stopping at epoch 361
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed5756.keras
# y | ZZx1 -> R² = 0.9854, R² diff = 0.9488
# y | ZZx2 -> R² = 0.9500, R² diff = 0.8834
# y | ZZxReto -> R² = -2.4983, R² diff = 0.3433
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.032625 | Val Loss 3.738172
# Epoch 100 | Train Loss 0.065907 | Val Loss 0.456351
# Epoch 200 | Train Loss 0.043128 | Val Loss 0.465437
# Epoch 300 | Train Loss 0.033298 | Val Loss 0.470737
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed4434.keras
# y | ZZx1 -> R² = 0.9819, R² diff = 0.9473
# y | ZZx2 -> R² = 0.9485, R² diff = 0.8851
# y | ZZxReto -> R² = -2.7339, R² diff = 0.3348
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.027346 | Val Loss 3.698157
# Epoch 100 | Train Loss 0.069071 | Val Loss 0.451083
# Epoch 200 | Train Loss 0.046621 | Val Loss 0.434671
# Epoch 300 | Train Loss 0.035775 | Val Loss 0.498829
# Early stopping at epoch 353
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed2243.keras
# y | ZZx1 -> R² = 0.9813, R² diff = 0.9451
# y | ZZx2 -> R² = 0.9660, R² diff = 0.8911
# y | ZZxReto -> R² = -2.9486, R² diff = 0.3078
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.179451 | Val Loss 4.204655
# Epoch 100 | Train Loss 0.070428 | Val Loss 0.480648
# Epoch 200 | Train Loss 0.045870 | Val Loss 0.462872
# Epoch 300 | Train Loss 0.034422 | Val Loss 0.510151
# Early stopping at epoch 360
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed5613.keras
# y | ZZx1 -> R² = 0.9824, R² diff = 0.9455
# y | ZZx2 -> R² = 0.9615, R² diff = 0.8841
# y | ZZxReto -> R² = -2.8501, R² diff = 0.3182
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.148714 | Val Loss 4.008396
# Epoch 100 | Train Loss 0.073525 | Val Loss 0.501832
# Epoch 200 | Train Loss 0.050938 | Val Loss 0.459837
# Epoch 300 | Train Loss 0.038995 | Val Loss 0.516266
# Early stopping at epoch 379
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed7093.keras
# y | ZZx1 -> R² = 0.9820, R² diff = 0.9440
# y | ZZx2 -> R² = 0.9634, R² diff = 0.8806
# y | ZZxReto -> R² = -2.8810, R² diff = 0.3066
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.039726 | Val Loss 3.702411
# Epoch 100 | Train Loss 0.071383 | Val Loss 0.492211
# Epoch 200 | Train Loss 0.048177 | Val Loss 0.428870
# Epoch 300 | Train Loss 0.038174 | Val Loss 0.480095
# Early stopping at epoch 382
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed5756.keras
# y | ZZx1 -> R² = 0.9841, R² diff = 0.9485
# y | ZZx2 -> R² = 0.9556, R² diff = 0.8875
# y | ZZxReto -> R² = -2.6075, R² diff = 0.3396
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 0.974275 | Val Loss 3.498691
# Epoch 100 | Train Loss 0.065631 | Val Loss 0.481618
# Epoch 200 | Train Loss 0.043244 | Val Loss 0.510024
# Epoch 300 | Train Loss 0.034706 | Val Loss 0.499031
# Early stopping at epoch 339
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed4434.keras
# y | ZZx1 -> R² = 0.9818, R² diff = 0.9455
# y | ZZx2 -> R² = 0.9478, R² diff = 0.8761
# y | ZZxReto -> R² = -2.7748, R² diff = 0.3245
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 1.242695 | Val Loss 4.358041
# Epoch 100 | Train Loss 0.071504 | Val Loss 0.479838
# Epoch 200 | Train Loss 0.050115 | Val Loss 0.412023
# Epoch 300 | Train Loss 0.039238 | Val Loss 0.476846
# Early stopping at epoch 390
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed2243.keras
# y | ZZx1 -> R² = 0.9847, R² diff = 0.9480
# y | ZZx2 -> R² = 0.9637, R² diff = 0.8917
# y | ZZxReto -> R² = -2.6043, R² diff = 0.3353
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 0.993700 | Val Loss 3.492092
# Epoch 100 | Train Loss 0.068542 | Val Loss 0.479015
# Epoch 200 | Train Loss 0.042746 | Val Loss 0.494001
# Epoch 300 | Train Loss 0.034137 | Val Loss 0.510552
# Early stopping at epoch 347
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9836, R² diff = 0.9458
# y | ZZx2 -> R² = 0.9562, R² diff = 0.8817
# y | ZZxReto -> R² = -2.7647, R² diff = 0.3209
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 1.154580 | Val Loss 4.014033
# Epoch 100 | Train Loss 0.068303 | Val Loss 0.472503
# Epoch 200 | Train Loss 0.045502 | Val Loss 0.463587
# Epoch 300 | Train Loss 0.036182 | Val Loss 0.507773
# Early stopping at epoch 352
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9823, R² diff = 0.9451
# y | ZZx2 -> R² = 0.9594, R² diff = 0.8830
# y | ZZxReto -> R² = -2.9514, R² diff = 0.3044
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.139428 | Val Loss 4.002221
# Epoch 100 | Train Loss 0.073517 | Val Loss 0.501398
# Epoch 200 | Train Loss 0.050968 | Val Loss 0.448177
# Epoch 300 | Train Loss 0.038948 | Val Loss 0.530261
# Early stopping at epoch 383
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9819, R² diff = 0.9442
# y | ZZx2 -> R² = 0.9598, R² diff = 0.8827
# y | ZZxReto -> R² = -2.9602, R² diff = 0.3029
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.109461 | Val Loss 3.840371
# Epoch 100 | Train Loss 0.070945 | Val Loss 0.496005
# Epoch 200 | Train Loss 0.045568 | Val Loss 0.477095
# Epoch 300 | Train Loss 0.036371 | Val Loss 0.535733
# Early stopping at epoch 364
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed4434.keras
# y | ZZx1 -> R² = 0.9837, R² diff = 0.9454
# y | ZZx2 -> R² = 0.9553, R² diff = 0.8785
# y | ZZxReto -> R² = -2.7852, R² diff = 0.3190
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.239634 | Val Loss 4.233105
# Epoch 100 | Train Loss 0.072274 | Val Loss 0.486923
# Epoch 200 | Train Loss 0.047787 | Val Loss 0.478196
# Epoch 300 | Train Loss 0.038590 | Val Loss 0.558335
# Early stopping at epoch 360
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed2243.keras
# y | ZZx1 -> R² = 0.9808, R² diff = 0.9421
# y | ZZx2 -> R² = 0.9627, R² diff = 0.8809
# y | ZZxReto -> R² = -3.0635, R² diff = 0.2933
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.089101 | Val Loss 3.706155
# Epoch 100 | Train Loss 0.072184 | Val Loss 0.505173
# Epoch 200 | Train Loss 0.047804 | Val Loss 0.465810
# Epoch 300 | Train Loss 0.037607 | Val Loss 0.527142
# Early stopping at epoch 368
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9823, R² diff = 0.9443
# y | ZZx2 -> R² = 0.9629, R² diff = 0.8802
# y | ZZxReto -> R² = -2.9310, R² diff = 0.2988
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.135177 | Val Loss 4.001231
# Epoch 100 | Train Loss 0.071978 | Val Loss 0.501697
# Epoch 200 | Train Loss 0.046676 | Val Loss 0.476059
# Epoch 300 | Train Loss 0.037225 | Val Loss 0.527846
# Early stopping at epoch 357
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9807, R² diff = 0.9433
# y | ZZx2 -> R² = 0.9552, R² diff = 0.8785
# y | ZZxReto -> R² = -3.0918, R² diff = 0.2937
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.134134 | Val Loss 4.046819
# Epoch 100 | Train Loss 0.068916 | Val Loss 0.470095
# Epoch 200 | Train Loss 0.044558 | Val Loss 0.460734
# Epoch 300 | Train Loss 0.036677 | Val Loss 0.511066
# Early stopping at epoch 354
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9832, R² diff = 0.9468
# y | ZZx2 -> R² = 0.9566, R² diff = 0.8853
# y | ZZxReto -> R² = -2.7245, R² diff = 0.3317
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.022555 | Val Loss 3.578882
# Epoch 100 | Train Loss 0.067748 | Val Loss 0.462294
# Epoch 200 | Train Loss 0.045143 | Val Loss 0.463259
# Epoch 300 | Train Loss 0.036984 | Val Loss 0.526965
# Early stopping at epoch 355
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed4434.keras
# y | ZZx1 -> R² = 0.9819, R² diff = 0.9458
# y | ZZx2 -> R² = 0.9551, R² diff = 0.8863
# y | ZZxReto -> R² = -2.8603, R² diff = 0.3200
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 1.061059 | Val Loss 3.758660
# Epoch 100 | Train Loss 0.069305 | Val Loss 0.488413
# Epoch 200 | Train Loss 0.044707 | Val Loss 0.482318
# Epoch 300 | Train Loss 0.035235 | Val Loss 0.516223
# Early stopping at epoch 351
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed2243.keras
# y | ZZx1 -> R² = 0.9807, R² diff = 0.9437
# y | ZZx2 -> R² = 0.9562, R² diff = 0.8782
# y | ZZxReto -> R² = -3.1069, R² diff = 0.2929
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 1.008746 | Val Loss 3.435496
# Epoch 100 | Train Loss 0.071616 | Val Loss 0.479246
# Epoch 200 | Train Loss 0.045576 | Val Loss 0.454298
# Epoch 300 | Train Loss 0.035809 | Val Loss 0.508596
# Early stopping at epoch 361
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed5613.keras
# y | ZZx1 -> R² = 0.9833, R² diff = 0.9445
# y | ZZx2 -> R² = 0.9654, R² diff = 0.8859
# y | ZZxReto -> R² = -2.8712, R² diff = 0.3087
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 0.939168 | Val Loss 3.288295
# Epoch 100 | Train Loss 0.068314 | Val Loss 0.490043
# Epoch 200 | Train Loss 0.040960 | Val Loss 0.528030
# Epoch 300 | Train Loss 0.032213 | Val Loss 0.511804
# Early stopping at epoch 336
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed7093.keras
# y | ZZx1 -> R² = 0.9813, R² diff = 0.9419
# y | ZZx2 -> R² = 0.9588, R² diff = 0.8755
# y | ZZxReto -> R² = -3.1714, R² diff = 0.2863
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.116954 | Val Loss 3.907910
# Epoch 100 | Train Loss 0.073104 | Val Loss 0.487637
# Epoch 200 | Train Loss 0.047699 | Val Loss 0.445620
# Epoch 300 | Train Loss 0.037675 | Val Loss 0.547123
# Early stopping at epoch 376
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed5756.keras
# y | ZZx1 -> R² = 0.9836, R² diff = 0.9455
# y | ZZx2 -> R² = 0.9559, R² diff = 0.8857
# y | ZZxReto -> R² = -2.7467, R² diff = 0.3210
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 0.946548 | Val Loss 3.238211
# Epoch 100 | Train Loss 0.068478 | Val Loss 0.471454
# Epoch 200 | Train Loss 0.042973 | Val Loss 0.508979
# Epoch 300 | Train Loss 0.035483 | Val Loss 0.506196
# Early stopping at epoch 318
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed4434.keras
# y | ZZx1 -> R² = 0.9768, R² diff = 0.9361
# y | ZZx2 -> R² = 0.9783, R² diff = 0.8794
# y | ZZxReto -> R² = -3.6421, R² diff = 0.2298
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.092760 | Val Loss 3.858691
# Epoch 100 | Train Loss 0.070469 | Val Loss 0.478187
# Epoch 200 | Train Loss 0.045258 | Val Loss 0.470844
# Epoch 300 | Train Loss 0.034767 | Val Loss 0.536377
# Early stopping at epoch 357
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed2243.keras
# y | ZZx1 -> R² = 0.9798, R² diff = 0.9427
# y | ZZx2 -> R² = 0.9568, R² diff = 0.8823
# y | ZZxReto -> R² = -3.1387, R² diff = 0.3008
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.068965 | Val Loss 3.660461
# Epoch 100 | Train Loss 0.070410 | Val Loss 0.503983
# Epoch 200 | Train Loss 0.044604 | Val Loss 0.513097
# Epoch 300 | Train Loss 0.035529 | Val Loss 0.508256
# Early stopping at epoch 345
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed5613.keras
# y | ZZx1 -> R² = 0.9807, R² diff = 0.9413
# y | ZZx2 -> R² = 0.9635, R² diff = 0.8726
# y | ZZxReto -> R² = -3.1747, R² diff = 0.2793
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.141631 | Val Loss 3.825103
# Epoch 100 | Train Loss 0.072560 | Val Loss 0.502464
# Epoch 200 | Train Loss 0.048016 | Val Loss 0.455831
# Epoch 300 | Train Loss 0.036682 | Val Loss 0.545914
# Early stopping at epoch 375
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed7093.keras
# y | ZZx1 -> R² = 0.9839, R² diff = 0.9449
# y | ZZx2 -> R² = 0.9615, R² diff = 0.8830
# y | ZZxReto -> R² = -2.8076, R² diff = 0.3125
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.193108 | Val Loss 4.122756
# Epoch 100 | Train Loss 0.073311 | Val Loss 0.509149
# Epoch 200 | Train Loss 0.048626 | Val Loss 0.460550
# Epoch 300 | Train Loss 0.037308 | Val Loss 0.519967
# Early stopping at epoch 383
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed5756.keras
# y | ZZx1 -> R² = 0.9823, R² diff = 0.9449
# y | ZZx2 -> R² = 0.9474, R² diff = 0.8792
# y | ZZxReto -> R² = -2.9067, R² diff = 0.3132
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.140386 | Val Loss 3.886587
# Epoch 100 | Train Loss 0.069637 | Val Loss 0.466087
# Epoch 200 | Train Loss 0.046803 | Val Loss 0.446938
# Epoch 300 | Train Loss 0.036819 | Val Loss 0.492909
# Early stopping at epoch 358
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed4434.keras
# y | ZZx1 -> R² = 0.9800, R² diff = 0.9428
# y | ZZx2 -> R² = 0.9648, R² diff = 0.8848
# y | ZZxReto -> R² = -3.1856, R² diff = 0.2868
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 1.141783 | Val Loss 3.973586
# Epoch 100 | Train Loss 0.068680 | Val Loss 0.494291
# Epoch 200 | Train Loss 0.044547 | Val Loss 0.475819
# Epoch 300 | Train Loss 0.035634 | Val Loss 0.510409
# Early stopping at epoch 357
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed2243.keras
# y | ZZx1 -> R² = 0.9823, R² diff = 0.9446
# y | ZZx2 -> R² = 0.9523, R² diff = 0.8773
# y | ZZxReto -> R² = -2.8456, R² diff = 0.3143
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 1.135942 | Val Loss 3.825724
# Epoch 100 | Train Loss 0.073761 | Val Loss 0.493075
# Epoch 200 | Train Loss 0.051280 | Val Loss 0.434980
# Epoch 300 | Train Loss 0.039132 | Val Loss 0.510031
# Early stopping at epoch 384
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.7_Lp0.3_seed5613.keras
# y | ZZx1 -> R² = 0.9825, R² diff = 0.9448
# y | ZZx2 -> R² = 0.9689, R² diff = 0.8868
# y | ZZxReto -> R² = -2.8316, R² diff = 0.3093
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 1.010528 | Val Loss 3.475030
# Epoch 100 | Train Loss 0.070083 | Val Loss 0.502347
# Epoch 200 | Train Loss 0.045064 | Val Loss 0.534097
# Epoch 300 | Train Loss 0.037801 | Val Loss 0.558276
# Early stopping at epoch 343
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.7_Lp0.3_seed7093.keras
# y | ZZx1 -> R² = 0.9804, R² diff = 0.9414
# y | ZZx2 -> R² = 0.9672, R² diff = 0.8731
# y | ZZxReto -> R² = -3.1139, R² diff = 0.2761
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.187937 | Val Loss 4.078342
# Epoch 100 | Train Loss 0.075714 | Val Loss 0.517123
# Epoch 200 | Train Loss 0.061536 | Val Loss 0.460231
# Epoch 300 | Train Loss 0.040769 | Val Loss 0.490815
# Epoch 400 | Train Loss 0.033619 | Val Loss 0.487383
# Early stopping at epoch 419
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.7_Lp0.3_seed5756.keras
# y | ZZx1 -> R² = 0.9803, R² diff = 0.9439
# y | ZZx2 -> R² = 0.9597, R² diff = 0.8810
# y | ZZxReto -> R² = -3.1060, R² diff = 0.2926
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.018724 | Val Loss 3.583258
# Epoch 100 | Train Loss 0.067227 | Val Loss 0.463615
# Epoch 200 | Train Loss 0.044708 | Val Loss 0.464278
# Epoch 300 | Train Loss 0.036102 | Val Loss 0.479760
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.7_Lp0.3_seed4434.keras
# y | ZZx1 -> R² = 0.9810, R² diff = 0.9454
# y | ZZx2 -> R² = 0.9612, R² diff = 0.8843
# y | ZZxReto -> R² = -2.8873, R² diff = 0.3132
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.175723 | Val Loss 4.226583
# Epoch 100 | Train Loss 0.070252 | Val Loss 0.485021
# Epoch 200 | Train Loss 0.046319 | Val Loss 0.437555
# Epoch 300 | Train Loss 0.036781 | Val Loss 0.471649
# Early stopping at epoch 379
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.7_Lp0.3_seed2243.keras
# y | ZZx1 -> R² = 0.9839, R² diff = 0.9498
# y | ZZx2 -> R² = 0.9413, R² diff = 0.8866
# y | ZZxReto -> R² = -2.6029, R² diff = 0.3477
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.081666 | Val Loss 3.744934
# Epoch 100 | Train Loss 0.073076 | Val Loss 0.485747
# Epoch 200 | Train Loss 0.052225 | Val Loss 0.427020
# Epoch 300 | Train Loss 0.040494 | Val Loss 0.486135
# Early stopping at epoch 384
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.7_Lp0.3_seed5613.keras
# y | ZZx1 -> R² = 0.9811, R² diff = 0.9444
# y | ZZx2 -> R² = 0.9669, R² diff = 0.8877
# y | ZZxReto -> R² = -2.9693, R² diff = 0.3072
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.049423 | Val Loss 3.700765
# Epoch 100 | Train Loss 0.067524 | Val Loss 0.474652
# Epoch 200 | Train Loss 0.045242 | Val Loss 0.470767
# Epoch 300 | Train Loss 0.037612 | Val Loss 0.526423
# Early stopping at epoch 349
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.7_Lp0.3_seed7093.keras
# y | ZZx1 -> R² = 0.9830, R² diff = 0.9463
# y | ZZx2 -> R² = 0.9617, R² diff = 0.8828
# y | ZZxReto -> R² = -2.6828, R² diff = 0.3249
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.136641 | Val Loss 3.999051
# Epoch 100 | Train Loss 0.071917 | Val Loss 0.484877
# Epoch 200 | Train Loss 0.049072 | Val Loss 0.429251
# Epoch 300 | Train Loss 0.038602 | Val Loss 0.494901
# Early stopping at epoch 384
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.7_Lp0.3_seed5756.keras
# y | ZZx1 -> R² = 0.9836, R² diff = 0.9476
# y | ZZx2 -> R² = 0.9563, R² diff = 0.8878
# y | ZZxReto -> R² = -2.7254, R² diff = 0.3289
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.019421 | Val Loss 3.568518
# Epoch 100 | Train Loss 0.069004 | Val Loss 0.460846
# Epoch 200 | Train Loss 0.046117 | Val Loss 0.457785
# Epoch 300 | Train Loss 0.036131 | Val Loss 0.525425
# Early stopping at epoch 353
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.7_Lp0.3_seed4434.keras
# y | ZZx1 -> R² = 0.9809, R² diff = 0.9442
# y | ZZx2 -> R² = 0.9686, R² diff = 0.8868
# y | ZZxReto -> R² = -3.0731, R² diff = 0.2939
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 1.096431 | Val Loss 3.833110
# Epoch 100 | Train Loss 0.071867 | Val Loss 0.502547
# Epoch 200 | Train Loss 0.047848 | Val Loss 0.482476
# Epoch 300 | Train Loss 0.038295 | Val Loss 0.567543
# Early stopping at epoch 359
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.7_Lp0.3_seed2243.keras
# y | ZZx1 -> R² = 0.9817, R² diff = 0.9432
# y | ZZx2 -> R² = 0.9641, R² diff = 0.8787
# y | ZZxReto -> R² = -2.9571, R² diff = 0.2922
# Modelo [83] | Ld=0.7 Lp=0.3 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 1.218309 | Val Loss 4.289154
# Epoch 100 | Train Loss 0.071663 | Val Loss 0.496953
# Epoch 200 | Train Loss 0.047645 | Val Loss 0.455106
# Epoch 300 | Train Loss 0.036763 | Val Loss 0.521774
# Early stopping at epoch 378
# Modelo salvo em:
# models/model_arch84_r0.01_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9829, R² diff = 0.9468
# y | ZZx2 -> R² = 0.9549, R² diff = 0.8818
# y | ZZxReto -> R² = -2.7834, R² diff = 0.3189
# Modelo [84] | Ld=0.5 Lp=0.5 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 1.241998 | Val Loss 4.327451
# Epoch 100 | Train Loss 0.072121 | Val Loss 0.494600
# Epoch 200 | Train Loss 0.047373 | Val Loss 0.492967
# Epoch 300 | Train Loss 0.037587 | Val Loss 0.526761
# Early stopping at epoch 351
# Modelo salvo em:
# models/model_arch84_r0.01_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9776, R² diff = 0.9394
# y | ZZx2 -> R² = 0.9690, R² diff = 0.8774
# y | ZZxReto -> R² = -3.4864, R² diff = 0.2529
# Modelo [84] | Ld=0.5 Lp=0.5 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.128058 | Val Loss 3.891478
# Epoch 100 | Train Loss 0.071528 | Val Loss 0.521588
# Epoch 200 | Train Loss 0.048750 | Val Loss 0.469846
# Epoch 300 | Train Loss 0.038944 | Val Loss 0.530155
# Early stopping at epoch 380
# Modelo salvo em:
# models/model_arch84_r0.01_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9825, R² diff = 0.9465
# y | ZZx2 -> R² = 0.9520, R² diff = 0.8773
# y | ZZxReto -> R² = -2.7528, R² diff = 0.3179
# Modelo [84] | Ld=0.5 Lp=0.5 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.081051 | Val Loss 3.793192
# Epoch 100 | Train Loss 0.067683 | Val Loss 0.467201
# Epoch 200 | Train Loss 0.043320 | Val Loss 0.521026
# Epoch 300 | Train Loss 0.036171 | Val Loss 0.547086
# Early stopping at epoch 326
# Modelo salvo em:
# models/model_arch84_r0.01_Ld0.5_Lp0.5_seed4434.keras
# y | ZZx1 -> R² = 0.9790, R² diff = 0.9408
# y | ZZx2 -> R² = 0.9732, R² diff = 0.8813
# y | ZZxReto -> R² = -3.2807, R² diff = 0.2687
# Modelo [84] | Ld=0.5 Lp=0.5 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.042210 | Val Loss 3.678997
# Epoch 100 | Train Loss 0.070798 | Val Loss 0.479447
# Epoch 200 | Train Loss 0.044381 | Val Loss 0.465721
# Epoch 300 | Train Loss 0.036044 | Val Loss 0.501513
# Early stopping at epoch 362
# Modelo salvo em:
# models/model_arch84_r0.01_Ld0.5_Lp0.5_seed2243.keras
# y | ZZx1 -> R² = 0.9829, R² diff = 0.9477
# y | ZZx2 -> R² = 0.9493, R² diff = 0.8850
# y | ZZxReto -> R² = -2.6939, R² diff = 0.3376
# Modelo [84] | Ld=0.5 Lp=0.5 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.165154 | Val Loss 4.088051
# Epoch 100 | Train Loss 0.071031 | Val Loss 0.477631
# Epoch 200 | Train Loss 0.046144 | Val Loss 0.468851
# Epoch 300 | Train Loss 0.036763 | Val Loss 0.518733
# Early stopping at epoch 358
# Modelo salvo em:
# models/model_arch84_r0.9_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9808, R² diff = 0.9443
# y | ZZx2 -> R² = 0.9541, R² diff = 0.8824
# y | ZZxReto -> R² = -3.0140, R² diff = 0.3085
# Modelo [84] | Ld=0.5 Lp=0.5 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.131065 | Val Loss 3.956476
# Epoch 100 | Train Loss 0.069051 | Val Loss 0.464810
# Epoch 200 | Train Loss 0.046674 | Val Loss 0.472309
# Epoch 300 | Train Loss 0.036935 | Val Loss 0.548305
# Early stopping at epoch 346
# Modelo salvo em:
# models/model_arch84_r0.9_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9790, R² diff = 0.9413
# y | ZZx2 -> R² = 0.9696, R² diff = 0.8830
# y | ZZxReto -> R² = -3.3124, R² diff = 0.2692
# Modelo [84] | Ld=0.5 Lp=0.5 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.178114 | Val Loss 4.129685
# Epoch 100 | Train Loss 0.070968 | Val Loss 0.505031
# Epoch 200 | Train Loss 0.045027 | Val Loss 0.476201
# Epoch 300 | Train Loss 0.036248 | Val Loss 0.523054
# Early stopping at epoch 365
# Modelo salvo em:
# models/model_arch84_r0.9_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9846, R² diff = 0.9468
# y | ZZx2 -> R² = 0.9452, R² diff = 0.8787
# y | ZZxReto -> R² = -2.6886, R² diff = 0.3311
# Modelo [84] | Ld=0.5 Lp=0.5 r=0.9 seed=5756 salvo.
# ...
# Epoch 300 | Train Loss 0.033983 | Val Loss 0.496731
# Early stopping at epoch 359
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9827, R² diff = 0.9460
# y | ZZx2 -> R² = 0.9590, R² diff = 0.8905
# y | ZZxReto -> R² = -2.8726, R² diff = 0.3229
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 1.205459 | Val Loss 4.287612
# Epoch 100 | Train Loss 0.068575 | Val Loss 0.455720
# Epoch 200 | Train Loss 0.044799 | Val Loss 0.449234
# Epoch 300 | Train Loss 0.034099 | Val Loss 0.497326
# Early stopping at epoch 362
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9812, R² diff = 0.9469
# y | ZZx2 -> R² = 0.9424, R² diff = 0.8869
# y | ZZxReto -> R² = -2.8449, R² diff = 0.3316
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.040655 | Val Loss 3.639260
# Epoch 100 | Train Loss 0.070857 | Val Loss 0.458042
# Epoch 200 | Train Loss 0.046197 | Val Loss 0.456607
# Epoch 300 | Train Loss 0.036469 | Val Loss 0.505872
# Early stopping at epoch 353
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9802, R² diff = 0.9430
# y | ZZx2 -> R² = 0.9713, R² diff = 0.8879
# y | ZZxReto -> R² = -3.1636, R² diff = 0.2892
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.193179 | Val Loss 3.928801
# Epoch 100 | Train Loss 0.070763 | Val Loss 0.473628
# Epoch 200 | Train Loss 0.046279 | Val Loss 0.474200
# Epoch 300 | Train Loss 0.036120 | Val Loss 0.524510
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed4434.keras
# y | ZZx1 -> R² = 0.9793, R² diff = 0.9408
# y | ZZx2 -> R² = 0.9741, R² diff = 0.8823
# y | ZZxReto -> R² = -3.3693, R² diff = 0.2644
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 0.869785 | Val Loss 3.002161
# Epoch 100 | Train Loss 0.069280 | Val Loss 0.472547
# Epoch 200 | Train Loss 0.042361 | Val Loss 0.460408
# Epoch 300 | Train Loss 0.034557 | Val Loss 0.514940
# Early stopping at epoch 355
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed2243.keras
# y | ZZx1 -> R² = 0.9840, R² diff = 0.9475
# y | ZZx2 -> R² = 0.9538, R² diff = 0.8877
# y | ZZxReto -> R² = -2.6968, R² diff = 0.3358
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.001327 | Val Loss 3.448856
# Epoch 100 | Train Loss 0.071648 | Val Loss 0.463764
# Epoch 200 | Train Loss 0.044365 | Val Loss 0.413086
# Epoch 300 | Train Loss 0.034684 | Val Loss 0.479032
# Early stopping at epoch 369
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed5613.keras
# y | ZZx1 -> R² = 0.9861, R² diff = 0.9485
# y | ZZx2 -> R² = 0.9596, R² diff = 0.8950
# y | ZZxReto -> R² = -2.5356, R² diff = 0.3498
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.099962 | Val Loss 3.773086
# Epoch 100 | Train Loss 0.072885 | Val Loss 0.469839
# Epoch 200 | Train Loss 0.046599 | Val Loss 0.469245
# Epoch 300 | Train Loss 0.035912 | Val Loss 0.516131
# Early stopping at epoch 354
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed7093.keras
# y | ZZx1 -> R² = 0.9785, R² diff = 0.9404
# y | ZZx2 -> R² = 0.9764, R² diff = 0.8862
# y | ZZxReto -> R² = -3.3995, R² diff = 0.2583
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.072040 | Val Loss 3.570147
# Epoch 100 | Train Loss 0.073978 | Val Loss 0.495099
# Epoch 200 | Train Loss 0.050904 | Val Loss 0.437779
# Epoch 300 | Train Loss 0.036555 | Val Loss 0.526975
# Early stopping at epoch 380
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed5756.keras
# y | ZZx1 -> R² = 0.9799, R² diff = 0.9431
# y | ZZx2 -> R² = 0.9704, R² diff = 0.8853
# y | ZZxReto -> R² = -3.2696, R² diff = 0.2787
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.109023 | Val Loss 3.627568
# Epoch 100 | Train Loss 0.069805 | Val Loss 0.465001
# Epoch 200 | Train Loss 0.048893 | Val Loss 0.426464
# Epoch 300 | Train Loss 0.037192 | Val Loss 0.500057
# Early stopping at epoch 378
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed4434.keras
# y | ZZx1 -> R² = 0.9814, R² diff = 0.9455
# y | ZZx2 -> R² = 0.9638, R² diff = 0.8892
# y | ZZxReto -> R² = -2.9848, R² diff = 0.3108
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 0.975547 | Val Loss 3.333789
# Epoch 100 | Train Loss 0.068015 | Val Loss 0.493662
# Epoch 200 | Train Loss 0.042300 | Val Loss 0.544780
# Epoch 300 | Train Loss 0.035284 | Val Loss 0.494363
# Epoch 400 | Train Loss 0.028389 | Val Loss 0.422440
# Epoch 500 | Train Loss 0.019880 | Val Loss 0.355028
# Epoch 600 | Train Loss 0.015880 | Val Loss 0.302884
# Epoch 700 | Train Loss 0.014624 | Val Loss 0.326046
# Early stopping at epoch 776
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed2243.keras
# y | ZZx1 -> R² = 0.9992, R² diff = 0.9831
# y | ZZx2 -> R² = 0.9344, R² diff = 0.9207
# y | ZZxReto -> R² = 0.5595, R² diff = 0.6509
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 1.155937 | Val Loss 3.976863
# Epoch 100 | Train Loss 0.068323 | Val Loss 0.467520
# Epoch 200 | Train Loss 0.040888 | Val Loss 0.495964
# Epoch 300 | Train Loss 0.032214 | Val Loss 0.486674
# Early stopping at epoch 328
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed5613.keras
# y | ZZx1 -> R² = 0.9792, R² diff = 0.9398
# y | ZZx2 -> R² = 0.9715, R² diff = 0.8813
# y | ZZxReto -> R² = -3.4547, R² diff = 0.2634
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 1.310272 | Val Loss 4.352141
# Epoch 100 | Train Loss 0.070744 | Val Loss 0.470242
# Epoch 200 | Train Loss 0.045905 | Val Loss 0.465571
# Epoch 300 | Train Loss 0.036199 | Val Loss 0.527998
# Early stopping at epoch 346
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed7093.keras
# y | ZZx1 -> R² = 0.9792, R² diff = 0.9404
# y | ZZx2 -> R² = 0.9747, R² diff = 0.8845
# y | ZZxReto -> R² = -3.3188, R² diff = 0.2701
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 1.102808 | Val Loss 3.660575
# Epoch 100 | Train Loss 0.072202 | Val Loss 0.484056
# Epoch 200 | Train Loss 0.046245 | Val Loss 0.486378
# Epoch 300 | Train Loss 0.035056 | Val Loss 0.556226
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed5756.keras
# y | ZZx1 -> R² = 0.9789, R² diff = 0.9390
# y | ZZx2 -> R² = 0.9765, R² diff = 0.8811
# y | ZZxReto -> R² = -3.4649, R² diff = 0.2539
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 0.915808 | Val Loss 3.002643
# Epoch 100 | Train Loss 0.069817 | Val Loss 0.478341
# Epoch 200 | Train Loss 0.044744 | Val Loss 0.480658
# Epoch 300 | Train Loss 0.034427 | Val Loss 0.537202
# Early stopping at epoch 344
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed4434.keras
# y | ZZx1 -> R² = 0.9770, R² diff = 0.9393
# y | ZZx2 -> R² = 0.9727, R² diff = 0.8801
# y | ZZxReto -> R² = -3.5942, R² diff = 0.2476
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 1.060861 | Val Loss 3.603692
# Epoch 100 | Train Loss 0.068895 | Val Loss 0.472905
# Epoch 200 | Train Loss 0.043807 | Val Loss 0.457085
# Epoch 300 | Train Loss 0.034601 | Val Loss 0.524260
# Early stopping at epoch 353
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed2243.keras
# y | ZZx1 -> R² = 0.9818, R² diff = 0.9446
# y | ZZx2 -> R² = 0.9550, R² diff = 0.8856
# y | ZZxReto -> R² = -2.9546, R² diff = 0.3149
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 1.025511 | Val Loss 3.587371
# Epoch 100 | Train Loss 0.065991 | Val Loss 0.480991
# Epoch 200 | Train Loss 0.039010 | Val Loss 0.489032
# Epoch 300 | Train Loss 0.026939 | Val Loss 0.443495
# Epoch 400 | Train Loss 0.017297 | Val Loss 0.419622
# Epoch 500 | Train Loss 0.014926 | Val Loss 0.440495
# Epoch 600 | Train Loss 0.014056 | Val Loss 0.454188
# Early stopping at epoch 611
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed5613.keras
# y | ZZx1 -> R² = 0.9984, R² diff = 0.9804
# y | ZZx2 -> R² = 0.8628, R² diff = 0.8902
# y | ZZxReto -> R² = 0.3019, R² diff = 0.6536
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.294614 | Val Loss 4.565787
# Epoch 100 | Train Loss 0.068317 | Val Loss 0.453546
# Epoch 200 | Train Loss 0.042749 | Val Loss 0.461761
# Epoch 300 | Train Loss 0.034065 | Val Loss 0.489170
# Early stopping at epoch 351
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed7093.keras
# y | ZZx1 -> R² = 0.9809, R² diff = 0.9450
# y | ZZx2 -> R² = 0.9424, R² diff = 0.8860
# y | ZZxReto -> R² = -2.9283, R² diff = 0.3273
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 0.983094 | Val Loss 3.394022
# Epoch 100 | Train Loss 0.071440 | Val Loss 0.474316
# Epoch 200 | Train Loss 0.044780 | Val Loss 0.481211
# Epoch 300 | Train Loss 0.035268 | Val Loss 0.509430
# Early stopping at epoch 334
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed5756.keras
# y | ZZx1 -> R² = 0.9763, R² diff = 0.9368
# y | ZZx2 -> R² = 0.9809, R² diff = 0.8819
# y | ZZxReto -> R² = -3.7263, R² diff = 0.2263
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.124006 | Val Loss 3.606220
# Epoch 100 | Train Loss 0.069987 | Val Loss 0.469407
# Epoch 200 | Train Loss 0.044268 | Val Loss 0.473652
# Epoch 300 | Train Loss 0.035663 | Val Loss 0.524336
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed4434.keras
# y | ZZx1 -> R² = 0.9806, R² diff = 0.9422
# y | ZZx2 -> R² = 0.9689, R² diff = 0.8860
# y | ZZxReto -> R² = -3.2138, R² diff = 0.2803
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 0.936435 | Val Loss 3.220133
# Epoch 100 | Train Loss 0.067081 | Val Loss 0.485053
# Epoch 200 | Train Loss 0.041247 | Val Loss 0.501809
# Epoch 300 | Train Loss 0.033814 | Val Loss 0.521600
# Early stopping at epoch 339
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed2243.keras
# y | ZZx1 -> R² = 0.9815, R² diff = 0.9440
# y | ZZx2 -> R² = 0.9532, R² diff = 0.8790
# y | ZZxReto -> R² = -3.0157, R² diff = 0.3067
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=2243 salvo.
# Epoch 0 | Train Loss 0.898889 | Val Loss 3.082790
# Epoch 100 | Train Loss 0.071531 | Val Loss 0.468349
# Epoch 200 | Train Loss 0.044153 | Val Loss 0.486467
# Epoch 300 | Train Loss 0.033789 | Val Loss 0.478611
# Epoch 400 | Train Loss 0.023457 | Val Loss 0.391345
# Epoch 500 | Train Loss 0.016401 | Val Loss 0.313377
# Epoch 600 | Train Loss 0.015303 | Val Loss 0.299175
# Epoch 700 | Train Loss 0.014515 | Val Loss 0.272485
# Epoch 800 | Train Loss 0.013881 | Val Loss 0.251214
# Epoch 900 | Train Loss 0.013349 | Val Loss 0.237982
# Epoch 1000 | Train Loss 0.012869 | Val Loss 0.226863
# Epoch 1100 | Train Loss 0.012414 | Val Loss 0.220625
# Epoch 1200 | Train Loss 0.011990 | Val Loss 0.218261
# Epoch 1300 | Train Loss 0.011478 | Val Loss 0.220625
# Epoch 1400 | Train Loss 0.011148 | Val Loss 0.223180
# Early stopping at epoch 1402
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed5613.keras
# y | ZZx1 -> R² = 0.9937, R² diff = 0.9886
# y | ZZx2 -> R² = 0.9921, R² diff = 0.9429
# y | ZZxReto -> R² = 0.6597, R² diff = 0.7410
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=5613 salvo.
# Epoch 0 | Train Loss 1.174449 | Val Loss 4.058371
# Epoch 100 | Train Loss 0.071824 | Val Loss 0.444877
# Epoch 200 | Train Loss 0.048081 | Val Loss 0.414987
# Epoch 300 | Train Loss 0.037271 | Val Loss 0.529719
# Early stopping at epoch 361
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed7093.keras
# y | ZZx1 -> R² = 0.9816, R² diff = 0.9441
# y | ZZx2 -> R² = 0.9803, R² diff = 0.8971
# y | ZZxReto -> R² = -3.0166, R² diff = 0.2985
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=7093 salvo.
# Epoch 0 | Train Loss 0.934844 | Val Loss 3.263437
# Epoch 100 | Train Loss 0.068841 | Val Loss 0.451537
# Epoch 200 | Train Loss 0.044440 | Val Loss 0.490878
# Epoch 300 | Train Loss 0.034802 | Val Loss 0.516996
# Early stopping at epoch 334
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed5756.keras
# y | ZZx1 -> R² = 0.9775, R² diff = 0.9406
# y | ZZx2 -> R² = 0.9768, R² diff = 0.8865
# y | ZZxReto -> R² = -3.4033, R² diff = 0.2628
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=5756 salvo.
# Epoch 0 | Train Loss 1.019568 | Val Loss 3.457471
# Epoch 100 | Train Loss 0.069466 | Val Loss 0.469218
# Epoch 200 | Train Loss 0.046281 | Val Loss 0.430401
# Epoch 300 | Train Loss 0.036318 | Val Loss 0.514194
# Early stopping at epoch 369
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed4434.keras
# y | ZZx1 -> R² = 0.9835, R² diff = 0.9474
# y | ZZx2 -> R² = 0.9654, R² diff = 0.8903
# y | ZZxReto -> R² = -2.7957, R² diff = 0.3256
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=4434 salvo.
# Epoch 0 | Train Loss 0.977990 | Val Loss 3.345280
# Epoch 100 | Train Loss 0.065488 | Val Loss 0.464934
# Epoch 200 | Train Loss 0.041533 | Val Loss 0.556922
# Epoch 300 | Train Loss 0.035125 | Val Loss 0.534826
# Early stopping at epoch 316
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed2243.keras
# y | ZZx1 -> R² = 0.9787, R² diff = 0.9401
# y | ZZx2 -> R² = 0.9740, R² diff = 0.8803
# y | ZZxReto -> R² = -3.3721, R² diff = 0.2642
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=2243 salvo.
# Epoch 0 | Train Loss 0.975894 | Val Loss 3.320026
# Epoch 100 | Train Loss 0.069772 | Val Loss 0.480519
# Epoch 200 | Train Loss 0.042377 | Val Loss 0.508374
# Epoch 300 | Train Loss 0.031419 | Val Loss 0.472571
# Epoch 400 | Train Loss 0.021004 | Val Loss 0.381467
# Epoch 500 | Train Loss 0.016522 | Val Loss 0.363791
# Epoch 600 | Train Loss 0.015490 | Val Loss 0.358218
# Epoch 700 | Train Loss 0.014722 | Val Loss 0.318558
# Epoch 800 | Train Loss 0.014003 | Val Loss 0.290364
# Epoch 900 | Train Loss 0.013324 | Val Loss 0.281600
# Epoch 1000 | Train Loss 0.012810 | Val Loss 0.270120
# Epoch 1100 | Train Loss 0.012428 | Val Loss 0.251913
# Epoch 1200 | Train Loss 0.012071 | Val Loss 0.237774
# Epoch 1300 | Train Loss 0.011718 | Val Loss 0.233796
# Epoch 1400 | Train Loss 0.011395 | Val Loss 0.236593
# Early stopping at epoch 1458
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed5613.keras
# y | ZZx1 -> R² = 0.9977, R² diff = 0.9889
# y | ZZx2 -> R² = 0.9927, R² diff = 0.9388
# y | ZZxReto -> R² = 0.7294, R² diff = 0.7373
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=5613 salvo.
# Epoch 0 | Train Loss 1.217440 | Val Loss 4.360148
# Epoch 100 | Train Loss 0.068104 | Val Loss 0.454760
# Epoch 200 | Train Loss 0.044459 | Val Loss 0.440578
# Epoch 300 | Train Loss 0.034155 | Val Loss 0.497799
# Early stopping at epoch 360
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed7093.keras
# y | ZZx1 -> R² = 0.9842, R² diff = 0.9479
# y | ZZx2 -> R² = 0.9637, R² diff = 0.8909
# y | ZZxReto -> R² = -2.7617, R² diff = 0.3303
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=7093 salvo.
# Epoch 0 | Train Loss 1.186832 | Val Loss 4.145186
# Epoch 100 | Train Loss 0.069289 | Val Loss 0.454198
# Epoch 200 | Train Loss 0.045982 | Val Loss 0.425845
# Epoch 300 | Train Loss 0.035641 | Val Loss 0.485340
# Early stopping at epoch 364
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed5756.keras
# y | ZZx1 -> R² = 0.9831, R² diff = 0.9477
# y | ZZx2 -> R² = 0.9585, R² diff = 0.8927
# y | ZZxReto -> R² = -2.7354, R² diff = 0.3350
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=5756 salvo.
# Epoch 0 | Train Loss 1.058169 | Val Loss 3.573580
# Epoch 100 | Train Loss 0.068192 | Val Loss 0.460632
# Epoch 200 | Train Loss 0.044693 | Val Loss 0.461204
# Epoch 300 | Train Loss 0.034696 | Val Loss 0.504981
# Early stopping at epoch 351
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed4434.keras
# y | ZZx1 -> R² = 0.9807, R² diff = 0.9450
# y | ZZx2 -> R² = 0.9637, R² diff = 0.8868
# y | ZZxReto -> R² = -3.0333, R² diff = 0.3045
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=4434 salvo.
# Epoch 0 | Train Loss 0.950937 | Val Loss 3.270241
# Epoch 100 | Train Loss 0.072405 | Val Loss 0.483945
# Epoch 200 | Train Loss 0.047485 | Val Loss 0.443986
# Epoch 300 | Train Loss 0.036852 | Val Loss 0.509231
# Early stopping at epoch 374
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed2243.keras
# y | ZZx1 -> R² = 0.9833, R² diff = 0.9467
# y | ZZx2 -> R² = 0.9602, R² diff = 0.8865
# y | ZZxReto -> R² = -2.7783, R² diff = 0.3236
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=2243 salvo.
