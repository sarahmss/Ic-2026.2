# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
import re
import os

TITLES = [
    "ZZx1",  # Train
    "ZZx2",  # Val
    "ZZxReto", # test
]

PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a", "costheta"]   
TARGET_INT = ["theta"]  
TARGET = ["dtheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
PLOT = False

# %%
Datasets = []
NormDatasets = []

# Ler Datasets.xlsx
for title in TITLES:
    df = pd.read_excel("./Data/Datasets.xlsx", sheet_name=title)
    Datasets.append(df)

# Ler NormDatasets.xlsx
for title in TITLES:
    df = pd.read_excel("./Data/NormDatasets.xlsx", sheet_name=title)
    NormDatasets.append(df)
    
SCALER = joblib.load("./scalers/scaler.pkl")    
OUT_SCALER = joblib.load("./scalers/out_scaler.pkl")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 6
#       4 # Ler Datasets.xlsx
#       5 for title in TITLES:
# ----> 6     df = pd.read_excel("./Data/Datasets.xlsx", sheet_name=title)
#       7     Datasets.append(df)
#       9 # Ler NormDatasets.xlsx
#
# File d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
#     512         index_col=index_col,
#     513         usecols=usecols,
#     514         dtype=dtype,
#     515         converters=converters,
#     516         true_values=true_values,
#     517         false_values=false_values,
#     518         skiprows=skiprows,
#     519         nrows=nrows,
#     520         na_values=na_values,
#     521         keep_default_na=keep_default_na,
#     522         na_filter=na_filter,
#     523         verbose=verbose,
#     524         parse_dates=parse_dates,
#     525         date_parser=date_parser,
#     526         date_format=date_format,
#     527         thousands=thousands,
#     528         decimal=decimal,
#     529         comment=comment,
#     530         skipfooter=skipfooter,
#     531         dtype_backend=dtype_backend,
#     532     )
#     533 finally:
#     534     # make sure to close opened file handles
#     535     if should_close:
#
# File d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\pandas\io\excel\_base.py:1616, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1576 def parse(
#    1577     self,
#    1578     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1596     **kwds,
#    1597 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1598     """
#    1599     Parse specified sheet(s) into a DataFrame.
#    1600
#    (...)
#    1614     >>> file.parse()  # doctest: +SKIP
#    1615     """
# -> 1616     return self._reader.parse(
#    1617         sheet_name=sheet_name,
#    1618         header=header,
#    1619         names=names,
#    1620         index_col=index_col,
#    1621         usecols=usecols,
#    1622         converters=converters,
#    1623         true_values=true_values,
#    1624         false_values=false_values,
#    1625         skiprows=skiprows,
#    1626         nrows=nrows,
#    1627         na_values=na_values,
#    1628         parse_dates=parse_dates,
#    1629         date_parser=date_parser,
#    1630         date_format=date_format,
#    1631         thousands=thousands,
#    1632         comment=comment,
#    1633         skipfooter=skipfooter,
#    1634         dtype_backend=dtype_backend,
#    1635         **kwds,
#    1636     )
#
# File d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\pandas\io\excel\_base.py:773, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     770     print(f"Reading sheet {asheetname}")
#     772 if isinstance(asheetname, str):
# --> 773     sheet = self.get_sheet_by_name(asheetname)
#     774 else:  # assume an integer if not a string
#     775     sheet = self.get_sheet_by_index(asheetname)
#
# File d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\pandas\io\excel\_openpyxl.py:582, in OpenpyxlReader.get_sheet_by_name(self, name)
#     581 def get_sheet_by_name(self, name: str):
# --> 582     self.raise_if_bad_sheet_by_name(name)
#     583     return self.book[name]
#
# File d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\pandas\io\excel\_base.py:624, in BaseExcelReader.raise_if_bad_sheet_by_name(self, name)
#     622 def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     623     if name not in self.sheet_names:
# --> 624         raise ValueError(f"Worksheet named '{name}' not found")
#
# ValueError: Worksheet named 'ZZy1' not found

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):

    dtheta_cin = (R / (2 * L)) * (phi_d - phi_e)
    # dx_cin = (R / 2) * tf.cos(theta) * (phi_d + phi_e)
    # dy_cin = (R / 2) * tf.sin(theta) * (phi_d + phi_e)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dtheta_cin]


def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T, np.vstack(dq).T

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
# Regex para extrair os parâmetros do nome do arquivo
# ex: model_arch36-22_r0.9_Ld0.3_Lp0.7_seed5124.keras
PATTERN = re.compile(
    r"^model_arch(?P<arch>[\d\-]+)_r(?P<r>-?[\d.]+)_Ld(?P<Ld>-?[\d.]+)_Lp(?P<Lp>-?[\d.]+)_seed(?P<seed>\d+)\.keras$"
)

def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_mse = f"MSE_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_mse, []).append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {mse:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"MSE_{safe_title}_{name}"] = to_scalar(metrics[name][f"MSE_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")


def ParseModelFilename(filename):
    m = PATTERN.match(filename)
    if not m:
        return None

    arch = [int(x) for x in m.group("arch").split("-")]
    r    = float(m.group("r"))
    Ld   = float(m.group("Ld"))
    Lp   = float(m.group("Lp"))
    seed = int(m.group("seed"))

    return arch, r, Ld, Lp, seed


def RebuildResultsNL(n_layers, models_dir="models", excel_file=None, verbose=True):
    excel_file = excel_file or f"resultados-{n_layers}l.xlsx"
    if os.path.exists(excel_file):
        os.remove(excel_file)

    all_files = sorted(f for f in os.listdir(models_dir) if f.endswith(".keras"))

    n_found = 0
    for filename in all_files:
        parsed = ParseModelFilename(filename)
        if parsed is None:
            continue

        arch, r, Ld, Lp, seed = parsed
        if len(arch) != n_layers:
            continue

        n_found += 1
        model = tf.keras.saving.load_model(os.path.join(models_dir, filename))
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file)

        if verbose:
            print(f"[{n_found}] {filename} -> ok")

    print(f"\nConcluído. {n_found} modelos de {n_layers} camadas -> {excel_file}")


PLOT = False
RebuildResultsNL(1)   # gera resultados-3l.xlsx
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# theta | ZZxReto -> R² = -0.0702, R² diff = 0.7125
# theta | ZZy1 -> R² = -5.2539, R² diff = 0.5122
# theta | ZZx2 -> R² = -0.9831, R² diff = 0.4971
# theta | ZZy2 -> R² = -0.8568, R² diff = 0.3683
# theta | LSG-1 -> R² = -3.3801, R² diff = 0.5917
# theta | LSG-2 -> R² = -27.6996, R² diff = 0.2525
# theta | ZZx1-inv -> R² = -2.0397, R² diff = 0.4756
# theta | ZZx1 -> R² = -1.1002, R² diff = 0.6370
# theta | ZZx2-inv -> R² = -0.4428, R² diff = 0.1572
# theta | semiCirc -> R² = -50.8890, R² diff = -0.7370
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.01 seed=1794 salvo.
# [1] model_arch35-17-10_r0.01_Ld0.3_Lp0.7_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.8623, R² diff = 0.6888
# theta | ZZy1 -> R² = -15.4249, R² diff = 0.2905
# theta | ZZx2 -> R² = 0.5995, R² diff = 0.4921
# theta | ZZy2 -> R² = -3.6343, R² diff = 0.3501
# theta | LSG-1 -> R² = -0.0595, R² diff = 0.5446
# theta | LSG-2 -> R² = -9.9794, R² diff = 0.3735
# theta | ZZx1-inv -> R² = 0.4912, R² diff = 0.5773
# theta | ZZx1 -> R² = 0.2255, R² diff = 0.6340
# theta | ZZx2-inv -> R² = -1.1829, R² diff = 0.3450
# theta | semiCirc -> R² = -30.9310, R² diff = -0.2094
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.01 seed=2206 salvo.
# [2] model_arch35-17-10_r0.01_Ld0.3_Lp0.7_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.7430, R² diff = 0.6506
# theta | ZZy1 -> R² = -17.2469, R² diff = 0.2467
# theta | ZZx2 -> R² = 0.7676, R² diff = 0.4950
# theta | ZZy2 -> R² = -4.7806, R² diff = 0.3195
# theta | LSG-1 -> R² = -0.6492, R² diff = 0.5275
# theta | LSG-2 -> R² = -15.4249, R² diff = 0.3039
# theta | ZZx1-inv -> R² = -0.4009, R² diff = 0.4940
# theta | ZZx1 -> R² = -0.5254, R² diff = 0.6178
# theta | ZZx2-inv -> R² = -1.5184, R² diff = 0.0962
# theta | semiCirc -> R² = -32.9942, R² diff = -0.2702
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.01 seed=3318 salvo.
# [3] model_arch35-17-10_r0.01_Ld0.3_Lp0.7_seed3318.keras -> ok
# theta | ZZxReto -> R² = 0.0249, R² diff = 0.6564
# theta | ZZy1 -> R² = -13.0391, R² diff = 0.2654
# theta | ZZx2 -> R² = -1.5362, R² diff = 0.4699
# theta | ZZy2 -> R² = -2.2260, R² diff = 0.3088
# theta | LSG-1 -> R² = -2.4182, R² diff = 0.5125
# theta | LSG-2 -> R² = -21.8624, R² diff = 0.2840
# theta | ZZx1-inv -> R² = -3.2123, R² diff = 0.4883
# theta | ZZx1 -> R² = -2.2328, R² diff = 0.5847
# theta | ZZx2-inv -> R² = -0.8951, R² diff = 0.0880
# theta | semiCirc -> R² = -40.3644, R² diff = -0.4420
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.01 seed=456 salvo.
# [4] model_arch35-17-10_r0.01_Ld0.3_Lp0.7_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.3276, R² diff = 0.6469
# theta | ZZy1 -> R² = -15.9949, R² diff = 0.2412
# theta | ZZx2 -> R² = -0.1833, R² diff = 0.4891
# theta | ZZy2 -> R² = -3.5743, R² diff = 0.3479
# theta | LSG-1 -> R² = -1.3053, R² diff = 0.5348
# theta | LSG-2 -> R² = -11.8114, R² diff = 0.3547
# theta | ZZx1-inv -> R² = -0.2571, R² diff = 0.5814
# theta | ZZx1 -> R² = -0.8929, R² diff = 0.6192
# theta | ZZx2-inv -> R² = -1.7764, R² diff = 0.0732
# theta | semiCirc -> R² = -32.4796, R² diff = -0.2483
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.01 seed=7674 salvo.
# [5] model_arch35-17-10_r0.01_Ld0.3_Lp0.7_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.4449, R² diff = 0.6849
# theta | ZZy1 -> R² = -23.4065, R² diff = 0.1636
# theta | ZZx2 -> R² = 0.0216, R² diff = 0.4832
# theta | ZZy2 -> R² = -2.8662, R² diff = 0.3278
# theta | LSG-1 -> R² = -2.5188, R² diff = 0.5175
# theta | LSG-2 -> R² = -23.8233, R² diff = 0.2627
# theta | ZZx1-inv -> R² = -1.2651, R² diff = 0.4962
# theta | ZZx1 -> R² = -2.3883, R² diff = 0.6266
# theta | ZZx2-inv -> R² = -1.7634, R² diff = 0.2656
# theta | semiCirc -> R² = -45.3135, R² diff = -0.5181
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=1794 salvo.
# [6] model_arch35-17-10_r0.01_Ld0.7_Lp0.3_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.7887, R² diff = 0.6777
# theta | ZZy1 -> R² = -26.5385, R² diff = 0.1697
# theta | ZZx2 -> R² = 0.6379, R² diff = 0.4634
# theta | ZZy2 -> R² = -6.0865, R² diff = 0.2661
# theta | LSG-1 -> R² = -0.6358, R² diff = 0.5576
# theta | LSG-2 -> R² = -13.3368, R² diff = 0.3192
# theta | ZZx1-inv -> R² = 0.4074, R² diff = 0.5211
# theta | ZZx1 -> R² = 0.3367, R² diff = 0.6624
# theta | ZZx2-inv -> R² = -4.9769, R² diff = 0.0268
# theta | semiCirc -> R² = -38.3676, R² diff = -0.3509
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=2206 salvo.
# [7] model_arch35-17-10_r0.01_Ld0.7_Lp0.3_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.3064, R² diff = 0.6945
# theta | ZZy1 -> R² = -23.7354, R² diff = 0.1440
# theta | ZZx2 -> R² = -2.0043, R² diff = 0.4574
# theta | ZZy2 -> R² = -1.2653, R² diff = 0.2650
# theta | LSG-1 -> R² = -3.3691, R² diff = 0.5062
# theta | LSG-2 -> R² = -34.9299, R² diff = 0.2066
# theta | ZZx1-inv -> R² = -3.6483, R² diff = 0.4405
# theta | ZZx1 -> R² = -3.0324, R² diff = 0.6029
# theta | ZZx2-inv -> R² = -0.1655, R² diff = 0.2747
# theta | semiCirc -> R² = -49.7425, R² diff = -0.6100
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=3318 salvo.
# [8] model_arch35-17-10_r0.01_Ld0.7_Lp0.3_seed3318.keras -> ok
# theta | ZZxReto -> R² = 0.5588, R² diff = 0.7193
# theta | ZZy1 -> R² = -20.3709, R² diff = 0.2210
# theta | ZZx2 -> R² = -0.2130, R² diff = 0.4987
# theta | ZZy2 -> R² = -4.1283, R² diff = 0.2998
# theta | LSG-1 -> R² = -1.6014, R² diff = 0.5319
# theta | LSG-2 -> R² = -24.5305, R² diff = 0.2269
# theta | ZZx1-inv -> R² = -1.9018, R² diff = 0.4362
# theta | ZZx1 -> R² = -1.5421, R² diff = 0.6559
# theta | ZZx2-inv -> R² = -0.7562, R² diff = 0.1574
# theta | semiCirc -> R² = -43.2555, R² diff = -0.4919
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=456 salvo.
# [9] model_arch35-17-10_r0.01_Ld0.7_Lp0.3_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.5300, R² diff = 0.6839
# theta | ZZy1 -> R² = -35.6216, R² diff = 0.0129
# theta | ZZx2 -> R² = -0.4129, R² diff = 0.4841
# theta | ZZy2 -> R² = -2.6357, R² diff = 0.3315
# theta | LSG-1 -> R² = -3.2990, R² diff = 0.5364
# theta | LSG-2 -> R² = -19.7836, R² diff = 0.2995
# theta | ZZx1-inv -> R² = -1.3239, R² diff = 0.5103
# theta | ZZx1 -> R² = -1.7767, R² diff = 0.6410
# theta | ZZx2-inv -> R² = -1.1996, R² diff = 0.1783
# theta | semiCirc -> R² = -50.8404, R² diff = -0.6164
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=7674 salvo.
# [10] model_arch35-17-10_r0.01_Ld0.7_Lp0.3_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.2841, R² diff = 0.6851
# theta | ZZy1 -> R² = -17.8374, R² diff = 0.3039
# theta | ZZx2 -> R² = -0.6456, R² diff = 0.4206
# theta | ZZy2 -> R² = -0.3184, R² diff = 0.4680
# theta | LSG-1 -> R² = -0.3232, R² diff = 0.5771
# theta | LSG-2 -> R² = -0.7896, R² diff = 0.4976
# theta | ZZx1-inv -> R² = 0.2022, R² diff = 0.6560
# theta | ZZx1 -> R² = 0.4555, R² diff = 0.6255
# theta | ZZx2-inv -> R² = 0.6640, R² diff = 0.1646
# theta | semiCirc -> R² = -33.9106, R² diff = -0.3504
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=1794 salvo.
# [11] model_arch35-17-10_r0.9_Ld0.3_Lp0.7_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.3456, R² diff = 0.7113
# theta | ZZy1 -> R² = -13.6048, R² diff = 0.3041
# theta | ZZx2 -> R² = -2.6067, R² diff = 0.4629
# theta | ZZy2 -> R² = -1.7176, R² diff = 0.3282
# theta | LSG-1 -> R² = -2.6515, R² diff = 0.5331
# theta | LSG-2 -> R² = -27.3325, R² diff = 0.2561
# theta | ZZx1-inv -> R² = -4.0790, R² diff = 0.4454
# theta | ZZx1 -> R² = -2.7092, R² diff = 0.6282
# theta | ZZx2-inv -> R² = -1.5264, R² diff = -0.1224
# theta | semiCirc -> R² = -45.7290, R² diff = -0.5548
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=2206 salvo.
# [12] model_arch35-17-10_r0.9_Ld0.3_Lp0.7_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.8109, R² diff = 0.6745
# theta | ZZy1 -> R² = -9.9972, R² diff = 0.3387
# theta | ZZx2 -> R² = 0.2391, R² diff = 0.4822
# theta | ZZy2 -> R² = -3.0693, R² diff = 0.3529
# theta | LSG-1 -> R² = 0.5861, R² diff = 0.5099
# theta | LSG-2 -> R² = -15.2905, R² diff = 0.3199
# theta | ZZx1-inv -> R² = -0.1778, R² diff = 0.4962
# theta | ZZx1 -> R² = -0.3856, R² diff = 0.5907
# theta | ZZx2-inv -> R² = -0.3915, R² diff = 0.2841
# theta | semiCirc -> R² = -25.8972, R² diff = -0.1383
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=3318 salvo.
# [13] model_arch35-17-10_r0.9_Ld0.3_Lp0.7_seed3318.keras -> ok
# theta | ZZxReto -> R² = 0.7169, R² diff = 0.7438
# theta | ZZy1 -> R² = -16.7841, R² diff = 0.3021
# theta | ZZx2 -> R² = 0.3387, R² diff = 0.4942
# theta | ZZy2 -> R² = -2.0656, R² diff = 0.2889
# theta | LSG-1 -> R² = -2.8513, R² diff = 0.5409
# theta | LSG-2 -> R² = -20.5456, R² diff = 0.3046
# theta | ZZx1-inv -> R² = -0.9737, R² diff = 0.4317
# theta | ZZx1 -> R² = -1.0232, R² diff = 0.6697
# theta | ZZx2-inv -> R² = -0.1679, R² diff = 0.2287
# theta | semiCirc -> R² = -52.0235, R² diff = -0.6399
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=456 salvo.
# [14] model_arch35-17-10_r0.9_Ld0.3_Lp0.7_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.8515, R² diff = 0.7122
# theta | ZZy1 -> R² = -11.4955, R² diff = 0.3707
# theta | ZZx2 -> R² = 0.2926, R² diff = 0.4913
# theta | ZZy2 -> R² = -2.5307, R² diff = 0.3511
# theta | LSG-1 -> R² = -0.2597, R² diff = 0.5513
# theta | LSG-2 -> R² = -10.9438, R² diff = 0.3817
# theta | ZZx1-inv -> R² = 0.4356, R² diff = 0.5596
# theta | ZZx1 -> R² = 0.0137, R² diff = 0.6287
# theta | ZZx2-inv -> R² = -2.3373, R² diff = 0.1280
# theta | semiCirc -> R² = -34.5322, R² diff = -0.2882
# Modelo [35, 17, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=7674 salvo.
# [15] model_arch35-17-10_r0.9_Ld0.3_Lp0.7_seed7674.keras -> ok
# theta | ZZxReto -> R² = -0.2054, R² diff = 0.6685
# theta | ZZy1 -> R² = -22.5303, R² diff = 0.1658
# theta | ZZx2 -> R² = -0.3487, R² diff = 0.4784
# theta | ZZy2 -> R² = -4.7520, R² diff = 0.2161
# theta | LSG-1 -> R² = -3.6658, R² diff = 0.5381
# theta | LSG-2 -> R² = -25.0856, R² diff = 0.2281
# theta | ZZx1-inv -> R² = -2.7386, R² diff = 0.4356
# theta | ZZx1 -> R² = -2.3298, R² diff = 0.6606
# theta | ZZx2-inv -> R² = -2.6500, R² diff = -0.2323
# theta | semiCirc -> R² = -47.6176, R² diff = -0.5642
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=1794 salvo.
# [16] model_arch35-17-10_r0.9_Ld0.7_Lp0.3_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.6642, R² diff = 0.7039
# theta | ZZy1 -> R² = -22.2570, R² diff = 0.2203
# theta | ZZx2 -> R² = 0.9253, R² diff = 0.5029
# theta | ZZy2 -> R² = -3.8609, R² diff = 0.3504
# theta | LSG-1 -> R² = -1.1032, R² diff = 0.5517
# theta | LSG-2 -> R² = -12.9839, R² diff = 0.3429
# theta | ZZx1-inv -> R² = 0.3839, R² diff = 0.5348
# theta | ZZx1 -> R² = -0.3442, R² diff = 0.6658
# theta | ZZx2-inv -> R² = -2.8105, R² diff = 0.2692
# theta | semiCirc -> R² = -41.6389, R² diff = -0.4172
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=2206 salvo.
# [17] model_arch35-17-10_r0.9_Ld0.7_Lp0.3_seed2206.keras -> ok
# theta | ZZxReto -> R² = -1.5334, R² diff = 0.6811
# theta | ZZy1 -> R² = -23.4483, R² diff = 0.1155
# theta | ZZx2 -> R² = 0.2979, R² diff = 0.4853
# theta | ZZy2 -> R² = -0.7033, R² diff = 0.3951
# theta | LSG-1 -> R² = -5.5646, R² diff = 0.5023
# theta | LSG-2 -> R² = -22.7927, R² diff = 0.3176
# theta | ZZx1-inv -> R² = -1.2346, R² diff = 0.5309
# theta | ZZx1 -> R² = -4.6939, R² diff = 0.6059
# theta | ZZx2-inv -> R² = -1.4987, R² diff = 0.3624
# theta | semiCirc -> R² = -50.4458, R² diff = -0.6097
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=3318 salvo.
# [18] model_arch35-17-10_r0.9_Ld0.7_Lp0.3_seed3318.keras -> ok
# theta | ZZxReto -> R² = -1.5680, R² diff = 0.5913
# theta | ZZy1 -> R² = -23.2603, R² diff = 0.1124
# theta | ZZx2 -> R² = 0.5728, R² diff = 0.4573
# theta | ZZy2 -> R² = 0.2393, R² diff = 0.4379
# theta | LSG-1 -> R² = -6.4534, R² diff = 0.4974
# theta | LSG-2 -> R² = -19.0545, R² diff = 0.3748
# theta | ZZx1-inv -> R² = -0.0550, R² diff = 0.5954
# theta | ZZx1 -> R² = -4.6619, R² diff = 0.5847
# theta | ZZx2-inv -> R² = -3.8750, R² diff = 0.2853
# theta | semiCirc -> R² = -48.4202, R² diff = -0.5647
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=456 salvo.
# [19] model_arch35-17-10_r0.9_Ld0.7_Lp0.3_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.6501, R² diff = 0.7144
# theta | ZZy1 -> R² = -29.4987, R² diff = 0.1530
# theta | ZZx2 -> R² = -1.8436, R² diff = 0.3963
# theta | ZZy2 -> R² = -2.5526, R² diff = 0.3744
# theta | LSG-1 -> R² = -0.3479, R² diff = 0.5747
# theta | LSG-2 -> R² = -14.0739, R² diff = 0.3541
# theta | ZZx1-inv -> R² = 0.4262, R² diff = 0.5815
# theta | ZZx1 -> R² = 0.4022, R² diff = 0.6660
# theta | ZZx2-inv -> R² = -1.0076, R² diff = 0.2039
# theta | semiCirc -> R² = -36.6951, R² diff = -0.3229
# Modelo [35, 17, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=7674 salvo.
# [20] model_arch35-17-10_r0.9_Ld0.7_Lp0.3_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.8027, R² diff = 0.6621
# theta | ZZy1 -> R² = -4.0169, R² diff = 0.4529
# theta | ZZx2 -> R² = 0.5909, R² diff = 0.4882
# theta | ZZy2 -> R² = -2.8844, R² diff = 0.3492
# theta | LSG-1 -> R² = 0.3120, R² diff = 0.4775
# theta | LSG-2 -> R² = -21.2911, R² diff = 0.2427
# theta | ZZx1-inv -> R² = -0.8147, R² diff = 0.4376
# theta | ZZx1 -> R² = -1.2903, R² diff = 0.6004
# theta | ZZx2-inv -> R² = 0.4038, R² diff = 0.4498
# theta | semiCirc -> R² = -27.3732, R² diff = -0.2101
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.01 seed=1794 salvo.
# [21] model_arch35-17-5_r0.01_Ld0.3_Lp0.7_seed1794.keras -> ok
# theta | ZZxReto -> R² = -4.5804, R² diff = 0.5033
# theta | ZZy1 -> R² = -14.7205, R² diff = 0.1452
# theta | ZZx2 -> R² = -1.4856, R² diff = 0.4325
# theta | ZZy2 -> R² = 0.2155, R² diff = 0.3087
# theta | LSG-1 -> R² = -4.4903, R² diff = 0.4868
# theta | LSG-2 -> R² = -23.7435, R² diff = 0.3219
# theta | ZZx1-inv -> R² = -3.1736, R² diff = 0.5604
# theta | ZZx1 -> R² = -6.7586, R² diff = 0.5414
# theta | ZZx2-inv -> R² = -0.9029, R² diff = 0.0008
# theta | semiCirc -> R² = -35.1291, R² diff = -0.3140
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.01 seed=2206 salvo.
# [22] model_arch35-17-5_r0.01_Ld0.3_Lp0.7_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.8255, R² diff = 0.5827
# theta | ZZy1 -> R² = -5.6651, R² diff = 0.3836
# theta | ZZx2 -> R² = -0.2908, R² diff = 0.4398
# theta | ZZy2 -> R² = -3.4856, R² diff = 0.3327
# theta | LSG-1 -> R² = 0.7279, R² diff = 0.4578
# theta | LSG-2 -> R² = -15.1504, R² diff = 0.2767
# theta | ZZx1-inv -> R² = -1.2585, R² diff = 0.4288
# theta | ZZx1 -> R² = -0.2453, R² diff = 0.5553
# theta | ZZx2-inv -> R² = 0.0986, R² diff = 0.2753
# theta | semiCirc -> R² = -18.3495, R² diff = -0.0522
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.01 seed=3318 salvo.
# [23] model_arch35-17-5_r0.01_Ld0.3_Lp0.7_seed3318.keras -> ok
# theta | ZZxReto -> R² = -2.6736, R² diff = 0.5695
# theta | ZZy1 -> R² = -7.0891, R² diff = 0.2969
# theta | ZZx2 -> R² = 0.4470, R² diff = 0.4504
# theta | ZZy2 -> R² = -1.0469, R² diff = 0.4208
# theta | LSG-1 -> R² = -2.4571, R² diff = 0.4881
# theta | LSG-2 -> R² = -11.3390, R² diff = 0.3982
# theta | ZZx1-inv -> R² = 0.2735, R² diff = 0.6073
# theta | ZZx1 -> R² = -4.6458, R² diff = 0.5566
# theta | ZZx2-inv -> R² = -2.2527, R² diff = 0.2949
# theta | semiCirc -> R² = -28.6282, R² diff = -0.1806
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.01 seed=456 salvo.
# [24] model_arch35-17-5_r0.01_Ld0.3_Lp0.7_seed456.keras -> ok
# theta | ZZxReto -> R² = -0.2008, R² diff = 0.6451
# theta | ZZy1 -> R² = -7.1095, R² diff = 0.3430
# theta | ZZx2 -> R² = 0.4990, R² diff = 0.4810
# theta | ZZy2 -> R² = -3.3109, R² diff = 0.3109
# theta | LSG-1 -> R² = -1.2504, R² diff = 0.5073
# theta | LSG-2 -> R² = -19.7053, R² diff = 0.2896
# theta | ZZx1-inv -> R² = -0.8212, R² diff = 0.4716
# theta | ZZx1 -> R² = -2.8755, R² diff = 0.6180
# theta | ZZx2-inv -> R² = -0.2337, R² diff = 0.3448
# theta | semiCirc -> R² = -36.1515, R² diff = -0.3444
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.01 seed=7674 salvo.
# [25] model_arch35-17-5_r0.01_Ld0.3_Lp0.7_seed7674.keras -> ok
# theta | ZZxReto -> R² = -1.2532, R² diff = 0.6513
# theta | ZZy1 -> R² = -13.6605, R² diff = 0.2248
# theta | ZZx2 -> R² = 0.3264, R² diff = 0.4232
# theta | ZZy2 -> R² = -1.9219, R² diff = 0.3909
# theta | LSG-1 -> R² = -1.4327, R² diff = 0.5151
# theta | LSG-2 -> R² = -13.4622, R² diff = 0.3567
# theta | ZZx1-inv -> R² = 0.5846, R² diff = 0.5736
# theta | ZZx1 -> R² = -3.1800, R² diff = 0.5928
# theta | ZZx2-inv -> R² = -4.5994, R² diff = 0.3805
# theta | semiCirc -> R² = -36.0234, R² diff = -0.3254
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.01 seed=1794 salvo.
# [26] model_arch35-17-5_r0.01_Ld0.7_Lp0.3_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.3145, R² diff = 0.6545
# theta | ZZy1 -> R² = -28.5256, R² diff = 0.0757
# theta | ZZx2 -> R² = 0.8480, R² diff = 0.4755
# theta | ZZy2 -> R² = -1.2662, R² diff = 0.4255
# theta | LSG-1 -> R² = -1.8803, R² diff = 0.5118
# theta | LSG-2 -> R² = -10.7722, R² diff = 0.3904
# theta | ZZx1-inv -> R² = 0.7440, R² diff = 0.5527
# theta | ZZx1 -> R² = -2.0344, R² diff = 0.5871
# theta | ZZx2-inv -> R² = -4.0581, R² diff = 0.2747
# theta | semiCirc -> R² = -39.7526, R² diff = -0.3882
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.01 seed=2206 salvo.
# [27] model_arch35-17-5_r0.01_Ld0.7_Lp0.3_seed2206.keras -> ok
# theta | ZZxReto -> R² = -0.5875, R² diff = 0.6697
# theta | ZZy1 -> R² = -18.8656, R² diff = 0.1824
# theta | ZZx2 -> R² = 0.8301, R² diff = 0.4828
# theta | ZZy2 -> R² = -4.5204, R² diff = 0.3340
# theta | LSG-1 -> R² = -1.1850, R² diff = 0.5210
# theta | LSG-2 -> R² = -12.1725, R² diff = 0.3352
# theta | ZZx1-inv -> R² = 0.4799, R² diff = 0.4988
# theta | ZZx1 -> R² = -2.2640, R² diff = 0.6293
# theta | ZZx2-inv -> R² = -5.6066, R² diff = 0.1473
# theta | semiCirc -> R² = -39.8794, R² diff = -0.4089
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.01 seed=3318 salvo.
# [28] model_arch35-17-5_r0.01_Ld0.7_Lp0.3_seed3318.keras -> ok
# theta | ZZxReto -> R² = 0.4157, R² diff = 0.5407
# theta | ZZy1 -> R² = -13.6525, R² diff = 0.2285
# theta | ZZx2 -> R² = 0.0548, R² diff = 0.4274
# theta | ZZy2 -> R² = -5.5516, R² diff = 0.3357
# theta | LSG-1 -> R² = 0.4020, R² diff = 0.4056
# theta | LSG-2 -> R² = -7.9508, R² diff = 0.2514
# theta | ZZx1-inv -> R² = -0.1557, R² diff = 0.4671
# theta | ZZx1 -> R² = 0.0681, R² diff = 0.5395
# theta | ZZx2-inv -> R² = 0.1721, R² diff = 0.3246
# theta | semiCirc -> R² = -13.6540, R² diff = -0.0397
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.01 seed=456 salvo.
# [29] model_arch35-17-5_r0.01_Ld0.7_Lp0.3_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.8355, R² diff = 0.6345
# theta | ZZy1 -> R² = -11.0085, R² diff = 0.3250
# theta | ZZx2 -> R² = -2.3697, R² diff = 0.4159
# theta | ZZy2 -> R² = -1.0553, R² diff = 0.3510
# theta | LSG-1 -> R² = 0.2309, R² diff = 0.4372
# theta | LSG-2 -> R² = -40.6838, R² diff = 0.0863
# theta | ZZx1-inv -> R² = -8.6775, R² diff = 0.2782
# theta | ZZx1 -> R² = -1.9893, R² diff = 0.5611
# theta | ZZx2-inv -> R² = -0.5751, R² diff = 0.3218
# theta | semiCirc -> R² = -26.7289, R² diff = -0.2841
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.01 seed=7674 salvo.
# [30] model_arch35-17-5_r0.01_Ld0.7_Lp0.3_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.8190, R² diff = 0.5995
# theta | ZZy1 -> R² = -5.1434, R² diff = 0.3801
# theta | ZZx2 -> R² = -0.6002, R² diff = 0.4469
# theta | ZZy2 -> R² = -3.0297, R² diff = 0.3406
# theta | LSG-1 -> R² = 0.4877, R² diff = 0.4305
# theta | LSG-2 -> R² = -22.7182, R² diff = 0.2034
# theta | ZZx1-inv -> R² = -3.3558, R² diff = 0.3941
# theta | ZZx1 -> R² = -1.8588, R² diff = 0.5504
# theta | ZZx2-inv -> R² = -0.4380, R² diff = 0.2788
# theta | semiCirc -> R² = -22.9539, R² diff = -0.1973
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.9 seed=1794 salvo.
# [31] model_arch35-17-5_r0.9_Ld0.3_Lp0.7_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.7505, R² diff = 0.5930
# theta | ZZy1 -> R² = -8.5309, R² diff = 0.3807
# theta | ZZx2 -> R² = 0.0533, R² diff = 0.4661
# theta | ZZy2 -> R² = -4.2948, R² diff = 0.3474
# theta | LSG-1 -> R² = 0.7130, R² diff = 0.4930
# theta | LSG-2 -> R² = -9.7430, R² diff = 0.2998
# theta | ZZx1-inv -> R² = 0.1125, R² diff = 0.4776
# theta | ZZx1 -> R² = 0.4120, R² diff = 0.5852
# theta | ZZx2-inv -> R² = -0.5476, R² diff = 0.0322
# theta | semiCirc -> R² = -19.5799, R² diff = -0.0567
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.9 seed=2206 salvo.
# [32] model_arch35-17-5_r0.9_Ld0.3_Lp0.7_seed2206.keras -> ok
# theta | ZZxReto -> R² = -1.8027, R² diff = 0.5659
# theta | ZZy1 -> R² = -13.8609, R² diff = 0.2234
# theta | ZZx2 -> R² = -1.2923, R² diff = 0.4507
# theta | ZZy2 -> R² = -1.4579, R² diff = 0.2775
# theta | LSG-1 -> R² = -2.4323, R² diff = 0.5006
# theta | LSG-2 -> R² = -24.7702, R² diff = 0.2718
# theta | ZZx1-inv -> R² = -2.5199, R² diff = 0.5061
# theta | ZZx1 -> R² = -5.2129, R² diff = 0.5966
# theta | ZZx2-inv -> R² = -0.3097, R² diff = 0.1955
# theta | semiCirc -> R² = -37.9623, R² diff = -0.3852
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.9 seed=3318 salvo.
# [33] model_arch35-17-5_r0.9_Ld0.3_Lp0.7_seed3318.keras -> ok
# theta | ZZxReto -> R² = -0.0100, R² diff = 0.5332
# theta | ZZy1 -> R² = -16.6880, R² diff = 0.1958
# theta | ZZx2 -> R² = 0.0877, R² diff = 0.4634
# theta | ZZy2 -> R² = -0.9244, R² diff = 0.3158
# theta | LSG-1 -> R² = -1.6177, R² diff = 0.4917
# theta | LSG-2 -> R² = -20.4677, R² diff = 0.3132
# theta | ZZx1-inv -> R² = -1.0269, R² diff = 0.5269
# theta | ZZx1 -> R² = -3.3025, R² diff = 0.5724
# theta | ZZx2-inv -> R² = -0.5299, R² diff = 0.1329
# theta | semiCirc -> R² = -31.7962, R² diff = -0.2486
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.9 seed=456 salvo.
# [34] model_arch35-17-5_r0.9_Ld0.3_Lp0.7_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.8393, R² diff = 0.6184
# theta | ZZy1 -> R² = -4.9485, R² diff = 0.4287
# theta | ZZx2 -> R² = 0.5216, R² diff = 0.4838
# theta | ZZy2 -> R² = -3.8618, R² diff = 0.3487
# theta | LSG-1 -> R² = 0.5735, R² diff = 0.4795
# theta | LSG-2 -> R² = -21.4285, R² diff = 0.2100
# theta | ZZx1-inv -> R² = -2.2157, R² diff = 0.3890
# theta | ZZx1 -> R² = -0.8324, R² diff = 0.5889
# theta | ZZx2-inv -> R² = 0.1317, R² diff = 0.2928
# theta | semiCirc -> R² = -27.6010, R² diff = -0.2442
# Modelo [35, 17, 5] | Ld=0.3 Lp=0.7 r=0.9 seed=7674 salvo.
# [35] model_arch35-17-5_r0.9_Ld0.3_Lp0.7_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.6653, R² diff = 0.6335
# theta | ZZy1 -> R² = -16.0208, R² diff = 0.2901
# theta | ZZx2 -> R² = 0.6929, R² diff = 0.5046
# theta | ZZy2 -> R² = -4.6121, R² diff = 0.3115
# theta | LSG-1 -> R² = 0.7999, R² diff = 0.5020
# theta | LSG-2 -> R² = -16.9585, R² diff = 0.2509
# theta | ZZx1-inv -> R² = -0.0770, R² diff = 0.4259
# theta | ZZx1 -> R² = 0.2835, R² diff = 0.6229
# theta | ZZx2-inv -> R² = 0.0936, R² diff = 0.3464
# theta | semiCirc -> R² = -25.4261, R² diff = -0.1389
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.9 seed=1794 salvo.
# [36] model_arch35-17-5_r0.9_Ld0.7_Lp0.3_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.6924, R² diff = 0.6769
# theta | ZZy1 -> R² = -22.1527, R² diff = 0.1793
# theta | ZZx2 -> R² = -1.2733, R² diff = 0.4539
# theta | ZZy2 -> R² = -2.3148, R² diff = 0.3175
# theta | LSG-1 -> R² = -0.4445, R² diff = 0.5008
# theta | LSG-2 -> R² = -23.5360, R² diff = 0.2382
# theta | ZZx1-inv -> R² = -0.8218, R² diff = 0.4667
# theta | ZZx1 -> R² = -1.9444, R² diff = 0.5937
# theta | ZZx2-inv -> R² = 0.6551, R² diff = 0.4994
# theta | semiCirc -> R² = -37.4744, R² diff = -0.3900
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.9 seed=2206 salvo.
# [37] model_arch35-17-5_r0.9_Ld0.7_Lp0.3_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.9120, R² diff = 0.6722
# theta | ZZy1 -> R² = -13.5692, R² diff = 0.3003
# theta | ZZx2 -> R² = 0.3373, R² diff = 0.4852
# theta | ZZy2 -> R² = -1.4458, R² diff = 0.3507
# theta | LSG-1 -> R² = -0.7359, R² diff = 0.4863
# theta | LSG-2 -> R² = -22.7114, R² diff = 0.2757
# theta | ZZx1-inv -> R² = -1.4012, R² diff = 0.4497
# theta | ZZx1 -> R² = -1.5252, R² diff = 0.6011
# theta | ZZx2-inv -> R² = 0.0158, R² diff = 0.3358
# theta | semiCirc -> R² = -34.7224, R² diff = -0.3408
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.9 seed=3318 salvo.
# [38] model_arch35-17-5_r0.9_Ld0.7_Lp0.3_seed3318.keras -> ok
# theta | ZZxReto -> R² = -0.5110, R² diff = 0.6675
# theta | ZZy1 -> R² = -19.8943, R² diff = 0.1781
# theta | ZZx2 -> R² = 0.4349, R² diff = 0.4568
# theta | ZZy2 -> R² = -1.3999, R² diff = 0.3440
# theta | LSG-1 -> R² = -1.3010, R² diff = 0.5130
# theta | LSG-2 -> R² = -18.0220, R² diff = 0.3121
# theta | ZZx1-inv -> R² = 0.4000, R² diff = 0.5389
# theta | ZZx1 -> R² = -2.9176, R² diff = 0.6106
# theta | ZZx2-inv -> R² = -1.0989, R² diff = 0.5188
# theta | semiCirc -> R² = -37.9509, R² diff = -0.3655
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.9 seed=456 salvo.
# [39] model_arch35-17-5_r0.9_Ld0.7_Lp0.3_seed456.keras -> ok
# theta | ZZxReto -> R² = -0.6543, R² diff = 0.6516
# theta | ZZy1 -> R² = -15.3867, R² diff = 0.1868
# theta | ZZx2 -> R² = 0.8772, R² diff = 0.4733
# theta | ZZy2 -> R² = -1.6209, R² diff = 0.3580
# theta | LSG-1 -> R² = -2.1824, R² diff = 0.5094
# theta | LSG-2 -> R² = -15.5761, R² diff = 0.3556
# theta | ZZx1-inv -> R² = 0.6343, R² diff = 0.5410
# theta | ZZx1 -> R² = -3.2000, R² diff = 0.5995
# theta | ZZx2-inv -> R² = -5.1347, R² diff = 0.1175
# theta | semiCirc -> R² = -37.8057, R² diff = -0.3565
# Modelo [35, 17, 5] | Ld=0.7 Lp=0.3 r=0.9 seed=7674 salvo.
# [40] model_arch35-17-5_r0.9_Ld0.7_Lp0.3_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.7610, R² diff = 0.6022
# theta | ZZy1 -> R² = -4.7738, R² diff = 0.3971
# theta | ZZx2 -> R² = 0.3648, R² diff = 0.4662
# theta | ZZy2 -> R² = -2.0571, R² diff = 0.3699
# theta | LSG-1 -> R² = 0.4007, R² diff = 0.4454
# theta | LSG-2 -> R² = -24.8425, R² diff = 0.2136
# theta | ZZx1-inv -> R² = -2.9764, R² diff = 0.3903
# theta | ZZx1 -> R² = -1.3530, R² diff = 0.5534
# theta | ZZx2-inv -> R² = 0.2746, R² diff = 0.4189
# theta | semiCirc -> R² = -23.2965, R² diff = -0.1710
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.01 seed=1794 salvo.
# [41] model_arch35-17-6_r0.01_Ld0.3_Lp0.7_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.0543, R² diff = 0.5926
# theta | ZZy1 -> R² = -10.5712, R² diff = 0.2852
# theta | ZZx2 -> R² = -0.4723, R² diff = 0.4411
# theta | ZZy2 -> R² = 0.0478, R² diff = 0.3664
# theta | LSG-1 -> R² = -2.2104, R² diff = 0.4640
# theta | LSG-2 -> R² = -21.8152, R² diff = 0.2994
# theta | ZZx1-inv -> R² = -3.5005, R² diff = 0.4462
# theta | ZZx1 -> R² = -5.4799, R² diff = 0.5515
# theta | ZZx2-inv -> R² = -0.1428, R² diff = 0.3443
# theta | semiCirc -> R² = -37.9515, R² diff = -0.4186
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.01 seed=2206 salvo.
# [42] model_arch35-17-6_r0.01_Ld0.3_Lp0.7_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.7987, R² diff = 0.6630
# theta | ZZy1 -> R² = -3.0916, R² diff = 0.4885
# theta | ZZx2 -> R² = -1.0441, R² diff = 0.4847
# theta | ZZy2 -> R² = -2.8400, R² diff = 0.2982
# theta | LSG-1 -> R² = -0.2674, R² diff = 0.5813
# theta | LSG-2 -> R² = -21.8627, R² diff = 0.2930
# theta | ZZx1-inv -> R² = -1.3369, R² diff = 0.4332
# theta | ZZx1 -> R² = -0.2383, R² diff = 0.5999
# theta | ZZx2-inv -> R² = -2.5551, R² diff = -0.4016
# theta | semiCirc -> R² = -34.9840, R² diff = -0.3670
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.01 seed=3318 salvo.
# [43] model_arch35-17-6_r0.01_Ld0.3_Lp0.7_seed3318.keras -> ok
# theta | ZZxReto -> R² = 0.8304, R² diff = 0.6373
# theta | ZZy1 -> R² = -24.3206, R² diff = 0.1409
# theta | ZZx2 -> R² = -1.8220, R² diff = 0.4359
# theta | ZZy2 -> R² = -0.9920, R² diff = 0.3562
# theta | LSG-1 -> R² = -0.3546, R² diff = 0.5127
# theta | LSG-2 -> R² = -17.6801, R² diff = 0.3175
# theta | ZZx1-inv -> R² = -1.4369, R² diff = 0.4905
# theta | ZZx1 -> R² = -0.9750, R² diff = 0.5934
# theta | ZZx2-inv -> R² = 0.5447, R² diff = 0.5731
# theta | semiCirc -> R² = -34.2936, R² diff = -0.3205
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.01 seed=456 salvo.
# [44] model_arch35-17-6_r0.01_Ld0.3_Lp0.7_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.5023, R² diff = 0.6000
# theta | ZZy1 -> R² = -12.3350, R² diff = 0.2516
# theta | ZZx2 -> R² = -1.3280, R² diff = 0.4366
# theta | ZZy2 -> R² = -2.7146, R² diff = 0.3419
# theta | LSG-1 -> R² = -0.1764, R² diff = 0.4701
# theta | LSG-2 -> R² = -18.0591, R² diff = 0.2729
# theta | ZZx1-inv -> R² = -2.3827, R² diff = 0.5012
# theta | ZZx1 -> R² = -1.8433, R² diff = 0.5625
# theta | ZZx2-inv -> R² = -0.4087, R² diff = 0.1814
# theta | semiCirc -> R² = -25.4330, R² diff = -0.1990
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.01 seed=7674 salvo.
# [45] model_arch35-17-6_r0.01_Ld0.3_Lp0.7_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.3069, R² diff = 0.6736
# theta | ZZy1 -> R² = -16.5904, R² diff = 0.2707
# theta | ZZx2 -> R² = 0.5681, R² diff = 0.4992
# theta | ZZy2 -> R² = -1.7136, R² diff = 0.3599
# theta | LSG-1 -> R² = -1.3094, R² diff = 0.4992
# theta | LSG-2 -> R² = -18.5534, R² diff = 0.3126
# theta | ZZx1-inv -> R² = -0.4301, R² diff = 0.5086
# theta | ZZx1 -> R² = -2.4760, R² diff = 0.6195
# theta | ZZx2-inv -> R² = 0.1912, R² diff = 0.4137
# theta | semiCirc -> R² = -37.5157, R² diff = -0.3711
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.01 seed=1794 salvo.
# [46] model_arch35-17-6_r0.01_Ld0.7_Lp0.3_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.8072, R² diff = 0.6448
# theta | ZZy1 -> R² = -18.2554, R² diff = 0.2401
# theta | ZZx2 -> R² = 0.4587, R² diff = 0.4644
# theta | ZZy2 -> R² = -5.5593, R² diff = 0.3159
# theta | LSG-1 -> R² = 0.6460, R² diff = 0.4911
# theta | LSG-2 -> R² = -17.4775, R² diff = 0.2435
# theta | ZZx1-inv -> R² = -0.4354, R² diff = 0.4641
# theta | ZZx1 -> R² = -0.1494, R² diff = 0.6174
# theta | ZZx2-inv -> R² = -1.1324, R² diff = 0.1669
# theta | semiCirc -> R² = -24.2117, R² diff = -0.1424
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.01 seed=2206 salvo.
# [47] model_arch35-17-6_r0.01_Ld0.7_Lp0.3_seed2206.keras -> ok
# theta | ZZxReto -> R² = -0.2553, R² diff = 0.6519
# theta | ZZy1 -> R² = -39.6176, R² diff = -0.0811
# theta | ZZx2 -> R² = 0.7056, R² diff = 0.4639
# theta | ZZy2 -> R² = -2.7498, R² diff = 0.2656
# theta | LSG-1 -> R² = -3.3935, R² diff = 0.5118
# theta | LSG-2 -> R² = -21.0284, R² diff = 0.3007
# theta | ZZx1-inv -> R² = 0.1512, R² diff = 0.4681
# theta | ZZx1 -> R² = -3.2344, R² diff = 0.6282
# theta | ZZx2-inv -> R² = -4.4580, R² diff = -0.2079
# theta | semiCirc -> R² = -47.5918, R² diff = -0.5515
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.01 seed=3318 salvo.
# [48] model_arch35-17-6_r0.01_Ld0.7_Lp0.3_seed3318.keras -> ok
# theta | ZZxReto -> R² = 0.2091, R² diff = 0.7093
# theta | ZZy1 -> R² = -6.7589, R² diff = 0.4967
# theta | ZZx2 -> R² = 0.2228, R² diff = 0.4832
# theta | ZZy2 -> R² = -2.5658, R² diff = 0.2593
# theta | LSG-1 -> R² = -2.6830, R² diff = 0.5195
# theta | LSG-2 -> R² = -20.9835, R² diff = 0.2804
# theta | ZZx1-inv -> R² = -0.2816, R² diff = 0.4485
# theta | ZZx1 -> R² = -2.4503, R² diff = 0.6558
# theta | ZZx2-inv -> R² = -0.3544, R² diff = 0.1234
# theta | semiCirc -> R² = -53.9340, R² diff = -0.6798
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.01 seed=456 salvo.
# [49] model_arch35-17-6_r0.01_Ld0.7_Lp0.3_seed456.keras -> ok
# theta | ZZxReto -> R² = -0.2101, R² diff = 0.6485
# theta | ZZy1 -> R² = -33.7227, R² diff = 0.0084
# theta | ZZx2 -> R² = 0.7571, R² diff = 0.4787
# theta | ZZy2 -> R² = -1.6242, R² diff = 0.3168
# theta | LSG-1 -> R² = -2.3356, R² diff = 0.5079
# theta | LSG-2 -> R² = -20.9936, R² diff = 0.2917
# theta | ZZx1-inv -> R² = 0.1583, R² diff = 0.4912
# theta | ZZx1 -> R² = -3.3504, R² diff = 0.6098
# theta | ZZx2-inv -> R² = -1.4217, R² diff = 0.2984
# theta | semiCirc -> R² = -44.0398, R² diff = -0.4846
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.01 seed=7674 salvo.
# [50] model_arch35-17-6_r0.01_Ld0.7_Lp0.3_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.3552, R² diff = 0.6068
# theta | ZZy1 -> R² = -7.4142, R² diff = 0.3319
# theta | ZZx2 -> R² = -2.6036, R² diff = 0.3835
# theta | ZZy2 -> R² = -2.0948, R² diff = 0.4067
# theta | LSG-1 -> R² = 0.0588, R² diff = 0.4880
# theta | LSG-2 -> R² = -15.0361, R² diff = 0.3047
# theta | ZZx1-inv -> R² = -1.6506, R² diff = 0.5486
# theta | ZZx1 -> R² = -1.3861, R² diff = 0.5831
# theta | ZZx2-inv -> R² = 0.3184, R² diff = 0.3867
# theta | semiCirc -> R² = -21.2131, R² diff = -0.0760
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.9 seed=1794 salvo.
# [51] model_arch35-17-6_r0.9_Ld0.3_Lp0.7_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.8129, R² diff = 0.6242
# theta | ZZy1 -> R² = -8.5004, R² diff = 0.3812
# theta | ZZx2 -> R² = 0.4813, R² diff = 0.4765
# theta | ZZy2 -> R² = -3.1315, R² diff = 0.3594
# theta | LSG-1 -> R² = 0.5149, R² diff = 0.4981
# theta | LSG-2 -> R² = -12.2230, R² diff = 0.3040
# theta | ZZx1-inv -> R² = 0.2644, R² diff = 0.4713
# theta | ZZx1 -> R² = -0.5267, R² diff = 0.5806
# theta | ZZx2-inv -> R² = 0.0439, R² diff = 0.2184
# theta | semiCirc -> R² = -28.3565, R² diff = -0.2165
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.9 seed=2206 salvo.
# [52] model_arch35-17-6_r0.9_Ld0.3_Lp0.7_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.5650, R² diff = 0.5819
# theta | ZZy1 -> R² = -15.7398, R² diff = 0.2425
# theta | ZZx2 -> R² = 0.9114, R² diff = 0.4729
# theta | ZZy2 -> R² = -4.1771, R² diff = 0.3637
# theta | LSG-1 -> R² = 0.6688, R² diff = 0.4865
# theta | LSG-2 -> R² = -7.8604, R² diff = 0.3509
# theta | ZZx1-inv -> R² = 0.5476, R² diff = 0.5328
# theta | ZZx1 -> R² = 0.3849, R² diff = 0.5837
# theta | ZZx2-inv -> R² = -0.2837, R² diff = 0.2899
# theta | semiCirc -> R² = -18.3734, R² diff = 0.0054
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.9 seed=3318 salvo.
# [53] model_arch35-17-6_r0.9_Ld0.3_Lp0.7_seed3318.keras -> ok
# theta | ZZxReto -> R² = -0.4504, R² diff = 0.6404
# theta | ZZy1 -> R² = -11.2411, R² diff = 0.2844
# theta | ZZx2 -> R² = 0.6035, R² diff = 0.4710
# theta | ZZy2 -> R² = -1.1652, R² diff = 0.2809
# theta | LSG-1 -> R² = -1.5792, R² diff = 0.5009
# theta | LSG-2 -> R² = -24.5723, R² diff = 0.2735
# theta | ZZx1-inv -> R² = -1.1852, R² diff = 0.4459
# theta | ZZx1 -> R² = -2.6886, R² diff = 0.5977
# theta | ZZx2-inv -> R² = 0.0018, R² diff = 0.2858
# theta | semiCirc -> R² = -38.7561, R² diff = -0.3935
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.9 seed=456 salvo.
# [54] model_arch35-17-6_r0.9_Ld0.3_Lp0.7_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.8276, R² diff = 0.5903
# theta | ZZy1 -> R² = -11.8709, R² diff = 0.2836
# theta | ZZx2 -> R² = 0.4107, R² diff = 0.4592
# theta | ZZy2 -> R² = -4.9142, R² diff = 0.3375
# theta | LSG-1 -> R² = 0.7266, R² diff = 0.4601
# theta | LSG-2 -> R² = -12.0068, R² diff = 0.2808
# theta | ZZx1-inv -> R² = -0.4417, R² diff = 0.4538
# theta | ZZx1 -> R² = -0.1047, R² diff = 0.5743
# theta | ZZx2-inv -> R² = -0.0920, R² diff = 0.2869
# theta | semiCirc -> R² = -19.1776, R² diff = -0.0718
# Modelo [35, 17, 6] | Ld=0.3 Lp=0.7 r=0.9 seed=7674 salvo.
# [55] model_arch35-17-6_r0.9_Ld0.3_Lp0.7_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.7279, R² diff = 0.6367
# theta | ZZy1 -> R² = -33.3315, R² diff = 0.0361
# theta | ZZx2 -> R² = -0.8969, R² diff = 0.4636
# theta | ZZy2 -> R² = -2.9798, R² diff = 0.2674
# theta | LSG-1 -> R² = 0.0159, R² diff = 0.5036
# theta | LSG-2 -> R² = -24.1194, R² diff = 0.2340
# theta | ZZx1-inv -> R² = -1.5952, R² diff = 0.4378
# theta | ZZx1 -> R² = -0.9408, R² diff = 0.6059
# theta | ZZx2-inv -> R² = -0.0394, R² diff = 0.3704
# theta | semiCirc -> R² = -34.2114, R² diff = -0.3344
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.9 seed=1794 salvo.
# [56] model_arch35-17-6_r0.9_Ld0.7_Lp0.3_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.6547, R² diff = 0.6935
# theta | ZZy1 -> R² = -13.3751, R² diff = 0.3209
# theta | ZZx2 -> R² = 0.7385, R² diff = 0.4885
# theta | ZZy2 -> R² = -3.1921, R² diff = 0.3212
# theta | LSG-1 -> R² = -0.2476, R² diff = 0.5211
# theta | LSG-2 -> R² = -24.3784, R² diff = 0.2290
# theta | ZZx1-inv -> R² = -0.8153, R² diff = 0.4306
# theta | ZZx1 -> R² = -0.7419, R² diff = 0.6392
# theta | ZZx2-inv -> R² = -0.2531, R² diff = 0.3411
# theta | semiCirc -> R² = -35.7683, R² diff = -0.3314
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.9 seed=2206 salvo.
# [57] model_arch35-17-6_r0.9_Ld0.7_Lp0.3_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.8584, R² diff = 0.6206
# theta | ZZy1 -> R² = -19.2431, R² diff = 0.2127
# theta | ZZx2 -> R² = 0.2624, R² diff = 0.4769
# theta | ZZy2 -> R² = -4.3666, R² diff = 0.3401
# theta | LSG-1 -> R² = 0.5508, R² diff = 0.4904
# theta | LSG-2 -> R² = -12.5723, R² diff = 0.3077
# theta | ZZx1-inv -> R² = -0.0394, R² diff = 0.5184
# theta | ZZx1 -> R² = 0.0213, R² diff = 0.6079
# theta | ZZx2-inv -> R² = -0.0947, R² diff = 0.2786
# theta | semiCirc -> R² = -21.6443, R² diff = -0.0841
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.9 seed=3318 salvo.
# [58] model_arch35-17-6_r0.9_Ld0.7_Lp0.3_seed3318.keras -> ok
# theta | ZZxReto -> R² = -1.6597, R² diff = 0.6314
# theta | ZZy1 -> R² = -23.0406, R² diff = 0.0957
# theta | ZZx2 -> R² = 0.7353, R² diff = 0.4579
# theta | ZZy2 -> R² = -0.7819, R² diff = 0.4149
# theta | LSG-1 -> R² = -3.4030, R² diff = 0.5067
# theta | LSG-2 -> R² = -11.8507, R² diff = 0.3864
# theta | ZZx1-inv -> R² = 0.7512, R² diff = 0.5681
# theta | ZZx1 -> R² = -3.9758, R² diff = 0.5734
# theta | ZZx2-inv -> R² = -5.6679, R² diff = 0.2262
# theta | semiCirc -> R² = -42.5747, R² diff = -0.4458
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.9 seed=456 salvo.
# [59] model_arch35-17-6_r0.9_Ld0.7_Lp0.3_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.7505, R² diff = 0.6647
# theta | ZZy1 -> R² = -10.2590, R² diff = 0.3677
# theta | ZZx2 -> R² = -0.7655, R² diff = 0.4875
# theta | ZZy2 -> R² = -1.9320, R² diff = 0.3522
# theta | LSG-1 -> R² = -0.4666, R² diff = 0.4869
# theta | LSG-2 -> R² = -28.6905, R² diff = 0.1966
# theta | ZZx1-inv -> R² = -3.2427, R² diff = 0.4213
# theta | ZZx1 -> R² = -2.1362, R² diff = 0.6109
# theta | ZZx2-inv -> R² = -0.3834, R² diff = 0.3187
# theta | semiCirc -> R² = -34.0174, R² diff = -0.3488
# Modelo [35, 17, 6] | Ld=0.7 Lp=0.3 r=0.9 seed=7674 salvo.
# [60] model_arch35-17-6_r0.9_Ld0.7_Lp0.3_seed7674.keras -> ok
# theta | ZZxReto -> R² = -0.8665, R² diff = 0.6338
# theta | ZZy1 -> R² = -13.2960, R² diff = 0.2442
# theta | ZZx2 -> R² = 0.3915, R² diff = 0.4601
# theta | ZZy2 -> R² = -2.1868, R² diff = 0.2210
# theta | LSG-1 -> R² = -2.2801, R² diff = 0.4914
# theta | LSG-2 -> R² = -28.5441, R² diff = 0.2318
# theta | ZZx1-inv -> R² = -2.4605, R² diff = 0.4027
# theta | ZZx1 -> R² = -3.5831, R² diff = 0.5888
# theta | ZZx2-inv -> R² = -0.8279, R² diff = 0.1188
# theta | semiCirc -> R² = -42.0916, R² diff = -0.4868
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.01 seed=1794 salvo.
# [61] model_arch35-17-7_r0.01_Ld0.3_Lp0.7_seed1794.keras -> ok
# theta | ZZxReto -> R² = 0.8013, R² diff = 0.5640
# theta | ZZy1 -> R² = -14.6374, R² diff = 0.2159
# theta | ZZx2 -> R² = 0.0223, R² diff = 0.4221
# theta | ZZy2 -> R² = -7.4416, R² diff = 0.2431
# theta | LSG-1 -> R² = 0.7227, R² diff = 0.4437
# theta | LSG-2 -> R² = -15.5210, R² diff = 0.1942
# theta | ZZx1-inv -> R² = -1.8976, R² diff = 0.3604
# theta | ZZx1 -> R² = -0.6012, R² diff = 0.5744
# theta | ZZx2-inv -> R² = -0.9736, R² diff = 0.0419
# theta | semiCirc -> R² = -22.4538, R² diff = -0.2252
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.01 seed=2206 salvo.
# [62] model_arch35-17-7_r0.01_Ld0.3_Lp0.7_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.8631, R² diff = 0.6152
# theta | ZZy1 -> R² = -8.2761, R² diff = 0.3851
# theta | ZZx2 -> R² = -1.6134, R² diff = 0.4502
# theta | ZZy2 -> R² = -2.4386, R² diff = 0.3160
# theta | LSG-1 -> R² = 0.1496, R² diff = 0.4681
# theta | LSG-2 -> R² = -31.7690, R² diff = 0.1505
# theta | ZZx1-inv -> R² = -4.1268, R² diff = 0.3304
# theta | ZZx1 -> R² = -1.1164, R² diff = 0.5870
# theta | ZZx2-inv -> R² = -0.5601, R² diff = 0.3659
# theta | semiCirc -> R² = -30.5811, R² diff = -0.2855
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.01 seed=3318 salvo.
# [63] model_arch35-17-7_r0.01_Ld0.3_Lp0.7_seed3318.keras -> ok
# theta | ZZxReto -> R² = 0.8981, R² diff = 0.6237
# theta | ZZy1 -> R² = -20.3955, R² diff = 0.1718
# theta | ZZx2 -> R² = -1.2513, R² diff = 0.4453
# theta | ZZy2 -> R² = -3.4832, R² diff = 0.2955
# theta | LSG-1 -> R² = 0.4191, R² diff = 0.4906
# theta | LSG-2 -> R² = -19.1891, R² diff = 0.2542
# theta | ZZx1-inv -> R² = -1.7640, R² diff = 0.4280
# theta | ZZx1 -> R² = -0.8511, R² diff = 0.5933
# theta | ZZx2-inv -> R² = -0.2640, R² diff = 0.3573
# theta | semiCirc -> R² = -29.3601, R² diff = -0.2658
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.01 seed=456 salvo.
# [64] model_arch35-17-7_r0.01_Ld0.3_Lp0.7_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.8898, R² diff = 0.6052
# theta | ZZy1 -> R² = -19.9029, R² diff = 0.1736
# theta | ZZx2 -> R² = 0.3488, R² diff = 0.4429
# theta | ZZy2 -> R² = -4.5215, R² diff = 0.2355
# theta | LSG-1 -> R² = 0.1199, R² diff = 0.4776
# theta | LSG-2 -> R² = -23.8975, R² diff = 0.2142
# theta | ZZx1-inv -> R² = -2.8018, R² diff = 0.3711
# theta | ZZx1 -> R² = -1.6058, R² diff = 0.5957
# theta | ZZx2-inv -> R² = -1.3205, R² diff = -0.0169
# theta | semiCirc -> R² = -30.2954, R² diff = -0.3053
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.01 seed=7674 salvo.
# [65] model_arch35-17-7_r0.01_Ld0.3_Lp0.7_seed7674.keras -> ok
# theta | ZZxReto -> R² = -0.0855, R² diff = 0.6835
# theta | ZZy1 -> R² = -24.1392, R² diff = 0.1474
# theta | ZZx2 -> R² = 0.5841, R² diff = 0.4949
# theta | ZZy2 -> R² = -2.8907, R² diff = 0.3094
# theta | LSG-1 -> R² = -2.5008, R² diff = 0.5023
# theta | LSG-2 -> R² = -25.7403, R² diff = 0.2483
# theta | ZZx1-inv -> R² = -1.3136, R² diff = 0.4603
# theta | ZZx1 -> R² = -3.7380, R² diff = 0.6258
# theta | ZZx2-inv -> R² = -1.7993, R² diff = 0.1953
# theta | semiCirc -> R² = -44.8952, R² diff = -0.5238
# Modelo [35, 17, 7] | Ld=0.7 Lp=0.3 r=0.01 seed=1794 salvo.
# [66] model_arch35-17-7_r0.01_Ld0.7_Lp0.3_seed1794.keras -> ok
# theta | ZZxReto -> R² = -3.5210, R² diff = 0.5897
# theta | ZZy1 -> R² = -22.1461, R² diff = 0.0630
# theta | ZZx2 -> R² = 0.0368, R² diff = 0.4463
# theta | ZZy2 -> R² = 0.3706, R² diff = 0.4263
# theta | LSG-1 -> R² = -6.2549, R² diff = 0.4943
# theta | LSG-2 -> R² = -16.8379, R² diff = 0.3888
# theta | ZZx1-inv -> R² = 0.2650, R² diff = 0.5987
# theta | ZZx1 -> R² = -5.5138, R² diff = 0.5525
# theta | ZZx2-inv -> R² = -3.8768, R² diff = 0.3116
# theta | semiCirc -> R² = -45.2348, R² diff = -0.5043
# Modelo [35, 17, 7] | Ld=0.7 Lp=0.3 r=0.01 seed=2206 salvo.
# [67] model_arch35-17-7_r0.01_Ld0.7_Lp0.3_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.8042, R² diff = 0.6677
# theta | ZZy1 -> R² = -17.1697, R² diff = 0.2640
# theta | ZZx2 -> R² = 0.2132, R² diff = 0.4898
# theta | ZZy2 -> R² = -2.8271, R² diff = 0.2833
# theta | LSG-1 -> R² = -0.6439, R² diff = 0.5204
# theta | LSG-2 -> R² = -23.6082, R² diff = 0.2630
# theta | ZZx1-inv -> R² = -0.6998, R² diff = 0.4770
# theta | ZZx1 -> R² = -0.7866, R² diff = 0.6127
# theta | ZZx2-inv -> R² = -0.5425, R² diff = 0.2090
# theta | semiCirc -> R² = -37.5047, R² diff = -0.3661
# Modelo [35, 17, 7] | Ld=0.7 Lp=0.3 r=0.01 seed=3318 salvo.
# [68] model_arch35-17-7_r0.01_Ld0.7_Lp0.3_seed3318.keras -> ok
# theta | ZZxReto -> R² = -0.2509, R² diff = 0.6083
# theta | ZZy1 -> R² = -23.2300, R² diff = 0.1388
# theta | ZZx2 -> R² = -0.1575, R² diff = 0.4731
# theta | ZZy2 -> R² = -0.3476, R² diff = 0.3842
# theta | LSG-1 -> R² = -2.6158, R² diff = 0.5130
# theta | LSG-2 -> R² = -17.2186, R² diff = 0.3498
# theta | ZZx1-inv -> R² = 0.3491, R² diff = 0.5866
# theta | ZZx1 -> R² = -2.2864, R² diff = 0.5839
# theta | ZZx2-inv -> R² = -1.6690, R² diff = 0.3725
# theta | semiCirc -> R² = -38.7481, R² diff = -0.3670
# Modelo [35, 17, 7] | Ld=0.7 Lp=0.3 r=0.01 seed=456 salvo.
# [69] model_arch35-17-7_r0.01_Ld0.7_Lp0.3_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.8154, R² diff = 0.6968
# theta | ZZy1 -> R² = -8.9251, R² diff = 0.3881
# theta | ZZx2 -> R² = 0.6749, R² diff = 0.4805
# theta | ZZy2 -> R² = -4.9584, R² diff = 0.2746
# theta | LSG-1 -> R² = -0.0853, R² diff = 0.5133
# theta | LSG-2 -> R² = -31.9638, R² diff = 0.1378
# theta | ZZx1-inv -> R² = -2.6196, R² diff = 0.3588
# theta | ZZx1 -> R² = -0.5269, R² diff = 0.6443
# theta | ZZx2-inv -> R² = -1.7096, R² diff = 0.1270
# theta | semiCirc -> R² = -33.8088, R² diff = -0.3319
# Modelo [35, 17, 7] | Ld=0.7 Lp=0.3 r=0.01 seed=7674 salvo.
# [70] model_arch35-17-7_r0.01_Ld0.7_Lp0.3_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.8738, R² diff = 0.6306
# theta | ZZy1 -> R² = -4.1062, R² diff = 0.4229
# theta | ZZx2 -> R² = 0.5146, R² diff = 0.4857
# theta | ZZy2 -> R² = -5.8007, R² diff = 0.3014
# theta | LSG-1 -> R² = 0.6854, R² diff = 0.4786
# theta | LSG-2 -> R² = -16.6033, R² diff = 0.2366
# theta | ZZx1-inv -> R² = -1.0520, R² diff = 0.3953
# theta | ZZx1 -> R² = -0.6356, R² diff = 0.6061
# theta | ZZx2-inv -> R² = -0.5017, R² diff = 0.1870
# theta | semiCirc -> R² = -26.6996, R² diff = -0.2128
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.9 seed=1794 salvo.
# [71] model_arch35-17-7_r0.9_Ld0.3_Lp0.7_seed1794.keras -> ok
# theta | ZZxReto -> R² = -0.3735, R² diff = 0.6229
# theta | ZZy1 -> R² = -11.2432, R² diff = 0.2935
# theta | ZZx2 -> R² = 0.0919, R² diff = 0.4804
# theta | ZZy2 -> R² = -1.8492, R² diff = 0.2204
# theta | LSG-1 -> R² = -2.3444, R² diff = 0.5118
# theta | LSG-2 -> R² = -28.9592, R² diff = 0.2433
# theta | ZZx1-inv -> R² = -2.6167, R² diff = 0.4363
# theta | ZZx1 -> R² = -3.7798, R² diff = 0.6237
# theta | ZZx2-inv -> R² = -0.5176, R² diff = 0.1815
# theta | semiCirc -> R² = -43.6680, R² diff = -0.4912
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.9 seed=2206 salvo.
# [72] model_arch35-17-7_r0.9_Ld0.3_Lp0.7_seed2206.keras -> ok
# theta | ZZxReto -> R² = -1.0364, R² diff = 0.6471
# theta | ZZy1 -> R² = -9.8427, R² diff = 0.2902
# theta | ZZx2 -> R² = 0.2440, R² diff = 0.4690
# theta | ZZy2 -> R² = -0.8677, R² diff = 0.2408
# theta | LSG-1 -> R² = -2.8861, R² diff = 0.4969
# theta | LSG-2 -> R² = -30.5089, R² diff = 0.2392
# theta | ZZx1-inv -> R² = -2.5776, R² diff = 0.4206
# theta | ZZx1 -> R² = -3.6038, R² diff = 0.5822
# theta | ZZx2-inv -> R² = -0.6574, R² diff = 0.1454
# theta | semiCirc -> R² = -44.7439, R² diff = -0.5178
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.9 seed=3318 salvo.
# [73] model_arch35-17-7_r0.9_Ld0.3_Lp0.7_seed3318.keras -> ok
# theta | ZZxReto -> R² = 0.8055, R² diff = 0.5891
# theta | ZZy1 -> R² = -8.5622, R² diff = 0.3292
# theta | ZZx2 -> R² = -0.6170, R² diff = 0.4058
# theta | ZZy2 -> R² = -3.8162, R² diff = 0.2927
# theta | LSG-1 -> R² = 0.3969, R² diff = 0.4889
# theta | LSG-2 -> R² = -11.2092, R² diff = 0.3263
# theta | ZZx1-inv -> R² = -0.7549, R² diff = 0.5146
# theta | ZZx1 -> R² = -0.1702, R² diff = 0.5855
# theta | ZZx2-inv -> R² = -0.2365, R² diff = 0.2583
# theta | semiCirc -> R² = -21.7947, R² diff = -0.0906
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.9 seed=456 salvo.
# [74] model_arch35-17-7_r0.9_Ld0.3_Lp0.7_seed456.keras -> ok
# theta | ZZxReto -> R² = 0.8947, R² diff = 0.7054
# theta | ZZy1 -> R² = -4.9530, R² diff = 0.4693
# theta | ZZx2 -> R² = 0.4081, R² diff = 0.5008
# theta | ZZy2 -> R² = -3.9843, R² diff = 0.2824
# theta | LSG-1 -> R² = -0.4841, R² diff = 0.5214
# theta | LSG-2 -> R² = -22.3800, R² diff = 0.2509
# theta | ZZx1-inv -> R² = -1.6533, R² diff = 0.4382
# theta | ZZx1 -> R² = -0.8422, R² diff = 0.6534
# theta | ZZx2-inv -> R² = -0.2697, R² diff = 0.2624
# theta | semiCirc -> R² = -35.9739, R² diff = -0.3644
# Modelo [35, 17, 7] | Ld=0.3 Lp=0.7 r=0.9 seed=7674 salvo.
# [75] model_arch35-17-7_r0.9_Ld0.3_Lp0.7_seed7674.keras -> ok
# theta | ZZxReto -> R² = 0.5370, R² diff = 0.6671
# theta | ZZy1 -> R² = -29.3324, R² diff = 0.0868
# theta | ZZx2 -> R² = 0.0487, R² diff = 0.4865
# theta | ZZy2 -> R² = -1.2330, R² diff = 0.3113
# theta | LSG-1 -> R² = -2.5531, R² diff = 0.4914
# theta | LSG-2 -> R² = -32.1726, R² diff = 0.2152
# theta | ZZx1-inv -> R² = -2.0050, R² diff = 0.4385
# theta | ZZx1 -> R² = -3.7340, R² diff = 0.6024
# theta | ZZx2-inv -> R² = -0.0623, R² diff = 0.3400
# theta | semiCirc -> R² = -46.5954, R² diff = -0.5593
# Modelo [35, 17, 7] | Ld=0.7 Lp=0.3 r=0.9 seed=1794 salvo.
# [76] model_arch35-17-7_r0.9_Ld0.7_Lp0.3_seed1794.keras -> ok
# theta | ZZxReto -> R² = -2.0886, R² diff = 0.6452
# theta | ZZy1 -> R² = -32.2269, R² diff = -0.0105
# theta | ZZx2 -> R² = 0.5162, R² diff = 0.4716
# theta | ZZy2 -> R² = -0.4237, R² diff = 0.3355
# theta | LSG-1 -> R² = -5.6585, R² diff = 0.4994
# theta | LSG-2 -> R² = -21.9812, R² diff = 0.3166
# theta | ZZx1-inv -> R² = -0.2192, R² diff = 0.4986
# theta | ZZx1 -> R² = -5.2236, R² diff = 0.5930
# theta | ZZx2-inv -> R² = -2.0092, R² diff = 0.3738
# theta | semiCirc -> R² = -54.4870, R² diff = -0.6857
# Modelo [35, 17, 7] | Ld=0.7 Lp=0.3 r=0.9 seed=2206 salvo.
# [77] model_arch35-17-7_r0.9_Ld0.7_Lp0.3_seed2206.keras -> ok
# theta | ZZxReto -> R² = 0.7768, R² diff = 0.6757
# theta | ZZy1 -> R² = -31.4260, R² diff = 0.0571
# theta | ZZx2 -> R² = -2.6550, R² diff = 0.4458
# theta | ZZy2 -> R² = -0.6151, R² diff = 0.2867
# theta | LSG-1 -> R² = -4.1672, R² diff = 0.5047
# theta | LSG-2 -> R² = -32.3302, R² diff = 0.2252
# theta | ZZx1-inv -> R² = -2.5906, R² diff = 0.4055
# theta | ZZx1 -> R² = -3.0329, R² diff = 0.5915
# theta | ZZx2-inv -> R² = 0.2364, R² diff = 0.3835
# theta | semiCirc -> R² = -58.1375, R² diff = -0.7629
# Modelo [35, 17, 7] | Ld=0.7 Lp=0.3 r=0.9 seed=3318 salvo.
# [78] model_arch35-17-7_r0.9_Ld0.7_Lp0.3_seed3318.keras -> ok
# theta | ZZxReto -> R² = 0.8533, R² diff = 0.6804
# theta | ZZy1 -> R² = -13.0170, R² diff = 0.3206
# theta | ZZx2 -> R² = 0.3805, R² diff = 0.5019
# theta | ZZy2 -> R² = -2.8544, R² diff = 0.2963
# theta | LSG-1 -> R² = -0.7240, R² diff = 0.4909
# theta | LSG-2 -> R² = -30.1090, R² diff = 0.1936
# ...
# theta | ZZxReto -> R² = 0.5492, R² diff = 0.6365
# theta | ZZy1 -> R² = -9.2840, R² diff = 0.3412
# theta | ZZx2 -> R² = 0.9524, R² diff = 0.4826
# theta | ZZy2 -> R² = -3.9777, R² diff = 0.3553
# theta | LSG-1 -> R² = 0.3733, R² diff = 0.4903
# theta | LSG-2 -> R² = -16.5989, R² diff = 0.2741
# theta | ZZx1-inv -> R² = -0.4771, R² diff = 0.4707
# theta | ZZx1 -> R² = -0.9594, R² diff = 0.6089
# theta | ZZx2-inv -> R² = -0.7800, R² diff = 0.2350
# theta | semiCirc -> R² = -24.7392, R² diff = -0.1421
# Modelo [36, 24, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=9017 salvo.
# [1286] model_arch36-24-8_r0.9_Ld0.3_Lp0.7_seed9017.keras -> ok
# theta | ZZxReto -> R² = -1.9652, R² diff = 0.6691
# theta | ZZy1 -> R² = -16.6720, R² diff = 0.1964
# theta | ZZx2 -> R² = 0.5672, R² diff = 0.4858
# theta | ZZy2 -> R² = -1.3163, R² diff = 0.3827
# theta | LSG-1 -> R² = -4.4838, R² diff = 0.5163
# theta | LSG-2 -> R² = -16.9550, R² diff = 0.3562
# theta | ZZx1-inv -> R² = -0.0246, R² diff = 0.5516
# theta | ZZx1 -> R² = -4.0655, R² diff = 0.6192
# theta | ZZx2-inv -> R² = -2.7406, R² diff = 0.1041
# theta | semiCirc -> R² = -47.0537, R² diff = -0.5349
# Modelo [36, 24, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=6260 salvo.
# [1287] model_arch36-24-8_r0.9_Ld0.7_Lp0.3_seed6260.keras -> ok
# theta | ZZxReto -> R² = 0.8216, R² diff = 0.6151
# theta | ZZy1 -> R² = -17.1291, R² diff = 0.2345
# theta | ZZx2 -> R² = -0.1643, R² diff = 0.4747
# theta | ZZy2 -> R² = -3.0307, R² diff = 0.3488
# theta | LSG-1 -> R² = 0.2591, R² diff = 0.4736
# theta | LSG-2 -> R² = -16.8508, R² diff = 0.2792
# theta | ZZx1-inv -> R² = -1.5121, R² diff = 0.5049
# theta | ZZx1 -> R² = -1.0194, R² diff = 0.5928
# theta | ZZx2-inv -> R² = 0.2627, R² diff = 0.3966
# theta | semiCirc -> R² = -24.4589, R² diff = -0.1681
# Modelo [36, 24, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=6996 salvo.
# [1288] model_arch36-24-8_r0.9_Ld0.7_Lp0.3_seed6996.keras -> ok
# theta | ZZxReto -> R² = 0.8951, R² diff = 0.6695
# theta | ZZy1 -> R² = -14.2506, R² diff = 0.3008
# theta | ZZx2 -> R² = -2.3567, R² diff = 0.4163
# theta | ZZy2 -> R² = -2.0168, R² diff = 0.3090
# theta | LSG-1 -> R² = -0.3565, R² diff = 0.4754
# theta | LSG-2 -> R² = -40.9007, R² diff = 0.0917
# theta | ZZx1-inv -> R² = -7.8555, R² diff = 0.2737
# theta | ZZx1 -> R² = -1.6892, R² diff = 0.6064
# theta | ZZx2-inv -> R² = -1.4910, R² diff = 0.1570
# theta | semiCirc -> R² = -34.6684, R² diff = -0.4053
# Modelo [36, 24, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=829 salvo.
# [1289] model_arch36-24-8_r0.9_Ld0.7_Lp0.3_seed829.keras -> ok
# theta | ZZxReto -> R² = 0.8148, R² diff = 0.6946
# theta | ZZy1 -> R² = -15.6425, R² diff = 0.2861
# theta | ZZx2 -> R² = -0.6613, R² diff = 0.4919
# theta | ZZy2 -> R² = -1.4412, R² diff = 0.3119
# theta | LSG-1 -> R² = -1.3655, R² diff = 0.5000
# theta | LSG-2 -> R² = -35.4161, R² diff = 0.1719
# theta | ZZx1-inv -> R² = -4.7132, R² diff = 0.3919
# theta | ZZx1 -> R² = -1.8603, R² diff = 0.6198
# theta | ZZx2-inv -> R² = -0.3464, R² diff = 0.2719
# theta | semiCirc -> R² = -38.8371, R² diff = -0.4291
# Modelo [36, 24, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=8508 salvo.
# [1290] model_arch36-24-8_r0.9_Ld0.7_Lp0.3_seed8508.keras -> ok
# theta | ZZxReto -> R² = 0.1172, R² diff = 0.6569
# theta | ZZy1 -> R² = -14.7979, R² diff = 0.2772
# theta | ZZx2 -> R² = 0.7920, R² diff = 0.4503
# theta | ZZy2 -> R² = -4.0050, R² diff = 0.2982
# theta | LSG-1 -> R² = -2.9200, R² diff = 0.5140
# theta | LSG-2 -> R² = -16.6230, R² diff = 0.3272
# theta | ZZx1-inv -> R² = 0.4783, R² diff = 0.4661
# theta | ZZx1 -> R² = -2.4122, R² diff = 0.6530
# theta | ZZx2-inv -> R² = -7.5342, R² diff = -0.0580
# theta | semiCirc -> R² = -48.3858, R² diff = -0.5640
# Modelo [36, 24, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=9017 salvo.
# [1291] model_arch36-24-8_r0.9_Ld0.7_Lp0.3_seed9017.keras -> ok
# theta | ZZxReto -> R² = 0.1676, R² diff = 0.6579
# theta | ZZy1 -> R² = -17.2822, R² diff = 0.2340
# theta | ZZx2 -> R² = -0.7776, R² diff = 0.4733
# theta | ZZy2 -> R² = -2.1363, R² diff = 0.4085
# theta | LSG-1 -> R² = -2.1233, R² diff = 0.5495
# theta | LSG-2 -> R² = -10.8027, R² diff = 0.3914
# theta | ZZx1-inv -> R² = -0.1205, R² diff = 0.6285
# theta | ZZx1 -> R² = -0.9581, R² diff = 0.6189
# theta | ZZx2-inv -> R² = -2.5226, R² diff = 0.0564
# theta | semiCirc -> R² = -33.7652, R² diff = -0.2536
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=6260 salvo.
# [1292] model_arch36-24-9_r0.01_Ld0.3_Lp0.7_seed6260.keras -> ok
# theta | ZZxReto -> R² = 0.7422, R² diff = 0.6317
# theta | ZZy1 -> R² = -19.2883, R² diff = 0.2100
# theta | ZZx2 -> R² = -1.2897, R² diff = 0.4685
# theta | ZZy2 -> R² = -3.9186, R² diff = 0.3446
# theta | LSG-1 -> R² = -0.2955, R² diff = 0.5438
# theta | LSG-2 -> R² = -11.0304, R² diff = 0.3459
# theta | ZZx1-inv -> R² = -0.4592, R² diff = 0.5711
# theta | ZZx1 -> R² = 0.0084, R² diff = 0.6159
# theta | ZZx2-inv -> R² = -1.1650, R² diff = 0.0318
# theta | semiCirc -> R² = -27.9043, R² diff = -0.1619
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=6996 salvo.
# [1293] model_arch36-24-9_r0.01_Ld0.3_Lp0.7_seed6996.keras -> ok
# theta | ZZxReto -> R² = 0.8265, R² diff = 0.6268
# theta | ZZy1 -> R² = -11.9768, R² diff = 0.2862
# theta | ZZx2 -> R² = -0.0305, R² diff = 0.4671
# theta | ZZy2 -> R² = -5.7074, R² diff = 0.2833
# theta | LSG-1 -> R² = 0.4939, R² diff = 0.4897
# theta | LSG-2 -> R² = -15.8447, R² diff = 0.2520
# theta | ZZx1-inv -> R² = -1.5645, R² diff = 0.4302
# theta | ZZx1 -> R² = -0.6403, R² diff = 0.6062
# theta | ZZx2-inv -> R² = -0.8682, R² diff = 0.0750
# theta | semiCirc -> R² = -26.1200, R² diff = -0.2161
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=829 salvo.
# [1294] model_arch36-24-9_r0.01_Ld0.3_Lp0.7_seed829.keras -> ok
# theta | ZZxReto -> R² = 0.7524, R² diff = 0.6779
# theta | ZZy1 -> R² = -13.0035, R² diff = 0.3069
# theta | ZZx2 -> R² = -2.0099, R² diff = 0.4342
# theta | ZZy2 -> R² = -3.3867, R² diff = 0.3761
# theta | LSG-1 -> R² = 0.1100, R² diff = 0.5680
# theta | LSG-2 -> R² = -9.6627, R² diff = 0.3840
# theta | ZZx1-inv -> R² = -0.0742, R² diff = 0.5683
# theta | ZZx1 -> R² = -0.2077, R² diff = 0.6345
# theta | ZZx2-inv -> R² = -1.0880, R² diff = 0.0507
# theta | semiCirc -> R² = -29.9452, R² diff = -0.2070
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=8508 salvo.
# [1295] model_arch36-24-9_r0.01_Ld0.3_Lp0.7_seed8508.keras -> ok
# theta | ZZxReto -> R² = 0.4000, R² diff = 0.6627
# theta | ZZy1 -> R² = -11.4372, R² diff = 0.3070
# theta | ZZx2 -> R² = 0.1177, R² diff = 0.4701
# theta | ZZy2 -> R² = -5.0261, R² diff = 0.2654
# theta | LSG-1 -> R² = -1.2039, R² diff = 0.5353
# theta | LSG-2 -> R² = -14.3377, R² diff = 0.3293
# theta | ZZx1-inv -> R² = -0.1256, R² diff = 0.5300
# theta | ZZx1 -> R² = -1.1416, R² diff = 0.6452
# theta | ZZx2-inv -> R² = -1.4579, R² diff = 0.1474
# theta | semiCirc -> R² = -36.5211, R² diff = -0.3347
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=9017 salvo.
# [1296] model_arch36-24-9_r0.01_Ld0.3_Lp0.7_seed9017.keras -> ok
# theta | ZZxReto -> R² = -1.3828, R² diff = 0.6943
# theta | ZZy1 -> R² = -21.0709, R² diff = 0.1555
# theta | ZZx2 -> R² = 0.4969, R² diff = 0.4948
# theta | ZZy2 -> R² = -1.0484, R² diff = 0.3692
# theta | LSG-1 -> R² = -5.4079, R² diff = 0.5015
# theta | LSG-2 -> R² = -29.4707, R² diff = 0.2563
# theta | ZZx1-inv -> R² = -2.1786, R² diff = 0.4711
# theta | ZZx1 -> R² = -4.6665, R² diff = 0.6095
# theta | ZZx2-inv -> R² = -1.2450, R² diff = 0.3421
# theta | semiCirc -> R² = -52.9644, R² diff = -0.6652
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=6260 salvo.
# [1297] model_arch36-24-9_r0.01_Ld0.7_Lp0.3_seed6260.keras -> ok
# theta | ZZxReto -> R² = 0.9119, R² diff = 0.7076
# theta | ZZy1 -> R² = -20.5087, R² diff = 0.2504
# theta | ZZx2 -> R² = -0.3053, R² diff = 0.4968
# theta | ZZy2 -> R² = -2.2595, R² diff = 0.3075
# theta | LSG-1 -> R² = -1.6100, R² diff = 0.5203
# theta | LSG-2 -> R² = -30.4811, R² diff = 0.2006
# theta | ZZx1-inv -> R² = -3.5753, R² diff = 0.3827
# theta | ZZx1 -> R² = -1.3912, R² diff = 0.6517
# theta | ZZx2-inv -> R² = -0.2925, R² diff = 0.2529
# theta | semiCirc -> R² = -47.1003, R² diff = -0.5725
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=6996 salvo.
# [1298] model_arch36-24-9_r0.01_Ld0.7_Lp0.3_seed6996.keras -> ok
# theta | ZZxReto -> R² = 0.8786, R² diff = 0.6691
# theta | ZZy1 -> R² = -21.5706, R² diff = 0.1824
# theta | ZZx2 -> R² = -1.2224, R² diff = 0.4664
# theta | ZZy2 -> R² = -4.7992, R² diff = 0.2466
# theta | LSG-1 -> R² = -0.7989, R² diff = 0.4997
# theta | LSG-2 -> R² = -28.0113, R² diff = 0.1731
# theta | ZZx1-inv -> R² = -4.1732, R² diff = 0.3742
# theta | ZZx1 -> R² = -1.5400, R² diff = 0.6240
# theta | ZZx2-inv -> R² = -1.0743, R² diff = 0.0169
# theta | semiCirc -> R² = -36.0870, R² diff = -0.4177
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=829 salvo.
# [1299] model_arch36-24-9_r0.01_Ld0.7_Lp0.3_seed829.keras -> ok
# theta | ZZxReto -> R² = 0.4736, R² diff = 0.7081
# theta | ZZy1 -> R² = -18.4448, R² diff = 0.2535
# theta | ZZx2 -> R² = -2.3996, R² diff = 0.4337
# theta | ZZy2 -> R² = -2.2965, R² diff = 0.3142
# theta | LSG-1 -> R² = -2.3568, R² diff = 0.5338
# theta | LSG-2 -> R² = -31.6490, R² diff = 0.2083
# theta | ZZx1-inv -> R² = -3.9416, R² diff = 0.4311
# theta | ZZx1 -> R² = -2.2574, R² diff = 0.6466
# theta | ZZx2-inv -> R² = -1.2113, R² diff = 0.0476
# theta | semiCirc -> R² = -45.0358, R² diff = -0.5430
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=8508 salvo.
# [1300] model_arch36-24-9_r0.01_Ld0.7_Lp0.3_seed8508.keras -> ok
# theta | ZZxReto -> R² = -0.7822, R² diff = 0.6524
# theta | ZZy1 -> R² = -22.8276, R² diff = 0.1616
# theta | ZZx2 -> R² = 0.7855, R² diff = 0.4650
# theta | ZZy2 -> R² = -2.0289, R² diff = 0.2853
# theta | LSG-1 -> R² = -4.6190, R² diff = 0.4972
# theta | LSG-2 -> R² = -27.0772, R² diff = 0.2630
# theta | ZZx1-inv -> R² = -0.7726, R² diff = 0.4356
# theta | ZZx1 -> R² = -4.7923, R² diff = 0.6380
# theta | ZZx2-inv -> R² = -3.3759, R² diff = 0.1054
# theta | semiCirc -> R² = -53.7933, R² diff = -0.6793
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=9017 salvo.
# [1301] model_arch36-24-9_r0.01_Ld0.7_Lp0.3_seed9017.keras -> ok
# theta | ZZxReto -> R² = -0.7436, R² diff = 0.7016
# theta | ZZy1 -> R² = -9.2808, R² diff = 0.3353
# theta | ZZx2 -> R² = 0.3161, R² diff = 0.4594
# theta | ZZy2 -> R² = -2.4044, R² diff = 0.2892
# theta | LSG-1 -> R² = -4.3844, R² diff = 0.5372
# theta | LSG-2 -> R² = -17.6873, R² diff = 0.3382
# theta | ZZx1-inv -> R² = -0.0942, R² diff = 0.5464
# theta | ZZx1 -> R² = -2.3362, R² diff = 0.6419
# theta | ZZx2-inv -> R² = -3.9758, R² diff = 0.2647
# theta | semiCirc -> R² = -52.9646, R² diff = -0.6525
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=6260 salvo.
# [1302] model_arch36-24-9_r0.9_Ld0.3_Lp0.7_seed6260.keras -> ok
# theta | ZZxReto -> R² = -0.6407, R² diff = 0.6655
# theta | ZZy1 -> R² = -10.5445, R² diff = 0.3064
# theta | ZZx2 -> R² = -0.1896, R² diff = 0.4728
# theta | ZZy2 -> R² = -4.7063, R² diff = 0.2729
# theta | LSG-1 -> R² = -1.9371, R² diff = 0.5324
# theta | LSG-2 -> R² = -15.0590, R² diff = 0.3162
# theta | ZZx1-inv -> R² = -0.6404, R² diff = 0.5223
# theta | ZZx1 -> R² = -2.3544, R² diff = 0.6452
# theta | ZZx2-inv -> R² = -1.8735, R² diff = 0.1342
# theta | semiCirc -> R² = -40.4762, R² diff = -0.4213
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=6996 salvo.
# [1303] model_arch36-24-9_r0.9_Ld0.3_Lp0.7_seed6996.keras -> ok
# theta | ZZxReto -> R² = -1.1392, R² diff = 0.6590
# theta | ZZy1 -> R² = -1.5327, R² diff = 0.5356
# theta | ZZx2 -> R² = -1.9884, R² diff = 0.5289
# theta | ZZy2 -> R² = -0.6988, R² diff = 0.4019
# theta | LSG-1 -> R² = -2.3920, R² diff = 0.5807
# theta | LSG-2 -> R² = -25.6700, R² diff = 0.2833
# theta | ZZx1-inv -> R² = -4.1647, R² diff = 0.4159
# theta | ZZx1 -> R² = -2.9578, R² diff = 0.5975
# theta | ZZx2-inv -> R² = -2.7833, R² diff = 0.1511
# theta | semiCirc -> R² = -45.1105, R² diff = -0.5570
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=829 salvo.
# [1304] model_arch36-24-9_r0.9_Ld0.3_Lp0.7_seed829.keras -> ok
# theta | ZZxReto -> R² = 0.7870, R² diff = 0.6870
# theta | ZZy1 -> R² = -11.3680, R² diff = 0.3708
# theta | ZZx2 -> R² = -0.4347, R² diff = 0.4849
# theta | ZZy2 -> R² = -3.1237, R² diff = 0.3201
# theta | LSG-1 -> R² = 0.1669, R² diff = 0.5289
# theta | LSG-2 -> R² = -22.2419, R² diff = 0.2609
# theta | ZZx1-inv -> R² = -1.0011, R² diff = 0.4449
# theta | ZZx1 -> R² = 0.3856, R² diff = 0.6388
# theta | ZZx2-inv -> R² = 0.1814, R² diff = 0.3604
# theta | semiCirc -> R² = -31.6218, R² diff = -0.2496
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=8508 salvo.
# [1305] model_arch36-24-9_r0.9_Ld0.3_Lp0.7_seed8508.keras -> ok
# theta | ZZxReto -> R² = 0.6086, R² diff = 0.6954
# theta | ZZy1 -> R² = -16.7727, R² diff = 0.2527
# theta | ZZx2 -> R² = -0.3250, R² diff = 0.4310
# theta | ZZy2 -> R² = -0.4283, R² diff = 0.3479
# theta | LSG-1 -> R² = -2.6355, R² diff = 0.5252
# theta | LSG-2 -> R² = -12.5382, R² diff = 0.4108
# theta | ZZx1-inv -> R² = 0.4077, R² diff = 0.6055
# theta | ZZx1 -> R² = -1.3682, R² diff = 0.6130
# theta | ZZx2-inv -> R² = -0.5119, R² diff = 0.5256
# theta | semiCirc -> R² = -43.0197, R² diff = -0.4522
# Modelo [36, 24, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=9017 salvo.
# [1306] model_arch36-24-9_r0.9_Ld0.3_Lp0.7_seed9017.keras -> ok
# theta | ZZxReto -> R² = -0.4018, R² diff = 0.6956
# theta | ZZy1 -> R² = -21.4894, R² diff = 0.1866
# theta | ZZx2 -> R² = -0.0878, R² diff = 0.4805
# theta | ZZy2 -> R² = -2.9375, R² diff = 0.2813
# theta | LSG-1 -> R² = -4.2847, R² diff = 0.5289
# theta | LSG-2 -> R² = -30.0054, R² diff = 0.2237
# theta | ZZx1-inv -> R² = -3.0627, R² diff = 0.4567
# theta | ZZx1 -> R² = -3.1566, R² diff = 0.6451
# theta | ZZx2-inv -> R² = -3.2685, R² diff = -0.1840
# theta | semiCirc -> R² = -47.8263, R² diff = -0.5668
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=6260 salvo.
# [1307] model_arch36-24-9_r0.9_Ld0.7_Lp0.3_seed6260.keras -> ok
# theta | ZZxReto -> R² = 0.1349, R² diff = 0.7012
# theta | ZZy1 -> R² = -15.4822, R² diff = 0.2935
# theta | ZZx2 -> R² = 0.9441, R² diff = 0.4968
# theta | ZZy2 -> R² = -3.2022, R² diff = 0.3348
# theta | LSG-1 -> R² = -1.6215, R² diff = 0.5092
# theta | LSG-2 -> R² = -25.6296, R² diff = 0.2303
# theta | ZZx1-inv -> R² = -1.2479, R² diff = 0.4259
# theta | ZZx1 -> R² = -2.2367, R² diff = 0.6399
# theta | ZZx2-inv -> R² = -1.5400, R² diff = 0.3960
# theta | semiCirc -> R² = -43.9403, R² diff = -0.5064
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=6996 salvo.
# [1308] model_arch36-24-9_r0.9_Ld0.7_Lp0.3_seed6996.keras -> ok
# theta | ZZxReto -> R² = -0.2510, R² diff = 0.6892
# theta | ZZy1 -> R² = -23.5734, R² diff = 0.1625
# theta | ZZx2 -> R² = 0.0921, R² diff = 0.4778
# theta | ZZy2 -> R² = -1.7557, R² diff = 0.3262
# theta | LSG-1 -> R² = -5.2604, R² diff = 0.5202
# theta | LSG-2 -> R² = -24.7030, R² diff = 0.2796
# theta | ZZx1-inv -> R² = -1.2748, R² diff = 0.4979
# theta | ZZx1 -> R² = -3.3920, R² diff = 0.6366
# theta | ZZx2-inv -> R² = -1.9063, R² diff = 0.3602
# theta | semiCirc -> R² = -58.5792, R² diff = -0.7652
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=829 salvo.
# [1309] model_arch36-24-9_r0.9_Ld0.7_Lp0.3_seed829.keras -> ok
# theta | ZZxReto -> R² = -0.2391, R² diff = 0.6312
# theta | ZZy1 -> R² = -49.6762, R² diff = -0.1043
# theta | ZZx2 -> R² = -0.7474, R² diff = 0.4458
# theta | ZZy2 -> R² = -0.4891, R² diff = 0.4323
# theta | LSG-1 -> R² = -1.6590, R² diff = 0.5281
# theta | LSG-2 -> R² = -10.8098, R² diff = 0.4058
# theta | ZZx1-inv -> R² = 0.7139, R² diff = 0.5750
# theta | ZZx1 -> R² = 0.1685, R² diff = 0.5978
# theta | ZZx2-inv -> R² = 0.0403, R² diff = 0.5661
# theta | semiCirc -> R² = -42.9094, R² diff = -0.4486
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=8508 salvo.
# [1310] model_arch36-24-9_r0.9_Ld0.7_Lp0.3_seed8508.keras -> ok
# theta | ZZxReto -> R² = 0.8908, R² diff = 0.6584
# theta | ZZy1 -> R² = -11.5649, R² diff = 0.3308
# theta | ZZx2 -> R² = -1.3467, R² diff = 0.4334
# theta | ZZy2 -> R² = -4.2472, R² diff = 0.2786
# theta | LSG-1 -> R² = 0.1052, R² diff = 0.4628
# theta | LSG-2 -> R² = -35.2535, R² diff = 0.0924
# theta | ZZx1-inv -> R² = -5.8591, R² diff = 0.2750
# theta | ZZx1 -> R² = -1.6677, R² diff = 0.6055
# theta | ZZx2-inv -> R² = -1.5418, R² diff = -0.0884
# theta | semiCirc -> R² = -31.7478, R² diff = -0.3774
# Modelo [36, 24, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=9017 salvo.
# [1311] model_arch36-24-9_r0.9_Ld0.7_Lp0.3_seed9017.keras -> ok
#
# Concluído. 1311 modelos de 3 camadas -> resultados-3l.xlsx
