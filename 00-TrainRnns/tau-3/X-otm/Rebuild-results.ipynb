# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
import re
import os

TITLES = [
    "ZZx1",  # Train
    "ZZx2",  # Val
    "ZZxReto", # test
]

PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a", "costheta"]   
TARGET_INT = ["theta"]  
TARGET = ["dtheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
PLOT = False

# %%
Datasets = []
NormDatasets = []

# Ler Datasets.xlsx
for title in TITLES:
    df = pd.read_excel("./Data/Datasets.xlsx", sheet_name=title)
    Datasets.append(df)

# Ler NormDatasets.xlsx
for title in TITLES:
    df = pd.read_excel("./Data/NormDatasets.xlsx", sheet_name=title)
    NormDatasets.append(df)
    
SCALER = joblib.load("./scalers/scaler.pkl")    
OUT_SCALER = joblib.load("./scalers/out_scaler.pkl")

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):

    #dtheta_cin = (R / (2 * L)) * (phi_d - phi_e)
    dx_cin = (R / 2) * tf.cos(theta) * (phi_d + phi_e)
    # dy_cin = (R / 2) * tf.sin(theta) * (phi_d + phi_e)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin]


def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T, np.vstack(dq).T

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
# Regex para extrair os parâmetros do nome do arquivo
# ex: model_arch36-22_r0.9_Ld0.3_Lp0.7_seed5124.keras
PATTERN = re.compile(
    r"^model_arch(?P<arch>[\d\-]+)_r(?P<r>-?[\d.]+)_Ld(?P<Ld>-?[\d.]+)_Lp(?P<Lp>-?[\d.]+)_seed(?P<seed>\d+)\.keras$"
)

def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_mse = f"MSE_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_mse, []).append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {mse:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"MSE_{safe_title}_{name}"] = to_scalar(metrics[name][f"MSE_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")


def ParseModelFilename(filename):
    m = PATTERN.match(filename)
    if not m:
        return None

    arch = [int(x) for x in m.group("arch").split("-")]
    r    = float(m.group("r"))
    Ld   = float(m.group("Ld"))
    Lp   = float(m.group("Lp"))
    seed = int(m.group("seed"))

    return arch, r, Ld, Lp, seed


def RebuildResultsNL(n_layers, models_dir="models", excel_file=None, verbose=True):
    excel_file = excel_file or f"resultados-{n_layers}l.xlsx"
    if os.path.exists(excel_file):
        os.remove(excel_file)

    all_files = sorted(f for f in os.listdir(models_dir) if f.endswith(".keras"))

    n_found = 0
    for filename in all_files:
        parsed = ParseModelFilename(filename)
        if parsed is None:
            continue

        arch, r, Ld, Lp, seed = parsed
        if len(arch) != n_layers:
            continue

        n_found += 1
        model = tf.keras.saving.load_model(os.path.join(models_dir, filename))
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file)

        if verbose:
            print(f"[{n_found}] {filename} -> ok")

    print(f"\nConcluído. {n_found} modelos de {n_layers} camadas -> {excel_file}")


PLOT = False
RebuildResultsNL(1)   # gera resultados-3l.xlsx
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# theta | ZZx1 -> R² = -0.2373, R² diff = -0.0698
# theta | ZZx2 -> R² = 0.0501, R² diff = -0.1031
# theta | ZZxReto -> R² = -0.3574, R² diff = -0.0891
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.01 seed=4808 salvo.
# [1] model_arch10_r0.01_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.2172, R² diff = -0.0865
# theta | ZZx2 -> R² = 0.0136, R² diff = -0.1345
# theta | ZZxReto -> R² = -0.4597, R² diff = -0.1303
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.01 seed=5973 salvo.
# [2] model_arch10_r0.01_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1425, R² diff = -0.1498
# theta | ZZx2 -> R² = -0.0481, R² diff = -0.0849
# theta | ZZxReto -> R² = -1.8271, R² diff = -0.1588
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.01 seed=8028 salvo.
# [3] model_arch10_r0.01_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.2067, R² diff = -0.1582
# theta | ZZx2 -> R² = -0.2807, R² diff = -0.0492
# theta | ZZxReto -> R² = -2.1041, R² diff = -0.1345
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.01 seed=8266 salvo.
# [4] model_arch10_r0.01_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.2378, R² diff = -0.1697
# theta | ZZx2 -> R² = -0.3728, R² diff = -0.0715
# theta | ZZxReto -> R² = -2.0925, R² diff = -0.1323
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.01 seed=8503 salvo.
# [5] model_arch10_r0.01_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.0775, R² diff = -0.1607
# theta | ZZx2 -> R² = -0.1110, R² diff = -0.0927
# theta | ZZxReto -> R² = -1.7977, R² diff = -0.1689
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.01 seed=4808 salvo.
# [6] model_arch10_r0.01_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1807, R² diff = -0.1453
# theta | ZZx2 -> R² = -0.2299, R² diff = -0.0578
# theta | ZZxReto -> R² = -1.9807, R² diff = -0.1492
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.01 seed=5973 salvo.
# [7] model_arch10_r0.01_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1198, R² diff = -0.1562
# theta | ZZx2 -> R² = -0.3703, R² diff = -0.1080
# theta | ZZxReto -> R² = -1.9437, R² diff = -0.1955
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.01 seed=8028 salvo.
# [8] model_arch10_r0.01_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.2038, R² diff = -0.1486
# theta | ZZx2 -> R² = -0.3216, R² diff = -0.0621
# theta | ZZxReto -> R² = -2.1175, R² diff = -0.1622
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.01 seed=8266 salvo.
# [9] model_arch10_r0.01_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1643, R² diff = -0.1530
# theta | ZZx2 -> R² = -0.1864, R² diff = -0.0634
# theta | ZZxReto -> R² = -1.9095, R² diff = -0.1794
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.01 seed=8503 salvo.
# [10] model_arch10_r0.01_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1326, R² diff = -0.1603
# theta | ZZx2 -> R² = -0.2301, R² diff = -0.0645
# theta | ZZxReto -> R² = -1.9039, R² diff = -0.1506
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.01 seed=4808 salvo.
# [11] model_arch10_r0.01_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1878, R² diff = -0.1655
# theta | ZZx2 -> R² = -0.4262, R² diff = -0.0720
# theta | ZZxReto -> R² = -1.9658, R² diff = -0.1409
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.01 seed=5973 salvo.
# [12] model_arch10_r0.01_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1741, R² diff = -0.1632
# theta | ZZx2 -> R² = -0.2225, R² diff = -0.0815
# theta | ZZxReto -> R² = -1.8411, R² diff = -0.1224
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.01 seed=8028 salvo.
# [13] model_arch10_r0.01_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.2325, R² diff = -0.0860
# theta | ZZx2 -> R² = 0.0351, R² diff = -0.1267
# theta | ZZxReto -> R² = -0.4877, R² diff = -0.1259
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.01 seed=8266 salvo.
# [14] model_arch10_r0.01_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1322, R² diff = -0.1555
# theta | ZZx2 -> R² = -0.2420, R² diff = -0.0759
# theta | ZZxReto -> R² = -1.9417, R² diff = -0.1873
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.01 seed=8503 salvo.
# [15] model_arch10_r0.01_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -0.2124, R² diff = -0.0735
# theta | ZZx2 -> R² = 0.0413, R² diff = -0.1099
# theta | ZZxReto -> R² = -0.3887, R² diff = -0.0989
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.9 seed=4808 salvo.
# [16] model_arch10_r0.9_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.2094, R² diff = -0.1583
# theta | ZZx2 -> R² = -0.2079, R² diff = -0.0783
# theta | ZZxReto -> R² = -2.0103, R² diff = -0.1608
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.9 seed=5973 salvo.
# [17] model_arch10_r0.9_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1544, R² diff = -0.0612
# theta | ZZx2 -> R² = 0.0653, R² diff = -0.0928
# theta | ZZxReto -> R² = -0.3407, R² diff = -0.0652
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.9 seed=8028 salvo.
# [18] model_arch10_r0.9_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.2658, R² diff = -0.0831
# theta | ZZx2 -> R² = 0.0421, R² diff = -0.1244
# theta | ZZxReto -> R² = -0.4708, R² diff = -0.1212
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.9 seed=8266 salvo.
# [19] model_arch10_r0.9_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.2273, R² diff = -0.0853
# theta | ZZx2 -> R² = 0.0161, R² diff = -0.1268
# theta | ZZxReto -> R² = -0.4520, R² diff = -0.1225
# Modelo [10] | Ld=0.3 Lp=0.7 r=0.9 seed=8503 salvo.
# [20] model_arch10_r0.9_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -0.2432, R² diff = -0.0718
# theta | ZZx2 -> R² = 0.0653, R² diff = -0.1008
# theta | ZZxReto -> R² = -0.3882, R² diff = -0.0910
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.9 seed=4808 salvo.
# [21] model_arch10_r0.9_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1778, R² diff = -0.1574
# theta | ZZx2 -> R² = -0.2844, R² diff = -0.0803
# theta | ZZxReto -> R² = -1.9651, R² diff = -0.1761
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.9 seed=5973 salvo.
# [22] model_arch10_r0.9_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.2031, R² diff = -0.0736
# theta | ZZx2 -> R² = 0.0652, R² diff = -0.1104
# theta | ZZxReto -> R² = -0.4218, R² diff = -0.0976
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.9 seed=8028 salvo.
# [23] model_arch10_r0.9_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.2059, R² diff = -0.0776
# theta | ZZx2 -> R² = 0.0408, R² diff = -0.1153
# theta | ZZxReto -> R² = -0.4274, R² diff = -0.1040
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.9 seed=8266 salvo.
# [24] model_arch10_r0.9_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1738, R² diff = -0.1456
# theta | ZZx2 -> R² = -0.2347, R² diff = -0.0584
# theta | ZZxReto -> R² = -1.8539, R² diff = -0.1457
# Modelo [10] | Ld=0.5 Lp=0.5 r=0.9 seed=8503 salvo.
# [25] model_arch10_r0.9_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1225, R² diff = -0.1646
# theta | ZZx2 -> R² = -0.0956, R² diff = -0.0949
# theta | ZZxReto -> R² = -1.8310, R² diff = -0.1399
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.9 seed=4808 salvo.
# [26] model_arch10_r0.9_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.2486, R² diff = -0.0900
# theta | ZZx2 -> R² = 0.0233, R² diff = -0.1345
# theta | ZZxReto -> R² = -0.5086, R² diff = -0.1350
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.9 seed=5973 salvo.
# [27] model_arch10_r0.9_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.2062, R² diff = -0.1602
# theta | ZZx2 -> R² = -0.4753, R² diff = -0.0685
# theta | ZZxReto -> R² = -2.0053, R² diff = -0.1336
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.9 seed=8028 salvo.
# [28] model_arch10_r0.9_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.3025, R² diff = -0.0848
# theta | ZZx2 -> R² = 0.0697, R² diff = -0.1173
# theta | ZZxReto -> R² = -0.5237, R² diff = -0.1207
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.9 seed=8266 salvo.
# [29] model_arch10_r0.9_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.0321, R² diff = -0.1649
# theta | ZZx2 -> R² = -0.1974, R² diff = -0.1105
# theta | ZZxReto -> R² = -1.6058, R² diff = -0.1892
# Modelo [10] | Ld=0.7 Lp=0.3 r=0.9 seed=8503 salvo.
# [30] model_arch10_r0.9_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1291, R² diff = -0.1637
# theta | ZZx2 -> R² = 0.0551, R² diff = -0.0856
# theta | ZZxReto -> R² = -1.9046, R² diff = -0.1576
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.01 seed=4808 salvo.
# [31] model_arch11_r0.01_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.1731, R² diff = -0.0596
# theta | ZZx2 -> R² = 0.0704, R² diff = -0.0979
# theta | ZZxReto -> R² = -0.3294, R² diff = -0.0698
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.01 seed=5973 salvo.
# [32] model_arch11_r0.01_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.2268, R² diff = -0.0725
# theta | ZZx2 -> R² = 0.0200, R² diff = -0.1081
# theta | ZZxReto -> R² = -0.3465, R² diff = -0.0829
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.01 seed=8028 salvo.
# [33] model_arch11_r0.01_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.1823, R² diff = -0.0739
# theta | ZZx2 -> R² = 0.0623, R² diff = -0.1145
# theta | ZZxReto -> R² = -0.4216, R² diff = -0.1007
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.01 seed=8266 salvo.
# [34] model_arch11_r0.01_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.0937, R² diff = -0.1670
# theta | ZZx2 -> R² = -0.2952, R² diff = -0.1175
# theta | ZZxReto -> R² = -1.7020, R² diff = -0.1886
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.01 seed=8503 salvo.
# [35] model_arch11_r0.01_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1913, R² diff = -0.1511
# theta | ZZx2 -> R² = -0.3096, R² diff = -0.0763
# theta | ZZxReto -> R² = -2.2659, R² diff = -0.1535
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.01 seed=4808 salvo.
# [36] model_arch11_r0.01_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1507, R² diff = -0.1485
# theta | ZZx2 -> R² = -0.2701, R² diff = -0.0580
# theta | ZZxReto -> R² = -1.9892, R² diff = -0.1523
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.01 seed=5973 salvo.
# [37] model_arch11_r0.01_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1426, R² diff = -0.0639
# theta | ZZx2 -> R² = -0.0090, R² diff = -0.1010
# theta | ZZxReto -> R² = -0.3061, R² diff = -0.0739
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.01 seed=8028 salvo.
# [38] model_arch11_r0.01_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1628, R² diff = -0.1591
# theta | ZZx2 -> R² = -0.3255, R² diff = -0.0633
# theta | ZZxReto -> R² = -1.8852, R² diff = -0.1358
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.01 seed=8266 salvo.
# [39] model_arch11_r0.01_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1573, R² diff = -0.1667
# theta | ZZx2 -> R² = -0.0814, R² diff = -0.0975
# theta | ZZxReto -> R² = -1.7664, R² diff = -0.1280
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.01 seed=8503 salvo.
# [40] model_arch11_r0.01_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1388, R² diff = -0.1708
# theta | ZZx2 -> R² = -0.3148, R² diff = -0.1320
# theta | ZZxReto -> R² = -1.7939, R² diff = -0.1839
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.01 seed=4808 salvo.
# [41] model_arch11_r0.01_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.0816, R² diff = -0.1669
# theta | ZZx2 -> R² = 0.0231, R² diff = -0.0901
# theta | ZZxReto -> R² = -1.8268, R² diff = -0.1547
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.01 seed=5973 salvo.
# [42] model_arch11_r0.01_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1654, R² diff = -0.1596
# theta | ZZx2 -> R² = -0.3496, R² diff = -0.0738
# theta | ZZxReto -> R² = -1.9128, R² diff = -0.1299
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.01 seed=8028 salvo.
# [43] model_arch11_r0.01_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1700, R² diff = -0.1590
# theta | ZZx2 -> R² = -0.2630, R² diff = -0.0791
# theta | ZZxReto -> R² = -1.9604, R² diff = -0.1341
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.01 seed=8266 salvo.
# [44] model_arch11_r0.01_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.2140, R² diff = -0.0696
# theta | ZZx2 -> R² = 0.0288, R² diff = -0.1061
# theta | ZZxReto -> R² = -0.3566, R² diff = -0.0871
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.01 seed=8503 salvo.
# [45] model_arch11_r0.01_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1274, R² diff = -0.1707
# theta | ZZx2 -> R² = -0.3177, R² diff = -0.1281
# theta | ZZxReto -> R² = -1.7522, R² diff = -0.1971
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.9 seed=4808 salvo.
# [46] model_arch11_r0.9_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.2406, R² diff = -0.0663
# theta | ZZx2 -> R² = 0.0969, R² diff = -0.0962
# theta | ZZxReto -> R² = -0.3860, R² diff = -0.0777
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.9 seed=5973 salvo.
# [47] model_arch11_r0.9_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1707, R² diff = -0.1653
# theta | ZZx2 -> R² = -0.1634, R² diff = -0.0735
# theta | ZZxReto -> R² = -1.8174, R² diff = -0.1204
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.9 seed=8028 salvo.
# [48] model_arch11_r0.9_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1506, R² diff = -0.1719
# theta | ZZx2 -> R² = -0.2013, R² diff = -0.1152
# theta | ZZxReto -> R² = -1.8025, R² diff = -0.1647
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.9 seed=8266 salvo.
# [49] model_arch11_r0.9_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.2384, R² diff = -0.1725
# theta | ZZx2 -> R² = -0.4673, R² diff = -0.0853
# theta | ZZxReto -> R² = -2.1492, R² diff = -0.1343
# Modelo [11] | Ld=0.3 Lp=0.7 r=0.9 seed=8503 salvo.
# [50] model_arch11_r0.9_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1806, R² diff = -0.1656
# theta | ZZx2 -> R² = -0.2234, R² diff = -0.0848
# theta | ZZxReto -> R² = -1.9980, R² diff = -0.1655
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.9 seed=4808 salvo.
# [51] model_arch11_r0.9_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1591, R² diff = -0.1503
# theta | ZZx2 -> R² = -0.2455, R² diff = -0.0424
# theta | ZZxReto -> R² = -1.9099, R² diff = -0.1528
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.9 seed=5973 salvo.
# [52] model_arch11_r0.9_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1968, R² diff = -0.0710
# theta | ZZx2 -> R² = -0.0010, R² diff = -0.1058
# theta | ZZxReto -> R² = -0.3362, R² diff = -0.0887
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.9 seed=8028 salvo.
# [53] model_arch11_r0.9_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1872, R² diff = -0.1436
# theta | ZZx2 -> R² = -0.3561, R² diff = -0.0481
# theta | ZZxReto -> R² = -2.4090, R² diff = -0.1729
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.9 seed=8266 salvo.
# [54] model_arch11_r0.9_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.0852, R² diff = -0.1622
# theta | ZZx2 -> R² = 0.0639, R² diff = -0.1040
# theta | ZZxReto -> R² = -1.7465, R² diff = -0.1518
# Modelo [11] | Ld=0.5 Lp=0.5 r=0.9 seed=8503 salvo.
# [55] model_arch11_r0.9_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1572, R² diff = -0.1495
# theta | ZZx2 -> R² = -0.3102, R² diff = -0.0653
# theta | ZZxReto -> R² = -2.1584, R² diff = -0.1631
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.9 seed=4808 salvo.
# [56] model_arch11_r0.9_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.2245, R² diff = -0.0689
# theta | ZZx2 -> R² = 0.1028, R² diff = -0.0969
# theta | ZZxReto -> R² = -0.4134, R² diff = -0.0819
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.9 seed=5973 salvo.
# [57] model_arch11_r0.9_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.0961, R² diff = -0.1626
# theta | ZZx2 -> R² = -0.1403, R² diff = -0.0926
# theta | ZZxReto -> R² = -1.8992, R² diff = -0.1424
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.9 seed=8028 salvo.
# [58] model_arch11_r0.9_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1788, R² diff = -0.1658
# theta | ZZx2 -> R² = -0.2845, R² diff = -0.0590
# theta | ZZxReto -> R² = -1.8869, R² diff = -0.1276
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.9 seed=8266 salvo.
# [59] model_arch11_r0.9_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.2466, R² diff = -0.0779
# theta | ZZx2 -> R² = 0.0693, R² diff = -0.1072
# theta | ZZxReto -> R² = -0.4592, R² diff = -0.1025
# Modelo [11] | Ld=0.7 Lp=0.3 r=0.9 seed=8503 salvo.
# [60] model_arch11_r0.9_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1925, R² diff = -0.1512
# theta | ZZx2 -> R² = -0.2647, R² diff = -0.0659
# theta | ZZxReto -> R² = -2.0491, R² diff = -0.1721
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.01 seed=4808 salvo.
# [61] model_arch12_r0.01_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.1279, R² diff = -0.0586
# theta | ZZx2 -> R² = 0.1156, R² diff = -0.0889
# theta | ZZxReto -> R² = -0.3741, R² diff = -0.0741
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.01 seed=5973 salvo.
# [62] model_arch12_r0.01_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1415, R² diff = -0.0582
# theta | ZZx2 -> R² = -0.0019, R² diff = -0.0893
# theta | ZZxReto -> R² = -0.2911, R² diff = -0.0511
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.01 seed=8028 salvo.
# [63] model_arch12_r0.01_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1982, R² diff = -0.1521
# theta | ZZx2 -> R² = -0.2173, R² diff = -0.0599
# theta | ZZxReto -> R² = -1.8537, R² diff = -0.1546
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.01 seed=8266 salvo.
# [64] model_arch12_r0.01_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1252, R² diff = -0.1773
# theta | ZZx2 -> R² = -0.1080, R² diff = -0.1173
# theta | ZZxReto -> R² = -1.8179, R² diff = -0.1607
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.01 seed=8503 salvo.
# [65] model_arch12_r0.01_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1728, R² diff = -0.1566
# theta | ZZx2 -> R² = -0.3001, R² diff = -0.0714
# theta | ZZxReto -> R² = -2.0363, R² diff = -0.1616
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.01 seed=4808 salvo.
# [66] model_arch12_r0.01_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.1769, R² diff = -0.0751
# theta | ZZx2 -> R² = 0.0541, R² diff = -0.1111
# theta | ZZxReto -> R² = -0.4247, R² diff = -0.1015
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.01 seed=5973 salvo.
# [67] model_arch12_r0.01_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.0607, R² diff = -0.1586
# theta | ZZx2 -> R² = -0.1217, R² diff = -0.0894
# theta | ZZxReto -> R² = -1.6854, R² diff = -0.1464
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.01 seed=8028 salvo.
# [68] model_arch12_r0.01_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1601, R² diff = -0.1594
# theta | ZZx2 -> R² = -0.2025, R² diff = -0.0874
# theta | ZZxReto -> R² = -1.9482, R² diff = -0.1677
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.01 seed=8266 salvo.
# [69] model_arch12_r0.01_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1752, R² diff = -0.1590
# theta | ZZx2 -> R² = -0.5276, R² diff = -0.0714
# theta | ZZxReto -> R² = -1.9395, R² diff = -0.1155
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.01 seed=8503 salvo.
# [70] model_arch12_r0.01_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1793, R² diff = -0.1422
# theta | ZZx2 -> R² = -0.3563, R² diff = -0.0769
# theta | ZZxReto -> R² = -2.0691, R² diff = -0.1810
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.01 seed=4808 salvo.
# [71] model_arch12_r0.01_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1408, R² diff = -0.1467
# theta | ZZx2 -> R² = -0.2557, R² diff = -0.0529
# theta | ZZxReto -> R² = -2.0583, R² diff = -0.1557
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.01 seed=5973 salvo.
# [72] model_arch12_r0.01_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1009, R² diff = -0.1615
# theta | ZZx2 -> R² = -0.2301, R² diff = -0.1010
# theta | ZZxReto -> R² = -1.8834, R² diff = -0.1675
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.01 seed=8028 salvo.
# [73] model_arch12_r0.01_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.1993, R² diff = -0.0792
# theta | ZZx2 -> R² = 0.0442, R² diff = -0.1201
# theta | ZZxReto -> R² = -0.4428, R² diff = -0.1078
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.01 seed=8266 salvo.
# [74] model_arch12_r0.01_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1581, R² diff = -0.1710
# theta | ZZx2 -> R² = -0.3930, R² diff = -0.0888
# theta | ZZxReto -> R² = -1.8869, R² diff = -0.1164
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.01 seed=8503 salvo.
# [75] model_arch12_r0.01_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1184, R² diff = -0.1607
# theta | ZZx2 -> R² = -0.1343, R² diff = -0.0872
# theta | ZZxReto -> R² = -1.7900, R² diff = -0.1635
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.9 seed=4808 salvo.
# [76] model_arch12_r0.9_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.1756, R² diff = -0.0699
# theta | ZZx2 -> R² = 0.0622, R² diff = -0.1116
# theta | ZZxReto -> R² = -0.3963, R² diff = -0.0949
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.9 seed=5973 salvo.
# [77] model_arch12_r0.9_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.2033, R² diff = -0.0693
# theta | ZZx2 -> R² = 0.0398, R² diff = -0.0985
# theta | ZZxReto -> R² = -0.3581, R² diff = -0.0742
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.9 seed=8028 salvo.
# [78] model_arch12_r0.9_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.2076, R² diff = -0.0866
# theta | ZZx2 -> R² = 0.0109, R² diff = -0.1321
# theta | ZZxReto -> R² = -0.4540, R² diff = -0.1224
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.9 seed=8266 salvo.
# [79] model_arch12_r0.9_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1980, R² diff = -0.1586
# theta | ZZx2 -> R² = -0.1433, R² diff = -0.0777
# theta | ZZxReto -> R² = -1.9249, R² diff = -0.1637
# Modelo [12] | Ld=0.3 Lp=0.7 r=0.9 seed=8503 salvo.
# [80] model_arch12_r0.9_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1618, R² diff = -0.1538
# theta | ZZx2 -> R² = -0.2651, R² diff = -0.0664
# theta | ZZxReto -> R² = -2.0416, R² diff = -0.1415
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.9 seed=4808 salvo.
# [81] model_arch12_r0.9_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1893, R² diff = -0.1385
# theta | ZZx2 -> R² = -0.2964, R² diff = -0.0411
# theta | ZZxReto -> R² = -1.9663, R² diff = -0.1608
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.9 seed=5973 salvo.
# [82] model_arch12_r0.9_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1653, R² diff = -0.1468
# theta | ZZx2 -> R² = -0.3033, R² diff = -0.0462
# theta | ZZxReto -> R² = -1.8719, R² diff = -0.1402
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.9 seed=8028 salvo.
# [83] model_arch12_r0.9_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1751, R² diff = -0.1697
# theta | ZZx2 -> R² = -0.3814, R² diff = -0.0934
# theta | ZZxReto -> R² = -1.8180, R² diff = -0.1317
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.9 seed=8266 salvo.
# [84] model_arch12_r0.9_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1186, R² diff = -0.1501
# theta | ZZx2 -> R² = -0.1738, R² diff = -0.0808
# theta | ZZxReto -> R² = -2.0471, R² diff = -0.1773
# Modelo [12] | Ld=0.5 Lp=0.5 r=0.9 seed=8503 salvo.
# [85] model_arch12_r0.9_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -0.9822, R² diff = -0.1764
# theta | ZZx2 -> R² = -0.5004, R² diff = -0.1439
# theta | ZZxReto -> R² = -1.8352, R² diff = -0.2441
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.9 seed=4808 salvo.
# [86] model_arch12_r0.9_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1356, R² diff = -0.1495
# theta | ZZx2 -> R² = -0.2134, R² diff = -0.0704
# theta | ZZxReto -> R² = -2.0573, R² diff = -0.1720
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.9 seed=5973 salvo.
# [87] model_arch12_r0.9_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1762, R² diff = -0.0657
# theta | ZZx2 -> R² = 0.0295, R² diff = -0.0955
# theta | ZZxReto -> R² = -0.3387, R² diff = -0.0733
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.9 seed=8028 salvo.
# [88] model_arch12_r0.9_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1794, R² diff = -0.1647
# theta | ZZx2 -> R² = -0.3092, R² diff = -0.0590
# theta | ZZxReto -> R² = -1.9690, R² diff = -0.1266
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.9 seed=8266 salvo.
# [89] model_arch12_r0.9_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1348, R² diff = -0.1605
# theta | ZZx2 -> R² = -0.2400, R² diff = -0.0826
# theta | ZZxReto -> R² = -1.8432, R² diff = -0.1252
# Modelo [12] | Ld=0.7 Lp=0.3 r=0.9 seed=8503 salvo.
# [90] model_arch12_r0.9_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1308, R² diff = -0.1485
# theta | ZZx2 -> R² = -0.2895, R² diff = -0.0727
# theta | ZZxReto -> R² = -2.1647, R² diff = -0.1771
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.01 seed=4808 salvo.
# [91] model_arch13_r0.01_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1292, R² diff = -0.1480
# theta | ZZx2 -> R² = -0.1938, R² diff = -0.0766
# theta | ZZxReto -> R² = -2.1405, R² diff = -0.1793
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.01 seed=5973 salvo.
# [92] model_arch13_r0.01_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1176, R² diff = -0.0610
# theta | ZZx2 -> R² = 0.0162, R² diff = -0.0997
# theta | ZZxReto -> R² = -0.3052, R² diff = -0.0720
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.01 seed=8028 salvo.
# [93] model_arch13_r0.01_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.0782, R² diff = -0.1739
# theta | ZZx2 -> R² = -0.0835, R² diff = -0.1110
# theta | ZZxReto -> R² = -1.9426, R² diff = -0.1890
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.01 seed=8266 salvo.
# [94] model_arch13_r0.01_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1607, R² diff = -0.1632
# theta | ZZx2 -> R² = -0.2753, R² diff = -0.1173
# theta | ZZxReto -> R² = -2.0804, R² diff = -0.1870
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.01 seed=8503 salvo.
# [95] model_arch13_r0.01_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1697, R² diff = -0.1532
# theta | ZZx2 -> R² = -0.3119, R² diff = -0.0528
# theta | ZZxReto -> R² = -2.1319, R² diff = -0.1612
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.01 seed=4808 salvo.
# [96] model_arch13_r0.01_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1181, R² diff = -0.1626
# theta | ZZx2 -> R² = -0.1304, R² diff = -0.0745
# theta | ZZxReto -> R² = -1.8214, R² diff = -0.1686
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.01 seed=5973 salvo.
# [97] model_arch13_r0.01_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1154, R² diff = -0.0629
# theta | ZZx2 -> R² = 0.0069, R² diff = -0.1056
# theta | ZZxReto -> R² = -0.3072, R² diff = -0.0793
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.01 seed=8028 salvo.
# [98] model_arch13_r0.01_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1999, R² diff = -0.1478
# theta | ZZx2 -> R² = -0.3418, R² diff = -0.0500
# theta | ZZxReto -> R² = -1.9743, R² diff = -0.1578
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.01 seed=8266 salvo.
# [99] model_arch13_r0.01_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1704, R² diff = -0.1394
# theta | ZZx2 -> R² = -0.3146, R² diff = -0.0471
# theta | ZZxReto -> R² = -2.1497, R² diff = -0.1657
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.01 seed=8503 salvo.
# [100] model_arch13_r0.01_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1178, R² diff = -0.1517
# theta | ZZx2 -> R² = -0.2214, R² diff = -0.0741
# theta | ZZxReto -> R² = -2.0038, R² diff = -0.1886
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.01 seed=4808 salvo.
# [101] model_arch13_r0.01_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1515, R² diff = -0.1429
# theta | ZZx2 -> R² = -0.3783, R² diff = -0.0613
# theta | ZZxReto -> R² = -2.2600, R² diff = -0.1714
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.01 seed=5973 salvo.
# [102] model_arch13_r0.01_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1439, R² diff = -0.0553
# theta | ZZx2 -> R² = 0.0630, R² diff = -0.0841
# theta | ZZxReto -> R² = -0.2895, R² diff = -0.0587
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.01 seed=8028 salvo.
# [103] model_arch13_r0.01_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1384, R² diff = -0.1572
# theta | ZZx2 -> R² = -0.1803, R² diff = -0.0753
# theta | ZZxReto -> R² = -1.8109, R² diff = -0.1377
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.01 seed=8266 salvo.
# [104] model_arch13_r0.01_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1555, R² diff = -0.1572
# theta | ZZx2 -> R² = -0.3467, R² diff = -0.0605
# theta | ZZxReto -> R² = -1.8294, R² diff = -0.1328
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.01 seed=8503 salvo.
# [105] model_arch13_r0.01_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1718, R² diff = -0.1451
# theta | ZZx2 -> R² = -0.2536, R² diff = -0.0583
# theta | ZZxReto -> R² = -2.2021, R² diff = -0.1634
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.9 seed=4808 salvo.
# [106] model_arch13_r0.9_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.2364, R² diff = -0.1432
# theta | ZZx2 -> R² = -0.3869, R² diff = -0.0359
# theta | ZZxReto -> R² = -2.0893, R² diff = -0.1642
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.9 seed=5973 salvo.
# [107] model_arch13_r0.9_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1553, R² diff = -0.1556
# theta | ZZx2 -> R² = -0.1829, R² diff = -0.0712
# theta | ZZxReto -> R² = -2.1087, R² diff = -0.1477
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.9 seed=8028 salvo.
# [108] model_arch13_r0.9_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.2362, R² diff = -0.1469
# theta | ZZx2 -> R² = -0.3659, R² diff = -0.0405
# theta | ZZxReto -> R² = -2.1775, R² diff = -0.1685
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.9 seed=8266 salvo.
# [109] model_arch13_r0.9_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1560, R² diff = -0.1707
# theta | ZZx2 -> R² = -0.1340, R² diff = -0.1046
# theta | ZZxReto -> R² = -1.9862, R² diff = -0.1710
# Modelo [13] | Ld=0.3 Lp=0.7 r=0.9 seed=8503 salvo.
# [110] model_arch13_r0.9_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1453, R² diff = -0.1599
# theta | ZZx2 -> R² = -0.2405, R² diff = -0.0788
# theta | ZZxReto -> R² = -2.0099, R² diff = -0.1768
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.9 seed=4808 salvo.
# [111] model_arch13_r0.9_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1597, R² diff = -0.1421
# theta | ZZx2 -> R² = -0.3083, R² diff = -0.0624
# theta | ZZxReto -> R² = -2.0410, R² diff = -0.1712
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.9 seed=5973 salvo.
# [112] model_arch13_r0.9_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.2213, R² diff = -0.1597
# theta | ZZx2 -> R² = -0.6403, R² diff = -0.0482
# theta | ZZxReto -> R² = -2.5246, R² diff = -0.1647
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.9 seed=8028 salvo.
# [113] model_arch13_r0.9_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1391, R² diff = -0.1470
# theta | ZZx2 -> R² = -0.2026, R² diff = -0.0726
# theta | ZZxReto -> R² = -2.1833, R² diff = -0.1782
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.9 seed=8266 salvo.
# [114] model_arch13_r0.9_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.1142, R² diff = -0.0592
# theta | ZZx2 -> R² = 0.0685, R² diff = -0.0971
# theta | ZZxReto -> R² = -0.3206, R² diff = -0.0743
# Modelo [13] | Ld=0.5 Lp=0.5 r=0.9 seed=8503 salvo.
# [115] model_arch13_r0.9_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.0897, R² diff = -0.1479
# theta | ZZx2 -> R² = -0.2912, R² diff = -0.0848
# theta | ZZxReto -> R² = -2.1893, R² diff = -0.1852
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.9 seed=4808 salvo.
# [116] model_arch13_r0.9_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.0657, R² diff = -0.1556
# theta | ZZx2 -> R² = -0.1277, R² diff = -0.0969
# theta | ZZxReto -> R² = -1.9088, R² diff = -0.1874
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.9 seed=5973 salvo.
# [117] model_arch13_r0.9_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1453, R² diff = -0.1504
# theta | ZZx2 -> R² = -0.2786, R² diff = -0.0539
# theta | ZZxReto -> R² = -2.0154, R² diff = -0.1475
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.9 seed=8028 salvo.
# [118] model_arch13_r0.9_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1050, R² diff = -0.1497
# theta | ZZx2 -> R² = -0.2092, R² diff = -0.0824
# theta | ZZxReto -> R² = -2.0858, R² diff = -0.1830
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.9 seed=8266 salvo.
# [119] model_arch13_r0.9_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1048, R² diff = -0.1531
# theta | ZZx2 -> R² = -0.2249, R² diff = -0.0700
# theta | ZZxReto -> R² = -1.7901, R² diff = -0.1544
# Modelo [13] | Ld=0.7 Lp=0.3 r=0.9 seed=8503 salvo.
# [120] model_arch13_r0.9_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1680, R² diff = -0.1598
# theta | ZZx2 -> R² = -0.2508, R² diff = -0.0693
# theta | ZZxReto -> R² = -1.9106, R² diff = -0.1447
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.01 seed=4808 salvo.
# [121] model_arch14_r0.01_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1159, R² diff = -0.1624
# theta | ZZx2 -> R² = -0.1175, R² diff = -0.0998
# theta | ZZxReto -> R² = -1.8767, R² diff = -0.1551
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.01 seed=5973 salvo.
# [122] model_arch14_r0.01_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1509, R² diff = -0.1516
# theta | ZZx2 -> R² = -0.1994, R² diff = -0.0845
# theta | ZZxReto -> R² = -2.0883, R² diff = -0.1662
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.01 seed=8028 salvo.
# [123] model_arch14_r0.01_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1323, R² diff = -0.1656
# theta | ZZx2 -> R² = -0.1570, R² diff = -0.0886
# theta | ZZxReto -> R² = -1.8340, R² diff = -0.1516
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.01 seed=8266 salvo.
# [124] model_arch14_r0.01_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1776, R² diff = -0.1391
# theta | ZZx2 -> R² = -0.2936, R² diff = -0.0481
# theta | ZZxReto -> R² = -2.0814, R² diff = -0.1685
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.01 seed=8503 salvo.
# [125] model_arch14_r0.01_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1494, R² diff = -0.1523
# theta | ZZx2 -> R² = -0.2676, R² diff = -0.0766
# theta | ZZxReto -> R² = -2.0039, R² diff = -0.1526
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.01 seed=4808 salvo.
# [126] model_arch14_r0.01_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1654, R² diff = -0.1542
# theta | ZZx2 -> R² = -0.2416, R² diff = -0.0713
# theta | ZZxReto -> R² = -1.8821, R² diff = -0.1627
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.01 seed=5973 salvo.
# [127] model_arch14_r0.01_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1134, R² diff = -0.1485
# theta | ZZx2 -> R² = -0.2410, R² diff = -0.0724
# theta | ZZxReto -> R² = -2.1562, R² diff = -0.1748
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.01 seed=8028 salvo.
# [128] model_arch14_r0.01_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1893, R² diff = -0.1458
# theta | ZZx2 -> R² = -0.3768, R² diff = -0.0528
# theta | ZZxReto -> R² = -1.9968, R² diff = -0.1438
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.01 seed=8266 salvo.
# [129] model_arch14_r0.01_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1664, R² diff = -0.1538
# theta | ZZx2 -> R² = -0.2902, R² diff = -0.0650
# theta | ZZxReto -> R² = -2.1507, R² diff = -0.1590
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.01 seed=8503 salvo.
# [130] model_arch14_r0.01_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1569, R² diff = -0.1674
# theta | ZZx2 -> R² = -0.3198, R² diff = -0.0726
# theta | ZZxReto -> R² = -2.0135, R² diff = -0.1585
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.01 seed=4808 salvo.
# [131] model_arch14_r0.01_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1050, R² diff = -0.1623
# theta | ZZx2 -> R² = -0.1779, R² diff = -0.1000
# theta | ZZxReto -> R² = -1.9099, R² diff = -0.1750
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.01 seed=5973 salvo.
# [132] model_arch14_r0.01_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.0855, R² diff = -0.1435
# theta | ZZx2 -> R² = -0.2953, R² diff = -0.0784
# theta | ZZxReto -> R² = -2.0636, R² diff = -0.1736
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.01 seed=8028 salvo.
# [133] model_arch14_r0.01_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1044, R² diff = -0.1442
# theta | ZZx2 -> R² = -0.3033, R² diff = -0.0773
# theta | ZZxReto -> R² = -2.2118, R² diff = -0.1761
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.01 seed=8266 salvo.
# [134] model_arch14_r0.01_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1035, R² diff = -0.1514
# theta | ZZx2 -> R² = -0.2739, R² diff = -0.0668
# theta | ZZxReto -> R² = -1.9578, R² diff = -0.1648
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.01 seed=8503 salvo.
# [135] model_arch14_r0.01_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1460, R² diff = -0.1548
# theta | ZZx2 -> R² = -0.2584, R² diff = -0.0961
# theta | ZZxReto -> R² = -1.9794, R² diff = -0.1821
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.9 seed=4808 salvo.
# [136] model_arch14_r0.9_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1769, R² diff = -0.1468
# theta | ZZx2 -> R² = -0.3807, R² diff = -0.0640
# theta | ZZxReto -> R² = -2.2424, R² diff = -0.1690
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.9 seed=5973 salvo.
# [137] model_arch14_r0.9_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1083, R² diff = -0.0630
# theta | ZZx2 -> R² = -0.0239, R² diff = -0.1055
# theta | ZZxReto -> R² = -0.3040, R² diff = -0.0768
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.9 seed=8028 salvo.
# [138] model_arch14_r0.9_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.1588, R² diff = -0.0628
# theta | ZZx2 -> R² = 0.0724, R² diff = -0.0953
# theta | ZZxReto -> R² = -0.3492, R² diff = -0.0715
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.9 seed=8266 salvo.
# [139] model_arch14_r0.9_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1856, R² diff = -0.1621
# theta | ZZx2 -> R² = -0.2570, R² diff = -0.0881
# theta | ZZxReto -> R² = -1.9938, R² diff = -0.1524
# Modelo [14] | Ld=0.3 Lp=0.7 r=0.9 seed=8503 salvo.
# [140] model_arch14_r0.9_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1945, R² diff = -0.1414
# theta | ZZx2 -> R² = -0.3987, R² diff = -0.0540
# theta | ZZxReto -> R² = -1.9823, R² diff = -0.1526
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.9 seed=4808 salvo.
# [141] model_arch14_r0.9_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.1484, R² diff = -0.0640
# theta | ZZx2 -> R² = 0.0637, R² diff = -0.1049
# theta | ZZxReto -> R² = -0.3540, R² diff = -0.0792
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.9 seed=5973 salvo.
# [142] model_arch14_r0.9_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1393, R² diff = -0.1492
# theta | ZZx2 -> R² = -0.2362, R² diff = -0.0771
# theta | ZZxReto -> R² = -2.0251, R² diff = -0.1575
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.9 seed=8028 salvo.
# [143] model_arch14_r0.9_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1358, R² diff = -0.1582
# theta | ZZx2 -> R² = -0.1791, R² diff = -0.0643
# theta | ZZxReto -> R² = -1.8159, R² diff = -0.1347
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.9 seed=8266 salvo.
# [144] model_arch14_r0.9_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1289, R² diff = -0.1516
# theta | ZZx2 -> R² = -0.2071, R² diff = -0.0760
# theta | ZZxReto -> R² = -1.8314, R² diff = -0.1488
# Modelo [14] | Ld=0.5 Lp=0.5 r=0.9 seed=8503 salvo.
# [145] model_arch14_r0.9_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1402, R² diff = -0.1586
# theta | ZZx2 -> R² = -0.2807, R² diff = -0.0798
# theta | ZZxReto -> R² = -2.0799, R² diff = -0.1630
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.9 seed=4808 salvo.
# [146] model_arch14_r0.9_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.0215, R² diff = -0.1688
# theta | ZZx2 -> R² = -0.2715, R² diff = -0.1091
# theta | ZZxReto -> R² = -1.6808, R² diff = -0.2041
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.9 seed=5973 salvo.
# [147] model_arch14_r0.9_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1807, R² diff = -0.1490
# theta | ZZx2 -> R² = -0.2887, R² diff = -0.0673
# theta | ZZxReto -> R² = -2.0421, R² diff = -0.1639
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.9 seed=8028 salvo.
# [148] model_arch14_r0.9_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1165, R² diff = -0.1499
# theta | ZZx2 -> R² = -0.2464, R² diff = -0.0612
# theta | ZZxReto -> R² = -1.8646, R² diff = -0.1427
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.9 seed=8266 salvo.
# [149] model_arch14_r0.9_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1239, R² diff = -0.1463
# theta | ZZx2 -> R² = -0.3189, R² diff = -0.0621
# theta | ZZxReto -> R² = -2.3043, R² diff = -0.1796
# Modelo [14] | Ld=0.7 Lp=0.3 r=0.9 seed=8503 salvo.
# [150] model_arch14_r0.9_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1719, R² diff = -0.1462
# theta | ZZx2 -> R² = -0.2353, R² diff = -0.0568
# theta | ZZxReto -> R² = -1.9982, R² diff = -0.1584
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.01 seed=4808 salvo.
# [151] model_arch15_r0.01_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.0746, R² diff = -0.1563
# theta | ZZx2 -> R² = -0.1917, R² diff = -0.0989
# theta | ZZxReto -> R² = -1.9494, R² diff = -0.1744
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.01 seed=5973 salvo.
# [152] model_arch15_r0.01_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.2570, R² diff = -0.1657
# theta | ZZx2 -> R² = -0.9158, R² diff = -0.0586
# theta | ZZxReto -> R² = -2.4981, R² diff = -0.1966
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.01 seed=8028 salvo.
# [153] model_arch15_r0.01_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1740, R² diff = -0.1530
# theta | ZZx2 -> R² = -0.2173, R² diff = -0.0579
# theta | ZZxReto -> R² = -2.0775, R² diff = -0.1738
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.01 seed=8266 salvo.
# [154] model_arch15_r0.01_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1807, R² diff = -0.1501
# theta | ZZx2 -> R² = -0.3259, R² diff = -0.0662
# theta | ZZxReto -> R² = -2.2162, R² diff = -0.1667
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.01 seed=8503 salvo.
# [155] model_arch15_r0.01_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1458, R² diff = -0.1524
# theta | ZZx2 -> R² = -0.3214, R² diff = -0.0765
# theta | ZZxReto -> R² = -1.9890, R² diff = -0.1845
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.01 seed=4808 salvo.
# [156] model_arch15_r0.01_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1368, R² diff = -0.1519
# theta | ZZx2 -> R² = -0.3318, R² diff = -0.0747
# theta | ZZxReto -> R² = -2.0510, R² diff = -0.1453
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.01 seed=5973 salvo.
# [157] model_arch15_r0.01_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1436, R² diff = -0.1445
# theta | ZZx2 -> R² = -0.3479, R² diff = -0.0612
# theta | ZZxReto -> R² = -2.3866, R² diff = -0.1795
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.01 seed=8028 salvo.
# [158] model_arch15_r0.01_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1534, R² diff = -0.1502
# theta | ZZx2 -> R² = -0.3293, R² diff = -0.0719
# theta | ZZxReto -> R² = -2.1719, R² diff = -0.1766
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.01 seed=8266 salvo.
# [159] model_arch15_r0.01_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.2356, R² diff = -0.1643
# theta | ZZx2 -> R² = -0.7476, R² diff = -0.0524
# theta | ZZxReto -> R² = -2.4017, R² diff = -0.1690
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.01 seed=8503 salvo.
# [160] model_arch15_r0.01_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1595, R² diff = -0.1507
# theta | ZZx2 -> R² = -0.3111, R² diff = -0.0768
# theta | ZZxReto -> R² = -2.1993, R² diff = -0.1787
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.01 seed=4808 salvo.
# [161] model_arch15_r0.01_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1003, R² diff = -0.1551
# theta | ZZx2 -> R² = -0.2979, R² diff = -0.1034
# theta | ZZxReto -> R² = -2.0411, R² diff = -0.1817
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.01 seed=5973 salvo.
# [162] model_arch15_r0.01_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.0721, R² diff = -0.1643
# theta | ZZx2 -> R² = -0.2023, R² diff = -0.0989
# theta | ZZxReto -> R² = -1.7706, R² diff = -0.1500
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.01 seed=8028 salvo.
# [163] model_arch15_r0.01_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1778, R² diff = -0.1531
# theta | ZZx2 -> R² = -0.3734, R² diff = -0.0598
# theta | ZZxReto -> R² = -2.0667, R² diff = -0.1602
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.01 seed=8266 salvo.
# [164] model_arch15_r0.01_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.0885, R² diff = -0.1446
# theta | ZZx2 -> R² = -0.2968, R² diff = -0.0745
# theta | ZZxReto -> R² = -2.0181, R² diff = -0.1766
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.01 seed=8503 salvo.
# [165] model_arch15_r0.01_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1463, R² diff = -0.1520
# theta | ZZx2 -> R² = -0.2625, R² diff = -0.0860
# theta | ZZxReto -> R² = -2.1725, R² diff = -0.1731
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.9 seed=4808 salvo.
# [166] model_arch15_r0.9_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1585, R² diff = -0.1592
# theta | ZZx2 -> R² = -0.2689, R² diff = -0.0998
# theta | ZZxReto -> R² = -1.9462, R² diff = -0.1776
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.9 seed=5973 salvo.
# [167] model_arch15_r0.9_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1975, R² diff = -0.1582
# theta | ZZx2 -> R² = -0.3925, R² diff = -0.0587
# theta | ZZxReto -> R² = -2.1041, R² diff = -0.1380
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.9 seed=8028 salvo.
# [168] model_arch15_r0.9_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1951, R² diff = -0.1536
# theta | ZZx2 -> R² = -0.2692, R² diff = -0.0658
# theta | ZZxReto -> R² = -2.0989, R² diff = -0.1488
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.9 seed=8266 salvo.
# [169] model_arch15_r0.9_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1706, R² diff = -0.1572
# theta | ZZx2 -> R² = -0.2450, R² diff = -0.0617
# theta | ZZxReto -> R² = -1.9770, R² diff = -0.1360
# Modelo [15] | Ld=0.3 Lp=0.7 r=0.9 seed=8503 salvo.
# [170] model_arch15_r0.9_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1645, R² diff = -0.1534
# theta | ZZx2 -> R² = -0.2887, R² diff = -0.0802
# theta | ZZxReto -> R² = -2.0906, R² diff = -0.1834
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.9 seed=4808 salvo.
# [171] model_arch15_r0.9_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1752, R² diff = -0.1532
# theta | ZZx2 -> R² = -0.3512, R² diff = -0.0457
# theta | ZZxReto -> R² = -2.1564, R² diff = -0.1465
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.9 seed=5973 salvo.
# [172] model_arch15_r0.9_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1664, R² diff = -0.1425
# theta | ZZx2 -> R² = -0.3420, R² diff = -0.0687
# theta | ZZxReto -> R² = -2.0568, R² diff = -0.1614
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.9 seed=8028 salvo.
# [173] model_arch15_r0.9_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.2337, R² diff = -0.1611
# theta | ZZx2 -> R² = -0.8267, R² diff = -0.0495
# theta | ZZxReto -> R² = -2.4136, R² diff = -0.1615
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.9 seed=8266 salvo.
# [174] model_arch15_r0.9_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1450, R² diff = -0.1471
# theta | ZZx2 -> R² = -0.3205, R² diff = -0.0486
# theta | ZZxReto -> R² = -2.2737, R² diff = -0.1763
# Modelo [15] | Ld=0.5 Lp=0.5 r=0.9 seed=8503 salvo.
# [175] model_arch15_r0.9_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1018, R² diff = -0.1646
# theta | ZZx2 -> R² = -0.4018, R² diff = -0.1193
# theta | ZZxReto -> R² = -2.0079, R² diff = -0.2163
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.9 seed=4808 salvo.
# [176] model_arch15_r0.9_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.0957, R² diff = -0.1620
# theta | ZZx2 -> R² = -0.2704, R² diff = -0.1041
# theta | ZZxReto -> R² = -1.8532, R² diff = -0.1742
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.9 seed=5973 salvo.
# [177] model_arch15_r0.9_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.1196, R² diff = -0.0550
# theta | ZZx2 -> R² = -0.0198, R² diff = -0.0965
# theta | ZZxReto -> R² = -0.2627, R² diff = -0.0593
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.9 seed=8028 salvo.
# [178] model_arch15_r0.9_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1056, R² diff = -0.1607
# theta | ZZx2 -> R² = -0.2356, R² diff = -0.0876
# theta | ZZxReto -> R² = -1.9637, R² diff = -0.1795
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.9 seed=8266 salvo.
# [179] model_arch15_r0.9_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1387, R² diff = -0.1445
# theta | ZZx2 -> R² = -0.2716, R² diff = -0.0614
# theta | ZZxReto -> R² = -1.9915, R² diff = -0.1735
# Modelo [15] | Ld=0.7 Lp=0.3 r=0.9 seed=8503 salvo.
# [180] model_arch15_r0.9_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1471, R² diff = -0.1639
# theta | ZZx2 -> R² = -0.3960, R² diff = -0.1001
# theta | ZZxReto -> R² = -2.2072, R² diff = -0.2014
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4808 salvo.
# [181] model_arch16_r0.01_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1872, R² diff = -0.1534
# theta | ZZx2 -> R² = -0.4155, R² diff = -0.0713
# theta | ZZxReto -> R² = -2.2355, R² diff = -0.1696
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5973 salvo.
# [182] model_arch16_r0.01_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1282, R² diff = -0.1430
# theta | ZZx2 -> R² = -0.2719, R² diff = -0.0717
# theta | ZZxReto -> R² = -2.0156, R² diff = -0.1669
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8028 salvo.
# [183] model_arch16_r0.01_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1337, R² diff = -0.1493
# theta | ZZx2 -> R² = -0.1932, R² diff = -0.0727
# theta | ZZxReto -> R² = -1.9663, R² diff = -0.1601
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8266 salvo.
# [184] model_arch16_r0.01_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1677, R² diff = -0.1598
# theta | ZZx2 -> R² = -0.2832, R² diff = -0.0913
# theta | ZZxReto -> R² = -2.0153, R² diff = -0.1840
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8503 salvo.
# [185] model_arch16_r0.01_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.0914, R² diff = -0.1639
# theta | ZZx2 -> R² = -0.2809, R² diff = -0.1058
# theta | ZZxReto -> R² = -1.9487, R² diff = -0.2031
# Modelo [16] | Ld=0.5 Lp=0.5 r=0.01 seed=4808 salvo.
# [186] model_arch16_r0.01_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1373, R² diff = -0.1507
# theta | ZZx2 -> R² = -0.1968, R² diff = -0.0848
# theta | ZZxReto -> R² = -2.1437, R² diff = -0.1604
# Modelo [16] | Ld=0.5 Lp=0.5 r=0.01 seed=5973 salvo.
# [187] model_arch16_r0.01_Ld0.5_Lp0.5_seed5973.keras -> ok
# ...
# theta | ZZxReto -> R² = -1.5699, R² diff = -0.1915
# Modelo [7] | Ld=0.7 Lp=0.3 r=0.9 seed=8028 salvo.
# [2353] model_arch7_r0.9_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1079, R² diff = -0.1495
# theta | ZZx2 -> R² = -0.0774, R² diff = -0.0477
# theta | ZZxReto -> R² = -1.6687, R² diff = -0.1280
# Modelo [7] | Ld=0.7 Lp=0.3 r=0.9 seed=8266 salvo.
# [2354] model_arch7_r0.9_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1597, R² diff = -0.1464
# theta | ZZx2 -> R² = -0.2654, R² diff = -0.0550
# theta | ZZxReto -> R² = -1.7736, R² diff = -0.1007
# Modelo [7] | Ld=0.7 Lp=0.3 r=0.9 seed=8503 salvo.
# [2355] model_arch7_r0.9_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1678, R² diff = -0.1479
# theta | ZZx2 -> R² = -0.1974, R² diff = -0.0578
# theta | ZZxReto -> R² = -1.9407, R² diff = -0.1379
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.01 seed=4808 salvo.
# [2356] model_arch8_r0.01_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.2129, R² diff = -0.0704
# theta | ZZx2 -> R² = 0.0751, R² diff = -0.0969
# theta | ZZxReto -> R² = -0.3936, R² diff = -0.0842
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.01 seed=5973 salvo.
# [2357] model_arch8_r0.01_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.2000, R² diff = -0.1545
# theta | ZZx2 -> R² = -0.2126, R² diff = -0.0702
# theta | ZZxReto -> R² = -2.0243, R² diff = -0.1547
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.01 seed=8028 salvo.
# [2358] model_arch8_r0.01_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.2447, R² diff = -0.1718
# theta | ZZx2 -> R² = -0.4451, R² diff = -0.0758
# theta | ZZxReto -> R² = -2.0120, R² diff = -0.1374
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.01 seed=8266 salvo.
# [2359] model_arch8_r0.01_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.2087, R² diff = -0.1711
# theta | ZZx2 -> R² = -0.3133, R² diff = -0.0983
# theta | ZZxReto -> R² = -1.8027, R² diff = -0.1027
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.01 seed=8503 salvo.
# [2360] model_arch8_r0.01_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1474, R² diff = -0.1703
# theta | ZZx2 -> R² = -0.1664, R² diff = -0.1137
# theta | ZZxReto -> R² = -1.7294, R² diff = -0.1526
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.01 seed=4808 salvo.
# [2361] model_arch8_r0.01_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1874, R² diff = -0.1759
# theta | ZZx2 -> R² = -0.3822, R² diff = -0.0792
# theta | ZZxReto -> R² = -1.9716, R² diff = -0.1141
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.01 seed=5973 salvo.
# [2362] model_arch8_r0.01_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1787, R² diff = -0.1731
# theta | ZZx2 -> R² = -0.0246, R² diff = -0.1134
# theta | ZZxReto -> R² = -1.8306, R² diff = -0.1350
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.01 seed=8028 salvo.
# [2363] model_arch8_r0.01_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.3184, R² diff = -0.0958
# theta | ZZx2 -> R² = 0.0283, R² diff = -0.1328
# theta | ZZxReto -> R² = -0.5602, R² diff = -0.1431
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.01 seed=8266 salvo.
# [2364] model_arch8_r0.01_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1239, R² diff = -0.1706
# theta | ZZx2 -> R² = -0.1340, R² diff = -0.1219
# theta | ZZxReto -> R² = -1.6906, R² diff = -0.1431
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.01 seed=8503 salvo.
# [2365] model_arch8_r0.01_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1074, R² diff = -0.1680
# theta | ZZx2 -> R² = -0.2166, R² diff = -0.1013
# theta | ZZxReto -> R² = -1.5262, R² diff = -0.1601
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.01 seed=4808 salvo.
# [2366] model_arch8_r0.01_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.3072, R² diff = -0.0806
# theta | ZZx2 -> R² = 0.0934, R² diff = -0.1033
# theta | ZZxReto -> R² = -0.4842, R² diff = -0.0974
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.01 seed=5973 salvo.
# [2367] model_arch8_r0.01_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1197, R² diff = -0.1569
# theta | ZZx2 -> R² = -0.0051, R² diff = -0.0850
# theta | ZZxReto -> R² = -1.7521, R² diff = -0.1508
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.01 seed=8028 salvo.
# [2368] model_arch8_r0.01_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.0831, R² diff = -0.1649
# theta | ZZx2 -> R² = -0.1575, R² diff = -0.0974
# theta | ZZxReto -> R² = -1.7083, R² diff = -0.1769
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.01 seed=8266 salvo.
# [2369] model_arch8_r0.01_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.2314, R² diff = -0.0819
# theta | ZZx2 -> R² = 0.0239, R² diff = -0.1194
# theta | ZZxReto -> R² = -0.4360, R² diff = -0.1093
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.01 seed=8503 salvo.
# [2370] model_arch8_r0.01_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.2372, R² diff = -0.1668
# theta | ZZx2 -> R² = -0.3446, R² diff = -0.0766
# theta | ZZxReto -> R² = -2.0339, R² diff = -0.1168
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.9 seed=4808 salvo.
# [2371] model_arch8_r0.9_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.3061, R² diff = -0.0872
# theta | ZZx2 -> R² = 0.0286, R² diff = -0.1271
# theta | ZZxReto -> R² = -0.4933, R² diff = -0.1285
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.9 seed=5973 salvo.
# [2372] model_arch8_r0.9_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1407, R² diff = -0.1614
# theta | ZZx2 -> R² = 0.0812, R² diff = -0.0764
# theta | ZZxReto -> R² = -1.5943, R² diff = -0.1433
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.9 seed=8028 salvo.
# [2373] model_arch8_r0.9_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1149, R² diff = -0.1721
# theta | ZZx2 -> R² = -0.6403, R² diff = -0.1370
# theta | ZZxReto -> R² = -1.8686, R² diff = -0.1910
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.9 seed=8266 salvo.
# [2374] model_arch8_r0.9_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.2340, R² diff = -0.1727
# theta | ZZx2 -> R² = -0.3246, R² diff = -0.0787
# theta | ZZxReto -> R² = -2.0998, R² diff = -0.1258
# Modelo [8] | Ld=0.3 Lp=0.7 r=0.9 seed=8503 salvo.
# [2375] model_arch8_r0.9_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -0.2640, R² diff = -0.0666
# theta | ZZx2 -> R² = 0.0634, R² diff = -0.1020
# theta | ZZxReto -> R² = -0.3505, R² diff = -0.0720
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.9 seed=4808 salvo.
# [2376] model_arch8_r0.9_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.1768, R² diff = -0.0669
# theta | ZZx2 -> R² = 0.0839, R² diff = -0.0947
# theta | ZZxReto -> R² = -0.3872, R² diff = -0.0755
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.9 seed=5973 salvo.
# [2377] model_arch8_r0.9_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.2501, R² diff = -0.0732
# theta | ZZx2 -> R² = 0.0646, R² diff = -0.1135
# theta | ZZxReto -> R² = -0.4239, R² diff = -0.0996
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.9 seed=8028 salvo.
# [2378] model_arch8_r0.9_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.2716, R² diff = -0.0860
# theta | ZZx2 -> R² = 0.0263, R² diff = -0.1301
# theta | ZZxReto -> R² = -0.4803, R² diff = -0.1276
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.9 seed=8266 salvo.
# [2379] model_arch8_r0.9_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.3601, R² diff = -0.0939
# theta | ZZx2 -> R² = 0.0451, R² diff = -0.1248
# theta | ZZxReto -> R² = -0.5672, R² diff = -0.1344
# Modelo [8] | Ld=0.5 Lp=0.5 r=0.9 seed=8503 salvo.
# [2380] model_arch8_r0.9_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -0.2614, R² diff = -0.0663
# theta | ZZx2 -> R² = 0.0816, R² diff = -0.1010
# theta | ZZxReto -> R² = -0.3734, R² diff = -0.0805
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.9 seed=4808 salvo.
# [2381] model_arch8_r0.9_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.3206, R² diff = -0.0887
# theta | ZZx2 -> R² = 0.0460, R² diff = -0.1205
# theta | ZZxReto -> R² = -0.5085, R² diff = -0.1247
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.9 seed=5973 salvo.
# [2382] model_arch8_r0.9_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1754, R² diff = -0.1450
# theta | ZZx2 -> R² = -0.3012, R² diff = -0.0425
# theta | ZZxReto -> R² = -2.2743, R² diff = -0.1709
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.9 seed=8028 salvo.
# [2383] model_arch8_r0.9_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.3024, R² diff = -0.0811
# theta | ZZx2 -> R² = 0.0670, R² diff = -0.1143
# theta | ZZxReto -> R² = -0.4807, R² diff = -0.1104
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.9 seed=8266 salvo.
# [2384] model_arch8_r0.9_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.2299, R² diff = -0.0818
# theta | ZZx2 -> R² = 0.0298, R² diff = -0.1182
# theta | ZZxReto -> R² = -0.4394, R² diff = -0.1099
# Modelo [8] | Ld=0.7 Lp=0.3 r=0.9 seed=8503 salvo.
# [2385] model_arch8_r0.9_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.0906, R² diff = -0.1637
# theta | ZZx2 -> R² = -0.1518, R² diff = -0.0794
# theta | ZZxReto -> R² = -1.6687, R² diff = -0.1660
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.01 seed=4808 salvo.
# [2386] model_arch9_r0.01_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.2959, R² diff = -0.0894
# theta | ZZx2 -> R² = 0.0319, R² diff = -0.1265
# theta | ZZxReto -> R² = -0.5006, R² diff = -0.1326
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.01 seed=5973 salvo.
# [2387] model_arch9_r0.01_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.3290, R² diff = -0.0865
# theta | ZZx2 -> R² = 0.0628, R² diff = -0.1227
# theta | ZZxReto -> R² = -0.5138, R² diff = -0.1165
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.01 seed=8028 salvo.
# [2388] model_arch9_r0.01_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.1042, R² diff = -0.1684
# theta | ZZx2 -> R² = 0.1819, R² diff = -0.1319
# theta | ZZxReto -> R² = -1.6100, R² diff = -0.1633
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.01 seed=8266 salvo.
# [2389] model_arch9_r0.01_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.1909, R² diff = -0.0600
# theta | ZZx2 -> R² = 0.1312, R² diff = -0.0833
# theta | ZZxReto -> R² = -0.3784, R² diff = -0.0663
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.01 seed=8503 salvo.
# [2390] model_arch9_r0.01_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -0.3016, R² diff = -0.0692
# theta | ZZx2 -> R² = 0.1003, R² diff = -0.0961
# theta | ZZxReto -> R² = -0.4048, R² diff = -0.0765
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.01 seed=4808 salvo.
# [2391] model_arch9_r0.01_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.2292, R² diff = -0.1726
# theta | ZZx2 -> R² = -0.4580, R² diff = -0.0778
# theta | ZZxReto -> R² = -2.1311, R² diff = -0.1364
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.01 seed=5973 salvo.
# [2392] model_arch9_r0.01_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.3088, R² diff = -0.0840
# theta | ZZx2 -> R² = 0.0613, R² diff = -0.1163
# theta | ZZxReto -> R² = -0.4920, R² diff = -0.1103
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.01 seed=8028 salvo.
# [2393] model_arch9_r0.01_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.2963, R² diff = -0.0852
# theta | ZZx2 -> R² = 0.0642, R² diff = -0.1217
# theta | ZZxReto -> R² = -0.5258, R² diff = -0.1209
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.01 seed=8266 salvo.
# [2394] model_arch9_r0.01_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.1731, R² diff = -0.0589
# theta | ZZx2 -> R² = 0.0948, R² diff = -0.0858
# theta | ZZxReto -> R² = -0.3471, R² diff = -0.0641
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.01 seed=8503 salvo.
# [2395] model_arch9_r0.01_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.1618, R² diff = -0.1637
# theta | ZZx2 -> R² = -0.3673, R² diff = -0.0764
# theta | ZZxReto -> R² = -1.8921, R² diff = -0.1305
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.01 seed=4808 salvo.
# [2396] model_arch9_r0.01_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -0.2681, R² diff = -0.0814
# theta | ZZx2 -> R² = 0.0524, R² diff = -0.1163
# theta | ZZxReto -> R² = -0.4438, R² diff = -0.1077
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.01 seed=5973 salvo.
# [2397] model_arch9_r0.01_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1916, R² diff = -0.1439
# theta | ZZx2 -> R² = -0.4074, R² diff = -0.0664
# theta | ZZxReto -> R² = -2.2622, R² diff = -0.1733
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.01 seed=8028 salvo.
# [2398] model_arch9_r0.01_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.2227, R² diff = -0.0834
# theta | ZZx2 -> R² = 0.0465, R² diff = -0.1192
# theta | ZZxReto -> R² = -0.4868, R² diff = -0.1194
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.01 seed=8266 salvo.
# [2399] model_arch9_r0.01_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.2032, R² diff = -0.0641
# theta | ZZx2 -> R² = 0.0789, R² diff = -0.0980
# theta | ZZxReto -> R² = -0.3678, R² diff = -0.0821
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.01 seed=8503 salvo.
# [2400] model_arch9_r0.01_Ld0.7_Lp0.3_seed8503.keras -> ok
# theta | ZZx1 -> R² = -0.1904, R² diff = -0.0778
# theta | ZZx2 -> R² = 0.0034, R² diff = -0.1180
# theta | ZZxReto -> R² = -0.3720, R² diff = -0.1051
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.9 seed=4808 salvo.
# [2401] model_arch9_r0.9_Ld0.3_Lp0.7_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1807, R² diff = -0.1425
# theta | ZZx2 -> R² = -0.2099, R² diff = -0.0742
# theta | ZZxReto -> R² = -2.1357, R² diff = -0.1527
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.9 seed=5973 salvo.
# [2402] model_arch9_r0.9_Ld0.3_Lp0.7_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.1568, R² diff = -0.1533
# theta | ZZx2 -> R² = -0.0760, R² diff = -0.0701
# theta | ZZxReto -> R² = -1.6446, R² diff = -0.1297
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.9 seed=8028 salvo.
# [2403] model_arch9_r0.9_Ld0.3_Lp0.7_seed8028.keras -> ok
# theta | ZZx1 -> R² = -0.2552, R² diff = -0.0810
# theta | ZZx2 -> R² = 0.0315, R² diff = -0.1182
# theta | ZZxReto -> R² = -0.4414, R² diff = -0.1126
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.9 seed=8266 salvo.
# [2404] model_arch9_r0.9_Ld0.3_Lp0.7_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.2502, R² diff = -0.0709
# theta | ZZx2 -> R² = 0.0902, R² diff = -0.1000
# theta | ZZxReto -> R² = -0.4004, R² diff = -0.0884
# Modelo [9] | Ld=0.3 Lp=0.7 r=0.9 seed=8503 salvo.
# [2405] model_arch9_r0.9_Ld0.3_Lp0.7_seed8503.keras -> ok
# theta | ZZx1 -> R² = -1.2279, R² diff = -0.1531
# theta | ZZx2 -> R² = -0.3265, R² diff = -0.0773
# theta | ZZxReto -> R² = -1.9633, R² diff = -0.1494
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.9 seed=4808 salvo.
# [2406] model_arch9_r0.9_Ld0.5_Lp0.5_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1355, R² diff = -0.1684
# theta | ZZx2 -> R² = -0.1107, R² diff = -0.1126
# theta | ZZxReto -> R² = -1.6595, R² diff = -0.1523
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.9 seed=5973 salvo.
# [2407] model_arch9_r0.9_Ld0.5_Lp0.5_seed5973.keras -> ok
# theta | ZZx1 -> R² = -1.2075, R² diff = -0.1738
# theta | ZZx2 -> R² = -0.4539, R² diff = -0.1153
# theta | ZZxReto -> R² = -1.8784, R² diff = -0.1288
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.9 seed=8028 salvo.
# [2408] model_arch9_r0.9_Ld0.5_Lp0.5_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.0648, R² diff = -0.1592
# theta | ZZx2 -> R² = -0.1855, R² diff = -0.1017
# theta | ZZxReto -> R² = -1.6485, R² diff = -0.1919
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.9 seed=8266 salvo.
# [2409] model_arch9_r0.9_Ld0.5_Lp0.5_seed8266.keras -> ok
# theta | ZZx1 -> R² = -1.1923, R² diff = -0.1439
# theta | ZZx2 -> R² = -0.3706, R² diff = -0.0358
# theta | ZZxReto -> R² = -2.2339, R² diff = -0.1739
# Modelo [9] | Ld=0.5 Lp=0.5 r=0.9 seed=8503 salvo.
# [2410] model_arch9_r0.9_Ld0.5_Lp0.5_seed8503.keras -> ok
# theta | ZZx1 -> R² = -0.2103, R² diff = -0.0642
# theta | ZZx2 -> R² = 0.0788, R² diff = -0.0993
# theta | ZZxReto -> R² = -0.3521, R² diff = -0.0769
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.9 seed=4808 salvo.
# [2411] model_arch9_r0.9_Ld0.7_Lp0.3_seed4808.keras -> ok
# theta | ZZx1 -> R² = -1.1638, R² diff = -0.1547
# theta | ZZx2 -> R² = -0.1558, R² diff = -0.0883
# theta | ZZxReto -> R² = -2.0441, R² diff = -0.1535
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.9 seed=5973 salvo.
# [2412] model_arch9_r0.9_Ld0.7_Lp0.3_seed5973.keras -> ok
# theta | ZZx1 -> R² = -0.2200, R² diff = -0.0722
# theta | ZZx2 -> R² = 0.0217, R² diff = -0.1082
# theta | ZZxReto -> R² = -0.3608, R² diff = -0.0874
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.9 seed=8028 salvo.
# [2413] model_arch9_r0.9_Ld0.7_Lp0.3_seed8028.keras -> ok
# theta | ZZx1 -> R² = -1.2352, R² diff = -0.1639
# theta | ZZx2 -> R² = -0.7304, R² diff = -0.1019
# theta | ZZxReto -> R² = -2.1374, R² diff = -0.1468
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.9 seed=8266 salvo.
# [2414] model_arch9_r0.9_Ld0.7_Lp0.3_seed8266.keras -> ok
# theta | ZZx1 -> R² = -0.2963, R² diff = -0.0906
# theta | ZZx2 -> R² = 0.0412, R² diff = -0.1317
# theta | ZZxReto -> R² = -0.5348, R² diff = -0.1310
# Modelo [9] | Ld=0.7 Lp=0.3 r=0.9 seed=8503 salvo.
# [2415] model_arch9_r0.9_Ld0.7_Lp0.3_seed8503.keras -> ok
#
# Concluído. 2415 modelos de 1 camadas -> resultados-1l.xlsx
