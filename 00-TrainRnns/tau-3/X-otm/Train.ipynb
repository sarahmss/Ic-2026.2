# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm", "cos(theta_pred)"
# - Saida: X
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = [
    "ZZx1",  # Train
    "ZZx2",  # Val
    "ZZxReto", # Test
    "ZZy1", # Test
    "ZZy2", # Test
    "LSG-1", # Test
    "LSG-2", # Test
    "ZZx1-inv", # Test
    "zzx2-inv2", # Test
    "semiCirc", # Test
]
PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a", "costheta"]   
TARGET_INT = ["x"]  
TARGET = ["dx"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
PLOT = False
TIME_STEPS = 3
TS = 0.07

# %%
Datasets = []
NormDatasets = []

for title in TITLES:
    df = pd.read_excel("./../Theta/Data/Datasets.xlsx", sheet_name=title)
    df_theta = pd.read_excel("./../Theta/resultados_comparacao.xlsx", sheet_name=title)

    df["theta_pred"] = df_theta["theta_pred_model_arch69_r0.9_Ld0.7_Lp0.3_seed1706"]

    df["costheta"] = np.cos(df["theta_pred"])
    df = df.dropna().reset_index(drop=True)

    Datasets.append(df)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train = Train1

for i in range(len(Datasets) - 1):
    CurrentTestDataset = Datasets[i + 1].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val =NormDatasets[1]

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1030, 3, 5)
# Dimensão da saida: (1030, 1)
# Dimensão da entrada: (1388, 3, 5)
# Dimensão da saida: (1388, 1)

# %%
phi_d_train =  Train["phi_d"].values[:len(x_train)]
phi_e_train =  Train["phi_e"].values[:len(x_train)]
theta_train = Train["theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(phi_d_train)}")
print(f"Dimensão da entrada fisica: {np.shape(phi_e_train)}")
# Out:
# Dimensão da entrada: (1030, 3, 5)
# Dimensão da saida: (1030, 1)
# Dimensão da entrada fisica : (1030,)
# Dimensão da entrada fisica: (1030,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):
    dx_cin = (R / 2) * tf.cos(theta) * (phi_d + phi_e)
    return [dx_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(dq).T, np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, phi_d, phi_e, theta, Ld, Lp):
    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(phi_d, phi_e, theta), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
phi_d_train = tf.convert_to_tensor(phi_d_train, dtype=tf.float32)
phi_e_train = tf.convert_to_tensor(phi_e_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          phi_d_train, phi_e_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_mse = f"MSE_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_mse, []).append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {mse:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"MSE_{safe_title}_{name}"] = to_scalar(metrics[name][f"MSE_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    #os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    model_path = f"models/{model_name}.keras"

    #model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}")

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import initializers
from itertools import product
import numpy as np
import tensorflow as tf79

N_MODELS = 5

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[n] for n in range(80, 101)]


# FirstLayers = [
#     [27], [30], [32], [35], [36], [37], [40],
#     [42], [44], [46], [49], [50], [52], [75],
# ]

# architectures = [
#     [fl[0], sl]
#     for fl in FirstLayers
#     for sl in range(
#         max(1, int(0.3 * fl[0])),
#         int(0.7 * fl[0])
#     )
# ]

# 🔹 retomar a partir do último modelo salvo
# last_saved = [27, 12]

# if last_saved in architectures:
#     idx = architectures.index(last_saved)
#     architectures = architectures[idx + 1:]  # começa DEPOIS do último salvo
#     print(f"Retomando a partir de {last_saved} (índice {idx}). Restam {len(architectures)} arquiteturas.")
# else:
#     print(f"⚠️ {last_saved} não encontrado na lista — rodando tudo do zero.")

print(len(architectures))
print(architectures)

Ld_Lp = [[0.5, 0.5], [0.3, 0.7], [0.7, 0.3]]
r_values = [0.01, 0.9]

results = {}

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados-1l-v2.xlsx")
# Out:
# 21
# [[80], [81], [82], [83], [84], [85], [86], [87], [88], [89], [90], [91], [92], [93], [94], [95], [96], [97], [98], [99], [100]]
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 0.734004 | Val Loss 0.279843
# Epoch 100 | Train Loss 0.024759 | Val Loss 0.106708
# Epoch 200 | Train Loss 0.023095 | Val Loss 0.109002
# Early stopping at epoch 250
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.9917, R² diff = 0.9760
# x | ZZx2 -> R² = -3.0859, R² diff = 0.7924
# x | ZZxReto -> R² = 0.3918, R² diff = 0.9417
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.521116 | Val Loss 0.196747
# Epoch 100 | Train Loss 0.023473 | Val Loss 0.091116
# Epoch 200 | Train Loss 0.021044 | Val Loss 0.094750
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.8789, R² diff = 0.9619
# x | ZZx2 -> R² = 0.8670, R² diff = 0.8548
# x | ZZxReto -> R² = 0.8803, R² diff = 0.9365
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.628808 | Val Loss 0.180619
# Epoch 100 | Train Loss 0.024748 | Val Loss 0.115354
# Epoch 200 | Train Loss 0.022908 | Val Loss 0.119054
# Early stopping at epoch 229
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.8345, R² diff = 0.9621
# x | ZZx2 -> R² = 0.8667, R² diff = 0.8263
# x | ZZxReto -> R² = 0.9211, R² diff = 0.9407
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.759667 | Val Loss 0.267347
# Epoch 100 | Train Loss 0.024488 | Val Loss 0.097782
# Epoch 200 | Train Loss 0.022323 | Val Loss 0.101231
# Early stopping at epoch 234
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.8885, R² diff = 0.9610
# x | ZZx2 -> R² = 0.8728, R² diff = 0.8306
# x | ZZxReto -> R² = 0.8826, R² diff = 0.9391
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.541485 | Val Loss 0.303144
# Epoch 100 | Train Loss 0.023761 | Val Loss 0.095769
# Epoch 200 | Train Loss 0.020499 | Val Loss 0.105112
# Early stopping at epoch 284
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.9938, R² diff = 0.9780
# x | ZZx2 -> R² = -3.3665, R² diff = 0.8048
# x | ZZxReto -> R² = 0.4302, R² diff = 0.9419
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.816519 | Val Loss 0.254762
# Epoch 100 | Train Loss 0.023956 | Val Loss 0.105480
# Epoch 200 | Train Loss 0.021414 | Val Loss 0.113247
# Early stopping at epoch 249
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.9870, R² diff = 0.9746
# x | ZZx2 -> R² = -2.1424, R² diff = 0.8072
# x | ZZxReto -> R² = 0.4333, R² diff = 0.9488
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.609359 | Val Loss 0.203305
# Epoch 100 | Train Loss 0.024356 | Val Loss 0.088212
# Epoch 200 | Train Loss 0.021878 | Val Loss 0.095801
# Early stopping at epoch 275
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.9906, R² diff = 0.9772
# x | ZZx2 -> R² = -3.7466, R² diff = 0.8171
# x | ZZxReto -> R² = 0.4651, R² diff = 0.9418
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.677827 | Val Loss 0.199135
# Epoch 100 | Train Loss 0.024198 | Val Loss 0.100509
# Epoch 200 | Train Loss 0.022132 | Val Loss 0.108642
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.8393, R² diff = 0.9607
# x | ZZx2 -> R² = 0.5858, R² diff = 0.8047
# x | ZZxReto -> R² = 0.9400, R² diff = 0.9416
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.764939 | Val Loss 0.257101
# Epoch 100 | Train Loss 0.024907 | Val Loss 0.096293
# Epoch 200 | Train Loss 0.022694 | Val Loss 0.100676
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.8625, R² diff = 0.9629
# x | ZZx2 -> R² = 0.9039, R² diff = 0.8368
# x | ZZxReto -> R² = 0.8810, R² diff = 0.9396
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.589452 | Val Loss 0.173232
# Epoch 100 | Train Loss 0.023765 | Val Loss 0.110252
# Epoch 200 | Train Loss 0.020962 | Val Loss 0.122543
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.9110, R² diff = 0.9624
# x | ZZx2 -> R² = 0.8627, R² diff = 0.8504
# x | ZZxReto -> R² = 0.8810, R² diff = 0.9407
# Modelo [80] | Ld=0.5 Lp=0.5 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.705927 | Val Loss 0.226751
# Epoch 100 | Train Loss 0.024652 | Val Loss 0.100511
# Epoch 200 | Train Loss 0.022422 | Val Loss 0.100497
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.8082, R² diff = 0.9615
# x | ZZx2 -> R² = 0.7853, R² diff = 0.8168
# x | ZZxReto -> R² = 0.9242, R² diff = 0.9389
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.327487 | Val Loss 0.195501
# Epoch 100 | Train Loss 0.024958 | Val Loss 0.093004
# Epoch 200 | Train Loss 0.021494 | Val Loss 0.095232
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.9353, R² diff = 0.9633
# x | ZZx2 -> R² = 0.2140, R² diff = 0.8626
# x | ZZxReto -> R² = 0.7277, R² diff = 0.9318
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.903916 | Val Loss 0.311287
# Epoch 100 | Train Loss 0.025305 | Val Loss 0.096029
# Epoch 200 | Train Loss 0.023638 | Val Loss 0.103532
# Early stopping at epoch 234
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.8422, R² diff = 0.9607
# x | ZZx2 -> R² = 0.7188, R² diff = 0.8166
# x | ZZxReto -> R² = 0.9226, R² diff = 0.9400
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.700843 | Val Loss 0.217240
# Epoch 100 | Train Loss 0.025987 | Val Loss 0.095155
# Epoch 200 | Train Loss 0.024343 | Val Loss 0.101681
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.8486, R² diff = 0.9606
# x | ZZx2 -> R² = 0.8371, R² diff = 0.8379
# x | ZZxReto -> R² = 0.8600, R² diff = 0.9328
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.612738 | Val Loss 0.241073
# Epoch 100 | Train Loss 0.024836 | Val Loss 0.094988
# Epoch 200 | Train Loss 0.022036 | Val Loss 0.099802
# Early stopping at epoch 294
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.9956, R² diff = 0.9778
# x | ZZx2 -> R² = -3.9858, R² diff = 0.7985
# x | ZZxReto -> R² = 0.3808, R² diff = 0.9413
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.809248 | Val Loss 0.319840
# Epoch 100 | Train Loss 0.024669 | Val Loss 0.110143
# Epoch 200 | Train Loss 0.022783 | Val Loss 0.111606
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.7959, R² diff = 0.9587
# x | ZZx2 -> R² = 0.4667, R² diff = 0.7979
# x | ZZxReto -> R² = 0.9333, R² diff = 0.9382
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.336561 | Val Loss 0.388707
# Epoch 100 | Train Loss 0.024011 | Val Loss 0.097679
# Epoch 200 | Train Loss 0.020369 | Val Loss 0.104875
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.9365, R² diff = 0.9658
# x | ZZx2 -> R² = 0.7271, R² diff = 0.8523
# x | ZZxReto -> R² = 0.7775, R² diff = 0.9396
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.743956 | Val Loss 0.219674
# Epoch 100 | Train Loss 0.024729 | Val Loss 0.110771
# Epoch 200 | Train Loss 0.022507 | Val Loss 0.119685
# Early stopping at epoch 243
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.9827, R² diff = 0.9706
# x | ZZx2 -> R² = -1.8969, R² diff = 0.8000
# x | ZZxReto -> R² = 0.4865, R² diff = 0.9532
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.820625 | Val Loss 0.267302
# Epoch 100 | Train Loss 0.024907 | Val Loss 0.090378
# Epoch 200 | Train Loss 0.022681 | Val Loss 0.096502
# Early stopping at epoch 298
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.9958, R² diff = 0.9774
# x | ZZx2 -> R² = -3.4857, R² diff = 0.8077
# x | ZZxReto -> R² = 0.4058, R² diff = 0.9416
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.559904 | Val Loss 0.234255
# Epoch 100 | Train Loss 0.025104 | Val Loss 0.092214
# Epoch 200 | Train Loss 0.022479 | Val Loss 0.097267
# Early stopping at epoch 287
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.9959, R² diff = 0.9774
# x | ZZx2 -> R² = -2.9777, R² diff = 0.8057
# x | ZZxReto -> R² = 0.3655, R² diff = 0.9412
# Modelo [80] | Ld=0.3 Lp=0.7 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.865050 | Val Loss 0.432171
# Epoch 100 | Train Loss 0.023475 | Val Loss 0.107325
# Epoch 200 | Train Loss 0.020804 | Val Loss 0.113176
# Early stopping at epoch 234
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.7_Lp0.3_seed8256.keras
# x | ZZx1 -> R² = 0.7900, R² diff = 0.9557
# x | ZZx2 -> R² = 0.7235, R² diff = 0.8210
# x | ZZxReto -> R² = 0.9341, R² diff = 0.9352
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.596279 | Val Loss 0.169540
# Epoch 100 | Train Loss 0.022964 | Val Loss 0.100011
# Epoch 200 | Train Loss 0.020010 | Val Loss 0.110366
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.7_Lp0.3_seed6040.keras
# x | ZZx1 -> R² = 0.8927, R² diff = 0.9588
# x | ZZx2 -> R² = 0.1960, R² diff = 0.8664
# x | ZZxReto -> R² = 0.8249, R² diff = 0.9305
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.844763 | Val Loss 0.257403
# Epoch 100 | Train Loss 0.024049 | Val Loss 0.115056
# Epoch 200 | Train Loss 0.022308 | Val Loss 0.122721
# Early stopping at epoch 244
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.7_Lp0.3_seed2393.keras
# x | ZZx1 -> R² = 0.9796, R² diff = 0.9717
# x | ZZx2 -> R² = -2.8835, R² diff = 0.7869
# x | ZZxReto -> R² = 0.3768, R² diff = 0.9494
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.754578 | Val Loss 0.243109
# Epoch 100 | Train Loss 0.023427 | Val Loss 0.095613
# Epoch 200 | Train Loss 0.021002 | Val Loss 0.103474
# Early stopping at epoch 234
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.8403, R² diff = 0.9625
# x | ZZx2 -> R² = 0.6761, R² diff = 0.8122
# x | ZZxReto -> R² = 0.9262, R² diff = 0.9425
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.541649 | Val Loss 0.147252
# Epoch 100 | Train Loss 0.022190 | Val Loss 0.093572
# Epoch 200 | Train Loss 0.019213 | Val Loss 0.102528
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch80_r0.01_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.8563, R² diff = 0.9613
# x | ZZx2 -> R² = 0.7910, R² diff = 0.8304
# x | ZZxReto -> R² = 0.9029, R² diff = 0.9385
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.774305 | Val Loss 0.275125
# Epoch 100 | Train Loss 0.023462 | Val Loss 0.097834
# Epoch 200 | Train Loss 0.020821 | Val Loss 0.100796
# Early stopping at epoch 249
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.7_Lp0.3_seed8256.keras
# x | ZZx1 -> R² = 0.9924, R² diff = 0.9762
# x | ZZx2 -> R² = -2.6567, R² diff = 0.8100
# x | ZZxReto -> R² = 0.4834, R² diff = 0.9448
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.430502 | Val Loss 0.210560
# Epoch 100 | Train Loss 0.023049 | Val Loss 0.088877
# Epoch 200 | Train Loss 0.019893 | Val Loss 0.099037
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.7_Lp0.3_seed6040.keras
# x | ZZx1 -> R² = 0.8859, R² diff = 0.9628
# x | ZZx2 -> R² = 0.8726, R² diff = 0.8305
# x | ZZxReto -> R² = 0.8095, R² diff = 0.9339
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.628421 | Val Loss 0.187114
# Epoch 100 | Train Loss 0.023185 | Val Loss 0.099207
# Epoch 200 | Train Loss 0.019959 | Val Loss 0.106045
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.7_Lp0.3_seed2393.keras
# x | ZZx1 -> R² = 0.8524, R² diff = 0.9605
# x | ZZx2 -> R² = 0.6296, R² diff = 0.8227
# x | ZZxReto -> R² = 0.9328, R² diff = 0.9413
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.737756 | Val Loss 0.309262
# Epoch 100 | Train Loss 0.023730 | Val Loss 0.100270
# Epoch 200 | Train Loss 0.021581 | Val Loss 0.101348
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.8079, R² diff = 0.9587
# x | ZZx2 -> R² = 0.8454, R² diff = 0.8200
# x | ZZxReto -> R² = 0.9086, R² diff = 0.9342
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.687702 | Val Loss 0.197519
# Epoch 100 | Train Loss 0.023022 | Val Loss 0.087158
# Epoch 200 | Train Loss 0.019928 | Val Loss 0.094396
# Early stopping at epoch 297
# Modelo salvo em:
# models/model_arch80_r0.9_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.9940, R² diff = 0.9782
# x | ZZx2 -> R² = -3.8722, R² diff = 0.8149
# x | ZZxReto -> R² = 0.4580, R² diff = 0.9432
# Modelo [80] | Ld=0.7 Lp=0.3 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.818729 | Val Loss 0.298191
# Epoch 100 | Train Loss 0.024057 | Val Loss 0.094141
# Epoch 200 | Train Loss 0.021914 | Val Loss 0.099094
# Early stopping at epoch 252
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.9899, R² diff = 0.9769
# x | ZZx2 -> R² = -2.5549, R² diff = 0.8201
# x | ZZxReto -> R² = 0.5122, R² diff = 0.9447
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.428058 | Val Loss 0.169836
# Epoch 100 | Train Loss 0.023437 | Val Loss 0.089468
# Epoch 200 | Train Loss 0.019784 | Val Loss 0.093611
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.9187, R² diff = 0.9639
# x | ZZx2 -> R² = 0.4458, R² diff = 0.8687
# x | ZZxReto -> R² = 0.7720, R² diff = 0.9332
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.565648 | Val Loss 0.161491
# Epoch 100 | Train Loss 0.024737 | Val Loss 0.091667
# Epoch 200 | Train Loss 0.022873 | Val Loss 0.096943
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.8898, R² diff = 0.9623
# x | ZZx2 -> R² = 0.1971, R² diff = 0.8457
# x | ZZxReto -> R² = 0.7808, R² diff = 0.9301
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.717526 | Val Loss 0.250692
# Epoch 100 | Train Loss 0.023598 | Val Loss 0.094416
# Epoch 200 | Train Loss 0.021218 | Val Loss 0.101604
# Early stopping at epoch 247
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.9839, R² diff = 0.9763
# x | ZZx2 -> R² = -3.0113, R² diff = 0.8005
# x | ZZxReto -> R² = 0.2195, R² diff = 0.9406
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.464491 | Val Loss 0.161582
# Epoch 100 | Train Loss 0.024510 | Val Loss 0.112009
# Epoch 200 | Train Loss 0.021140 | Val Loss 0.120762
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.9252, R² diff = 0.9646
# x | ZZx2 -> R² = 0.3732, R² diff = 0.8504
# x | ZZxReto -> R² = 0.7819, R² diff = 0.9374
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.825266 | Val Loss 0.249835
# Epoch 100 | Train Loss 0.024118 | Val Loss 0.094204
# Epoch 200 | Train Loss 0.021476 | Val Loss 0.097781
# Early stopping at epoch 250
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.9909, R² diff = 0.9770
# x | ZZx2 -> R² = -3.0354, R² diff = 0.8115
# x | ZZxReto -> R² = 0.4723, R² diff = 0.9417
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.577962 | Val Loss 0.163985
# Epoch 100 | Train Loss 0.024273 | Val Loss 0.090890
# Epoch 200 | Train Loss 0.021601 | Val Loss 0.100287
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.8929, R² diff = 0.9634
# x | ZZx2 -> R² = 0.6835, R² diff = 0.8576
# x | ZZxReto -> R² = 0.8179, R² diff = 0.9358
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.735861 | Val Loss 0.226367
# Epoch 100 | Train Loss 0.024476 | Val Loss 0.095892
# Epoch 200 | Train Loss 0.022298 | Val Loss 0.101698
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.8610, R² diff = 0.9633
# x | ZZx2 -> R² = -0.1957, R² diff = 0.8589
# x | ZZxReto -> R² = 0.8040, R² diff = 0.9308
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.687436 | Val Loss 0.234666
# Epoch 100 | Train Loss 0.024004 | Val Loss 0.099548
# Epoch 200 | Train Loss 0.021190 | Val Loss 0.107166
# Early stopping at epoch 244
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.9904, R² diff = 0.9734
# x | ZZx2 -> R² = -2.0316, R² diff = 0.8057
# x | ZZxReto -> R² = 0.4258, R² diff = 0.9485
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.600153 | Val Loss 0.166135
# Epoch 100 | Train Loss 0.024446 | Val Loss 0.092059
# Epoch 200 | Train Loss 0.022368 | Val Loss 0.102947
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.9091, R² diff = 0.9627
# x | ZZx2 -> R² = 0.5362, R² diff = 0.8652
# x | ZZxReto -> R² = 0.7979, R² diff = 0.9334
# Modelo [81] | Ld=0.5 Lp=0.5 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.710702 | Val Loss 0.211389
# Epoch 100 | Train Loss 0.024260 | Val Loss 0.110264
# Epoch 200 | Train Loss 0.021882 | Val Loss 0.117544
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.8329, R² diff = 0.9622
# x | ZZx2 -> R² = 0.2873, R² diff = 0.7803
# x | ZZxReto -> R² = 0.9493, R² diff = 0.9449
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.601702 | Val Loss 0.167130
# Epoch 100 | Train Loss 0.025171 | Val Loss 0.094211
# Epoch 200 | Train Loss 0.023017 | Val Loss 0.103409
# Early stopping at epoch 229
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.9048, R² diff = 0.9655
# x | ZZx2 -> R² = 0.8450, R² diff = 0.8196
# x | ZZxReto -> R² = 0.8612, R² diff = 0.9423
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.731822 | Val Loss 0.246227
# Epoch 100 | Train Loss 0.024716 | Val Loss 0.105377
# Epoch 200 | Train Loss 0.022471 | Val Loss 0.115781
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.8620, R² diff = 0.9619
# x | ZZx2 -> R² = -0.1341, R² diff = 0.8595
# x | ZZxReto -> R² = 0.8509, R² diff = 0.9322
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.711534 | Val Loss 0.231639
# Epoch 100 | Train Loss 0.025412 | Val Loss 0.091733
# Epoch 200 | Train Loss 0.023128 | Val Loss 0.093450
# Early stopping at epoch 292
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.9950, R² diff = 0.9771
# x | ZZx2 -> R² = -3.1615, R² diff = 0.8069
# x | ZZxReto -> R² = 0.4039, R² diff = 0.9416
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.542934 | Val Loss 0.175036
# Epoch 100 | Train Loss 0.025694 | Val Loss 0.111376
# Epoch 200 | Train Loss 0.023097 | Val Loss 0.113090
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.9402, R² diff = 0.9629
# x | ZZx2 -> R² = 0.2846, R² diff = 0.8508
# x | ZZxReto -> R² = 0.7453, R² diff = 0.9353
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.691953 | Val Loss 0.207283
# Epoch 100 | Train Loss 0.024863 | Val Loss 0.096005
# Epoch 200 | Train Loss 0.022849 | Val Loss 0.101234
# Early stopping at epoch 288
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.9946, R² diff = 0.9776
# x | ZZx2 -> R² = -3.4113, R² diff = 0.8012
# x | ZZxReto -> R² = 0.4392, R² diff = 0.9420
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.540327 | Val Loss 0.163033
# Epoch 100 | Train Loss 0.025117 | Val Loss 0.093461
# Epoch 200 | Train Loss 0.023043 | Val Loss 0.099333
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.8758, R² diff = 0.9612
# x | ZZx2 -> R² = 0.7003, R² diff = 0.8645
# x | ZZxReto -> R² = 0.8401, R² diff = 0.9325
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.712207 | Val Loss 0.211249
# Epoch 100 | Train Loss 0.024703 | Val Loss 0.096261
# Epoch 200 | Train Loss 0.022465 | Val Loss 0.102811
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.8937, R² diff = 0.9630
# x | ZZx2 -> R² = -0.5913, R² diff = 0.8561
# x | ZZxReto -> R² = 0.7721, R² diff = 0.9301
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.836772 | Val Loss 0.256966
# Epoch 100 | Train Loss 0.024991 | Val Loss 0.096115
# Epoch 200 | Train Loss 0.023306 | Val Loss 0.106790
# Early stopping at epoch 250
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.9794, R² diff = 0.9756
# x | ZZx2 -> R² = -3.6091, R² diff = 0.8025
# x | ZZxReto -> R² = 0.2432, R² diff = 0.9423
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.667484 | Val Loss 0.199515
# Epoch 100 | Train Loss 0.025332 | Val Loss 0.097140
# Epoch 200 | Train Loss 0.023496 | Val Loss 0.098869
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.9017, R² diff = 0.9639
# x | ZZx2 -> R² = 0.0515, R² diff = 0.8651
# x | ZZxReto -> R² = 0.8024, R² diff = 0.9342
# Modelo [81] | Ld=0.3 Lp=0.7 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.766940 | Val Loss 0.244083
# Epoch 100 | Train Loss 0.023371 | Val Loss 0.097649
# Epoch 200 | Train Loss 0.021124 | Val Loss 0.106171
# Early stopping at epoch 249
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed8256.keras
# x | ZZx1 -> R² = 0.9909, R² diff = 0.9765
# x | ZZx2 -> R² = -3.0557, R² diff = 0.8162
# x | ZZxReto -> R² = 0.5077, R² diff = 0.9448
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.430534 | Val Loss 0.227551
# Epoch 100 | Train Loss 0.023535 | Val Loss 0.100429
# Epoch 200 | Train Loss 0.021415 | Val Loss 0.113188
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed6040.keras
# x | ZZx1 -> R² = 0.9347, R² diff = 0.9623
# x | ZZx2 -> R² = -0.0821, R² diff = 0.8681
# x | ZZxReto -> R² = 0.7422, R² diff = 0.9316
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.620624 | Val Loss 0.187399
# Epoch 100 | Train Loss 0.023106 | Val Loss 0.098032
# Epoch 200 | Train Loss 0.020025 | Val Loss 0.102579
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed2393.keras
# x | ZZx1 -> R² = 0.8751, R² diff = 0.9614
# x | ZZx2 -> R² = -0.1294, R² diff = 0.8598
# x | ZZxReto -> R² = 0.8100, R² diff = 0.9298
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.756763 | Val Loss 0.229193
# Epoch 100 | Train Loss 0.023323 | Val Loss 0.090406
# Epoch 200 | Train Loss 0.020831 | Val Loss 0.094205
# Early stopping at epoch 251
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.9905, R² diff = 0.9761
# x | ZZx2 -> R² = -2.6881, R² diff = 0.8147
# x | ZZxReto -> R² = 0.3171, R² diff = 0.9417
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.677489 | Val Loss 0.204966
# Epoch 100 | Train Loss 0.023067 | Val Loss 0.100948
# Epoch 200 | Train Loss 0.020325 | Val Loss 0.107538
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch81_r0.01_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.9169, R² diff = 0.9622
# x | ZZx2 -> R² = 0.3507, R² diff = 0.8567
# x | ZZxReto -> R² = 0.7859, R² diff = 0.9343
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.654760 | Val Loss 0.196312
# Epoch 100 | Train Loss 0.023462 | Val Loss 0.115871
# Epoch 200 | Train Loss 0.021189 | Val Loss 0.126809
# Early stopping at epoch 244
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed8256.keras
# x | ZZx1 -> R² = 0.9823, R² diff = 0.9739
# x | ZZx2 -> R² = -3.5088, R² diff = 0.7834
# x | ZZxReto -> R² = 0.3265, R² diff = 0.9453
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.520469 | Val Loss 0.145482
# Epoch 100 | Train Loss 0.022902 | Val Loss 0.091113
# Epoch 200 | Train Loss 0.019455 | Val Loss 0.099935
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed6040.keras
# x | ZZx1 -> R² = 0.9101, R² diff = 0.9633
# x | ZZx2 -> R² = 0.8821, R² diff = 0.8502
# x | ZZxReto -> R² = 0.8331, R² diff = 0.9387
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.617463 | Val Loss 0.179082
# Epoch 100 | Train Loss 0.023884 | Val Loss 0.101350
# Epoch 200 | Train Loss 0.022260 | Val Loss 0.106913
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed2393.keras
# x | ZZx1 -> R² = 0.9349, R² diff = 0.9653
# x | ZZx2 -> R² = -0.6385, R² diff = 0.8522
# x | ZZxReto -> R² = 0.7171, R² diff = 0.9328
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.655165 | Val Loss 0.213836
# Epoch 100 | Train Loss 0.022873 | Val Loss 0.094455
# Epoch 200 | Train Loss 0.020019 | Val Loss 0.111276
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.8507, R² diff = 0.9625
# x | ZZx2 -> R² = 0.6588, R² diff = 0.8122
# x | ZZxReto -> R² = 0.9212, R² diff = 0.9421
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.754435 | Val Loss 0.241413
# Epoch 100 | Train Loss 0.023400 | Val Loss 0.115223
# Epoch 200 | Train Loss 0.020853 | Val Loss 0.119282
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch81_r0.9_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.8650, R² diff = 0.9616
# x | ZZx2 -> R² = 0.6971, R² diff = 0.8528
# x | ZZxReto -> R² = 0.8921, R² diff = 0.9378
# Modelo [81] | Ld=0.7 Lp=0.3 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.605395 | Val Loss 0.181985
# Epoch 100 | Train Loss 0.024559 | Val Loss 0.105931
# Epoch 200 | Train Loss 0.022405 | Val Loss 0.109058
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.8619, R² diff = 0.9611
# x | ZZx2 -> R² = 0.5057, R² diff = 0.8535
# x | ZZxReto -> R² = 0.8457, R² diff = 0.9326
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.361966 | Val Loss 0.159810
# Epoch 100 | Train Loss 0.024972 | Val Loss 0.096821
# Epoch 200 | Train Loss 0.021331 | Val Loss 0.097687
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.9368, R² diff = 0.9622
# x | ZZx2 -> R² = -0.9029, R² diff = 0.8527
# x | ZZxReto -> R² = 0.6660, R² diff = 0.9283
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.879144 | Val Loss 0.410594
# Epoch 100 | Train Loss 0.023935 | Val Loss 0.100546
# Epoch 200 | Train Loss 0.021277 | Val Loss 0.112151
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.8170, R² diff = 0.9577
# x | ZZx2 -> R² = 0.8591, R² diff = 0.8411
# x | ZZxReto -> R² = 0.9246, R² diff = 0.9349
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.511550 | Val Loss 0.173411
# Epoch 100 | Train Loss 0.023945 | Val Loss 0.097197
# Epoch 200 | Train Loss 0.020823 | Val Loss 0.099452
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.8791, R² diff = 0.9650
# x | ZZx2 -> R² = 0.9019, R² diff = 0.8421
# x | ZZxReto -> R² = 0.8877, R² diff = 0.9418
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.666552 | Val Loss 0.241448
# Epoch 100 | Train Loss 0.023713 | Val Loss 0.095511
# Epoch 200 | Train Loss 0.020592 | Val Loss 0.106260
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.8674, R² diff = 0.9642
# x | ZZx2 -> R² = 0.8982, R² diff = 0.8444
# x | ZZxReto -> R² = 0.9034, R² diff = 0.9419
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.812180 | Val Loss 0.276456
# Epoch 100 | Train Loss 0.024314 | Val Loss 0.115135
# Epoch 200 | Train Loss 0.022112 | Val Loss 0.119707
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.8249, R² diff = 0.9597
# x | ZZx2 -> R² = 0.7741, R² diff = 0.8240
# x | ZZxReto -> R² = 0.9250, R² diff = 0.9389
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.637080 | Val Loss 0.188558
# Epoch 100 | Train Loss 0.024004 | Val Loss 0.099843
# Epoch 200 | Train Loss 0.021047 | Val Loss 0.112990
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.8972, R² diff = 0.9615
# x | ZZx2 -> R² = 0.1508, R² diff = 0.8594
# x | ZZxReto -> R² = 0.8047, R² diff = 0.9328
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.643600 | Val Loss 0.183828
# Epoch 100 | Train Loss 0.024162 | Val Loss 0.097683
# Epoch 200 | Train Loss 0.022266 | Val Loss 0.099053
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.8520, R² diff = 0.9588
# x | ZZx2 -> R² = 0.7438, R² diff = 0.8562
# x | ZZxReto -> R² = 0.8687, R² diff = 0.9314
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.475512 | Val Loss 0.212958
# Epoch 100 | Train Loss 0.023817 | Val Loss 0.113108
# Epoch 200 | Train Loss 0.020547 | Val Loss 0.112680
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.8752, R² diff = 0.9650
# x | ZZx2 -> R² = 0.8488, R² diff = 0.8192
# x | ZZxReto -> R² = 0.9106, R² diff = 0.9441
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.619606 | Val Loss 0.256828
# Epoch 100 | Train Loss 0.023973 | Val Loss 0.081303
# Epoch 200 | Train Loss 0.020561 | Val Loss 0.090011
# Early stopping at epoch 246
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.9951, R² diff = 0.9763
# x | ZZx2 -> R² = -2.8279, R² diff = 0.8331
# x | ZZxReto -> R² = 0.3161, R² diff = 0.9366
# Modelo [82] | Ld=0.5 Lp=0.5 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.633930 | Val Loss 0.184926
# Epoch 100 | Train Loss 0.025343 | Val Loss 0.104821
# Epoch 200 | Train Loss 0.023187 | Val Loss 0.108957
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.8572, R² diff = 0.9671
# x | ZZx2 -> R² = 0.7322, R² diff = 0.8016
# x | ZZxReto -> R² = 0.9106, R² diff = 0.9467
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.512355 | Val Loss 0.246064
# Epoch 100 | Train Loss 0.024956 | Val Loss 0.090862
# Epoch 200 | Train Loss 0.022032 | Val Loss 0.099403
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.9098, R² diff = 0.9647
# x | ZZx2 -> R² = 0.5616, R² diff = 0.8565
# x | ZZxReto -> R² = 0.7930, R² diff = 0.9356
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.633607 | Val Loss 0.184606
# Epoch 100 | Train Loss 0.024657 | Val Loss 0.108625
# Epoch 200 | Train Loss 0.022569 | Val Loss 0.110695
# Early stopping at epoch 229
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.8496, R² diff = 0.9618
# x | ZZx2 -> R² = 0.8139, R² diff = 0.8478
# x | ZZxReto -> R² = 0.8986, R² diff = 0.9372
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.684387 | Val Loss 0.201649
# Epoch 100 | Train Loss 0.024763 | Val Loss 0.093936
# Epoch 200 | Train Loss 0.022203 | Val Loss 0.097347
# Early stopping at epoch 276
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.9945, R² diff = 0.9773
# x | ZZx2 -> R² = -3.3289, R² diff = 0.8000
# x | ZZxReto -> R² = 0.3868, R² diff = 0.9396
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.714710 | Val Loss 0.294068
# Epoch 100 | Train Loss 0.025006 | Val Loss 0.090661
# Epoch 200 | Train Loss 0.022270 | Val Loss 0.098411
# Early stopping at epoch 274
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.9898, R² diff = 0.9771
# x | ZZx2 -> R² = -2.4015, R² diff = 0.8150
# x | ZZxReto -> R² = 0.4701, R² diff = 0.9413
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.752248 | Val Loss 0.300568
# Epoch 100 | Train Loss 0.024820 | Val Loss 0.103652
# Epoch 200 | Train Loss 0.022381 | Val Loss 0.108378
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.8411, R² diff = 0.9647
# x | ZZx2 -> R² = 0.9054, R² diff = 0.8365
# x | ZZxReto -> R² = 0.9005, R² diff = 0.9409
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.603225 | Val Loss 0.192904
# Epoch 100 | Train Loss 0.025444 | Val Loss 0.103970
# Epoch 200 | Train Loss 0.022916 | Val Loss 0.121101
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.9191, R² diff = 0.9639
# x | ZZx2 -> R² = -0.6578, R² diff = 0.8492
# x | ZZxReto -> R² = 0.7415, R² diff = 0.9317
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.726579 | Val Loss 0.224646
# Epoch 100 | Train Loss 0.024611 | Val Loss 0.111302
# Epoch 200 | Train Loss 0.022678 | Val Loss 0.114008
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.8418, R² diff = 0.9634
# x | ZZx2 -> R² = 0.7353, R² diff = 0.8076
# x | ZZxReto -> R² = 0.9289, R² diff = 0.9434
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.596314 | Val Loss 0.168477
# Epoch 100 | Train Loss 0.025052 | Val Loss 0.100441
# Epoch 200 | Train Loss 0.022646 | Val Loss 0.103946
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.8886, R² diff = 0.9647
# x | ZZx2 -> R² = 0.8579, R² diff = 0.8169
# x | ZZxReto -> R² = 0.8747, R² diff = 0.9426
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.799368 | Val Loss 0.306673
# Epoch 100 | Train Loss 0.025329 | Val Loss 0.091177
# Epoch 200 | Train Loss 0.023284 | Val Loss 0.101330
# Early stopping at epoch 293
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.9944, R² diff = 0.9770
# x | ZZx2 -> R² = -3.7685, R² diff = 0.8089
# x | ZZxReto -> R² = 0.4114, R² diff = 0.9416
# Modelo [82] | Ld=0.3 Lp=0.7 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.627195 | Val Loss 0.181311
# Epoch 100 | Train Loss 0.023362 | Val Loss 0.101027
# Epoch 200 | Train Loss 0.020840 | Val Loss 0.102292
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed8256.keras
# x | ZZx1 -> R² = 0.8604, R² diff = 0.9608
# x | ZZx2 -> R² = 0.5872, R² diff = 0.8608
# x | ZZxReto -> R² = 0.8560, R² diff = 0.9337
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.579490 | Val Loss 0.166133
# Epoch 100 | Train Loss 0.023112 | Val Loss 0.109642
# Epoch 200 | Train Loss 0.020362 | Val Loss 0.117377
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed6040.keras
# x | ZZx1 -> R² = 0.8979, R² diff = 0.9600
# x | ZZx2 -> R² = -0.1980, R² diff = 0.8674
# x | ZZxReto -> R² = 0.8062, R² diff = 0.9306
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.675407 | Val Loss 0.201006
# Epoch 100 | Train Loss 0.022866 | Val Loss 0.100223
# Epoch 200 | Train Loss 0.019919 | Val Loss 0.107426
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed2393.keras
# x | ZZx1 -> R² = 0.8589, R² diff = 0.9583
# x | ZZx2 -> R² = 0.8820, R² diff = 0.8469
# x | ZZxReto -> R² = 0.9074, R² diff = 0.9356
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.484247 | Val Loss 0.167319
# Epoch 100 | Train Loss 0.023351 | Val Loss 0.106546
# Epoch 200 | Train Loss 0.020842 | Val Loss 0.114800
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.8926, R² diff = 0.9627
# x | ZZx2 -> R² = 0.8841, R² diff = 0.8281
# x | ZZxReto -> R² = 0.8759, R² diff = 0.9400
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.620871 | Val Loss 0.295586
# Epoch 100 | Train Loss 0.023371 | Val Loss 0.088830
# Epoch 200 | Train Loss 0.020366 | Val Loss 0.101307
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch82_r0.01_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.8833, R² diff = 0.9654
# x | ZZx2 -> R² = 0.8790, R² diff = 0.8309
# x | ZZxReto -> R² = 0.8772, R² diff = 0.9433
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.835462 | Val Loss 0.317653
# Epoch 100 | Train Loss 0.023117 | Val Loss 0.102912
# Epoch 200 | Train Loss 0.020366 | Val Loss 0.112737
# Early stopping at epoch 234
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed8256.keras
# x | ZZx1 -> R² = 0.8308, R² diff = 0.9638
# x | ZZx2 -> R² = 0.9026, R² diff = 0.8387
# x | ZZxReto -> R² = 0.9062, R² diff = 0.9409
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.487763 | Val Loss 0.147036
# Epoch 100 | Train Loss 0.023085 | Val Loss 0.097922
# Epoch 200 | Train Loss 0.020027 | Val Loss 0.112291
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed6040.keras
# x | ZZx1 -> R² = 0.8997, R² diff = 0.9619
# x | ZZx2 -> R² = 0.2737, R² diff = 0.8602
# x | ZZxReto -> R² = 0.7854, R² diff = 0.9307
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.493560 | Val Loss 0.139902
# Epoch 100 | Train Loss 0.023294 | Val Loss 0.109642
# Epoch 200 | Train Loss 0.021065 | Val Loss 0.119665
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed2393.keras
# x | ZZx1 -> R² = 0.8419, R² diff = 0.9588
# x | ZZx2 -> R² = 0.6590, R² diff = 0.8517
# x | ZZxReto -> R² = 0.8815, R² diff = 0.9319
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.603179 | Val Loss 0.180273
# Epoch 100 | Train Loss 0.023298 | Val Loss 0.097408
# Epoch 200 | Train Loss 0.020813 | Val Loss 0.103059
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.8695, R² diff = 0.9622
# x | ZZx2 -> R² = 0.9094, R² diff = 0.8399
# x | ZZxReto -> R² = 0.8723, R² diff = 0.9366
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.429160 | Val Loss 0.302499
# Epoch 100 | Train Loss 0.023081 | Val Loss 0.086831
# Epoch 200 | Train Loss 0.019332 | Val Loss 0.091692
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch82_r0.9_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.8840, R² diff = 0.9661
# x | ZZx2 -> R² = 0.8780, R² diff = 0.8274
# x | ZZxReto -> R² = 0.8377, R² diff = 0.9401
# Modelo [82] | Ld=0.7 Lp=0.3 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.758318 | Val Loss 0.222156
# Epoch 100 | Train Loss 0.024458 | Val Loss 0.095493
# Epoch 200 | Train Loss 0.022681 | Val Loss 0.098321
# Early stopping at epoch 247
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.9937, R² diff = 0.9764
# x | ZZx2 -> R² = -3.5844, R² diff = 0.8021
# x | ZZxReto -> R² = 0.3603, R² diff = 0.9387
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.774843 | Val Loss 0.319901
# Epoch 100 | Train Loss 0.024241 | Val Loss 0.105670
# Epoch 200 | Train Loss 0.022019 | Val Loss 0.114392
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.9359, R² diff = 0.9660
# x | ZZx2 -> R² = -1.5417, R² diff = 0.8380
# x | ZZxReto -> R² = 0.7284, R² diff = 0.9351
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.881505 | Val Loss 0.281581
# Epoch 100 | Train Loss 0.024182 | Val Loss 0.096107
# Epoch 200 | Train Loss 0.022003 | Val Loss 0.106253
# Early stopping at epoch 249
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.9903, R² diff = 0.9754
# x | ZZx2 -> R² = -3.6215, R² diff = 0.8127
# x | ZZxReto -> R² = 0.3908, R² diff = 0.9453
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.591500 | Val Loss 0.210343
# Epoch 100 | Train Loss 0.024049 | Val Loss 0.110908
# Epoch 200 | Train Loss 0.021296 | Val Loss 0.112195
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.8787, R² diff = 0.9621
# x | ZZx2 -> R² = 0.3655, R² diff = 0.8498
# x | ZZxReto -> R² = 0.8342, R² diff = 0.9337
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.577090 | Val Loss 0.162850
# Epoch 100 | Train Loss 0.023684 | Val Loss 0.111424
# Epoch 200 | Train Loss 0.020675 | Val Loss 0.118048
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.8825, R² diff = 0.9601
# x | ZZx2 -> R² = 0.6594, R² diff = 0.8639
# x | ZZxReto -> R² = 0.8660, R² diff = 0.9359
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.555046 | Val Loss 0.166664
# Epoch 100 | Train Loss 0.024658 | Val Loss 0.110734
# Epoch 200 | Train Loss 0.022985 | Val Loss 0.115540
# Early stopping at epoch 288
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.9910, R² diff = 0.9772
# x | ZZx2 -> R² = -6.0949, R² diff = 0.7795
# x | ZZxReto -> R² = 0.4515, R² diff = 0.9410
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.691930 | Val Loss 0.226796
# Epoch 100 | Train Loss 0.024433 | Val Loss 0.104587
# Epoch 200 | Train Loss 0.022687 | Val Loss 0.110216
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.9233, R² diff = 0.9591
# x | ZZx2 -> R² = -0.2690, R² diff = 0.8654
# x | ZZxReto -> R² = 0.7661, R² diff = 0.9284
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.930013 | Val Loss 0.380389
# Epoch 100 | Train Loss 0.023631 | Val Loss 0.093868
# Epoch 200 | Train Loss 0.021567 | Val Loss 0.101364
# Early stopping at epoch 234
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.8175, R² diff = 0.9595
# x | ZZx2 -> R² = 0.6289, R² diff = 0.8158
# x | ZZxReto -> R² = 0.9365, R² diff = 0.9394
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.803941 | Val Loss 0.249716
# Epoch 100 | Train Loss 0.024971 | Val Loss 0.108201
# Epoch 200 | Train Loss 0.022797 | Val Loss 0.116660
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.8819, R² diff = 0.9616
# x | ZZx2 -> R² = 0.8891, R² diff = 0.8235
# x | ZZxReto -> R² = 0.8671, R² diff = 0.9386
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.475314 | Val Loss 0.167825
# Epoch 100 | Train Loss 0.023603 | Val Loss 0.107244
# Epoch 200 | Train Loss 0.021501 | Val Loss 0.112719
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.9199, R² diff = 0.9606
# x | ZZx2 -> R² = -0.2267, R² diff = 0.8561
# x | ZZxReto -> R² = 0.7785, R² diff = 0.9313
# Modelo [83] | Ld=0.5 Lp=0.5 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.867491 | Val Loss 0.287165
# Epoch 100 | Train Loss 0.025208 | Val Loss 0.100142
# Epoch 200 | Train Loss 0.023446 | Val Loss 0.110352
# Early stopping at epoch 251
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.9916, R² diff = 0.9751
# x | ZZx2 -> R² = -3.5114, R² diff = 0.7998
# x | ZZxReto -> R² = 0.4230, R² diff = 0.9438
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.912413 | Val Loss 0.365777
# Epoch 100 | Train Loss 0.024842 | Val Loss 0.104924
# Epoch 200 | Train Loss 0.022759 | Val Loss 0.114444
# Early stopping at epoch 229
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.8456, R² diff = 0.9578
# x | ZZx2 -> R² = 0.0235, R² diff = 0.8482
# x | ZZxReto -> R² = 0.8600, R² diff = 0.9287
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.811458 | Val Loss 0.244413
# Epoch 100 | Train Loss 0.025002 | Val Loss 0.100007
# Epoch 200 | Train Loss 0.022840 | Val Loss 0.108828
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.8535, R² diff = 0.9616
# x | ZZx2 -> R² = 0.5003, R² diff = 0.8089
# x | ZZxReto -> R² = 0.9417, R² diff = 0.9441
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.681317 | Val Loss 0.251318
# Epoch 100 | Train Loss 0.025000 | Val Loss 0.110972
# Epoch 200 | Train Loss 0.022606 | Val Loss 0.110041
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.8273, R² diff = 0.9638
# x | ZZx2 -> R² = 0.7412, R² diff = 0.8061
# x | ZZxReto -> R² = 0.9279, R² diff = 0.9432
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.541218 | Val Loss 0.152968
# Epoch 100 | Train Loss 0.024095 | Val Loss 0.103063
# Epoch 200 | Train Loss 0.021402 | Val Loss 0.118449
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch83_r0.01_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.9338, R² diff = 0.9615
# x | ZZx2 -> R² = -0.1585, R² diff = 0.8566
# x | ZZxReto -> R² = 0.7410, R² diff = 0.9331
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.626438 | Val Loss 0.199761
# Epoch 100 | Train Loss 0.025084 | Val Loss 0.100493
# Epoch 200 | Train Loss 0.022729 | Val Loss 0.104304
# Early stopping at epoch 244
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.9920, R² diff = 0.9765
# x | ZZx2 -> R² = -3.5944, R² diff = 0.8001
# x | ZZxReto -> R² = 0.4324, R² diff = 0.9401
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.857038 | Val Loss 0.286105
# Epoch 100 | Train Loss 0.025359 | Val Loss 0.116185
# Epoch 200 | Train Loss 0.023684 | Val Loss 0.115453
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.9255, R² diff = 0.9626
# x | ZZx2 -> R² = -0.2492, R² diff = 0.8574
# x | ZZxReto -> R² = 0.8078, R² diff = 0.9357
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.940944 | Val Loss 0.294236
# Epoch 100 | Train Loss 0.024460 | Val Loss 0.117516
# Epoch 200 | Train Loss 0.022099 | Val Loss 0.130176
# Early stopping at epoch 247
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.9809, R² diff = 0.9724
# x | ZZx2 -> R² = -2.2368, R² diff = 0.7983
# x | ZZxReto -> R² = 0.4544, R² diff = 0.9524
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.712216 | Val Loss 0.206690
# Epoch 100 | Train Loss 0.025617 | Val Loss 0.099898
# Epoch 200 | Train Loss 0.023507 | Val Loss 0.104158
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.8854, R² diff = 0.9623
# x | ZZx2 -> R² = 0.7691, R² diff = 0.8074
# x | ZZxReto -> R² = 0.8788, R² diff = 0.9407
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.799096 | Val Loss 0.271560
# Epoch 100 | Train Loss 0.023507 | Val Loss 0.095328
# Epoch 200 | Train Loss 0.021175 | Val Loss 0.102197
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch83_r0.9_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.8512, R² diff = 0.9633
# x | ZZx2 -> R² = 0.8279, R² diff = 0.8642
# x | ZZxReto -> R² = 0.8898, R² diff = 0.9382
# Modelo [83] | Ld=0.3 Lp=0.7 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.765159 | Val Loss 0.231883
# ...
# Epoch 200 | Train Loss 0.020563 | Val Loss 0.112180
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch99_r0.01_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.8742, R² diff = 0.9578
# x | ZZx2 -> R² = -0.1125, R² diff = 0.8576
# x | ZZxReto -> R² = 0.8184, R² diff = 0.9271
# Modelo [99] | Ld=0.7 Lp=0.3 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.352381 | Val Loss 0.168240
# Epoch 100 | Train Loss 0.023590 | Val Loss 0.112667
# Epoch 200 | Train Loss 0.020074 | Val Loss 0.123798
# Early stopping at epoch 218
# Modelo salvo em:
# models/model_arch99_r0.01_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.9003, R² diff = 0.9545
# x | ZZx2 -> R² = -0.2908, R² diff = 0.8433
# x | ZZxReto -> R² = 0.7988, R² diff = 0.9248
# Modelo [99] | Ld=0.7 Lp=0.3 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.728637 | Val Loss 0.209189
# Epoch 100 | Train Loss 0.023164 | Val Loss 0.106420
# Epoch 200 | Train Loss 0.021515 | Val Loss 0.115821
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch99_r0.9_Ld0.7_Lp0.3_seed8256.keras
# x | ZZx1 -> R² = 0.8346, R² diff = 0.9594
# x | ZZx2 -> R² = 0.8000, R² diff = 0.8610
# x | ZZxReto -> R² = 0.8913, R² diff = 0.9327
# Modelo [99] | Ld=0.7 Lp=0.3 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.494357 | Val Loss 0.187721
# Epoch 100 | Train Loss 0.022199 | Val Loss 0.113531
# Epoch 200 | Train Loss 0.019146 | Val Loss 0.128787
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch99_r0.9_Ld0.7_Lp0.3_seed6040.keras
# x | ZZx1 -> R² = 0.8698, R² diff = 0.9573
# x | ZZx2 -> R² = 0.3632, R² diff = 0.8671
# x | ZZxReto -> R² = 0.8496, R² diff = 0.9287
# Modelo [99] | Ld=0.7 Lp=0.3 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.707432 | Val Loss 0.254778
# Epoch 100 | Train Loss 0.022897 | Val Loss 0.093973
# Epoch 200 | Train Loss 0.020095 | Val Loss 0.109219
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch99_r0.9_Ld0.7_Lp0.3_seed2393.keras
# x | ZZx1 -> R² = 0.7941, R² diff = 0.9538
# x | ZZx2 -> R² = 0.7647, R² diff = 0.8612
# x | ZZxReto -> R² = 0.8862, R² diff = 0.9251
# Modelo [99] | Ld=0.7 Lp=0.3 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.829971 | Val Loss 0.285527
# Epoch 100 | Train Loss 0.022890 | Val Loss 0.105915
# Epoch 200 | Train Loss 0.020545 | Val Loss 0.114717
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch99_r0.9_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.8351, R² diff = 0.9540
# x | ZZx2 -> R² = 0.6827, R² diff = 0.8683
# x | ZZxReto -> R² = 0.8722, R² diff = 0.9262
# Modelo [99] | Ld=0.7 Lp=0.3 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.409067 | Val Loss 0.117228
# Epoch 100 | Train Loss 0.022740 | Val Loss 0.105990
# Epoch 200 | Train Loss 0.018923 | Val Loss 0.113618
# Early stopping at epoch 217
# Modelo salvo em:
# models/model_arch99_r0.9_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.9481, R² diff = 0.9651
# x | ZZx2 -> R² = -1.2794, R² diff = 0.8297
# x | ZZxReto -> R² = 0.6823, R² diff = 0.9336
# Modelo [99] | Ld=0.7 Lp=0.3 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.522892 | Val Loss 0.195819
# Epoch 100 | Train Loss 0.023881 | Val Loss 0.100768
# Epoch 200 | Train Loss 0.021063 | Val Loss 0.113221
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.9235, R² diff = 0.9603
# x | ZZx2 -> R² = -0.1431, R² diff = 0.8613
# x | ZZxReto -> R² = 0.7202, R² diff = 0.9285
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.484776 | Val Loss 0.248564
# Epoch 100 | Train Loss 0.024692 | Val Loss 0.108920
# Epoch 200 | Train Loss 0.022055 | Val Loss 0.120440
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.8996, R² diff = 0.9596
# x | ZZx2 -> R² = 0.8295, R² diff = 0.8557
# x | ZZxReto -> R² = 0.8437, R² diff = 0.9326
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.499831 | Val Loss 0.132214
# Epoch 100 | Train Loss 0.024273 | Val Loss 0.112213
# Epoch 200 | Train Loss 0.021512 | Val Loss 0.117679
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.8959, R² diff = 0.9590
# x | ZZx2 -> R² = 0.1727, R² diff = 0.8589
# x | ZZxReto -> R² = 0.8053, R² diff = 0.9295
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.678984 | Val Loss 0.268726
# Epoch 100 | Train Loss 0.024378 | Val Loss 0.094019
# Epoch 200 | Train Loss 0.022538 | Val Loss 0.098142
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.8701, R² diff = 0.9607
# x | ZZx2 -> R² = 0.4265, R² diff = 0.8633
# x | ZZxReto -> R² = 0.8056, R² diff = 0.9292
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.532261 | Val Loss 0.174999
# Epoch 100 | Train Loss 0.024649 | Val Loss 0.122634
# Epoch 200 | Train Loss 0.022509 | Val Loss 0.142357
# Early stopping at epoch 218
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.9596, R² diff = 0.9664
# x | ZZx2 -> R² = -0.9380, R² diff = 0.8275
# x | ZZxReto -> R² = 0.6843, R² diff = 0.9378
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.789880 | Val Loss 0.229000
# Epoch 100 | Train Loss 0.023797 | Val Loss 0.111173
# Epoch 200 | Train Loss 0.021402 | Val Loss 0.124198
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed8256.keras
# x | ZZx1 -> R² = 0.8955, R² diff = 0.9573
# x | ZZx2 -> R² = 0.3412, R² diff = 0.8603
# x | ZZxReto -> R² = 0.8071, R² diff = 0.9286
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.392504 | Val Loss 0.198219
# Epoch 100 | Train Loss 0.023776 | Val Loss 0.104313
# Epoch 200 | Train Loss 0.019988 | Val Loss 0.125816
# Early stopping at epoch 218
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed6040.keras
# x | ZZx1 -> R² = 0.8831, R² diff = 0.9583
# x | ZZx2 -> R² = 0.6001, R² diff = 0.8688
# x | ZZxReto -> R² = 0.8362, R² diff = 0.9291
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.610704 | Val Loss 0.202042
# Epoch 100 | Train Loss 0.024292 | Val Loss 0.105383
# Epoch 200 | Train Loss 0.021554 | Val Loss 0.103482
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed2393.keras
# x | ZZx1 -> R² = 0.9293, R² diff = 0.9626
# x | ZZx2 -> R² = -0.2106, R² diff = 0.8567
# x | ZZxReto -> R² = 0.7698, R² diff = 0.9340
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.575006 | Val Loss 0.154194
# Epoch 100 | Train Loss 0.024342 | Val Loss 0.098069
# Epoch 200 | Train Loss 0.022435 | Val Loss 0.103162
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed4073.keras
# x | ZZx1 -> R² = 0.8423, R² diff = 0.9578
# x | ZZx2 -> R² = 0.3616, R² diff = 0.8671
# x | ZZxReto -> R² = 0.8408, R² diff = 0.9270
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.357513 | Val Loss 0.145058
# Epoch 100 | Train Loss 0.023997 | Val Loss 0.113060
# Epoch 200 | Train Loss 0.020701 | Val Loss 0.119364
# Early stopping at epoch 215
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.5_Lp0.5_seed9339.keras
# x | ZZx1 -> R² = 0.9628, R² diff = 0.9663
# x | ZZx2 -> R² = -2.1229, R² diff = 0.8378
# x | ZZxReto -> R² = 0.5942, R² diff = 0.9345
# Modelo [100] | Ld=0.5 Lp=0.5 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.547745 | Val Loss 0.202694
# Epoch 100 | Train Loss 0.024855 | Val Loss 0.102509
# Epoch 200 | Train Loss 0.022788 | Val Loss 0.106776
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.8779, R² diff = 0.9640
# x | ZZx2 -> R² = 0.7994, R² diff = 0.8384
# x | ZZxReto -> R² = 0.8488, R² diff = 0.9372
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.514646 | Val Loss 0.235539
# Epoch 100 | Train Loss 0.024761 | Val Loss 0.098367
# Epoch 200 | Train Loss 0.021730 | Val Loss 0.109302
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.8702, R² diff = 0.9623
# x | ZZx2 -> R² = 0.8518, R² diff = 0.8607
# x | ZZxReto -> R² = 0.8726, R² diff = 0.9360
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.735283 | Val Loss 0.283038
# Epoch 100 | Train Loss 0.025194 | Val Loss 0.101930
# Epoch 200 | Train Loss 0.023360 | Val Loss 0.101325
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.8355, R² diff = 0.9591
# x | ZZx2 -> R² = 0.8622, R² diff = 0.8557
# x | ZZxReto -> R² = 0.8842, R² diff = 0.9327
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.619066 | Val Loss 0.159942
# Epoch 100 | Train Loss 0.025006 | Val Loss 0.097783
# Epoch 200 | Train Loss 0.023020 | Val Loss 0.101282
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.8741, R² diff = 0.9604
# x | ZZx2 -> R² = 0.3655, R² diff = 0.8674
# x | ZZxReto -> R² = 0.8218, R² diff = 0.9305
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.451883 | Val Loss 0.166002
# Epoch 100 | Train Loss 0.024751 | Val Loss 0.115777
# Epoch 200 | Train Loss 0.021122 | Val Loss 0.130969
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.9328, R² diff = 0.9596
# x | ZZx2 -> R² = -0.4083, R² diff = 0.8545
# x | ZZxReto -> R² = 0.7432, R² diff = 0.9302
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.730408 | Val Loss 0.203719
# Epoch 100 | Train Loss 0.025105 | Val Loss 0.099845
# Epoch 200 | Train Loss 0.023303 | Val Loss 0.107531
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed8256.keras
# x | ZZx1 -> R² = 0.9020, R² diff = 0.9592
# x | ZZx2 -> R² = 0.4054, R² diff = 0.8566
# x | ZZxReto -> R² = 0.7955, R² diff = 0.9298
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.411471 | Val Loss 0.188073
# Epoch 100 | Train Loss 0.024793 | Val Loss 0.099203
# Epoch 200 | Train Loss 0.021661 | Val Loss 0.110051
# Early stopping at epoch 219
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed6040.keras
# x | ZZx1 -> R² = 0.8736, R² diff = 0.9602
# x | ZZx2 -> R² = 0.6921, R² diff = 0.8600
# x | ZZxReto -> R² = 0.8354, R² diff = 0.9299
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.632063 | Val Loss 0.184458
# Epoch 100 | Train Loss 0.025027 | Val Loss 0.098727
# Epoch 200 | Train Loss 0.023099 | Val Loss 0.102749
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed2393.keras
# x | ZZx1 -> R² = 0.8961, R² diff = 0.9575
# x | ZZx2 -> R² = 0.0939, R² diff = 0.8657
# x | ZZxReto -> R² = 0.7791, R² diff = 0.9258
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.452133 | Val Loss 0.115281
# Epoch 100 | Train Loss 0.024935 | Val Loss 0.105773
# Epoch 200 | Train Loss 0.022378 | Val Loss 0.114690
# Early stopping at epoch 218
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed4073.keras
# x | ZZx1 -> R² = 0.9338, R² diff = 0.9594
# x | ZZx2 -> R² = -0.1386, R² diff = 0.8576
# x | ZZxReto -> R² = 0.7176, R² diff = 0.9292
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.443267 | Val Loss 0.144630
# Epoch 100 | Train Loss 0.024904 | Val Loss 0.116938
# Epoch 200 | Train Loss 0.021854 | Val Loss 0.139032
# Early stopping at epoch 217
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed9339.keras
# x | ZZx1 -> R² = 0.9484, R² diff = 0.9629
# x | ZZx2 -> R² = -0.0467, R² diff = 0.8485
# x | ZZxReto -> R² = 0.7554, R² diff = 0.9382
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=9339 salvo.
# Epoch 0 | Train Loss 0.717767 | Val Loss 0.218057
# Epoch 100 | Train Loss 0.023033 | Val Loss 0.122530
# Epoch 200 | Train Loss 0.020680 | Val Loss 0.129648
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed8256.keras
# x | ZZx1 -> R² = 0.8827, R² diff = 0.9574
# x | ZZx2 -> R² = 0.1462, R² diff = 0.8649
# x | ZZxReto -> R² = 0.8454, R² diff = 0.9291
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=8256 salvo.
# Epoch 0 | Train Loss 0.462686 | Val Loss 0.194592
# Epoch 100 | Train Loss 0.023696 | Val Loss 0.094180
# Epoch 200 | Train Loss 0.021524 | Val Loss 0.102270
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed6040.keras
# x | ZZx1 -> R² = 0.8601, R² diff = 0.9599
# x | ZZx2 -> R² = 0.8776, R² diff = 0.8546
# x | ZZxReto -> R² = 0.8477, R² diff = 0.9313
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=6040 salvo.
# Epoch 0 | Train Loss 0.492440 | Val Loss 0.177061
# Epoch 100 | Train Loss 0.023264 | Val Loss 0.100560
# Epoch 200 | Train Loss 0.020268 | Val Loss 0.111886
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed2393.keras
# x | ZZx1 -> R² = 0.8472, R² diff = 0.9585
# x | ZZx2 -> R² = -0.3141, R² diff = 0.8618
# x | ZZxReto -> R² = 0.8248, R² diff = 0.9261
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=2393 salvo.
# Epoch 0 | Train Loss 0.777285 | Val Loss 0.234551
# Epoch 100 | Train Loss 0.023877 | Val Loss 0.098623
# Epoch 200 | Train Loss 0.022297 | Val Loss 0.104010
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.9014, R² diff = 0.9584
# x | ZZx2 -> R² = -0.6539, R² diff = 0.8552
# x | ZZxReto -> R² = 0.7192, R² diff = 0.9226
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=4073 salvo.
# Epoch 0 | Train Loss 0.404639 | Val Loss 0.183019
# Epoch 100 | Train Loss 0.022621 | Val Loss 0.127174
# Epoch 200 | Train Loss 0.019038 | Val Loss 0.141711
# Early stopping at epoch 216
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.9600, R² diff = 0.9644
# x | ZZx2 -> R² = -1.8231, R² diff = 0.8235
# x | ZZxReto -> R² = 0.6685, R² diff = 0.9384
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=9339 salvo.
# Epoch 0 | Train Loss 0.558197 | Val Loss 0.155421
# Epoch 100 | Train Loss 0.023050 | Val Loss 0.111104
# Epoch 200 | Train Loss 0.021007 | Val Loss 0.124853
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed8256.keras
# x | ZZx1 -> R² = 0.8364, R² diff = 0.9599
# x | ZZx2 -> R² = 0.5963, R² diff = 0.8567
# x | ZZxReto -> R² = 0.8773, R² diff = 0.9327
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=8256 salvo.
# Epoch 0 | Train Loss 0.425686 | Val Loss 0.230327
# Epoch 100 | Train Loss 0.022753 | Val Loss 0.093937
# Epoch 200 | Train Loss 0.019369 | Val Loss 0.103566
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed6040.keras
# x | ZZx1 -> R² = 0.8916, R² diff = 0.9603
# x | ZZx2 -> R² = 0.6527, R² diff = 0.8692
# x | ZZxReto -> R² = 0.8243, R² diff = 0.9312
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=6040 salvo.
# Epoch 0 | Train Loss 0.682107 | Val Loss 0.209351
# Epoch 100 | Train Loss 0.023386 | Val Loss 0.104799
# Epoch 200 | Train Loss 0.020800 | Val Loss 0.103935
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed2393.keras
# x | ZZx1 -> R² = 0.8683, R² diff = 0.9567
# x | ZZx2 -> R² = 0.3654, R² diff = 0.8606
# x | ZZxReto -> R² = 0.8284, R² diff = 0.9269
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=2393 salvo.
# Epoch 0 | Train Loss 0.581762 | Val Loss 0.191124
# Epoch 100 | Train Loss 0.023205 | Val Loss 0.123420
# Epoch 200 | Train Loss 0.020643 | Val Loss 0.139727
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed4073.keras
# x | ZZx1 -> R² = 0.9043, R² diff = 0.9535
# x | ZZx2 -> R² = 0.1943, R² diff = 0.8641
# x | ZZxReto -> R² = 0.8061, R² diff = 0.9256
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=4073 salvo.
# Epoch 0 | Train Loss 0.628458 | Val Loss 0.161432
# Epoch 100 | Train Loss 0.023505 | Val Loss 0.114762
# Epoch 200 | Train Loss 0.021463 | Val Loss 0.131489
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed9339.keras
# x | ZZx1 -> R² = 0.9322, R² diff = 0.9609
# x | ZZx2 -> R² = -1.1438, R² diff = 0.8438
# x | ZZxReto -> R² = 0.7285, R² diff = 0.9289
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=9339 salvo.
