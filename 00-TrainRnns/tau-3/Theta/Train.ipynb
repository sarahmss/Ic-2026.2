# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = [
    "ZZx1",  # Train
    "ZZx2",  # Val
    "ZZxReto", # Test
    "ZZy1", # Test
    "ZZy2", # Test
    "LSG-1", # Test
    "LSG-2", # Test
    "ZZx1-inv", # Test
    "zzx2-inv2", # Test
    "semiCirc", # Test
]

PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a"]   
TARGET_INT = ["theta"]  
TARGET = ["dtheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
PLOT = False
# Out:
# /Users/cyberxoke/Documents/Sarah/Ic-2026.2/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
Datasets = []
for title in TITLES:
    df = pd.read_excel("./../../00-Data/SavgolDatasets.xlsx", sheet_name=title)
    Datasets.append(df)

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["Se_a"] = Dataset["e_a_d"] + Dataset["e_a_e"]
    Dataset["De_a"] = Dataset["e_a_d"] - Dataset["e_a_e"]

    Dataset = Dataset.dropna(subset=[f"d{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train = Train1

# Train2 = Datasets[1].copy()
# Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
# Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
# NormDatasets.append(Train2)

# # concatena
# Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(9):
    CurrentTestDataset = Datasets[i + 1].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = NormDatasets[1]

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1033, 3, 4)
# Dimensão da saida: (1033, 1)
# Dimensão da entrada: (1391, 3, 4)
# Dimensão da saida: (1391, 1)

# %%
phi_d_train =  Train["phi_d"].values[:len(x_train)]
phi_e_train =  Train["phi_e"].values[:len(x_train)]
theta_train = Train["theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(phi_d_train)}")
print(f"Dimensão da entrada fisica: {np.shape(phi_e_train)}")
# Out:
# Dimensão da entrada: (1033, 3, 4)
# Dimensão da saida: (1033, 1)
# Dimensão da entrada fisica : (1033,)
# Dimensão da entrada fisica: (1033,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):

    dtheta_cin = (R / (2 * L)) * (phi_d - phi_e)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(dq).T, np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, phi_d, phi_e, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(phi_d, phi_e, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss, data_loss, physics_loss

# %%
phi_d_train = tf.convert_to_tensor(phi_d_train, dtype=tf.float32)
phi_e_train = tf.convert_to_tensor(phi_e_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss, data_loss, physics_loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          phi_d_train, phi_e_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | data Loss {data_loss.numpy():.6f} |  physics Loss {physics_loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_mse = f"MSE_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_mse, []).append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {mse:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"MSE_{safe_title}_{name}"] = to_scalar(metrics[name][f"MSE_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    #os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    #weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    #model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}")

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import initializers
from itertools import product
import numpy as np
import tensorflow as tf

N_MODELS = 5

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

# architectures = [[n] for n in range(1, 101)]


#FirstLayers = [
#   [2], [3], [4]
#]
#architectures = [
#    [fl[0], sl]
#    for fl in FirstLayers
#    for sl in range(
#        max(1, int(0.3 * fl[0])),
#        int(0.7 * fl[0])
#    )
#]

# 🔹 retomar a partir do último modelo salvo
# last_saved = [27, 12]

# if last_saved in architectures:
#     idx = architectures.index(last_saved)
#     architectures = architectures[idx + 1:]  # começa DEPOIS do último salvo
#     print(f"Retomando a partir de {last_saved} (índice {idx}). Restam {len(architectures)} arquiteturas.")
# else:
#     print(f"⚠️ {last_saved} não encontrado na lista — rodando tudo do zero.")

architectures = [[3, 1, 1]]
print(len(architectures))
print(architectures)

Ld_Lp = [[0.5, 0.5], [0.3, 0.7], [0.7, 0.3]]

r_values = [0.01, 0.9]

results = {}

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados-2l.xlsx")
# Out:
# 1
# [[3, 1, 1]]
# Epoch 0 | Train Loss 1.037327 | data Loss 1.001955 |  physics Loss 1.072699 | Val Loss 0.977492
# Epoch 100 | Train Loss 0.992166 | data Loss 0.953013 |  physics Loss 1.031319 | Val Loss 0.907088
# Epoch 200 | Train Loss 0.749274 | data Loss 0.684738 |  physics Loss 0.813810 | Val Loss 0.717315
# Epoch 300 | Train Loss 0.654568 | data Loss 0.574649 |  physics Loss 0.734487 | Val Loss 0.669749
# Epoch 400 | Train Loss 0.614111 | data Loss 0.527202 |  physics Loss 0.701020 | Val Loss 0.659536
# Epoch 500 | Train Loss 0.588643 | data Loss 0.496654 |  physics Loss 0.680631 | Val Loss 0.658393
# Epoch 600 | Train Loss 0.567867 | data Loss 0.472245 |  physics Loss 0.663488 | Val Loss 0.640023
# Epoch 700 | Train Loss 0.548158 | data Loss 0.450834 |  physics Loss 0.645481 | Val Loss 0.609191
# Epoch 800 | Train Loss 0.527274 | data Loss 0.429947 |  physics Loss 0.624602 | Val Loss 0.587901
# Epoch 900 | Train Loss 0.503294 | data Loss 0.408283 |  physics Loss 0.598306 | Val Loss 0.570262
# Epoch 1000 | Train Loss 0.472423 | data Loss 0.383726 |  physics Loss 0.561119 | Val Loss 0.555732
# Epoch 1100 | Train Loss 0.436897 | data Loss 0.358777 |  physics Loss 0.515016 | Val Loss 0.550200
# Epoch 1200 | Train Loss 0.406375 | data Loss 0.341126 |  physics Loss 0.471624 | Val Loss 0.557058
# Early stopping at epoch 1278
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed4210.keras
# theta | ZZx1 -> R² = 0.7006, R² diff = 0.6372
# theta | ZZx2 -> R² = 0.1921, R² diff = 0.4374
# theta | ZZxReto -> R² = 0.5275, R² diff = 0.6135
# theta | ZZy1 -> R² = -8.9551, R² diff = 0.3149
# theta | ZZy2 -> R² = -15.7428, R² diff = 0.1698
# theta | LSG-1 -> R² = -0.7355, R² diff = 0.4982
# theta | LSG-2 -> R² = -2.9474, R² diff = 0.2876
# theta | ZZx1-inv -> R² = -0.7458, R² diff = 0.4068
# theta | zzx2-inv2 -> R² = -8.2391, R² diff = 0.1410
# theta | semiCirc -> R² = -14.8995, R² diff = 0.0281
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=4210 salvo.
# Epoch 0 | Train Loss 1.037802 | data Loss 1.002475 |  physics Loss 1.073130 | Val Loss 0.978606
# Epoch 100 | Train Loss 1.029652 | data Loss 0.993520 |  physics Loss 1.065784 | Val Loss 0.962277
# Epoch 200 | Train Loss 0.831819 | data Loss 0.772477 |  physics Loss 0.891161 | Val Loss 0.775891
# Epoch 300 | Train Loss 0.709801 | data Loss 0.630314 |  physics Loss 0.789287 | Val Loss 0.698477
# Epoch 400 | Train Loss 0.656702 | data Loss 0.568559 |  physics Loss 0.744846 | Val Loss 0.670188
# Epoch 500 | Train Loss 0.624223 | data Loss 0.529775 |  physics Loss 0.718672 | Val Loss 0.650439
# Epoch 600 | Train Loss 0.600558 | data Loss 0.501237 |  physics Loss 0.699878 | Val Loss 0.632498
# Epoch 700 | Train Loss 0.581999 | data Loss 0.478790 |  physics Loss 0.685207 | Val Loss 0.616306
# Epoch 800 | Train Loss 0.566635 | data Loss 0.460306 |  physics Loss 0.672963 | Val Loss 0.601776
# Epoch 900 | Train Loss 0.553273 | data Loss 0.444384 |  physics Loss 0.662161 | Val Loss 0.589515
# Epoch 1000 | Train Loss 0.541225 | data Loss 0.430156 |  physics Loss 0.652294 | Val Loss 0.581784
# Epoch 1100 | Train Loss 0.530042 | data Loss 0.417193 |  physics Loss 0.642891 | Val Loss 0.587944
# Early stopping at epoch 1191
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed355.keras
# theta | ZZx1 -> R² = 0.6623, R² diff = 0.5698
# theta | ZZx2 -> R² = 0.6478, R² diff = 0.4046
# theta | ZZxReto -> R² = 0.5071, R² diff = 0.5590
# theta | ZZy1 -> R² = -6.5882, R² diff = 0.3025
# theta | ZZy2 -> R² = -16.8693, R² diff = 0.1531
# theta | LSG-1 -> R² = -1.6374, R² diff = 0.4738
# theta | LSG-2 -> R² = -2.6937, R² diff = 0.2540
# theta | ZZx1-inv -> R² = -1.4551, R² diff = 0.3140
# theta | zzx2-inv2 -> R² = -7.1690, R² diff = 0.1623
# theta | semiCirc -> R² = -13.4408, R² diff = 0.0660
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=355 salvo.
# Epoch 0 | Train Loss 1.037782 | data Loss 1.002453 |  physics Loss 1.073111 | Val Loss 0.978570
# Epoch 100 | Train Loss 1.028169 | data Loss 0.991832 |  physics Loss 1.064505 | Val Loss 0.962518
# Epoch 200 | Train Loss 0.855960 | data Loss 0.799061 |  physics Loss 0.912859 | Val Loss 0.790433
# Epoch 300 | Train Loss 0.711180 | data Loss 0.629682 |  physics Loss 0.792679 | Val Loss 0.697168
# Epoch 400 | Train Loss 0.655805 | data Loss 0.565409 |  physics Loss 0.746201 | Val Loss 0.666444
# Epoch 500 | Train Loss 0.622842 | data Loss 0.525262 |  physics Loss 0.720423 | Val Loss 0.645832
# Epoch 600 | Train Loss 0.599826 | data Loss 0.496904 |  physics Loss 0.702747 | Val Loss 0.630502
# Epoch 700 | Train Loss 0.581617 | data Loss 0.474981 |  physics Loss 0.688253 | Val Loss 0.614877
# Epoch 800 | Train Loss 0.566093 | data Loss 0.456576 |  physics Loss 0.675610 | Val Loss 0.600654
# Epoch 900 | Train Loss 0.552518 | data Loss 0.440563 |  physics Loss 0.664472 | Val Loss 0.588839
# Epoch 1000 | Train Loss 0.540411 | data Loss 0.426423 |  physics Loss 0.654399 | Val Loss 0.578404
# Epoch 1100 | Train Loss 0.529591 | data Loss 0.413754 |  physics Loss 0.645428 | Val Loss 0.568873
# Epoch 1200 | Train Loss 0.520072 | data Loss 0.402394 |  physics Loss 0.637750 | Val Loss 0.560899
# Epoch 1300 | Train Loss 0.511813 | data Loss 0.392390 |  physics Loss 0.631236 | Val Loss 0.554545
# Epoch 1400 | Train Loss 0.504593 | data Loss 0.383612 |  physics Loss 0.625574 | Val Loss 0.550338
# Epoch 1500 | Train Loss 0.498172 | data Loss 0.375826 |  physics Loss 0.620518 | Val Loss 0.548191
# Epoch 1600 | Train Loss 0.492413 | data Loss 0.368874 |  physics Loss 0.615952 | Val Loss 0.547366
# Epoch 1700 | Train Loss 0.487162 | data Loss 0.362460 |  physics Loss 0.611863 | Val Loss 0.549808
# Early stopping at epoch 1739
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed7095.keras
# theta | ZZx1 -> R² = 0.7331, R² diff = 0.6280
# theta | ZZx2 -> R² = -0.1419, R² diff = 0.4398
# theta | ZZxReto -> R² = 0.6103, R² diff = 0.6456
# theta | ZZy1 -> R² = -15.2298, R² diff = 0.2429
# theta | ZZy2 -> R² = -17.8698, R² diff = 0.1007
# theta | LSG-1 -> R² = 0.1974, R² diff = 0.5387
# theta | LSG-2 -> R² = -2.6737, R² diff = 0.2909
# theta | ZZx1-inv -> R² = -1.1601, R² diff = 0.4166
# theta | zzx2-inv2 -> R² = -10.7970, R² diff = 0.0867
# theta | semiCirc -> R² = -20.0335, R² diff = -0.0331
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=7095 salvo.
# Epoch 0 | Train Loss 1.037746 | data Loss 1.002411 |  physics Loss 1.073081 | Val Loss 0.978450
# Epoch 100 | Train Loss 1.023390 | data Loss 0.986457 |  physics Loss 1.060322 | Val Loss 0.953472
# Epoch 200 | Train Loss 0.821741 | data Loss 0.759647 |  physics Loss 0.883834 | Val Loss 0.758909
# Epoch 300 | Train Loss 0.687823 | data Loss 0.602636 |  physics Loss 0.773010 | Val Loss 0.673727
# Epoch 400 | Train Loss 0.640077 | data Loss 0.546661 |  physics Loss 0.733493 | Val Loss 0.640496
# Epoch 500 | Train Loss 0.609615 | data Loss 0.510912 |  physics Loss 0.708317 | Val Loss 0.629448
# Epoch 600 | Train Loss 0.586781 | data Loss 0.484033 |  physics Loss 0.689529 | Val Loss 0.621285
# Epoch 700 | Train Loss 0.568203 | data Loss 0.462601 |  physics Loss 0.673804 | Val Loss 0.601776
# Epoch 800 | Train Loss 0.551770 | data Loss 0.444143 |  physics Loss 0.659397 | Val Loss 0.571954
# Epoch 900 | Train Loss 0.533991 | data Loss 0.425223 |  physics Loss 0.642759 | Val Loss 0.542789
# Epoch 1000 | Train Loss 0.507603 | data Loss 0.397643 |  physics Loss 0.617562 | Val Loss 0.566306
# Epoch 1100 | Train Loss 0.491152 | data Loss 0.378876 |  physics Loss 0.603427 | Val Loss 0.596323
# Early stopping at epoch 1115
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed3174.keras
# theta | ZZx1 -> R² = 0.7490, R² diff = 0.5803
# theta | ZZx2 -> R² = 0.8952, R² diff = 0.4471
# theta | ZZxReto -> R² = 0.7050, R² diff = 0.5621
# theta | ZZy1 -> R² = -5.0612, R² diff = 0.3256
# theta | ZZy2 -> R² = -14.9200, R² diff = 0.1958
# theta | LSG-1 -> R² = -1.5036, R² diff = 0.4709
# theta | LSG-2 -> R² = -2.2337, R² diff = 0.2844
# theta | ZZx1-inv -> R² = -1.9113, R² diff = 0.3986
# theta | zzx2-inv2 -> R² = -7.7716, R² diff = 0.2024
# theta | semiCirc -> R² = -13.3171, R² diff = 0.0766
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=3174 salvo.
# Epoch 0 | Train Loss 1.037758 | data Loss 1.002426 |  physics Loss 1.073090 | Val Loss 0.978505
# Epoch 100 | Train Loss 1.021847 | data Loss 0.984831 |  physics Loss 1.058862 | Val Loss 0.955306
# Epoch 200 | Train Loss 0.826940 | data Loss 0.766175 |  physics Loss 0.887706 | Val Loss 0.772481
# Epoch 300 | Train Loss 0.699755 | data Loss 0.617961 |  physics Loss 0.781548 | Val Loss 0.692531
# Epoch 400 | Train Loss 0.648843 | data Loss 0.558741 |  physics Loss 0.738944 | Val Loss 0.663734
# Epoch 500 | Train Loss 0.616286 | data Loss 0.519665 |  physics Loss 0.712907 | Val Loss 0.642962
# Epoch 600 | Train Loss 0.592459 | data Loss 0.490738 |  physics Loss 0.694180 | Val Loss 0.627243
# Epoch 700 | Train Loss 0.572924 | data Loss 0.467704 |  physics Loss 0.678144 | Val Loss 0.607384
# Epoch 800 | Train Loss 0.556309 | data Loss 0.447806 |  physics Loss 0.664813 | Val Loss 0.591693
# Epoch 900 | Train Loss 0.542637 | data Loss 0.431107 |  physics Loss 0.654167 | Val Loss 0.579346
# Epoch 1000 | Train Loss 0.531153 | data Loss 0.416991 |  physics Loss 0.645314 | Val Loss 0.568716
# Epoch 1100 | Train Loss 0.521379 | data Loss 0.404831 |  physics Loss 0.637927 | Val Loss 0.560215
# Epoch 1200 | Train Loss 0.513027 | data Loss 0.394319 |  physics Loss 0.631735 | Val Loss 0.553690
# Epoch 1300 | Train Loss 0.505799 | data Loss 0.385205 |  physics Loss 0.626393 | Val Loss 0.548862
# Epoch 1400 | Train Loss 0.499404 | data Loss 0.377248 |  physics Loss 0.621561 | Val Loss 0.545483
# Epoch 1500 | Train Loss 0.493686 | data Loss 0.370372 |  physics Loss 0.617000 | Val Loss 0.543121
# Epoch 1600 | Train Loss 0.488579 | data Loss 0.364254 |  physics Loss 0.612904 | Val Loss 0.542456
# Epoch 1700 | Train Loss 0.483982 | data Loss 0.358790 |  physics Loss 0.609174 | Val Loss 0.543506
# Early stopping at epoch 1785
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed5986.keras
# theta | ZZx1 -> R² = 0.7413, R² diff = 0.6358
# theta | ZZx2 -> R² = 0.1354, R² diff = 0.4452
# theta | ZZxReto -> R² = 0.7773, R² diff = 0.6452
# theta | ZZy1 -> R² = -12.2743, R² diff = 0.2650
# theta | ZZy2 -> R² = -19.0195, R² diff = 0.0485
# theta | LSG-1 -> R² = 0.2218, R² diff = 0.5380
# theta | LSG-2 -> R² = -3.0008, R² diff = 0.2896
# theta | ZZx1-inv -> R² = -1.2945, R² diff = 0.4106
# theta | zzx2-inv2 -> R² = -11.9957, R² diff = 0.0383
# theta | semiCirc -> R² = -19.9115, R² diff = -0.0287
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=5986 salvo.
# Epoch 0 | Train Loss 1.037747 | data Loss 1.002398 |  physics Loss 1.073095 | Val Loss 0.978381
# Epoch 100 | Train Loss 1.003750 | data Loss 0.965583 |  physics Loss 1.041916 | Val Loss 0.918148
# Epoch 200 | Train Loss 0.743830 | data Loss 0.678935 |  physics Loss 0.808726 | Val Loss 0.710570
# Epoch 300 | Train Loss 0.647731 | data Loss 0.566543 |  physics Loss 0.728919 | Val Loss 0.665002
# Epoch 400 | Train Loss 0.606328 | data Loss 0.519398 |  physics Loss 0.693258 | Val Loss 0.633981
# Epoch 500 | Train Loss 0.572801 | data Loss 0.483940 |  physics Loss 0.661662 | Val Loss 0.615565
# Epoch 600 | Train Loss 0.545536 | data Loss 0.453716 |  physics Loss 0.637355 | Val Loss 0.629304
# Early stopping at epoch 662
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed4210.keras
# theta | ZZx1 -> R² = 0.5855, R² diff = 0.5046
# theta | ZZx2 -> R² = 0.7185, R² diff = 0.3739
# theta | ZZxReto -> R² = 0.0473, R² diff = 0.4792
# theta | ZZy1 -> R² = -3.8431, R² diff = 0.2871
# theta | ZZy2 -> R² = -13.2255, R² diff = 0.2023
# theta | LSG-1 -> R² = -3.5780, R² diff = 0.3997
# theta | LSG-2 -> R² = -2.2299, R² diff = 0.2350
# theta | ZZx1-inv -> R² = -0.8883, R² diff = 0.2825
# theta | zzx2-inv2 -> R² = -4.1278, R² diff = 0.2021
# theta | semiCirc -> R² = -8.3501, R² diff = 0.1093
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=4210 salvo.
# Epoch 0 | Train Loss 1.037786 | data Loss 1.002457 |  physics Loss 1.073115 | Val Loss 0.978573
# Epoch 100 | Train Loss 1.030632 | data Loss 0.994556 |  physics Loss 1.066708 | Val Loss 0.966065
# Epoch 200 | Train Loss 0.858286 | data Loss 0.801672 |  physics Loss 0.914900 | Val Loss 0.785185
# Epoch 300 | Train Loss 0.699828 | data Loss 0.615902 |  physics Loss 0.783754 | Val Loss 0.685853
# Epoch 400 | Train Loss 0.647855 | data Loss 0.554167 |  physics Loss 0.741543 | Val Loss 0.660435
# Epoch 500 | Train Loss 0.618721 | data Loss 0.518229 |  physics Loss 0.719213 | Val Loss 0.645206
# Epoch 600 | Train Loss 0.597379 | data Loss 0.492346 |  physics Loss 0.702413 | Val Loss 0.630626
# Epoch 700 | Train Loss 0.579405 | data Loss 0.471229 |  physics Loss 0.687580 | Val Loss 0.615821
# Epoch 800 | Train Loss 0.563056 | data Loss 0.452643 |  physics Loss 0.673469 | Val Loss 0.600978
# Epoch 900 | Train Loss 0.548158 | data Loss 0.435740 |  physics Loss 0.660576 | Val Loss 0.583567
# Epoch 1000 | Train Loss 0.535200 | data Loss 0.420594 |  physics Loss 0.649806 | Val Loss 0.571364
# Epoch 1100 | Train Loss 0.524268 | data Loss 0.407460 |  physics Loss 0.641076 | Val Loss 0.562219
# Epoch 1200 | Train Loss 0.515185 | data Loss 0.396352 |  physics Loss 0.634018 | Val Loss 0.555027
# Epoch 1300 | Train Loss 0.507539 | data Loss 0.386931 |  physics Loss 0.628146 | Val Loss 0.549318
# Epoch 1400 | Train Loss 0.500940 | data Loss 0.378748 |  physics Loss 0.623133 | Val Loss 0.545273
# Epoch 1500 | Train Loss 0.495105 | data Loss 0.371531 |  physics Loss 0.618678 | Val Loss 0.542433
# Epoch 1600 | Train Loss 0.489772 | data Loss 0.364968 |  physics Loss 0.614577 | Val Loss 0.541273
# Epoch 1700 | Train Loss 0.484603 | data Loss 0.358825 |  physics Loss 0.610382 | Val Loss 0.544288
# Early stopping at epoch 1772
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed355.keras
# theta | ZZx1 -> R² = 0.7368, R² diff = 0.6342
# theta | ZZx2 -> R² = 0.0084, R² diff = 0.4464
# theta | ZZxReto -> R² = 0.7376, R² diff = 0.6550
# theta | ZZy1 -> R² = -13.0030, R² diff = 0.2662
# theta | ZZy2 -> R² = -18.4367, R² diff = 0.0827
# theta | LSG-1 -> R² = 0.4159, R² diff = 0.5506
# theta | LSG-2 -> R² = -2.6162, R² diff = 0.2959
# theta | ZZx1-inv -> R² = -1.4475, R² diff = 0.4149
# theta | zzx2-inv2 -> R² = -11.4964, R² diff = 0.0659
# theta | semiCirc -> R² = -21.7891, R² diff = -0.0582
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=355 salvo.
# Epoch 0 | Train Loss 1.037782 | data Loss 1.002453 |  physics Loss 1.073111 | Val Loss 0.978571
# Epoch 100 | Train Loss 1.027168 | data Loss 0.991005 |  physics Loss 1.063330 | Val Loss 0.958262
# Epoch 200 | Train Loss 0.823888 | data Loss 0.768651 |  physics Loss 0.879125 | Val Loss 0.777848
# Epoch 300 | Train Loss 0.690008 | data Loss 0.615429 |  physics Loss 0.764588 | Val Loss 0.698848
# Epoch 400 | Train Loss 0.637327 | data Loss 0.556193 |  physics Loss 0.718462 | Val Loss 0.662775
# Epoch 500 | Train Loss 0.600712 | data Loss 0.515525 |  physics Loss 0.685899 | Val Loss 0.649858
# Epoch 600 | Train Loss 0.573136 | data Loss 0.484687 |  physics Loss 0.661586 | Val Loss 0.653916
# Epoch 700 | Train Loss 0.551071 | data Loss 0.459480 |  physics Loss 0.642662 | Val Loss 0.640952
# Epoch 800 | Train Loss 0.531003 | data Loss 0.437555 |  physics Loss 0.624450 | Val Loss 0.600402
# Epoch 900 | Train Loss 0.509988 | data Loss 0.417800 |  physics Loss 0.602176 | Val Loss 0.547191
# Epoch 1000 | Train Loss 0.486491 | data Loss 0.398946 |  physics Loss 0.574036 | Val Loss 0.534904
# Epoch 1100 | Train Loss 0.459872 | data Loss 0.377175 |  physics Loss 0.542569 | Val Loss 0.528698
# Epoch 1200 | Train Loss 0.430458 | data Loss 0.349245 |  physics Loss 0.511672 | Val Loss 0.518707
# Epoch 1300 | Train Loss 0.407609 | data Loss 0.332423 |  physics Loss 0.482795 | Val Loss 0.573275
# Early stopping at epoch 1366
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed7095.keras
# theta | ZZx1 -> R² = 0.8377, R² diff = 0.6408
# theta | ZZx2 -> R² = 0.8098, R² diff = 0.4736
# theta | ZZxReto -> R² = 0.5782, R² diff = 0.5879
# theta | ZZy1 -> R² = -17.5450, R² diff = 0.2104
# theta | ZZy2 -> R² = -13.9098, R² diff = 0.2285
# theta | LSG-1 -> R² = -0.7408, R² diff = 0.4947
# theta | LSG-2 -> R² = -1.7169, R² diff = 0.2999
# theta | ZZx1-inv -> R² = -1.4387, R² diff = 0.4388
# theta | zzx2-inv2 -> R² = -6.9447, R² diff = 0.3036
# theta | semiCirc -> R² = -19.5295, R² diff = -0.0383
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=7095 salvo.
# Epoch 0 | Train Loss 1.037510 | data Loss 1.002153 |  physics Loss 1.072866 | Val Loss 0.977883
# Epoch 100 | Train Loss 0.987651 | data Loss 0.947200 |  physics Loss 1.028102 | Val Loss 0.912626
# Epoch 200 | Train Loss 0.797844 | data Loss 0.733494 |  physics Loss 0.862194 | Val Loss 0.755625
# Epoch 300 | Train Loss 0.706992 | data Loss 0.627861 |  physics Loss 0.786124 | Val Loss 0.699322
# Epoch 400 | Train Loss 0.657464 | data Loss 0.570423 |  physics Loss 0.744506 | Val Loss 0.668440
# Epoch 500 | Train Loss 0.623842 | data Loss 0.530835 |  physics Loss 0.716850 | Val Loss 0.650279
# Epoch 600 | Train Loss 0.598825 | data Loss 0.501077 |  physics Loss 0.696573 | Val Loss 0.632877
# Epoch 700 | Train Loss 0.579267 | data Loss 0.477456 |  physics Loss 0.681077 | Val Loss 0.617649
# Epoch 800 | Train Loss 0.563467 | data Loss 0.458159 |  physics Loss 0.668775 | Val Loss 0.603973
# Epoch 900 | Train Loss 0.550294 | data Loss 0.441952 |  physics Loss 0.658636 | Val Loss 0.592146
# Epoch 1000 | Train Loss 0.539053 | data Loss 0.428049 |  physics Loss 0.650056 | Val Loss 0.581775
# Epoch 1100 | Train Loss 0.529293 | data Loss 0.415933 |  physics Loss 0.642652 | Val Loss 0.572971
# Epoch 1200 | Train Loss 0.520723 | data Loss 0.405266 |  physics Loss 0.636180 | Val Loss 0.565022
# Epoch 1300 | Train Loss 0.513150 | data Loss 0.395805 |  physics Loss 0.630495 | Val Loss 0.558335
# Epoch 1400 | Train Loss 0.506437 | data Loss 0.387385 |  physics Loss 0.625489 | Val Loss 0.552581
# Epoch 1500 | Train Loss 0.500477 | data Loss 0.379872 |  physics Loss 0.621082 | Val Loss 0.547849
# Epoch 1600 | Train Loss 0.495179 | data Loss 0.373148 |  physics Loss 0.617210 | Val Loss 0.544127
# Epoch 1700 | Train Loss 0.490447 | data Loss 0.367168 |  physics Loss 0.613727 | Val Loss 0.540993
# Epoch 1800 | Train Loss 0.486183 | data Loss 0.361760 |  physics Loss 0.610606 | Val Loss 0.538680
# Epoch 1900 | Train Loss 0.482314 | data Loss 0.356816 |  physics Loss 0.607812 | Val Loss 0.537755
# Epoch 2000 | Train Loss 0.478745 | data Loss 0.352348 |  physics Loss 0.605141 | Val Loss 0.536045
# Epoch 2100 | Train Loss 0.475469 | data Loss 0.348203 |  physics Loss 0.602736 | Val Loss 0.535616
# Epoch 2200 | Train Loss 0.472453 | data Loss 0.344435 |  physics Loss 0.600472 | Val Loss 0.535296
# Early stopping at epoch 2251
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed3174.keras
# theta | ZZx1 -> R² = 0.7507, R² diff = 0.6507
# theta | ZZx2 -> R² = 0.0245, R² diff = 0.4527
# theta | ZZxReto -> R² = 0.7521, R² diff = 0.6783
# theta | ZZy1 -> R² = -14.5793, R² diff = 0.2553
# theta | ZZy2 -> R² = -18.3361, R² diff = 0.0631
# theta | LSG-1 -> R² = 0.6459, R² diff = 0.5668
# theta | LSG-2 -> R² = -2.5274, R² diff = 0.3092
# theta | ZZx1-inv -> R² = -1.6274, R² diff = 0.4257
# theta | zzx2-inv2 -> R² = -12.7372, R² diff = 0.0221
# theta | semiCirc -> R² = -25.6794, R² diff = -0.1244
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=3174 salvo.
# Epoch 0 | Train Loss 1.037768 | data Loss 1.002436 |  physics Loss 1.073099 | Val Loss 0.978542
# Epoch 100 | Train Loss 1.018764 | data Loss 0.981867 |  physics Loss 1.055660 | Val Loss 0.946168
# Epoch 200 | Train Loss 0.796078 | data Loss 0.737203 |  physics Loss 0.854953 | Val Loss 0.755798
# Epoch 300 | Train Loss 0.681588 | data Loss 0.605302 |  physics Loss 0.757874 | Val Loss 0.690798
# Epoch 400 | Train Loss 0.631717 | data Loss 0.548912 |  physics Loss 0.714522 | Val Loss 0.661323
# Epoch 500 | Train Loss 0.600530 | data Loss 0.512477 |  physics Loss 0.688584 | Val Loss 0.641828
# Epoch 600 | Train Loss 0.574679 | data Loss 0.483432 |  physics Loss 0.665926 | Val Loss 0.602520
# Epoch 700 | Train Loss 0.548257 | data Loss 0.455953 |  physics Loss 0.640561 | Val Loss 0.636316
# Epoch 800 | Train Loss 0.522603 | data Loss 0.430226 |  physics Loss 0.614981 | Val Loss 0.703554
# Early stopping at epoch 810
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed5986.keras
# theta | ZZx1 -> R² = 0.6015, R² diff = 0.5208
# theta | ZZx2 -> R² = 0.7069, R² diff = 0.3863
# theta | ZZxReto -> R² = 0.2041, R² diff = 0.4930
# theta | ZZy1 -> R² = -4.2598, R² diff = 0.2917
# theta | ZZy2 -> R² = -13.4530, R² diff = 0.2012
# theta | LSG-1 -> R² = -3.2245, R² diff = 0.4177
# theta | LSG-2 -> R² = -2.4660, R² diff = 0.2405
# theta | ZZx1-inv -> R² = -0.8702, R² diff = 0.2931
# theta | zzx2-inv2 -> R² = -4.0686, R² diff = 0.2043
# theta | semiCirc -> R² = -9.3552, R² diff = 0.1060
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=5986 salvo.
# Epoch 0 | Train Loss 1.051536 | data Loss 1.002013 |  physics Loss 1.072761 | Val Loss 0.977568
# Epoch 100 | Train Loss 1.026860 | data Loss 0.973494 |  physics Loss 1.049731 | Val Loss 0.948025
# Epoch 200 | Train Loss 0.948281 | data Loss 0.880973 |  physics Loss 0.977127 | Val Loss 0.874816
# Epoch 300 | Train Loss 0.865221 | data Loss 0.780366 |  physics Loss 0.901588 | Val Loss 0.803890
# Epoch 400 | Train Loss 0.783512 | data Loss 0.682499 |  physics Loss 0.826804 | Val Loss 0.739351
# Epoch 500 | Train Loss 0.712146 | data Loss 0.597232 |  physics Loss 0.761395 | Val Loss 0.715096
# Epoch 600 | Train Loss 0.658136 | data Loss 0.530582 |  physics Loss 0.712801 | Val Loss 0.756112
# Early stopping at epoch 672
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed4210.keras
# theta | ZZx1 -> R² = 0.4609, R² diff = 0.3832
# theta | ZZx2 -> R² = 0.3763, R² diff = 0.2686
# theta | ZZxReto -> R² = -0.2107, R² diff = 0.3737
# theta | ZZy1 -> R² = -0.7484, R² diff = 0.2502
# theta | ZZy2 -> R² = -11.2934, R² diff = 0.1646
# theta | LSG-1 -> R² = -6.5691, R² diff = 0.2837
# theta | LSG-2 -> R² = -1.2431, R² diff = 0.1895
# theta | ZZx1-inv -> R² = -1.5437, R² diff = 0.1897
# theta | zzx2-inv2 -> R² = -3.0625, R² diff = 0.1698
# theta | semiCirc -> R² = -3.5990, R² diff = 0.1341
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=4210 salvo.
# Epoch 0 | Train Loss 1.051924 | data Loss 1.002464 |  physics Loss 1.073120 | Val Loss 0.978585
# Epoch 100 | Train Loss 1.036812 | data Loss 0.985078 |  physics Loss 1.058983 | Val Loss 0.948194
# Epoch 200 | Train Loss 0.843626 | data Loss 0.757016 |  physics Loss 0.880744 | Val Loss 0.765351
# Epoch 300 | Train Loss 0.741764 | data Loss 0.629281 |  physics Loss 0.789971 | Val Loss 0.697845
# Epoch 400 | Train Loss 0.694548 | data Loss 0.571438 |  physics Loss 0.747310 | Val Loss 0.668345
# Epoch 500 | Train Loss 0.662328 | data Loss 0.531574 |  physics Loss 0.718365 | Val Loss 0.644186
# Epoch 600 | Train Loss 0.637804 | data Loss 0.500720 |  physics Loss 0.696554 | Val Loss 0.624069
# Epoch 700 | Train Loss 0.619241 | data Loss 0.476825 |  physics Loss 0.680277 | Val Loss 0.607841
# Epoch 800 | Train Loss 0.604500 | data Loss 0.457561 |  physics Loss 0.667474 | Val Loss 0.593818
# Epoch 900 | Train Loss 0.592276 | data Loss 0.441419 |  physics Loss 0.656929 | Val Loss 0.581683
# Epoch 1000 | Train Loss 0.581895 | data Loss 0.427599 |  physics Loss 0.648022 | Val Loss 0.571238
# Epoch 1100 | Train Loss 0.572960 | data Loss 0.415617 |  physics Loss 0.640393 | Val Loss 0.562280
# Epoch 1200 | Train Loss 0.565204 | data Loss 0.405139 |  physics Loss 0.633804 | Val Loss 0.554726
# Epoch 1300 | Train Loss 0.558430 | data Loss 0.395929 |  physics Loss 0.628074 | Val Loss 0.548307
# Epoch 1400 | Train Loss 0.552481 | data Loss 0.387799 |  physics Loss 0.623059 | Val Loss 0.542853
# Epoch 1500 | Train Loss 0.547216 | data Loss 0.380605 |  physics Loss 0.618621 | Val Loss 0.538479
# Epoch 1600 | Train Loss 0.542513 | data Loss 0.374166 |  physics Loss 0.614662 | Val Loss 0.534986
# Epoch 1700 | Train Loss 0.538268 | data Loss 0.368364 |  physics Loss 0.611085 | Val Loss 0.532234
# Epoch 1800 | Train Loss 0.534409 | data Loss 0.363065 |  physics Loss 0.607842 | Val Loss 0.530098
# Epoch 1900 | Train Loss 0.530879 | data Loss 0.358276 |  physics Loss 0.604851 | Val Loss 0.528928
# Epoch 2000 | Train Loss 0.527632 | data Loss 0.353839 |  physics Loss 0.602115 | Val Loss 0.528498
# Epoch 2100 | Train Loss 0.524670 | data Loss 0.349893 |  physics Loss 0.599574 | Val Loss 0.528870
# Early stopping at epoch 2122
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed355.keras
# theta | ZZx1 -> R² = 0.7548, R² diff = 0.6437
# theta | ZZx2 -> R² = 0.1683, R² diff = 0.4592
# theta | ZZxReto -> R² = 0.7842, R² diff = 0.6708
# theta | ZZy1 -> R² = -11.9604, R² diff = 0.2780
# theta | ZZy2 -> R² = -17.9482, R² diff = 0.0849
# theta | LSG-1 -> R² = 0.5697, R² diff = 0.5588
# theta | LSG-2 -> R² = -2.3820, R² diff = 0.3137
# theta | ZZx1-inv -> R² = -1.5709, R² diff = 0.4348
# theta | zzx2-inv2 -> R² = -12.3159, R² diff = 0.0414
# theta | semiCirc -> R² = -23.5487, R² diff = -0.0864
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=355 salvo.
# Epoch 0 | Train Loss 1.051914 | data Loss 1.002453 |  physics Loss 1.073111 | Val Loss 0.978571
# Epoch 100 | Train Loss 1.034842 | data Loss 0.983377 |  physics Loss 1.056899 | Val Loss 0.950447
# Epoch 200 | Train Loss 0.840085 | data Loss 0.760761 |  physics Loss 0.874080 | Val Loss 0.778234
# Epoch 300 | Train Loss 0.731865 | data Loss 0.630070 |  physics Loss 0.775492 | Val Loss 0.708479
# Epoch 400 | Train Loss 0.680003 | data Loss 0.569131 |  physics Loss 0.727520 | Val Loss 0.671350
# Epoch 500 | Train Loss 0.648350 | data Loss 0.529668 |  physics Loss 0.699214 | Val Loss 0.650679
# Epoch 600 | Train Loss 0.624205 | data Loss 0.499001 |  physics Loss 0.677864 | Val Loss 0.630536
# Epoch 700 | Train Loss 0.603764 | data Loss 0.473846 |  physics Loss 0.659443 | Val Loss 0.611852
# Epoch 800 | Train Loss 0.583936 | data Loss 0.452067 |  physics Loss 0.640452 | Val Loss 0.592652
# Epoch 900 | Train Loss 0.551965 | data Loss 0.429529 |  physics Loss 0.604437 | Val Loss 0.581495
# Epoch 1000 | Train Loss 0.486102 | data Loss 0.393401 |  physics Loss 0.525831 | Val Loss 0.589979
# Early stopping at epoch 1093
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed7095.keras
# theta | ZZx1 -> R² = 0.5919, R² diff = 0.5699
# theta | ZZx2 -> R² = 0.6266, R² diff = 0.4052
# theta | ZZxReto -> R² = 0.4713, R² diff = 0.5495
# theta | ZZy1 -> R² = -5.4059, R² diff = 0.3117
# theta | ZZy2 -> R² = -16.1217, R² diff = 0.1766
# theta | LSG-1 -> R² = -1.9551, R² diff = 0.4554
# theta | LSG-2 -> R² = -2.3576, R² diff = 0.2648
# theta | ZZx1-inv -> R² = -1.1285, R² diff = 0.3606
# theta | zzx2-inv2 -> R² = -6.9215, R² diff = 0.1774
# theta | semiCirc -> R² = -9.5667, R² diff = 0.0793
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=7095 salvo.
# Epoch 0 | Train Loss 1.051849 | data Loss 1.002377 |  physics Loss 1.073052 | Val Loss 0.978376
# Epoch 100 | Train Loss 1.034223 | data Loss 0.982001 |  physics Loss 1.056604 | Val Loss 0.948318
# Epoch 200 | Train Loss 0.844311 | data Loss 0.757561 |  physics Loss 0.881490 | Val Loss 0.758162
# Epoch 300 | Train Loss 0.727353 | data Loss 0.608974 |  physics Loss 0.778086 | Val Loss 0.678339
# Epoch 400 | Train Loss 0.681409 | data Loss 0.552605 |  physics Loss 0.736611 | Val Loss 0.641167
# Epoch 500 | Train Loss 0.655423 | data Loss 0.518219 |  physics Loss 0.714225 | Val Loss 0.638056
# Epoch 600 | Train Loss 0.633412 | data Loss 0.491818 |  physics Loss 0.694095 | Val Loss 0.615712
# Epoch 700 | Train Loss 0.615145 | data Loss 0.469654 |  physics Loss 0.677498 | Val Loss 0.596348
# Epoch 800 | Train Loss 0.598793 | data Loss 0.450557 |  physics Loss 0.662323 | Val Loss 0.575164
# Epoch 900 | Train Loss 0.583407 | data Loss 0.433009 |  physics Loss 0.647864 | Val Loss 0.564550
# Epoch 1000 | Train Loss 0.554233 | data Loss 0.404257 |  physics Loss 0.618509 | Val Loss 0.614547
# Early stopping at epoch 1091
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed3174.keras
# theta | ZZx1 -> R² = 0.7403, R² diff = 0.5665
# theta | ZZx2 -> R² = 0.8571, R² diff = 0.4226
# theta | ZZxReto -> R² = 0.8010, R² diff = 0.5585
# theta | ZZy1 -> R² = -4.8999, R² diff = 0.3122
# theta | ZZy2 -> R² = -14.1653, R² diff = 0.2343
# theta | LSG-1 -> R² = -1.5488, R² diff = 0.4692
# theta | LSG-2 -> R² = -1.7515, R² diff = 0.2978
# theta | ZZx1-inv -> R² = -2.9874, R² diff = 0.4003
# theta | zzx2-inv2 -> R² = -8.1573, R² diff = 0.2523
# theta | semiCirc -> R² = -13.2545, R² diff = 0.0790
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=3174 salvo.
# Epoch 0 | Train Loss 1.051880 | data Loss 1.002415 |  physics Loss 1.073080 | Val Loss 0.978485
# Epoch 100 | Train Loss 1.029098 | data Loss 0.976906 |  physics Loss 1.051466 | Val Loss 0.940955
# Epoch 200 | Train Loss 0.822427 | data Loss 0.740374 |  physics Loss 0.857592 | Val Loss 0.760357
# Epoch 300 | Train Loss 0.717406 | data Loss 0.612543 |  physics Loss 0.762347 | Val Loss 0.694852
# Epoch 400 | Train Loss 0.669759 | data Loss 0.556072 |  physics Loss 0.718482 | Val Loss 0.662234
# Epoch 500 | Train Loss 0.642005 | data Loss 0.520650 |  physics Loss 0.694014 | Val Loss 0.648096
# Epoch 600 | Train Loss 0.621825 | data Loss 0.493636 |  physics Loss 0.676763 | Val Loss 0.640462
# Epoch 700 | Train Loss 0.603434 | data Loss 0.470913 |  physics Loss 0.660228 | Val Loss 0.630420
# Epoch 800 | Train Loss 0.584228 | data Loss 0.450414 |  physics Loss 0.641577 | Val Loss 0.610734
# Epoch 900 | Train Loss 0.560054 | data Loss 0.428593 |  physics Loss 0.616395 | Val Loss 0.592526
# Epoch 1000 | Train Loss 0.526249 | data Loss 0.404415 |  physics Loss 0.578464 | Val Loss 0.607412
# Epoch 1100 | Train Loss 0.489359 | data Loss 0.383728 |  physics Loss 0.534630 | Val Loss 0.672469
# Early stopping at epoch 1109
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed5986.keras
# theta | ZZx1 -> R² = 0.6383, R² diff = 0.5748
# theta | ZZx2 -> R² = 0.1424, R² diff = 0.3948
# theta | ZZxReto -> R² = 0.3882, R² diff = 0.5519
# theta | ZZy1 -> R² = -7.3182, R² diff = 0.2891
# theta | ZZy2 -> R² = -15.8924, R² diff = 0.1774
# theta | LSG-1 -> R² = -1.7824, R² diff = 0.4619
# theta | LSG-2 -> R² = -2.3727, R² diff = 0.2623
# theta | ZZx1-inv -> R² = -1.0876, R² diff = 0.3327
# theta | zzx2-inv2 -> R² = -6.9103, R² diff = 0.1725
# theta | semiCirc -> R² = -11.0833, R² diff = 0.0657
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=5986 salvo.
# Epoch 0 | Train Loss 1.051878 | data Loss 1.002396 |  physics Loss 1.073085 | Val Loss 0.978405
# Epoch 100 | Train Loss 1.025393 | data Loss 0.971837 |  physics Loss 1.048346 | Val Loss 0.931194
# Epoch 200 | Train Loss 0.824303 | data Loss 0.733145 |  physics Loss 0.863370 | Val Loss 0.731785
# Epoch 300 | Train Loss 0.705869 | data Loss 0.583753 |  physics Loss 0.758204 | Val Loss 0.656253
# Epoch 400 | Train Loss 0.665572 | data Loss 0.531454 |  physics Loss 0.723050 | Val Loss 0.630740
# Epoch 500 | Train Loss 0.640163 | data Loss 0.499253 |  physics Loss 0.700553 | Val Loss 0.597200
# Epoch 600 | Train Loss 0.619981 | data Loss 0.474605 |  physics Loss 0.682285 | Val Loss 0.574812
# Epoch 700 | Train Loss 0.602835 | data Loss 0.453879 |  physics Loss 0.666673 | Val Loss 0.563246
# Epoch 800 | Train Loss 0.585442 | data Loss 0.434046 |  physics Loss 0.650326 | Val Loss 0.581412
# Epoch 900 | Train Loss 0.563855 | data Loss 0.411191 |  physics Loss 0.629283 | Val Loss 0.577798
# Early stopping at epoch 914
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed4210.keras
# theta | ZZx1 -> R² = 0.6761, R² diff = 0.5501
# theta | ZZx2 -> R² = 0.8858, R² diff = 0.4245
# theta | ZZxReto -> R² = 0.6016, R² diff = 0.5434
# theta | ZZy1 -> R² = -5.7492, R² diff = 0.2920
# theta | ZZy2 -> R² = -13.7892, R² diff = 0.2027
# theta | LSG-1 -> R² = -1.9510, R² diff = 0.4555
# theta | LSG-2 -> R² = -1.9052, R² diff = 0.2776
# theta | ZZx1-inv -> R² = -1.3887, R² diff = 0.3346
# theta | zzx2-inv2 -> R² = -5.6222, R² diff = 0.2015
# theta | semiCirc -> R² = -12.4628, R² diff = 0.0780
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=4210 salvo.
# Epoch 0 | Train Loss 1.051916 | data Loss 1.002456 |  physics Loss 1.073114 | Val Loss 0.978569
# Epoch 100 | Train Loss 1.043913 | data Loss 0.993232 |  physics Loss 1.065634 | Val Loss 0.965219
# Epoch 200 | Train Loss 0.880400 | data Loss 0.801382 |  physics Loss 0.914265 | Val Loss 0.792866
# Epoch 300 | Train Loss 0.727826 | data Loss 0.614390 |  physics Loss 0.776442 | Val Loss 0.674623
# Epoch 400 | Train Loss 0.673697 | data Loss 0.548649 |  physics Loss 0.727289 | Val Loss 0.632141
# Epoch 500 | Train Loss 0.640729 | data Loss 0.508305 |  physics Loss 0.697482 | Val Loss 0.603214
# Epoch 600 | Train Loss 0.615209 | data Loss 0.478388 |  physics Loss 0.673847 | Val Loss 0.581272
# Epoch 700 | Train Loss 0.591419 | data Loss 0.453223 |  physics Loss 0.650646 | Val Loss 0.568613
# Epoch 800 | Train Loss 0.562779 | data Loss 0.423415 |  physics Loss 0.622507 | Val Loss 0.562091
# Epoch 900 | Train Loss 0.531595 | data Loss 0.391440 |  physics Loss 0.591661 | Val Loss 0.601621
# Early stopping at epoch 995
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed355.keras
# theta | ZZx1 -> R² = 0.6601, R² diff = 0.5761
# theta | ZZx2 -> R² = 0.2227, R² diff = 0.4246
# theta | ZZxReto -> R² = 0.4161, R² diff = 0.5262
# theta | ZZy1 -> R² = -5.6131, R² diff = 0.2923
# theta | ZZy2 -> R² = -10.3838, R² diff = 0.2639
# theta | LSG-1 -> R² = -3.6058, R² diff = 0.4258
# theta | LSG-2 -> R² = -1.3681, R² diff = 0.2784
# theta | ZZx1-inv -> R² = -0.4981, R² diff = 0.4289
# theta | zzx2-inv2 -> R² = -3.1690, R² diff = 0.2888
# theta | semiCirc -> R² = -8.5550, R² diff = 0.1142
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=355 salvo.
# Epoch 0 | Train Loss 1.051914 | data Loss 1.002453 |  physics Loss 1.073111 | Val Loss 0.978570
# Epoch 100 | Train Loss 1.028822 | data Loss 0.975929 |  physics Loss 1.051491 | Val Loss 0.942791
# Epoch 200 | Train Loss 0.850523 | data Loss 0.765932 |  physics Loss 0.886776 | Val Loss 0.779658
# Epoch 300 | Train Loss 0.752564 | data Loss 0.646130 |  physics Loss 0.798179 | Val Loss 0.711243
# Epoch 400 | Train Loss 0.701998 | data Loss 0.584221 |  physics Loss 0.752474 | Val Loss 0.677184
# Epoch 500 | Train Loss 0.669163 | data Loss 0.542709 |  physics Loss 0.723357 | Val Loss 0.654196
# Epoch 600 | Train Loss 0.644623 | data Loss 0.511308 |  physics Loss 0.701758 | Val Loss 0.634460
# Epoch 700 | Train Loss 0.625673 | data Loss 0.486593 |  physics Loss 0.685278 | Val Loss 0.617047
# Epoch 800 | Train Loss 0.610434 | data Loss 0.466512 |  physics Loss 0.672114 | Val Loss 0.601677
# Epoch 900 | Train Loss 0.597732 | data Loss 0.449658 |  physics Loss 0.661193 | Val Loss 0.588879
# Epoch 1000 | Train Loss 0.586924 | data Loss 0.435217 |  physics Loss 0.651941 | Val Loss 0.577827
# Epoch 1100 | Train Loss 0.577592 | data Loss 0.422671 |  physics Loss 0.643986 | Val Loss 0.568290
# Epoch 1200 | Train Loss 0.569456 | data Loss 0.411674 |  physics Loss 0.637077 | Val Loss 0.559860
# Epoch 1300 | Train Loss 0.562306 | data Loss 0.401938 |  physics Loss 0.631035 | Val Loss 0.552975
# Epoch 1400 | Train Loss 0.556008 | data Loss 0.393323 |  physics Loss 0.625731 | Val Loss 0.547215
# Epoch 1500 | Train Loss 0.550428 | data Loss 0.385672 |  physics Loss 0.621038 | Val Loss 0.542173
# Epoch 1600 | Train Loss 0.545439 | data Loss 0.378829 |  physics Loss 0.616843 | Val Loss 0.538148
# Epoch 1700 | Train Loss 0.540936 | data Loss 0.372662 |  physics Loss 0.613053 | Val Loss 0.534881
# Epoch 1800 | Train Loss 0.536861 | data Loss 0.367090 |  physics Loss 0.609620 | Val Loss 0.531956
# Epoch 1900 | Train Loss 0.533168 | data Loss 0.361977 |  physics Loss 0.606536 | Val Loss 0.530297
# Epoch 2000 | Train Loss 0.529818 | data Loss 0.357366 |  physics Loss 0.603727 | Val Loss 0.528710
# Epoch 2100 | Train Loss 0.526761 | data Loss 0.353133 |  physics Loss 0.601172 | Val Loss 0.528258
# Epoch 2200 | Train Loss 0.523940 | data Loss 0.349217 |  physics Loss 0.598821 | Val Loss 0.528992
# Early stopping at epoch 2237
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed7095.keras
# theta | ZZx1 -> R² = 0.7418, R² diff = 0.6452
# theta | ZZx2 -> R² = 0.2361, R² diff = 0.4598
# theta | ZZxReto -> R² = 0.7587, R² diff = 0.6723
# theta | ZZy1 -> R² = -12.2357, R² diff = 0.2757
# theta | ZZy2 -> R² = -18.0872, R² diff = 0.0790
# theta | LSG-1 -> R² = 0.5247, R² diff = 0.5575
# theta | LSG-2 -> R² = -2.3926, R² diff = 0.3146
# theta | ZZx1-inv -> R² = -1.6722, R² diff = 0.4323
# theta | zzx2-inv2 -> R² = -12.5456, R² diff = 0.0354
# theta | semiCirc -> R² = -23.4471, R² diff = -0.0846
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=7095 salvo.
# Epoch 0 | Train Loss 1.051796 | data Loss 1.002320 |  physics Loss 1.073000 | Val Loss 0.978279
# Epoch 100 | Train Loss 1.018059 | data Loss 0.964553 |  physics Loss 1.040991 | Val Loss 0.925129
# Epoch 200 | Train Loss 0.807246 | data Loss 0.722360 |  physics Loss 0.843626 | Val Loss 0.747839
# Epoch 300 | Train Loss 0.712561 | data Loss 0.606736 |  physics Loss 0.757915 | Val Loss 0.689732
# Epoch 400 | Train Loss 0.665278 | data Loss 0.552017 |  physics Loss 0.713818 | Val Loss 0.654303
# Epoch 500 | Train Loss 0.636008 | data Loss 0.516031 |  physics Loss 0.687427 | Val Loss 0.631743
# Epoch 600 | Train Loss 0.606064 | data Loss 0.484692 |  physics Loss 0.658080 | Val Loss 0.587807
# Epoch 700 | Train Loss 0.576255 | data Loss 0.455099 |  physics Loss 0.628179 | Val Loss 0.575579
# Epoch 800 | Train Loss 0.543272 | data Loss 0.429485 |  physics Loss 0.592038 | Val Loss 0.585939
# Early stopping at epoch 894
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed3174.keras
# theta | ZZx1 -> R² = 0.6842, R² diff = 0.5447
# theta | ZZx2 -> R² = 0.8454, R² diff = 0.4110
# theta | ZZxReto -> R² = 0.4875, R² diff = 0.5200
# theta | ZZy1 -> R² = -5.8482, R² diff = 0.2889
# theta | ZZy2 -> R² = -13.7623, R² diff = 0.2126
# theta | LSG-1 -> R² = -2.3332, R² diff = 0.4374
# theta | LSG-2 -> R² = -2.0289, R² diff = 0.2674
# theta | ZZx1-inv -> R² = -1.4752, R² diff = 0.3168
# theta | zzx2-inv2 -> R² = -5.3201, R² diff = 0.2175
# theta | semiCirc -> R² = -10.6683, R² diff = 0.0917
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=3174 salvo.
# Epoch 0 | Train Loss 1.051920 | data Loss 1.002460 |  physics Loss 1.073118 | Val Loss 0.978576
# Epoch 100 | Train Loss 1.040054 | data Loss 0.989254 |  physics Loss 1.061826 | Val Loss 0.957397
# Epoch 200 | Train Loss 0.835570 | data Loss 0.756503 |  physics Loss 0.869456 | Val Loss 0.768613
# Epoch 300 | Train Loss 0.711706 | data Loss 0.606067 |  physics Loss 0.756981 | Val Loss 0.691648
# Epoch 400 | Train Loss 0.663221 | data Loss 0.548184 |  physics Loss 0.712522 | Val Loss 0.660171
# Epoch 500 | Train Loss 0.630131 | data Loss 0.510207 |  physics Loss 0.681526 | Val Loss 0.632020
# Epoch 600 | Train Loss 0.594735 | data Loss 0.475569 |  physics Loss 0.645806 | Val Loss 0.664683
# Early stopping at epoch 694
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed5986.keras
# theta | ZZx1 -> R² = 0.5459, R² diff = 0.4893
# theta | ZZx2 -> R² = 0.7344, R² diff = 0.3538
# theta | ZZxReto -> R² = -0.0064, R² diff = 0.4650
# theta | ZZy1 -> R² = -3.0487, R² diff = 0.2862
# theta | ZZy2 -> R² = -12.6986, R² diff = 0.2023
# theta | LSG-1 -> R² = -3.9928, R² diff = 0.3848
# theta | LSG-2 -> R² = -2.2088, R² diff = 0.2297
# theta | ZZx1-inv -> R² = -0.7939, R² diff = 0.2740
# theta | zzx2-inv2 -> R² = -3.5663, R² diff = 0.2017
# theta | semiCirc -> R² = -7.2810, R² diff = 0.1167
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=5986 salvo.
# Epoch 0 | Train Loss 1.023709 | data Loss 1.002511 |  physics Loss 1.073170 | Val Loss 0.978556
# Epoch 100 | Train Loss 0.996344 | data Loss 0.973854 |  physics Loss 1.048820 | Val Loss 0.927488
# Epoch 200 | Train Loss 0.732350 | data Loss 0.694685 |  physics Loss 0.820235 | Val Loss 0.716274
# Epoch 300 | Train Loss 0.615010 | data Loss 0.565789 |  physics Loss 0.729861 | Val Loss 0.665557
# Epoch 400 | Train Loss 0.571750 | data Loss 0.518707 |  physics Loss 0.695518 | Val Loss 0.646492
# Epoch 500 | Train Loss 0.543258 | data Loss 0.487432 |  physics Loss 0.673521 | Val Loss 0.618506
# Epoch 600 | Train Loss 0.516853 | data Loss 0.459689 |  physics Loss 0.650237 | Val Loss 0.606194
# Epoch 700 | Train Loss 0.492899 | data Loss 0.435035 |  physics Loss 0.627917 | Val Loss 0.642564
# Early stopping at epoch 760
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed4210.keras
# theta | ZZx1 -> R² = 0.6252, R² diff = 0.5309
# theta | ZZx2 -> R² = 0.5379, R² diff = 0.3845
# theta | ZZxReto -> R² = 0.2088, R² diff = 0.5005
# theta | ZZy1 -> R² = -5.1271, R² diff = 0.2837
# theta | ZZy2 -> R² = -13.8579, R² diff = 0.1969
# theta | LSG-1 -> R² = -2.8699, R² diff = 0.4305
# theta | LSG-2 -> R² = -2.4611, R² diff = 0.2396
# theta | ZZx1-inv -> R² = -0.7416, R² diff = 0.2903
# theta | zzx2-inv2 -> R² = -4.2914, R² diff = 0.2012
# theta | semiCirc -> R² = -10.6229, R² diff = 0.0818
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=4210 salvo.
# Epoch 0 | Train Loss 1.023657 | data Loss 1.002460 |  physics Loss 1.073117 | Val Loss 0.978583
# Epoch 100 | Train Loss 1.008782 | data Loss 0.986878 |  physics Loss 1.059890 | Val Loss 0.953020
# Epoch 200 | Train Loss 0.787158 | data Loss 0.752805 |  physics Loss 0.867315 | Val Loss 0.767678
# Epoch 300 | Train Loss 0.657506 | data Loss 0.612043 |  physics Loss 0.763585 | Val Loss 0.696599
# Epoch 400 | Train Loss 0.603139 | data Loss 0.553474 |  physics Loss 0.719023 | Val Loss 0.664374
# Epoch 500 | Train Loss 0.569551 | data Loss 0.516464 |  physics Loss 0.693420 | Val Loss 0.650179
# Epoch 600 | Train Loss 0.544835 | data Loss 0.488650 |  physics Loss 0.675932 | Val Loss 0.650717
# Epoch 700 | Train Loss 0.524370 | data Loss 0.465941 |  physics Loss 0.660703 | Val Loss 0.644381
# Epoch 800 | Train Loss 0.505390 | data Loss 0.445699 |  physics Loss 0.644670 | Val Loss 0.622943
# Epoch 900 | Train Loss 0.484833 | data Loss 0.425033 |  physics Loss 0.624366 | Val Loss 0.589538
# Epoch 1000 | Train Loss 0.460219 | data Loss 0.401484 |  physics Loss 0.597269 | Val Loss 0.567051
# Epoch 1100 | Train Loss 0.436856 | data Loss 0.380318 |  physics Loss 0.568780 | Val Loss 0.592093
# Early stopping at epoch 1184
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed355.keras
# theta | ZZx1 -> R² = 0.7149, R² diff = 0.5960
# theta | ZZx2 -> R² = 0.4262, R² diff = 0.4194
# theta | ZZxReto -> R² = 0.6657, R² diff = 0.5685
# theta | ZZy1 -> R² = -8.1722, R² diff = 0.2895
# theta | ZZy2 -> R² = -17.3144, R² diff = 0.1491
# theta | LSG-1 -> R² = -1.1192, R² diff = 0.4877
# theta | LSG-2 -> R² = -2.5852, R² diff = 0.2642
# theta | ZZx1-inv -> R² = -1.6928, R² diff = 0.3050
# theta | zzx2-inv2 -> R² = -8.0358, R² diff = 0.1525
# theta | semiCirc -> R² = -14.4204, R² diff = 0.0353
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=355 salvo.
# Epoch 0 | Train Loss 1.023651 | data Loss 1.002453 |  physics Loss 1.073112 | Val Loss 0.978570
# Epoch 100 | Train Loss 1.015242 | data Loss 0.993530 |  physics Loss 1.065905 | Val Loss 0.964517
# Epoch 200 | Train Loss 0.841226 | data Loss 0.807508 |  physics Loss 0.919900 | Val Loss 0.790881
# Epoch 300 | Train Loss 0.674844 | data Loss 0.624737 |  physics Loss 0.791762 | Val Loss 0.689415
# Epoch 400 | Train Loss 0.614430 | data Loss 0.559532 |  physics Loss 0.742524 | Val Loss 0.644779
# Epoch 500 | Train Loss 0.575307 | data Loss 0.517446 |  physics Loss 0.710315 | Val Loss 0.616048
# Epoch 600 | Train Loss 0.546589 | data Loss 0.486307 |  physics Loss 0.687246 | Val Loss 0.594481
# Epoch 700 | Train Loss 0.523521 | data Loss 0.461259 |  physics Loss 0.668799 | Val Loss 0.577876
# Epoch 800 | Train Loss 0.503512 | data Loss 0.439521 |  physics Loss 0.652823 | Val Loss 0.569431
# Epoch 900 | Train Loss 0.485785 | data Loss 0.420306 |  physics Loss 0.638569 | Val Loss 0.566738
# Epoch 1000 | Train Loss 0.470057 | data Loss 0.403465 |  physics Loss 0.625440 | Val Loss 0.565173
# Epoch 1100 | Train Loss 0.453206 | data Loss 0.385957 |  physics Loss 0.610121 | Val Loss 0.553794
# Epoch 1200 | Train Loss 0.428881 | data Loss 0.359602 |  physics Loss 0.590531 | Val Loss 0.504508
# Epoch 1300 | Train Loss 0.411661 | data Loss 0.342050 |  physics Loss 0.574087 | Val Loss 0.498932
# Epoch 1400 | Train Loss 0.397231 | data Loss 0.326945 |  physics Loss 0.561233 | Val Loss 0.500020
# Epoch 1500 | Train Loss 0.384679 | data Loss 0.313678 |  physics Loss 0.550351 | Val Loss 0.504414
# Early stopping at epoch 1501
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed7095.keras
# theta | ZZx1 -> R² = 0.7542, R² diff = 0.6591
# theta | ZZx2 -> R² = 0.6862, R² diff = 0.4901
# theta | ZZxReto -> R² = 0.7582, R² diff = 0.6133
# theta | ZZy1 -> R² = -8.2295, R² diff = 0.3163
# theta | ZZy2 -> R² = -13.1286, R² diff = 0.1892
# theta | LSG-1 -> R² = -0.4792, R² diff = 0.5345
# theta | LSG-2 -> R² = -2.2324, R² diff = 0.3059
# theta | ZZx1-inv -> R² = -0.7956, R² diff = 0.4689
# theta | zzx2-inv2 -> R² = -7.2160, R² diff = 0.2146
# theta | semiCirc -> R² = -19.7574, R² diff = -0.0148
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=7095 salvo.
# Epoch 0 | Train Loss 1.023424 | data Loss 1.002213 |  physics Loss 1.072917 | Val Loss 0.978051
# Epoch 100 | Train Loss 0.975607 | data Loss 0.951555 |  physics Loss 1.031729 | Val Loss 0.914160
# Epoch 200 | Train Loss 0.768898 | data Loss 0.729856 |  physics Loss 0.859994 | Val Loss 0.752002
# Epoch 300 | Train Loss 0.669906 | data Loss 0.621709 |  physics Loss 0.782366 | Val Loss 0.695201
# Epoch 400 | Train Loss 0.618492 | data Loss 0.565578 |  physics Loss 0.741956 | Val Loss 0.669541
# Epoch 500 | Train Loss 0.584716 | data Loss 0.528193 |  physics Loss 0.716604 | Val Loss 0.651370
# Epoch 600 | Train Loss 0.559735 | data Loss 0.500317 |  physics Loss 0.698377 | Val Loss 0.634307
# Epoch 700 | Train Loss 0.540086 | data Loss 0.478273 |  physics Loss 0.684317 | Val Loss 0.618275
# Epoch 800 | Train Loss 0.523830 | data Loss 0.460008 |  physics Loss 0.672747 | Val Loss 0.603841
# Epoch 900 | Train Loss 0.509663 | data Loss 0.444180 |  physics Loss 0.662457 | Val Loss 0.591164
# Epoch 1000 | Train Loss 0.495165 | data Loss 0.428734 |  physics Loss 0.650172 | Val Loss 0.578146
# Epoch 1100 | Train Loss 0.474750 | data Loss 0.407146 |  physics Loss 0.632492 | Val Loss 0.552071
# Epoch 1200 | Train Loss 0.451542 | data Loss 0.381798 |  physics Loss 0.614279 | Val Loss 0.637096
# Epoch 1300 | Train Loss 0.429602 | data Loss 0.359715 |  physics Loss 0.592670 | Val Loss 0.837914
# Early stopping at epoch 1328
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed3174.keras
# theta | ZZx1 -> R² = 0.7293, R² diff = 0.6006
# theta | ZZx2 -> R² = 0.8413, R² diff = 0.4439
# theta | ZZxReto -> R² = 0.7168, R² diff = 0.5792
# theta | ZZy1 -> R² = -6.3216, R² diff = 0.3282
# theta | ZZy2 -> R² = -19.3486, R² diff = 0.1131
# theta | LSG-1 -> R² = -1.4995, R² diff = 0.4877
# theta | LSG-2 -> R² = -2.8208, R² diff = 0.2555
# theta | ZZx1-inv -> R² = -2.7801, R² diff = 0.2915
# theta | zzx2-inv2 -> R² = -9.7055, R² diff = 0.1349
# theta | semiCirc -> R² = -16.1513, R² diff = 0.0376
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=3174 salvo.
# Epoch 0 | Train Loss 1.023623 | data Loss 1.002423 |  physics Loss 1.073089 | Val Loss 0.978488
# Epoch 100 | Train Loss 0.991424 | data Loss 0.968349 |  physics Loss 1.045267 | Val Loss 0.932736
# Epoch 200 | Train Loss 0.779969 | data Loss 0.741981 |  physics Loss 0.868609 | Val Loss 0.760201
# Epoch 300 | Train Loss 0.674970 | data Loss 0.626981 |  physics Loss 0.786943 | Val Loss 0.700088
# Epoch 400 | Train Loss 0.621246 | data Loss 0.568472 |  physics Loss 0.744386 | Val Loss 0.667882
# Epoch 500 | Train Loss 0.584102 | data Loss 0.527709 |  physics Loss 0.715685 | Val Loss 0.647101
# Epoch 600 | Train Loss 0.557051 | data Loss 0.497611 |  physics Loss 0.695743 | Val Loss 0.630741
# Epoch 700 | Train Loss 0.535795 | data Loss 0.473756 |  physics Loss 0.680553 | Val Loss 0.615692
# Epoch 800 | Train Loss 0.518511 | data Loss 0.454241 |  physics Loss 0.668474 | Val Loss 0.602769
# Epoch 900 | Train Loss 0.504060 | data Loss 0.437861 |  physics Loss 0.658526 | Val Loss 0.591668
# Epoch 1000 | Train Loss 0.491721 | data Loss 0.423837 |  physics Loss 0.650115 | Val Loss 0.582035
# Epoch 1100 | Train Loss 0.481017 | data Loss 0.411652 |  physics Loss 0.642867 | Val Loss 0.573614
# Epoch 1200 | Train Loss 0.471636 | data Loss 0.400950 |  physics Loss 0.636571 | Val Loss 0.566844
# Epoch 1300 | Train Loss 0.463354 | data Loss 0.391481 |  physics Loss 0.631059 | Val Loss 0.561055
# Epoch 1400 | Train Loss 0.455993 | data Loss 0.383044 |  physics Loss 0.626208 | Val Loss 0.556389
# Epoch 1500 | Train Loss 0.449414 | data Loss 0.375499 |  physics Loss 0.621883 | Val Loss 0.551879
# Epoch 1600 | Train Loss 0.443527 | data Loss 0.368724 |  physics Loss 0.618065 | Val Loss 0.548915
# Epoch 1700 | Train Loss 0.438225 | data Loss 0.362620 |  physics Loss 0.614637 | Val Loss 0.546755
# Epoch 1800 | Train Loss 0.433417 | data Loss 0.357087 |  physics Loss 0.611520 | Val Loss 0.545447
# Epoch 1900 | Train Loss 0.429024 | data Loss 0.352041 |  physics Loss 0.608652 | Val Loss 0.544971
# Epoch 2000 | Train Loss 0.424983 | data Loss 0.347404 |  physics Loss 0.606002 | Val Loss 0.545401
# Early stopping at epoch 2027
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed5986.keras
# theta | ZZx1 -> R² = 0.7369, R² diff = 0.6452
# theta | ZZx2 -> R² = 0.0060, R² diff = 0.4429
# theta | ZZxReto -> R² = 0.7496, R² diff = 0.6639
# theta | ZZy1 -> R² = -13.8633, R² diff = 0.2611
# theta | ZZy2 -> R² = -19.0915, R² diff = 0.0369
# theta | LSG-1 -> R² = 0.5556, R² diff = 0.5613
# theta | LSG-2 -> R² = -2.9101, R² diff = 0.2908
# theta | ZZx1-inv -> R² = -1.5301, R² diff = 0.3956
# theta | zzx2-inv2 -> R² = -11.8829, R² diff = 0.0225
# theta | semiCirc -> R² = -24.4735, R² diff = -0.1019
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=5986 salvo.
# Epoch 0 | Train Loss 1.023038 | data Loss 1.001800 |  physics Loss 1.072594 | Val Loss 0.977114
# Epoch 100 | Train Loss 0.991260 | data Loss 0.967958 |  physics Loss 1.045630 | Val Loss 0.926068
# Epoch 200 | Train Loss 0.760906 | data Loss 0.720220 |  physics Loss 0.855839 | Val Loss 0.727945
# Epoch 300 | Train Loss 0.638864 | data Loss 0.585221 |  physics Loss 0.764033 | Val Loss 0.665047
# Epoch 400 | Train Loss 0.592523 | data Loss 0.534230 |  physics Loss 0.728538 | Val Loss 0.630248
# Epoch 500 | Train Loss 0.558493 | data Loss 0.497974 |  physics Loss 0.699705 | Val Loss 0.600790
# Epoch 600 | Train Loss 0.531370 | data Loss 0.468765 |  physics Loss 0.677448 | Val Loss 0.583688
# Epoch 700 | Train Loss 0.509777 | data Loss 0.445277 |  physics Loss 0.660275 | Val Loss 0.577308
# Epoch 800 | Train Loss 0.492146 | data Loss 0.426027 |  physics Loss 0.646423 | Val Loss 0.582067
# Early stopping at epoch 873
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed4210.keras
# theta | ZZx1 -> R² = 0.6949, R² diff = 0.5502
# theta | ZZx2 -> R² = 0.8734, R² diff = 0.4091
# theta | ZZxReto -> R² = 0.4891, R² diff = 0.5346
# theta | ZZy1 -> R² = -7.1429, R² diff = 0.2813
# theta | ZZy2 -> R² = -13.3496, R² diff = 0.1883
# theta | LSG-1 -> R² = -1.7453, R² diff = 0.4596
# theta | LSG-2 -> R² = -2.8232, R² diff = 0.2605
# theta | ZZx1-inv -> R² = -0.8119, R² diff = 0.3044
# theta | zzx2-inv2 -> R² = -4.9459, R² diff = 0.1768
# theta | semiCirc -> R² = -13.1125, R² diff = 0.0654
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=4210 salvo.
# Epoch 0 | Train Loss 1.023664 | data Loss 1.002467 |  physics Loss 1.073124 | Val Loss 0.978593
# Epoch 100 | Train Loss 0.996047 | data Loss 0.973242 |  physics Loss 1.049259 | Val Loss 0.939063
# Epoch 200 | Train Loss 0.791349 | data Loss 0.754314 |  physics Loss 0.877764 | Val Loss 0.769545
# Epoch 300 | Train Loss 0.681518 | data Loss 0.634367 |  physics Loss 0.791537 | Val Loss 0.704297
# Epoch 400 | Train Loss 0.625843 | data Loss 0.573610 |  physics Loss 0.747720 | Val Loss 0.675651
# Epoch 500 | Train Loss 0.590107 | data Loss 0.533956 |  physics Loss 0.721127 | Val Loss 0.657090
# Epoch 600 | Train Loss 0.563842 | data Loss 0.504541 |  physics Loss 0.702210 | Val Loss 0.639934
# Epoch 700 | Train Loss 0.543231 | data Loss 0.481351 |  physics Loss 0.687618 | Val Loss 0.623734
# Epoch 800 | Train Loss 0.526201 | data Loss 0.462241 |  physics Loss 0.675442 | Val Loss 0.607536
# Epoch 900 | Train Loss 0.510993 | data Loss 0.445446 |  physics Loss 0.663937 | Val Loss 0.589869
# Epoch 1000 | Train Loss 0.495812 | data Loss 0.429095 |  physics Loss 0.651484 | Val Loss 0.577869
# Epoch 1100 | Train Loss 0.478641 | data Loss 0.410968 |  physics Loss 0.636543 | Val Loss 0.598460
# Early stopping at epoch 1178
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed355.keras
# theta | ZZx1 -> R² = 0.6874, R² diff = 0.5685
# theta | ZZx2 -> R² = 0.8018, R² diff = 0.4082
# theta | ZZxReto -> R² = 0.5576, R² diff = 0.5526
# theta | ZZy1 -> R² = -6.5337, R² diff = 0.3014
# theta | ZZy2 -> R² = -17.2896, R² diff = 0.1423
# theta | LSG-1 -> R² = -1.7660, R² diff = 0.4673
# theta | LSG-2 -> R² = -2.8685, R² diff = 0.2465
# theta | ZZx1-inv -> R² = -1.6162, R² diff = 0.3028
# theta | zzx2-inv2 -> R² = -7.4505, R² diff = 0.1574
# theta | semiCirc -> R² = -13.2734, R² diff = 0.0668
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=355 salvo.
# Epoch 0 | Train Loss 1.023651 | data Loss 1.002454 |  physics Loss 1.073112 | Val Loss 0.978573
# Epoch 100 | Train Loss 1.021831 | data Loss 1.000529 |  physics Loss 1.071536 | Val Loss 0.975687
# Epoch 200 | Train Loss 0.960349 | data Loss 0.935192 |  physics Loss 1.019051 | Val Loss 0.924639
# Epoch 300 | Train Loss 0.841381 | data Loss 0.808298 |  physics Loss 0.918575 | Val Loss 0.843317
# Epoch 400 | Train Loss 0.724867 | data Loss 0.684564 |  physics Loss 0.818905 | Val Loss 0.769248
# Epoch 500 | Train Loss 0.637457 | data Loss 0.592716 |  physics Loss 0.741853 | Val Loss 0.760141
# Epoch 600 | Train Loss 0.567486 | data Loss 0.522286 |  physics Loss 0.672951 | Val Loss 0.800957
# Early stopping at epoch 647
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed7095.keras
# theta | ZZx1 -> R² = 0.3828, R² diff = 0.3649
# theta | ZZx2 -> R² = 0.5135, R² diff = 0.2275
# theta | ZZxReto -> R² = -1.0246, R² diff = 0.3325
# theta | ZZy1 -> R² = -0.4332, R² diff = 0.2194
# theta | ZZy2 -> R² = -11.3476, R² diff = 0.1374
# theta | LSG-1 -> R² = -8.3267, R² diff = 0.2187
# theta | LSG-2 -> R² = -1.0008, R² diff = 0.1527
# theta | ZZx1-inv -> R² = -0.8761, R² diff = 0.2109
# theta | zzx2-inv2 -> R² = -2.5059, R² diff = 0.1654
# theta | semiCirc -> R² = -1.7992, R² diff = 0.0690
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=7095 salvo.
# Epoch 0 | Train Loss 1.023667 | data Loss 1.002470 |  physics Loss 1.073127 | Val Loss 0.978584
# Epoch 100 | Train Loss 1.016508 | data Loss 0.994875 |  physics Loss 1.066984 | Val Loss 0.966794
# Epoch 200 | Train Loss 0.936462 | data Loss 0.909432 |  physics Loss 0.999534 | Val Loss 0.893325
# Epoch 300 | Train Loss 0.839621 | data Loss 0.804988 |  physics Loss 0.920430 | Val Loss 0.816044
# Epoch 400 | Train Loss 0.744745 | data Loss 0.702468 |  physics Loss 0.843390 | Val Loss 0.752390
# Epoch 500 | Train Loss 0.659653 | data Loss 0.609569 |  physics Loss 0.776515 | Val Loss 0.719552
# Epoch 600 | Train Loss 0.592047 | data Loss 0.536026 |  physics Loss 0.722765 | Val Loss 0.759119
# Early stopping at epoch 679
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed3174.keras
# theta | ZZx1 -> R² = 0.4407, R² diff = 0.3747
# theta | ZZx2 -> R² = 0.5454, R² diff = 0.2637
# theta | ZZxReto -> R² = -0.5959, R² diff = 0.3605
# theta | ZZy1 -> R² = -0.8542, R² diff = 0.2462
# theta | ZZy2 -> R² = -11.1042, R² diff = 0.1614
# theta | LSG-1 -> R² = -6.6846, R² diff = 0.2717
# theta | LSG-2 -> R² = -1.6158, R² diff = 0.1727
# theta | ZZx1-inv -> R² = -0.9607, R² diff = 0.1884
# theta | zzx2-inv2 -> R² = -2.8583, R² diff = 0.1681
# theta | semiCirc -> R² = -3.3033, R² diff = 0.1226
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=3174 salvo.
# Epoch 0 | Train Loss 1.023552 | data Loss 1.002349 |  physics Loss 1.073027 | Val Loss 0.978340
# Epoch 100 | Train Loss 0.987304 | data Loss 0.963975 |  physics Loss 1.041740 | Val Loss 0.930376
# Epoch 200 | Train Loss 0.783569 | data Loss 0.745891 |  physics Loss 0.871482 | Val Loss 0.764146
# Epoch 300 | Train Loss 0.678505 | data Loss 0.631079 |  physics Loss 0.789165 | Val Loss 0.702554
# Epoch 400 | Train Loss 0.624589 | data Loss 0.572045 |  physics Loss 0.747192 | Val Loss 0.674625
# Epoch 500 | Train Loss 0.588964 | data Loss 0.532644 |  physics Loss 0.720376 | Val Loss 0.657045
# Epoch 600 | Train Loss 0.561980 | data Loss 0.502755 |  physics Loss 0.700171 | Val Loss 0.640294
# Epoch 700 | Train Loss 0.540335 | data Loss 0.478679 |  physics Loss 0.684199 | Val Loss 0.623881
# Epoch 800 | Train Loss 0.522453 | data Loss 0.458658 |  physics Loss 0.671308 | Val Loss 0.609138
# Epoch 900 | Train Loss 0.507450 | data Loss 0.441752 |  physics Loss 0.660746 | Val Loss 0.596925
# Epoch 1000 | Train Loss 0.494690 | data Loss 0.427299 |  physics Loss 0.651936 | Val Loss 0.586637
# Epoch 1100 | Train Loss 0.483666 | data Loss 0.414766 |  physics Loss 0.644434 | Val Loss 0.577802
# Epoch 1200 | Train Loss 0.474026 | data Loss 0.403772 |  physics Loss 0.637951 | Val Loss 0.570182
# Epoch 1300 | Train Loss 0.465517 | data Loss 0.394042 |  physics Loss 0.632292 | Val Loss 0.563810
# Epoch 1400 | Train Loss 0.457956 | data Loss 0.385374 |  physics Loss 0.627314 | Val Loss 0.558303
# Epoch 1500 | Train Loss 0.451209 | data Loss 0.377618 |  physics Loss 0.622922 | Val Loss 0.553916
# Epoch 1600 | Train Loss 0.445174 | data Loss 0.370665 |  physics Loss 0.619029 | Val Loss 0.550273
# Epoch 1700 | Train Loss 0.439762 | data Loss 0.364419 |  physics Loss 0.615564 | Val Loss 0.547464
# Epoch 1800 | Train Loss 0.434890 | data Loss 0.358788 |  physics Loss 0.612463 | Val Loss 0.545530
# Epoch 1900 | Train Loss 0.430484 | data Loss 0.353710 |  physics Loss 0.609624 | Val Loss 0.543794
# Epoch 2000 | Train Loss 0.426450 | data Loss 0.349043 |  physics Loss 0.607067 | Val Loss 0.543609
# Early stopping at epoch 2088
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed5986.keras
# theta | ZZx1 -> R² = 0.7466, R² diff = 0.6466
# theta | ZZx2 -> R² = -0.1081, R² diff = 0.4440
# theta | ZZxReto -> R² = 0.7368, R² diff = 0.6675
# theta | ZZy1 -> R² = -15.2048, R² diff = 0.2487
# theta | ZZy2 -> R² = -18.5320, R² diff = 0.0496
# theta | LSG-1 -> R² = 0.5887, R² diff = 0.5632
# theta | LSG-2 -> R² = -2.8364, R² diff = 0.2949
# theta | ZZx1-inv -> R² = -1.4268, R² diff = 0.4022
# theta | zzx2-inv2 -> R² = -11.6691, R² diff = 0.0282
# theta | semiCirc -> R² = -25.2036, R² diff = -0.1156
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=5986 salvo.
