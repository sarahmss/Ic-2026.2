# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = [
    "ZZx1",  # Train
    "ZZx2",  # Val
    "ZZxReto", # Test
    "ZZy1", # Test
    "ZZy2", # Test
    "LSG-1", # Test
    "LSG-2", # Test
    "ZZx1-inv", # Test
    "zzx2-inv2", # Test
    "semiCirc", # Test
]

PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a"]   
TARGET_INT = ["theta"]  
TARGET = ["dtheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 6
TS = 0.07
PLOT = False

# %%
Datasets = []
for title in TITLES:
    df = pd.read_excel("./../../00-Data/SavgolDatasets.xlsx", sheet_name=title)
    Datasets.append(df)

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["Se_a"] = Dataset["e_a_d"] + Dataset["e_a_e"]
    Dataset["De_a"] = Dataset["e_a_d"] - Dataset["e_a_e"]

    Dataset = Dataset.dropna(subset=[f"d{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train = Train1

# Train2 = Datasets[1].copy()
# Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
# Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
# NormDatasets.append(Train2)

# # concatena
# Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(9):
    CurrentTestDataset = Datasets[i + 1].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = NormDatasets[1]

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1030, 6, 4)
# Dimensão da saida: (1030, 1)
# Dimensão da entrada: (1388, 6, 4)
# Dimensão da saida: (1388, 1)

# %%
phi_d_train =  Train["phi_d"].values[:len(x_train)]
phi_e_train =  Train["phi_e"].values[:len(x_train)]
theta_train = Train["theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(phi_d_train)}")
print(f"Dimensão da entrada fisica: {np.shape(phi_e_train)}")
# Out:
# Dimensão da entrada: (1030, 6, 4)
# Dimensão da saida: (1030, 1)
# Dimensão da entrada fisica : (1030,)
# Dimensão da entrada fisica: (1030,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):

    dtheta_cin = (R / (2 * L)) * (phi_d - phi_e)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(dq).T, np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, phi_d, phi_e, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(phi_d, phi_e, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss, data_loss, physics_loss

# %%
phi_d_train = tf.convert_to_tensor(phi_d_train, dtype=tf.float32)
phi_e_train = tf.convert_to_tensor(phi_e_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss, data_loss, physics_loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          phi_d_train, phi_e_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | data Loss {data_loss.numpy():.6f} |  physics Loss {physics_loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_mse = f"MSE_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_mse, []).append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {mse:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"MSE_{safe_title}_{name}"] = to_scalar(metrics[name][f"MSE_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    #os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    #weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    #model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}")

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import initializers
from itertools import product
import numpy as np
import tensorflow as tf

N_MODELS = 5

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[n] for n in range(1, 101)]


FirstLayers = [
    [2], [3], [4]
]
architectures = [
    [fl[0], sl]
    for fl in FirstLayers
    for sl in range(
        max(1, int(0.3 * fl[0])),
        int(0.7 * fl[0])
    )
]

# 🔹 retomar a partir do último modelo salvo
# last_saved = [27, 12]

# if last_saved in architectures:
#     idx = architectures.index(last_saved)
#     architectures = architectures[idx + 1:]  # começa DEPOIS do último salvo
#     print(f"Retomando a partir de {last_saved} (índice {idx}). Restam {len(architectures)} arquiteturas.")
# else:
#     print(f"⚠️ {last_saved} não encontrado na lista — rodando tudo do zero.")

architectures = [[3, 1, 1]]
print(len(architectures))
print(architectures)

Ld_Lp = [[0.5, 0.5], [0.3, 0.7], [0.7, 0.3]]

r_values = [0.01, 0.9]

results = {}

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados-2l.xlsx")
# Out:
# 1
# [[3, 1, 1]]
# Epoch 0 | Train Loss 1.040613 | data Loss 1.005111 |  physics Loss 1.076115 | Val Loss 0.980176
# Epoch 100 | Train Loss 0.998869 | data Loss 0.959377 |  physics Loss 1.038361 | Val Loss 0.924367
# Epoch 200 | Train Loss 0.766459 | data Loss 0.700896 |  physics Loss 0.832022 | Val Loss 0.771383
# Epoch 300 | Train Loss 0.697395 | data Loss 0.624311 |  physics Loss 0.770480 | Val Loss 0.736724
# Epoch 400 | Train Loss 0.651983 | data Loss 0.572243 |  physics Loss 0.731724 | Val Loss 0.722966
# Epoch 500 | Train Loss 0.614137 | data Loss 0.529724 |  physics Loss 0.698549 | Val Loss 0.713067
# Epoch 600 | Train Loss 0.576121 | data Loss 0.496358 |  physics Loss 0.655883 | Val Loss 0.705142
# Epoch 700 | Train Loss 0.539322 | data Loss 0.479455 |  physics Loss 0.599189 | Val Loss 0.726341
# Epoch 800 | Train Loss 0.510748 | data Loss 0.466384 |  physics Loss 0.555113 | Val Loss 0.789305
# Early stopping at epoch 806
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed6274.keras
# theta | ZZx1 -> R² = 0.5825, R² diff = 0.5079
# theta | ZZx2 -> R² = 0.5836, R² diff = 0.2836
# theta | ZZxReto -> R² = 0.0686, R² diff = 0.4471
# theta | ZZy1 -> R² = -4.6329, R² diff = 0.2811
# theta | ZZy2 -> R² = -16.3803, R² diff = 0.1595
# theta | LSG-1 -> R² = -4.1046, R² diff = 0.3621
# theta | LSG-2 -> R² = -2.0967, R² diff = 0.2049
# theta | ZZx1-inv -> R² = -1.9892, R² diff = 0.2168
# theta | zzx2-inv2 -> R² = -6.6864, R² diff = 0.1545
# theta | semiCirc -> R² = -6.9579, R² diff = 0.0958
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=6274 salvo.
# Epoch 0 | Train Loss 1.040616 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 1.021518 | data Loss 0.982746 |  physics Loss 1.060290 | Val Loss 0.953427
# Epoch 200 | Train Loss 0.811133 | data Loss 0.734020 |  physics Loss 0.888246 | Val Loss 0.783172
# Epoch 300 | Train Loss 0.729300 | data Loss 0.639301 |  physics Loss 0.819299 | Val Loss 0.728185
# Epoch 400 | Train Loss 0.678110 | data Loss 0.577417 |  physics Loss 0.778804 | Val Loss 0.701504
# Epoch 500 | Train Loss 0.643934 | data Loss 0.535635 |  physics Loss 0.752234 | Val Loss 0.689676
# Epoch 600 | Train Loss 0.618319 | data Loss 0.504553 |  physics Loss 0.732084 | Val Loss 0.675479
# Epoch 700 | Train Loss 0.596623 | data Loss 0.478196 |  physics Loss 0.715050 | Val Loss 0.658287
# Epoch 800 | Train Loss 0.576471 | data Loss 0.453451 |  physics Loss 0.699491 | Val Loss 0.637587
# Epoch 900 | Train Loss 0.555936 | data Loss 0.428652 |  physics Loss 0.683219 | Val Loss 0.623765
# Epoch 1000 | Train Loss 0.533606 | data Loss 0.403601 |  physics Loss 0.663611 | Val Loss 0.741861
# Epoch 1100 | Train Loss 0.515435 | data Loss 0.381949 |  physics Loss 0.648921 | Val Loss 0.797993
# Early stopping at epoch 1104
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed7805.keras
# theta | ZZx1 -> R² = 0.6336, R² diff = 0.5747
# theta | ZZx2 -> R² = 0.7862, R² diff = 0.3649
# theta | ZZxReto -> R² = 0.4472, R² diff = 0.5047
# theta | ZZy1 -> R² = -7.3027, R² diff = 0.2811
# theta | ZZy2 -> R² = -18.0943, R² diff = 0.1464
# theta | LSG-1 -> R² = -2.5601, R² diff = 0.4184
# theta | LSG-2 -> R² = -2.6103, R² diff = 0.2249
# theta | ZZx1-inv -> R² = -1.6512, R² diff = 0.3034
# theta | zzx2-inv2 -> R² = -8.4113, R² diff = 0.1553
# theta | semiCirc -> R² = -8.9181, R² diff = 0.0904
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=7805 salvo.
# Epoch 0 | Train Loss 1.040391 | data Loss 1.004842 |  physics Loss 1.075940 | Val Loss 0.979501
# Epoch 100 | Train Loss 0.951406 | data Loss 0.899593 |  physics Loss 1.003219 | Val Loss 0.873468
# Epoch 200 | Train Loss 0.788017 | data Loss 0.701367 |  physics Loss 0.874667 | Val Loss 0.761434
# Epoch 300 | Train Loss 0.721533 | data Loss 0.625355 |  physics Loss 0.817710 | Val Loss 0.720477
# Epoch 400 | Train Loss 0.675014 | data Loss 0.571686 |  physics Loss 0.778342 | Val Loss 0.696457
# Epoch 500 | Train Loss 0.639461 | data Loss 0.531077 |  physics Loss 0.747846 | Val Loss 0.676858
# Epoch 600 | Train Loss 0.606041 | data Loss 0.498578 |  physics Loss 0.713503 | Val Loss 0.658255
# Epoch 700 | Train Loss 0.565848 | data Loss 0.474172 |  physics Loss 0.657524 | Val Loss 0.651791
# Epoch 800 | Train Loss 0.525255 | data Loss 0.456101 |  physics Loss 0.594409 | Val Loss 0.651610
# Epoch 900 | Train Loss 0.497780 | data Loss 0.444491 |  physics Loss 0.551069 | Val Loss 0.643598
# Epoch 1000 | Train Loss 0.480669 | data Loss 0.433807 |  physics Loss 0.527530 | Val Loss 0.637192
# Epoch 1100 | Train Loss 0.467491 | data Loss 0.421910 |  physics Loss 0.513073 | Val Loss 0.631173
# Epoch 1200 | Train Loss 0.457581 | data Loss 0.411445 |  physics Loss 0.503717 | Val Loss 0.622238
# Epoch 1300 | Train Loss 0.447328 | data Loss 0.398980 |  physics Loss 0.495675 | Val Loss 0.618732
# Epoch 1400 | Train Loss 0.438988 | data Loss 0.388951 |  physics Loss 0.489025 | Val Loss 0.614232
# Epoch 1500 | Train Loss 0.431341 | data Loss 0.379844 |  physics Loss 0.482838 | Val Loss 0.611756
# Epoch 1600 | Train Loss 0.424216 | data Loss 0.371711 |  physics Loss 0.476721 | Val Loss 0.611936
# Epoch 1700 | Train Loss 0.417533 | data Loss 0.364357 |  physics Loss 0.470709 | Val Loss 0.617369
# Early stopping at epoch 1719
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed3109.keras
# theta | ZZx1 -> R² = 0.5285, R² diff = 0.6237
# theta | ZZx2 -> R² = 0.5020, R² diff = 0.3766
# theta | ZZxReto -> R² = 0.6492, R² diff = 0.5558
# theta | ZZy1 -> R² = -13.4843, R² diff = 0.2447
# theta | ZZy2 -> R² = -18.6308, R² diff = -0.0349
# theta | LSG-1 -> R² = -0.2777, R² diff = 0.4792
# theta | LSG-2 -> R² = -3.6327, R² diff = 0.2539
# theta | ZZx1-inv -> R² = -1.1007, R² diff = 0.2701
# theta | zzx2-inv2 -> R² = -10.2585, R² diff = -0.0150
# theta | semiCirc -> R² = -16.6474, R² diff = -0.0060
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=3109 salvo.
# Epoch 0 | Train Loss 1.040616 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 0.973706 | data Loss 0.927857 |  physics Loss 1.019555 | Val Loss 0.909795
# Epoch 200 | Train Loss 0.815923 | data Loss 0.743419 |  physics Loss 0.888428 | Val Loss 0.792700
# Epoch 300 | Train Loss 0.744268 | data Loss 0.660499 |  physics Loss 0.828036 | Val Loss 0.742954
# Epoch 400 | Train Loss 0.693852 | data Loss 0.601589 |  physics Loss 0.786116 | Val Loss 0.710818
# Epoch 500 | Train Loss 0.655577 | data Loss 0.556756 |  physics Loss 0.754398 | Val Loss 0.688013
# Epoch 600 | Train Loss 0.625592 | data Loss 0.520930 |  physics Loss 0.730255 | Val Loss 0.668560
# Epoch 700 | Train Loss 0.601157 | data Loss 0.491441 |  physics Loss 0.710873 | Val Loss 0.645747
# Epoch 800 | Train Loss 0.578090 | data Loss 0.464595 |  physics Loss 0.691586 | Val Loss 0.610425
# Epoch 900 | Train Loss 0.555439 | data Loss 0.438524 |  physics Loss 0.672355 | Val Loss 0.616423
# Epoch 1000 | Train Loss 0.539643 | data Loss 0.418705 |  physics Loss 0.660580 | Val Loss 0.639074
# Early stopping at epoch 1036
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed8496.keras
# theta | ZZx1 -> R² = 0.6377, R² diff = 0.5480
# theta | ZZx2 -> R² = 0.8002, R² diff = 0.3830
# theta | ZZxReto -> R² = 0.5263, R² diff = 0.4880
# theta | ZZy1 -> R² = -3.8368, R² diff = 0.3127
# theta | ZZy2 -> R² = -16.5656, R² diff = 0.1775
# theta | LSG-1 -> R² = -3.4947, R² diff = 0.3991
# theta | LSG-2 -> R² = -2.1959, R² diff = 0.2376
# theta | ZZx1-inv -> R² = -2.5217, R² diff = 0.2878
# theta | zzx2-inv2 -> R² = -7.1913, R² diff = 0.1862
# theta | semiCirc -> R² = -8.2608, R² diff = 0.1102
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=8496 salvo.
# Epoch 0 | Train Loss 1.040636 | data Loss 1.005137 |  physics Loss 1.076136 | Val Loss 0.980223
# Epoch 100 | Train Loss 0.969066 | data Loss 0.926592 |  physics Loss 1.011540 | Val Loss 0.898564
# Epoch 200 | Train Loss 0.771919 | data Loss 0.707097 |  physics Loss 0.836741 | Val Loss 0.774607
# Epoch 300 | Train Loss 0.704527 | data Loss 0.630814 |  physics Loss 0.778239 | Val Loss 0.736020
# Epoch 400 | Train Loss 0.657292 | data Loss 0.575254 |  physics Loss 0.739331 | Val Loss 0.708224
# Epoch 500 | Train Loss 0.620399 | data Loss 0.531440 |  physics Loss 0.709358 | Val Loss 0.684270
# Epoch 600 | Train Loss 0.588979 | data Loss 0.495020 |  physics Loss 0.682939 | Val Loss 0.663779
# Epoch 700 | Train Loss 0.561489 | data Loss 0.464275 |  physics Loss 0.658703 | Val Loss 0.648634
# Epoch 800 | Train Loss 0.535875 | data Loss 0.442462 |  physics Loss 0.629287 | Val Loss 0.641062
# Epoch 900 | Train Loss 0.505262 | data Loss 0.433198 |  physics Loss 0.577327 | Val Loss 0.643175
# Early stopping at epoch 995
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.5_Lp0.5_seed5727.keras
# theta | ZZx1 -> R² = 0.5317, R² diff = 0.5594
# theta | ZZx2 -> R² = -0.1728, R² diff = 0.3451
# theta | ZZxReto -> R² = 0.2572, R² diff = 0.4899
# theta | ZZy1 -> R² = -8.2823, R² diff = 0.2568
# theta | ZZy2 -> R² = -16.1390, R² diff = 0.1578
# theta | LSG-1 -> R² = -2.7310, R² diff = 0.4022
# theta | LSG-2 -> R² = -2.3641, R² diff = 0.2282
# theta | ZZx1-inv -> R² = -0.9217, R² diff = 0.3349
# theta | zzx2-inv2 -> R² = -6.7354, R² diff = 0.1697
# theta | semiCirc -> R² = -7.5519, R² diff = 0.0845
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.01 seed=5727 salvo.
# Epoch 0 | Train Loss 1.040607 | data Loss 1.005105 |  physics Loss 1.076110 | Val Loss 0.980157
# Epoch 100 | Train Loss 0.968775 | data Loss 0.926237 |  physics Loss 1.011314 | Val Loss 0.898705
# Epoch 200 | Train Loss 0.775040 | data Loss 0.710593 |  physics Loss 0.839488 | Val Loss 0.776027
# Epoch 300 | Train Loss 0.706879 | data Loss 0.633869 |  physics Loss 0.779889 | Val Loss 0.729412
# Epoch 400 | Train Loss 0.658643 | data Loss 0.577853 |  physics Loss 0.739433 | Val Loss 0.696726
# Epoch 500 | Train Loss 0.621945 | data Loss 0.533530 |  physics Loss 0.710360 | Val Loss 0.671782
# Epoch 600 | Train Loss 0.590672 | data Loss 0.495966 |  physics Loss 0.685378 | Val Loss 0.647027
# Epoch 700 | Train Loss 0.559415 | data Loss 0.458022 |  physics Loss 0.660808 | Val Loss 0.631606
# Epoch 800 | Train Loss 0.529605 | data Loss 0.424111 |  physics Loss 0.635100 | Val Loss 0.688617
# Early stopping at epoch 883
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed6274.keras
# theta | ZZx1 -> R² = 0.5530, R² diff = 0.5382
# theta | ZZx2 -> R² = 0.4777, R² diff = 0.3548
# theta | ZZxReto -> R² = 0.4041, R² diff = 0.4719
# theta | ZZy1 -> R² = -4.4857, R² diff = 0.2892
# theta | ZZy2 -> R² = -16.2682, R² diff = 0.1819
# theta | LSG-1 -> R² = -3.6242, R² diff = 0.3873
# theta | LSG-2 -> R² = -2.0491, R² diff = 0.2227
# theta | ZZx1-inv -> R² = -2.0245, R² diff = 0.3016
# theta | zzx2-inv2 -> R² = -6.7799, R² diff = 0.1909
# theta | semiCirc -> R² = -7.0879, R² diff = 0.1096
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=6274 salvo.
# Epoch 0 | Train Loss 1.040616 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 1.035982 | data Loss 1.000064 |  physics Loss 1.071900 | Val Loss 0.968885
# Epoch 200 | Train Loss 0.798003 | data Loss 0.737796 |  physics Loss 0.858211 | Val Loss 0.785549
# Epoch 300 | Train Loss 0.699898 | data Loss 0.624934 |  physics Loss 0.774861 | Val Loss 0.733165
# Epoch 400 | Train Loss 0.652225 | data Loss 0.570827 |  physics Loss 0.733622 | Val Loss 0.693940
# Epoch 500 | Train Loss 0.613965 | data Loss 0.528446 |  physics Loss 0.699483 | Val Loss 0.664821
# Epoch 600 | Train Loss 0.582464 | data Loss 0.493430 |  physics Loss 0.671498 | Val Loss 0.701865
# Early stopping at epoch 692
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed7805.keras
# theta | ZZx1 -> R² = 0.5386, R² diff = 0.4716
# theta | ZZx2 -> R² = 0.7104, R² diff = 0.3206
# theta | ZZxReto -> R² = -0.2554, R² diff = 0.4106
# theta | ZZy1 -> R² = -2.7442, R² diff = 0.2772
# theta | ZZy2 -> R² = -12.9390, R² diff = 0.1919
# theta | LSG-1 -> R² = -4.9719, R² diff = 0.3412
# theta | LSG-2 -> R² = -2.2855, R² diff = 0.2069
# theta | ZZx1-inv -> R² = -0.9833, R² diff = 0.2405
# theta | zzx2-inv2 -> R² = -3.7934, R² diff = 0.1864
# theta | semiCirc -> R² = -5.6818, R² diff = 0.1111
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=7805 salvo.
# Epoch 0 | Train Loss 1.040654 | data Loss 1.005155 |  physics Loss 1.076154 | Val Loss 0.980265
# Epoch 100 | Train Loss 0.992648 | data Loss 0.952603 |  physics Loss 1.032693 | Val Loss 0.915711
# Epoch 200 | Train Loss 0.765538 | data Loss 0.699919 |  physics Loss 0.831158 | Val Loss 0.771443
# Epoch 300 | Train Loss 0.696607 | data Loss 0.624291 |  physics Loss 0.768923 | Val Loss 0.730222
# Epoch 400 | Train Loss 0.650126 | data Loss 0.569884 |  physics Loss 0.730368 | Val Loss 0.703952
# Epoch 500 | Train Loss 0.612404 | data Loss 0.526131 |  physics Loss 0.698676 | Val Loss 0.680903
# Epoch 600 | Train Loss 0.578391 | data Loss 0.491885 |  physics Loss 0.664896 | Val Loss 0.665217
# Epoch 700 | Train Loss 0.544957 | data Loss 0.467376 |  physics Loss 0.622538 | Val Loss 0.655853
# Epoch 800 | Train Loss 0.513319 | data Loss 0.450665 |  physics Loss 0.575972 | Val Loss 0.652442
# Epoch 900 | Train Loss 0.487531 | data Loss 0.435402 |  physics Loss 0.539659 | Val Loss 0.707739
# Early stopping at epoch 970
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed3109.keras
# theta | ZZx1 -> R² = 0.5398, R² diff = 0.5470
# theta | ZZx2 -> R² = 0.4625, R² diff = 0.3361
# theta | ZZxReto -> R² = 0.4659, R² diff = 0.4688
# theta | ZZy1 -> R² = -6.5069, R² diff = 0.2689
# theta | ZZy2 -> R² = -16.6882, R² diff = 0.1332
# theta | LSG-1 -> R² = -2.8883, R² diff = 0.3834
# theta | LSG-2 -> R² = -2.3988, R² diff = 0.2211
# theta | ZZx1-inv -> R² = -1.3545, R² diff = 0.2848
# theta | zzx2-inv2 -> R² = -7.1735, R² diff = 0.1462
# theta | semiCirc -> R² = -7.2504, R² diff = 0.0963
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=3109 salvo.
# Epoch 0 | Train Loss 1.040616 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 1.040533 | data Loss 1.005031 |  physics Loss 1.076036 | Val Loss 0.979856
# Epoch 200 | Train Loss 0.839016 | data Loss 0.782546 |  physics Loss 0.895486 | Val Loss 0.817783
# Epoch 300 | Train Loss 0.734654 | data Loss 0.665098 |  physics Loss 0.804211 | Val Loss 0.753507
# Epoch 400 | Train Loss 0.676772 | data Loss 0.598320 |  physics Loss 0.755223 | Val Loss 0.725845
# Epoch 500 | Train Loss 0.633892 | data Loss 0.548579 |  physics Loss 0.719206 | Val Loss 0.698332
# Epoch 600 | Train Loss 0.598626 | data Loss 0.509402 |  physics Loss 0.687849 | Val Loss 0.690896
# Epoch 700 | Train Loss 0.568218 | data Loss 0.475726 |  physics Loss 0.660710 | Val Loss 0.755611
# Early stopping at epoch 759
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed8496.keras
# theta | ZZx1 -> R² = 0.4531, R² diff = 0.4784
# theta | ZZx2 -> R² = -0.3000, R² diff = 0.2981
# theta | ZZxReto -> R² = -0.3534, R² diff = 0.4194
# theta | ZZy1 -> R² = -3.9994, R² diff = 0.2605
# theta | ZZy2 -> R² = -13.3765, R² diff = 0.1922
# theta | LSG-1 -> R² = -4.5109, R² diff = 0.3362
# theta | LSG-2 -> R² = -1.8625, R² diff = 0.1982
# theta | ZZx1-inv -> R² = -0.6571, R² diff = 0.2902
# theta | zzx2-inv2 -> R² = -4.2243, R² diff = 0.1938
# theta | semiCirc -> R² = -4.9190, R² diff = 0.0938
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=8496 salvo.
# Epoch 0 | Train Loss 1.040428 | data Loss 1.004894 |  physics Loss 1.075962 | Val Loss 0.979674
# Epoch 100 | Train Loss 0.943383 | data Loss 0.892226 |  physics Loss 0.994539 | Val Loss 0.876758
# Epoch 200 | Train Loss 0.787855 | data Loss 0.708159 |  physics Loss 0.867550 | Val Loss 0.768546
# Epoch 300 | Train Loss 0.722811 | data Loss 0.632146 |  physics Loss 0.813476 | Val Loss 0.727125
# Epoch 400 | Train Loss 0.676727 | data Loss 0.577412 |  physics Loss 0.776041 | Val Loss 0.699451
# Epoch 500 | Train Loss 0.641972 | data Loss 0.535750 |  physics Loss 0.748194 | Val Loss 0.681674
# Epoch 600 | Train Loss 0.614715 | data Loss 0.502932 |  physics Loss 0.726498 | Val Loss 0.666868
# Epoch 700 | Train Loss 0.592385 | data Loss 0.475969 |  physics Loss 0.708801 | Val Loss 0.649669
# Epoch 800 | Train Loss 0.572801 | data Loss 0.452558 |  physics Loss 0.693044 | Val Loss 0.624603
# Epoch 900 | Train Loss 0.553262 | data Loss 0.430082 |  physics Loss 0.676442 | Val Loss 0.593048
# Epoch 1000 | Train Loss 0.533365 | data Loss 0.407863 |  physics Loss 0.658867 | Val Loss 0.594598
# Epoch 1100 | Train Loss 0.518450 | data Loss 0.389822 |  physics Loss 0.647078 | Val Loss 0.586979
# Epoch 1200 | Train Loss 0.503287 | data Loss 0.371560 |  physics Loss 0.635015 | Val Loss 0.555909
# Epoch 1300 | Train Loss 0.486199 | data Loss 0.351182 |  physics Loss 0.621217 | Val Loss 0.528752
# Epoch 1400 | Train Loss 0.469128 | data Loss 0.330941 |  physics Loss 0.607315 | Val Loss 0.529513
# Epoch 1500 | Train Loss 0.454880 | data Loss 0.314628 |  physics Loss 0.595131 | Val Loss 0.538960
# Early stopping at epoch 1540
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.5_Lp0.5_seed5727.keras
# theta | ZZx1 -> R² = 0.6133, R² diff = 0.6589
# theta | ZZx2 -> R² = 0.8203, R² diff = 0.4647
# theta | ZZxReto -> R² = 0.4170, R² diff = 0.5925
# theta | ZZy1 -> R² = -9.7935, R² diff = 0.3186
# theta | ZZy2 -> R² = -17.5055, R² diff = 0.1754
# theta | LSG-1 -> R² = -1.7507, R² diff = 0.4974
# theta | LSG-2 -> R² = -2.5966, R² diff = 0.2903
# theta | ZZx1-inv -> R² = -2.8483, R² diff = 0.4056
# theta | zzx2-inv2 -> R² = -10.2188, R² diff = 0.2014
# theta | semiCirc -> R² = -15.6526, R² diff = 0.0427
# Modelo [3, 1, 1] | Ld=0.5 Lp=0.5 r=0.9 seed=5727 salvo.
# Epoch 0 | Train Loss 1.054857 | data Loss 1.005162 |  physics Loss 1.076156 | Val Loss 0.980272
# Epoch 100 | Train Loss 1.020862 | data Loss 0.966608 |  physics Loss 1.044114 | Val Loss 0.934555
# Epoch 200 | Train Loss 0.817523 | data Loss 0.731289 |  physics Loss 0.854480 | Val Loss 0.788883
# Epoch 300 | Train Loss 0.748878 | data Loss 0.650374 |  physics Loss 0.791095 | Val Loss 0.742433
# Epoch 400 | Train Loss 0.697750 | data Loss 0.593836 |  physics Loss 0.742284 | Val Loss 0.706411
# Epoch 500 | Train Loss 0.640392 | data Loss 0.555904 |  physics Loss 0.676601 | Val Loss 0.746826
# Epoch 600 | Train Loss 0.577671 | data Loss 0.566794 |  physics Loss 0.582333 | Val Loss 0.852676
# Early stopping at epoch 624
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed6274.keras
# theta | ZZx1 -> R² = 0.4683, R² diff = 0.4210
# theta | ZZx2 -> R² = 0.5771, R² diff = 0.2896
# theta | ZZxReto -> R² = -0.4717, R² diff = 0.3692
# theta | ZZy1 -> R² = -1.4896, R² diff = 0.2547
# theta | ZZy2 -> R² = -11.6997, R² diff = 0.1890
# theta | LSG-1 -> R² = -6.2593, R² diff = 0.2987
# theta | LSG-2 -> R² = -1.3793, R² diff = 0.1960
# theta | ZZx1-inv -> R² = -0.9774, R² diff = 0.2213
# theta | zzx2-inv2 -> R² = -3.0374, R² diff = 0.1797
# theta | semiCirc -> R² = -4.2434, R² diff = 0.1101
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=6274 salvo.
# Epoch 0 | Train Loss 1.054816 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 1.029529 | data Loss 0.973322 |  physics Loss 1.053618 | Val Loss 0.944503
# Epoch 200 | Train Loss 0.839739 | data Loss 0.732810 |  physics Loss 0.885566 | Val Loss 0.783522
# Epoch 300 | Train Loss 0.764814 | data Loss 0.641542 |  physics Loss 0.817645 | Val Loss 0.730059
# Epoch 400 | Train Loss 0.717121 | data Loss 0.580910 |  physics Loss 0.775497 | Val Loss 0.702985
# Epoch 500 | Train Loss 0.685737 | data Loss 0.539769 |  physics Loss 0.748295 | Val Loss 0.691045
# Epoch 600 | Train Loss 0.662345 | data Loss 0.509013 |  physics Loss 0.728059 | Val Loss 0.676789
# Epoch 700 | Train Loss 0.641918 | data Loss 0.482091 |  physics Loss 0.710415 | Val Loss 0.659407
# Epoch 800 | Train Loss 0.622278 | data Loss 0.457798 |  physics Loss 0.692769 | Val Loss 0.648126
# Epoch 900 | Train Loss 0.600456 | data Loss 0.433960 |  physics Loss 0.671811 | Val Loss 0.724293
# Epoch 1000 | Train Loss 0.577639 | data Loss 0.408774 |  physics Loss 0.650009 | Val Loss 0.880453
# Early stopping at epoch 1002
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed7805.keras
# theta | ZZx1 -> R² = 0.5116, R² diff = 0.5453
# theta | ZZx2 -> R² = -0.2455, R² diff = 0.3383
# theta | ZZxReto -> R² = 0.1547, R² diff = 0.4788
# theta | ZZy1 -> R² = -5.8386, R² diff = 0.2775
# theta | ZZy2 -> R² = -15.6688, R² diff = 0.1781
# theta | LSG-1 -> R² = -3.6042, R² diff = 0.3936
# theta | LSG-2 -> R² = -2.2560, R² diff = 0.2263
# theta | ZZx1-inv -> R² = -1.0425, R² diff = 0.3220
# theta | zzx2-inv2 -> R² = -6.0405, R² diff = 0.1845
# theta | semiCirc -> R² = -7.1422, R² diff = 0.1062
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=7805 salvo.
# Epoch 0 | Train Loss 1.054651 | data Loss 1.004892 |  physics Loss 1.075976 | Val Loss 0.979616
# Epoch 100 | Train Loss 0.952782 | data Loss 0.877203 |  physics Loss 0.985173 | Val Loss 0.865310
# Epoch 200 | Train Loss 0.820088 | data Loss 0.707397 |  physics Loss 0.868384 | Val Loss 0.767253
# Epoch 300 | Train Loss 0.760191 | data Loss 0.633457 |  physics Loss 0.814506 | Val Loss 0.726128
# Epoch 400 | Train Loss 0.716923 | data Loss 0.579679 |  physics Loss 0.775743 | Val Loss 0.696919
# Epoch 500 | Train Loss 0.683217 | data Loss 0.538132 |  physics Loss 0.745396 | Val Loss 0.668812
# Epoch 600 | Train Loss 0.654364 | data Loss 0.503512 |  physics Loss 0.719014 | Val Loss 0.641085
# Epoch 700 | Train Loss 0.627508 | data Loss 0.472252 |  physics Loss 0.694046 | Val Loss 0.623588
# Epoch 800 | Train Loss 0.605731 | data Loss 0.446608 |  physics Loss 0.673927 | Val Loss 0.632822
# Epoch 900 | Train Loss 0.585506 | data Loss 0.423662 |  physics Loss 0.654868 | Val Loss 0.665312
# Early stopping at epoch 918
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed3109.keras
# theta | ZZx1 -> R² = 0.6232, R² diff = 0.5354
# theta | ZZx2 -> R² = 0.7716, R² diff = 0.3645
# theta | ZZxReto -> R² = 0.4719, R² diff = 0.4764
# theta | ZZy1 -> R² = -2.3918, R² diff = 0.3226
# theta | ZZy2 -> R² = -16.4280, R² diff = 0.1762
# theta | LSG-1 -> R² = -4.0957, R² diff = 0.3898
# theta | LSG-2 -> R² = -2.0502, R² diff = 0.2319
# theta | ZZx1-inv -> R² = -2.7064, R² diff = 0.2590
# theta | zzx2-inv2 -> R² = -6.6914, R² diff = 0.1833
# theta | semiCirc -> R² = -8.0231, R² diff = 0.1160
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=3109 salvo.
# Epoch 0 | Train Loss 1.054817 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 1.053681 | data Loss 1.003834 |  physics Loss 1.075044 | Val Loss 0.977525
# Epoch 200 | Train Loss 0.835760 | data Loss 0.753662 |  physics Loss 0.870945 | Val Loss 0.798322
# Epoch 300 | Train Loss 0.740500 | data Loss 0.645477 |  physics Loss 0.781225 | Val Loss 0.741597
# Epoch 400 | Train Loss 0.688631 | data Loss 0.588695 |  physics Loss 0.731461 | Val Loss 0.731907
# Epoch 500 | Train Loss 0.634134 | data Loss 0.554628 |  physics Loss 0.668208 | Val Loss 0.790157
# Epoch 600 | Train Loss 0.577124 | data Loss 0.542350 |  physics Loss 0.592027 | Val Loss 0.701588
# Epoch 700 | Train Loss 0.545517 | data Loss 0.531700 |  physics Loss 0.551439 | Val Loss 0.708242
# Epoch 800 | Train Loss 0.518324 | data Loss 0.522604 |  physics Loss 0.516490 | Val Loss 0.696665
# Epoch 900 | Train Loss 0.496611 | data Loss 0.509705 |  physics Loss 0.491000 | Val Loss 0.685238
# Epoch 1000 | Train Loss 0.479647 | data Loss 0.497231 |  physics Loss 0.472111 | Val Loss 0.678441
# Epoch 1100 | Train Loss 0.465089 | data Loss 0.485190 |  physics Loss 0.456473 | Val Loss 0.669458
# Epoch 1200 | Train Loss 0.452820 | data Loss 0.474789 |  physics Loss 0.443405 | Val Loss 0.661854
# Epoch 1300 | Train Loss 0.442275 | data Loss 0.465678 |  physics Loss 0.432246 | Val Loss 0.655690
# Epoch 1400 | Train Loss 0.432366 | data Loss 0.456407 |  physics Loss 0.422063 | Val Loss 0.650648
# Epoch 1500 | Train Loss 0.423693 | data Loss 0.448229 |  physics Loss 0.413177 | Val Loss 0.646944
# Epoch 1600 | Train Loss 0.415887 | data Loss 0.441284 |  physics Loss 0.405003 | Val Loss 0.642320
# Epoch 1700 | Train Loss 0.408772 | data Loss 0.434385 |  physics Loss 0.397795 | Val Loss 0.638529
# Epoch 1800 | Train Loss 0.402211 | data Loss 0.428979 |  physics Loss 0.390739 | Val Loss 0.635908
# Epoch 1900 | Train Loss 0.396189 | data Loss 0.423960 |  physics Loss 0.384287 | Val Loss 0.633573
# Epoch 2000 | Train Loss 0.390565 | data Loss 0.419457 |  physics Loss 0.378183 | Val Loss 0.631464
# Epoch 2100 | Train Loss 0.385349 | data Loss 0.415722 |  physics Loss 0.372332 | Val Loss 0.630437
# Epoch 2200 | Train Loss 0.380432 | data Loss 0.412575 |  physics Loss 0.366657 | Val Loss 0.630301
# Early stopping at epoch 2242
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed8496.keras
# theta | ZZx1 -> R² = 0.7890, R² diff = 0.5857
# theta | ZZx2 -> R² = 0.3910, R² diff = 0.3581
# theta | ZZxReto -> R² = 0.7840, R² diff = 0.5508
# theta | ZZy1 -> R² = -12.3128, R² diff = 0.2737
# theta | ZZy2 -> R² = -16.1880, R² diff = -0.0438
# theta | LSG-1 -> R² = 0.6575, R² diff = 0.4970
# theta | LSG-2 -> R² = -1.9427, R² diff = 0.2855
# theta | ZZx1-inv -> R² = -1.1897, R² diff = 0.2813
# theta | zzx2-inv2 -> R² = -12.4157, R² diff = -0.0944
# theta | semiCirc -> R² = -23.6061, R² diff = -0.1225
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=8496 salvo.
# Epoch 0 | Train Loss 1.054815 | data Loss 1.005111 |  physics Loss 1.076117 | Val Loss 0.980150
# Epoch 100 | Train Loss 1.040440 | data Loss 0.986976 |  physics Loss 1.063354 | Val Loss 0.948704
# Epoch 200 | Train Loss 0.841821 | data Loss 0.727177 |  physics Loss 0.890954 | Val Loss 0.746035
# Epoch 300 | Train Loss 0.739128 | data Loss 0.588688 |  physics Loss 0.803602 | Val Loss 0.684687
# Epoch 400 | Train Loss 0.695290 | data Loss 0.533289 |  physics Loss 0.764719 | Val Loss 0.665495
# Epoch 500 | Train Loss 0.660709 | data Loss 0.496364 |  physics Loss 0.731142 | Val Loss 0.653186
# Epoch 600 | Train Loss 0.633667 | data Loss 0.465820 |  physics Loss 0.705601 | Val Loss 0.644809
# Epoch 700 | Train Loss 0.607623 | data Loss 0.437114 |  physics Loss 0.680699 | Val Loss 0.615918
# Epoch 800 | Train Loss 0.584400 | data Loss 0.411691 |  physics Loss 0.658418 | Val Loss 0.603322
# Epoch 900 | Train Loss 0.566013 | data Loss 0.390251 |  physics Loss 0.641339 | Val Loss 0.603873
# Epoch 1000 | Train Loss 0.549465 | data Loss 0.372451 |  physics Loss 0.625329 | Val Loss 0.688227
# Early stopping at epoch 1057
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.3_Lp0.7_seed5727.keras
# theta | ZZx1 -> R² = 0.5972, R² diff = 0.6029
# theta | ZZx2 -> R² = 0.1996, R² diff = 0.3867
# theta | ZZxReto -> R² = 0.5459, R² diff = 0.5465
# theta | ZZy1 -> R² = -10.5075, R² diff = 0.2562
# theta | ZZy2 -> R² = -16.7000, R² diff = 0.1584
# theta | LSG-1 -> R² = -1.6387, R² diff = 0.4572
# theta | LSG-2 -> R² = -2.2270, R² diff = 0.2713
# theta | ZZx1-inv -> R² = -1.6446, R² diff = 0.3735
# theta | zzx2-inv2 -> R² = -7.9131, R² diff = 0.1634
# theta | semiCirc -> R² = -10.7677, R² diff = 0.0849
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.01 seed=5727 salvo.
# Epoch 0 | Train Loss 1.054809 | data Loss 1.005105 |  physics Loss 1.076111 | Val Loss 0.980162
# Epoch 100 | Train Loss 0.979190 | data Loss 0.918918 |  physics Loss 1.005021 | Val Loss 0.895657
# Epoch 200 | Train Loss 0.803753 | data Loss 0.714979 |  physics Loss 0.841799 | Val Loss 0.779429
# Epoch 300 | Train Loss 0.741528 | data Loss 0.640933 |  physics Loss 0.784640 | Val Loss 0.741104
# Epoch 400 | Train Loss 0.699246 | data Loss 0.587377 |  physics Loss 0.747190 | Val Loss 0.722520
# Epoch 500 | Train Loss 0.665050 | data Loss 0.544557 |  physics Loss 0.716689 | Val Loss 0.698180
# Epoch 600 | Train Loss 0.629351 | data Loss 0.513838 |  physics Loss 0.678857 | Val Loss 0.674648
# Epoch 700 | Train Loss 0.590315 | data Loss 0.497083 |  physics Loss 0.630272 | Val Loss 0.680502
# Early stopping at epoch 797
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed6274.keras
# theta | ZZx1 -> R² = 0.4695, R² diff = 0.4884
# theta | ZZx2 -> R² = -0.2381, R² diff = 0.3110
# theta | ZZxReto -> R² = -0.4636, R² diff = 0.4294
# theta | ZZy1 -> R² = -4.1533, R² diff = 0.2716
# theta | ZZy2 -> R² = -13.2335, R² diff = 0.2001
# theta | LSG-1 -> R² = -4.2501, R² diff = 0.3521
# theta | LSG-2 -> R² = -1.9954, R² diff = 0.2091
# theta | ZZx1-inv -> R² = -0.5520, R² diff = 0.2882
# theta | zzx2-inv2 -> R² = -4.1207, R² diff = 0.1953
# theta | semiCirc -> R² = -5.6226, R² diff = 0.0960
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=6274 salvo.
# Epoch 0 | Train Loss 1.054816 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 1.046319 | data Loss 0.994299 |  physics Loss 1.068614 | Val Loss 0.970992
# Epoch 200 | Train Loss 0.994687 | data Loss 0.930025 |  physics Loss 1.022400 | Val Loss 0.923090
# Epoch 300 | Train Loss 0.911402 | data Loss 0.827472 |  physics Loss 0.947372 | Val Loss 0.851700
# Epoch 400 | Train Loss 0.832405 | data Loss 0.725003 |  physics Loss 0.878434 | Val Loss 0.795480
# Epoch 500 | Train Loss 0.785183 | data Loss 0.657703 |  physics Loss 0.839818 | Val Loss 0.774795
# Epoch 600 | Train Loss 0.716395 | data Loss 0.581681 |  physics Loss 0.774130 | Val Loss 0.739488
# Epoch 700 | Train Loss 0.649834 | data Loss 0.492579 |  physics Loss 0.717229 | Val Loss 0.652827
# Epoch 800 | Train Loss 0.608223 | data Loss 0.440030 |  physics Loss 0.680306 | Val Loss 0.621139
# Epoch 900 | Train Loss 0.580983 | data Loss 0.403221 |  physics Loss 0.657167 | Val Loss 0.612700
# Epoch 1000 | Train Loss 0.560559 | data Loss 0.378912 |  physics Loss 0.638407 | Val Loss 0.602570
# Epoch 1100 | Train Loss 0.522535 | data Loss 0.361218 |  physics Loss 0.591670 | Val Loss 0.940826
# Epoch 1200 | Train Loss 0.461865 | data Loss 0.385491 |  physics Loss 0.494597 | Val Loss 1.204158
# Early stopping at epoch 1212
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed7805.keras
# theta | ZZx1 -> R² = 0.7743, R² diff = 0.6241
# theta | ZZx2 -> R² = 0.9046, R² diff = 0.3977
# theta | ZZxReto -> R² = 0.8366, R² diff = 0.5678
# theta | ZZy1 -> R² = -4.8751, R² diff = 0.3388
# theta | ZZy2 -> R² = -18.2422, R² diff = 0.1358
# theta | LSG-1 -> R² = -0.4178, R² diff = 0.4960
# theta | LSG-2 -> R² = -2.1583, R² diff = 0.2983
# theta | ZZx1-inv -> R² = -1.7174, R² diff = 0.3502
# theta | zzx2-inv2 -> R² = -10.2320, R² diff = 0.1379
# theta | semiCirc -> R² = -14.8904, R² diff = 0.0041
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=7805 salvo.
# Epoch 0 | Train Loss 1.054668 | data Loss 1.004921 |  physics Loss 1.075989 | Val Loss 0.979748
# Epoch 100 | Train Loss 0.993931 | data Loss 0.928986 |  physics Loss 1.021765 | Val Loss 0.906191
# Epoch 200 | Train Loss 0.817513 | data Loss 0.707684 |  physics Loss 0.864582 | Val Loss 0.765334
# Epoch 300 | Train Loss 0.753179 | data Loss 0.627264 |  physics Loss 0.807142 | Val Loss 0.724420
# Epoch 400 | Train Loss 0.710570 | data Loss 0.571856 |  physics Loss 0.770019 | Val Loss 0.707790
# Epoch 500 | Train Loss 0.680155 | data Loss 0.531632 |  physics Loss 0.743808 | Val Loss 0.691234
# Epoch 600 | Train Loss 0.656927 | data Loss 0.500864 |  physics Loss 0.723812 | Val Loss 0.664445
# Epoch 700 | Train Loss 0.632725 | data Loss 0.473176 |  physics Loss 0.701103 | Val Loss 0.618992
# Epoch 800 | Train Loss 0.601882 | data Loss 0.440323 |  physics Loss 0.671122 | Val Loss 0.608015
# Epoch 900 | Train Loss 0.582136 | data Loss 0.417411 |  physics Loss 0.652733 | Val Loss 0.618110
# Early stopping at epoch 931
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed3109.keras
# theta | ZZx1 -> R² = 0.6563, R² diff = 0.5408
# theta | ZZx2 -> R² = 0.8039, R² diff = 0.3817
# theta | ZZxReto -> R² = 0.5531, R² diff = 0.4823
# theta | ZZy1 -> R² = -2.2182, R² diff = 0.3242
# theta | ZZy2 -> R² = -15.2623, R² diff = 0.1994
# theta | LSG-1 -> R² = -3.6172, R² diff = 0.3976
# theta | LSG-2 -> R² = -1.8672, R² diff = 0.2449
# theta | ZZx1-inv -> R² = -2.2656, R² diff = 0.2927
# theta | zzx2-inv2 -> R² = -6.2013, R² diff = 0.2001
# theta | semiCirc -> R² = -8.3879, R² diff = 0.1092
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=3109 salvo.
# Epoch 0 | Train Loss 1.054816 | data Loss 1.005114 |  physics Loss 1.076117 | Val Loss 0.980185
# Epoch 100 | Train Loss 1.001234 | data Loss 0.938170 |  physics Loss 1.028262 | Val Loss 0.910754
# Epoch 200 | Train Loss 0.841815 | data Loss 0.734263 |  physics Loss 0.887910 | Val Loss 0.785398
# Epoch 300 | Train Loss 0.774546 | data Loss 0.652592 |  physics Loss 0.826812 | Val Loss 0.736623
# Epoch 400 | Train Loss 0.727303 | data Loss 0.594431 |  physics Loss 0.784248 | Val Loss 0.706474
# Epoch 500 | Train Loss 0.692525 | data Loss 0.551016 |  physics Loss 0.753171 | Val Loss 0.684999
# Epoch 600 | Train Loss 0.664932 | data Loss 0.517596 |  physics Loss 0.728076 | Val Loss 0.660313
# Epoch 700 | Train Loss 0.637317 | data Loss 0.485743 |  physics Loss 0.702278 | Val Loss 0.629912
# Epoch 800 | Train Loss 0.612720 | data Loss 0.456711 |  physics Loss 0.679581 | Val Loss 0.610606
# Epoch 900 | Train Loss 0.591403 | data Loss 0.430163 |  physics Loss 0.660505 | Val Loss 0.584953
# Epoch 1000 | Train Loss 0.572075 | data Loss 0.405839 |  physics Loss 0.643319 | Val Loss 0.564666
# Epoch 1100 | Train Loss 0.554322 | data Loss 0.383730 |  physics Loss 0.627433 | Val Loss 0.550297
# Epoch 1200 | Train Loss 0.538378 | data Loss 0.363749 |  physics Loss 0.613219 | Val Loss 0.543829
# Epoch 1300 | Train Loss 0.524698 | data Loss 0.346342 |  physics Loss 0.601136 | Val Loss 0.543646
# Epoch 1400 | Train Loss 0.512613 | data Loss 0.331398 |  physics Loss 0.590277 | Val Loss 0.543450
# Epoch 1500 | Train Loss 0.501979 | data Loss 0.319077 |  physics Loss 0.580365 | Val Loss 0.546733
# Early stopping at epoch 1568
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed8496.keras
# theta | ZZx1 -> R² = 0.5492, R² diff = 0.6656
# theta | ZZx2 -> R² = 0.1249, R² diff = 0.4488
# theta | ZZxReto -> R² = 0.0965, R² diff = 0.5833
# theta | ZZy1 -> R² = -9.0702, R² diff = 0.3084
# theta | ZZy2 -> R² = -12.9038, R² diff = 0.2405
# theta | LSG-1 -> R² = -1.9807, R² diff = 0.5078
# theta | LSG-2 -> R² = -2.1392, R² diff = 0.3182
# theta | ZZx1-inv -> R² = -1.2991, R² diff = 0.4573
# theta | zzx2-inv2 -> R² = -6.5845, R² diff = 0.2459
# theta | semiCirc -> R² = -17.0650, R² diff = 0.0230
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=8496 salvo.
# Epoch 0 | Train Loss 1.054546 | data Loss 1.004774 |  physics Loss 1.075877 | Val Loss 0.979296
# Epoch 100 | Train Loss 0.958738 | data Loss 0.884840 |  physics Loss 0.990409 | Val Loss 0.872878
# Epoch 200 | Train Loss 0.823487 | data Loss 0.713820 |  physics Loss 0.870488 | Val Loss 0.771540
# Epoch 300 | Train Loss 0.761065 | data Loss 0.637990 |  physics Loss 0.813811 | Val Loss 0.729051
# Epoch 400 | Train Loss 0.717208 | data Loss 0.583934 |  physics Loss 0.774325 | Val Loss 0.700520
# Epoch 500 | Train Loss 0.683856 | data Loss 0.542573 |  physics Loss 0.744406 | Val Loss 0.675390
# Epoch 600 | Train Loss 0.655895 | data Loss 0.508246 |  physics Loss 0.719173 | Val Loss 0.646237
# Epoch 700 | Train Loss 0.628615 | data Loss 0.476408 |  physics Loss 0.693847 | Val Loss 0.623774
# Epoch 800 | Train Loss 0.605612 | data Loss 0.449113 |  physics Loss 0.672683 | Val Loss 0.616022
# Epoch 900 | Train Loss 0.584773 | data Loss 0.425213 |  physics Loss 0.653157 | Val Loss 0.628650
# Early stopping at epoch 992
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.3_Lp0.7_seed5727.keras
# theta | ZZx1 -> R² = 0.6620, R² diff = 0.5512
# theta | ZZx2 -> R² = 0.7639, R² diff = 0.3730
# theta | ZZxReto -> R² = 0.5894, R² diff = 0.4912
# theta | ZZy1 -> R² = -2.0200, R² diff = 0.3413
# theta | ZZy2 -> R² = -16.5328, R² diff = 0.1745
# theta | LSG-1 -> R² = -3.4683, R² diff = 0.4008
# theta | LSG-2 -> R² = -2.2947, R² diff = 0.2392
# theta | ZZx1-inv -> R² = -2.5886, R² diff = 0.2837
# theta | zzx2-inv2 -> R² = -6.9859, R² diff = 0.1836
# theta | semiCirc -> R² = -8.5665, R² diff = 0.1103
# Modelo [3, 1, 1] | Ld=0.3 Lp=0.7 r=0.9 seed=5727 salvo.
# Epoch 0 | Train Loss 1.026402 | data Loss 1.005100 |  physics Loss 1.076106 | Val Loss 0.980144
# Epoch 100 | Train Loss 0.963792 | data Loss 0.939025 |  physics Loss 1.021580 | Val Loss 0.909273
# Epoch 200 | Train Loss 0.747119 | data Loss 0.707662 |  physics Loss 0.839186 | Val Loss 0.773628
# Epoch 300 | Train Loss 0.674052 | data Loss 0.629692 |  physics Loss 0.777557 | Val Loss 0.733111
# Epoch 400 | Train Loss 0.622261 | data Loss 0.572980 |  physics Loss 0.737249 | Val Loss 0.703399
# Epoch 500 | Train Loss 0.581866 | data Loss 0.528140 |  physics Loss 0.707228 | Val Loss 0.683846
# Epoch 600 | Train Loss 0.548778 | data Loss 0.491297 |  physics Loss 0.682902 | Val Loss 0.671612
# Epoch 700 | Train Loss 0.519495 | data Loss 0.459133 |  physics Loss 0.660338 | Val Loss 0.699823
# Epoch 800 | Train Loss 0.489139 | data Loss 0.426715 |  physics Loss 0.634794 | Val Loss 0.725645
# Early stopping at epoch 809
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed6274.keras
# theta | ZZx1 -> R² = 0.5135, R² diff = 0.5145
# theta | ZZx2 -> R² = -0.0101, R² diff = 0.3146
# theta | ZZxReto -> R² = -0.0612, R² diff = 0.4538
# theta | ZZy1 -> R² = -5.1796, R² diff = 0.2526
# theta | ZZy2 -> R² = -14.8142, R² diff = 0.1636
# theta | LSG-1 -> R² = -3.8334, R² diff = 0.3663
# theta | LSG-2 -> R² = -2.1429, R² diff = 0.2072
# theta | ZZx1-inv -> R² = -0.9682, R² diff = 0.2977
# theta | zzx2-inv2 -> R² = -5.2350, R² diff = 0.1832
# theta | semiCirc -> R² = -6.2449, R² diff = 0.0917
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=6274 salvo.
# Epoch 0 | Train Loss 1.026415 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 1.007594 | data Loss 0.985273 |  physics Loss 1.059677 | Val Loss 0.953556
# Epoch 200 | Train Loss 0.773504 | data Loss 0.736187 |  physics Loss 0.860576 | Val Loss 0.791445
# Epoch 300 | Train Loss 0.689334 | data Loss 0.646077 |  physics Loss 0.790265 | Val Loss 0.742764
# Epoch 400 | Train Loss 0.633280 | data Loss 0.585090 |  physics Loss 0.745723 | Val Loss 0.719106
# Epoch 500 | Train Loss 0.588540 | data Loss 0.536189 |  physics Loss 0.710692 | Val Loss 0.763044
# Early stopping at epoch 584
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed7805.keras
# theta | ZZx1 -> R² = 0.4197, R² diff = 0.4097
# theta | ZZx2 -> R² = 0.2858, R² diff = 0.2651
# theta | ZZxReto -> R² = -0.8349, R² diff = 0.3606
# theta | ZZy1 -> R² = -1.6309, R² diff = 0.2403
# theta | ZZy2 -> R² = -11.9375, R² diff = 0.1696
# theta | LSG-1 -> R² = -6.3374, R² diff = 0.2756
# theta | LSG-2 -> R² = -1.6335, R² diff = 0.1709
# theta | ZZx1-inv -> R² = -0.6646, R² diff = 0.2308
# theta | zzx2-inv2 -> R² = -3.1403, R² diff = 0.1743
# theta | semiCirc -> R² = -3.3502, R² diff = 0.0860
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=7805 salvo.
# Epoch 0 | Train Loss 1.026309 | data Loss 1.004994 |  physics Loss 1.076043 | Val Loss 0.979891
# Epoch 100 | Train Loss 0.971694 | data Loss 0.944877 |  physics Loss 1.034268 | Val Loss 0.915681
# Epoch 200 | Train Loss 0.750474 | data Loss 0.699144 |  physics Loss 0.870245 | Val Loss 0.760225
# Epoch 300 | Train Loss 0.673812 | data Loss 0.614321 |  physics Loss 0.812625 | Val Loss 0.717404
# Epoch 400 | Train Loss 0.624664 | data Loss 0.559155 |  physics Loss 0.777521 | Val Loss 0.702548
# Epoch 500 | Train Loss 0.589310 | data Loss 0.519872 |  physics Loss 0.751333 | Val Loss 0.688931
# Epoch 600 | Train Loss 0.560151 | data Loss 0.488271 |  physics Loss 0.727871 | Val Loss 0.666770
# Epoch 700 | Train Loss 0.535370 | data Loss 0.461206 |  physics Loss 0.708420 | Val Loss 0.651220
# Epoch 800 | Train Loss 0.513933 | data Loss 0.437989 |  physics Loss 0.691137 | Val Loss 0.643348
# Epoch 900 | Train Loss 0.494929 | data Loss 0.417419 |  physics Loss 0.675784 | Val Loss 0.640662
# Epoch 1000 | Train Loss 0.477568 | data Loss 0.398622 |  physics Loss 0.661776 | Val Loss 0.636231
# Epoch 1100 | Train Loss 0.461232 | data Loss 0.381084 |  physics Loss 0.648243 | Val Loss 0.626085
# Epoch 1200 | Train Loss 0.445645 | data Loss 0.364782 |  physics Loss 0.634325 | Val Loss 0.609623
# Epoch 1300 | Train Loss 0.429965 | data Loss 0.350157 |  physics Loss 0.616185 | Val Loss 0.587962
# Epoch 1400 | Train Loss 0.410108 | data Loss 0.335442 |  physics Loss 0.584329 | Val Loss 0.673222
# Epoch 1500 | Train Loss 0.394739 | data Loss 0.323791 |  physics Loss 0.560283 | Val Loss 1.019951
# Early stopping at epoch 1533
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed3109.keras
# theta | ZZx1 -> R² = 0.7434, R² diff = 0.6562
# theta | ZZx2 -> R² = 0.1547, R² diff = 0.4039
# theta | ZZxReto -> R² = 0.6074, R² diff = 0.6114
# theta | ZZy1 -> R² = -14.2026, R² diff = 0.2705
# theta | ZZy2 -> R² = -18.5130, R² diff = 0.1162
# theta | LSG-1 -> R² = -0.1322, R² diff = 0.5162
# theta | LSG-2 -> R² = -2.7302, R² diff = 0.2677
# theta | ZZx1-inv -> R² = -1.1833, R² diff = 0.3787
# theta | zzx2-inv2 -> R² = -10.3605, R² diff = 0.1152
# theta | semiCirc -> R² = -17.1277, R² diff = -0.0033
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=3109 salvo.
# Epoch 0 | Train Loss 1.026415 | data Loss 1.005114 |  physics Loss 1.076117 | Val Loss 0.980185
# Epoch 100 | Train Loss 0.945941 | data Loss 0.917619 |  physics Loss 1.012027 | Val Loss 0.903888
# Epoch 200 | Train Loss 0.788840 | data Loss 0.745005 |  physics Loss 0.891123 | Val Loss 0.794228
# Epoch 300 | Train Loss 0.713831 | data Loss 0.663014 |  physics Loss 0.832404 | Val Loss 0.745021
# Epoch 400 | Train Loss 0.659947 | data Loss 0.603712 |  physics Loss 0.791162 | Val Loss 0.714595
# Epoch 500 | Train Loss 0.618946 | data Loss 0.558233 |  physics Loss 0.760609 | Val Loss 0.694257
# Epoch 600 | Train Loss 0.586254 | data Loss 0.521895 |  physics Loss 0.736425 | Val Loss 0.674832
# Epoch 700 | Train Loss 0.558595 | data Loss 0.491066 |  physics Loss 0.716162 | Val Loss 0.648260
# Epoch 800 | Train Loss 0.531965 | data Loss 0.461651 |  physics Loss 0.696031 | Val Loss 0.612071
# Epoch 900 | Train Loss 0.508181 | data Loss 0.435022 |  physics Loss 0.678886 | Val Loss 0.617275
# Epoch 1000 | Train Loss 0.490181 | data Loss 0.414210 |  physics Loss 0.667448 | Val Loss 0.599751
# Epoch 1100 | Train Loss 0.473183 | data Loss 0.394384 |  physics Loss 0.657047 | Val Loss 0.572266
# Epoch 1200 | Train Loss 0.457070 | data Loss 0.375378 |  physics Loss 0.647683 | Val Loss 0.557189
# Epoch 1300 | Train Loss 0.442395 | data Loss 0.357909 |  physics Loss 0.639529 | Val Loss 0.561037
# Epoch 1400 | Train Loss 0.429416 | data Loss 0.342420 |  physics Loss 0.632405 | Val Loss 0.573571
# Early stopping at epoch 1455
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed8496.keras
# theta | ZZx1 -> R² = 0.7018, R² diff = 0.6362
# theta | ZZx2 -> R² = 0.9273, R² diff = 0.4361
# theta | ZZxReto -> R² = 0.5834, R² diff = 0.5672
# theta | ZZy1 -> R² = -10.0664, R² diff = 0.2995
# theta | ZZy2 -> R² = -20.4902, R² diff = 0.1202
# theta | LSG-1 -> R² = -1.5755, R² diff = 0.4802
# theta | LSG-2 -> R² = -2.7512, R² diff = 0.2541
# theta | ZZx1-inv -> R² = -3.1693, R² diff = 0.2886
# theta | zzx2-inv2 -> R² = -11.2748, R² diff = 0.1283
# theta | semiCirc -> R² = -14.7973, R² diff = 0.0451
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=8496 salvo.
# Epoch 0 | Train Loss 1.026465 | data Loss 1.005166 |  physics Loss 1.076161 | Val Loss 0.980291
# Epoch 100 | Train Loss 1.025473 | data Loss 1.004123 |  physics Loss 1.075289 | Val Loss 0.977969
# Epoch 200 | Train Loss 0.792600 | data Loss 0.757360 |  physics Loss 0.874826 | Val Loss 0.786666
# Epoch 300 | Train Loss 0.663634 | data Loss 0.616916 |  physics Loss 0.772641 | Val Loss 0.726649
# Epoch 400 | Train Loss 0.609600 | data Loss 0.560059 |  physics Loss 0.725197 | Val Loss 0.684218
# Epoch 500 | Train Loss 0.569949 | data Loss 0.516798 |  physics Loss 0.693969 | Val Loss 0.653670
# Epoch 600 | Train Loss 0.536175 | data Loss 0.480460 |  physics Loss 0.666177 | Val Loss 0.629821
# Epoch 700 | Train Loss 0.497471 | data Loss 0.441055 |  physics Loss 0.629108 | Val Loss 0.604626
# Epoch 800 | Train Loss 0.455974 | data Loss 0.403705 |  physics Loss 0.577933 | Val Loss 0.699246
# Epoch 900 | Train Loss 0.428072 | data Loss 0.374848 |  physics Loss 0.552261 | Val Loss 0.840458
# Early stopping at epoch 919
# Modelo salvo em:
# models/model_arch3-1-1_r0.01_Ld0.7_Lp0.3_seed5727.keras
# theta | ZZx1 -> R² = 0.6604, R² diff = 0.5697
# theta | ZZx2 -> R² = 0.8446, R² diff = 0.3899
# theta | ZZxReto -> R² = 0.4978, R² diff = 0.4972
# theta | ZZy1 -> R² = -5.4187, R² diff = 0.3068
# theta | ZZy2 -> R² = -16.4548, R² diff = 0.1845
# theta | LSG-1 -> R² = -2.9515, R² diff = 0.4141
# theta | LSG-2 -> R² = -2.1540, R² diff = 0.2426
# theta | ZZx1-inv -> R² = -1.9064, R² diff = 0.3191
# theta | zzx2-inv2 -> R² = -8.1224, R² diff = 0.2008
# theta | semiCirc -> R² = -9.7719, R² diff = 0.0881
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.01 seed=5727 salvo.
# Epoch 0 | Train Loss 1.026420 | data Loss 1.005119 |  physics Loss 1.076123 | Val Loss 0.980194
# Epoch 100 | Train Loss 1.015549 | data Loss 0.993158 |  physics Loss 1.067795 | Val Loss 0.970014
# Epoch 200 | Train Loss 0.952882 | data Loss 0.924504 |  physics Loss 1.019098 | Val Loss 0.919358
# Epoch 300 | Train Loss 0.854458 | data Loss 0.817778 |  physics Loss 0.940047 | Val Loss 0.847099
# Epoch 400 | Train Loss 0.740398 | data Loss 0.696863 |  physics Loss 0.841979 | Val Loss 0.769039
# Epoch 500 | Train Loss 0.639449 | data Loss 0.590253 |  physics Loss 0.754240 | Val Loss 0.704240
# Epoch 600 | Train Loss 0.565571 | data Loss 0.513576 |  physics Loss 0.686893 | Val Loss 0.659978
# Epoch 700 | Train Loss 0.516564 | data Loss 0.462279 |  physics Loss 0.643229 | Val Loss 0.638718
# Epoch 800 | Train Loss 0.481004 | data Loss 0.424374 |  physics Loss 0.613139 | Val Loss 0.625607
# Epoch 900 | Train Loss 0.450052 | data Loss 0.392248 |  physics Loss 0.584928 | Val Loss 0.648392
# Epoch 1000 | Train Loss 0.426448 | data Loss 0.368849 |  physics Loss 0.560844 | Val Loss 0.714428
# Early stopping at epoch 1013
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed6274.keras
# theta | ZZx1 -> R² = 0.5478, R² diff = 0.5825
# theta | ZZx2 -> R² = 0.7879, R² diff = 0.3622
# theta | ZZxReto -> R² = 0.6744, R² diff = 0.5076
# theta | ZZy1 -> R² = -4.6191, R² diff = 0.3156
# theta | ZZy2 -> R² = -18.4631, R² diff = 0.1346
# theta | LSG-1 -> R² = -2.4005, R² diff = 0.4424
# theta | LSG-2 -> R² = -2.6176, R² diff = 0.2552
# theta | ZZx1-inv -> R² = -2.1391, R² diff = 0.2766
# theta | zzx2-inv2 -> R² = -8.0840, R² diff = 0.1422
# theta | semiCirc -> R² = -10.5097, R² diff = 0.0945
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=6274 salvo.
# Epoch 0 | Train Loss 1.026415 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 0.999350 | data Loss 0.976562 |  physics Loss 1.052522 | Val Loss 0.945649
# Epoch 200 | Train Loss 0.776320 | data Loss 0.739180 |  physics Loss 0.862980 | Val Loss 0.794770
# Epoch 300 | Train Loss 0.695659 | data Loss 0.652684 |  physics Loss 0.795932 | Val Loss 0.745744
# Epoch 400 | Train Loss 0.639485 | data Loss 0.591444 |  physics Loss 0.751582 | Val Loss 0.711689
# Epoch 500 | Train Loss 0.595968 | data Loss 0.543280 |  physics Loss 0.718908 | Val Loss 0.679359
# Epoch 600 | Train Loss 0.556074 | data Loss 0.499905 |  physics Loss 0.687135 | Val Loss 0.648315
# Epoch 700 | Train Loss 0.521297 | data Loss 0.461354 |  physics Loss 0.661165 | Val Loss 0.697558
# Early stopping at epoch 790
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed7805.keras
# theta | ZZx1 -> R² = 0.5249, R² diff = 0.4989
# theta | ZZx2 -> R² = 0.6356, R² diff = 0.3381
# theta | ZZxReto -> R² = 0.0511, R² diff = 0.4378
# theta | ZZy1 -> R² = -4.0995, R² diff = 0.2769
# theta | ZZy2 -> R² = -15.4089, R² diff = 0.1761
# theta | LSG-1 -> R² = -4.2832, R² diff = 0.3477
# theta | LSG-2 -> R² = -2.0388, R² diff = 0.1978
# theta | ZZx1-inv -> R² = -1.6167, R² diff = 0.2716
# theta | zzx2-inv2 -> R² = -5.9125, R² diff = 0.1836
# theta | semiCirc -> R² = -5.5865, R² diff = 0.1022
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=7805 salvo.
# Epoch 0 | Train Loss 1.026445 | data Loss 1.005145 |  physics Loss 1.076144 | Val Loss 0.980248
# Epoch 100 | Train Loss 1.012096 | data Loss 0.989986 |  physics Loss 1.063686 | Val Loss 0.949655
# Epoch 200 | Train Loss 0.746857 | data Loss 0.707282 |  physics Loss 0.839199 | Val Loss 0.760766
# Epoch 300 | Train Loss 0.653001 | data Loss 0.604414 |  physics Loss 0.766372 | Val Loss 0.720166
# Epoch 400 | Train Loss 0.600257 | data Loss 0.549206 |  physics Loss 0.719376 | Val Loss 0.686065
# Epoch 500 | Train Loss 0.562427 | data Loss 0.507963 |  physics Loss 0.689509 | Val Loss 0.657388
# Epoch 600 | Train Loss 0.523090 | data Loss 0.476750 |  physics Loss 0.631218 | Val Loss 0.637463
# Epoch 700 | Train Loss 0.492457 | data Loss 0.449313 |  physics Loss 0.593125 | Val Loss 0.661099
# Early stopping at epoch 770
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed3109.keras
# theta | ZZx1 -> R² = 0.5613, R² diff = 0.5176
# theta | ZZx2 -> R² = 0.6202, R² diff = 0.3540
# theta | ZZxReto -> R² = 0.2610, R² diff = 0.4462
# theta | ZZy1 -> R² = -4.4027, R² diff = 0.2748
# theta | ZZy2 -> R² = -13.5162, R² diff = 0.2000
# theta | LSG-1 -> R² = -3.5226, R² diff = 0.3745
# theta | LSG-2 -> R² = -2.3268, R² diff = 0.2247
# theta | ZZx1-inv -> R² = -0.4931, R² diff = 0.2944
# theta | zzx2-inv2 -> R² = -4.6546, R² diff = 0.1933
# theta | semiCirc -> R² = -7.0375, R² diff = 0.0961
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=3109 salvo.
# Epoch 0 | Train Loss 1.026415 | data Loss 1.005114 |  physics Loss 1.076118 | Val Loss 0.980186
# Epoch 100 | Train Loss 1.026408 | data Loss 1.005111 |  physics Loss 1.076102 | Val Loss 0.980089
# Epoch 200 | Train Loss 0.845562 | data Loss 0.813510 |  physics Loss 0.920349 | Val Loss 0.835668
# Epoch 300 | Train Loss 0.715710 | data Loss 0.674072 |  physics Loss 0.812865 | Val Loss 0.757059
# Epoch 400 | Train Loss 0.649460 | data Loss 0.602135 |  physics Loss 0.759884 | Val Loss 0.725389
# Epoch 500 | Train Loss 0.601515 | data Loss 0.549099 |  physics Loss 0.723820 | Val Loss 0.697129
# Epoch 600 | Train Loss 0.563053 | data Loss 0.506962 |  physics Loss 0.693933 | Val Loss 0.670994
# Epoch 700 | Train Loss 0.530794 | data Loss 0.471881 |  physics Loss 0.668257 | Val Loss 0.652728
# Epoch 800 | Train Loss 0.504072 | data Loss 0.443046 |  physics Loss 0.646468 | Val Loss 0.640031
# Epoch 900 | Train Loss 0.481880 | data Loss 0.419662 |  physics Loss 0.627056 | Val Loss 0.646750
# Epoch 1000 | Train Loss 0.463401 | data Loss 0.400302 |  physics Loss 0.610634 | Val Loss 0.760009
# Early stopping at epoch 1055
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed8496.keras
# theta | ZZx1 -> R² = 0.5603, R² diff = 0.5728
# theta | ZZx2 -> R² = -0.3066, R² diff = 0.3508
# theta | ZZxReto -> R² = 0.3470, R² diff = 0.4976
# theta | ZZy1 -> R² = -9.2431, R² diff = 0.2479
# theta | ZZy2 -> R² = -16.5007, R² diff = 0.1464
# theta | LSG-1 -> R² = -2.3912, R² diff = 0.4155
# theta | LSG-2 -> R² = -2.7474, R² diff = 0.2240
# theta | ZZx1-inv -> R² = -0.8316, R² diff = 0.3344
# theta | zzx2-inv2 -> R² = -6.8184, R² diff = 0.1619
# theta | semiCirc -> R² = -8.4288, R² diff = 0.0839
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=8496 salvo.
# Epoch 0 | Train Loss 1.026287 | data Loss 1.004973 |  physics Loss 1.076020 | Val Loss 0.979883
# Epoch 100 | Train Loss 0.969424 | data Loss 0.942754 |  physics Loss 1.031652 | Val Loss 0.917944
# Epoch 200 | Train Loss 0.755126 | data Loss 0.705762 |  physics Loss 0.870308 | Val Loss 0.767599
# Epoch 300 | Train Loss 0.678265 | data Loss 0.621288 |  physics Loss 0.811212 | Val Loss 0.721153
# Epoch 400 | Train Loss 0.627276 | data Loss 0.563586 |  physics Loss 0.775887 | Val Loss 0.704161
# Epoch 500 | Train Loss 0.591789 | data Loss 0.523377 |  physics Loss 0.751417 | Val Loss 0.693570
# Epoch 600 | Train Loss 0.564381 | data Loss 0.493080 |  physics Loss 0.730751 | Val Loss 0.674001
# Epoch 700 | Train Loss 0.539343 | data Loss 0.465871 |  physics Loss 0.710779 | Val Loss 0.656703
# Epoch 800 | Train Loss 0.518067 | data Loss 0.442089 |  physics Loss 0.695348 | Val Loss 0.643294
# Epoch 900 | Train Loss 0.498496 | data Loss 0.420499 |  physics Loss 0.680490 | Val Loss 0.629397
# Epoch 1000 | Train Loss 0.479679 | data Loss 0.400357 |  physics Loss 0.664763 | Val Loss 0.619922
# Epoch 1100 | Train Loss 0.461050 | data Loss 0.381600 |  physics Loss 0.646435 | Val Loss 0.600441
# Epoch 1200 | Train Loss 0.443588 | data Loss 0.364488 |  physics Loss 0.628155 | Val Loss 0.612820
# Epoch 1300 | Train Loss 0.429292 | data Loss 0.350426 |  physics Loss 0.613315 | Val Loss 0.648793
# Early stopping at epoch 1338
# Modelo salvo em:
# models/model_arch3-1-1_r0.9_Ld0.7_Lp0.3_seed5727.keras
# theta | ZZx1 -> R² = 0.7362, R² diff = 0.6262
# theta | ZZx2 -> R² = 0.3610, R² diff = 0.3905
# theta | ZZxReto -> R² = 0.5521, R² diff = 0.5730
# theta | ZZy1 -> R² = -11.4273, R² diff = 0.2769
# theta | ZZy2 -> R² = -17.2517, R² diff = 0.1573
# theta | LSG-1 -> R² = -0.7050, R² diff = 0.4833
# theta | LSG-2 -> R² = -2.6659, R² diff = 0.2590
# theta | ZZx1-inv -> R² = -1.0107, R² diff = 0.3724
# theta | zzx2-inv2 -> R² = -8.8756, R² diff = 0.1488
# theta | semiCirc -> R² = -13.6566, R² diff = 0.0463
# Modelo [3, 1, 1] | Ld=0.7 Lp=0.3 r=0.9 seed=5727 salvo.
