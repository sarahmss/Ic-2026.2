# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = [
    "ZZx1",  # Train
    "ZZx2",  # Val
    "ZZxReto", # Test
    "ZZy1", # Test
    "ZZy2", # Test
    "LSG-1", # Test
    "LSG-2", # Test
    "ZZx1-inv", # Test
    "zzx2-inv2", # Test
    "semiCirc", # Test
]

PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a"]   
TARGET_INT = ["theta"]  
TARGET = ["dtheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 12
TS = 0.07
PLOT = False
# Out:
# /Users/cyberxoke/Documents/Sarah/Ic-2026.2/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
Datasets = []
for title in TITLES:
    df = pd.read_excel("./../../00-Data/SavgolDatasets.xlsx", sheet_name=title)
    Datasets.append(df)

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["Se_a"] = Dataset["e_a_d"] + Dataset["e_a_e"]
    Dataset["De_a"] = Dataset["e_a_d"] - Dataset["e_a_e"]

    Dataset = Dataset.dropna(subset=[f"d{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train = Train1

# Train2 = Datasets[1].copy()
# Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
# Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
# NormDatasets.append(Train2)

# # concatena
# Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(9):
    CurrentTestDataset = Datasets[i + 1].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = NormDatasets[1]

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1024, 12, 4)
# Dimensão da saida: (1024, 1)
# Dimensão da entrada: (1382, 12, 4)
# Dimensão da saida: (1382, 1)

# %%
phi_d_train =  Train["phi_d"].values[:len(x_train)]
phi_e_train =  Train["phi_e"].values[:len(x_train)]
theta_train = Train["theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(phi_d_train)}")
print(f"Dimensão da entrada fisica: {np.shape(phi_e_train)}")
# Out:
# Dimensão da entrada: (1024, 12, 4)
# Dimensão da saida: (1024, 1)
# Dimensão da entrada fisica : (1024,)
# Dimensão da entrada fisica: (1024,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):

    dtheta_cin = (R / (2 * L)) * (phi_d - phi_e)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(dq).T, np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, phi_d, phi_e, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(phi_d, phi_e, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss, data_loss, physics_loss

# %%
phi_d_train = tf.convert_to_tensor(phi_d_train, dtype=tf.float32)
phi_e_train = tf.convert_to_tensor(phi_e_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss, data_loss, physics_loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          phi_d_train, phi_e_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | data Loss {data_loss.numpy():.6f} |  physics Loss {physics_loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            R2diff = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_r2diff = f"R2diff_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_r2diff, []).append(R2diff)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {R2diff:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"R2diff_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2diff_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    #os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    #weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    #model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}")

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import initializers
from itertools import product
import numpy as np
import tensorflow as tf

N_MODELS = 5

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

#architectures = [[n] for n in range(1, 101)]

FirstLayers = [
     [94, 31],
[94, 41],
[94, 52],
]

architectures = [
    [fl, sl, tl]
    for fl, sl in FirstLayers
    for tl in range(
         max(1, int(0.3 * sl)),
         int(0.7 * sl)
     )
 ]



print(len(architectures))
print(architectures)

Ld_Lp = [[0.5, 0.5], [0.3, 0.7], [0.7, 0.3]]
r_values = [0.01, 0.9]

results = {}

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados-3l.xlsx")
# Out:
# 49
# [[94, 31, 9], [94, 31, 10], [94, 31, 11], [94, 31, 12], [94, 31, 13], [94, 31, 14], [94, 31, 15], [94, 31, 16], [94, 31, 17], [94, 31, 18], [94, 31, 19], [94, 31, 20], [94, 41, 12], [94, 41, 13], [94, 41, 14], [94, 41, 15], [94, 41, 16], [94, 41, 17], [94, 41, 18], [94, 41, 19], [94, 41, 20], [94, 41, 21], [94, 41, 22], [94, 41, 23], [94, 41, 24], [94, 41, 25], [94, 41, 26], [94, 41, 27], [94, 52, 15], [94, 52, 16], [94, 52, 17], [94, 52, 18], [94, 52, 19], [94, 52, 20], [94, 52, 21], [94, 52, 22], [94, 52, 23], [94, 52, 24], [94, 52, 25], [94, 52, 26], [94, 52, 27], [94, 52, 28], [94, 52, 29], [94, 52, 30], [94, 52, 31], [94, 52, 32], [94, 52, 33], [94, 52, 34], [94, 52, 35]]
# Epoch 0 | Train Loss 1.041588 | data Loss 1.006108 |  physics Loss 1.077069 | Val Loss 0.935951
# Epoch 100 | Train Loss 0.573834 | data Loss 0.509869 |  physics Loss 0.637800 | Val Loss 0.651110
# Epoch 200 | Train Loss 0.494764 | data Loss 0.420603 |  physics Loss 0.568925 | Val Loss 0.664505
# Epoch 300 | Train Loss 0.467055 | data Loss 0.390623 |  physics Loss 0.543488 | Val Loss 0.709916
# Epoch 400 | Train Loss 0.423505 | data Loss 0.390622 |  physics Loss 0.456388 | Val Loss 0.648100
# Epoch 500 | Train Loss 0.424402 | data Loss 0.406241 |  physics Loss 0.442563 | Val Loss 0.652466
# Epoch 600 | Train Loss 0.394568 | data Loss 0.383341 |  physics Loss 0.405794 | Val Loss 0.669206
# Early stopping at epoch 670
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.5_Lp0.5_seed7872.keras
# theta | ZZx1 -> R² = 0.8408, R² diff = 0.5759
# theta | ZZx2 -> R² = 0.6643, R² diff = 0.4163
# theta | ZZxReto -> R² = 0.9162, R² diff = 0.5733
# theta | ZZy1 -> R² = -13.7826, R² diff = 0.2535
# theta | ZZy2 -> R² = -8.2626, R² diff = 0.0242
# theta | LSG-1 -> R² = 0.7209, R² diff = 0.5906
# theta | LSG-2 -> R² = -1.1771, R² diff = 0.3911
# theta | ZZx1-inv -> R² = -0.1962, R² diff = 0.3464
# theta | zzx2-inv2 -> R² = -8.0992, R² diff = 0.1300
# theta | semiCirc -> R² = -36.4947, R² diff = -0.3227
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.01 seed=7872 salvo.
# Epoch 0 | Train Loss 1.066701 | data Loss 1.036082 |  physics Loss 1.097320 | Val Loss 0.985821
# Epoch 100 | Train Loss 0.530056 | data Loss 0.484095 |  physics Loss 0.576017 | Val Loss 0.626491
# Epoch 200 | Train Loss 0.422703 | data Loss 0.387711 |  physics Loss 0.457694 | Val Loss 0.604957
# Epoch 300 | Train Loss 0.383320 | data Loss 0.369485 |  physics Loss 0.397155 | Val Loss 0.674686
# Early stopping at epoch 375
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.5_Lp0.5_seed2586.keras
# theta | ZZx1 -> R² = 0.7646, R² diff = 0.6015
# theta | ZZx2 -> R² = 0.9713, R² diff = 0.4003
# theta | ZZxReto -> R² = 0.9000, R² diff = 0.5148
# theta | ZZy1 -> R² = -13.6290, R² diff = 0.2898
# theta | ZZy2 -> R² = -12.0737, R² diff = 0.0300
# theta | LSG-1 -> R² = 0.8856, R² diff = 0.5671
# theta | LSG-2 -> R² = -2.1644, R² diff = 0.3033
# theta | ZZx1-inv -> R² = -0.2475, R² diff = 0.3400
# theta | zzx2-inv2 -> R² = -11.9679, R² diff = 0.0478
# theta | semiCirc -> R² = -27.2511, R² diff = -0.1581
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.01 seed=2586 salvo.
# Epoch 0 | Train Loss 1.038168 | data Loss 1.002296 |  physics Loss 1.074041 | Val Loss 0.952245
# Epoch 100 | Train Loss 0.555692 | data Loss 0.499909 |  physics Loss 0.611475 | Val Loss 0.627238
# Epoch 200 | Train Loss 0.455618 | data Loss 0.401055 |  physics Loss 0.510181 | Val Loss 0.625886
# Epoch 300 | Train Loss 0.394456 | data Loss 0.360173 |  physics Loss 0.428739 | Val Loss 0.681585
# Early stopping at epoch 375
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.5_Lp0.5_seed7869.keras
# theta | ZZx1 -> R² = 0.5627, R² diff = 0.5964
# theta | ZZx2 -> R² = 0.7197, R² diff = 0.3999
# theta | ZZxReto -> R² = -0.0161, R² diff = 0.5344
# theta | ZZy1 -> R² = -15.0361, R² diff = 0.2538
# theta | ZZy2 -> R² = -22.0021, R² diff = -0.0865
# theta | LSG-1 -> R² = -0.7320, R² diff = 0.4648
# theta | LSG-2 -> R² = -3.6440, R² diff = 0.2251
# theta | ZZx1-inv -> R² = -3.2156, R² diff = 0.2021
# theta | zzx2-inv2 -> R² = -19.5976, R² diff = 0.0113
# theta | semiCirc -> R² = -19.1098, R² diff = -0.1023
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.01 seed=7869 salvo.
# Epoch 0 | Train Loss 1.053966 | data Loss 1.021104 |  physics Loss 1.086827 | Val Loss 0.968210
# Epoch 100 | Train Loss 0.586481 | data Loss 0.532633 |  physics Loss 0.640329 | Val Loss 0.678700
# Epoch 200 | Train Loss 0.501316 | data Loss 0.433222 |  physics Loss 0.569409 | Val Loss 0.642744
# Epoch 300 | Train Loss 0.471458 | data Loss 0.410229 |  physics Loss 0.532686 | Val Loss 0.636134
# Epoch 400 | Train Loss 0.453659 | data Loss 0.402869 |  physics Loss 0.504449 | Val Loss 0.622178
# Epoch 500 | Train Loss 0.432713 | data Loss 0.391816 |  physics Loss 0.473610 | Val Loss 0.616924
# Epoch 600 | Train Loss 0.402635 | data Loss 0.383376 |  physics Loss 0.421895 | Val Loss 0.722256
# Early stopping at epoch 660
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.5_Lp0.5_seed7621.keras
# theta | ZZx1 -> R² = 0.8468, R² diff = 0.6148
# theta | ZZx2 -> R² = 0.8547, R² diff = 0.3958
# theta | ZZxReto -> R² = 0.7320, R² diff = 0.5417
# theta | ZZy1 -> R² = -24.3664, R² diff = 0.1353
# theta | ZZy2 -> R² = -9.5317, R² diff = 0.0594
# theta | LSG-1 -> R² = 0.7388, R² diff = 0.5871
# theta | LSG-2 -> R² = -0.8295, R² diff = 0.3794
# theta | ZZx1-inv -> R² = -0.5696, R² diff = 0.2769
# theta | zzx2-inv2 -> R² = -8.9230, R² diff = 0.0889
# theta | semiCirc -> R² = -38.9104, R² diff = -0.4138
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.01 seed=7621 salvo.
# Epoch 0 | Train Loss 1.041991 | data Loss 1.007502 |  physics Loss 1.076480 | Val Loss 0.955488
# Epoch 100 | Train Loss 0.558919 | data Loss 0.538009 |  physics Loss 0.579829 | Val Loss 0.650036
# Epoch 200 | Train Loss 0.449541 | data Loss 0.413858 |  physics Loss 0.485225 | Val Loss 0.751327
# Epoch 300 | Train Loss 0.388766 | data Loss 0.379567 |  physics Loss 0.397965 | Val Loss 0.747252
# Early stopping at epoch 315
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.5_Lp0.5_seed8488.keras
# theta | ZZx1 -> R² = 0.6338, R² diff = 0.4873
# theta | ZZx2 -> R² = 0.9520, R² diff = 0.3439
# theta | ZZxReto -> R² = 0.6446, R² diff = 0.4437
# theta | ZZy1 -> R² = -10.4235, R² diff = 0.2292
# theta | ZZy2 -> R² = -14.5938, R² diff = -0.0023
# theta | LSG-1 -> R² = -0.0048, R² diff = 0.4411
# theta | LSG-2 -> R² = -1.7054, R² diff = 0.2711
# theta | ZZx1-inv -> R² = -0.7651, R² diff = 0.2367
# theta | zzx2-inv2 -> R² = -8.6150, R² diff = 0.0389
# theta | semiCirc -> R² = -15.0178, R² diff = 0.0143
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.01 seed=8488 salvo.
# Epoch 0 | Train Loss 1.049318 | data Loss 1.013430 |  physics Loss 1.085207 | Val Loss 0.954585
# Epoch 100 | Train Loss 0.576444 | data Loss 0.508032 |  physics Loss 0.644857 | Val Loss 0.629395
# Epoch 200 | Train Loss 0.497920 | data Loss 0.438620 |  physics Loss 0.557220 | Val Loss 0.602418
# Epoch 300 | Train Loss 0.481984 | data Loss 0.371733 |  physics Loss 0.592235 | Val Loss 0.592057
# Epoch 400 | Train Loss 0.436001 | data Loss 0.390999 |  physics Loss 0.481003 | Val Loss 0.615309
# Epoch 500 | Train Loss 0.413556 | data Loss 0.377014 |  physics Loss 0.450098 | Val Loss 0.586361
# Epoch 600 | Train Loss 0.425968 | data Loss 0.386468 |  physics Loss 0.465468 | Val Loss 0.575086
# Early stopping at epoch 687
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.5_Lp0.5_seed7872.keras
# theta | ZZx1 -> R² = 0.1438, R² diff = 0.6212
# theta | ZZx2 -> R² = 0.8296, R² diff = 0.4482
# theta | ZZxReto -> R² = 0.4256, R² diff = 0.5199
# theta | ZZy1 -> R² = -8.2046, R² diff = 0.2304
# theta | ZZy2 -> R² = -8.5701, R² diff = 0.0782
# theta | LSG-1 -> R² = 0.6711, R² diff = 0.5503
# theta | LSG-2 -> R² = -0.5679, R² diff = 0.3710
# theta | ZZx1-inv -> R² = -0.5359, R² diff = 0.3780
# theta | zzx2-inv2 -> R² = -11.1632, R² diff = 0.0894
# theta | semiCirc -> R² = -29.5985, R² diff = -0.1934
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.9 seed=7872 salvo.
# Epoch 0 | Train Loss 1.046065 | data Loss 1.011441 |  physics Loss 1.080690 | Val Loss 0.928794
# Epoch 100 | Train Loss 0.552332 | data Loss 0.519288 |  physics Loss 0.585375 | Val Loss 0.638486
# Epoch 200 | Train Loss 0.446384 | data Loss 0.440946 |  physics Loss 0.451821 | Val Loss 0.673445
# Epoch 300 | Train Loss 0.402998 | data Loss 0.407477 |  physics Loss 0.398519 | Val Loss 0.678679
# Epoch 400 | Train Loss 0.424270 | data Loss 0.406719 |  physics Loss 0.441820 | Val Loss 0.924036
# Early stopping at epoch 422
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.5_Lp0.5_seed2586.keras
# theta | ZZx1 -> R² = 0.2595, R² diff = 0.5672
# theta | ZZx2 -> R² = 0.9192, R² diff = 0.3675
# theta | ZZxReto -> R² = -0.5312, R² diff = 0.4513
# theta | ZZy1 -> R² = -33.3302, R² diff = 0.0216
# theta | ZZy2 -> R² = -14.5547, R² diff = -0.1376
# theta | LSG-1 -> R² = 0.8838, R² diff = 0.5444
# theta | LSG-2 -> R² = -1.9632, R² diff = 0.3203
# theta | ZZx1-inv -> R² = -1.9040, R² diff = 0.2793
# theta | zzx2-inv2 -> R² = -14.2963, R² diff = -0.1156
# theta | semiCirc -> R² = -30.4240, R² diff = -0.2335
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.9 seed=2586 salvo.
# Epoch 0 | Train Loss 1.050063 | data Loss 1.013916 |  physics Loss 1.086210 | Val Loss 0.949772
# Epoch 100 | Train Loss 0.568992 | data Loss 0.537211 |  physics Loss 0.600773 | Val Loss 0.647667
# Epoch 200 | Train Loss 0.435798 | data Loss 0.395865 |  physics Loss 0.475730 | Val Loss 0.614275
# Epoch 300 | Train Loss 0.390333 | data Loss 0.366124 |  physics Loss 0.414543 | Val Loss 0.772260
# Early stopping at epoch 344
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.5_Lp0.5_seed7869.keras
# theta | ZZx1 -> R² = 0.6756, R² diff = 0.5659
# theta | ZZx2 -> R² = 0.9846, R² diff = 0.4062
# theta | ZZxReto -> R² = 0.4398, R² diff = 0.5248
# theta | ZZy1 -> R² = -14.5914, R² diff = 0.2542
# theta | ZZy2 -> R² = -10.9045, R² diff = 0.1085
# theta | LSG-1 -> R² = 0.3539, R² diff = 0.5116
# theta | LSG-2 -> R² = -1.4023, R² diff = 0.3592
# theta | ZZx1-inv -> R² = -1.3203, R² diff = 0.3803
# theta | zzx2-inv2 -> R² = -10.8509, R² diff = 0.1106
# theta | semiCirc -> R² = -20.4067, R² diff = -0.0266
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.9 seed=7869 salvo.
# Epoch 0 | Train Loss 1.045126 | data Loss 1.011779 |  physics Loss 1.078472 | Val Loss 0.961785
# Epoch 100 | Train Loss 0.562740 | data Loss 0.530457 |  physics Loss 0.595024 | Val Loss 0.638088
# Epoch 200 | Train Loss 0.445946 | data Loss 0.427518 |  physics Loss 0.464374 | Val Loss 0.600333
# Epoch 300 | Train Loss 0.399774 | data Loss 0.395729 |  physics Loss 0.403819 | Val Loss 0.618020
# Early stopping at epoch 372
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.5_Lp0.5_seed7621.keras
# theta | ZZx1 -> R² = -0.1121, R² diff = 0.5739
# theta | ZZx2 -> R² = 0.9124, R² diff = 0.4100
# theta | ZZxReto -> R² = -0.9476, R² diff = 0.5284
# theta | ZZy1 -> R² = -23.4140, R² diff = 0.1540
# theta | ZZy2 -> R² = -18.8160, R² diff = -0.0348
# theta | LSG-1 -> R² = -0.5524, R² diff = 0.5421
# theta | LSG-2 -> R² = -3.3185, R² diff = 0.3365
# theta | ZZx1-inv -> R² = -4.4037, R² diff = 0.2948
# theta | zzx2-inv2 -> R² = -15.9079, R² diff = 0.0428
# theta | semiCirc -> R² = -16.5978, R² diff = 0.0682
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.9 seed=7621 salvo.
# Epoch 0 | Train Loss 1.048785 | data Loss 1.014616 |  physics Loss 1.082954 | Val Loss 0.969760
# Epoch 100 | Train Loss 0.549916 | data Loss 0.528941 |  physics Loss 0.570891 | Val Loss 0.628073
# Epoch 200 | Train Loss 0.435185 | data Loss 0.405539 |  physics Loss 0.464831 | Val Loss 0.605539
# Epoch 300 | Train Loss 0.394681 | data Loss 0.370214 |  physics Loss 0.419147 | Val Loss 0.619727
# Early stopping at epoch 378
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.5_Lp0.5_seed8488.keras
# theta | ZZx1 -> R² = 0.7287, R² diff = 0.5806
# theta | ZZx2 -> R² = 0.8868, R² diff = 0.4017
# theta | ZZxReto -> R² = 0.2465, R² diff = 0.5420
# theta | ZZy1 -> R² = -18.0028, R² diff = 0.2263
# theta | ZZy2 -> R² = -10.3231, R² diff = 0.1066
# theta | LSG-1 -> R² = 0.3090, R² diff = 0.5346
# theta | LSG-2 -> R² = -1.5616, R² diff = 0.3434
# theta | ZZx1-inv -> R² = -0.7939, R² diff = 0.3352
# theta | zzx2-inv2 -> R² = -11.2396, R² diff = 0.1084
# theta | semiCirc -> R² = -22.1857, R² diff = -0.0426
# Modelo [94, 31, 9] | Ld=0.5 Lp=0.5 r=0.9 seed=8488 salvo.
# Epoch 0 | Train Loss 1.066745 | data Loss 1.020462 |  physics Loss 1.086580 | Val Loss 0.973383
# Epoch 100 | Train Loss 0.536665 | data Loss 0.717488 |  physics Loss 0.459170 | Val Loss 0.778073
# Epoch 200 | Train Loss 0.412195 | data Loss 0.626990 |  physics Loss 0.320139 | Val Loss 0.916558
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.3_Lp0.7_seed7872.keras
# theta | ZZx1 -> R² = 0.5318, R² diff = 0.3382
# theta | ZZx2 -> R² = 0.7723, R² diff = 0.2557
# theta | ZZxReto -> R² = 0.3639, R² diff = 0.2938
# theta | ZZy1 -> R² = -6.3995, R² diff = 0.1665
# theta | ZZy2 -> R² = -12.6521, R² diff = 0.0669
# theta | LSG-1 -> R² = -3.6090, R² diff = 0.3084
# theta | LSG-2 -> R² = -1.3210, R² diff = 0.2106
# theta | ZZx1-inv -> R² = -1.3687, R² diff = 0.1185
# theta | zzx2-inv2 -> R² = -5.0587, R² diff = 0.1097
# theta | semiCirc -> R² = -6.7334, R² diff = 0.0843
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=7872 salvo.
# Epoch 0 | Train Loss 1.049449 | data Loss 0.999281 |  physics Loss 1.070950 | Val Loss 0.903799
# Epoch 100 | Train Loss 0.539945 | data Loss 0.625728 |  physics Loss 0.503180 | Val Loss 0.788067
# Epoch 200 | Train Loss 0.436859 | data Loss 0.633873 |  physics Loss 0.352425 | Val Loss 0.907481
# Early stopping at epoch 247
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.3_Lp0.7_seed2586.keras
# theta | ZZx1 -> R² = 0.6001, R² diff = 0.3942
# theta | ZZx2 -> R² = 0.8224, R² diff = 0.2813
# theta | ZZxReto -> R² = 0.7150, R² diff = 0.3492
# theta | ZZy1 -> R² = -6.0625, R² diff = 0.1783
# theta | ZZy2 -> R² = -12.9949, R² diff = 0.0915
# theta | LSG-1 -> R² = -2.9473, R² diff = 0.3223
# theta | LSG-2 -> R² = -1.4261, R² diff = 0.2110
# theta | ZZx1-inv -> R² = -1.1420, R² diff = 0.1884
# theta | zzx2-inv2 -> R² = -5.7278, R² diff = 0.1156
# theta | semiCirc -> R² = -6.7370, R² diff = 0.0655
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=2586 salvo.
# Epoch 0 | Train Loss 1.055961 | data Loss 1.006566 |  physics Loss 1.077131 | Val Loss 0.946378
# Epoch 100 | Train Loss 0.536277 | data Loss 0.704740 |  physics Loss 0.464078 | Val Loss 0.792098
# Epoch 200 | Train Loss 0.414333 | data Loss 0.620334 |  physics Loss 0.326047 | Val Loss 0.716419
# Epoch 300 | Train Loss 0.351401 | data Loss 0.598694 |  physics Loss 0.245418 | Val Loss 0.806857
# Early stopping at epoch 385
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.3_Lp0.7_seed7869.keras
# theta | ZZx1 -> R² = 0.1305, R² diff = 0.3886
# theta | ZZx2 -> R² = 0.5201, R² diff = 0.3005
# theta | ZZxReto -> R² = 0.0993, R² diff = 0.3222
# theta | ZZy1 -> R² = -30.7888, R² diff = 0.0199
# theta | ZZy2 -> R² = -14.3039, R² diff = -0.1316
# theta | LSG-1 -> R² = 0.4490, R² diff = 0.4927
# theta | LSG-2 -> R² = -3.3432, R² diff = 0.2955
# theta | ZZx1-inv -> R² = -2.5923, R² diff = 0.1935
# theta | zzx2-inv2 -> R² = -17.8504, R² diff = -0.0694
# theta | semiCirc -> R² = -20.7405, R² diff = -0.0626
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=7869 salvo.
# Epoch 0 | Train Loss 1.060425 | data Loss 1.012686 |  physics Loss 1.080884 | Val Loss 0.949590
# Epoch 100 | Train Loss 0.578558 | data Loss 0.633302 |  physics Loss 0.555096 | Val Loss 1.109476
# Epoch 200 | Train Loss 0.502560 | data Loss 0.594625 |  physics Loss 0.463103 | Val Loss 1.155718
# Early stopping at epoch 229
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.3_Lp0.7_seed7621.keras
# theta | ZZx1 -> R² = -0.7529, R² diff = 0.2804
# theta | ZZx2 -> R² = 0.5341, R² diff = 0.1965
# theta | ZZxReto -> R² = -2.5071, R² diff = 0.2249
# theta | ZZy1 -> R² = -2.1300, R² diff = 0.1638
# theta | ZZy2 -> R² = -11.8801, R² diff = 0.1249
# theta | LSG-1 -> R² = -10.7745, R² diff = 0.1968
# theta | LSG-2 -> R² = -1.2682, R² diff = 0.1679
# theta | ZZx1-inv -> R² = -2.6164, R² diff = 0.1439
# theta | zzx2-inv2 -> R² = -3.8076, R² diff = 0.1404
# theta | semiCirc -> R² = -0.6666, R² diff = 0.1670
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=7621 salvo.
# Epoch 0 | Train Loss 1.047990 | data Loss 0.991017 |  physics Loss 1.072406 | Val Loss 0.913906
# Epoch 100 | Train Loss 0.619381 | data Loss 0.561395 |  physics Loss 0.644232 | Val Loss 0.670680
# Epoch 200 | Train Loss 0.533857 | data Loss 0.562564 |  physics Loss 0.521554 | Val Loss 0.785392
# Epoch 300 | Train Loss 0.505419 | data Loss 0.535480 |  physics Loss 0.492536 | Val Loss 1.101116
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.3_Lp0.7_seed8488.keras
# theta | ZZx1 -> R² = 0.7380, R² diff = 0.4759
# theta | ZZx2 -> R² = 0.8922, R² diff = 0.3392
# theta | ZZxReto -> R² = 0.8377, R² diff = 0.4192
# theta | ZZy1 -> R² = -16.2424, R² diff = 0.1203
# theta | ZZy2 -> R² = -9.0883, R² diff = 0.1156
# theta | LSG-1 -> R² = 0.5642, R² diff = 0.4388
# theta | LSG-2 -> R² = -0.9339, R² diff = 0.3088
# theta | ZZx1-inv -> R² = 0.1493, R² diff = 0.3009
# theta | zzx2-inv2 -> R² = -5.9704, R² diff = 0.1075
# theta | semiCirc -> R² = -17.7787, R² diff = -0.0384
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.01 seed=8488 salvo.
# Epoch 0 | Train Loss 1.055795 | data Loss 1.008558 |  physics Loss 1.076040 | Val Loss 0.962695
# Epoch 100 | Train Loss 0.539603 | data Loss 0.683340 |  physics Loss 0.478001 | Val Loss 0.756321
# Epoch 200 | Train Loss 0.419474 | data Loss 0.607502 |  physics Loss 0.338891 | Val Loss 0.707655
# Epoch 300 | Train Loss 0.374586 | data Loss 0.588871 |  physics Loss 0.282749 | Val Loss 0.857148
# Early stopping at epoch 356
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.3_Lp0.7_seed7872.keras
# theta | ZZx1 -> R² = 0.1572, R² diff = 0.3734
# theta | ZZx2 -> R² = 0.4595, R² diff = 0.3229
# theta | ZZxReto -> R² = -0.0583, R² diff = 0.3483
# theta | ZZy1 -> R² = -19.5819, R² diff = 0.1087
# theta | ZZy2 -> R² = -12.5783, R² diff = 0.0052
# theta | LSG-1 -> R² = -0.7101, R² diff = 0.4395
# theta | LSG-2 -> R² = -4.4105, R² diff = 0.3131
# theta | ZZx1-inv -> R² = -5.0208, R² diff = 0.2707
# theta | zzx2-inv2 -> R² = -14.4456, R² diff = 0.1018
# theta | semiCirc -> R² = -12.5920, R² diff = 0.0720
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=7872 salvo.
# Epoch 0 | Train Loss 1.066007 | data Loss 1.020981 |  physics Loss 1.085304 | Val Loss 0.941780
# Epoch 100 | Train Loss 0.515452 | data Loss 0.704717 |  physics Loss 0.434338 | Val Loss 0.950386
# Epoch 200 | Train Loss 0.410704 | data Loss 0.654790 |  physics Loss 0.306095 | Val Loss 0.874688
# Early stopping at epoch 234
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.3_Lp0.7_seed2586.keras
# theta | ZZx1 -> R² = 0.1721, R² diff = 0.3299
# theta | ZZx2 -> R² = 0.6905, R² diff = 0.2104
# theta | ZZxReto -> R² = -0.9344, R² diff = 0.2745
# theta | ZZy1 -> R² = -3.7643, R² diff = 0.1836
# theta | ZZy2 -> R² = -14.2796, R² diff = 0.0737
# theta | LSG-1 -> R² = -7.1124, R² diff = 0.2489
# theta | LSG-2 -> R² = -1.5156, R² diff = 0.1687
# theta | ZZx1-inv -> R² = -1.6158, R² diff = 0.1193
# theta | zzx2-inv2 -> R² = -5.1512, R² diff = 0.1060
# theta | semiCirc -> R² = -3.4687, R² diff = 0.0738
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=2586 salvo.
# Epoch 0 | Train Loss 1.059521 | data Loss 1.014762 |  physics Loss 1.078703 | Val Loss 0.964697
# Epoch 100 | Train Loss 0.520631 | data Loss 0.707046 |  physics Loss 0.440739 | Val Loss 0.778429
# Epoch 200 | Train Loss 0.399753 | data Loss 0.625513 |  physics Loss 0.302999 | Val Loss 0.647811
# Epoch 300 | Train Loss 0.345484 | data Loss 0.603634 |  physics Loss 0.234848 | Val Loss 0.751789
# Early stopping at epoch 394
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.3_Lp0.7_seed7869.keras
# theta | ZZx1 -> R² = 0.9024, R² diff = 0.3739
# theta | ZZx2 -> R² = 0.9680, R² diff = 0.3423
# theta | ZZxReto -> R² = 0.5936, R² diff = 0.3230
# theta | ZZy1 -> R² = -12.4089, R² diff = 0.2123
# theta | ZZy2 -> R² = -23.4368, R² diff = -0.2811
# theta | LSG-1 -> R² = -1.3962, R² diff = 0.3860
# theta | LSG-2 -> R² = -3.7837, R² diff = 0.1552
# theta | ZZx1-inv -> R² = -1.9487, R² diff = 0.0279
# theta | zzx2-inv2 -> R² = -20.9014, R² diff = -0.1031
# theta | semiCirc -> R² = -20.8442, R² diff = -0.1094
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=7869 salvo.
# Epoch 0 | Train Loss 1.053067 | data Loss 1.004537 |  physics Loss 1.073866 | Val Loss 0.955041
# Epoch 100 | Train Loss 0.540261 | data Loss 0.683945 |  physics Loss 0.478682 | Val Loss 0.763180
# Epoch 200 | Train Loss 0.415311 | data Loss 0.637809 |  physics Loss 0.319954 | Val Loss 0.720121
# Epoch 300 | Train Loss 0.349510 | data Loss 0.612274 |  physics Loss 0.236896 | Val Loss 0.672716
# Epoch 400 | Train Loss 0.317366 | data Loss 0.612177 |  physics Loss 0.191018 | Val Loss 0.745193
# Early stopping at epoch 443
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.3_Lp0.7_seed7621.keras
# theta | ZZx1 -> R² = 0.8515, R² diff = 0.3921
# theta | ZZx2 -> R² = 0.8872, R² diff = 0.3494
# theta | ZZxReto -> R² = 0.8533, R² diff = 0.3402
# theta | ZZy1 -> R² = -21.0860, R² diff = 0.1163
# theta | ZZy2 -> R² = -19.1756, R² diff = -0.2753
# theta | LSG-1 -> R² = 0.8559, R² diff = 0.5336
# theta | LSG-2 -> R² = -2.0517, R² diff = 0.2683
# theta | ZZx1-inv -> R² = -2.9927, R² diff = 0.0773
# theta | zzx2-inv2 -> R² = -19.3559, R² diff = -0.2229
# theta | semiCirc -> R² = -29.8207, R² diff = -0.1923
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=7621 salvo.
# Epoch 0 | Train Loss 1.053006 | data Loss 1.006027 |  physics Loss 1.073140 | Val Loss 0.958594
# Epoch 100 | Train Loss 0.512689 | data Loss 0.726124 |  physics Loss 0.421217 | Val Loss 0.812874
# Epoch 200 | Train Loss 0.393535 | data Loss 0.637484 |  physics Loss 0.288985 | Val Loss 0.646564
# Epoch 300 | Train Loss 0.347277 | data Loss 0.600314 |  physics Loss 0.238833 | Val Loss 0.666629
# Epoch 400 | Train Loss 0.320955 | data Loss 0.603088 |  physics Loss 0.200040 | Val Loss 0.709507
# Early stopping at epoch 494
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.3_Lp0.7_seed8488.keras
# theta | ZZx1 -> R² = 0.9394, R² diff = 0.4182
# theta | ZZx2 -> R² = 0.8011, R² diff = 0.3567
# theta | ZZxReto -> R² = 0.4718, R² diff = 0.3344
# theta | ZZy1 -> R² = -10.6355, R² diff = 0.2394
# theta | ZZy2 -> R² = -12.7750, R² diff = -0.1394
# theta | LSG-1 -> R² = -0.1175, R² diff = 0.4678
# theta | LSG-2 -> R² = -3.0257, R² diff = 0.2197
# theta | ZZx1-inv -> R² = -0.3170, R² diff = 0.1243
# theta | zzx2-inv2 -> R² = -14.2513, R² diff = -0.0253
# theta | semiCirc -> R² = -27.5806, R² diff = -0.1503
# Modelo [94, 31, 9] | Ld=0.3 Lp=0.7 r=0.9 seed=8488 salvo.
# Epoch 0 | Train Loss 1.013852 | data Loss 0.990908 |  physics Loss 1.067389 | Val Loss 0.931897
# Epoch 100 | Train Loss 0.513778 | data Loss 0.394258 |  physics Loss 0.792660 | Val Loss 0.576618
# Epoch 200 | Train Loss 0.404163 | data Loss 0.266909 |  physics Loss 0.724424 | Val Loss 0.607807
# Epoch 300 | Train Loss 0.363088 | data Loss 0.221477 |  physics Loss 0.693516 | Val Loss 0.575729
# Early stopping at epoch 353
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.7_Lp0.3_seed7872.keras
# theta | ZZx1 -> R² = 0.8127, R² diff = 0.7027
# theta | ZZx2 -> R² = 0.9632, R² diff = 0.4487
# theta | ZZxReto -> R² = 0.7686, R² diff = 0.6546
# theta | ZZy1 -> R² = -10.8141, R² diff = 0.3450
# theta | ZZy2 -> R² = -14.4138, R² diff = 0.0943
# theta | LSG-1 -> R² = 0.4639, R² diff = 0.5565
# theta | LSG-2 -> R² = -2.1589, R² diff = 0.3245
# theta | ZZx1-inv -> R² = -1.1281, R² diff = 0.3810
# theta | zzx2-inv2 -> R² = -11.9443, R² diff = 0.1065
# theta | semiCirc -> R² = -24.6056, R² diff = -0.1096
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=7872 salvo.
# Epoch 0 | Train Loss 1.021226 | data Loss 0.998390 |  physics Loss 1.074511 | Val Loss 0.934745
# Epoch 100 | Train Loss 0.506384 | data Loss 0.391385 |  physics Loss 0.774714 | Val Loss 0.653107
# Epoch 200 | Train Loss 0.397426 | data Loss 0.253629 |  physics Loss 0.732953 | Val Loss 0.560685
# Epoch 300 | Train Loss 0.353696 | data Loss 0.208295 |  physics Loss 0.692963 | Val Loss 0.567040
# Epoch 400 | Train Loss 0.336736 | data Loss 0.191656 |  physics Loss 0.675256 | Val Loss 0.584360
# Early stopping at epoch 421
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.7_Lp0.3_seed2586.keras
# theta | ZZx1 -> R² = 0.8615, R² diff = 0.7446
# theta | ZZx2 -> R² = 0.3148, R² diff = 0.4647
# theta | ZZxReto -> R² = 0.8865, R² diff = 0.6709
# theta | ZZy1 -> R² = -11.2359, R² diff = 0.3216
# theta | ZZy2 -> R² = -5.3924, R² diff = 0.3079
# theta | LSG-1 -> R² = 0.6014, R² diff = 0.5596
# theta | LSG-2 -> R² = -0.8170, R² diff = 0.3919
# theta | ZZx1-inv -> R² = 0.6476, R² diff = 0.5221
# theta | zzx2-inv2 -> R² = -7.1488, R² diff = 0.1232
# theta | semiCirc -> R² = -33.5031, R² diff = -0.2661
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=2586 salvo.
# Epoch 0 | Train Loss 1.036371 | data Loss 1.016818 |  physics Loss 1.081994 | Val Loss 0.921719
# Epoch 100 | Train Loss 0.515471 | data Loss 0.402871 |  physics Loss 0.778205 | Val Loss 0.571860
# Epoch 200 | Train Loss 0.427816 | data Loss 0.302279 |  physics Loss 0.720734 | Val Loss 0.544769
# Epoch 300 | Train Loss 0.358258 | data Loss 0.220706 |  physics Loss 0.679212 | Val Loss 0.606361
# Early stopping at epoch 399
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.7_Lp0.3_seed7869.keras
# theta | ZZx1 -> R² = 0.8654, R² diff = 0.7010
# theta | ZZx2 -> R² = 0.9585, R² diff = 0.4586
# theta | ZZxReto -> R² = 0.8596, R² diff = 0.6577
# theta | ZZy1 -> R² = -6.3627, R² diff = 0.3735
# theta | ZZy2 -> R² = -15.7642, R² diff = 0.0146
# theta | LSG-1 -> R² = 0.8533, R² diff = 0.5882
# theta | LSG-2 -> R² = -2.2229, R² diff = 0.3368
# theta | ZZx1-inv -> R² = -0.9557, R² diff = 0.3930
# theta | zzx2-inv2 -> R² = -16.2152, R² diff = 0.0474
# theta | semiCirc -> R² = -27.2658, R² diff = -0.1741
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=7869 salvo.
# Epoch 0 | Train Loss 1.025700 | data Loss 1.003288 |  physics Loss 1.077996 | Val Loss 0.952362
# Epoch 100 | Train Loss 0.546752 | data Loss 0.442909 |  physics Loss 0.789052 | Val Loss 0.655391
# Epoch 200 | Train Loss 0.432650 | data Loss 0.290091 |  physics Loss 0.765289 | Val Loss 0.624714
# Epoch 300 | Train Loss 0.385090 | data Loss 0.237047 |  physics Loss 0.730523 | Val Loss 0.589419
# Epoch 400 | Train Loss 0.348595 | data Loss 0.210849 |  physics Loss 0.670002 | Val Loss 0.614551
# Early stopping at epoch 493
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.7_Lp0.3_seed7621.keras
# theta | ZZx1 -> R² = 0.8110, R² diff = 0.7605
# theta | ZZx2 -> R² = 0.8097, R² diff = 0.4093
# theta | ZZxReto -> R² = 0.7589, R² diff = 0.6609
# theta | ZZy1 -> R² = -22.8731, R² diff = 0.2254
# theta | ZZy2 -> R² = -21.4135, R² diff = -0.2652
# theta | LSG-1 -> R² = 0.5862, R² diff = 0.5892
# theta | LSG-2 -> R² = -2.7154, R² diff = 0.3325
# theta | ZZx1-inv -> R² = -2.3702, R² diff = 0.3128
# theta | zzx2-inv2 -> R² = -16.8327, R² diff = -0.2075
# theta | semiCirc -> R² = -38.9864, R² diff = -0.3826
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=7621 salvo.
# Epoch 0 | Train Loss 1.036154 | data Loss 1.014741 |  physics Loss 1.086118 | Val Loss 0.962970
# Epoch 100 | Train Loss 0.524523 | data Loss 0.422546 |  physics Loss 0.762469 | Val Loss 0.600782
# Epoch 200 | Train Loss 0.404899 | data Loss 0.272891 |  physics Loss 0.712918 | Val Loss 0.600995
# Epoch 300 | Train Loss 0.351181 | data Loss 0.218646 |  physics Loss 0.660430 | Val Loss 0.613380
# Epoch 400 | Train Loss 0.332245 | data Loss 0.207694 |  physics Loss 0.622865 | Val Loss 0.646332
# Epoch 500 | Train Loss 0.310715 | data Loss 0.180094 |  physics Loss 0.615499 | Val Loss 0.684249
# Early stopping at epoch 521
# Modelo salvo em:
# models/model_arch94-31-9_r0.01_Ld0.7_Lp0.3_seed8488.keras
# theta | ZZx1 -> R² = 0.7293, R² diff = 0.7224
# theta | ZZx2 -> R² = 0.2531, R² diff = 0.4250
# theta | ZZxReto -> R² = 0.2332, R² diff = 0.7036
# theta | ZZy1 -> R² = -19.3847, R² diff = 0.2385
# theta | ZZy2 -> R² = -15.7069, R² diff = -0.0921
# theta | LSG-1 -> R² = 0.2659, R² diff = 0.5962
# theta | LSG-2 -> R² = -2.3617, R² diff = 0.3406
# theta | ZZx1-inv -> R² = -0.6603, R² diff = 0.4157
# theta | zzx2-inv2 -> R² = -14.8889, R² diff = -0.1925
# theta | semiCirc -> R² = -45.3994, R² diff = -0.5543
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.01 seed=8488 salvo.
# Epoch 0 | Train Loss 1.037105 | data Loss 1.017034 |  physics Loss 1.083938 | Val Loss 0.966630
# Epoch 100 | Train Loss 0.495792 | data Loss 0.388971 |  physics Loss 0.745040 | Val Loss 0.601354
# Epoch 200 | Train Loss 0.397021 | data Loss 0.257409 |  physics Loss 0.722782 | Val Loss 0.571610
# Epoch 300 | Train Loss 0.329739 | data Loss 0.202038 |  physics Loss 0.627708 | Val Loss 0.647772
# Epoch 400 | Train Loss 0.305684 | data Loss 0.177380 |  physics Loss 0.605062 | Val Loss 0.694756
# Early stopping at epoch 401
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.7_Lp0.3_seed7872.keras
# theta | ZZx1 -> R² = 0.8785, R² diff = 0.7526
# theta | ZZx2 -> R² = 0.7241, R² diff = 0.4296
# theta | ZZxReto -> R² = 0.8362, R² diff = 0.6741
# theta | ZZy1 -> R² = -12.6908, R² diff = 0.3120
# theta | ZZy2 -> R² = -17.1592, R² diff = -0.0668
# theta | LSG-1 -> R² = 0.7368, R² diff = 0.5905
# theta | LSG-2 -> R² = -2.6155, R² diff = 0.3057
# theta | ZZx1-inv -> R² = -0.0879, R² diff = 0.4002
# theta | zzx2-inv2 -> R² = -14.2149, R² diff = -0.0295
# theta | semiCirc -> R² = -34.6087, R² diff = -0.3453
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=7872 salvo.
# Epoch 0 | Train Loss 1.031463 | data Loss 1.010527 |  physics Loss 1.080314 | Val Loss 0.925428
# Epoch 100 | Train Loss 0.505835 | data Loss 0.394069 |  physics Loss 0.766624 | Val Loss 0.577673
# Epoch 200 | Train Loss 0.405086 | data Loss 0.285873 |  physics Loss 0.683252 | Val Loss 0.576022
# Epoch 300 | Train Loss 0.361627 | data Loss 0.218637 |  physics Loss 0.695268 | Val Loss 0.577447
# Early stopping at epoch 344
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.7_Lp0.3_seed2586.keras
# theta | ZZx1 -> R² = 0.7707, R² diff = 0.6729
# theta | ZZx2 -> R² = 0.9351, R² diff = 0.4311
# theta | ZZxReto -> R² = 0.8143, R² diff = 0.6206
# theta | ZZy1 -> R² = -16.6856, R² diff = 0.2412
# theta | ZZy2 -> R² = -13.7300, R² diff = 0.0489
# theta | LSG-1 -> R² = 0.8030, R² diff = 0.5368
# theta | LSG-2 -> R² = -1.7549, R² diff = 0.3298
# theta | ZZx1-inv -> R² = -1.0838, R² diff = 0.3698
# theta | zzx2-inv2 -> R² = -10.1474, R² diff = 0.0436
# theta | semiCirc -> R² = -26.1071, R² diff = -0.1553
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=2586 salvo.
# Epoch 0 | Train Loss 1.022867 | data Loss 0.999748 |  physics Loss 1.076811 | Val Loss 0.930718
# Epoch 100 | Train Loss 0.495153 | data Loss 0.371818 |  physics Loss 0.782936 | Val Loss 0.588330
# Epoch 200 | Train Loss 0.386642 | data Loss 0.248084 |  physics Loss 0.709945 | Val Loss 0.620101
# Epoch 300 | Train Loss 0.344176 | data Loss 0.208685 |  physics Loss 0.660322 | Val Loss 0.706625
# Early stopping at epoch 370
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.7_Lp0.3_seed7869.keras
# theta | ZZx1 -> R² = 0.8642, R² diff = 0.7345
# theta | ZZx2 -> R² = 0.6064, R² diff = 0.4192
# theta | ZZxReto -> R² = 0.9195, R² diff = 0.6514
# theta | ZZy1 -> R² = -14.9542, R² diff = 0.2882
# theta | ZZy2 -> R² = -14.0951, R² diff = 0.0331
# theta | LSG-1 -> R² = 0.8596, R² diff = 0.5770
# theta | LSG-2 -> R² = -2.3749, R² diff = 0.3259
# theta | ZZx1-inv -> R² = -0.1784, R² diff = 0.4326
# theta | zzx2-inv2 -> R² = -11.3102, R² diff = 0.0458
# theta | semiCirc -> R² = -30.1147, R² diff = -0.2084
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=7869 salvo.
# Epoch 0 | Train Loss 1.034916 | data Loss 1.015121 |  physics Loss 1.081105 | Val Loss 0.968720
# Epoch 100 | Train Loss 0.532677 | data Loss 0.434426 |  physics Loss 0.761931 | Val Loss 0.599052
# Epoch 200 | Train Loss 0.404177 | data Loss 0.281972 |  physics Loss 0.689322 | Val Loss 0.576494
# Epoch 300 | Train Loss 0.352651 | data Loss 0.222461 |  physics Loss 0.656426 | Val Loss 0.672133
# Early stopping at epoch 378
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.7_Lp0.3_seed7621.keras
# theta | ZZx1 -> R² = 0.6180, R² diff = 0.6848
# theta | ZZx2 -> R² = 0.9596, R² diff = 0.4289
# theta | ZZxReto -> R² = 0.7471, R² diff = 0.5721
# theta | ZZy1 -> R² = -19.1112, R² diff = 0.2032
# theta | ZZy2 -> R² = -19.7482, R² diff = -0.0057
# theta | LSG-1 -> R² = 0.7839, R² diff = 0.5635
# theta | LSG-2 -> R² = -2.3302, R² diff = 0.3531
# theta | ZZx1-inv -> R² = -2.7340, R² diff = 0.4017
# theta | zzx2-inv2 -> R² = -14.6885, R² diff = 0.0315
# theta | semiCirc -> R² = -20.8435, R² diff = -0.0297
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=7621 salvo.
# Epoch 0 | Train Loss 1.021334 | data Loss 0.999192 |  physics Loss 1.073001 | Val Loss 0.953008
# Epoch 100 | Train Loss 0.524814 | data Loss 0.432463 |  physics Loss 0.740300 | Val Loss 0.659912
# Epoch 200 | Train Loss 0.394644 | data Loss 0.279584 |  physics Loss 0.663117 | Val Loss 0.594946
# Epoch 300 | Train Loss 0.345885 | data Loss 0.221133 |  physics Loss 0.636972 | Val Loss 0.677133
# Early stopping at epoch 366
# Modelo salvo em:
# models/model_arch94-31-9_r0.9_Ld0.7_Lp0.3_seed8488.keras
# theta | ZZx1 -> R² = 0.8215, R² diff = 0.6752
# theta | ZZx2 -> R² = 0.3100, R² diff = 0.4248
# theta | ZZxReto -> R² = 0.6803, R² diff = 0.6192
# theta | ZZy1 -> R² = -12.0787, R² diff = 0.2725
# theta | ZZy2 -> R² = -13.7773, R² diff = 0.0721
# theta | LSG-1 -> R² = 0.8614, R² diff = 0.5448
# theta | LSG-2 -> R² = -2.0793, R² diff = 0.3132
# theta | ZZx1-inv -> R² = 0.0911, R² diff = 0.4095
# theta | zzx2-inv2 -> R² = -8.4870, R² diff = 0.1007
# theta | semiCirc -> R² = -24.9219, R² diff = -0.1603
# Modelo [94, 31, 9] | Ld=0.7 Lp=0.3 r=0.9 seed=8488 salvo.
# Epoch 0 | Train Loss 1.046150 | data Loss 1.011696 |  physics Loss 1.080603 | Val Loss 0.957111
# Epoch 100 | Train Loss 0.534962 | data Loss 0.509953 |  physics Loss 0.559971 | Val Loss 0.641918
# Epoch 200 | Train Loss 0.432459 | data Loss 0.411826 |  physics Loss 0.453091 | Val Loss 0.608850
# Epoch 300 | Train Loss 0.392422 | data Loss 0.371516 |  physics Loss 0.413328 | Val Loss 0.617906
# Early stopping at epoch 342
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.5_Lp0.5_seed7872.keras
# theta | ZZx1 -> R² = 0.3169, R² diff = 0.5771
# theta | ZZx2 -> R² = 0.8844, R² diff = 0.3910
# theta | ZZxReto -> R² = 0.4063, R² diff = 0.5357
# theta | ZZy1 -> R² = -14.2501, R² diff = 0.2555
# theta | ZZy2 -> R² = -15.9329, R² diff = -0.0415
# theta | LSG-1 -> R² = 0.4841, R² diff = 0.5253
# theta | LSG-2 -> R² = -2.3767, R² diff = 0.3111
# theta | ZZx1-inv -> R² = -1.7397, R² diff = 0.2994
# theta | zzx2-inv2 -> R² = -13.2010, R² diff = 0.0092
# theta | semiCirc -> R² = -23.7225, R² diff = -0.1018
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.01 seed=7872 salvo.
# Epoch 0 | Train Loss 1.066187 | data Loss 1.036645 |  physics Loss 1.095729 | Val Loss 0.960769
# Epoch 100 | Train Loss 0.560438 | data Loss 0.472537 |  physics Loss 0.648339 | Val Loss 0.606525
# Epoch 200 | Train Loss 0.485797 | data Loss 0.404881 |  physics Loss 0.566714 | Val Loss 0.576782
# Epoch 300 | Train Loss 0.437382 | data Loss 0.400245 |  physics Loss 0.474519 | Val Loss 0.641078
# Epoch 400 | Train Loss 0.430436 | data Loss 0.403545 |  physics Loss 0.457326 | Val Loss 0.836798
# Early stopping at epoch 407
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.5_Lp0.5_seed2586.keras
# theta | ZZx1 -> R² = 0.4517, R² diff = 0.6065
# theta | ZZx2 -> R² = 0.8545, R² diff = 0.4171
# theta | ZZxReto -> R² = -0.1960, R² diff = 0.5471
# theta | ZZy1 -> R² = -12.9049, R² diff = 0.2708
# theta | ZZy2 -> R² = -16.2292, R² diff = -0.0625
# theta | LSG-1 -> R² = 0.4460, R² diff = 0.5266
# theta | LSG-2 -> R² = -2.3055, R² diff = 0.3018
# theta | ZZx1-inv -> R² = -2.1819, R² diff = 0.2679
# theta | zzx2-inv2 -> R² = -13.6838, R² diff = 0.0174
# theta | semiCirc -> R² = -25.4249, R² diff = -0.1528
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.01 seed=2586 salvo.
# Epoch 0 | Train Loss 1.045891 | data Loss 1.012586 |  physics Loss 1.079197 | Val Loss 0.946182
# Epoch 100 | Train Loss 0.551036 | data Loss 0.511825 |  physics Loss 0.590246 | Val Loss 0.675689
# Epoch 200 | Train Loss 0.469568 | data Loss 0.414561 |  physics Loss 0.524575 | Val Loss 0.783867
# Epoch 300 | Train Loss 0.422242 | data Loss 0.400739 |  physics Loss 0.443746 | Val Loss 0.657454
# Epoch 400 | Train Loss 0.379141 | data Loss 0.358735 |  physics Loss 0.399547 | Val Loss 0.683626
# Early stopping at epoch 493
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.5_Lp0.5_seed7869.keras
# theta | ZZx1 -> R² = 0.8076, R² diff = 0.6050
# theta | ZZx2 -> R² = 0.9317, R² diff = 0.3503
# theta | ZZxReto -> R² = 0.7572, R² diff = 0.4332
# theta | ZZy1 -> R² = -20.7969, R² diff = 0.1371
# theta | ZZy2 -> R² = -22.6093, R² diff = -0.3153
# theta | LSG-1 -> R² = 0.7995, R² diff = 0.5076
# theta | LSG-2 -> R² = -3.1122, R² diff = 0.2512
# theta | ZZx1-inv -> R² = -1.8155, R² diff = 0.3004
# theta | zzx2-inv2 -> R² = -28.7134, R² diff = -0.2072
# theta | semiCirc -> R² = -22.4232, R² diff = -0.2014
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.01 seed=7869 salvo.
# Epoch 0 | Train Loss 1.021452 | data Loss 0.981231 |  physics Loss 1.061673 | Val Loss 0.928065
# Epoch 100 | Train Loss 0.570721 | data Loss 0.500500 |  physics Loss 0.640942 | Val Loss 0.667657
# Epoch 200 | Train Loss 0.494770 | data Loss 0.418252 |  physics Loss 0.571288 | Val Loss 0.636742
# Epoch 300 | Train Loss 0.464256 | data Loss 0.390717 |  physics Loss 0.537794 | Val Loss 0.673527
# Epoch 400 | Train Loss 0.440063 | data Loss 0.378190 |  physics Loss 0.501936 | Val Loss 0.674824
# Epoch 500 | Train Loss 0.420485 | data Loss 0.369204 |  physics Loss 0.471766 | Val Loss 0.686477
# Early stopping at epoch 537
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.5_Lp0.5_seed7621.keras
# theta | ZZx1 -> R² = 0.9052, R² diff = 0.6114
# theta | ZZx2 -> R² = 0.5374, R² diff = 0.3934
# theta | ZZxReto -> R² = 0.8875, R² diff = 0.5342
# theta | ZZy1 -> R² = -18.4348, R² diff = 0.2106
# theta | ZZy2 -> R² = -8.7602, R² diff = 0.0773
# theta | LSG-1 -> R² = 0.6695, R² diff = 0.5742
# theta | LSG-2 -> R² = -0.7309, R² diff = 0.3926
# theta | ZZx1-inv -> R² = -0.1636, R² diff = 0.3255
# theta | zzx2-inv2 -> R² = -7.7618, R² diff = 0.0914
# theta | semiCirc -> R² = -38.0719, R² diff = -0.3889
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.01 seed=7621 salvo.
# Epoch 0 | Train Loss 1.019730 | data Loss 0.979175 |  physics Loss 1.060285 | Val Loss 0.933686
# Epoch 100 | Train Loss 0.566588 | data Loss 0.518829 |  physics Loss 0.614348 | Val Loss 0.669050
# Epoch 200 | Train Loss 0.501052 | data Loss 0.440337 |  physics Loss 0.561768 | Val Loss 0.635233
# Epoch 300 | Train Loss 0.451611 | data Loss 0.404463 |  physics Loss 0.498760 | Val Loss 0.617204
# Epoch 400 | Train Loss 0.406144 | data Loss 0.370386 |  physics Loss 0.441903 | Val Loss 0.627815
# Epoch 500 | Train Loss 0.381572 | data Loss 0.342797 |  physics Loss 0.420347 | Val Loss 0.640528
# Early stopping at epoch 547
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.5_Lp0.5_seed8488.keras
# theta | ZZx1 -> R² = 0.8238, R² diff = 0.6195
# theta | ZZx2 -> R² = 0.1965, R² diff = 0.3889
# theta | ZZxReto -> R² = 0.7581, R² diff = 0.4972
# theta | ZZy1 -> R² = -17.3809, R² diff = 0.1911
# theta | ZZy2 -> R² = -11.8602, R² diff = -0.0696
# theta | LSG-1 -> R² = 0.7984, R² diff = 0.5333
# theta | LSG-2 -> R² = -1.7573, R² diff = 0.3167
# theta | ZZx1-inv -> R² = -0.2604, R² diff = 0.2822
# theta | zzx2-inv2 -> R² = -7.8158, R² diff = 0.0334
# theta | semiCirc -> R² = -31.8114, R² diff = -0.2465
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.01 seed=8488 salvo.
# Epoch 0 | Train Loss 1.054233 | data Loss 1.019719 |  physics Loss 1.088747 | Val Loss 0.948433
# Epoch 100 | Train Loss 0.565034 | data Loss 0.477492 |  physics Loss 0.652577 | Val Loss 0.598346
# Epoch 200 | Train Loss 0.465812 | data Loss 0.396469 |  physics Loss 0.535155 | Val Loss 0.671394
# Epoch 300 | Train Loss 0.440086 | data Loss 0.393643 |  physics Loss 0.486530 | Val Loss 0.674964
# Early stopping at epoch 320
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.5_Lp0.5_seed7872.keras
# theta | ZZx1 -> R² = 0.6599, R² diff = 0.5565
# theta | ZZx2 -> R² = 0.8645, R² diff = 0.4027
# theta | ZZxReto -> R² = 0.8525, R² diff = 0.5191
# theta | ZZy1 -> R² = -10.5562, R² diff = 0.2666
# theta | ZZy2 -> R² = -12.9489, R² diff = 0.1366
# theta | LSG-1 -> R² = -0.1320, R² diff = 0.5021
# theta | LSG-2 -> R² = -2.4140, R² diff = 0.3426
# theta | ZZx1-inv -> R² = -2.8657, R² diff = 0.3493
# theta | zzx2-inv2 -> R² = -11.5971, R² diff = 0.1605
# theta | semiCirc -> R² = -17.1045, R² diff = 0.0206
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.9 seed=7872 salvo.
# Epoch 0 | Train Loss 1.018062 | data Loss 0.979266 |  physics Loss 1.056858 | Val Loss 0.933227
# Epoch 100 | Train Loss 0.529157 | data Loss 0.482216 |  physics Loss 0.576099 | Val Loss 0.625026
# Epoch 200 | Train Loss 0.417119 | data Loss 0.379421 |  physics Loss 0.454817 | Val Loss 0.587774
# Epoch 300 | Train Loss 0.369857 | data Loss 0.359132 |  physics Loss 0.380582 | Val Loss 0.718952
# Early stopping at epoch 381
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.5_Lp0.5_seed2586.keras
# theta | ZZx1 -> R² = 0.7923, R² diff = 0.6059
# theta | ZZx2 -> R² = 0.9255, R² diff = 0.4063
# theta | ZZxReto -> R² = 0.6967, R² diff = 0.5581
# theta | ZZy1 -> R² = -18.1012, R² diff = 0.2513
# theta | ZZy2 -> R² = -16.5309, R² diff = -0.0736
# theta | LSG-1 -> R² = 0.7242, R² diff = 0.5453
# theta | LSG-2 -> R² = -2.4533, R² diff = 0.2941
# theta | ZZx1-inv -> R² = -2.2401, R² diff = 0.2793
# theta | zzx2-inv2 -> R² = -17.1087, R² diff = -0.0173
# theta | semiCirc -> R² = -28.8600, R² diff = -0.1767
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.9 seed=2586 salvo.
# Epoch 0 | Train Loss 1.066087 | data Loss 1.037488 |  physics Loss 1.094686 | Val Loss 0.965243
# Epoch 100 | Train Loss 0.567847 | data Loss 0.489336 |  physics Loss 0.646358 | Val Loss 0.642068
# Epoch 200 | Train Loss 0.492431 | data Loss 0.413644 |  physics Loss 0.571219 | Val Loss 0.656155
# Epoch 300 | Train Loss 0.461327 | data Loss 0.396278 |  physics Loss 0.526377 | Val Loss 0.732016
# Epoch 400 | Train Loss 0.414750 | data Loss 0.385186 |  physics Loss 0.444314 | Val Loss 0.672100
# Early stopping at epoch 438
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.5_Lp0.5_seed7869.keras
# theta | ZZx1 -> R² = 0.8500, R² diff = 0.5800
# theta | ZZx2 -> R² = 0.8247, R² diff = 0.3754
# theta | ZZxReto -> R² = 0.8143, R² diff = 0.5054
# theta | ZZy1 -> R² = -26.3802, R² diff = 0.0809
# theta | ZZy2 -> R² = -8.8085, R² diff = 0.0259
# theta | LSG-1 -> R² = 0.5355, R² diff = 0.5269
# theta | LSG-2 -> R² = -0.7149, R² diff = 0.3739
# theta | ZZx1-inv -> R² = -0.4396, R² diff = 0.3394
# theta | zzx2-inv2 -> R² = -7.9588, R² diff = 0.0164
# theta | semiCirc -> R² = -36.1678, R² diff = -0.3592
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.9 seed=7869 salvo.
# Epoch 0 | Train Loss 1.052948 | data Loss 1.018464 |  physics Loss 1.087432 | Val Loss 0.971239
# Epoch 100 | Train Loss 0.579609 | data Loss 0.541513 |  physics Loss 0.617706 | Val Loss 0.674547
# Epoch 200 | Train Loss 0.494779 | data Loss 0.428216 |  physics Loss 0.561343 | Val Loss 0.615461
# Epoch 300 | Train Loss 0.452531 | data Loss 0.382111 |  physics Loss 0.522952 | Val Loss 0.625137
# Epoch 400 | Train Loss 0.399216 | data Loss 0.373332 |  physics Loss 0.425100 | Val Loss 0.643325
# Epoch 500 | Train Loss 0.379921 | data Loss 0.356548 |  physics Loss 0.403294 | Val Loss 0.670597
# Early stopping at epoch 502
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.5_Lp0.5_seed7621.keras
# theta | ZZx1 -> R² = 0.8486, R² diff = 0.6110
# theta | ZZx2 -> R² = -0.2948, R² diff = 0.4255
# theta | ZZxReto -> R² = 0.8542, R² diff = 0.5180
# theta | ZZy1 -> R² = -8.1472, R² diff = 0.2783
# theta | ZZy2 -> R² = -13.2047, R² diff = -0.1288
# theta | LSG-1 -> R² = 0.8115, R² diff = 0.5205
# theta | LSG-2 -> R² = -3.9618, R² diff = 0.2250
# theta | ZZx1-inv -> R² = 0.2947, R² diff = 0.1614
# theta | zzx2-inv2 -> R² = -7.6554, R² diff = -0.0942
# theta | semiCirc -> R² = -37.3966, R² diff = -0.3345
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.9 seed=7621 salvo.
# Epoch 0 | Train Loss 1.033006 | data Loss 0.991190 |  physics Loss 1.074823 | Val Loss 0.932080
# Epoch 100 | Train Loss 0.564590 | data Loss 0.481429 |  physics Loss 0.647752 | Val Loss 0.611374
# Epoch 200 | Train Loss 0.478846 | data Loss 0.426309 |  physics Loss 0.531383 | Val Loss 0.585264
# Epoch 300 | Train Loss 0.420303 | data Loss 0.397096 |  physics Loss 0.443510 | Val Loss 0.594535
# Epoch 400 | Train Loss 0.400106 | data Loss 0.386831 |  physics Loss 0.413381 | Val Loss 0.619028
# Early stopping at epoch 460
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.5_Lp0.5_seed8488.keras
# theta | ZZx1 -> R² = 0.4150, R² diff = 0.6125
# theta | ZZx2 -> R² = 0.8905, R² diff = 0.4087
# theta | ZZxReto -> R² = -0.3935, R² diff = 0.5315
# theta | ZZy1 -> R² = -21.5187, R² diff = 0.1931
# theta | ZZy2 -> R² = -16.4813, R² diff = -0.1475
# theta | LSG-1 -> R² = 0.6377, R² diff = 0.5538
# theta | LSG-2 -> R² = -2.7541, R² diff = 0.3036
# theta | ZZx1-inv -> R² = -2.1932, R² diff = 0.2727
# theta | zzx2-inv2 -> R² = -15.7725, R² diff = -0.0254
# theta | semiCirc -> R² = -28.7534, R² diff = -0.1872
# Modelo [94, 31, 10] | Ld=0.5 Lp=0.5 r=0.9 seed=8488 salvo.
# Epoch 0 | Train Loss 1.049155 | data Loss 1.000813 |  physics Loss 1.069874 | Val Loss 0.940753
# Epoch 100 | Train Loss 0.520112 | data Loss 0.687044 |  physics Loss 0.448570 | Val Loss 0.858911
# Epoch 200 | Train Loss 0.387636 | data Loss 0.627211 |  physics Loss 0.284961 | Val Loss 0.796496
# Early stopping at epoch 248
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.3_Lp0.7_seed7872.keras
# theta | ZZx1 -> R² = 0.5075, R² diff = 0.2934
# theta | ZZx2 -> R² = 0.8018, R² diff = 0.2265
# theta | ZZxReto -> R² = 0.0519, R² diff = 0.2417
# theta | ZZy1 -> R² = -4.5176, R² diff = 0.1629
# theta | ZZy2 -> R² = -13.1530, R² diff = 0.0426
# theta | LSG-1 -> R² = -4.0694, R² diff = 0.2727
# theta | LSG-2 -> R² = -1.4012, R² diff = 0.1936
# theta | ZZx1-inv -> R² = -1.2329, R² diff = 0.0678
# theta | zzx2-inv2 -> R² = -5.6505, R² diff = 0.0887
# theta | semiCirc -> R² = -6.8931, R² diff = 0.0604
# Modelo [94, 31, 10] | Ld=0.3 Lp=0.7 r=0.01 seed=7872 salvo.
# Epoch 0 | Train Loss 1.085078 | data Loss 1.049779 |  physics Loss 1.100206 | Val Loss 0.978405
# Epoch 100 | Train Loss 0.510735 | data Loss 0.676487 |  physics Loss 0.439699 | Val Loss 0.829971
# Epoch 200 | Train Loss 0.396466 | data Loss 0.619859 |  physics Loss 0.300727 | Val Loss 0.817253
# Early stopping at epoch 238
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.3_Lp0.7_seed2586.keras
# theta | ZZx1 -> R² = 0.5803, R² diff = 0.3744
# theta | ZZx2 -> R² = 0.6881, R² diff = 0.2543
# theta | ZZxReto -> R² = 0.1046, R² diff = 0.3222
# theta | ZZy1 -> R² = -5.5232, R² diff = 0.1778
# theta | ZZy2 -> R² = -14.7746, R² diff = 0.0485
# theta | LSG-1 -> R² = -5.5501, R² diff = 0.2632
# theta | LSG-2 -> R² = -1.6500, R² diff = 0.1658
# theta | ZZx1-inv -> R² = -1.5708, R² diff = 0.1102
# theta | zzx2-inv2 -> R² = -5.6359, R² diff = 0.1004
# theta | semiCirc -> R² = -4.9689, R² diff = -0.0140
# Modelo [94, 31, 10] | Ld=0.3 Lp=0.7 r=0.01 seed=2586 salvo.
# Epoch 0 | Train Loss 1.061023 | data Loss 1.014077 |  physics Loss 1.081143 | Val Loss 0.965783
# Epoch 100 | Train Loss 0.513810 | data Loss 0.648402 |  physics Loss 0.456128 | Val Loss 0.750688
# Epoch 200 | Train Loss 0.403490 | data Loss 0.609216 |  physics Loss 0.315322 | Val Loss 0.919858
# Early stopping at epoch 255
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.3_Lp0.7_seed7869.keras
# theta | ZZx1 -> R² = 0.4429, R² diff = 0.3898
# theta | ZZx2 -> R² = 0.8726, R² diff = 0.3027
# theta | ZZxReto -> R² = 0.4215, R² diff = 0.3500
# theta | ZZy1 -> R² = -9.3598, R² diff = 0.1647
# theta | ZZy2 -> R² = -13.8946, R² diff = 0.0994
# theta | LSG-1 -> R² = -2.9961, R² diff = 0.3643
# theta | LSG-2 -> R² = -1.9405, R² diff = 0.2371
# theta | ZZx1-inv -> R² = -1.8278, R² diff = 0.1828
# theta | zzx2-inv2 -> R² = -7.3449, R² diff = 0.1278
# theta | semiCirc -> R² = -9.0821, R² diff = 0.0774
# Modelo [94, 31, 10] | Ld=0.3 Lp=0.7 r=0.01 seed=7869 salvo.
# Epoch 0 | Train Loss 1.050069 | data Loss 1.001302 |  physics Loss 1.070969 | Val Loss 0.951399
# Epoch 100 | Train Loss 0.543918 | data Loss 0.695840 |  physics Loss 0.478809 | Val Loss 0.999616
# Epoch 200 | Train Loss 0.415185 | data Loss 0.646988 |  physics Loss 0.315841 | Val Loss 0.930521
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.3_Lp0.7_seed7621.keras
# theta | ZZx1 -> R² = 0.0528, R² diff = 0.1834
# theta | ZZx2 -> R² = 0.4105, R² diff = 0.1262
# theta | ZZxReto -> R² = -2.0573, R² diff = 0.1548
# theta | ZZy1 -> R² = 0.1805, R² diff = 0.1311
# ...
# Epoch 300 | Train Loss 0.340829 | data Loss 0.609744 |  physics Loss 0.225580 | Val Loss 0.690419
# Epoch 400 | Train Loss 0.355660 | data Loss 0.581833 |  physics Loss 0.258729 | Val Loss 0.679738
# Epoch 500 | Train Loss 0.321549 | data Loss 0.549936 |  physics Loss 0.223669 | Val Loss 0.956315
# Early stopping at epoch 522
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.3_Lp0.7_seed7872.keras
# theta | ZZx1 -> R² = 0.8268, R² diff = 0.4334
# theta | ZZx2 -> R² = 0.8229, R² diff = 0.3380
# theta | ZZxReto -> R² = -0.6520, R² diff = 0.2715
# theta | ZZy1 -> R² = -18.7908, R² diff = 0.1162
# theta | ZZy2 -> R² = -18.6236, R² diff = -0.2393
# theta | LSG-1 -> R² = -1.4149, R² diff = 0.4277
# theta | LSG-2 -> R² = -3.9134, R² diff = 0.1837
# theta | ZZx1-inv -> R² = -3.7994, R² diff = 0.0897
# theta | zzx2-inv2 -> R² = -28.3967, R² diff = -0.2352
# theta | semiCirc -> R² = -18.1944, R² diff = 0.0090
# Modelo [94, 31, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=7872 salvo.
# Epoch 0 | Train Loss 1.065161 | data Loss 1.013767 |  physics Loss 1.087187 | Val Loss 0.947125
# Epoch 100 | Train Loss 0.509414 | data Loss 0.682348 |  physics Loss 0.435300 | Val Loss 0.993429
# Epoch 200 | Train Loss 0.392737 | data Loss 0.625007 |  physics Loss 0.293193 | Val Loss 0.751100
# Epoch 300 | Train Loss 0.346483 | data Loss 0.619281 |  physics Loss 0.229569 | Val Loss 0.772088
# Epoch 400 | Train Loss 0.317076 | data Loss 0.601640 |  physics Loss 0.195119 | Val Loss 0.807083
# Early stopping at epoch 416
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.3_Lp0.7_seed2586.keras
# theta | ZZx1 -> R² = -0.1113, R² diff = 0.3753
# theta | ZZx2 -> R² = 0.3485, R² diff = 0.2907
# theta | ZZxReto -> R² = 0.1433, R² diff = 0.2199
# theta | ZZy1 -> R² = -11.8303, R² diff = 0.1732
# theta | ZZy2 -> R² = -19.4138, R² diff = -0.3340
# theta | LSG-1 -> R² = 0.4590, R² diff = 0.3288
# theta | LSG-2 -> R² = -1.9462, R² diff = 0.1835
# theta | ZZx1-inv -> R² = -0.2709, R² diff = 0.1432
# theta | zzx2-inv2 -> R² = -26.1815, R² diff = -0.2570
# theta | semiCirc -> R² = -17.7490, R² diff = -0.0361
# Modelo [94, 31, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=2586 salvo.
# Epoch 0 | Train Loss 1.057607 | data Loss 0.997601 |  physics Loss 1.083324 | Val Loss 0.897909
# Epoch 100 | Train Loss 0.583647 | data Loss 0.574324 |  physics Loss 0.587643 | Val Loss 0.873033
# Epoch 200 | Train Loss 0.477138 | data Loss 0.600549 |  physics Loss 0.424248 | Val Loss 1.130277
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.3_Lp0.7_seed7869.keras
# theta | ZZx1 -> R² = 0.0776, R² diff = 0.3792
# theta | ZZx2 -> R² = 0.6882, R² diff = 0.2763
# theta | ZZxReto -> R² = -0.2574, R² diff = 0.3342
# theta | ZZy1 -> R² = -4.0483, R² diff = 0.2036
# theta | ZZy2 -> R² = -12.6097, R² diff = 0.1502
# theta | LSG-1 -> R² = -6.6704, R² diff = 0.2864
# theta | LSG-2 -> R² = -1.6788, R² diff = 0.2029
# theta | ZZx1-inv -> R² = -2.3628, R² diff = 0.2077
# theta | zzx2-inv2 -> R² = -5.1150, R² diff = 0.1703
# theta | semiCirc -> R² = -3.4156, R² diff = 0.1330
# Modelo [94, 31, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=7869 salvo.
# Epoch 0 | Train Loss 1.057226 | data Loss 1.009914 |  physics Loss 1.077502 | Val Loss 0.961993
# Epoch 100 | Train Loss 0.547264 | data Loss 0.662766 |  physics Loss 0.497763 | Val Loss 0.739086
# Epoch 200 | Train Loss 0.442103 | data Loss 0.635751 |  physics Loss 0.359111 | Val Loss 0.770954
# Epoch 300 | Train Loss 0.390106 | data Loss 0.596478 |  physics Loss 0.301660 | Val Loss 0.806663
# Early stopping at epoch 318
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.3_Lp0.7_seed7621.keras
# theta | ZZx1 -> R² = 0.8381, R² diff = 0.3507
# theta | ZZx2 -> R² = 0.8065, R² diff = 0.2707
# theta | ZZxReto -> R² = 0.6898, R² diff = 0.2771
# theta | ZZy1 -> R² = -6.2616, R² diff = 0.1863
# theta | ZZy2 -> R² = -15.0215, R² diff = -0.1495
# theta | LSG-1 -> R² = -0.0035, R² diff = 0.3700
# theta | LSG-2 -> R² = -1.8920, R² diff = 0.2216
# theta | ZZx1-inv -> R² = -0.8812, R² diff = 0.0824
# theta | zzx2-inv2 -> R² = -5.8815, R² diff = 0.0024
# theta | semiCirc -> R² = -15.6029, R² diff = -0.1171
# Modelo [94, 31, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=7621 salvo.
# Epoch 0 | Train Loss 1.060086 | data Loss 1.011700 |  physics Loss 1.080823 | Val Loss 0.957462
# Epoch 100 | Train Loss 0.565406 | data Loss 0.703949 |  physics Loss 0.506030 | Val Loss 0.878779
# Epoch 200 | Train Loss 0.446152 | data Loss 0.635695 |  physics Loss 0.364919 | Val Loss 0.900398
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.3_Lp0.7_seed8488.keras
# theta | ZZx1 -> R² = 0.1067, R² diff = 0.2778
# theta | ZZx2 -> R² = 0.5360, R² diff = 0.1686
# theta | ZZxReto -> R² = -1.2317, R² diff = 0.2289
# theta | ZZy1 -> R² = -1.3710, R² diff = 0.1616
# theta | ZZy2 -> R² = -12.9145, R² diff = 0.0586
# theta | LSG-1 -> R² = -10.1349, R² diff = 0.1662
# theta | LSG-2 -> R² = -1.0983, R² diff = 0.1248
# theta | ZZx1-inv -> R² = -2.0537, R² diff = 0.0892
# theta | zzx2-inv2 -> R² = -4.1138, R² diff = 0.0812
# theta | semiCirc -> R² = -1.2135, R² diff = 0.0302
# Modelo [94, 31, 10] | Ld=0.3 Lp=0.7 r=0.9 seed=8488 salvo.
# Epoch 0 | Train Loss 1.018351 | data Loss 0.996389 |  physics Loss 1.069595 | Val Loss 0.922209
# Epoch 100 | Train Loss 0.508736 | data Loss 0.390834 |  physics Loss 0.783839 | Val Loss 0.566048
# Epoch 200 | Train Loss 0.393489 | data Loss 0.250670 |  physics Loss 0.726734 | Val Loss 0.578782
# Epoch 300 | Train Loss 0.352993 | data Loss 0.211100 |  physics Loss 0.684078 | Val Loss 0.573082
# Epoch 400 | Train Loss 0.339797 | data Loss 0.193431 |  physics Loss 0.681316 | Val Loss 0.555133
# Epoch 500 | Train Loss 0.333421 | data Loss 0.185988 |  physics Loss 0.677430 | Val Loss 0.598738
# Early stopping at epoch 518
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.7_Lp0.3_seed7872.keras
# theta | ZZx1 -> R² = 0.7564, R² diff = 0.7652
# theta | ZZx2 -> R² = 0.3303, R² diff = 0.4759
# theta | ZZxReto -> R² = 0.4561, R² diff = 0.6701
# theta | ZZy1 -> R² = -11.0314, R² diff = 0.3132
# theta | ZZy2 -> R² = -5.4291, R² diff = 0.1950
# theta | LSG-1 -> R² = 0.4829, R² diff = 0.5546
# theta | LSG-2 -> R² = -3.3010, R² diff = 0.2429
# theta | ZZx1-inv -> R² = 0.4796, R² diff = 0.4024
# theta | zzx2-inv2 -> R² = -9.9101, R² diff = 0.0783
# theta | semiCirc -> R² = -44.9584, R² diff = -0.5081
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=7872 salvo.
# Epoch 0 | Train Loss 1.023806 | data Loss 1.003553 |  physics Loss 1.071065 | Val Loss 0.928956
# Epoch 100 | Train Loss 0.456870 | data Loss 0.345161 |  physics Loss 0.717527 | Val Loss 0.588558
# Epoch 200 | Train Loss 0.374579 | data Loss 0.243958 |  physics Loss 0.679359 | Val Loss 0.616336
# Early stopping at epoch 298
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.7_Lp0.3_seed2586.keras
# theta | ZZx1 -> R² = 0.7352, R² diff = 0.6509
# theta | ZZx2 -> R² = 0.9630, R² diff = 0.4233
# theta | ZZxReto -> R² = 0.8611, R² diff = 0.5647
# theta | ZZy1 -> R² = -14.7522, R² diff = 0.2453
# theta | ZZy2 -> R² = -17.2022, R² diff = -0.0004
# theta | LSG-1 -> R² = 0.5313, R² diff = 0.5283
# theta | LSG-2 -> R² = -2.0940, R² diff = 0.3091
# theta | ZZx1-inv -> R² = -1.2826, R² diff = 0.3659
# theta | zzx2-inv2 -> R² = -12.0403, R² diff = 0.0379
# theta | semiCirc -> R² = -18.8786, R² diff = -0.0199
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=2586 salvo.
# Epoch 0 | Train Loss 1.040003 | data Loss 1.021129 |  physics Loss 1.084044 | Val Loss 0.958059
# Epoch 100 | Train Loss 0.481884 | data Loss 0.359522 |  physics Loss 0.767395 | Val Loss 0.601648
# Epoch 200 | Train Loss 0.372083 | data Loss 0.237790 |  physics Loss 0.685434 | Val Loss 0.615130
# Early stopping at epoch 292
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.7_Lp0.3_seed7869.keras
# theta | ZZx1 -> R² = 0.6052, R² diff = 0.6272
# theta | ZZx2 -> R² = 0.9555, R² diff = 0.4147
# theta | ZZxReto -> R² = 0.8282, R² diff = 0.5433
# theta | ZZy1 -> R² = -14.7426, R² diff = 0.2219
# theta | ZZy2 -> R² = -15.9407, R² diff = 0.0841
# theta | LSG-1 -> R² = 0.0658, R² diff = 0.5084
# theta | LSG-2 -> R² = -2.1249, R² diff = 0.3021
# theta | ZZx1-inv -> R² = -1.6088, R² diff = 0.3777
# theta | zzx2-inv2 -> R² = -11.1032, R² diff = 0.0967
# theta | semiCirc -> R² = -16.5381, R² diff = 0.0171
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=7869 salvo.
# Epoch 0 | Train Loss 1.026179 | data Loss 1.003751 |  physics Loss 1.078513 | Val Loss 0.956602
# Epoch 100 | Train Loss 0.520615 | data Loss 0.412980 |  physics Loss 0.771764 | Val Loss 0.601772
# Epoch 200 | Train Loss 0.418789 | data Loss 0.286508 |  physics Loss 0.727447 | Val Loss 0.584270
# Epoch 300 | Train Loss 0.360477 | data Loss 0.222694 |  physics Loss 0.681971 | Val Loss 0.628516
# Early stopping at epoch 364
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.7_Lp0.3_seed7621.keras
# theta | ZZx1 -> R² = 0.8070, R² diff = 0.6829
# theta | ZZx2 -> R² = 0.8947, R² diff = 0.4261
# theta | ZZxReto -> R² = 0.8407, R² diff = 0.5882
# theta | ZZy1 -> R² = -16.9591, R² diff = 0.2249
# theta | ZZy2 -> R² = -17.6285, R² diff = -0.0281
# theta | LSG-1 -> R² = 0.8164, R² diff = 0.5389
# theta | LSG-2 -> R² = -2.3937, R² diff = 0.2891
# theta | ZZx1-inv -> R² = -1.3145, R² diff = 0.3361
# theta | zzx2-inv2 -> R² = -11.9553, R² diff = -0.0076
# theta | semiCirc -> R² = -25.6152, R² diff = -0.1459
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=7621 salvo.
# Epoch 0 | Train Loss 1.021552 | data Loss 0.999168 |  physics Loss 1.073781 | Val Loss 0.942364
# Epoch 100 | Train Loss 0.511804 | data Loss 0.399268 |  physics Loss 0.774387 | Val Loss 0.606229
# Epoch 200 | Train Loss 0.403992 | data Loss 0.262363 |  physics Loss 0.734461 | Val Loss 0.599003
# Epoch 300 | Train Loss 0.349325 | data Loss 0.211754 |  physics Loss 0.670324 | Val Loss 0.605697
# Early stopping at epoch 366
# Modelo salvo em:
# models/model_arch94-31-10_r0.01_Ld0.7_Lp0.3_seed8488.keras
# theta | ZZx1 -> R² = 0.8392, R² diff = 0.6911
# theta | ZZx2 -> R² = 0.9204, R² diff = 0.4150
# theta | ZZxReto -> R² = 0.9094, R² diff = 0.6180
# theta | ZZy1 -> R² = -11.2973, R² diff = 0.2866
# theta | ZZy2 -> R² = -15.9485, R² diff = -0.0082
# theta | LSG-1 -> R² = 0.8931, R² diff = 0.5565
# theta | LSG-2 -> R² = -2.2543, R² diff = 0.3061
# theta | ZZx1-inv -> R² = -0.9857, R² diff = 0.3663
# theta | zzx2-inv2 -> R² = -12.4486, R² diff = -0.0089
# theta | semiCirc -> R² = -29.2545, R² diff = -0.2083
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.01 seed=8488 salvo.
# Epoch 0 | Train Loss 1.026623 | data Loss 1.005681 |  physics Loss 1.075490 | Val Loss 0.959134
# Epoch 100 | Train Loss 0.509465 | data Loss 0.443689 |  physics Loss 0.662943 | Val Loss 0.598492
# Epoch 200 | Train Loss 0.376081 | data Loss 0.249998 |  physics Loss 0.670277 | Val Loss 0.565723
# Epoch 300 | Train Loss 0.335150 | data Loss 0.205774 |  physics Loss 0.637027 | Val Loss 0.602842
# Epoch 400 | Train Loss 0.318145 | data Loss 0.192010 |  physics Loss 0.612461 | Val Loss 0.709757
# Early stopping at epoch 409
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.7_Lp0.3_seed7872.keras
# theta | ZZx1 -> R² = 0.8971, R² diff = 0.7486
# theta | ZZx2 -> R² = 0.8504, R² diff = 0.4378
# theta | ZZxReto -> R² = 0.8957, R² diff = 0.6712
# theta | ZZy1 -> R² = -19.3779, R² diff = 0.2605
# theta | ZZy2 -> R² = -17.9883, R² diff = -0.1143
# theta | LSG-1 -> R² = 0.7288, R² diff = 0.6018
# theta | LSG-2 -> R² = -2.4602, R² diff = 0.3459
# theta | ZZx1-inv -> R² = -1.5181, R² diff = 0.3829
# theta | zzx2-inv2 -> R² = -16.5766, R² diff = -0.1083
# theta | semiCirc -> R² = -35.5950, R² diff = -0.3260
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=7872 salvo.
# Epoch 0 | Train Loss 1.049811 | data Loss 1.032196 |  physics Loss 1.090912 | Val Loss 0.968132
# Epoch 100 | Train Loss 0.489900 | data Loss 0.399723 |  physics Loss 0.700312 | Val Loss 0.589064
# Epoch 200 | Train Loss 0.365668 | data Loss 0.240216 |  physics Loss 0.658389 | Val Loss 0.573632
# Epoch 300 | Train Loss 0.322843 | data Loss 0.189548 |  physics Loss 0.633863 | Val Loss 0.799485
# Early stopping at epoch 355
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.7_Lp0.3_seed2586.keras
# theta | ZZx1 -> R² = -0.0717, R² diff = 0.7063
# theta | ZZx2 -> R² = 0.8768, R² diff = 0.4412
# theta | ZZxReto -> R² = -0.1800, R² diff = 0.6339
# theta | ZZy1 -> R² = -10.5627, R² diff = 0.3052
# theta | ZZy2 -> R² = -15.5611, R² diff = -0.0318
# theta | LSG-1 -> R² = 0.4169, R² diff = 0.5558
# theta | LSG-2 -> R² = -2.7918, R² diff = 0.3063
# theta | ZZx1-inv -> R² = 0.2740, R² diff = 0.3824
# theta | zzx2-inv2 -> R² = -11.4314, R² diff = 0.0324
# theta | semiCirc -> R² = -32.4031, R² diff = -0.2992
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=2586 salvo.
# Epoch 0 | Train Loss 1.017500 | data Loss 0.994181 |  physics Loss 1.071910 | Val Loss 0.939466
# Epoch 100 | Train Loss 0.503184 | data Loss 0.385115 |  physics Loss 0.778677 | Val Loss 0.586655
# Epoch 200 | Train Loss 0.420314 | data Loss 0.284184 |  physics Loss 0.737952 | Val Loss 0.659741
# Epoch 300 | Train Loss 0.393018 | data Loss 0.267902 |  physics Loss 0.684956 | Val Loss 0.699856
# Early stopping at epoch 326
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.7_Lp0.3_seed7869.keras
# theta | ZZx1 -> R² = 0.7578, R² diff = 0.6627
# theta | ZZx2 -> R² = 0.9445, R² diff = 0.4095
# theta | ZZxReto -> R² = 0.8639, R² diff = 0.5624
# theta | ZZy1 -> R² = -23.7442, R² diff = 0.1239
# theta | ZZy2 -> R² = -17.1484, R² diff = -0.0135
# theta | LSG-1 -> R² = 0.6296, R² diff = 0.5215
# theta | LSG-2 -> R² = -2.2892, R² diff = 0.3025
# theta | ZZx1-inv -> R² = -1.4377, R² diff = 0.3199
# theta | zzx2-inv2 -> R² = -11.0379, R² diff = 0.0074
# theta | semiCirc -> R² = -22.6622, R² diff = -0.0968
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=7869 salvo.
# Epoch 0 | Train Loss 1.016976 | data Loss 0.995400 |  physics Loss 1.067320 | Val Loss 0.943506
# Epoch 100 | Train Loss 0.510197 | data Loss 0.408925 |  physics Loss 0.746499 | Val Loss 0.597289
# Epoch 200 | Train Loss 0.397858 | data Loss 0.266731 |  physics Loss 0.703821 | Val Loss 0.598491
# Epoch 300 | Train Loss 0.350346 | data Loss 0.221514 |  physics Loss 0.650953 | Val Loss 0.593052
# Epoch 400 | Train Loss 0.338942 | data Loss 0.227301 |  physics Loss 0.599440 | Val Loss 0.644976
# Early stopping at epoch 494
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.7_Lp0.3_seed7621.keras
# theta | ZZx1 -> R² = 0.7716, R² diff = 0.7707
# theta | ZZx2 -> R² = 0.5057, R² diff = 0.4077
# theta | ZZxReto -> R² = 0.4191, R² diff = 0.6413
# theta | ZZy1 -> R² = -20.5759, R² diff = 0.2142
# theta | ZZy2 -> R² = -21.8856, R² diff = -0.3135
# theta | LSG-1 -> R² = -0.7029, R² diff = 0.6108
# theta | LSG-2 -> R² = -2.5195, R² diff = 0.3347
# theta | ZZx1-inv -> R² = -0.8767, R² diff = 0.3520
# theta | zzx2-inv2 -> R² = -18.3812, R² diff = -0.2852
# theta | semiCirc -> R² = -44.3567, R² diff = -0.5057
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=7621 salvo.
# Epoch 0 | Train Loss 1.020916 | data Loss 0.997817 |  physics Loss 1.074812 | Val Loss 0.941777
# Epoch 100 | Train Loss 0.518123 | data Loss 0.401739 |  physics Loss 0.789687 | Val Loss 0.593420
# Epoch 200 | Train Loss 0.399499 | data Loss 0.263626 |  physics Loss 0.716538 | Val Loss 0.548059
# Epoch 300 | Train Loss 0.342368 | data Loss 0.217367 |  physics Loss 0.634038 | Val Loss 0.609019
# Early stopping at epoch 392
# Modelo salvo em:
# models/model_arch94-31-10_r0.9_Ld0.7_Lp0.3_seed8488.keras
# theta | ZZx1 -> R² = 0.8720, R² diff = 0.7352
# theta | ZZx2 -> R² = 0.9693, R² diff = 0.4491
# theta | ZZxReto -> R² = 0.5565, R² diff = 0.6516
# theta | ZZy1 -> R² = -11.7925, R² diff = 0.3370
# theta | ZZy2 -> R² = -16.5720, R² diff = -0.0190
# theta | LSG-1 -> R² = 0.8696, R² diff = 0.5835
# theta | LSG-2 -> R² = -3.1462, R² diff = 0.2931
# theta | ZZx1-inv -> R² = -1.1385, R² diff = 0.4027
# theta | zzx2-inv2 -> R² = -16.5966, R² diff = 0.0198
# theta | semiCirc -> R² = -30.4621, R² diff = -0.2189
# Modelo [94, 31, 10] | Ld=0.7 Lp=0.3 r=0.9 seed=8488 salvo.
# Epoch 0 | Train Loss 1.054425 | data Loss 1.021441 |  physics Loss 1.087408 | Val Loss 0.947376
# Epoch 100 | Train Loss 0.549557 | data Loss 0.458089 |  physics Loss 0.641025 | Val Loss 0.669014
# Epoch 200 | Train Loss 0.484307 | data Loss 0.412482 |  physics Loss 0.556132 | Val Loss 0.861473
