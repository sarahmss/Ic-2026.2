# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = [
    "ZZx1",  # Train
    "ZZx2",  # Val
    "ZZxReto", # Test
    "ZZy1", # Test
    "ZZy2", # Test
    "LSG-1", # Test
    "LSG-2", # Test
    "ZZx1-inv", # Test
    "zzx2-inv2", # Test
    "semiCirc", # Test
]

PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a"]   
TARGET_INT = ["theta"]  
TARGET = ["dtheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 12
TS = 0.07
PLOT = False
# Out:
# /Users/cyberxoke/Documents/Sarah/Ic-2026.2/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
Datasets = []
for title in TITLES:
    df = pd.read_excel("./../../00-Data/SavgolDatasets.xlsx", sheet_name=title)
    Datasets.append(df)

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["Se_a"] = Dataset["e_a_d"] + Dataset["e_a_e"]
    Dataset["De_a"] = Dataset["e_a_d"] - Dataset["e_a_e"]

    Dataset = Dataset.dropna(subset=[f"d{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train = Train1

# Train2 = Datasets[1].copy()
# Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
# Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
# NormDatasets.append(Train2)

# # concatena
# Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(9):
    CurrentTestDataset = Datasets[i + 1].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = NormDatasets[1]

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1024, 12, 4)
# Dimensão da saida: (1024, 1)
# Dimensão da entrada: (1382, 12, 4)
# Dimensão da saida: (1382, 1)

# %%
phi_d_train =  Train["phi_d"].values[:len(x_train)]
phi_e_train =  Train["phi_e"].values[:len(x_train)]
theta_train = Train["theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(phi_d_train)}")
print(f"Dimensão da entrada fisica: {np.shape(phi_e_train)}")
# Out:
# Dimensão da entrada: (1024, 12, 4)
# Dimensão da saida: (1024, 1)
# Dimensão da entrada fisica : (1024,)
# Dimensão da entrada fisica: (1024,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):

    dtheta_cin = (R / (2 * L)) * (phi_d - phi_e)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(dq).T, np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, phi_d, phi_e, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(phi_d, phi_e, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss, data_loss, physics_loss

# %%
phi_d_train = tf.convert_to_tensor(phi_d_train, dtype=tf.float32)
phi_e_train = tf.convert_to_tensor(phi_e_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss, data_loss, physics_loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          phi_d_train, phi_e_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | data Loss {data_loss.numpy():.6f} |  physics Loss {physics_loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            R2diff = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_r2diff = f"R2diff_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_r2diff, []).append(R2diff)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {R2diff:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"R2diff_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2diff_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    #os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    #weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    #model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}")

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import initializers
from itertools import product
import numpy as np
import tensorflow as tf

N_MODELS = 5

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

#architectures = [[n] for n in range(1, 101)]

FirstLayers = [
     [94, 31],
[94, 41],
[94, 52],
]

architectures = [
    [fl, sl, tl]
    for fl, sl in FirstLayers
    for tl in range(
         max(1, int(0.3 * sl)),
         int(0.7 * sl)
     )
 ]


# 🔹 retomar a partir do último modelo salvo
last_saved = [94, 52, 17]
 
if last_saved in architectures:
    idx = architectures.index(last_saved)
    architectures = architectures[idx + 1:]  # começa DEPOIS do último salvo
    print(f"Retomando a partir de {last_saved} (índice {idx}). Restam {len(architectures)} arquiteturas.")
else:
    print(f"⚠️ {last_saved} não encontrado na lista — rodando tudo do zero.")

print(len(architectures))
print(architectures)

Ld_Lp = [[0.5, 0.5], [0.3, 0.7], [0.7, 0.3]]
r_values = [0.01, 0.9]

results = {}

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados-3l.xlsx")
# Out:
# Retomando a partir de [94, 52, 17] (índice 30). Restam 18 arquiteturas.
# 18
# [[94, 52, 18], [94, 52, 19], [94, 52, 20], [94, 52, 21], [94, 52, 22], [94, 52, 23], [94, 52, 24], [94, 52, 25], [94, 52, 26], [94, 52, 27], [94, 52, 28], [94, 52, 29], [94, 52, 30], [94, 52, 31], [94, 52, 32], [94, 52, 33], [94, 52, 34], [94, 52, 35]]
# Epoch 0 | Train Loss 1.051211 | data Loss 1.018686 |  physics Loss 1.083735 | Val Loss 0.941029
# Epoch 100 | Train Loss 0.455853 | data Loss 0.421958 |  physics Loss 0.489748 | Val Loss 0.603687
# Epoch 200 | Train Loss 0.383415 | data Loss 0.351618 |  physics Loss 0.415212 | Val Loss 0.629546
# Epoch 300 | Train Loss 0.423081 | data Loss 0.414225 |  physics Loss 0.431937 | Val Loss 0.580329
# Epoch 400 | Train Loss 0.354217 | data Loss 0.347733 |  physics Loss 0.360700 | Val Loss 0.633055
# Early stopping at epoch 497
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.5_Lp0.5_seed6262.keras
# theta | ZZx1 -> R² = 0.7449, R² diff = 0.6243
# theta | ZZx2 -> R² = 0.5742, R² diff = 0.4493
# theta | ZZxReto -> R² = 0.8970, R² diff = 0.5143
# theta | ZZy1 -> R² = -10.1391, R² diff = 0.2440
# theta | ZZy2 -> R² = -7.5196, R² diff = -0.0909
# theta | LSG-1 -> R² = 0.5221, R² diff = 0.4953
# theta | LSG-2 -> R² = -4.5292, R² diff = 0.2872
# theta | ZZx1-inv -> R² = 0.4128, R² diff = 0.2671
# theta | zzx2-inv2 -> R² = -9.8359, R² diff = -0.0867
# theta | semiCirc -> R² = -41.8920, R² diff = -0.4478
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.01 seed=6262 salvo.
# Epoch 0 | Train Loss 1.070788 | data Loss 1.044983 |  physics Loss 1.096593 | Val Loss 0.893462
# Epoch 100 | Train Loss 0.496671 | data Loss 0.429561 |  physics Loss 0.563780 | Val Loss 0.606490
# Epoch 200 | Train Loss 0.392834 | data Loss 0.354650 |  physics Loss 0.431019 | Val Loss 0.581673
# Epoch 300 | Train Loss 0.363966 | data Loss 0.344777 |  physics Loss 0.383154 | Val Loss 0.612806
# Early stopping at epoch 388
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.5_Lp0.5_seed1241.keras
# theta | ZZx1 -> R² = 0.9360, R² diff = 0.6452
# theta | ZZx2 -> R² = 0.7893, R² diff = 0.4163
# theta | ZZxReto -> R² = 0.9483, R² diff = 0.5280
# theta | ZZy1 -> R² = -18.3413, R² diff = 0.1974
# theta | ZZy2 -> R² = -12.7564, R² diff = -0.0947
# theta | LSG-1 -> R² = 0.8023, R² diff = 0.5454
# theta | LSG-2 -> R² = -2.6726, R² diff = 0.2685
# theta | ZZx1-inv -> R² = -0.9306, R² diff = 0.2989
# theta | zzx2-inv2 -> R² = -14.4753, R² diff = -0.0060
# theta | semiCirc -> R² = -33.8826, R² diff = -0.2467
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.01 seed=1241 salvo.
# Epoch 0 | Train Loss 1.035744 | data Loss 1.001945 |  physics Loss 1.069542 | Val Loss 0.892803
# Epoch 100 | Train Loss 0.420703 | data Loss 0.366810 |  physics Loss 0.474596 | Val Loss 0.591845
# Epoch 200 | Train Loss 0.364969 | data Loss 0.345221 |  physics Loss 0.384717 | Val Loss 0.801296
# Early stopping at epoch 289
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.5_Lp0.5_seed913.keras
# theta | ZZx1 -> R² = 0.7257, R² diff = 0.6306
# theta | ZZx2 -> R² = 0.9187, R² diff = 0.4054
# theta | ZZxReto -> R² = 0.7084, R² diff = 0.5677
# theta | ZZy1 -> R² = -21.8242, R² diff = 0.2048
# theta | ZZy2 -> R² = -16.2150, R² diff = -0.1268
# theta | LSG-1 -> R² = 0.8547, R² diff = 0.5410
# theta | LSG-2 -> R² = -2.4436, R² diff = 0.2939
# theta | ZZx1-inv -> R² = -1.7469, R² diff = 0.2964
# theta | zzx2-inv2 -> R² = -18.0087, R² diff = -0.0934
# theta | semiCirc -> R² = -34.5703, R² diff = -0.3039
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.01 seed=913 salvo.
# Epoch 0 | Train Loss 1.053638 | data Loss 1.020866 |  physics Loss 1.086410 | Val Loss 0.904759
# Epoch 100 | Train Loss 0.459149 | data Loss 0.389026 |  physics Loss 0.529271 | Val Loss 0.704093
# Epoch 200 | Train Loss 0.393337 | data Loss 0.364933 |  physics Loss 0.421741 | Val Loss 0.751760
# Early stopping at epoch 246
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.5_Lp0.5_seed1842.keras
# theta | ZZx1 -> R² = 0.8228, R² diff = 0.5129
# theta | ZZx2 -> R² = 0.9671, R² diff = 0.3737
# theta | ZZxReto -> R² = 0.9057, R² diff = 0.4781
# theta | ZZy1 -> R² = -8.3305, R² diff = 0.2566
# theta | ZZy2 -> R² = -11.2843, R² diff = 0.0401
# theta | LSG-1 -> R² = 0.4464, R² diff = 0.4624
# theta | LSG-2 -> R² = -1.3492, R² diff = 0.3110
# theta | ZZx1-inv -> R² = -0.3474, R² diff = 0.2851
# theta | zzx2-inv2 -> R² = -7.4495, R² diff = 0.0804
# theta | semiCirc -> R² = -18.6197, R² diff = -0.0680
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.01 seed=1842 salvo.
# Epoch 0 | Train Loss 1.056921 | data Loss 1.020631 |  physics Loss 1.093211 | Val Loss 0.911086
# Epoch 100 | Train Loss 0.486728 | data Loss 0.420972 |  physics Loss 0.552485 | Val Loss 0.647112
# Epoch 200 | Train Loss 0.413327 | data Loss 0.350619 |  physics Loss 0.476035 | Val Loss 0.606270
# Early stopping at epoch 278
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.5_Lp0.5_seed1629.keras
# theta | ZZx1 -> R² = 0.8699, R² diff = 0.5759
# theta | ZZx2 -> R² = 0.9292, R² diff = 0.4008
# theta | ZZxReto -> R² = 0.8865, R² diff = 0.5229
# theta | ZZy1 -> R² = -12.3616, R² diff = 0.2338
# theta | ZZy2 -> R² = -11.6471, R² diff = 0.0179
# theta | LSG-1 -> R² = 0.8734, R² diff = 0.5209
# theta | LSG-2 -> R² = -1.6480, R² diff = 0.3366
# theta | ZZx1-inv -> R² = -1.1400, R² diff = 0.3475
# theta | zzx2-inv2 -> R² = -11.6100, R² diff = 0.0313
# theta | semiCirc -> R² = -28.9383, R² diff = -0.2165
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.01 seed=1629 salvo.
# Epoch 0 | Train Loss 1.084220 | data Loss 1.061216 |  physics Loss 1.107224 | Val Loss 0.939340
# Epoch 100 | Train Loss 0.515513 | data Loss 0.428629 |  physics Loss 0.602397 | Val Loss 0.647009
# Epoch 200 | Train Loss 0.424958 | data Loss 0.389200 |  physics Loss 0.460715 | Val Loss 0.599501
# Epoch 300 | Train Loss 0.368643 | data Loss 0.347265 |  physics Loss 0.390021 | Val Loss 0.606281
# Epoch 400 | Train Loss 0.360203 | data Loss 0.330392 |  physics Loss 0.390015 | Val Loss 0.624101
# Early stopping at epoch 477
# Modelo salvo em:
# models/model_arch94-52-18_r0.9_Ld0.5_Lp0.5_seed6262.keras
# theta | ZZx1 -> R² = 0.9318, R² diff = 0.6725
# theta | ZZx2 -> R² = 0.2903, R² diff = 0.4171
# theta | ZZxReto -> R² = 0.8979, R² diff = 0.5754
# theta | ZZy1 -> R² = -16.4667, R² diff = 0.2413
# theta | ZZy2 -> R² = -7.8608, R² diff = 0.0605
# theta | LSG-1 -> R² = 0.1568, R² diff = 0.5802
# theta | LSG-2 -> R² = -2.6370, R² diff = 0.2440
# theta | ZZx1-inv -> R² = 0.2424, R² diff = 0.2536
# theta | zzx2-inv2 -> R² = -12.1733, R² diff = -0.0952
# theta | semiCirc -> R² = -54.1185, R² diff = -0.7186
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.9 seed=6262 salvo.
# Epoch 0 | Train Loss 1.062336 | data Loss 1.032755 |  physics Loss 1.091918 | Val Loss 0.925074
# Epoch 100 | Train Loss 0.436614 | data Loss 0.392316 |  physics Loss 0.480913 | Val Loss 0.600188
# Epoch 200 | Train Loss 0.374179 | data Loss 0.355927 |  physics Loss 0.392431 | Val Loss 0.599474
# Epoch 300 | Train Loss 0.381193 | data Loss 0.354581 |  physics Loss 0.407805 | Val Loss 0.643795
# Epoch 400 | Train Loss 0.351106 | data Loss 0.342925 |  physics Loss 0.359288 | Val Loss 0.696274
# Early stopping at epoch 420
# Modelo salvo em:
# models/model_arch94-52-18_r0.9_Ld0.5_Lp0.5_seed1241.keras
# theta | ZZx1 -> R² = 0.8965, R² diff = 0.6245
# theta | ZZx2 -> R² = 0.6236, R² diff = 0.4473
# theta | ZZxReto -> R² = 0.9317, R² diff = 0.5467
# theta | ZZy1 -> R² = -23.2343, R² diff = 0.1560
# theta | ZZy2 -> R² = -10.9433, R² diff = -0.0051
# theta | LSG-1 -> R² = 0.4630, R² diff = 0.5719
# theta | LSG-2 -> R² = -1.3326, R² diff = 0.3490
# theta | ZZx1-inv -> R² = -0.9469, R² diff = 0.3300
# theta | zzx2-inv2 -> R² = -17.6587, R² diff = -0.1138
# theta | semiCirc -> R² = -34.6066, R² diff = -0.2646
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.9 seed=1241 salvo.
# Epoch 0 | Train Loss 1.041431 | data Loss 1.002779 |  physics Loss 1.080083 | Val Loss 0.912261
# Epoch 100 | Train Loss 0.444882 | data Loss 0.397207 |  physics Loss 0.492557 | Val Loss 0.601516
# Epoch 200 | Train Loss 0.382058 | data Loss 0.339376 |  physics Loss 0.424739 | Val Loss 0.663470
# Epoch 300 | Train Loss 0.361508 | data Loss 0.344675 |  physics Loss 0.378341 | Val Loss 0.733903
# Early stopping at epoch 338
# Modelo salvo em:
# models/model_arch94-52-18_r0.9_Ld0.5_Lp0.5_seed913.keras
# theta | ZZx1 -> R² = 0.9278, R² diff = 0.6332
# theta | ZZx2 -> R² = 0.8141, R² diff = 0.3984
# theta | ZZxReto -> R² = 0.8486, R² diff = 0.5460
# theta | ZZy1 -> R² = -18.1308, R² diff = 0.2236
# theta | ZZy2 -> R² = -11.3244, R² diff = -0.0660
# theta | LSG-1 -> R² = 0.5755, R² diff = 0.5783
# theta | LSG-2 -> R² = -1.3291, R² diff = 0.3921
# theta | ZZx1-inv -> R² = -1.3883, R² diff = 0.3919
# theta | zzx2-inv2 -> R² = -15.1351, R² diff = -0.0233
# theta | semiCirc -> R² = -37.5376, R² diff = -0.3768
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.9 seed=913 salvo.
# Epoch 0 | Train Loss 0.992717 | data Loss 0.948457 |  physics Loss 1.036978 | Val Loss 0.831257
# Epoch 100 | Train Loss 0.436575 | data Loss 0.384063 |  physics Loss 0.489087 | Val Loss 0.619853
# Epoch 200 | Train Loss 0.382337 | data Loss 0.360591 |  physics Loss 0.404082 | Val Loss 0.568517
# Epoch 300 | Train Loss 0.361922 | data Loss 0.336701 |  physics Loss 0.387144 | Val Loss 0.584348
# Epoch 400 | Train Loss 0.360008 | data Loss 0.334450 |  physics Loss 0.385567 | Val Loss 0.621769
# Early stopping at epoch 453
# Modelo salvo em:
# models/model_arch94-52-18_r0.9_Ld0.5_Lp0.5_seed1842.keras
# theta | ZZx1 -> R² = 0.9313, R² diff = 0.6687
# theta | ZZx2 -> R² = 0.0678, R² diff = 0.4310
# theta | ZZxReto -> R² = 0.7811, R² diff = 0.5476
# theta | ZZy1 -> R² = -19.8409, R² diff = 0.2197
# theta | ZZy2 -> R² = -6.4372, R² diff = -0.0547
# theta | LSG-1 -> R² = 0.6626, R² diff = 0.5657
# theta | LSG-2 -> R² = -1.6709, R² diff = 0.3370
# theta | ZZx1-inv -> R² = 0.1259, R² diff = 0.3661
# theta | zzx2-inv2 -> R² = -9.9940, R² diff = -0.0220
# theta | semiCirc -> R² = -40.4505, R² diff = -0.4095
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.9 seed=1842 salvo.
# Epoch 0 | Train Loss 1.040177 | data Loss 1.008957 |  physics Loss 1.071398 | Val Loss 0.913999
# Epoch 100 | Train Loss 0.472864 | data Loss 0.420399 |  physics Loss 0.525330 | Val Loss 0.644004
# Epoch 200 | Train Loss 0.384278 | data Loss 0.357320 |  physics Loss 0.411236 | Val Loss 0.657448
# Early stopping at epoch 282
# Modelo salvo em:
# models/model_arch94-52-18_r0.9_Ld0.5_Lp0.5_seed1629.keras
# theta | ZZx1 -> R² = 0.8334, R² diff = 0.5490
# theta | ZZx2 -> R² = 0.9589, R² diff = 0.3869
# theta | ZZxReto -> R² = 0.8950, R² diff = 0.4930
# theta | ZZy1 -> R² = -13.2479, R² diff = 0.2167
# theta | ZZy2 -> R² = -13.8661, R² diff = -0.0594
# theta | LSG-1 -> R² = 0.8892, R² diff = 0.5061
# theta | LSG-2 -> R² = -1.8149, R² diff = 0.3170
# theta | ZZx1-inv -> R² = -1.6438, R² diff = 0.2968
# theta | zzx2-inv2 -> R² = -12.4492, R² diff = -0.0426
# theta | semiCirc -> R² = -28.2081, R² diff = -0.2069
# Modelo [94, 52, 18] | Ld=0.5 Lp=0.5 r=0.9 seed=1629 salvo.
# Epoch 0 | Train Loss 1.072256 | data Loss 1.030432 |  physics Loss 1.090180 | Val Loss 0.942387
# Epoch 100 | Train Loss 0.445419 | data Loss 0.618220 |  physics Loss 0.371362 | Val Loss 0.804783
# Epoch 200 | Train Loss 0.364529 | data Loss 0.617535 |  physics Loss 0.256098 | Val Loss 0.953219
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.3_Lp0.7_seed6262.keras
# theta | ZZx1 -> R² = 0.5211, R² diff = 0.3906
# theta | ZZx2 -> R² = 0.8423, R² diff = 0.2904
# theta | ZZxReto -> R² = 0.2077, R² diff = 0.3502
# theta | ZZy1 -> R² = -8.5568, R² diff = 0.1743
# theta | ZZy2 -> R² = -14.7933, R² diff = 0.0832
# theta | LSG-1 -> R² = -4.1479, R² diff = 0.3299
# theta | LSG-2 -> R² = -1.6796, R² diff = 0.2199
# theta | ZZx1-inv -> R² = -2.0082, R² diff = 0.1611
# theta | zzx2-inv2 -> R² = -6.9076, R² diff = 0.1283
# theta | semiCirc -> R² = -7.5336, R² diff = 0.0608
# Modelo [94, 52, 18] | Ld=0.3 Lp=0.7 r=0.01 seed=6262 salvo.
# Epoch 0 | Train Loss 1.080919 | data Loss 1.035013 |  physics Loss 1.100593 | Val Loss 0.926107
# Epoch 100 | Train Loss 0.463111 | data Loss 0.669162 |  physics Loss 0.374804 | Val Loss 0.910470
# Epoch 200 | Train Loss 0.378721 | data Loss 0.661762 |  physics Loss 0.257417 | Val Loss 1.011598
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.3_Lp0.7_seed1241.keras
# theta | ZZx1 -> R² = 0.7173, R² diff = 0.4447
# theta | ZZx2 -> R² = 0.9004, R² diff = 0.3127
# theta | ZZxReto -> R² = 0.7029, R² diff = 0.4033
# theta | ZZy1 -> R² = -10.9402, R² diff = 0.1755
# theta | ZZy2 -> R² = -16.6253, R² diff = -0.0010
# theta | LSG-1 -> R² = -1.6406, R² diff = 0.3841
# theta | LSG-2 -> R² = -2.4467, R² diff = 0.1990
# theta | ZZx1-inv -> R² = -1.2476, R² diff = 0.1363
# theta | zzx2-inv2 -> R² = -8.1103, R² diff = 0.0585
# theta | semiCirc -> R² = -13.3749, R² diff = -0.0490
# Modelo [94, 52, 18] | Ld=0.3 Lp=0.7 r=0.01 seed=1241 salvo.
# Epoch 0 | Train Loss 1.046035 | data Loss 0.993286 |  physics Loss 1.068642 | Val Loss 0.914408
# Epoch 100 | Train Loss 0.451036 | data Loss 0.682568 |  physics Loss 0.351808 | Val Loss 0.798428
# Epoch 200 | Train Loss 0.351167 | data Loss 0.635816 |  physics Loss 0.229174 | Val Loss 0.778623
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.3_Lp0.7_seed913.keras
# theta | ZZx1 -> R² = 0.6479, R² diff = 0.3958
# theta | ZZx2 -> R² = 0.7796, R² diff = 0.2884
# theta | ZZxReto -> R² = 0.6215, R² diff = 0.3604
# theta | ZZy1 -> R² = -5.5440, R² diff = 0.2076
# theta | ZZy2 -> R² = -13.8713, R² diff = 0.0669
# theta | LSG-1 -> R² = -2.8493, R² diff = 0.3284
# theta | LSG-2 -> R² = -1.7571, R² diff = 0.1975
# theta | ZZx1-inv -> R² = -0.9475, R² diff = 0.1566
# theta | zzx2-inv2 -> R² = -5.6600, R² diff = 0.1001
# theta | semiCirc -> R² = -7.8995, R² diff = 0.0304
# Modelo [94, 52, 18] | Ld=0.3 Lp=0.7 r=0.01 seed=913 salvo.
# Epoch 0 | Train Loss 1.056353 | data Loss 0.998377 |  physics Loss 1.081199 | Val Loss 0.878294
# Epoch 100 | Train Loss 0.473877 | data Loss 0.598201 |  physics Loss 0.420595 | Val Loss 0.972439
# Epoch 200 | Train Loss 0.360561 | data Loss 0.569884 |  physics Loss 0.270852 | Val Loss 0.809947
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.3_Lp0.7_seed1842.keras
# theta | ZZx1 -> R² = 0.3022, R² diff = 0.4868
# theta | ZZx2 -> R² = 0.9354, R² diff = 0.3516
# theta | ZZxReto -> R² = 0.7166, R² diff = 0.4241
# theta | ZZy1 -> R² = -12.7221, R² diff = 0.1675
# theta | ZZy2 -> R² = -12.9358, R² diff = 0.1229
# theta | LSG-1 -> R² = -1.1938, R² diff = 0.4293
# theta | LSG-2 -> R² = -2.3323, R² diff = 0.3001
# theta | ZZx1-inv -> R² = -2.0265, R² diff = 0.3201
# theta | zzx2-inv2 -> R² = -8.0858, R² diff = 0.1402
# theta | semiCirc -> R² = -10.8855, R² diff = 0.1038
# Modelo [94, 52, 18] | Ld=0.3 Lp=0.7 r=0.01 seed=1842 salvo.
# Epoch 0 | Train Loss 1.053951 | data Loss 1.008697 |  physics Loss 1.073346 | Val Loss 0.911031
# Epoch 100 | Train Loss 0.473605 | data Loss 0.657750 |  physics Loss 0.394685 | Val Loss 0.935731
# Epoch 200 | Train Loss 0.390852 | data Loss 0.637405 |  physics Loss 0.285186 | Val Loss 1.021681
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch94-52-18_r0.01_Ld0.3_Lp0.7_seed1629.keras
# theta | ZZx1 -> R² = 0.2787, R² diff = 0.3697
# theta | ZZx2 -> R² = 0.5279, R² diff = 0.2418
# theta | ZZxReto -> R² = -0.0901, R² diff = 0.3148
# theta | ZZy1 -> R² = -3.3584, R² diff = 0.2084
# theta | ZZy2 -> R² = -12.7320, R² diff = 0.1119
# theta | LSG-1 -> R² = -4.7617, R² diff = 0.3062
# theta | LSG-2 -> R² = -1.3884, R² diff = 0.2112
# theta | ZZx1-inv -> R² = -1.2331, R² diff = 0.1805
# theta | zzx2-inv2 -> R² = -4.5778, R² diff = 0.1367
# theta | semiCirc -> R² = -4.7600, R² diff = 0.1148
# Modelo [94, 52, 18] | Ld=0.3 Lp=0.7 r=0.01 seed=1629 salvo.
# Epoch 0 | Train Loss 1.050627 | data Loss 0.992637 |  physics Loss 1.075479 | Val Loss 0.903292
# Epoch 100 | Train Loss 0.423119 | data Loss 0.626141 |  physics Loss 0.336109 | Val Loss 0.936395
# Epoch 200 | Train Loss 0.341473 | data Loss 0.614308 |  physics Loss 0.224544 | Val Loss 1.015470
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch94-52-18_r0.9_Ld0.3_Lp0.7_seed6262.keras
# theta | ZZx1 -> R² = 0.0099, R² diff = 0.3417
# theta | ZZx2 -> R² = 0.6784, R² diff = 0.2311
# theta | ZZxReto -> R² = -1.8348, R² diff = 0.2847
# theta | ZZy1 -> R² = -4.3973, R² diff = 0.1842
# theta | ZZy2 -> R² = -13.9858, R² diff = 0.0944
# theta | LSG-1 -> R² = -8.4045, R² diff = 0.2357
# theta | LSG-2 -> R² = -1.3501, R² diff = 0.1608
# theta | ZZx1-inv -> R² = -1.9970, R² diff = 0.1199
# theta | zzx2-inv2 -> R² = -5.1147, R² diff = 0.1177
# theta | semiCirc -> R² = -2.8384, R² diff = 0.0908
# Modelo [94, 52, 18] | Ld=0.3 Lp=0.7 r=0.9 seed=6262 salvo.
# Epoch 0 | Train Loss 1.068581 | data Loss 1.023953 |  physics Loss 1.087707 | Val Loss 0.960021
# Epoch 100 | Train Loss 0.443683 | data Loss 0.667856 |  physics Loss 0.347610 | Val Loss 0.845617
# Epoch 200 | Train Loss 0.352171 | data Loss 0.649584 |  physics Loss 0.224708 | Val Loss 0.755478
# Epoch 300 | Train Loss 0.334229 | data Loss 0.638528 |  physics Loss 0.203816 | Val Loss 0.732984
# Epoch 400 | Train Loss 0.302363 | data Loss 0.611396 |  physics Loss 0.169920 | Val Loss 0.821439
# Early stopping at epoch 450
# Modelo salvo em:
# models/model_arch94-52-18_r0.9_Ld0.3_Lp0.7_seed1241.keras
# theta | ZZx1 -> R² = 0.9188, R² diff = 0.3651
# theta | ZZx2 -> R² = 0.9371, R² diff = 0.2836
# theta | ZZxReto -> R² = 0.7189, R² diff = 0.1541
# theta | ZZy1 -> R² = -29.0094, R² diff = -0.0293
# theta | ZZy2 -> R² = -16.2647, R² diff = -0.3239
# theta | LSG-1 -> R² = 0.6216, R² diff = 0.4356
# theta | LSG-2 -> R² = -1.6669, R² diff = 0.2552
# theta | ZZx1-inv -> R² = -2.4450, R² diff = 0.0449
# theta | zzx2-inv2 -> R² = -21.8801, R² diff = -0.2550
# theta | semiCirc -> R² = -23.0261, R² diff = -0.0471
# Modelo [94, 52, 18] | Ld=0.3 Lp=0.7 r=0.9 seed=1241 salvo.
# Epoch 0 | Train Loss 1.043642 | data Loss 0.986914 |  physics Loss 1.067954 | Val Loss 0.887279
# Epoch 100 | Train Loss 0.473589 | data Loss 0.621483 |  physics Loss 0.410206 | Val Loss 0.781968
# Epoch 200 | Train Loss 0.367436 | data Loss 0.621030 |  physics Loss 0.258753 | Val Loss 0.889182
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch94-52-18_r0.9_Ld0.3_Lp0.7_seed913.keras
# theta | ZZx1 -> R² = 0.3057, R² diff = 0.4298
# theta | ZZx2 -> R² = 0.6383, R² diff = 0.3160
# theta | ZZxReto -> R² = 0.0644, R² diff = 0.3805
# theta | ZZy1 -> R² = -5.8385, R² diff = 0.2330
# theta | ZZy2 -> R² = -13.6537, R² diff = 0.1172
# theta | LSG-1 -> R² = -3.3317, R² diff = 0.3572
# theta | LSG-2 -> R² = -1.6654, R² diff = 0.2261
# theta | ZZx1-inv -> R² = -1.1824, R² diff = 0.2058
# theta | zzx2-inv2 -> R² = -5.6932, R² diff = 0.1434
# theta | semiCirc -> R² = -7.5585, R² diff = 0.0976
# Modelo [94, 52, 18] | Ld=0.3 Lp=0.7 r=0.9 seed=913 salvo.
# Epoch 0 | Train Loss 1.109877 | data Loss 1.072920 |  physics Loss 1.125716 | Val Loss 0.937529
# Epoch 100 | Train Loss 0.463753 | data Loss 0.594769 |  physics Loss 0.407603 | Val Loss 0.799690
# Epoch 200 | Train Loss 0.359183 | data Loss 0.593417 |  physics Loss 0.258798 | Val Loss 0.754545
# Early stopping at epoch 240
# Modelo salvo em:
# models/model_arch94-52-18_r0.9_Ld0.3_Lp0.7_seed1842.keras
# theta | ZZx1 -> R² = 0.7346, R² diff = 0.4648
# theta | ZZx2 -> R² = 0.9263, R² diff = 0.3374
# theta | ZZxReto -> R² = 0.8564, R² diff = 0.4334
# theta | ZZy1 -> R² = -5.6821, R² diff = 0.2482
# theta | ZZy2 -> R² = -12.8315, R² diff = 0.0825
# theta | LSG-1 -> R² = -0.6488, R² diff = 0.4177
# theta | LSG-2 -> R² = -1.6980, R² diff = 0.2669
# theta | ZZx1-inv -> R² = -1.0101, R² diff = 0.2429
# theta | zzx2-inv2 -> R² = -7.6159, R² diff = 0.1223
# theta | semiCirc -> R² = -13.7907, R² diff = -0.0114
# Modelo [94, 52, 18] | Ld=0.3 Lp=0.7 r=0.9 seed=1842 salvo.
# Epoch 0 | Train Loss 1.047167 | data Loss 0.991517 |  physics Loss 1.071018 | Val Loss 0.898364
