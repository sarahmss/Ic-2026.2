# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = [
    "SuperZZ1",
    "SuperZZ2",
    "LSG-1",
    "LSG-2",
    "ZZx1-inv",
    "ZZx1",
    "ZZx2-inv2",
    "ZZx2",
    "ZZxReto",
    "ZZy1",
    "ZZy2",
    "semiCirc",
]

PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a"]   
TARGET_INT = ["theta"]  
TARGET = ["dtheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 6
TS = 0.07
PLOT = False
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for title in TITLES:
    df = pd.read_excel("./../../00-Data/SavgolDatasets.xlsx", sheet_name=title)
    Datasets.append(df)

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["Se_a"] = Dataset["e_a_d"] + Dataset["e_a_e"]
    Dataset["De_a"] = Dataset["e_a_d"] - Dataset["e_a_e"]

    Dataset = Dataset.dropna(subset=[f"d{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train = Train1

# Train2 = Datasets[1].copy()
# Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
# Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
# NormDatasets.append(Train2)

# # concatena
# Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(len(TITLES)-1):
    CurrentTestDataset = Datasets[i + 1].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = NormDatasets[1]

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (2215, 6, 4)
# Dimensão da saida: (2215, 1)
# Dimensão da entrada: (3060, 6, 4)
# Dimensão da saida: (3060, 1)

# %%
phi_d_train =  Train["phi_d"].values[:len(x_train)]
phi_e_train =  Train["phi_e"].values[:len(x_train)]
theta_train = Train["theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(phi_d_train)}")
print(f"Dimensão da entrada fisica: {np.shape(phi_e_train)}")
# Out:
# Dimensão da entrada: (2215, 6, 4)
# Dimensão da saida: (2215, 1)
# Dimensão da entrada fisica : (2215,)
# Dimensão da entrada fisica: (2215,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):

    dtheta_cin = (R / (2 * L)) * (phi_d - phi_e)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(dq).T, np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, phi_d, phi_e, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(phi_d, phi_e, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss, data_loss, physics_loss

# %%
phi_d_train = tf.convert_to_tensor(phi_d_train, dtype=tf.float32)
phi_e_train = tf.convert_to_tensor(phi_e_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss, data_loss, physics_loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          phi_d_train, phi_e_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | data Loss {data_loss.numpy():.6f} |  physics Loss {physics_loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_mse = f"MSE_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_mse, []).append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {mse:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"MSE_{safe_title}_{name}"] = to_scalar(metrics[name][f"MSE_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    #os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    #weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    #model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}")

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import initializers
from itertools import product
import numpy as np
import tensorflow as tf

N_MODELS = 5

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[n] for n in range(85, 101)]


# FirstLayers = [
#     [27], [30], [32], [35], [36], [37], [40],
#     [42], [44], [46], [49], [50], [52], [75],
# ]

# architectures = [
#     [fl[0], sl]
#     for fl in FirstLayers
#     for sl in range(
#         max(1, int(0.3 * fl[0])),
#         int(0.7 * fl[0])
#     )
# ]

# 🔹 retomar a partir do último modelo salvo
# last_saved = [27, 12]

# if last_saved in architectures:
#     idx = architectures.index(last_saved)
#     architectures = architectures[idx + 1:]  # começa DEPOIS do último salvo
#     print(f"Retomando a partir de {last_saved} (índice {idx}). Restam {len(architectures)} arquiteturas.")
# else:
#     print(f"⚠️ {last_saved} não encontrado na lista — rodando tudo do zero.")

print(len(architectures))
print(architectures)

Ld_Lp = [[0.3, 0.7], [0.7, 0.3]]
r_values = [0.01, 0.9]

results = {}

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados-1l-v2.xlsx")
# Out:
# 16
# [[85], [86], [87], [88], [89], [90], [91], [92], [93], [94], [95], [96], [97], [98], [99], [100]]
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 1.023293 | data Loss 0.965668 |  physics Loss 1.047989 | Val Loss 1.034659
# Epoch 100 | Train Loss 0.351184 | data Loss 0.402348 |  physics Loss 0.329257 | Val Loss 0.595715
# Epoch 200 | Train Loss 0.253603 | data Loss 0.339654 |  physics Loss 0.216724 | Val Loss 0.628251
# Early stopping at epoch 271
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed1097.keras
# theta | SuperZZ1 -> R² = 0.8595, R² diff = 0.6134
# theta | SuperZZ2 -> R² = -0.0940, R² diff = 0.5423
# theta | LSG-1 -> R² = -0.7854, R² diff = 0.4826
# theta | LSG-2 -> R² = 0.3737, R² diff = 0.4940
# theta | ZZx1-inv -> R² = 0.5658, R² diff = 0.6845
# theta | ZZx1 -> R² = -0.0972, R² diff = 0.4578
# theta | ZZx2-inv2 -> R² = 0.8070, R² diff = 0.4604
# theta | ZZx2 -> R² = -2.4857, R² diff = 0.2642
# theta | ZZxReto -> R² = -0.9993, R² diff = 0.4162
# theta | ZZy1 -> R² = -40.6757, R² diff = -0.1581
# theta | ZZy2 -> R² = 0.5757, R² diff = 0.5272
# theta | semiCirc -> R² = -9.2763, R² diff = 0.1289
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=1097 salvo.
# Epoch 0 | Train Loss 0.964838 | data Loss 0.878025 |  physics Loss 1.002044 | Val Loss 0.967708
# Epoch 100 | Train Loss 0.360158 | data Loss 0.387075 |  physics Loss 0.348623 | Val Loss 0.590829
# Epoch 200 | Train Loss 0.264325 | data Loss 0.330539 |  physics Loss 0.235948 | Val Loss 0.628011
# Early stopping at epoch 245
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed4916.keras
# theta | SuperZZ1 -> R² = 0.8214, R² diff = 0.6143
# theta | SuperZZ2 -> R² = -1.4213, R² diff = 0.5274
# theta | LSG-1 -> R² = -0.3179, R² diff = 0.5394
# theta | LSG-2 -> R² = 0.3837, R² diff = 0.4942
# theta | ZZx1-inv -> R² = 0.5445, R² diff = 0.7123
# theta | ZZx1 -> R² = 0.1792, R² diff = 0.4972
# theta | ZZx2-inv2 -> R² = -0.1426, R² diff = 0.4414
# theta | ZZx2 -> R² = -1.7367, R² diff = 0.4187
# theta | ZZxReto -> R² = -0.0972, R² diff = 0.5749
# theta | ZZy1 -> R² = -23.5765, R² diff = 0.1485
# theta | ZZy2 -> R² = 0.2561, R² diff = 0.5824
# theta | semiCirc -> R² = -17.3501, R² diff = 0.0837
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=4916 salvo.
# Epoch 0 | Train Loss 1.006289 | data Loss 0.941424 |  physics Loss 1.034089 | Val Loss 1.051005
# Epoch 100 | Train Loss 0.358927 | data Loss 0.407618 |  physics Loss 0.338060 | Val Loss 0.616823
# Epoch 200 | Train Loss 0.276929 | data Loss 0.363808 |  physics Loss 0.239695 | Val Loss 0.601413
# Early stopping at epoch 284
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed8685.keras
# theta | SuperZZ1 -> R² = 0.3290, R² diff = 0.6109
# theta | SuperZZ2 -> R² = 0.5744, R² diff = 0.5501
# theta | LSG-1 -> R² = -3.2698, R² diff = 0.4477
# theta | LSG-2 -> R² = -1.1140, R² diff = 0.4690
# theta | ZZx1-inv -> R² = 0.7435, R² diff = 0.6561
# theta | ZZx1 -> R² = -1.2284, R² diff = 0.3881
# theta | ZZx2-inv2 -> R² = 0.7251, R² diff = 0.4331
# theta | ZZx2 -> R² = -2.0570, R² diff = 0.2965
# theta | ZZxReto -> R² = -0.5228, R² diff = 0.3751
# theta | ZZy1 -> R² = -31.4468, R² diff = -0.0879
# theta | ZZy2 -> R² = 0.9374, R² diff = 0.5393
# theta | semiCirc -> R² = -12.5702, R² diff = 0.0441
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=8685 salvo.
# Epoch 0 | Train Loss 0.992404 | data Loss 0.923236 |  physics Loss 1.022047 | Val Loss 1.024284
# Epoch 100 | Train Loss 0.344763 | data Loss 0.411336 |  physics Loss 0.316232 | Val Loss 0.625386
# Epoch 200 | Train Loss 0.266190 | data Loss 0.339827 |  physics Loss 0.234631 | Val Loss 0.659303
# Early stopping at epoch 270
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed6961.keras
# theta | SuperZZ1 -> R² = 0.7303, R² diff = 0.6214
# theta | SuperZZ2 -> R² = 0.1133, R² diff = 0.5540
# theta | LSG-1 -> R² = -1.6156, R² diff = 0.4635
# theta | LSG-2 -> R² = -0.2427, R² diff = 0.4806
# theta | ZZx1-inv -> R² = 0.8300, R² diff = 0.6849
# theta | ZZx1 -> R² = -0.4044, R² diff = 0.4346
# theta | ZZx2-inv2 -> R² = 0.5837, R² diff = 0.4570
# theta | ZZx2 -> R² = -1.3260, R² diff = 0.3415
# theta | ZZxReto -> R² = -0.3542, R² diff = 0.4114
# theta | ZZy1 -> R² = -37.3692, R² diff = -0.1202
# theta | ZZy2 -> R² = 0.8256, R² diff = 0.5535
# theta | semiCirc -> R² = -10.9029, R² diff = 0.0993
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=6961 salvo.
# Epoch 0 | Train Loss 1.084224 | data Loss 1.025168 |  physics Loss 1.109534 | Val Loss 1.126291
# Epoch 100 | Train Loss 0.402689 | data Loss 0.375395 |  physics Loss 0.414386 | Val Loss 0.599433
# Epoch 200 | Train Loss 0.293613 | data Loss 0.375445 |  physics Loss 0.258542 | Val Loss 0.594584
# Early stopping at epoch 291
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed4080.keras
# theta | SuperZZ1 -> R² = 0.7826, R² diff = 0.6182
# theta | SuperZZ2 -> R² = -0.1056, R² diff = 0.5375
# theta | LSG-1 -> R² = -1.0521, R² diff = 0.4650
# theta | LSG-2 -> R² = -0.0584, R² diff = 0.4733
# theta | ZZx1-inv -> R² = 0.8618, R² diff = 0.6908
# theta | ZZx1 -> R² = -0.2093, R² diff = 0.4634
# theta | ZZx2-inv2 -> R² = 0.5296, R² diff = 0.4281
# theta | ZZx2 -> R² = -2.0093, R² diff = 0.2874
# theta | ZZxReto -> R² = -0.3875, R² diff = 0.4207
# theta | ZZy1 -> R² = -40.4916, R² diff = -0.1871
# theta | ZZy2 -> R² = 0.6658, R² diff = 0.5180
# theta | semiCirc -> R² = -9.1472, R² diff = 0.0863
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=4080 salvo.
# Epoch 0 | Train Loss 1.014532 | data Loss 0.953762 |  physics Loss 1.040576 | Val Loss 1.051404
# Epoch 100 | Train Loss 0.359379 | data Loss 0.395537 |  physics Loss 0.343882 | Val Loss 0.622979
# Epoch 200 | Train Loss 0.265131 | data Loss 0.351386 |  physics Loss 0.228164 | Val Loss 0.634247
# Early stopping at epoch 286
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed1097.keras
# theta | SuperZZ1 -> R² = 0.8423, R² diff = 0.6072
# theta | SuperZZ2 -> R² = -0.0367, R² diff = 0.5286
# theta | LSG-1 -> R² = -0.9943, R² diff = 0.4671
# theta | LSG-2 -> R² = 0.2071, R² diff = 0.4674
# theta | ZZx1-inv -> R² = 0.7113, R² diff = 0.6576
# theta | ZZx1 -> R² = -0.1575, R² diff = 0.4320
# theta | ZZx2-inv2 -> R² = 0.5944, R² diff = 0.4140
# theta | ZZx2 -> R² = -1.5553, R² diff = 0.2926
# theta | ZZxReto -> R² = -0.4536, R² diff = 0.4099
# theta | ZZy1 -> R² = -33.8682, R² diff = -0.1078
# theta | ZZy2 -> R² = 0.6449, R² diff = 0.4982
# theta | semiCirc -> R² = -7.3941, R² diff = 0.1089
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=1097 salvo.
# Epoch 0 | Train Loss 0.976074 | data Loss 0.893280 |  physics Loss 1.011557 | Val Loss 0.980790
# Epoch 100 | Train Loss 0.373737 | data Loss 0.385898 |  physics Loss 0.368525 | Val Loss 0.575928
# Epoch 200 | Train Loss 0.283592 | data Loss 0.370059 |  physics Loss 0.246535 | Val Loss 0.624170
# Early stopping at epoch 258
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed4916.keras
# theta | SuperZZ1 -> R² = 0.8528, R² diff = 0.6261
# theta | SuperZZ2 -> R² = -1.4317, R² diff = 0.5266
# theta | LSG-1 -> R² = -0.5313, R² diff = 0.5364
# theta | LSG-2 -> R² = 0.3630, R² diff = 0.5079
# theta | ZZx1-inv -> R² = 0.6314, R² diff = 0.7295
# theta | ZZx1 -> R² = 0.1175, R² diff = 0.5089
# theta | ZZx2-inv2 -> R² = -0.0493, R² diff = 0.4432
# theta | ZZx2 -> R² = -2.3819, R² diff = 0.3730
# theta | ZZxReto -> R² = -0.4069, R² diff = 0.5446
# theta | ZZy1 -> R² = -30.2586, R² diff = 0.0550
# theta | ZZy2 -> R² = 0.2798, R² diff = 0.5709
# theta | semiCirc -> R² = -16.0408, R² diff = 0.0838
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=4916 salvo.
# Epoch 0 | Train Loss 1.012728 | data Loss 0.942716 |  physics Loss 1.042733 | Val Loss 1.061476
# Epoch 100 | Train Loss 0.365741 | data Loss 0.384868 |  physics Loss 0.357544 | Val Loss 0.603079
# Epoch 200 | Train Loss 0.274989 | data Loss 0.362118 |  physics Loss 0.237647 | Val Loss 0.595548
# Early stopping at epoch 276
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed8685.keras
# theta | SuperZZ1 -> R² = 0.8795, R² diff = 0.6192
# theta | SuperZZ2 -> R² = -0.5520, R² diff = 0.5387
# theta | LSG-1 -> R² = -0.7473, R² diff = 0.4717
# theta | LSG-2 -> R² = 0.3373, R² diff = 0.4851
# theta | ZZx1-inv -> R² = 0.4705, R² diff = 0.6924
# theta | ZZx1 -> R² = -0.1037, R² diff = 0.4574
# theta | ZZx2-inv2 -> R² = 0.2139, R² diff = 0.4348
# theta | ZZx2 -> R² = -1.6725, R² diff = 0.2984
# theta | ZZxReto -> R² = -1.0314, R² diff = 0.4356
# theta | ZZy1 -> R² = -37.5346, R² diff = -0.1109
# theta | ZZy2 -> R² = 0.4992, R² diff = 0.5248
# theta | semiCirc -> R² = -7.6821, R² diff = 0.1446
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=8685 salvo.
# Epoch 0 | Train Loss 1.014397 | data Loss 0.948858 |  physics Loss 1.042484 | Val Loss 1.054915
# Epoch 100 | Train Loss 0.354316 | data Loss 0.401642 |  physics Loss 0.334034 | Val Loss 0.644446
# Epoch 200 | Train Loss 0.271329 | data Loss 0.352138 |  physics Loss 0.236696 | Val Loss 0.634606
# Early stopping at epoch 279
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed6961.keras
# theta | SuperZZ1 -> R² = 0.7590, R² diff = 0.6187
# theta | SuperZZ2 -> R² = 0.1468, R² diff = 0.5458
# theta | LSG-1 -> R² = -1.3978, R² diff = 0.4767
# theta | LSG-2 -> R² = -0.0496, R² diff = 0.4852
# theta | ZZx1-inv -> R² = 0.6602, R² diff = 0.6741
# theta | ZZx1 -> R² = -0.1760, R² diff = 0.4218
# theta | ZZx2-inv2 -> R² = 0.5255, R² diff = 0.4509
# theta | ZZx2 -> R² = -0.9938, R² diff = 0.3485
# theta | ZZxReto -> R² = -0.6656, R² diff = 0.4183
# theta | ZZy1 -> R² = -38.3862, R² diff = -0.1055
# theta | ZZy2 -> R² = 0.8081, R² diff = 0.5513
# theta | semiCirc -> R² = -10.8646, R² diff = 0.1175
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=6961 salvo.
# Epoch 0 | Train Loss 1.054091 | data Loss 0.982342 |  physics Loss 1.084841 | Val Loss 1.071484
# Epoch 100 | Train Loss 0.370863 | data Loss 0.398585 |  physics Loss 0.358982 | Val Loss 0.602877
# Epoch 200 | Train Loss 0.278572 | data Loss 0.363239 |  physics Loss 0.242286 | Val Loss 0.607792
# Early stopping at epoch 288
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed4080.keras
# theta | SuperZZ1 -> R² = 0.5132, R² diff = 0.6210
# theta | SuperZZ2 -> R² = 0.1310, R² diff = 0.5529
# theta | LSG-1 -> R² = -2.5159, R² diff = 0.4622
# theta | LSG-2 -> R² = -1.2499, R² diff = 0.4647
# theta | ZZx1-inv -> R² = 0.8243, R² diff = 0.6801
# theta | ZZx1 -> R² = -1.2047, R² diff = 0.4342
# theta | ZZx2-inv2 -> R² = 0.6002, R² diff = 0.4497
# theta | ZZx2 -> R² = -1.3616, R² diff = 0.3600
# theta | ZZxReto -> R² = -0.3559, R² diff = 0.4124
# theta | ZZy1 -> R² = -30.5339, R² diff = -0.0392
# theta | ZZy2 -> R² = 0.8839, R² diff = 0.5518
# theta | semiCirc -> R² = -13.1061, R² diff = 0.0459
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=4080 salvo.
# Epoch 0 | Train Loss 1.078628 | data Loss 1.057920 |  physics Loss 1.126948 | Val Loss 1.192919
# Epoch 100 | Train Loss 0.376097 | data Loss 0.334893 |  physics Loss 0.472239 | Val Loss 0.512652
# Epoch 200 | Train Loss 0.288551 | data Loss 0.268418 |  physics Loss 0.335529 | Val Loss 0.535047
# Epoch 300 | Train Loss 0.246013 | data Loss 0.220235 |  physics Loss 0.306159 | Val Loss 0.624169
# Early stopping at epoch 351
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed1097.keras
# theta | SuperZZ1 -> R² = 0.7624, R² diff = 0.6850
# theta | SuperZZ2 -> R² = -2.1155, R² diff = 0.5965
# theta | LSG-1 -> R² = -2.2335, R² diff = 0.5115
# theta | LSG-2 -> R² = 0.0291, R² diff = 0.5114
# theta | ZZx1-inv -> R² = 0.4330, R² diff = 0.6902
# theta | ZZx1 -> R² = -0.9024, R² diff = 0.3999
# theta | ZZx2-inv2 -> R² = -1.0301, R² diff = 0.4658
# theta | ZZx2 -> R² = 0.0534, R² diff = 0.5091
# theta | ZZxReto -> R² = -0.4918, R² diff = 0.3921
# theta | ZZy1 -> R² = -27.3267, R² diff = 0.0511
# theta | ZZy2 -> R² = 0.6653, R² diff = 0.6404
# theta | semiCirc -> R² = -11.0441, R² diff = 0.1720
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=1097 salvo.
# Epoch 0 | Train Loss 0.947848 | data Loss 0.915576 |  physics Loss 1.023149 | Val Loss 0.998329
# Epoch 100 | Train Loss 0.369754 | data Loss 0.335605 |  physics Loss 0.449436 | Val Loss 0.539323
# Epoch 200 | Train Loss 0.292536 | data Loss 0.266568 |  physics Loss 0.353127 | Val Loss 0.520984
# Epoch 300 | Train Loss 0.250555 | data Loss 0.218326 |  physics Loss 0.325754 | Val Loss 0.621785
# Early stopping at epoch 398
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed4916.keras
# theta | SuperZZ1 -> R² = 0.8518, R² diff = 0.7330
# theta | SuperZZ2 -> R² = -0.3855, R² diff = 0.5762
# theta | LSG-1 -> R² = -3.3099, R² diff = 0.5081
# theta | LSG-2 -> R² = -0.5824, R² diff = 0.5304
# theta | ZZx1-inv -> R² = 0.2111, R² diff = 0.6862
# theta | ZZx1 -> R² = -1.1630, R² diff = 0.3237
# theta | ZZx2-inv2 -> R² = -2.7102, R² diff = 0.2565
# theta | ZZx2 -> R² = -0.3768, R² diff = 0.5628
# theta | ZZxReto -> R² = -0.7749, R² diff = 0.3231
# theta | ZZy1 -> R² = -35.0863, R² diff = -0.0783
# theta | ZZy2 -> R² = 0.8720, R² diff = 0.6643
# theta | semiCirc -> R² = -9.2639, R² diff = 0.2656
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=4916 salvo.
# Epoch 0 | Train Loss 1.054320 | data Loss 1.032944 |  physics Loss 1.104199 | Val Loss 1.181031
# Epoch 100 | Train Loss 0.373916 | data Loss 0.334953 |  physics Loss 0.464830 | Val Loss 0.513252
# Epoch 200 | Train Loss 0.289419 | data Loss 0.268088 |  physics Loss 0.339190 | Val Loss 0.574464
# Epoch 300 | Train Loss 0.246988 | data Loss 0.223050 |  physics Loss 0.302843 | Val Loss 0.646982
# Early stopping at epoch 312
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed8685.keras
# theta | SuperZZ1 -> R² = 0.9021, R² diff = 0.6658
# theta | SuperZZ2 -> R² = -1.5131, R² diff = 0.5871
# theta | LSG-1 -> R² = -1.6396, R² diff = 0.5266
# theta | LSG-2 -> R² = 0.1231, R² diff = 0.5077
# theta | ZZx1-inv -> R² = 0.7081, R² diff = 0.7151
# theta | ZZx1 -> R² = -0.2572, R² diff = 0.4791
# theta | ZZx2-inv2 -> R² = -0.2980, R² diff = 0.4765
# theta | ZZx2 -> R² = -0.6756, R² diff = 0.4306
# theta | ZZxReto -> R² = -0.0527, R² diff = 0.4933
# theta | ZZy1 -> R² = -34.0536, R² diff = 0.0057
# theta | ZZy2 -> R² = 0.5954, R² diff = 0.6051
# theta | semiCirc -> R² = -15.1275, R² diff = 0.0489
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=8685 salvo.
# Epoch 0 | Train Loss 1.026219 | data Loss 0.999706 |  physics Loss 1.088081 | Val Loss 1.105381
# Epoch 100 | Train Loss 0.389925 | data Loss 0.340032 |  physics Loss 0.506341 | Val Loss 0.524161
# Epoch 200 | Train Loss 0.290495 | data Loss 0.266281 |  physics Loss 0.346994 | Val Loss 0.564489
# Epoch 300 | Train Loss 0.249170 | data Loss 0.219598 |  physics Loss 0.318170 | Val Loss 0.694068
# Early stopping at epoch 313
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed6961.keras
# theta | SuperZZ1 -> R² = 0.9094, R² diff = 0.6617
# theta | SuperZZ2 -> R² = -1.2006, R² diff = 0.5841
# theta | LSG-1 -> R² = -1.0402, R² diff = 0.5318
# theta | LSG-2 -> R² = 0.3072, R² diff = 0.5110
# theta | ZZx1-inv -> R² = 0.4994, R² diff = 0.7207
# theta | ZZx1 -> R² = -0.0170, R² diff = 0.4889
# theta | ZZx2-inv2 -> R² = -0.1600, R² diff = 0.4767
# theta | ZZx2 -> R² = -1.2010, R² diff = 0.3964
# theta | ZZxReto -> R² = -0.2709, R² diff = 0.5103
# theta | ZZy1 -> R² = -35.8378, R² diff = -0.0028
# theta | ZZy2 -> R² = 0.5347, R² diff = 0.5955
# theta | semiCirc -> R² = -14.0383, R² diff = 0.0685
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=6961 salvo.
# Epoch 0 | Train Loss 1.100417 | data Loss 1.077780 |  physics Loss 1.153237 | Val Loss 1.216517
# Epoch 100 | Train Loss 0.391020 | data Loss 0.336698 |  physics Loss 0.517770 | Val Loss 0.524819
# Epoch 200 | Train Loss 0.282187 | data Loss 0.251722 |  physics Loss 0.353271 | Val Loss 0.551606
# Epoch 300 | Train Loss 0.247305 | data Loss 0.225089 |  physics Loss 0.299143 | Val Loss 0.590442
# Early stopping at epoch 363
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed4080.keras
# theta | SuperZZ1 -> R² = 0.5526, R² diff = 0.6997
# theta | SuperZZ2 -> R² = -0.7648, R² diff = 0.5810
# theta | LSG-1 -> R² = -5.9560, R² diff = 0.4944
# theta | LSG-2 -> R² = -2.0446, R² diff = 0.4912
# theta | ZZx1-inv -> R² = 0.6388, R² diff = 0.7111
# theta | ZZx1 -> R² = -3.0112, R² diff = 0.3913
# theta | ZZx2-inv2 -> R² = -1.5436, R² diff = 0.3144
# theta | ZZx2 -> R² = -0.7740, R² diff = 0.5012
# theta | ZZxReto -> R² = -2.0087, R² diff = 0.4144
# theta | ZZy1 -> R² = -23.4642, R² diff = 0.0675
# theta | ZZy2 -> R² = 0.9122, R² diff = 0.6426
# theta | semiCirc -> R² = -19.1983, R² diff = 0.0010
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=4080 salvo.
# Epoch 0 | Train Loss 1.021015 | data Loss 0.997158 |  physics Loss 1.076681 | Val Loss 1.111080
# Epoch 100 | Train Loss 0.374630 | data Loss 0.334130 |  physics Loss 0.469132 | Val Loss 0.515607
# Epoch 200 | Train Loss 0.269731 | data Loss 0.243123 |  physics Loss 0.331817 | Val Loss 0.555644
# Epoch 300 | Train Loss 0.237316 | data Loss 0.214332 |  physics Loss 0.290944 | Val Loss 0.621086
# Early stopping at epoch 315
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed1097.keras
# theta | SuperZZ1 -> R² = 0.9063, R² diff = 0.6748
# theta | SuperZZ2 -> R² = -1.4711, R² diff = 0.5827
# theta | LSG-1 -> R² = -2.6249, R² diff = 0.5207
# theta | LSG-2 -> R² = -0.5128, R² diff = 0.5026
# theta | ZZx1-inv -> R² = 0.8762, R² diff = 0.7194
# theta | ZZx1 -> R² = -0.7001, R² diff = 0.4718
# theta | ZZx2-inv2 -> R² = -0.5916, R² diff = 0.4497
# theta | ZZx2 -> R² = -0.3544, R² diff = 0.4598
# theta | ZZxReto -> R² = -0.1921, R² diff = 0.4905
# theta | ZZy1 -> R² = -31.7365, R² diff = 0.0166
# theta | ZZy2 -> R² = 0.7087, R² diff = 0.6097
# theta | semiCirc -> R² = -16.9779, R² diff = 0.0007
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=1097 salvo.
# Epoch 0 | Train Loss 1.004203 | data Loss 0.972942 |  physics Loss 1.077145 | Val Loss 1.088479
# Epoch 100 | Train Loss 0.377164 | data Loss 0.337372 |  physics Loss 0.470014 | Val Loss 0.521062
# Epoch 200 | Train Loss 0.273286 | data Loss 0.247764 |  physics Loss 0.332837 | Val Loss 0.587466
# Epoch 300 | Train Loss 0.244805 | data Loss 0.220161 |  physics Loss 0.302307 | Val Loss 0.624954
# Early stopping at epoch 306
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed4916.keras
# theta | SuperZZ1 -> R² = 0.9156, R² diff = 0.6649
# theta | SuperZZ2 -> R² = -1.2402, R² diff = 0.5780
# theta | LSG-1 -> R² = -1.8249, R² diff = 0.5200
# theta | LSG-2 -> R² = 0.1399, R² diff = 0.5107
# theta | ZZx1-inv -> R² = 0.7330, R² diff = 0.7220
# theta | ZZx1 -> R² = -0.3802, R² diff = 0.4716
# theta | ZZx2-inv2 -> R² = -0.1405, R² diff = 0.4717
# theta | ZZx2 -> R² = -1.2322, R² diff = 0.4451
# theta | ZZxReto -> R² = -0.1535, R² diff = 0.4715
# theta | ZZy1 -> R² = -35.7695, R² diff = -0.0343
# theta | ZZy2 -> R² = 0.6852, R² diff = 0.6120
# theta | semiCirc -> R² = -16.7689, R² diff = 0.0555
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=4916 salvo.
# Epoch 0 | Train Loss 1.066996 | data Loss 1.046557 |  physics Loss 1.114686 | Val Loss 1.189197
# Epoch 100 | Train Loss 0.396220 | data Loss 0.340322 |  physics Loss 0.526648 | Val Loss 0.525565
# Epoch 200 | Train Loss 0.276686 | data Loss 0.250141 |  physics Loss 0.338625 | Val Loss 0.547275
# Epoch 300 | Train Loss 0.251608 | data Loss 0.235493 |  physics Loss 0.289208 | Val Loss 0.602227
# Early stopping at epoch 320
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed8685.keras
# theta | SuperZZ1 -> R² = 0.9005, R² diff = 0.6683
# theta | SuperZZ2 -> R² = -1.2007, R² diff = 0.5781
# theta | LSG-1 -> R² = -2.1136, R² diff = 0.4634
# theta | LSG-2 -> R² = -0.0008, R² diff = 0.4870
# theta | ZZx1-inv -> R² = 0.5591, R² diff = 0.7017
# theta | ZZx1 -> R² = -0.5887, R² diff = 0.4265
# theta | ZZx2-inv2 -> R² = -0.8205, R² diff = 0.4322
# theta | ZZx2 -> R² = -0.3119, R² diff = 0.4432
# theta | ZZxReto -> R² = -0.4536, R² diff = 0.4035
# theta | ZZy1 -> R² = -41.1244, R² diff = -0.1573
# theta | ZZy2 -> R² = 0.7789, R² diff = 0.6060
# theta | semiCirc -> R² = -13.0100, R² diff = 0.0628
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=8685 salvo.
# Epoch 0 | Train Loss 0.922901 | data Loss 0.889356 |  physics Loss 1.001174 | Val Loss 0.969283
# Epoch 100 | Train Loss 0.363442 | data Loss 0.318372 |  physics Loss 0.468606 | Val Loss 0.550607
# Epoch 200 | Train Loss 0.285908 | data Loss 0.259279 |  physics Loss 0.348043 | Val Loss 0.516408
# Early stopping at epoch 279
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed6961.keras
# theta | SuperZZ1 -> R² = 0.8295, R² diff = 0.6624
# theta | SuperZZ2 -> R² = -0.6905, R² diff = 0.5708
# theta | LSG-1 -> R² = -2.9574, R² diff = 0.4949
# theta | LSG-2 -> R² = -0.2102, R² diff = 0.5042
# theta | ZZx1-inv -> R² = 0.7568, R² diff = 0.7291
# theta | ZZx1 -> R² = -0.5547, R² diff = 0.4494
# theta | ZZx2-inv2 -> R² = -0.3548, R² diff = 0.4225
# theta | ZZx2 -> R² = -2.0334, R² diff = 0.4165
# theta | ZZxReto -> R² = -0.3573, R² diff = 0.4538
# theta | ZZy1 -> R² = -40.7403, R² diff = -0.1415
# theta | ZZy2 -> R² = 0.8632, R² diff = 0.6256
# theta | semiCirc -> R² = -19.9703, R² diff = -0.0170
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=6961 salvo.
# Epoch 0 | Train Loss 0.999736 | data Loss 0.972607 |  physics Loss 1.063038 | Val Loss 1.039250
# Epoch 100 | Train Loss 0.380886 | data Loss 0.327588 |  physics Loss 0.505248 | Val Loss 0.547264
# Epoch 200 | Train Loss 0.297006 | data Loss 0.267812 |  physics Loss 0.365126 | Val Loss 0.589561
# Epoch 300 | Train Loss 0.256147 | data Loss 0.228339 |  physics Loss 0.321031 | Val Loss 0.696711
# Early stopping at epoch 303
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed4080.keras
# theta | SuperZZ1 -> R² = 0.3107, R² diff = 0.6685
# theta | SuperZZ2 -> R² = 0.1079, R² diff = 0.5724
# theta | LSG-1 -> R² = -6.5700, R² diff = 0.4174
# theta | LSG-2 -> R² = -2.7488, R² diff = 0.4609
# theta | ZZx1-inv -> R² = 0.4379, R² diff = 0.7069
# theta | ZZx1 -> R² = -3.5538, R² diff = 0.3736
# theta | ZZx2-inv2 -> R² = -0.1343, R² diff = 0.3900
# theta | ZZx2 -> R² = -1.1319, R² diff = 0.4277
# theta | ZZxReto -> R² = -2.3750, R² diff = 0.3767
# theta | ZZy1 -> R² = -29.1257, R² diff = -0.0731
# theta | ZZy2 -> R² = 0.8199, R² diff = 0.6213
# theta | semiCirc -> R² = -19.4556, R² diff = -0.0538
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=4080 salvo.
# Epoch 0 | Train Loss 1.051976 | data Loss 0.996959 |  physics Loss 1.075554 | Val Loss 1.092646
# Epoch 100 | Train Loss 0.371766 | data Loss 0.373289 |  physics Loss 0.371114 | Val Loss 0.576015
# Epoch 200 | Train Loss 0.282622 | data Loss 0.364267 |  physics Loss 0.247631 | Val Loss 0.604258
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed1097.keras
# theta | SuperZZ1 -> R² = 0.8747, R² diff = 0.6171
# theta | SuperZZ2 -> R² = -0.1378, R² diff = 0.5359
# theta | LSG-1 -> R² = -1.1705, R² diff = 0.4480
# theta | LSG-2 -> R² = 0.2335, R² diff = 0.4783
# theta | ZZx1-inv -> R² = 0.6536, R² diff = 0.6770
# theta | ZZx1 -> R² = -0.2976, R² diff = 0.4380
# theta | ZZx2-inv2 -> R² = 0.5145, R² diff = 0.4265
# theta | ZZx2 -> R² = -1.8542, R² diff = 0.2764
# theta | ZZxReto -> R² = -0.6384, R² diff = 0.3793
# theta | ZZy1 -> R² = -39.9471, R² diff = -0.2158
# theta | ZZy2 -> R² = 0.6682, R² diff = 0.5191
# theta | semiCirc -> R² = -7.8451, R² diff = 0.0970
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=1097 salvo.
# Epoch 0 | Train Loss 1.046705 | data Loss 0.984922 |  physics Loss 1.073184 | Val Loss 1.078228
# Epoch 100 | Train Loss 0.365674 | data Loss 0.392600 |  physics Loss 0.354134 | Val Loss 0.602385
# Epoch 200 | Train Loss 0.264577 | data Loss 0.334487 |  physics Loss 0.234616 | Val Loss 0.595662
# Early stopping at epoch 280
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed4916.keras
# theta | SuperZZ1 -> R² = 0.6730, R² diff = 0.6095
# theta | SuperZZ2 -> R² = 0.4186, R² diff = 0.5383
# theta | LSG-1 -> R² = -1.8108, R² diff = 0.4308
# theta | LSG-2 -> R² = -0.3657, R² diff = 0.4659
# theta | ZZx1-inv -> R² = 0.8073, R² diff = 0.6722
# theta | ZZx1 -> R² = -0.5923, R² diff = 0.4171
# theta | ZZx2-inv2 -> R² = 0.7061, R² diff = 0.4230
# theta | ZZx2 -> R² = -1.4379, R² diff = 0.2752
# theta | ZZxReto -> R² = -0.4401, R² diff = 0.3774
# theta | ZZy1 -> R² = -39.1769, R² diff = -0.2097
# theta | ZZy2 -> R² = 0.8742, R² diff = 0.5118
# theta | semiCirc -> R² = -8.8035, R² diff = 0.0620
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=4916 salvo.
# Epoch 0 | Train Loss 1.041907 | data Loss 0.984210 |  physics Loss 1.066634 | Val Loss 1.111929
# Epoch 100 | Train Loss 0.363408 | data Loss 0.395457 |  physics Loss 0.349672 | Val Loss 0.603649
# Epoch 200 | Train Loss 0.256125 | data Loss 0.335946 |  physics Loss 0.221916 | Val Loss 0.627929
# Early stopping at epoch 254
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed8685.keras
# theta | SuperZZ1 -> R² = 0.7964, R² diff = 0.6221
# theta | SuperZZ2 -> R² = -1.1616, R² diff = 0.5416
# theta | LSG-1 -> R² = -0.5585, R² diff = 0.5408
# theta | LSG-2 -> R² = 0.3023, R² diff = 0.4984
# theta | ZZx1-inv -> R² = 0.5963, R² diff = 0.7189
# theta | ZZx1 -> R² = 0.1679, R² diff = 0.4990
# theta | ZZx2-inv2 -> R² = -0.0854, R² diff = 0.4509
# theta | ZZx2 -> R² = -1.8539, R² diff = 0.4183
# theta | ZZxReto -> R² = -0.2232, R² diff = 0.5689
# theta | ZZy1 -> R² = -27.6995, R² diff = 0.1002
# theta | ZZy2 -> R² = 0.4125, R² diff = 0.5914
# theta | semiCirc -> R² = -18.6662, R² diff = 0.0504
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=8685 salvo.
# Epoch 0 | Train Loss 1.061328 | data Loss 0.991517 |  physics Loss 1.091247 | Val Loss 1.116143
# Epoch 100 | Train Loss 0.369054 | data Loss 0.398772 |  physics Loss 0.356318 | Val Loss 0.632046
# Epoch 200 | Train Loss 0.292238 | data Loss 0.382803 |  physics Loss 0.253425 | Val Loss 0.608082
# Epoch 300 | Train Loss 0.251421 | data Loss 0.340410 |  physics Loss 0.213283 | Val Loss 0.581956
# Epoch 400 | Train Loss 0.240710 | data Loss 0.327303 |  physics Loss 0.203599 | Val Loss 0.585826
# Early stopping at epoch 440
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed6961.keras
# theta | SuperZZ1 -> R² = 0.7663, R² diff = 0.6452
# theta | SuperZZ2 -> R² = -0.2156, R² diff = 0.5349
# theta | LSG-1 -> R² = -3.0044, R² diff = 0.5410
# theta | LSG-2 -> R² = -0.4828, R² diff = 0.5072
# theta | ZZx1-inv -> R² = 0.8780, R² diff = 0.5977
# theta | ZZx1 -> R² = -2.1515, R² diff = 0.3661
# theta | ZZx2-inv2 -> R² = -0.3699, R² diff = 0.3604
# theta | ZZx2 -> R² = -0.4844, R² diff = 0.4411
# theta | ZZxReto -> R² = -1.0188, R² diff = 0.3878
# theta | ZZy1 -> R² = -12.2482, R² diff = 0.2235
# theta | ZZy2 -> R² = 0.8815, R² diff = 0.5276
# theta | semiCirc -> R² = -11.4910, R² diff = 0.1100
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=6961 salvo.
# Epoch 0 | Train Loss 1.039779 | data Loss 0.981347 |  physics Loss 1.064821 | Val Loss 1.081575
# Epoch 100 | Train Loss 0.368624 | data Loss 0.377697 |  physics Loss 0.364735 | Val Loss 0.576064
# Epoch 200 | Train Loss 0.292696 | data Loss 0.371415 |  physics Loss 0.258959 | Val Loss 0.623120
# Early stopping at epoch 285
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed4080.keras
# theta | SuperZZ1 -> R² = 0.8105, R² diff = 0.6208
# theta | SuperZZ2 -> R² = 0.0093, R² diff = 0.5352
# theta | LSG-1 -> R² = -1.1755, R² diff = 0.4714
# theta | LSG-2 -> R² = 0.1246, R² diff = 0.4837
# theta | ZZx1-inv -> R² = 0.6969, R² diff = 0.6810
# theta | ZZx1 -> R² = -0.2175, R² diff = 0.4410
# theta | ZZx2-inv2 -> R² = 0.4964, R² diff = 0.4272
# theta | ZZx2 -> R² = -1.5889, R² diff = 0.3037
# theta | ZZxReto -> R² = -0.4401, R² diff = 0.4265
# theta | ZZy1 -> R² = -33.3816, R² diff = -0.0844
# theta | ZZy2 -> R² = 0.7221, R² diff = 0.5263
# theta | semiCirc -> R² = -8.7063, R² diff = 0.1101
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=4080 salvo.
# Epoch 0 | Train Loss 1.070365 | data Loss 1.015483 |  physics Loss 1.093885 | Val Loss 1.131032
# Epoch 100 | Train Loss 0.379151 | data Loss 0.384895 |  physics Loss 0.376689 | Val Loss 0.602073
# Epoch 200 | Train Loss 0.270934 | data Loss 0.356963 |  physics Loss 0.234065 | Val Loss 0.589172
# Early stopping at epoch 286
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed1097.keras
# theta | SuperZZ1 -> R² = 0.8215, R² diff = 0.6099
# theta | SuperZZ2 -> R² = 0.0605, R² diff = 0.5358
# theta | LSG-1 -> R² = -0.9103, R² diff = 0.4921
# theta | LSG-2 -> R² = 0.3173, R² diff = 0.5014
# theta | ZZx1-inv -> R² = 0.4365, R² diff = 0.6671
# theta | ZZx1 -> R² = -0.1956, R² diff = 0.4366
# theta | ZZx2-inv2 -> R² = 0.8118, R² diff = 0.4512
# theta | ZZx2 -> R² = -2.5687, R² diff = 0.2428
# theta | ZZxReto -> R² = -0.9943, R² diff = 0.4231
# theta | ZZy1 -> R² = -33.1604, R² diff = -0.0670
# theta | ZZy2 -> R² = 0.6629, R² diff = 0.5216
# theta | semiCirc -> R² = -8.9334, R² diff = 0.1349
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=1097 salvo.
# Epoch 0 | Train Loss 0.974225 | data Loss 0.902771 |  physics Loss 1.004848 | Val Loss 0.991465
# Epoch 100 | Train Loss 0.346600 | data Loss 0.382943 |  physics Loss 0.331024 | Val Loss 0.576653
# Epoch 200 | Train Loss 0.272009 | data Loss 0.355030 |  physics Loss 0.236429 | Val Loss 0.618047
# Early stopping at epoch 272
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed4916.keras
# theta | SuperZZ1 -> R² = 0.8834, R² diff = 0.6125
# theta | SuperZZ2 -> R² = -0.4199, R² diff = 0.5300
# theta | LSG-1 -> R² = -0.9515, R² diff = 0.4566
# theta | LSG-2 -> R² = 0.2878, R² diff = 0.4746
# theta | ZZx1-inv -> R² = 0.6205, R² diff = 0.6814
# theta | ZZx1 -> R² = -0.1734, R² diff = 0.4494
# theta | ZZx2-inv2 -> R² = 0.4327, R² diff = 0.4228
# theta | ZZx2 -> R² = -1.7122, R² diff = 0.2828
# theta | ZZxReto -> R² = -0.6388, R² diff = 0.4065
# theta | ZZy1 -> R² = -37.2188, R² diff = -0.1562
# theta | ZZy2 -> R² = 0.5648, R² diff = 0.5063
# theta | semiCirc -> R² = -7.4500, R² diff = 0.1097
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=4916 salvo.
# Epoch 0 | Train Loss 1.087126 | data Loss 1.038614 |  physics Loss 1.107917 | Val Loss 1.167822
# Epoch 100 | Train Loss 0.366004 | data Loss 0.405464 |  physics Loss 0.349093 | Val Loss 0.638831
# Epoch 200 | Train Loss 0.277373 | data Loss 0.359669 |  physics Loss 0.242103 | Val Loss 0.594368
# Epoch 300 | Train Loss 0.247524 | data Loss 0.334362 |  physics Loss 0.210307 | Val Loss 0.557265
# Epoch 400 | Train Loss 0.239862 | data Loss 0.330777 |  physics Loss 0.200898 | Val Loss 0.545818
# Epoch 500 | Train Loss 0.233409 | data Loss 0.322609 |  physics Loss 0.195181 | Val Loss 0.546532
# Early stopping at epoch 562
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed8685.keras
# theta | SuperZZ1 -> R² = 0.5864, R² diff = 0.6802
# theta | SuperZZ2 -> R² = -0.4296, R² diff = 0.5505
# theta | LSG-1 -> R² = -5.3897, R² diff = 0.5883
# theta | LSG-2 -> R² = -3.9287, R² diff = 0.5143
# theta | ZZx1-inv -> R² = 0.6775, R² diff = 0.5750
# theta | ZZx1 -> R² = -4.4973, R² diff = 0.4060
# theta | ZZx2-inv2 -> R² = -0.7620, R² diff = 0.3433
# theta | ZZx2 -> R² = 0.3589, R² diff = 0.5011
# theta | ZZxReto -> R² = -3.4849, R² diff = 0.4195
# theta | ZZy1 -> R² = -10.4926, R² diff = 0.2771
# theta | ZZy2 -> R² = 0.6860, R² diff = 0.5162
# theta | semiCirc -> R² = -18.0874, R² diff = -0.0083
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=8685 salvo.
# Epoch 0 | Train Loss 1.084456 | data Loss 1.025818 |  physics Loss 1.109586 | Val Loss 1.144296
# Epoch 100 | Train Loss 0.361148 | data Loss 0.379471 |  physics Loss 0.353296 | Val Loss 0.616636
# Epoch 200 | Train Loss 0.274200 | data Loss 0.342545 |  physics Loss 0.244909 | Val Loss 0.641951
# Early stopping at epoch 281
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed6961.keras
# theta | SuperZZ1 -> R² = 0.7490, R² diff = 0.6221
# theta | SuperZZ2 -> R² = 0.1022, R² diff = 0.5407
# theta | LSG-1 -> R² = -1.8281, R² diff = 0.4526
# theta | LSG-2 -> R² = -0.1033, R² diff = 0.4826
# theta | ZZx1-inv -> R² = 0.7110, R² diff = 0.6714
# theta | ZZx1 -> R² = -0.4207, R² diff = 0.4071
# theta | ZZx2-inv2 -> R² = 0.4151, R² diff = 0.4280
# theta | ZZx2 -> R² = -1.2197, R² diff = 0.3439
# theta | ZZxReto -> R² = -0.5579, R² diff = 0.3821
# theta | ZZy1 -> R² = -35.4362, R² diff = -0.1213
# theta | ZZy2 -> R² = 0.8587, R² diff = 0.5476
# theta | semiCirc -> R² = -10.7541, R² diff = 0.0916
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=6961 salvo.
# Epoch 0 | Train Loss 0.987751 | data Loss 0.918402 |  physics Loss 1.017472 | Val Loss 1.024113
# Epoch 100 | Train Loss 0.342149 | data Loss 0.404988 |  physics Loss 0.315217 | Val Loss 0.612659
# Epoch 200 | Train Loss 0.262828 | data Loss 0.332914 |  physics Loss 0.232792 | Val Loss 0.614844
# Early stopping at epoch 252
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed4080.keras
# theta | SuperZZ1 -> R² = 0.8512, R² diff = 0.6305
# theta | SuperZZ2 -> R² = -1.5347, R² diff = 0.5384
# theta | LSG-1 -> R² = -0.8152, R² diff = 0.5372
# theta | LSG-2 -> R² = 0.2331, R² diff = 0.5039
# theta | ZZx1-inv -> R² = 0.5912, R² diff = 0.7290
# theta | ZZx1 -> R² = 0.1504, R² diff = 0.4971
# theta | ZZx2-inv2 -> R² = -0.3247, R² diff = 0.4441
# theta | ZZx2 -> R² = -1.4341, R² diff = 0.4281
# theta | ZZxReto -> R² = -0.3039, R² diff = 0.5580
# theta | ZZy1 -> R² = -31.5499, R² diff = 0.0521
# theta | ZZy2 -> R² = 0.3938, R² diff = 0.5900
# theta | semiCirc -> R² = -18.5152, R² diff = 0.0536
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=4080 salvo.
# Epoch 0 | Train Loss 1.005149 | data Loss 0.979371 |  physics Loss 1.065296 | Val Loss 1.079218
# Epoch 100 | Train Loss 0.371908 | data Loss 0.326437 |  physics Loss 0.478006 | Val Loss 0.515797
# Epoch 200 | Train Loss 0.286982 | data Loss 0.258758 |  physics Loss 0.352837 | Val Loss 0.543340
# Epoch 300 | Train Loss 0.248977 | data Loss 0.226130 |  physics Loss 0.302287 | Val Loss 0.601604
# Early stopping at epoch 302
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed1097.keras
# theta | SuperZZ1 -> R² = 0.8599, R² diff = 0.6695
# theta | SuperZZ2 -> R² = -2.6260, R² diff = 0.5720
# theta | LSG-1 -> R² = -1.8261, R² diff = 0.5105
# theta | LSG-2 -> R² = 0.0341, R² diff = 0.4968
# theta | ZZx1-inv -> R² = 0.7036, R² diff = 0.7154
# theta | ZZx1 -> R² = -0.3270, R² diff = 0.4822
# theta | ZZx2-inv2 -> R² = -1.0628, R² diff = 0.4497
# theta | ZZx2 -> R² = -0.0183, R² diff = 0.4587
# theta | ZZxReto -> R² = -0.0276, R² diff = 0.5037
# theta | ZZy1 -> R² = -32.4748, R² diff = 0.0130
# theta | ZZy2 -> R² = 0.4476, R² diff = 0.6134
# theta | semiCirc -> R² = -16.0996, R² diff = 0.0243
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=1097 salvo.
# Epoch 0 | Train Loss 1.025737 | data Loss 1.003053 |  physics Loss 1.078665 | Val Loss 1.099523
# Epoch 100 | Train Loss 0.382480 | data Loss 0.336773 |  physics Loss 0.489128 | Val Loss 0.561145
# Epoch 200 | Train Loss 0.288741 | data Loss 0.257673 |  physics Loss 0.361233 | Val Loss 0.564866
# Early stopping at epoch 292
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed4916.keras
# theta | SuperZZ1 -> R² = 0.5845, R² diff = 0.6564
# theta | SuperZZ2 -> R² = 0.0440, R² diff = 0.5783
# theta | LSG-1 -> R² = -4.5599, R² diff = 0.4678
# theta | LSG-2 -> R² = -1.0647, R² diff = 0.4903
# theta | ZZx1-inv -> R² = 0.7841, R² diff = 0.7132
# theta | ZZx1 -> R² = -1.2707, R² diff = 0.4167
# theta | ZZx2-inv2 -> R² = 0.3298, R² diff = 0.4492
# theta | ZZx2 -> R² = -2.0401, R² diff = 0.3964
# theta | ZZxReto -> R² = -0.6618, R² diff = 0.4206
# theta | ZZy1 -> R² = -35.9674, R² diff = -0.1183
# theta | ZZy2 -> R² = 0.8874, R² diff = 0.6194
# theta | semiCirc -> R² = -20.8772, R² diff = -0.0617
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=4916 salvo.
# Epoch 0 | Train Loss 1.001069 | data Loss 0.976103 |  physics Loss 1.059323 | Val Loss 1.079414
# Epoch 100 | Train Loss 0.379637 | data Loss 0.327344 |  physics Loss 0.501652 | Val Loss 0.535390
# Epoch 200 | Train Loss 0.276954 | data Loss 0.253690 |  physics Loss 0.331236 | Val Loss 0.581386
# Epoch 300 | Train Loss 0.241892 | data Loss 0.216060 |  physics Loss 0.302166 | Val Loss 0.694672
# Early stopping at epoch 305
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed8685.keras
# theta | SuperZZ1 -> R² = 0.7758, R² diff = 0.6712
# theta | SuperZZ2 -> R² = -0.5625, R² diff = 0.5715
# theta | LSG-1 -> R² = -3.8480, R² diff = 0.4489
# theta | LSG-2 -> R² = -0.7267, R² diff = 0.4799
# theta | ZZx1-inv -> R² = 0.7931, R² diff = 0.7113
# theta | ZZx1 -> R² = -1.4357, R² diff = 0.4035
# theta | ZZx2-inv2 -> R² = -0.5877, R² diff = 0.4000
# theta | ZZx2 -> R² = -1.2734, R² diff = 0.4396
# theta | ZZxReto -> R² = -0.7886, R² diff = 0.3782
# theta | ZZy1 -> R² = -39.3738, R² diff = -0.1749
# theta | ZZy2 -> R² = 0.9170, R² diff = 0.6130
# theta | semiCirc -> R² = -17.0829, R² diff = -0.0117
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=8685 salvo.
# Epoch 0 | Train Loss 1.071933 | data Loss 1.042841 |  physics Loss 1.139816 | Val Loss 1.154975
# Epoch 100 | Train Loss 0.397058 | data Loss 0.339068 |  physics Loss 0.532369 | Val Loss 0.528098
# Epoch 200 | Train Loss 0.301025 | data Loss 0.274214 |  physics Loss 0.363585 | Val Loss 0.593976
# Epoch 300 | Train Loss 0.260362 | data Loss 0.236926 |  physics Loss 0.315044 | Val Loss 0.658817
# Early stopping at epoch 323
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed6961.keras
# theta | SuperZZ1 -> R² = 0.9121, R² diff = 0.6736
# theta | SuperZZ2 -> R² = -1.7240, R² diff = 0.5801
# theta | LSG-1 -> R² = -2.3088, R² diff = 0.4945
# theta | LSG-2 -> R² = -0.2173, R² diff = 0.4938
# theta | ZZx1-inv -> R² = 0.8157, R² diff = 0.7231
# theta | ZZx1 -> R² = -0.7023, R² diff = 0.4623
# theta | ZZx2-inv2 -> R² = -0.9343, R² diff = 0.4367
# theta | ZZx2 -> R² = -0.5007, R² diff = 0.4639
# theta | ZZxReto -> R² = -0.2254, R² diff = 0.4712
# theta | ZZy1 -> R² = -33.8256, R² diff = -0.0202
# theta | ZZy2 -> R² = 0.7290, R² diff = 0.6196
# theta | semiCirc -> R² = -16.2139, R² diff = 0.0358
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=6961 salvo.
# Epoch 0 | Train Loss 1.062474 | data Loss 1.034301 |  physics Loss 1.128214 | Val Loss 1.149698
# Epoch 100 | Train Loss 0.394976 | data Loss 0.338160 |  physics Loss 0.527548 | Val Loss 0.518197
# Epoch 200 | Train Loss 0.324388 | data Loss 0.296238 |  physics Loss 0.390070 | Val Loss 0.527589
# Epoch 300 | Train Loss 0.257642 | data Loss 0.235244 |  physics Loss 0.309904 | Val Loss 0.556680
# Early stopping at epoch 356
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed4080.keras
# theta | SuperZZ1 -> R² = 0.7563, R² diff = 0.6935
# theta | SuperZZ2 -> R² = -0.4332, R² diff = 0.5820
# theta | LSG-1 -> R² = -4.3884, R² diff = 0.4384
# theta | LSG-2 -> R² = -0.8960, R² diff = 0.4768
# theta | ZZx1-inv -> R² = 0.7802, R² diff = 0.6865
# theta | ZZx1 -> R² = -2.4776, R² diff = 0.3381
# theta | ZZx2-inv2 -> R² = -1.2616, R² diff = 0.3512
# theta | ZZx2 -> R² = -0.3429, R² diff = 0.5136
# theta | ZZxReto -> R² = -1.5466, R² diff = 0.2989
# theta | ZZy1 -> R² = -33.5496, R² diff = -0.1150
# theta | ZZy2 -> R² = 0.9396, R² diff = 0.6401
# theta | semiCirc -> R² = -12.4760, R² diff = 0.1418
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=4080 salvo.
# Epoch 0 | Train Loss 0.996398 | data Loss 0.972343 |  physics Loss 1.052526 | Val Loss 1.075840
# Epoch 100 | Train Loss 0.368951 | data Loss 0.326961 |  physics Loss 0.466928 | Val Loss 0.532884
# Epoch 200 | Train Loss 0.281967 | data Loss 0.255987 |  physics Loss 0.342586 | Val Loss 0.615258
# Epoch 300 | Train Loss 0.251775 | data Loss 0.224866 |  physics Loss 0.314562 | Val Loss 0.662916
# Early stopping at epoch 301
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed1097.keras
# theta | SuperZZ1 -> R² = 0.7859, R² diff = 0.6676
# theta | SuperZZ2 -> R² = -2.8379, R² diff = 0.5712
# theta | LSG-1 -> R² = -2.3442, R² diff = 0.4805
# theta | LSG-2 -> R² = -0.0662, R² diff = 0.4869
# theta | ZZx1-inv -> R² = 0.6549, R² diff = 0.7114
# theta | ZZx1 -> R² = -0.7515, R² diff = 0.4574
# theta | ZZx2-inv2 -> R² = -1.4570, R² diff = 0.4402
# theta | ZZx2 -> R² = 0.4734, R² diff = 0.4700
# theta | ZZxReto -> R² = -0.2860, R² diff = 0.4697
# theta | ZZy1 -> R² = -32.8597, R² diff = -0.0180
# theta | ZZy2 -> R² = 0.5577, R² diff = 0.6167
# theta | semiCirc -> R² = -15.6259, R² diff = 0.0299
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=1097 salvo.
# Epoch 0 | Train Loss 1.102659 | data Loss 1.082535 |  physics Loss 1.149614 | Val Loss 1.221648
# Epoch 100 | Train Loss 0.381197 | data Loss 0.335497 |  physics Loss 0.487832 | Val Loss 0.514563
# Epoch 200 | Train Loss 0.273672 | data Loss 0.250536 |  physics Loss 0.327657 | Val Loss 0.559245
# Epoch 300 | Train Loss 0.245220 | data Loss 0.218902 |  physics Loss 0.306628 | Val Loss 0.625771
# Early stopping at epoch 321
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed4916.keras
# theta | SuperZZ1 -> R² = 0.8924, R² diff = 0.6737
# theta | SuperZZ2 -> R² = -1.9983, R² diff = 0.5753
# theta | LSG-1 -> R² = -1.8535, R² diff = 0.4904
# theta | LSG-2 -> R² = 0.0357, R² diff = 0.4923
# theta | ZZx1-inv -> R² = 0.7079, R² diff = 0.7075
# theta | ZZx1 -> R² = -0.6211, R² diff = 0.4543
# theta | ZZx2-inv2 -> R² = -1.4575, R² diff = 0.4219
# theta | ZZx2 -> R² = 0.0834, R² diff = 0.4769
# theta | ZZxReto -> R² = -0.2863, R² diff = 0.4367
# theta | ZZy1 -> R² = -38.5738, R² diff = -0.0900
# theta | ZZy2 -> R² = 0.5993, R² diff = 0.6075
# theta | semiCirc -> R² = -13.2718, R² diff = 0.0694
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=4916 salvo.
# Epoch 0 | Train Loss 0.968740 | data Loss 0.941994 |  physics Loss 1.031149 | Val Loss 1.034187
# Epoch 100 | Train Loss 0.372462 | data Loss 0.335368 |  physics Loss 0.459015 | Val Loss 0.552361
# Epoch 200 | Train Loss 0.283371 | data Loss 0.260944 |  physics Loss 0.335701 | Val Loss 0.561778
# Epoch 300 | Train Loss 0.253045 | data Loss 0.229047 |  physics Loss 0.309042 | Val Loss 0.557478
# Early stopping at epoch 340
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed8685.keras
# theta | SuperZZ1 -> R² = 0.8676, R² diff = 0.6793
# theta | SuperZZ2 -> R² = -0.9508, R² diff = 0.5870
# theta | LSG-1 -> R² = -3.7314, R² diff = 0.4452
# theta | LSG-2 -> R² = -0.5523, R² diff = 0.4743
# theta | ZZx1-inv -> R² = 0.6980, R² diff = 0.6814
# theta | ZZx1 -> R² = -1.8989, R² diff = 0.3515
# theta | ZZx2-inv2 -> R² = -1.5718, R² diff = 0.3746
# theta | ZZx2 -> R² = -0.0154, R² diff = 0.4915
# theta | ZZxReto -> R² = -1.0739, R² diff = 0.3393
# theta | ZZy1 -> R² = -24.8481, R² diff = 0.0243
# theta | ZZy2 -> R² = 0.9453, R² diff = 0.6243
# theta | semiCirc -> R² = -12.2889, R² diff = 0.0897
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=8685 salvo.
# Epoch 0 | Train Loss 1.002310 | data Loss 0.972350 |  physics Loss 1.072218 | Val Loss 1.083575
# Epoch 100 | Train Loss 0.405763 | data Loss 0.342091 |  physics Loss 0.554333 | Val Loss 0.534512
# Epoch 200 | Train Loss 0.324841 | data Loss 0.303525 |  physics Loss 0.374580 | Val Loss 0.529258
# Epoch 300 | Train Loss 0.277028 | data Loss 0.254366 |  physics Loss 0.329905 | Val Loss 0.506765
# Epoch 400 | Train Loss 0.256263 | data Loss 0.233375 |  physics Loss 0.309668 | Val Loss 0.547608
# Early stopping at epoch 476
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed6961.keras
# theta | SuperZZ1 -> R² = 0.8015, R² diff = 0.7197
# theta | SuperZZ2 -> R² = -0.6668, R² diff = 0.6037
# theta | LSG-1 -> R² = -3.3071, R² diff = 0.4983
# theta | LSG-2 -> R² = -0.5043, R² diff = 0.5134
# theta | ZZx1-inv -> R² = 0.3959, R² diff = 0.6856
# theta | ZZx1 -> R² = -1.2471, R² diff = 0.3136
# theta | ZZx2-inv2 -> R² = -2.9558, R² diff = 0.2805
# theta | ZZx2 -> R² = -0.5337, R² diff = 0.5474
# theta | ZZxReto -> R² = -0.8636, R² diff = 0.2886
# theta | ZZy1 -> R² = -37.1233, R² diff = -0.0952
# theta | ZZy2 -> R² = 0.9129, R² diff = 0.6696
# theta | semiCirc -> R² = -10.6146, R² diff = 0.2281
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=6961 salvo.
# Epoch 0 | Train Loss 1.117092 | data Loss 1.095900 |  physics Loss 1.166540 | Val Loss 1.227802
# Epoch 100 | Train Loss 0.388007 | data Loss 0.335705 |  physics Loss 0.510046 | Val Loss 0.524538
# Epoch 200 | Train Loss 0.288575 | data Loss 0.260931 |  physics Loss 0.353077 | Val Loss 0.542577
# Epoch 300 | Train Loss 0.255904 | data Loss 0.230517 |  physics Loss 0.315141 | Val Loss 0.584265
# Early stopping at epoch 367
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed4080.keras
# theta | SuperZZ1 -> R² = 0.8102, R² diff = 0.7058
# theta | SuperZZ2 -> R² = -0.6403, R² diff = 0.5770
# theta | LSG-1 -> R² = -4.6361, R² diff = 0.4665
# theta | LSG-2 -> R² = -0.7555, R² diff = 0.4954
# theta | ZZx1-inv -> R² = 0.7500, R² diff = 0.6914
# theta | ZZx1 -> R² = -2.0772, R² diff = 0.3391
# theta | ZZx2-inv2 -> R² = -1.5234, R² diff = 0.3275
# theta | ZZx2 -> R² = -0.5837, R² diff = 0.5059
# theta | ZZxReto -> R² = -1.3224, R² diff = 0.3193
# theta | ZZy1 -> R² = -33.7712, R² diff = -0.1023
# theta | ZZy2 -> R² = 0.9197, R² diff = 0.6560
# theta | semiCirc -> R² = -13.2518, R² diff = 0.1387
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=4080 salvo.
# Epoch 0 | Train Loss 1.014243 | data Loss 0.955413 |  physics Loss 1.039456 | Val Loss 1.044371
# Epoch 100 | Train Loss 0.335241 | data Loss 0.407438 |  physics Loss 0.304300 | Val Loss 0.614346
# Epoch 200 | Train Loss 0.257215 | data Loss 0.339889 |  physics Loss 0.221784 | Val Loss 0.616230
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch87_r0.01_Ld0.3_Lp0.7_seed1097.keras
# theta | SuperZZ1 -> R² = 0.8447, R² diff = 0.6150
# theta | SuperZZ2 -> R² = -0.0241, R² diff = 0.5364
# theta | LSG-1 -> R² = -1.4210, R² diff = 0.4772
# theta | LSG-2 -> R² = 0.0626, R² diff = 0.4835
# theta | ZZx1-inv -> R² = 0.7509, R² diff = 0.6755
# theta | ZZx1 -> R² = -0.3060, R² diff = 0.4373
# theta | ZZx2-inv2 -> R² = 0.4398, R² diff = 0.4263
# theta | ZZx2 -> R² = -1.7019, R² diff = 0.3027
# theta | ZZxReto -> R² = -0.5033, R² diff = 0.3937
# theta | ZZy1 -> R² = -38.6367, R² diff = -0.1483
# theta | ZZy2 -> R² = 0.7488, R² diff = 0.5186
# theta | semiCirc -> R² = -10.1181, R² diff = 0.0704
# Modelo [87] | Ld=0.3 Lp=0.7 r=0.01 seed=1097 salvo.
# Epoch 0 | Train Loss 1.059924 | data Loss 0.992878 |  physics Loss 1.088658 | Val Loss 1.107756
# Epoch 100 | Train Loss 0.366592 | data Loss 0.386808 |  physics Loss 0.357928 | Val Loss 0.570081
# Epoch 200 | Train Loss 0.280030 | data Loss 0.367437 |  physics Loss 0.242569 | Val Loss 0.603235
# Early stopping at epoch 281
# Modelo salvo em:
# models/model_arch87_r0.01_Ld0.3_Lp0.7_seed4916.keras
# theta | SuperZZ1 -> R² = 0.8298, R² diff = 0.6092
# theta | SuperZZ2 -> R² = -0.1008, R² diff = 0.5422
# theta | LSG-1 -> R² = -0.7988, R² diff = 0.4794
# theta | LSG-2 -> R² = 0.3155, R² diff = 0.4843
# theta | ZZx1-inv -> R² = 0.6254, R² diff = 0.6715
# theta | ZZx1 -> R² = -0.1091, R² diff = 0.4454
# theta | ZZx2-inv2 -> R² = 0.6962, R² diff = 0.4517
# theta | ZZx2 -> R² = -2.5810, R² diff = 0.2548
# theta | ZZxReto -> R² = -0.6254, R² diff = 0.4290
# theta | ZZy1 -> R² = -34.1342, R² diff = -0.0712
# theta | ZZy2 -> R² = 0.6353, R² diff = 0.5276
# theta | semiCirc -> R² = -8.1062, R² diff = 0.1653
# Modelo [87] | Ld=0.3 Lp=0.7 r=0.01 seed=4916 salvo.
# Epoch 0 | Train Loss 1.092567 | data Loss 1.042926 |  physics Loss 1.113841 | Val Loss 1.185864
# Epoch 100 | Train Loss 0.365702 | data Loss 0.393278 |  physics Loss 0.353884 | Val Loss 0.567616
# Epoch 200 | Train Loss 0.277138 | data Loss 0.368786 |  physics Loss 0.237860 | Val Loss 0.627764
# Early stopping at epoch 289
# Modelo salvo em:
# models/model_arch87_r0.01_Ld0.3_Lp0.7_seed8685.keras
# theta | SuperZZ1 -> R² = 0.8584, R² diff = 0.6005
# theta | SuperZZ2 -> R² = -0.3029, R² diff = 0.5498
# theta | LSG-1 -> R² = -0.8794, R² diff = 0.4807
# theta | LSG-2 -> R² = 0.2512, R² diff = 0.4811
# theta | ZZx1-inv -> R² = 0.4569, R² diff = 0.6464
# theta | ZZx1 -> R² = -0.1907, R² diff = 0.4185
# theta | ZZx2-inv2 -> R² = 0.5649, R² diff = 0.4559
# theta | ZZx2 -> R² = -2.7650, R² diff = 0.2544
# theta | ZZxReto -> R² = -0.5615, R² diff = 0.4071
# theta | ZZy1 -> R² = -30.7005, R² diff = -0.0214
# theta | ZZy2 -> R² = 0.6850, R² diff = 0.5340
# theta | semiCirc -> R² = -8.3543, R² diff = 0.1865
# Modelo [87] | Ld=0.3 Lp=0.7 r=0.01 seed=8685 salvo.
# Epoch 0 | Train Loss 1.106924 | data Loss 1.057758 |  physics Loss 1.127995 | Val Loss 1.181340
# Epoch 100 | Train Loss 0.362255 | data Loss 0.392265 |  physics Loss 0.349394 | Val Loss 0.572505
# Epoch 200 | Train Loss 0.254656 | data Loss 0.334861 |  physics Loss 0.220282 | Val Loss 0.616459
# Early stopping at epoch 291
# Modelo salvo em:
# models/model_arch87_r0.01_Ld0.3_Lp0.7_seed6961.keras
# theta | SuperZZ1 -> R² = 0.7008, R² diff = 0.6114
# theta | SuperZZ2 -> R² = 0.2243, R² diff = 0.5369
# theta | LSG-1 -> R² = -2.2035, R² diff = 0.4734
# theta | LSG-2 -> R² = -0.4343, R² diff = 0.4752
# theta | ZZx1-inv -> R² = 0.8741, R² diff = 0.6626
# theta | ZZx1 -> R² = -0.7137, R² diff = 0.4249
# theta | ZZx2-inv2 -> R² = 0.7119, R² diff = 0.4362
# theta | ZZx2 -> R² = -1.3451, R² diff = 0.3378
# theta | ZZxReto -> R² = -0.2502, R² diff = 0.4080
# theta | ZZy1 -> R² = -30.9013, R² diff = -0.0612
# theta | ZZy2 -> R² = 0.8571, R² diff = 0.5279
# theta | semiCirc -> R² = -12.1257, R² diff = 0.0580
# Modelo [87] | Ld=0.3 Lp=0.7 r=0.01 seed=6961 salvo.
# ...
# theta | ZZxReto -> R² = -0.2360, R² diff = 0.4164
# theta | ZZy1 -> R² = -36.6022, R² diff = -0.1415
# theta | ZZy2 -> R² = 0.7708, R² diff = 0.5243
# theta | semiCirc -> R² = -11.8310, R² diff = 0.0427
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=1097 salvo.
# Epoch 0 | Train Loss 1.085501 | data Loss 1.035165 |  physics Loss 1.107074 | Val Loss 1.142307
# Epoch 100 | Train Loss 0.338357 | data Loss 0.413660 |  physics Loss 0.306084 | Val Loss 0.619547
# Epoch 200 | Train Loss 0.274130 | data Loss 0.357579 |  physics Loss 0.238367 | Val Loss 0.642644
# Epoch 300 | Train Loss 0.249918 | data Loss 0.336082 |  physics Loss 0.212990 | Val Loss 0.617645
# Epoch 400 | Train Loss 0.240432 | data Loss 0.328262 |  physics Loss 0.202791 | Val Loss 0.606769
# Early stopping at epoch 403
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed4916.keras
# theta | SuperZZ1 -> R² = 0.0023, R² diff = 0.6359
# theta | SuperZZ2 -> R² = 0.5782, R² diff = 0.5360
# theta | LSG-1 -> R² = -7.8489, R² diff = 0.5084
# theta | LSG-2 -> R² = -2.5151, R² diff = 0.5006
# theta | ZZx1-inv -> R² = 0.2434, R² diff = 0.5703
# theta | ZZx1 -> R² = -4.4600, R² diff = 0.2959
# theta | ZZx2-inv2 -> R² = 0.0451, R² diff = 0.3167
# theta | ZZx2 -> R² = -1.2694, R² diff = 0.3809
# theta | ZZxReto -> R² = -3.8030, R² diff = 0.3038
# theta | ZZy1 -> R² = -13.3938, R² diff = 0.1543
# theta | ZZy2 -> R² = 0.7102, R² diff = 0.5109
# theta | semiCirc -> R² = -16.5640, R² diff = -0.0752
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=4916 salvo.
# Epoch 0 | Train Loss 1.009391 | data Loss 0.943473 |  physics Loss 1.037641 | Val Loss 1.015587
# Epoch 100 | Train Loss 0.331576 | data Loss 0.405857 |  physics Loss 0.299742 | Val Loss 0.626294
# Epoch 200 | Train Loss 0.252457 | data Loss 0.328886 |  physics Loss 0.219701 | Val Loss 0.652834
# Early stopping at epoch 246
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed8685.keras
# theta | SuperZZ1 -> R² = 0.8040, R² diff = 0.6251
# theta | SuperZZ2 -> R² = -1.0837, R² diff = 0.5355
# theta | LSG-1 -> R² = -0.7662, R² diff = 0.5238
# theta | LSG-2 -> R² = 0.1768, R² diff = 0.4962
# theta | ZZx1-inv -> R² = 0.6822, R² diff = 0.7184
# theta | ZZx1 -> R² = 0.1286, R² diff = 0.4980
# theta | ZZx2-inv2 -> R² = -0.1124, R² diff = 0.4443
# theta | ZZx2 -> R² = -1.4284, R² diff = 0.4285
# theta | ZZxReto -> R² = -0.2015, R² diff = 0.5431
# theta | ZZy1 -> R² = -29.7803, R² diff = 0.0534
# theta | ZZy2 -> R² = 0.4296, R² diff = 0.5889
# theta | semiCirc -> R² = -17.2613, R² diff = 0.0646
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=8685 salvo.
# Epoch 0 | Train Loss 1.072403 | data Loss 1.015616 |  physics Loss 1.096741 | Val Loss 1.113210
# Epoch 100 | Train Loss 0.354962 | data Loss 0.401361 |  physics Loss 0.335077 | Val Loss 0.618379
# Epoch 200 | Train Loss 0.291792 | data Loss 0.365303 |  physics Loss 0.260286 | Val Loss 0.621982
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed6961.keras
# theta | SuperZZ1 -> R² = 0.7580, R² diff = 0.5945
# theta | SuperZZ2 -> R² = 0.4617, R² diff = 0.5297
# theta | LSG-1 -> R² = -1.2141, R² diff = 0.4463
# theta | LSG-2 -> R² = 0.1141, R² diff = 0.4644
# theta | ZZx1-inv -> R² = 0.6744, R² diff = 0.6477
# theta | ZZx1 -> R² = -0.3061, R² diff = 0.4149
# theta | ZZx2-inv2 -> R² = 0.8122, R² diff = 0.4145
# theta | ZZx2 -> R² = -2.2307, R² diff = 0.2293
# theta | ZZxReto -> R² = -0.5953, R² diff = 0.3778
# theta | ZZy1 -> R² = -36.6041, R² diff = -0.1730
# theta | ZZy2 -> R² = 0.8360, R² diff = 0.4952
# theta | semiCirc -> R² = -7.2299, R² diff = 0.1043
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=6961 salvo.
# Epoch 0 | Train Loss 0.975106 | data Loss 0.901748 |  physics Loss 1.006545 | Val Loss 0.972041
# Epoch 100 | Train Loss 0.333966 | data Loss 0.417251 |  physics Loss 0.298273 | Val Loss 0.622833
# Epoch 200 | Train Loss 0.266310 | data Loss 0.338239 |  physics Loss 0.235484 | Val Loss 0.625736
# Early stopping at epoch 270
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed4080.keras
# theta | SuperZZ1 -> R² = 0.8923, R² diff = 0.6078
# theta | SuperZZ2 -> R² = -0.1982, R² diff = 0.5418
# theta | LSG-1 -> R² = -0.7883, R² diff = 0.4938
# theta | LSG-2 -> R² = 0.3364, R² diff = 0.4863
# theta | ZZx1-inv -> R² = 0.4877, R² diff = 0.6575
# theta | ZZx1 -> R² = -0.0487, R² diff = 0.4468
# theta | ZZx2-inv2 -> R² = 0.5921, R² diff = 0.4508
# theta | ZZx2 -> R² = -1.1496, R² diff = 0.3238
# theta | ZZxReto -> R² = -0.7270, R² diff = 0.4272
# theta | ZZy1 -> R² = -39.7041, R² diff = -0.1227
# theta | ZZy2 -> R² = 0.5735, R² diff = 0.5233
# theta | semiCirc -> R² = -9.8973, R² diff = 0.1176
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=4080 salvo.
# Epoch 0 | Train Loss 0.963492 | data Loss 0.929871 |  physics Loss 1.041939 | Val Loss 0.997212
# Epoch 100 | Train Loss 0.366397 | data Loss 0.332566 |  physics Loss 0.445336 | Val Loss 0.544182
# Epoch 200 | Train Loss 0.281652 | data Loss 0.263672 |  physics Loss 0.323605 | Val Loss 0.492484
# Epoch 300 | Train Loss 0.248343 | data Loss 0.222387 |  physics Loss 0.308906 | Val Loss 0.591304
# Early stopping at epoch 334
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed1097.keras
# theta | SuperZZ1 -> R² = 0.7829, R² diff = 0.6717
# theta | SuperZZ2 -> R² = -1.6409, R² diff = 0.5851
# theta | LSG-1 -> R² = -2.6903, R² diff = 0.4079
# theta | LSG-2 -> R² = -0.7109, R² diff = 0.4551
# theta | ZZx1-inv -> R² = -0.2157, R² diff = 0.6523
# theta | ZZx1 -> R² = -1.1237, R² diff = 0.3031
# theta | ZZx2-inv2 -> R² = -3.1412, R² diff = 0.3274
# theta | ZZx2 -> R² = 0.2328, R² diff = 0.5026
# theta | ZZxReto -> R² = -0.9763, R² diff = 0.2547
# theta | ZZy1 -> R² = -40.1521, R² diff = -0.1937
# theta | ZZy2 -> R² = 0.9280, R² diff = 0.6279
# theta | semiCirc -> R² = -8.3090, R² diff = 0.2062
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=1097 salvo.
# Epoch 0 | Train Loss 0.910050 | data Loss 0.878288 |  physics Loss 0.984160 | Val Loss 0.931043
# Epoch 100 | Train Loss 0.345217 | data Loss 0.304736 |  physics Loss 0.439673 | Val Loss 0.532874
# Epoch 200 | Train Loss 0.273115 | data Loss 0.248352 |  physics Loss 0.330893 | Val Loss 0.498854
# Epoch 300 | Train Loss 0.245854 | data Loss 0.221733 |  physics Loss 0.302135 | Val Loss 0.582535
# Epoch 400 | Train Loss 0.230750 | data Loss 0.202753 |  physics Loss 0.296076 | Val Loss 0.673832
# Early stopping at epoch 444
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed4916.keras
# theta | SuperZZ1 -> R² = 0.4594, R² diff = 0.7564
# theta | SuperZZ2 -> R² = 0.3043, R² diff = 0.5850
# theta | LSG-1 -> R² = -3.8271, R² diff = 0.5913
# theta | LSG-2 -> R² = -1.4447, R² diff = 0.5720
# theta | ZZx1-inv -> R² = 0.7659, R² diff = 0.6852
# theta | ZZx1 -> R² = -1.3164, R² diff = 0.4180
# theta | ZZx2-inv2 -> R² = -2.5659, R² diff = 0.1833
# theta | ZZx2 -> R² = 0.1543, R² diff = 0.5571
# theta | ZZxReto -> R² = -0.4916, R² diff = 0.4618
# theta | ZZy1 -> R² = -19.7265, R² diff = 0.1769
# theta | ZZy2 -> R² = 0.7172, R² diff = 0.6545
# theta | semiCirc -> R² = -8.1161, R² diff = 0.3241
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=4916 salvo.
# Epoch 0 | Train Loss 0.978030 | data Loss 0.947715 |  physics Loss 1.048766 | Val Loss 1.025361
# Epoch 100 | Train Loss 0.373011 | data Loss 0.334604 |  physics Loss 0.462626 | Val Loss 0.512662
# Epoch 200 | Train Loss 0.298734 | data Loss 0.280434 |  physics Loss 0.341433 | Val Loss 0.530370
# Epoch 300 | Train Loss 0.252444 | data Loss 0.227444 |  physics Loss 0.310778 | Val Loss 0.568717
# Early stopping at epoch 303
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed8685.keras
# theta | SuperZZ1 -> R² = 0.7730, R² diff = 0.6620
# theta | SuperZZ2 -> R² = -0.3433, R² diff = 0.5910
# theta | LSG-1 -> R² = -3.2499, R² diff = 0.5118
# theta | LSG-2 -> R² = -0.8987, R² diff = 0.4968
# theta | ZZx1-inv -> R² = 0.8833, R² diff = 0.7075
# theta | ZZx1 -> R² = -0.7603, R² diff = 0.4555
# theta | ZZx2-inv2 -> R² = 0.3544, R² diff = 0.4821
# theta | ZZx2 -> R² = -0.8697, R² diff = 0.4209
# theta | ZZxReto -> R² = -0.2095, R² diff = 0.4929
# theta | ZZy1 -> R² = -30.9850, R² diff = 0.0175
# theta | ZZy2 -> R² = 0.8827, R² diff = 0.6211
# theta | semiCirc -> R² = -18.8112, R² diff = -0.0144
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=8685 salvo.
# Epoch 0 | Train Loss 1.084301 | data Loss 1.062240 |  physics Loss 1.135776 | Val Loss 1.163144
# Epoch 100 | Train Loss 0.369934 | data Loss 0.325592 |  physics Loss 0.473397 | Val Loss 0.523892
# Epoch 200 | Train Loss 0.280912 | data Loss 0.256699 |  physics Loss 0.337409 | Val Loss 0.529622
# Epoch 300 | Train Loss 0.247196 | data Loss 0.226294 |  physics Loss 0.295968 | Val Loss 0.632432
# Early stopping at epoch 309
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed6961.keras
# theta | SuperZZ1 -> R² = 0.8105, R² diff = 0.6743
# theta | SuperZZ2 -> R² = -0.5927, R² diff = 0.5785
# theta | LSG-1 -> R² = -4.1516, R² diff = 0.4519
# theta | LSG-2 -> R² = -0.9542, R² diff = 0.4789
# theta | ZZx1-inv -> R² = 0.7877, R² diff = 0.6975
# theta | ZZx1 -> R² = -1.9732, R² diff = 0.4003
# theta | ZZx2-inv2 -> R² = -0.5889, R² diff = 0.4039
# theta | ZZx2 -> R² = -0.7756, R² diff = 0.4458
# theta | ZZxReto -> R² = -1.1554, R² diff = 0.3786
# theta | ZZy1 -> R² = -34.9636, R² diff = -0.1188
# theta | ZZy2 -> R² = 0.9305, R² diff = 0.6207
# theta | semiCirc -> R² = -16.4350, R² diff = 0.0034
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=6961 salvo.
# Epoch 0 | Train Loss 1.010862 | data Loss 0.984417 |  physics Loss 1.072565 | Val Loss 1.046177
# Epoch 100 | Train Loss 0.360952 | data Loss 0.318978 |  physics Loss 0.458893 | Val Loss 0.555506
# Epoch 200 | Train Loss 0.289158 | data Loss 0.262715 |  physics Loss 0.350857 | Val Loss 0.579103
# Epoch 300 | Train Loss 0.253077 | data Loss 0.230846 |  physics Loss 0.304950 | Val Loss 0.611532
# Early stopping at epoch 323
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed4080.keras
# theta | SuperZZ1 -> R² = 0.7955, R² diff = 0.6547
# theta | SuperZZ2 -> R² = 0.0670, R² diff = 0.5889
# theta | LSG-1 -> R² = -5.4608, R² diff = 0.3573
# theta | LSG-2 -> R² = -1.2758, R² diff = 0.4353
# theta | ZZx1-inv -> R² = 0.5438, R² diff = 0.6257
# theta | ZZx1 -> R² = -3.0823, R² diff = 0.2417
# theta | ZZx2-inv2 -> R² = -0.9221, R² diff = 0.3635
# theta | ZZx2 -> R² = -0.5620, R² diff = 0.4292
# theta | ZZxReto -> R² = -2.2999, R² diff = 0.2011
# theta | ZZy1 -> R² = -30.6268, R² diff = -0.1609
# theta | ZZy2 -> R² = 0.7068, R² diff = 0.6299
# theta | semiCirc -> R² = -11.3817, R² diff = 0.1232
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=4080 salvo.
# Epoch 0 | Train Loss 1.148180 | data Loss 1.126376 |  physics Loss 1.199056 | Val Loss 1.241950
# Epoch 100 | Train Loss 0.368775 | data Loss 0.332388 |  physics Loss 0.453680 | Val Loss 0.509108
# Epoch 200 | Train Loss 0.287967 | data Loss 0.264590 |  physics Loss 0.342511 | Val Loss 0.530471
# Epoch 300 | Train Loss 0.262944 | data Loss 0.227092 |  physics Loss 0.346598 | Val Loss 0.605246
# Early stopping at epoch 305
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed1097.keras
# theta | SuperZZ1 -> R² = 0.8931, R² diff = 0.6594
# theta | SuperZZ2 -> R² = -1.1931, R² diff = 0.5946
# theta | LSG-1 -> R² = -1.3324, R² diff = 0.5169
# theta | LSG-2 -> R² = 0.2479, R² diff = 0.5044
# theta | ZZx1-inv -> R² = 0.4476, R² diff = 0.7062
# theta | ZZx1 -> R² = -0.1932, R² diff = 0.4641
# theta | ZZx2-inv2 -> R² = -0.1799, R² diff = 0.4871
# theta | ZZx2 -> R² = -0.8714, R² diff = 0.4302
# theta | ZZxReto -> R² = -0.1906, R² diff = 0.4761
# theta | ZZy1 -> R² = -33.6673, R² diff = 0.0052
# theta | ZZy2 -> R² = 0.6487, R² diff = 0.6071
# theta | semiCirc -> R² = -13.8028, R² diff = 0.0920
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=1097 salvo.
# Epoch 0 | Train Loss 1.018864 | data Loss 0.993476 |  physics Loss 1.078104 | Val Loss 1.081136
# Epoch 100 | Train Loss 0.368237 | data Loss 0.325342 |  physics Loss 0.468325 | Val Loss 0.522391
# Epoch 200 | Train Loss 0.266077 | data Loss 0.244952 |  physics Loss 0.315371 | Val Loss 0.540316
# Epoch 300 | Train Loss 0.240555 | data Loss 0.214859 |  physics Loss 0.300512 | Val Loss 0.583925
# Early stopping at epoch 357
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed4916.keras
# theta | SuperZZ1 -> R² = 0.6956, R² diff = 0.7241
# theta | SuperZZ2 -> R² = -0.6699, R² diff = 0.5824
# theta | LSG-1 -> R² = -4.0495, R² diff = 0.5046
# theta | LSG-2 -> R² = -0.7343, R² diff = 0.5195
# theta | ZZx1-inv -> R² = 0.7948, R² diff = 0.6999
# theta | ZZx1 -> R² = -1.8979, R² diff = 0.3582
# theta | ZZx2-inv2 -> R² = -2.0008, R² diff = 0.2906
# theta | ZZx2 -> R² = -0.7416, R² diff = 0.5430
# theta | ZZxReto -> R² = -1.0058, R² diff = 0.3372
# theta | ZZy1 -> R² = -32.6896, R² diff = -0.0484
# theta | ZZy2 -> R² = 0.8994, R² diff = 0.6716
# theta | semiCirc -> R² = -14.3128, R² diff = 0.1637
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=4916 salvo.
# Epoch 0 | Train Loss 1.019535 | data Loss 0.994538 |  physics Loss 1.077863 | Val Loss 1.075665
# Epoch 100 | Train Loss 0.382801 | data Loss 0.337643 |  physics Loss 0.488169 | Val Loss 0.524412
# Epoch 200 | Train Loss 0.285707 | data Loss 0.263290 |  physics Loss 0.338015 | Val Loss 0.610669
# Epoch 300 | Train Loss 0.250252 | data Loss 0.222550 |  physics Loss 0.314890 | Val Loss 0.646436
# Early stopping at epoch 302
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed8685.keras
# theta | SuperZZ1 -> R² = 0.9190, R² diff = 0.6632
# theta | SuperZZ2 -> R² = -1.4165, R² diff = 0.5766
# theta | LSG-1 -> R² = -1.7775, R² diff = 0.5384
# theta | LSG-2 -> R² = -0.0001, R² diff = 0.5095
# theta | ZZx1-inv -> R² = 0.7439, R² diff = 0.7259
# theta | ZZx1 -> R² = -0.0519, R² diff = 0.4942
# theta | ZZx2-inv2 -> R² = -0.0586, R² diff = 0.4813
# theta | ZZx2 -> R² = -0.7680, R² diff = 0.4378
# theta | ZZxReto -> R² = 0.0792, R² diff = 0.5382
# theta | ZZy1 -> R² = -33.5245, R² diff = 0.0268
# theta | ZZy2 -> R² = 0.5886, R² diff = 0.6151
# theta | semiCirc -> R² = -18.7705, R² diff = 0.0127
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=8685 salvo.
# Epoch 0 | Train Loss 1.051282 | data Loss 1.027864 |  physics Loss 1.105926 | Val Loss 1.121880
# Epoch 100 | Train Loss 0.374883 | data Loss 0.329000 |  physics Loss 0.481943 | Val Loss 0.623324
# Epoch 200 | Train Loss 0.280692 | data Loss 0.252712 |  physics Loss 0.345980 | Val Loss 0.555950
# Epoch 300 | Train Loss 0.248763 | data Loss 0.226254 |  physics Loss 0.301282 | Val Loss 0.638512
# Early stopping at epoch 301
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed6961.keras
# theta | SuperZZ1 -> R² = 0.3777, R² diff = 0.6659
# theta | SuperZZ2 -> R² = 0.2004, R² diff = 0.5822
# theta | LSG-1 -> R² = -6.3414, R² diff = 0.4116
# theta | LSG-2 -> R² = -2.1153, R² diff = 0.4590
# theta | ZZx1-inv -> R² = 0.4959, R² diff = 0.6907
# theta | ZZx1 -> R² = -3.5141, R² diff = 0.3559
# theta | ZZx2-inv2 -> R² = -0.1756, R² diff = 0.3920
# theta | ZZx2 -> R² = -1.4046, R² diff = 0.4276
# theta | ZZxReto -> R² = -2.3032, R² diff = 0.3408
# theta | ZZy1 -> R² = -32.3221, R² diff = -0.1360
# theta | ZZy2 -> R² = 0.7635, R² diff = 0.6278
# theta | semiCirc -> R² = -19.1936, R² diff = -0.0389
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=6961 salvo.
# Epoch 0 | Train Loss 0.960230 | data Loss 0.928984 |  physics Loss 1.033137 | Val Loss 1.001856
# Epoch 100 | Train Loss 0.357429 | data Loss 0.328110 |  physics Loss 0.425838 | Val Loss 0.517190
# Epoch 200 | Train Loss 0.271683 | data Loss 0.251904 |  physics Loss 0.317833 | Val Loss 0.504958
# Epoch 300 | Train Loss 0.246954 | data Loss 0.223775 |  physics Loss 0.301038 | Val Loss 0.561833
# Early stopping at epoch 379
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed4080.keras
# theta | SuperZZ1 -> R² = 0.8279, R² diff = 0.7361
# theta | SuperZZ2 -> R² = -1.1995, R² diff = 0.6064
# theta | LSG-1 -> R² = -2.0551, R² diff = 0.5665
# theta | LSG-2 -> R² = 0.0321, R² diff = 0.5493
# theta | ZZx1-inv -> R² = 0.6075, R² diff = 0.7080
# theta | ZZx1 -> R² = -0.7450, R² diff = 0.4069
# theta | ZZx2-inv2 -> R² = -2.3781, R² diff = 0.3462
# theta | ZZx2 -> R² = -0.8503, R² diff = 0.5724
# theta | ZZxReto -> R² = -0.4130, R² diff = 0.4016
# theta | ZZy1 -> R² = -28.1885, R² diff = 0.0889
# theta | ZZy2 -> R² = 0.8468, R² diff = 0.6768
# theta | semiCirc -> R² = -11.7011, R² diff = 0.2288
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=4080 salvo.
