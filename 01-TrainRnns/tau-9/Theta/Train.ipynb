# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = [
    "SuperZZ1",
    "SuperZZ2",
    "LSG-1",
    "LSG-2",
    "ZZx1-inv",
    "ZZx1",
    "ZZx2-inv2",
    "ZZx2",
    "ZZxReto",
    "ZZy1",
    "ZZy2",
    "semiCirc",
]

PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a"]   
TARGET_INT = ["theta"]  
TARGET = ["dtheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 9
TS = 0.07
PLOT = False
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for title in TITLES:
    df = pd.read_excel("./../../00-Data/SavgolDatasets.xlsx", sheet_name=title)
    Datasets.append(df)

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["Se_a"] = Dataset["e_a_d"] + Dataset["e_a_e"]
    Dataset["De_a"] = Dataset["e_a_d"] - Dataset["e_a_e"]

    Dataset = Dataset.dropna(subset=[f"d{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train = Train1

# Train2 = Datasets[1].copy()
# Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
# Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
# NormDatasets.append(Train2)

# # concatena
# Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(len(TITLES)-1):
    CurrentTestDataset = Datasets[i + 1].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = NormDatasets[1]

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (2212, 9, 4)
# Dimensão da saida: (2212, 1)
# Dimensão da entrada: (3057, 9, 4)
# Dimensão da saida: (3057, 1)

# %%
phi_d_train =  Train["phi_d"].values[:len(x_train)]
phi_e_train =  Train["phi_e"].values[:len(x_train)]
theta_train = Train["theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(phi_d_train)}")
print(f"Dimensão da entrada fisica: {np.shape(phi_e_train)}")
# Out:
# Dimensão da entrada: (2212, 9, 4)
# Dimensão da saida: (2212, 1)
# Dimensão da entrada fisica : (2212,)
# Dimensão da entrada fisica: (2212,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):

    dtheta_cin = (R / (2 * L)) * (phi_d - phi_e)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(dq).T, np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, phi_d, phi_e, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(phi_d, phi_e, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss, data_loss, physics_loss

# %%
phi_d_train = tf.convert_to_tensor(phi_d_train, dtype=tf.float32)
phi_e_train = tf.convert_to_tensor(phi_e_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss, data_loss, physics_loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          phi_d_train, phi_e_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | data Loss {data_loss.numpy():.6f} |  physics Loss {physics_loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_mse = f"MSE_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_mse, []).append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {mse:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"MSE_{safe_title}_{name}"] = to_scalar(metrics[name][f"MSE_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    #os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    #weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    #model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}")

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import initializers
from itertools import product
import numpy as np
import tensorflow as tf

N_MODELS = 5

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[n] for n in range(85, 101)]


# FirstLayers = [
#     [27], [30], [32], [35], [36], [37], [40],
#     [42], [44], [46], [49], [50], [52], [75],
# ]

# architectures = [
#     [fl[0], sl]
#     for fl in FirstLayers
#     for sl in range(
#         max(1, int(0.3 * fl[0])),
#         int(0.7 * fl[0])
#     )
# ]

# 🔹 retomar a partir do último modelo salvo
# last_saved = [27, 12]

# if last_saved in architectures:
#     idx = architectures.index(last_saved)
#     architectures = architectures[idx + 1:]  # começa DEPOIS do último salvo
#     print(f"Retomando a partir de {last_saved} (índice {idx}). Restam {len(architectures)} arquiteturas.")
# else:
#     print(f"⚠️ {last_saved} não encontrado na lista — rodando tudo do zero.")

print(len(architectures))
print(architectures)

Ld_Lp = [[0.3, 0.7], [0.7, 0.3]]
r_values = [0.01, 0.9]

results = {}

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados-1l-v2.xlsx")
# Out:
# 16
# [[85], [86], [87], [88], [89], [90], [91], [92], [93], [94], [95], [96], [97], [98], [99], [100]]
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 1.060312 | data Loss 0.987623 |  physics Loss 1.091464 | Val Loss 1.053870
# Epoch 100 | Train Loss 0.384149 | data Loss 0.489314 |  physics Loss 0.339079 | Val Loss 0.738370
# Epoch 200 | Train Loss 0.337662 | data Loss 0.469199 |  physics Loss 0.281289 | Val Loss 0.707985
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed4485.keras
# theta | SuperZZ1 -> R² = 0.8263, R² diff = 0.5872
# theta | SuperZZ2 -> R² = -1.8299, R² diff = 0.4869
# theta | LSG-1 -> R² = -0.8658, R² diff = 0.5156
# theta | LSG-2 -> R² = 0.3478, R² diff = 0.4926
# theta | ZZx1-inv -> R² = 0.6337, R² diff = 0.7014
# theta | ZZx1 -> R² = 0.0776, R² diff = 0.4632
# theta | ZZx2-inv2 -> R² = -0.6022, R² diff = 0.3724
# theta | ZZx2 -> R² = -2.4160, R² diff = 0.3455
# theta | ZZxReto -> R² = -0.0507, R² diff = 0.5184
# theta | ZZy1 -> R² = -25.0855, R² diff = 0.0919
# theta | ZZy2 -> R² = 0.4464, R² diff = 0.5356
# theta | semiCirc -> R² = -16.2216, R² diff = 0.1023
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=4485 salvo.
# Epoch 0 | Train Loss 1.081016 | data Loss 1.018787 |  physics Loss 1.107685 | Val Loss 1.119480
# Epoch 100 | Train Loss 0.407888 | data Loss 0.520012 |  physics Loss 0.359835 | Val Loss 0.696834
# Epoch 200 | Train Loss 0.327265 | data Loss 0.457355 |  physics Loss 0.271512 | Val Loss 0.699092
# Early stopping at epoch 229
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed1627.keras
# theta | SuperZZ1 -> R² = 0.7798, R² diff = 0.5667
# theta | SuperZZ2 -> R² = -1.1751, R² diff = 0.4834
# theta | LSG-1 -> R² = -0.5453, R² diff = 0.4836
# theta | LSG-2 -> R² = 0.2573, R² diff = 0.4647
# theta | ZZx1-inv -> R² = 0.3750, R² diff = 0.6783
# theta | ZZx1 -> R² = 0.1120, R² diff = 0.4333
# theta | ZZx2-inv2 -> R² = -0.5621, R² diff = 0.3833
# theta | ZZx2 -> R² = -0.3588, R² diff = 0.4182
# theta | ZZxReto -> R² = -0.3825, R² diff = 0.5262
# theta | ZZy1 -> R² = -24.9940, R² diff = 0.0988
# theta | ZZy2 -> R² = 0.4112, R² diff = 0.5273
# theta | semiCirc -> R² = -14.9006, R² diff = 0.1275
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=1627 salvo.
# Epoch 0 | Train Loss 1.026007 | data Loss 0.944475 |  physics Loss 1.060949 | Val Loss 1.001142
# Epoch 100 | Train Loss 0.392470 | data Loss 0.504240 |  physics Loss 0.344568 | Val Loss 0.700069
# Epoch 200 | Train Loss 0.331929 | data Loss 0.476071 |  physics Loss 0.270153 | Val Loss 0.637007
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed7931.keras
# theta | SuperZZ1 -> R² = 0.7875, R² diff = 0.5591
# theta | SuperZZ2 -> R² = -1.5783, R² diff = 0.4930
# theta | LSG-1 -> R² = -0.2588, R² diff = 0.4916
# theta | LSG-2 -> R² = 0.3962, R² diff = 0.4559
# theta | ZZx1-inv -> R² = 0.5684, R² diff = 0.6710
# theta | ZZx1 -> R² = 0.1696, R² diff = 0.4529
# theta | ZZx2-inv2 -> R² = -0.3764, R² diff = 0.4014
# theta | ZZx2 -> R² = -1.6932, R² diff = 0.3784
# theta | ZZxReto -> R² = 0.1766, R² diff = 0.5340
# theta | ZZy1 -> R² = -17.6958, R² diff = 0.1736
# theta | ZZy2 -> R² = 0.2610, R² diff = 0.5409
# theta | semiCirc -> R² = -13.6803, R² diff = 0.1618
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=7931 salvo.
# Epoch 0 | Train Loss 1.013709 | data Loss 0.933275 |  physics Loss 1.048181 | Val Loss 1.000832
# Epoch 100 | Train Loss 0.389797 | data Loss 0.506274 |  physics Loss 0.339878 | Val Loss 0.709758
# Epoch 200 | Train Loss 0.325617 | data Loss 0.467508 |  physics Loss 0.264807 | Val Loss 0.676007
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed8994.keras
# theta | SuperZZ1 -> R² = 0.7510, R² diff = 0.5741
# theta | SuperZZ2 -> R² = -1.2762, R² diff = 0.4817
# theta | LSG-1 -> R² = -0.5087, R² diff = 0.4969
# theta | LSG-2 -> R² = 0.3660, R² diff = 0.4816
# theta | ZZx1-inv -> R² = 0.5537, R² diff = 0.6878
# theta | ZZx1 -> R² = 0.0599, R² diff = 0.4531
# theta | ZZx2-inv2 -> R² = -0.2161, R² diff = 0.3909
# theta | ZZx2 -> R² = -1.9087, R² diff = 0.3559
# theta | ZZxReto -> R² = -0.2064, R² diff = 0.5109
# theta | ZZy1 -> R² = -22.5218, R² diff = 0.1185
# theta | ZZy2 -> R² = 0.3868, R² diff = 0.5337
# theta | semiCirc -> R² = -13.8451, R² diff = 0.1504
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=8994 salvo.
# Epoch 0 | Train Loss 1.043605 | data Loss 0.975584 |  physics Loss 1.072757 | Val Loss 1.083193
# Epoch 100 | Train Loss 0.373621 | data Loss 0.503350 |  physics Loss 0.318023 | Val Loss 0.697165
# Epoch 200 | Train Loss 0.311335 | data Loss 0.457537 |  physics Loss 0.248677 | Val Loss 0.698003
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.3_Lp0.7_seed7257.keras
# theta | SuperZZ1 -> R² = 0.7013, R² diff = 0.5595
# theta | SuperZZ2 -> R² = -0.8449, R² diff = 0.5004
# theta | LSG-1 -> R² = -0.1561, R² diff = 0.4993
# theta | LSG-2 -> R² = 0.3792, R² diff = 0.4542
# theta | ZZx1-inv -> R² = 0.5270, R² diff = 0.6514
# theta | ZZx1 -> R² = 0.1728, R² diff = 0.4478
# theta | ZZx2-inv2 -> R² = 0.1672, R² diff = 0.4332
# theta | ZZx2 -> R² = -1.2015, R² diff = 0.4002
# theta | ZZxReto -> R² = -0.0148, R² diff = 0.5320
# theta | ZZy1 -> R² = -18.0686, R² diff = 0.1796
# theta | ZZy2 -> R² = 0.2815, R² diff = 0.5417
# theta | semiCirc -> R² = -13.4253, R² diff = 0.1594
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.01 seed=7257 salvo.
# Epoch 0 | Train Loss 1.308900 | data Loss 1.234558 |  physics Loss 1.340761 | Val Loss 1.322106
# Epoch 100 | Train Loss 0.396133 | data Loss 0.516488 |  physics Loss 0.344553 | Val Loss 0.695535
# Epoch 200 | Train Loss 0.308057 | data Loss 0.481950 |  physics Loss 0.233532 | Val Loss 0.698211
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed4485.keras
# theta | SuperZZ1 -> R² = 0.6824, R² diff = 0.5771
# theta | SuperZZ2 -> R² = -0.9086, R² diff = 0.5086
# theta | LSG-1 -> R² = -0.7279, R² diff = 0.4975
# theta | LSG-2 -> R² = 0.2306, R² diff = 0.4655
# theta | ZZx1-inv -> R² = 0.6534, R² diff = 0.6817
# theta | ZZx1 -> R² = 0.0972, R² diff = 0.4430
# theta | ZZx2-inv2 -> R² = -0.1608, R² diff = 0.4036
# theta | ZZx2 -> R² = -1.5334, R² diff = 0.4031
# theta | ZZxReto -> R² = 0.1441, R² diff = 0.5295
# theta | ZZy1 -> R² = -20.4729, R² diff = 0.1398
# theta | ZZy2 -> R² = 0.5962, R² diff = 0.5581
# theta | semiCirc -> R² = -15.8237, R² diff = 0.1174
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=4485 salvo.
# Epoch 0 | Train Loss 1.129618 | data Loss 1.105836 |  physics Loss 1.139809 | Val Loss 1.246126
# Epoch 100 | Train Loss 0.374470 | data Loss 0.492624 |  physics Loss 0.323833 | Val Loss 0.733355
# Epoch 200 | Train Loss 0.318552 | data Loss 0.481215 |  physics Loss 0.248839 | Val Loss 0.712943
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed1627.keras
# theta | SuperZZ1 -> R² = 0.6212, R² diff = 0.5418
# theta | SuperZZ2 -> R² = -1.0822, R² diff = 0.4707
# theta | LSG-1 -> R² = -0.2879, R² diff = 0.4756
# theta | LSG-2 -> R² = 0.2331, R² diff = 0.4393
# theta | ZZx1-inv -> R² = 0.7063, R² diff = 0.6346
# theta | ZZx1 -> R² = 0.1775, R² diff = 0.4260
# theta | ZZx2-inv2 -> R² = -0.1337, R² diff = 0.3905
# theta | ZZx2 -> R² = -0.8445, R² diff = 0.3977
# theta | ZZxReto -> R² = 0.0946, R² diff = 0.5054
# theta | ZZy1 -> R² = -17.8469, R² diff = 0.1661
# theta | ZZy2 -> R² = 0.2817, R² diff = 0.5107
# theta | semiCirc -> R² = -12.4828, R² diff = 0.1705
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=1627 salvo.
# Epoch 0 | Train Loss 0.964831 | data Loss 0.845064 |  physics Loss 1.016160 | Val Loss 0.906894
# Epoch 100 | Train Loss 0.381335 | data Loss 0.506833 |  physics Loss 0.327550 | Val Loss 0.702954
# Epoch 200 | Train Loss 0.317711 | data Loss 0.464963 |  physics Loss 0.254603 | Val Loss 0.696111
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed7931.keras
# theta | SuperZZ1 -> R² = 0.8000, R² diff = 0.5842
# theta | SuperZZ2 -> R² = -1.2418, R² diff = 0.4979
# theta | LSG-1 -> R² = -0.7934, R² diff = 0.5082
# theta | LSG-2 -> R² = 0.2643, R² diff = 0.4805
# theta | ZZx1-inv -> R² = 0.5252, R² diff = 0.6943
# theta | ZZx1 -> R² = 0.1545, R² diff = 0.4629
# theta | ZZx2-inv2 -> R² = -0.3598, R² diff = 0.4005
# theta | ZZx2 -> R² = -1.0027, R² diff = 0.4157
# theta | ZZxReto -> R² = -0.1722, R² diff = 0.5388
# theta | ZZy1 -> R² = -26.7830, R² diff = 0.0814
# theta | ZZy2 -> R² = 0.4501, R² diff = 0.5439
# theta | semiCirc -> R² = -18.0027, R² diff = 0.0581
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=7931 salvo.
# Epoch 0 | Train Loss 1.043148 | data Loss 0.971406 |  physics Loss 1.073895 | Val Loss 1.052080
# Epoch 100 | Train Loss 0.379727 | data Loss 0.500240 |  physics Loss 0.328078 | Val Loss 0.675437
# Epoch 200 | Train Loss 0.317090 | data Loss 0.430478 |  physics Loss 0.268495 | Val Loss 0.678136
# Early stopping at epoch 250
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed8994.keras
# theta | SuperZZ1 -> R² = 0.3841, R² diff = 0.5212
# theta | SuperZZ2 -> R² = 0.5244, R² diff = 0.4791
# theta | LSG-1 -> R² = -1.0849, R² diff = 0.4358
# theta | LSG-2 -> R² = 0.0888, R² diff = 0.4426
# theta | ZZx1-inv -> R² = 0.7621, R² diff = 0.5570
# theta | ZZx1 -> R² = -0.1523, R² diff = 0.3521
# theta | ZZx2-inv2 -> R² = 0.8265, R² diff = 0.3959
# theta | ZZx2 -> R² = -2.5164, R² diff = 0.2456
# theta | ZZxReto -> R² = -0.4863, R² diff = 0.3559
# theta | ZZy1 -> R² = -30.2679, R² diff = -0.0667
# theta | ZZy2 -> R² = 0.8809, R² diff = 0.4593
# theta | semiCirc -> R² = -9.3326, R² diff = 0.1638
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=8994 salvo.
# Epoch 0 | Train Loss 1.056826 | data Loss 0.977394 |  physics Loss 1.090869 | Val Loss 1.086490
# Epoch 100 | Train Loss 0.375836 | data Loss 0.516378 |  physics Loss 0.315604 | Val Loss 0.735398
# Epoch 200 | Train Loss 0.310921 | data Loss 0.464557 |  physics Loss 0.245076 | Val Loss 0.677581
# Early stopping at epoch 255
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.3_Lp0.7_seed7257.keras
# theta | SuperZZ1 -> R² = 0.8331, R² diff = 0.5095
# theta | SuperZZ2 -> R² = 0.0655, R² diff = 0.4777
# theta | LSG-1 -> R² = -1.5355, R² diff = 0.3925
# theta | LSG-2 -> R² = -0.0083, R² diff = 0.4387
# theta | ZZx1-inv -> R² = 0.2828, R² diff = 0.5329
# theta | ZZx1 -> R² = -0.3722, R² diff = 0.3055
# theta | ZZx2-inv2 -> R² = 0.4146, R² diff = 0.3783
# theta | ZZx2 -> R² = -1.3907, R² diff = 0.2223
# theta | ZZxReto -> R² = -1.0625, R² diff = 0.2589
# theta | ZZy1 -> R² = -43.1315, R² diff = -0.2627
# theta | ZZy2 -> R² = 0.8606, R² diff = 0.4435
# theta | semiCirc -> R² = -9.1978, R² diff = 0.1042
# Modelo [85] | Ld=0.3 Lp=0.7 r=0.9 seed=7257 salvo.
# Epoch 0 | Train Loss 0.982957 | data Loss 0.945460 |  physics Loss 1.070447 | Val Loss 1.043174
# Epoch 100 | Train Loss 0.392020 | data Loss 0.334131 |  physics Loss 0.527094 | Val Loss 0.569306
# Epoch 200 | Train Loss 0.341806 | data Loss 0.290914 |  physics Loss 0.460552 | Val Loss 0.536303
# Epoch 300 | Train Loss 0.308057 | data Loss 0.253504 |  physics Loss 0.435346 | Val Loss 0.627209
# Early stopping at epoch 386
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed4485.keras
# theta | SuperZZ1 -> R² = 0.8038, R² diff = 0.6470
# theta | SuperZZ2 -> R² = 0.2725, R² diff = 0.5678
# theta | LSG-1 -> R² = -3.2850, R² diff = 0.3692
# theta | LSG-2 -> R² = -1.8498, R² diff = 0.4346
# theta | ZZx1-inv -> R² = -0.3458, R² diff = 0.5467
# theta | ZZx1 -> R² = -1.4651, R² diff = 0.2170
# theta | ZZx2-inv2 -> R² = -1.6844, R² diff = 0.2703
# theta | ZZx2 -> R² = -0.0313, R² diff = 0.4666
# theta | ZZxReto -> R² = -1.0535, R² diff = 0.1966
# theta | ZZy1 -> R² = -33.7705, R² diff = -0.1773
# theta | ZZy2 -> R² = 0.7170, R² diff = 0.6097
# theta | semiCirc -> R² = -4.8143, R² diff = 0.3879
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=4485 salvo.
# Epoch 0 | Train Loss 0.978763 | data Loss 0.949361 |  physics Loss 1.047368 | Val Loss 1.062564
# Epoch 100 | Train Loss 0.393145 | data Loss 0.339558 |  physics Loss 0.518181 | Val Loss 0.543454
# Epoch 200 | Train Loss 0.306170 | data Loss 0.252387 |  physics Loss 0.431665 | Val Loss 0.550983
# Epoch 300 | Train Loss 0.287217 | data Loss 0.224493 |  physics Loss 0.433572 | Val Loss 0.614672
# Early stopping at epoch 372
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed1627.keras
# theta | SuperZZ1 -> R² = -0.0035, R² diff = 0.7220
# theta | SuperZZ2 -> R² = 0.3188, R² diff = 0.5780
# theta | LSG-1 -> R² = -3.9799, R² diff = 0.5574
# theta | LSG-2 -> R² = -1.4069, R² diff = 0.5273
# theta | ZZx1-inv -> R² = 0.7381, R² diff = 0.6183
# theta | ZZx1 -> R² = -0.9795, R² diff = 0.3338
# theta | ZZx2-inv2 -> R² = -1.4949, R² diff = 0.2708
# theta | ZZx2 -> R² = -0.4130, R² diff = 0.5165
# theta | ZZxReto -> R² = -0.0857, R² diff = 0.3952
# theta | ZZy1 -> R² = -21.5829, R² diff = 0.1045
# theta | ZZy2 -> R² = 0.8648, R² diff = 0.6371
# theta | semiCirc -> R² = -9.8269, R² diff = 0.2379
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=1627 salvo.
# Epoch 0 | Train Loss 0.888927 | data Loss 0.836958 |  physics Loss 1.010188 | Val Loss 0.914366
# Epoch 100 | Train Loss 0.399341 | data Loss 0.344938 |  physics Loss 0.526281 | Val Loss 0.619328
# Epoch 200 | Train Loss 0.324198 | data Loss 0.274318 |  physics Loss 0.440584 | Val Loss 0.599791
# Epoch 300 | Train Loss 0.293052 | data Loss 0.233129 |  physics Loss 0.432871 | Val Loss 0.733084
# Early stopping at epoch 360
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed7931.keras
# theta | SuperZZ1 -> R² = 0.8115, R² diff = 0.6905
# theta | SuperZZ2 -> R² = -0.1558, R² diff = 0.5626
# theta | LSG-1 -> R² = -2.4555, R² diff = 0.4675
# theta | LSG-2 -> R² = -0.4315, R² diff = 0.4858
# theta | ZZx1-inv -> R² = 0.5692, R² diff = 0.6331
# theta | ZZx1 -> R² = -1.0408, R² diff = 0.3517
# theta | ZZx2-inv2 -> R² = -2.0803, R² diff = 0.2458
# theta | ZZx2 -> R² = -0.0336, R² diff = 0.5159
# theta | ZZxReto -> R² = -0.4173, R² diff = 0.3724
# theta | ZZy1 -> R² = -28.1506, R² diff = 0.0023
# theta | ZZy2 -> R² = 0.9373, R² diff = 0.6187
# theta | semiCirc -> R² = -8.1199, R² diff = 0.3105
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=7931 salvo.
# Epoch 0 | Train Loss 0.959567 | data Loss 0.926352 |  physics Loss 1.037069 | Val Loss 0.989141
# Epoch 100 | Train Loss 0.373657 | data Loss 0.312536 |  physics Loss 0.516275 | Val Loss 0.595454
# Epoch 200 | Train Loss 0.308538 | data Loss 0.254860 |  physics Loss 0.433785 | Val Loss 0.629882
# Early stopping at epoch 246
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed8994.keras
# theta | SuperZZ1 -> R² = 0.6921, R² diff = 0.6202
# theta | SuperZZ2 -> R² = -0.4208, R² diff = 0.5552
# theta | LSG-1 -> R² = -3.2163, R² diff = 0.4482
# theta | LSG-2 -> R² = -0.6322, R² diff = 0.4594
# theta | ZZx1-inv -> R² = 0.8451, R² diff = 0.6853
# theta | ZZx1 -> R² = -1.1460, R² diff = 0.4131
# theta | ZZx2-inv2 -> R² = -0.0182, R² diff = 0.4270
# theta | ZZx2 -> R² = -1.4848, R² diff = 0.3961
# theta | ZZxReto -> R² = -0.4208, R² diff = 0.4291
# theta | ZZy1 -> R² = -31.8309, R² diff = -0.0568
# theta | ZZy2 -> R² = 0.9091, R² diff = 0.5806
# theta | semiCirc -> R² = -17.8487, R² diff = 0.0081
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=8994 salvo.
# Epoch 0 | Train Loss 0.927729 | data Loss 0.880707 |  physics Loss 1.037445 | Val Loss 0.966849
# Epoch 100 | Train Loss 0.419335 | data Loss 0.362084 |  physics Loss 0.552919 | Val Loss 0.547871
# Epoch 200 | Train Loss 0.355604 | data Loss 0.307181 |  physics Loss 0.468591 | Val Loss 0.538938
# Epoch 300 | Train Loss 0.321499 | data Loss 0.266739 |  physics Loss 0.449274 | Val Loss 0.558939
# Epoch 400 | Train Loss 0.294562 | data Loss 0.233135 |  physics Loss 0.437890 | Val Loss 0.588875
# Early stopping at epoch 413
# Modelo salvo em:
# models/model_arch85_r0.01_Ld0.7_Lp0.3_seed7257.keras
# theta | SuperZZ1 -> R² = 0.5998, R² diff = 0.6625
# theta | SuperZZ2 -> R² = -1.4949, R² diff = 0.5884
# theta | LSG-1 -> R² = -2.1895, R² diff = 0.4236
# theta | LSG-2 -> R² = -2.1425, R² diff = 0.4605
# theta | ZZx1-inv -> R² = -2.1013, R² diff = 0.5671
# theta | ZZx1 -> R² = -1.1190, R² diff = 0.2464
# theta | ZZx2-inv2 -> R² = -3.8961, R² diff = 0.2785
# theta | ZZx2 -> R² = 0.3773, R² diff = 0.5320
# theta | ZZxReto -> R² = -2.1748, R² diff = 0.2046
# theta | ZZy1 -> R² = -52.6080, R² diff = -0.3032
# theta | ZZy2 -> R² = 0.9076, R² diff = 0.6447
# theta | semiCirc -> R² = -6.0218, R² diff = 0.3336
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.01 seed=7257 salvo.
# Epoch 0 | Train Loss 1.100879 | data Loss 1.075035 |  physics Loss 1.161183 | Val Loss 1.192716
# Epoch 100 | Train Loss 0.400784 | data Loss 0.340739 |  physics Loss 0.540890 | Val Loss 0.546017
# Epoch 200 | Train Loss 0.321531 | data Loss 0.262377 |  physics Loss 0.459557 | Val Loss 0.660742
# Early stopping at epoch 279
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed4485.keras
# theta | SuperZZ1 -> R² = -0.0695, R² diff = 0.6297
# theta | SuperZZ2 -> R² = 0.4574, R² diff = 0.5588
# theta | LSG-1 -> R² = -8.6442, R² diff = 0.4122
# theta | LSG-2 -> R² = -3.7746, R² diff = 0.4387
# theta | ZZx1-inv -> R² = 0.1535, R² diff = 0.6571
# theta | ZZx1 -> R² = -4.2700, R² diff = 0.3458
# theta | ZZx2-inv2 -> R² = 0.2523, R² diff = 0.3874
# theta | ZZx2 -> R² = -0.9264, R² diff = 0.4218
# theta | ZZxReto -> R² = -3.1245, R² diff = 0.3700
# theta | ZZy1 -> R² = -29.8042, R² diff = -0.0915
# theta | ZZy2 -> R² = 0.6349, R² diff = 0.5988
# theta | semiCirc -> R² = -25.3403, R² diff = -0.1604
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=4485 salvo.
# Epoch 0 | Train Loss 1.016005 | data Loss 0.988187 |  physics Loss 1.080915 | Val Loss 1.081885
# Epoch 100 | Train Loss 0.404444 | data Loss 0.348487 |  physics Loss 0.535011 | Val Loss 0.515144
# Epoch 200 | Train Loss 0.352489 | data Loss 0.306710 |  physics Loss 0.459307 | Val Loss 0.545527
# Epoch 300 | Train Loss 0.306470 | data Loss 0.252862 |  physics Loss 0.431556 | Val Loss 0.578003
# Epoch 400 | Train Loss 0.286204 | data Loss 0.218323 |  physics Loss 0.444593 | Val Loss 0.642402
# Early stopping at epoch 431
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed1627.keras
# theta | SuperZZ1 -> R² = 0.8917, R² diff = 0.7034
# theta | SuperZZ2 -> R² = -0.5553, R² diff = 0.5813
# theta | LSG-1 -> R² = -2.0510, R² diff = 0.5223
# theta | LSG-2 -> R² = -0.1981, R² diff = 0.5211
# theta | ZZx1-inv -> R² = -0.0329, R² diff = 0.6201
# theta | ZZx1 -> R² = -0.6301, R² diff = 0.3503
# theta | ZZx2-inv2 -> R² = -2.1306, R² diff = 0.3339
# theta | ZZx2 -> R² = 0.2285, R² diff = 0.5558
# theta | ZZxReto -> R² = -0.3979, R² diff = 0.3574
# theta | ZZy1 -> R² = -31.8335, R² diff = -0.0219
# theta | ZZy2 -> R² = 0.9146, R² diff = 0.6384
# theta | semiCirc -> R² = -5.6824, R² diff = 0.3691
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=1627 salvo.
# Epoch 0 | Train Loss 0.916318 | data Loss 0.876759 |  physics Loss 1.008623 | Val Loss 0.965346
# Epoch 100 | Train Loss 0.374140 | data Loss 0.317141 |  physics Loss 0.507138 | Val Loss 0.620844
# Epoch 200 | Train Loss 0.316493 | data Loss 0.266010 |  physics Loss 0.434287 | Val Loss 0.573786
# Early stopping at epoch 270
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed7931.keras
# theta | SuperZZ1 -> R² = 0.8981, R² diff = 0.6578
# theta | SuperZZ2 -> R² = -1.1303, R² diff = 0.5388
# theta | LSG-1 -> R² = -2.5060, R² diff = 0.4501
# theta | LSG-2 -> R² = -0.1505, R² diff = 0.4664
# theta | ZZx1-inv -> R² = 0.7001, R² diff = 0.6488
# theta | ZZx1 -> R² = -0.8026, R² diff = 0.3963
# theta | ZZx2-inv2 -> R² = -1.0211, R² diff = 0.3688
# theta | ZZx2 -> R² = 0.0776, R² diff = 0.5002
# theta | ZZxReto -> R² = -0.4207, R² diff = 0.3739
# theta | ZZy1 -> R² = -45.4753, R² diff = -0.2297
# theta | ZZy2 -> R² = 0.8704, R² diff = 0.5936
# theta | semiCirc -> R² = -16.4324, R² diff = 0.0566
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=7931 salvo.
# Epoch 0 | Train Loss 0.980847 | data Loss 0.945536 |  physics Loss 1.063238 | Val Loss 1.000718
# Epoch 100 | Train Loss 0.396218 | data Loss 0.348144 |  physics Loss 0.508391 | Val Loss 0.559182
# Epoch 200 | Train Loss 0.337478 | data Loss 0.292518 |  physics Loss 0.442383 | Val Loss 0.576150
# Epoch 300 | Train Loss 0.308824 | data Loss 0.254134 |  physics Loss 0.436433 | Val Loss 0.605066
# Early stopping at epoch 309
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed8994.keras
# theta | SuperZZ1 -> R² = 0.4903, R² diff = 0.6059
# theta | SuperZZ2 -> R² = -1.2203, R² diff = 0.5659
# theta | LSG-1 -> R² = -2.5228, R² diff = 0.3878
# theta | LSG-2 -> R² = -1.4486, R² diff = 0.4249
# theta | ZZx1-inv -> R² = -1.0148, R² diff = 0.5628
# theta | ZZx1 -> R² = -0.9092, R² diff = 0.2739
# theta | ZZx2-inv2 -> R² = -1.5915, R² diff = 0.3900
# theta | ZZx2 -> R² = 0.3153, R² diff = 0.4343
# theta | ZZxReto -> R² = -0.8452, R² diff = 0.2563
# theta | ZZy1 -> R² = -39.3950, R² diff = -0.2022
# theta | ZZy2 -> R² = 0.9394, R² diff = 0.5961
# theta | semiCirc -> R² = -10.2696, R² diff = 0.1474
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=8994 salvo.
# Epoch 0 | Train Loss 1.112020 | data Loss 1.079642 |  physics Loss 1.187570 | Val Loss 1.156765
# Epoch 100 | Train Loss 0.406558 | data Loss 0.339766 |  physics Loss 0.562405 | Val Loss 0.605818
# Epoch 200 | Train Loss 0.337097 | data Loss 0.285733 |  physics Loss 0.456947 | Val Loss 0.586872
# Early stopping at epoch 276
# Modelo salvo em:
# models/model_arch85_r0.9_Ld0.7_Lp0.3_seed7257.keras
# theta | SuperZZ1 -> R² = 0.4430, R² diff = 0.6206
# theta | SuperZZ2 -> R² = 0.5937, R² diff = 0.5419
# theta | LSG-1 -> R² = -5.3637, R² diff = 0.3405
# theta | LSG-2 -> R² = -1.2643, R² diff = 0.4240
# theta | ZZx1-inv -> R² = 0.5586, R² diff = 0.6111
# theta | ZZx1 -> R² = -1.9194, R² diff = 0.2550
# theta | ZZx2-inv2 -> R² = 0.0460, R² diff = 0.3699
# theta | ZZx2 -> R² = -0.8660, R² diff = 0.4048
# theta | ZZxReto -> R² = -1.3230, R² diff = 0.2042
# theta | ZZy1 -> R² = -48.3045, R² diff = -0.4147
# theta | ZZy2 -> R² = 0.6391, R² diff = 0.5890
# theta | semiCirc -> R² = -16.1145, R² diff = 0.0049
# Modelo [85] | Ld=0.7 Lp=0.3 r=0.9 seed=7257 salvo.
# Epoch 0 | Train Loss 1.119530 | data Loss 1.061430 |  physics Loss 1.144431 | Val Loss 1.141540
# Epoch 100 | Train Loss 0.408692 | data Loss 0.517082 |  physics Loss 0.362239 | Val Loss 0.733463
# Epoch 200 | Train Loss 0.336569 | data Loss 0.477909 |  physics Loss 0.275995 | Val Loss 0.739838
# Early stopping at epoch 211
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed4485.keras
# theta | SuperZZ1 -> R² = 0.7438, R² diff = 0.5603
# theta | SuperZZ2 -> R² = -1.1108, R² diff = 0.4877
# theta | LSG-1 -> R² = -1.1644, R² diff = 0.4631
# theta | LSG-2 -> R² = 0.1638, R² diff = 0.4697
# theta | ZZx1-inv -> R² = 0.4802, R² diff = 0.6867
# theta | ZZx1 -> R² = -0.1152, R² diff = 0.4073
# theta | ZZx2-inv2 -> R² = -0.4470, R² diff = 0.3591
# theta | ZZx2 -> R² = -2.7113, R² diff = 0.3156
# theta | ZZxReto -> R² = -0.0328, R² diff = 0.4832
# theta | ZZy1 -> R² = -20.5292, R² diff = 0.0940
# theta | ZZy2 -> R² = 0.7278, R² diff = 0.5437
# theta | semiCirc -> R² = -14.0644, R² diff = 0.1472
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=4485 salvo.
# Epoch 0 | Train Loss 0.963334 | data Loss 0.869242 |  physics Loss 1.003659 | Val Loss 0.933837
# Epoch 100 | Train Loss 0.375235 | data Loss 0.496764 |  physics Loss 0.323152 | Val Loss 0.691673
# Epoch 200 | Train Loss 0.311274 | data Loss 0.456937 |  physics Loss 0.248846 | Val Loss 0.673683
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed1627.keras
# theta | SuperZZ1 -> R² = 0.9086, R² diff = 0.5855
# theta | SuperZZ2 -> R² = -1.7003, R² diff = 0.4902
# theta | LSG-1 -> R² = -0.7434, R² diff = 0.5110
# theta | LSG-2 -> R² = 0.3208, R² diff = 0.4825
# theta | ZZx1-inv -> R² = 0.0741, R² diff = 0.6836
# theta | ZZx1 -> R² = 0.0751, R² diff = 0.4448
# theta | ZZx2-inv2 -> R² = -1.0223, R² diff = 0.3767
# theta | ZZx2 -> R² = 0.0183, R² diff = 0.4431
# theta | ZZxReto -> R² = -0.5304, R² diff = 0.5316
# theta | ZZy1 -> R² = -30.0130, R² diff = 0.0621
# theta | ZZy2 -> R² = 0.3508, R² diff = 0.5378
# theta | semiCirc -> R² = -17.6650, R² diff = 0.0693
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=1627 salvo.
# Epoch 0 | Train Loss 1.037903 | data Loss 0.958294 |  physics Loss 1.072021 | Val Loss 1.047366
# Epoch 100 | Train Loss 0.384730 | data Loss 0.498315 |  physics Loss 0.336051 | Val Loss 0.688363
# Epoch 200 | Train Loss 0.326513 | data Loss 0.480060 |  physics Loss 0.260707 | Val Loss 0.732717
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed7931.keras
# theta | SuperZZ1 -> R² = 0.9154, R² diff = 0.5868
# theta | SuperZZ2 -> R² = -2.0662, R² diff = 0.4834
# theta | LSG-1 -> R² = -0.4238, R² diff = 0.5144
# theta | LSG-2 -> R² = 0.4472, R² diff = 0.4969
# theta | ZZx1-inv -> R² = -0.0404, R² diff = 0.6846
# theta | ZZx1 -> R² = -0.1845, R² diff = 0.4555
# theta | ZZx2-inv2 -> R² = -0.7886, R² diff = 0.3814
# theta | ZZx2 -> R² = -1.3695, R² diff = 0.3650
# theta | ZZxReto -> R² = -1.0913, R² diff = 0.5031
# theta | ZZy1 -> R² = -31.0520, R² diff = 0.0407
# theta | ZZy2 -> R² = 0.2160, R² diff = 0.5275
# theta | semiCirc -> R² = -14.8386, R² diff = 0.1145
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=7931 salvo.
# Epoch 0 | Train Loss 1.049528 | data Loss 0.979774 |  physics Loss 1.079423 | Val Loss 1.066999
# Epoch 100 | Train Loss 0.369318 | data Loss 0.500398 |  physics Loss 0.313141 | Val Loss 0.701598
# Epoch 200 | Train Loss 0.310680 | data Loss 0.460156 |  physics Loss 0.246619 | Val Loss 0.694781
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed8994.keras
# theta | SuperZZ1 -> R² = 0.6527, R² diff = 0.5578
# theta | SuperZZ2 -> R² = -0.5780, R² diff = 0.4879
# theta | LSG-1 -> R² = -0.7130, R² diff = 0.4876
# theta | LSG-2 -> R² = 0.2176, R² diff = 0.4619
# theta | ZZx1-inv -> R² = 0.4646, R² diff = 0.6667
# theta | ZZx1 -> R² = 0.0457, R² diff = 0.4119
# theta | ZZx2-inv2 -> R² = -0.2891, R² diff = 0.3748
# theta | ZZx2 -> R² = -1.0880, R² diff = 0.3788
# theta | ZZxReto -> R² = -0.1232, R² diff = 0.5111
# theta | ZZy1 -> R² = -21.1281, R² diff = 0.1324
# theta | ZZy2 -> R² = 0.6590, R² diff = 0.5276
# theta | semiCirc -> R² = -14.0450, R² diff = 0.1485
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=8994 salvo.
# Epoch 0 | Train Loss 0.989387 | data Loss 0.903583 |  physics Loss 1.026160 | Val Loss 0.994990
# Epoch 100 | Train Loss 0.369273 | data Loss 0.517434 |  physics Loss 0.305775 | Val Loss 0.688248
# Epoch 200 | Train Loss 0.320367 | data Loss 0.458486 |  physics Loss 0.261173 | Val Loss 0.773490
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.3_Lp0.7_seed7257.keras
# theta | SuperZZ1 -> R² = 0.7992, R² diff = 0.5537
# theta | SuperZZ2 -> R² = -1.7122, R² diff = 0.4727
# theta | LSG-1 -> R² = -0.2158, R² diff = 0.4946
# theta | LSG-2 -> R² = 0.4009, R² diff = 0.4568
# theta | ZZx1-inv -> R² = 0.4792, R² diff = 0.6574
# theta | ZZx1 -> R² = 0.1516, R² diff = 0.4410
# theta | ZZx2-inv2 -> R² = -0.5206, R² diff = 0.3818
# theta | ZZx2 -> R² = -1.0506, R² diff = 0.3926
# theta | ZZxReto -> R² = -0.0482, R² diff = 0.5229
# theta | ZZy1 -> R² = -18.7304, R² diff = 0.1667
# theta | ZZy2 -> R² = 0.1399, R² diff = 0.5197
# theta | semiCirc -> R² = -13.3565, R² diff = 0.1637
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.01 seed=7257 salvo.
# Epoch 0 | Train Loss 1.135803 | data Loss 1.095924 |  physics Loss 1.152893 | Val Loss 1.188327
# Epoch 100 | Train Loss 0.392320 | data Loss 0.509066 |  physics Loss 0.342286 | Val Loss 0.700744
# Epoch 200 | Train Loss 0.331966 | data Loss 0.463738 |  physics Loss 0.275492 | Val Loss 0.746445
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed4485.keras
# theta | SuperZZ1 -> R² = 0.7583, R² diff = 0.5493
# theta | SuperZZ2 -> R² = -1.6433, R² diff = 0.4816
# theta | LSG-1 -> R² = -0.2600, R² diff = 0.4855
# theta | LSG-2 -> R² = 0.3680, R² diff = 0.4470
# theta | ZZx1-inv -> R² = 0.5540, R² diff = 0.6589
# theta | ZZx1 -> R² = 0.1517, R² diff = 0.4294
# theta | ZZx2-inv2 -> R² = -0.6149, R² diff = 0.3788
# theta | ZZx2 -> R² = -1.3255, R² diff = 0.3807
# theta | ZZxReto -> R² = 0.1956, R² diff = 0.5258
# theta | ZZy1 -> R² = -15.4334, R² diff = 0.1997
# theta | ZZy2 -> R² = 0.2705, R² diff = 0.5257
# theta | semiCirc -> R² = -11.7752, R² diff = 0.2034
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=4485 salvo.
# Epoch 0 | Train Loss 1.113992 | data Loss 1.040740 |  physics Loss 1.145386 | Val Loss 1.130304
# Epoch 100 | Train Loss 0.399552 | data Loss 0.509241 |  physics Loss 0.352542 | Val Loss 0.738564
# Epoch 200 | Train Loss 0.334605 | data Loss 0.478581 |  physics Loss 0.272901 | Val Loss 0.703955
# Early stopping at epoch 239
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed1627.keras
# theta | SuperZZ1 -> R² = 0.8135, R² diff = 0.5883
# theta | SuperZZ2 -> R² = -1.0790, R² diff = 0.5033
# theta | LSG-1 -> R² = -1.1204, R² diff = 0.4855
# theta | LSG-2 -> R² = 0.2092, R² diff = 0.4835
# theta | ZZx1-inv -> R² = 0.5789, R² diff = 0.6941
# theta | ZZx1 -> R² = 0.0151, R² diff = 0.4501
# theta | ZZx2-inv2 -> R² = -0.1462, R² diff = 0.4150
# theta | ZZx2 -> R² = -1.1176, R² diff = 0.4067
# theta | ZZxReto -> R² = -0.2939, R² diff = 0.4856
# theta | ZZy1 -> R² = -30.5969, R² diff = 0.0098
# theta | ZZy2 -> R² = 0.5736, R² diff = 0.5501
# theta | semiCirc -> R² = -16.5099, R² diff = 0.0837
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=1627 salvo.
# Epoch 0 | Train Loss 1.074773 | data Loss 1.026287 |  physics Loss 1.095553 | Val Loss 1.130099
# Epoch 100 | Train Loss 0.373963 | data Loss 0.509160 |  physics Loss 0.316022 | Val Loss 0.724220
# Epoch 200 | Train Loss 0.313244 | data Loss 0.468648 |  physics Loss 0.246643 | Val Loss 0.721252
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed7931.keras
# theta | SuperZZ1 -> R² = 0.8741, R² diff = 0.5858
# theta | SuperZZ2 -> R² = -1.8944, R² diff = 0.4751
# theta | LSG-1 -> R² = -0.9735, R² diff = 0.5172
# theta | LSG-2 -> R² = 0.3777, R² diff = 0.5018
# theta | ZZx1-inv -> R² = 0.5745, R² diff = 0.6902
# theta | ZZx1 -> R² = 0.0666, R² diff = 0.4648
# theta | ZZx2-inv2 -> R² = -0.4910, R² diff = 0.3710
# theta | ZZx2 -> R² = -2.3672, R² diff = 0.3396
# theta | ZZxReto -> R² = -0.2566, R² diff = 0.4983
# theta | ZZy1 -> R² = -29.2927, R² diff = 0.0422
# theta | ZZy2 -> R² = 0.3964, R² diff = 0.5187
# theta | semiCirc -> R² = -17.5488, R² diff = 0.0615
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=7931 salvo.
# Epoch 0 | Train Loss 0.971087 | data Loss 0.859680 |  physics Loss 1.018832 | Val Loss 0.933560
# Epoch 100 | Train Loss 0.371385 | data Loss 0.506903 |  physics Loss 0.313305 | Val Loss 0.728727
# Epoch 200 | Train Loss 0.308387 | data Loss 0.458928 |  physics Loss 0.243870 | Val Loss 0.729859
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed8994.keras
# theta | SuperZZ1 -> R² = 0.8443, R² diff = 0.5935
# theta | SuperZZ2 -> R² = -1.3557, R² diff = 0.4935
# theta | LSG-1 -> R² = -1.1659, R² diff = 0.5212
# theta | LSG-2 -> R² = 0.2986, R² diff = 0.5024
# theta | ZZx1-inv -> R² = 0.3699, R² diff = 0.7104
# theta | ZZx1 -> R² = 0.0481, R² diff = 0.4610
# theta | ZZx2-inv2 -> R² = -0.7667, R² diff = 0.3576
# theta | ZZx2 -> R² = -1.7397, R² diff = 0.3643
# theta | ZZxReto -> R² = -0.4275, R² diff = 0.5284
# theta | ZZy1 -> R² = -31.6020, R² diff = 0.0306
# theta | ZZy2 -> R² = 0.5803, R² diff = 0.5395
# theta | semiCirc -> R² = -19.2759, R² diff = 0.0321
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=8994 salvo.
# Epoch 0 | Train Loss 1.045133 | data Loss 0.943465 |  physics Loss 1.088705 | Val Loss 1.018829
# Epoch 100 | Train Loss 0.384208 | data Loss 0.511101 |  physics Loss 0.329826 | Val Loss 0.719458
# Epoch 200 | Train Loss 0.322628 | data Loss 0.459829 |  physics Loss 0.263827 | Val Loss 0.708398
# Early stopping at epoch 260
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.3_Lp0.7_seed7257.keras
# theta | SuperZZ1 -> R² = 0.8487, R² diff = 0.5248
# theta | SuperZZ2 -> R² = -0.3820, R² diff = 0.4874
# theta | LSG-1 -> R² = -0.8238, R² diff = 0.4414
# theta | LSG-2 -> R² = -0.0336, R² diff = 0.4530
# theta | ZZx1-inv -> R² = -0.3856, R² diff = 0.5598
# theta | ZZx1 -> R² = -0.4569, R² diff = 0.3469
# theta | ZZx2-inv2 -> R² = 0.3268, R² diff = 0.4069
# theta | ZZx2 -> R² = -1.3331, R² diff = 0.2543
# theta | ZZxReto -> R² = -1.8490, R² diff = 0.3303
# theta | ZZy1 -> R² = -39.2867, R² diff = -0.1546
# theta | ZZy2 -> R² = 0.6274, R² diff = 0.4692
# theta | semiCirc -> R² = -8.2359, R² diff = 0.1771
# Modelo [86] | Ld=0.3 Lp=0.7 r=0.9 seed=7257 salvo.
# Epoch 0 | Train Loss 1.122715 | data Loss 1.105397 |  physics Loss 1.163124 | Val Loss 1.216107
# Epoch 100 | Train Loss 0.391616 | data Loss 0.337358 |  physics Loss 0.518217 | Val Loss 0.540844
# Epoch 200 | Train Loss 0.327314 | data Loss 0.282050 |  physics Loss 0.432929 | Val Loss 0.550057
# Epoch 300 | Train Loss 0.294028 | data Loss 0.240239 |  physics Loss 0.419536 | Val Loss 0.619482
# Early stopping at epoch 393
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed4485.keras
# theta | SuperZZ1 -> R² = 0.2120, R² diff = 0.7118
# theta | SuperZZ2 -> R² = 0.4110, R² diff = 0.5635
# theta | LSG-1 -> R² = -4.4639, R² diff = 0.5525
# theta | LSG-2 -> R² = -2.4155, R² diff = 0.5229
# theta | ZZx1-inv -> R² = 0.8922, R² diff = 0.6467
# theta | ZZx1 -> R² = -2.4559, R² diff = 0.4064
# theta | ZZx2-inv2 -> R² = -0.4078, R² diff = 0.2731
# theta | ZZx2 -> R² = -0.0719, R² diff = 0.5070
# theta | ZZxReto -> R² = -1.7314, R² diff = 0.4389
# theta | ZZy1 -> R² = -14.4268, R² diff = 0.2133
# theta | ZZy2 -> R² = 0.6944, R² diff = 0.6348
# theta | semiCirc -> R² = -9.4396, R² diff = 0.2866
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=4485 salvo.
# Epoch 0 | Train Loss 0.973111 | data Loss 0.939193 |  physics Loss 1.052253 | Val Loss 1.044150
# Epoch 100 | Train Loss 0.386009 | data Loss 0.333622 |  physics Loss 0.508246 | Val Loss 0.607115
# Epoch 200 | Train Loss 0.303240 | data Loss 0.245529 |  physics Loss 0.437900 | Val Loss 0.652912
# Early stopping at epoch 266
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed1627.keras
# theta | SuperZZ1 -> R² = 0.7638, R² diff = 0.6335
# theta | SuperZZ2 -> R² = -0.4430, R² diff = 0.5517
# theta | LSG-1 -> R² = -2.5278, R² diff = 0.4836
# theta | LSG-2 -> R² = -0.4717, R² diff = 0.4733
# theta | ZZx1-inv -> R² = 0.8529, R² diff = 0.6689
# theta | ZZx1 -> R² = -0.6014, R² diff = 0.4418
# theta | ZZx2-inv2 -> R² = -0.0383, R² diff = 0.4272
# theta | ZZx2 -> R² = -0.5772, R² diff = 0.4542
# theta | ZZxReto -> R² = -0.1261, R² diff = 0.4561
# theta | ZZy1 -> R² = -38.8403, R² diff = -0.1152
# theta | ZZy2 -> R² = 0.8651, R² diff = 0.5820
# theta | semiCirc -> R² = -18.9917, R² diff = -0.0174
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=1627 salvo.
# Epoch 0 | Train Loss 1.007063 | data Loss 0.974057 |  physics Loss 1.084077 | Val Loss 1.070000
# Epoch 100 | Train Loss 0.394718 | data Loss 0.343368 |  physics Loss 0.514536 | Val Loss 0.553642
# Epoch 200 | Train Loss 0.336401 | data Loss 0.289477 |  physics Loss 0.445892 | Val Loss 0.587080
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed7931.keras
# theta | SuperZZ1 -> R² = 0.8834, R² diff = 0.6257
# theta | SuperZZ2 -> R² = -0.6987, R² diff = 0.5630
# theta | LSG-1 -> R² = -2.2866, R² diff = 0.4821
# theta | LSG-2 -> R² = -0.0586, R² diff = 0.4719
# theta | ZZx1-inv -> R² = 0.7564, R² diff = 0.6556
# theta | ZZx1 -> R² = -0.5702, R² diff = 0.4333
# theta | ZZx2-inv2 -> R² = -0.2150, R² diff = 0.4344
# theta | ZZx2 -> R² = -0.7815, R² diff = 0.4324
# theta | ZZxReto -> R² = -0.1229, R² diff = 0.4513
# theta | ZZy1 -> R² = -35.3462, R² diff = -0.0689
# theta | ZZy2 -> R² = 0.8546, R² diff = 0.5850
# theta | semiCirc -> R² = -18.1797, R² diff = -0.0005
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=7931 salvo.
# Epoch 0 | Train Loss 1.105474 | data Loss 1.077650 |  physics Loss 1.170397 | Val Loss 1.187943
# Epoch 100 | Train Loss 0.402514 | data Loss 0.354075 |  physics Loss 0.515538 | Val Loss 0.541387
# Epoch 200 | Train Loss 0.329444 | data Loss 0.283774 |  physics Loss 0.436007 | Val Loss 0.575656
# Epoch 300 | Train Loss 0.290882 | data Loss 0.230371 |  physics Loss 0.432074 | Val Loss 0.693313
# Early stopping at epoch 306
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed8994.keras
# theta | SuperZZ1 -> R² = 0.8838, R² diff = 0.6475
# theta | SuperZZ2 -> R² = -1.1406, R² diff = 0.5606
# theta | LSG-1 -> R² = -2.4155, R² diff = 0.4888
# theta | LSG-2 -> R² = -0.2829, R² diff = 0.4729
# theta | ZZx1-inv -> R² = 0.8320, R² diff = 0.6485
# theta | ZZx1 -> R² = -0.7110, R² diff = 0.4243
# theta | ZZx2-inv2 -> R² = -0.9237, R² diff = 0.4002
# theta | ZZx2 -> R² = 0.0806, R² diff = 0.4887
# theta | ZZxReto -> R² = -0.1479, R² diff = 0.4476
# theta | ZZy1 -> R² = -37.0107, R² diff = -0.0747
# theta | ZZy2 -> R² = 0.8360, R² diff = 0.5945
# theta | semiCirc -> R² = -17.5753, R² diff = 0.0360
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=8994 salvo.
# Epoch 0 | Train Loss 1.015490 | data Loss 0.983938 |  physics Loss 1.089110 | Val Loss 1.055828
# Epoch 100 | Train Loss 0.398707 | data Loss 0.349591 |  physics Loss 0.513313 | Val Loss 0.530389
# Epoch 200 | Train Loss 0.332624 | data Loss 0.285548 |  physics Loss 0.442466 | Val Loss 0.565805
# Early stopping at epoch 280
# Modelo salvo em:
# models/model_arch86_r0.01_Ld0.7_Lp0.3_seed7257.keras
# theta | SuperZZ1 -> R² = 0.8542, R² diff = 0.6274
# theta | SuperZZ2 -> R² = -0.7946, R² diff = 0.5581
# theta | LSG-1 -> R² = -3.2698, R² diff = 0.4987
# theta | LSG-2 -> R² = -0.4708, R² diff = 0.4784
# theta | ZZx1-inv -> R² = 0.8302, R² diff = 0.6582
# theta | ZZx1 -> R² = -0.6300, R² diff = 0.4256
# theta | ZZx2-inv2 -> R² = -0.0872, R² diff = 0.4352
# theta | ZZx2 -> R² = -0.3304, R² diff = 0.4485
# theta | ZZxReto -> R² = -0.1291, R² diff = 0.4761
# theta | ZZy1 -> R² = -29.4092, R² diff = 0.0314
# theta | ZZy2 -> R² = 0.8695, R² diff = 0.5948
# theta | semiCirc -> R² = -22.5200, R² diff = -0.0731
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.01 seed=7257 salvo.
# Epoch 0 | Train Loss 1.067932 | data Loss 1.033545 |  physics Loss 1.148167 | Val Loss 1.107656
# Epoch 100 | Train Loss 0.450137 | data Loss 0.393463 |  physics Loss 0.582378 | Val Loss 0.519856
# Epoch 200 | Train Loss 0.356417 | data Loss 0.308102 |  physics Loss 0.469152 | Val Loss 0.579228
# Epoch 300 | Train Loss 0.308708 | data Loss 0.254825 |  physics Loss 0.434435 | Val Loss 0.633626
# Early stopping at epoch 301
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed4485.keras
# theta | SuperZZ1 -> R² = 0.8764, R² diff = 0.6190
# theta | SuperZZ2 -> R² = -0.9446, R² diff = 0.5719
# theta | LSG-1 -> R² = -1.5541, R² diff = 0.4857
# theta | LSG-2 -> R² = 0.1264, R² diff = 0.4780
# theta | ZZx1-inv -> R² = 0.1174, R² diff = 0.6401
# theta | ZZx1 -> R² = -0.1611, R² diff = 0.4156
# theta | ZZx2-inv2 -> R² = -0.4251, R² diff = 0.4496
# theta | ZZx2 -> R² = -0.2227, R² diff = 0.4252
# theta | ZZxReto -> R² = -0.4069, R² diff = 0.4336
# theta | ZZy1 -> R² = -42.0698, R² diff = -0.1142
# theta | ZZy2 -> R² = 0.7790, R² diff = 0.5849
# theta | semiCirc -> R² = -16.2508, R² diff = 0.0184
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=4485 salvo.
# Epoch 0 | Train Loss 0.909605 | data Loss 0.868020 |  physics Loss 1.006637 | Val Loss 0.918841
# Epoch 100 | Train Loss 0.388374 | data Loss 0.326869 |  physics Loss 0.531884 | Val Loss 0.623265
# Epoch 200 | Train Loss 0.333528 | data Loss 0.277504 |  physics Loss 0.464251 | Val Loss 0.718587
# Early stopping at epoch 263
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed1627.keras
# theta | SuperZZ1 -> R² = 0.8318, R² diff = 0.6266
# theta | SuperZZ2 -> R² = -0.5734, R² diff = 0.5536
# theta | LSG-1 -> R² = -2.8551, R² diff = 0.4867
# theta | LSG-2 -> R² = -0.2428, R² diff = 0.4768
# theta | ZZx1-inv -> R² = 0.7444, R² diff = 0.6759
# theta | ZZx1 -> R² = -0.3904, R² diff = 0.4284
# theta | ZZx2-inv2 -> R² = -0.2275, R² diff = 0.4190
# theta | ZZx2 -> R² = -0.6630, R² diff = 0.4484
# theta | ZZxReto -> R² = -0.1142, R² diff = 0.4701
# theta | ZZy1 -> R² = -36.7489, R² diff = -0.0689
# theta | ZZy2 -> R² = 0.8886, R² diff = 0.5880
# theta | semiCirc -> R² = -22.0493, R² diff = -0.0719
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=1627 salvo.
# Epoch 0 | Train Loss 1.040220 | data Loss 1.010850 |  physics Loss 1.108749 | Val Loss 1.084525
# Epoch 100 | Train Loss 0.406716 | data Loss 0.351117 |  physics Loss 0.536445 | Val Loss 0.545134
# Epoch 200 | Train Loss 0.344752 | data Loss 0.294751 |  physics Loss 0.461420 | Val Loss 0.556106
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed7931.keras
# theta | SuperZZ1 -> R² = 0.4617, R² diff = 0.6266
# theta | SuperZZ2 -> R² = 0.1908, R² diff = 0.5557
# theta | LSG-1 -> R² = -4.5920, R² diff = 0.4700
# theta | LSG-2 -> R² = -1.1506, R² diff = 0.4760
# theta | ZZx1-inv -> R² = 0.8268, R² diff = 0.6697
# theta | ZZx1 -> R² = -1.0093, R² diff = 0.3985
# theta | ZZx2-inv2 -> R² = 0.0952, R² diff = 0.4054
# theta | ZZx2 -> R² = -1.2447, R² diff = 0.4164
# theta | ZZxReto -> R² = -0.3853, R² diff = 0.4331
# theta | ZZy1 -> R² = -37.1607, R² diff = -0.1075
# theta | ZZy2 -> R² = 0.8874, R² diff = 0.5901
# theta | semiCirc -> R² = -23.9421, R² diff = -0.1133
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=7931 salvo.
# Epoch 0 | Train Loss 0.956364 | data Loss 0.918869 |  physics Loss 1.043854 | Val Loss 0.989930
# Epoch 100 | Train Loss 0.411755 | data Loss 0.365761 |  physics Loss 0.519076 | Val Loss 0.554949
# Epoch 200 | Train Loss 0.345434 | data Loss 0.298219 |  physics Loss 0.455603 | Val Loss 0.551603
# Epoch 300 | Train Loss 0.301801 | data Loss 0.226214 |  physics Loss 0.478170 | Val Loss 0.669834
# Early stopping at epoch 319
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed8994.keras
# theta | SuperZZ1 -> R² = 0.7866, R² diff = 0.6181
# theta | SuperZZ2 -> R² = 0.1711, R² diff = 0.5661
# theta | LSG-1 -> R² = -3.6798, R² diff = 0.3682
# theta | LSG-2 -> R² = -0.8968, R² diff = 0.4165
# theta | ZZx1-inv -> R² = 0.3637, R² diff = 0.5844
# theta | ZZx1 -> R² = -1.4788, R² diff = 0.2560
# theta | ZZx2-inv2 -> R² = -0.6201, R² diff = 0.3760
# theta | ZZx2 -> R² = -0.2139, R² diff = 0.4424
# theta | ZZxReto -> R² = -0.9558, R² diff = 0.2259
# theta | ZZy1 -> R² = -42.4944, R² diff = -0.2825
# theta | ZZy2 -> R² = 0.8830, R² diff = 0.5848
# theta | semiCirc -> R² = -11.4861, R² diff = 0.1143
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=8994 salvo.
# Epoch 0 | Train Loss 0.954706 | data Loss 0.919149 |  physics Loss 1.037672 | Val Loss 1.002072
# Epoch 100 | Train Loss 0.398659 | data Loss 0.344232 |  physics Loss 0.525656 | Val Loss 0.583487
# Epoch 200 | Train Loss 0.327462 | data Loss 0.273426 |  physics Loss 0.453545 | Val Loss 0.633331
# Early stopping at epoch 290
# Modelo salvo em:
# models/model_arch86_r0.9_Ld0.7_Lp0.3_seed7257.keras
# theta | SuperZZ1 -> R² = 0.8518, R² diff = 0.6413
# theta | SuperZZ2 -> R² = -0.5890, R² diff = 0.5583
# theta | LSG-1 -> R² = -3.4641, R² diff = 0.4516
# theta | LSG-2 -> R² = -0.4058, R² diff = 0.4653
# theta | ZZx1-inv -> R² = 0.6985, R² diff = 0.6532
# theta | ZZx1 -> R² = -1.0003, R² diff = 0.3764
# theta | ZZx2-inv2 -> R² = -0.5985, R² diff = 0.4006
# theta | ZZx2 -> R² = -0.4464, R² diff = 0.4500
# theta | ZZxReto -> R² = -0.5129, R² diff = 0.3718
# theta | ZZy1 -> R² = -42.9797, R² diff = -0.2106
# theta | ZZy2 -> R² = 0.9334, R² diff = 0.5948
# theta | semiCirc -> R² = -18.1377, R² diff = -0.0179
# Modelo [86] | Ld=0.7 Lp=0.3 r=0.9 seed=7257 salvo.
# Epoch 0 | Train Loss 1.066294 | data Loss 0.989811 |  physics Loss 1.099072 | Val Loss 1.071135
# Epoch 100 | Train Loss 0.380951 | data Loss 0.517800 |  physics Loss 0.322302 | Val Loss 0.713493
# Epoch 200 | Train Loss 0.315975 | data Loss 0.461340 |  physics Loss 0.253676 | Val Loss 0.662542
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch87_r0.01_Ld0.3_Lp0.7_seed4485.keras
# theta | SuperZZ1 -> R² = 0.7804, R² diff = 0.5564
# theta | SuperZZ2 -> R² = -1.5473, R² diff = 0.4856
# theta | LSG-1 -> R² = -0.3275, R² diff = 0.4824
# theta | LSG-2 -> R² = 0.3638, R² diff = 0.4535
# theta | ZZx1-inv -> R² = 0.5529, R² diff = 0.6714
# theta | ZZx1 -> R² = 0.1488, R² diff = 0.4420
# theta | ZZx2-inv2 -> R² = -0.5127, R² diff = 0.3906
# theta | ZZx2 -> R² = -1.1393, R² diff = 0.3903
# theta | ZZxReto -> R² = 0.1024, R² diff = 0.5275
# theta | ZZy1 -> R² = -17.8676, R² diff = 0.1683
# theta | ZZy2 -> R² = 0.2663, R² diff = 0.5305
# theta | semiCirc -> R² = -12.4553, R² diff = 0.1801
# Modelo [87] | Ld=0.3 Lp=0.7 r=0.01 seed=4485 salvo.
# Epoch 0 | Train Loss 1.069209 | data Loss 1.019569 |  physics Loss 1.090484 | Val Loss 1.145528
# Epoch 100 | Train Loss 0.381125 | data Loss 0.504474 |  physics Loss 0.328261 | Val Loss 0.684185
# Epoch 200 | Train Loss 0.324479 | data Loss 0.482663 |  physics Loss 0.256685 | Val Loss 0.722413
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch87_r0.01_Ld0.3_Lp0.7_seed1627.keras
# theta | SuperZZ1 -> R² = 0.7375, R² diff = 0.5448
# theta | SuperZZ2 -> R² = -1.4561, R² diff = 0.4733
# theta | LSG-1 -> R² = -0.8345, R² diff = 0.4584
# theta | LSG-2 -> R² = 0.2410, R² diff = 0.4628
# theta | ZZx1-inv -> R² = 0.5912, R² diff = 0.6645
# theta | ZZx1 -> R² = -0.0933, R² diff = 0.4091
# theta | ZZx2-inv2 -> R² = -0.3572, R² diff = 0.3616
# theta | ZZx2 -> R² = -3.3051, R² diff = 0.2690
# theta | ZZxReto -> R² = 0.0747, R² diff = 0.4668
# theta | ZZy1 -> R² = -16.9498, R² diff = 0.1290
# theta | ZZy2 -> R² = 0.6043, R² diff = 0.5218
# theta | semiCirc -> R² = -11.3787, R² diff = 0.2008
# Modelo [87] | Ld=0.3 Lp=0.7 r=0.01 seed=1627 salvo.
# Epoch 0 | Train Loss 0.969684 | data Loss 0.881666 |  physics Loss 1.007406 | Val Loss 0.948618
# Epoch 100 | Train Loss 0.366986 | data Loss 0.512988 |  physics Loss 0.304414 | Val Loss 0.709441
# Epoch 200 | Train Loss 0.307844 | data Loss 0.461059 |  physics Loss 0.242180 | Val Loss 0.684737
# Early stopping at epoch 236
# Modelo salvo em:
# models/model_arch87_r0.01_Ld0.3_Lp0.7_seed7931.keras
# theta | SuperZZ1 -> R² = 0.7559, R² diff = 0.5650
# theta | SuperZZ2 -> R² = -0.1720, R² diff = 0.4849
# theta | LSG-1 -> R² = -1.6434, R² diff = 0.4646
# theta | LSG-2 -> R² = 0.0427, R² diff = 0.4926
# theta | ZZx1-inv -> R² = 0.0556, R² diff = 0.6525
# theta | ZZx1 -> R² = -0.3429, R² diff = 0.3743
# theta | ZZx2-inv2 -> R² = -0.2004, R² diff = 0.3532
# theta | ZZx2 -> R² = -2.1880, R² diff = 0.2605
# theta | ZZxReto -> R² = -1.1781, R² diff = 0.4071
# theta | ZZy1 -> R² = -36.0009, R² diff = -0.0831
# theta | ZZy2 -> R² = 0.8255, R² diff = 0.5053
# theta | semiCirc -> R² = -14.0665, R² diff = 0.0956
# Modelo [87] | Ld=0.3 Lp=0.7 r=0.01 seed=7931 salvo.
# Epoch 0 | Train Loss 1.150870 | data Loss 1.101251 |  physics Loss 1.172135 | Val Loss 1.199612
# Epoch 100 | Train Loss 0.390383 | data Loss 0.521500 |  physics Loss 0.334190 | Val Loss 0.704719
# Epoch 200 | Train Loss 0.324601 | data Loss 0.480037 |  physics Loss 0.257986 | Val Loss 0.666176
# Early stopping at epoch 229
# Modelo salvo em:
# models/model_arch87_r0.01_Ld0.3_Lp0.7_seed8994.keras
# theta | SuperZZ1 -> R² = 0.7887, R² diff = 0.5661
# theta | SuperZZ2 -> R² = -1.4344, R² diff = 0.4667
# theta | LSG-1 -> R² = -0.5743, R² diff = 0.4871
# theta | LSG-2 -> R² = 0.3240, R² diff = 0.4731
# theta | ZZx1-inv -> R² = 0.3285, R² diff = 0.6767
# theta | ZZx1 -> R² = -0.0114, R² diff = 0.4231
# theta | ZZx2-inv2 -> R² = -0.9146, R² diff = 0.3373
# theta | ZZx2 -> R² = -1.1265, R² diff = 0.3616
# theta | ZZxReto -> R² = -0.5098, R² diff = 0.5042
# theta | ZZy1 -> R² = -24.4550, R² diff = 0.0988
# theta | ZZy2 -> R² = 0.4518, R² diff = 0.5117
# theta | semiCirc -> R² = -12.8907, R² diff = 0.1681
# Modelo [87] | Ld=0.3 Lp=0.7 r=0.01 seed=8994 salvo.
# Epoch 0 | Train Loss 1.015215 | data Loss 0.941536 |  physics Loss 1.046792 | Val Loss 1.021653
# Epoch 100 | Train Loss 0.367444 | data Loss 0.521165 |  physics Loss 0.301564 | Val Loss 0.722981
# Epoch 200 | Train Loss 0.309820 | data Loss 0.466098 |  physics Loss 0.242844 | Val Loss 0.679562
# Epoch 300 | Train Loss 0.305081 | data Loss 0.477765 |  physics Loss 0.231074 | Val Loss 0.708959
# Early stopping at epoch 359
# Modelo salvo em:
# models/model_arch87_r0.01_Ld0.3_Lp0.7_seed7257.keras
# theta | SuperZZ1 -> R² = 0.6879, R² diff = 0.5547
# theta | SuperZZ2 -> R² = 0.1647, R² diff = 0.4696
# theta | LSG-1 -> R² = -3.8952, R² diff = 0.5078
# theta | LSG-2 -> R² = -0.9213, R² diff = 0.4937
# theta | ZZx1-inv -> R² = 0.8414, R² diff = 0.4298
# theta | ZZx1 -> R² = -2.3520, R² diff = 0.2885
# theta | ZZx2-inv2 -> R² = -0.8447, R² diff = 0.2757
# theta | ZZx2 -> R² = 0.3680, R² diff = 0.4054
# theta | ZZxReto -> R² = -1.1437, R² diff = 0.2914
# theta | ZZy1 -> R² = -20.3433, R² diff = 0.0850
# theta | ZZy2 -> R² = 0.8584, R² diff = 0.4428
# theta | semiCirc -> R² = -19.7536, R² diff = -0.0751
# Modelo [87] | Ld=0.3 Lp=0.7 r=0.01 seed=7257 salvo.
# Epoch 0 | Train Loss 1.097360 | data Loss 1.031880 |  physics Loss 1.125423 | Val Loss 1.148471
# ...
# Epoch 0 | Train Loss 1.058411 | data Loss 0.974019 |  physics Loss 1.094579 | Val Loss 1.026713
# Epoch 100 | Train Loss 0.358900 | data Loss 0.490444 |  physics Loss 0.302524 | Val Loss 0.683416
# Epoch 200 | Train Loss 0.307075 | data Loss 0.471636 |  physics Loss 0.236549 | Val Loss 0.668225
# Epoch 300 | Train Loss 0.315740 | data Loss 0.439690 |  physics Loss 0.262618 | Val Loss 0.757008
# Epoch 400 | Train Loss 0.290325 | data Loss 0.459637 |  physics Loss 0.217762 | Val Loss 0.696740
# Early stopping at epoch 411
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed4485.keras
# theta | SuperZZ1 -> R² = 0.7720, R² diff = 0.5057
# theta | SuperZZ2 -> R² = -0.3041, R² diff = 0.4733
# theta | LSG-1 -> R² = -1.2579, R² diff = 0.4289
# theta | LSG-2 -> R² = -0.1047, R² diff = 0.4309
# theta | ZZx1-inv -> R² = -0.5152, R² diff = 0.3523
# theta | ZZx1 -> R² = -0.7541, R² diff = 0.2075
# theta | ZZx2-inv2 -> R² = -2.1023, R² diff = 0.2622
# theta | ZZx2 -> R² = 0.6141, R² diff = 0.3439
# theta | ZZxReto -> R² = -0.0959, R² diff = 0.2033
# theta | ZZy1 -> R² = -18.8203, R² diff = 0.0455
# theta | ZZy2 -> R² = 0.6028, R² diff = 0.4069
# theta | semiCirc -> R² = -5.1768, R² diff = 0.2443
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=4485 salvo.
# Epoch 0 | Train Loss 1.090492 | data Loss 1.036757 |  physics Loss 1.113522 | Val Loss 1.147005
# Epoch 100 | Train Loss 0.360241 | data Loss 0.511653 |  physics Loss 0.295350 | Val Loss 0.694051
# Epoch 200 | Train Loss 0.316963 | data Loss 0.463485 |  physics Loss 0.254167 | Val Loss 0.726280
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed1627.keras
# theta | SuperZZ1 -> R² = 0.6666, R² diff = 0.5461
# theta | SuperZZ2 -> R² = -1.3193, R² diff = 0.4792
# theta | LSG-1 -> R² = -0.3445, R² diff = 0.4877
# theta | LSG-2 -> R² = 0.3055, R² diff = 0.4458
# theta | ZZx1-inv -> R² = 0.7240, R² diff = 0.6440
# theta | ZZx1 -> R² = 0.1415, R² diff = 0.4219
# theta | ZZx2-inv2 -> R² = -0.3450, R² diff = 0.3789
# theta | ZZx2 -> R² = -1.5444, R² diff = 0.3722
# theta | ZZxReto -> R² = 0.3392, R² diff = 0.5136
# theta | ZZy1 -> R² = -14.1687, R² diff = 0.2103
# theta | ZZy2 -> R² = 0.3581, R² diff = 0.5196
# theta | semiCirc -> R² = -12.0356, R² diff = 0.1922
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=1627 salvo.
# Epoch 0 | Train Loss 1.225751 | data Loss 1.179090 |  physics Loss 1.245749 | Val Loss 1.264326
# Epoch 100 | Train Loss 0.373953 | data Loss 0.497408 |  physics Loss 0.321044 | Val Loss 0.699000
# Epoch 200 | Train Loss 0.322376 | data Loss 0.478054 |  physics Loss 0.255657 | Val Loss 0.696701
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed7931.keras
# theta | SuperZZ1 -> R² = 0.9085, R² diff = 0.5772
# theta | SuperZZ2 -> R² = -1.7709, R² diff = 0.4894
# theta | LSG-1 -> R² = -0.5114, R² diff = 0.5066
# theta | LSG-2 -> R² = 0.4062, R² diff = 0.4951
# theta | ZZx1-inv -> R² = 0.0903, R² diff = 0.6778
# theta | ZZx1 -> R² = -0.1112, R² diff = 0.4524
# theta | ZZx2-inv2 -> R² = -0.5184, R² diff = 0.3940
# theta | ZZx2 -> R² = -2.0086, R² diff = 0.3278
# theta | ZZxReto -> R² = -0.7448, R² diff = 0.4874
# theta | ZZy1 -> R² = -29.3362, R² diff = 0.0414
# theta | ZZy2 -> R² = 0.3276, R² diff = 0.5250
# theta | semiCirc -> R² = -14.4866, R² diff = 0.1170
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=7931 salvo.
# Epoch 0 | Train Loss 1.028777 | data Loss 0.970151 |  physics Loss 1.053902 | Val Loss 1.028547
# Epoch 100 | Train Loss 0.355860 | data Loss 0.506685 |  physics Loss 0.291221 | Val Loss 0.706948
# Epoch 200 | Train Loss 0.309838 | data Loss 0.478046 |  physics Loss 0.237749 | Val Loss 0.671925
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed8994.keras
# theta | SuperZZ1 -> R² = 0.7889, R² diff = 0.5940
# theta | SuperZZ2 -> R² = -1.0192, R² diff = 0.5067
# theta | LSG-1 -> R² = -1.0970, R² diff = 0.5225
# theta | LSG-2 -> R² = 0.1658, R² diff = 0.4893
# theta | ZZx1-inv -> R² = 0.5262, R² diff = 0.7000
# theta | ZZx1 -> R² = 0.1495, R² diff = 0.4631
# theta | ZZx2-inv2 -> R² = -0.3183, R² diff = 0.4035
# theta | ZZx2 -> R² = -0.8610, R² diff = 0.4269
# theta | ZZxReto -> R² = -0.1556, R² diff = 0.5445
# theta | ZZy1 -> R² = -28.4019, R² diff = 0.0762
# theta | ZZy2 -> R² = 0.5566, R² diff = 0.5509
# theta | semiCirc -> R² = -19.4425, R² diff = 0.0328
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=8994 salvo.
# Epoch 0 | Train Loss 1.021431 | data Loss 0.905847 |  physics Loss 1.070967 | Val Loss 0.915201
# Epoch 100 | Train Loss 0.373236 | data Loss 0.517041 |  physics Loss 0.311605 | Val Loss 0.700168
# Epoch 200 | Train Loss 0.315568 | data Loss 0.451548 |  physics Loss 0.257291 | Val Loss 0.684659
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed7257.keras
# theta | SuperZZ1 -> R² = 0.7250, R² diff = 0.5805
# theta | SuperZZ2 -> R² = -0.8478, R² diff = 0.4977
# theta | LSG-1 -> R² = -0.7247, R² diff = 0.5145
# theta | LSG-2 -> R² = 0.2537, R² diff = 0.4817
# theta | ZZx1-inv -> R² = 0.4895, R² diff = 0.6790
# theta | ZZx1 -> R² = 0.0826, R² diff = 0.4391
# theta | ZZx2-inv2 -> R² = -0.3498, R² diff = 0.3826
# theta | ZZx2 -> R² = -1.1237, R² diff = 0.3952
# theta | ZZxReto -> R² = -0.1277, R² diff = 0.5252
# theta | ZZy1 -> R² = -22.9016, R² diff = 0.1344
# theta | ZZy2 -> R² = 0.5773, R² diff = 0.5418
# theta | semiCirc -> R² = -15.5633, R² diff = 0.1213
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=7257 salvo.
# Epoch 0 | Train Loss 1.029886 | data Loss 1.000046 |  physics Loss 1.099514 | Val Loss 1.060228
# Epoch 100 | Train Loss 0.372871 | data Loss 0.316230 |  physics Loss 0.505032 | Val Loss 0.560718
# Epoch 200 | Train Loss 0.312302 | data Loss 0.265642 |  physics Loss 0.421177 | Val Loss 0.650621
# Early stopping at epoch 272
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed4485.keras
# theta | SuperZZ1 -> R² = 0.8980, R² diff = 0.6448
# theta | SuperZZ2 -> R² = -0.8478, R² diff = 0.5615
# theta | LSG-1 -> R² = -1.6649, R² diff = 0.4735
# theta | LSG-2 -> R² = 0.0500, R² diff = 0.4704
# theta | ZZx1-inv -> R² = 0.5199, R² diff = 0.6522
# theta | ZZx1 -> R² = -0.2565, R² diff = 0.4183
# theta | ZZx2-inv2 -> R² = -0.8159, R² diff = 0.4079
# theta | ZZx2 -> R² = -0.3123, R² diff = 0.4600
# theta | ZZxReto -> R² = -0.3617, R² diff = 0.4200
# theta | ZZy1 -> R² = -49.0900, R² diff = -0.2376
# theta | ZZy2 -> R² = 0.8155, R² diff = 0.5823
# theta | semiCirc -> R² = -14.9846, R² diff = 0.0654
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=4485 salvo.
# Epoch 0 | Train Loss 1.034969 | data Loss 1.000682 |  physics Loss 1.114974 | Val Loss 1.056796
# Epoch 100 | Train Loss 0.401667 | data Loss 0.346448 |  physics Loss 0.530514 | Val Loss 0.569646
# Epoch 200 | Train Loss 0.342303 | data Loss 0.291871 |  physics Loss 0.459980 | Val Loss 0.599306
# Early stopping at epoch 263
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed1627.keras
# theta | SuperZZ1 -> R² = 0.8444, R² diff = 0.6227
# theta | SuperZZ2 -> R² = -0.4042, R² diff = 0.5623
# theta | LSG-1 -> R² = -2.6800, R² diff = 0.4904
# theta | LSG-2 -> R² = -0.0382, R² diff = 0.4873
# theta | ZZx1-inv -> R² = 0.6606, R² diff = 0.6667
# theta | ZZx1 -> R² = -0.3819, R² diff = 0.4216
# theta | ZZx2-inv2 -> R² = 0.1414, R² diff = 0.4454
# theta | ZZx2 -> R² = -1.6258, R² diff = 0.4000
# theta | ZZxReto -> R² = -0.2073, R² diff = 0.4429
# theta | ZZy1 -> R² = -36.6621, R² diff = -0.0779
# theta | ZZy2 -> R² = 0.8927, R² diff = 0.5952
# theta | semiCirc -> R² = -21.4164, R² diff = -0.0575
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=1627 salvo.
# Epoch 0 | Train Loss 1.084603 | data Loss 1.052965 |  physics Loss 1.158425 | Val Loss 1.113344
# Epoch 100 | Train Loss 0.395285 | data Loss 0.339221 |  physics Loss 0.526103 | Val Loss 0.529538
# Epoch 200 | Train Loss 0.326631 | data Loss 0.275670 |  physics Loss 0.445540 | Val Loss 0.596875
# Early stopping at epoch 280
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed7931.keras
# theta | SuperZZ1 -> R² = 0.8974, R² diff = 0.6284
# theta | SuperZZ2 -> R² = -1.0224, R² diff = 0.5673
# theta | LSG-1 -> R² = -1.8246, R² diff = 0.4854
# theta | LSG-2 -> R² = 0.1005, R² diff = 0.4730
# theta | ZZx1-inv -> R² = 0.5087, R² diff = 0.6627
# theta | ZZx1 -> R² = -0.2754, R² diff = 0.4258
# theta | ZZx2-inv2 -> R² = -0.3560, R² diff = 0.4472
# theta | ZZx2 -> R² = -0.5035, R² diff = 0.4421
# theta | ZZxReto -> R² = -0.1053, R² diff = 0.4520
# theta | ZZy1 -> R² = -35.7116, R² diff = -0.0514
# theta | ZZy2 -> R² = 0.7778, R² diff = 0.5810
# theta | semiCirc -> R² = -15.9062, R² diff = 0.0417
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=7931 salvo.
# Epoch 0 | Train Loss 1.068311 | data Loss 1.038037 |  physics Loss 1.138951 | Val Loss 1.071783
# Epoch 100 | Train Loss 0.405886 | data Loss 0.358015 |  physics Loss 0.517585 | Val Loss 0.537042
# Epoch 200 | Train Loss 0.352385 | data Loss 0.303517 |  physics Loss 0.466411 | Val Loss 0.547912
# Early stopping at epoch 279
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed8994.keras
# theta | SuperZZ1 -> R² = -0.3490, R² diff = 0.6210
# theta | SuperZZ2 -> R² = 0.7799, R² diff = 0.5770
# theta | LSG-1 -> R² = -6.1503, R² diff = 0.4740
# theta | LSG-2 -> R² = -2.7395, R² diff = 0.4678
# theta | ZZx1-inv -> R² = 0.5049, R² diff = 0.6531
# theta | ZZx1 -> R² = -2.0588, R² diff = 0.3946
# theta | ZZx2-inv2 -> R² = 0.7473, R² diff = 0.4485
# theta | ZZx2 -> R² = -1.8456, R² diff = 0.3701
# theta | ZZxReto -> R² = -1.0707, R² diff = 0.4417
# theta | ZZy1 -> R² = -29.1519, R² diff = -0.0067
# theta | ZZy2 -> R² = 0.7237, R² diff = 0.5897
# theta | semiCirc -> R² = -24.0212, R² diff = -0.1328
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=8994 salvo.
# Epoch 0 | Train Loss 1.113927 | data Loss 1.090790 |  physics Loss 1.167915 | Val Loss 1.165724
# Epoch 100 | Train Loss 0.392456 | data Loss 0.338790 |  physics Loss 0.517677 | Val Loss 0.530719
# Epoch 200 | Train Loss 0.320449 | data Loss 0.269715 |  physics Loss 0.438828 | Val Loss 0.537731
# Epoch 300 | Train Loss 0.288234 | data Loss 0.219419 |  physics Loss 0.448801 | Val Loss 0.620035
# Early stopping at epoch 363
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed7257.keras
# theta | SuperZZ1 -> R² = 0.8067, R² diff = 0.6945
# theta | SuperZZ2 -> R² = 0.1347, R² diff = 0.5816
# theta | LSG-1 -> R² = -2.6285, R² diff = 0.4897
# theta | LSG-2 -> R² = -0.3725, R² diff = 0.4980
# theta | ZZx1-inv -> R² = 0.5466, R² diff = 0.6258
# theta | ZZx1 -> R² = -1.0392, R² diff = 0.3672
# theta | ZZx2-inv2 -> R² = -1.3215, R² diff = 0.3226
# theta | ZZx2 -> R² = 0.0285, R² diff = 0.4914
# theta | ZZxReto -> R² = -0.4003, R² diff = 0.3805
# theta | ZZy1 -> R² = -27.7683, R² diff = -0.0011
# theta | ZZy2 -> R² = 0.9181, R² diff = 0.6204
# theta | semiCirc -> R² = -7.4003, R² diff = 0.3409
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=7257 salvo.
# Epoch 0 | Train Loss 1.030753 | data Loss 0.997869 |  physics Loss 1.107482 | Val Loss 1.051572
# Epoch 100 | Train Loss 0.386769 | data Loss 0.334217 |  physics Loss 0.509389 | Val Loss 0.527413
# Epoch 200 | Train Loss 0.327547 | data Loss 0.275892 |  physics Loss 0.448074 | Val Loss 0.638517
# Early stopping at epoch 272
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed4485.keras
# theta | SuperZZ1 -> R² = 0.9078, R² diff = 0.6292
# theta | SuperZZ2 -> R² = -1.1652, R² diff = 0.5586
# theta | LSG-1 -> R² = -1.6900, R² diff = 0.5048
# theta | LSG-2 -> R² = 0.1661, R² diff = 0.4807
# theta | ZZx1-inv -> R² = 0.6193, R² diff = 0.6557
# theta | ZZx1 -> R² = -0.2093, R² diff = 0.4440
# theta | ZZx2-inv2 -> R² = -0.3081, R² diff = 0.4415
# theta | ZZx2 -> R² = -0.5170, R² diff = 0.4546
# theta | ZZxReto -> R² = 0.0152, R² diff = 0.4716
# theta | ZZy1 -> R² = -35.9323, R² diff = -0.0420
# theta | ZZy2 -> R² = 0.7241, R² diff = 0.5851
# theta | semiCirc -> R² = -18.1436, R² diff = 0.0210
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=4485 salvo.
# Epoch 0 | Train Loss 0.934379 | data Loss 0.890279 |  physics Loss 1.037278 | Val Loss 0.905274
# Epoch 100 | Train Loss 0.395403 | data Loss 0.331540 |  physics Loss 0.544415 | Val Loss 0.566331
# Epoch 200 | Train Loss 0.335200 | data Loss 0.287311 |  physics Loss 0.446942 | Val Loss 0.570508
# Epoch 300 | Train Loss 0.298552 | data Loss 0.240814 |  physics Loss 0.433276 | Val Loss 0.625029
# Epoch 400 | Train Loss 0.282650 | data Loss 0.215615 |  physics Loss 0.439064 | Val Loss 0.715389
# Early stopping at epoch 420
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed1627.keras
# theta | SuperZZ1 -> R² = 0.6938, R² diff = 0.7003
# theta | SuperZZ2 -> R² = 0.3323, R² diff = 0.5611
# theta | LSG-1 -> R² = -2.8584, R² diff = 0.4850
# theta | LSG-2 -> R² = -0.6203, R² diff = 0.5082
# theta | ZZx1-inv -> R² = 0.5186, R² diff = 0.6222
# theta | ZZx1 -> R² = -1.1285, R² diff = 0.3393
# theta | ZZx2-inv2 -> R² = -1.8981, R² diff = 0.2105
# theta | ZZx2 -> R² = -0.0899, R² diff = 0.4953
# theta | ZZxReto -> R² = -0.4770, R² diff = 0.3855
# theta | ZZy1 -> R² = -21.2165, R² diff = 0.0855
# theta | ZZy2 -> R² = 0.7786, R² diff = 0.6193
# theta | semiCirc -> R² = -7.1934, R² diff = 0.3669
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=1627 salvo.
# Epoch 0 | Train Loss 1.067676 | data Loss 1.050307 |  physics Loss 1.108204 | Val Loss 1.128438
# Epoch 100 | Train Loss 0.375580 | data Loss 0.322366 |  physics Loss 0.499745 | Val Loss 0.562295
# Epoch 200 | Train Loss 0.317226 | data Loss 0.257705 |  physics Loss 0.456109 | Val Loss 0.584575
# Early stopping at epoch 278
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed7931.keras
# theta | SuperZZ1 -> R² = 0.8834, R² diff = 0.6435
# theta | SuperZZ2 -> R² = -0.7499, R² diff = 0.5535
# theta | LSG-1 -> R² = -3.0521, R² diff = 0.4460
# theta | LSG-2 -> R² = -0.2757, R² diff = 0.4576
# theta | ZZx1-inv -> R² = 0.6272, R² diff = 0.6427
# theta | ZZx1 -> R² = -0.9699, R² diff = 0.3754
# theta | ZZx2-inv2 -> R² = -0.9935, R² diff = 0.3718
# theta | ZZx2 -> R² = -0.0512, R² diff = 0.4754
# theta | ZZxReto -> R² = -0.4885, R² diff = 0.3799
# theta | ZZy1 -> R² = -36.8785, R² diff = -0.1299
# theta | ZZy2 -> R² = 0.9307, R² diff = 0.5931
# theta | semiCirc -> R² = -16.7473, R² diff = 0.0227
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=7931 salvo.
# Epoch 0 | Train Loss 1.005586 | data Loss 0.979842 |  physics Loss 1.065656 | Val Loss 1.058786
# Epoch 100 | Train Loss 0.382959 | data Loss 0.329992 |  physics Loss 0.506549 | Val Loss 0.527970
# Epoch 200 | Train Loss 0.329372 | data Loss 0.285766 |  physics Loss 0.431120 | Val Loss 0.621435
# Early stopping at epoch 271
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed8994.keras
# theta | SuperZZ1 -> R² = 0.8947, R² diff = 0.6381
# theta | SuperZZ2 -> R² = -1.0952, R² diff = 0.5641
# theta | LSG-1 -> R² = -1.4626, R² diff = 0.4996
# theta | LSG-2 -> R² = 0.1854, R² diff = 0.4830
# theta | ZZx1-inv -> R² = 0.3768, R² diff = 0.6497
# theta | ZZx1 -> R² = -0.1272, R² diff = 0.4338
# theta | ZZx2-inv2 -> R² = -0.5112, R² diff = 0.4407
# theta | ZZx2 -> R² = -0.0242, R² diff = 0.4670
# theta | ZZxReto -> R² = -0.2323, R² diff = 0.4492
# theta | ZZy1 -> R² = -44.3730, R² diff = -0.1397
# theta | ZZy2 -> R² = 0.7053, R² diff = 0.5871
# theta | semiCirc -> R² = -16.1612, R² diff = 0.0531
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=8994 salvo.
# Epoch 0 | Train Loss 1.179288 | data Loss 1.155446 |  physics Loss 1.234919 | Val Loss 1.182025
# Epoch 100 | Train Loss 0.406600 | data Loss 0.360871 |  physics Loss 0.513302 | Val Loss 0.575897
# Epoch 200 | Train Loss 0.347299 | data Loss 0.299206 |  physics Loss 0.459517 | Val Loss 0.612319
# Early stopping at epoch 286
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed7257.keras
# theta | SuperZZ1 -> R² = 0.8740, R² diff = 0.6116
# theta | SuperZZ2 -> R² = -0.6582, R² diff = 0.5658
# theta | LSG-1 -> R² = -1.7643, R² diff = 0.4793
# theta | LSG-2 -> R² = 0.0452, R² diff = 0.4655
# theta | ZZx1-inv -> R² = 0.2239, R² diff = 0.6394
# theta | ZZx1 -> R² = -0.1956, R² diff = 0.4028
# theta | ZZx2-inv2 -> R² = -0.2280, R² diff = 0.4436
# theta | ZZx2 -> R² = -0.2596, R² diff = 0.4120
# theta | ZZxReto -> R² = -0.2172, R² diff = 0.4404
# theta | ZZy1 -> R² = -36.1950, R² diff = -0.0580
# theta | ZZy2 -> R² = 0.8270, R² diff = 0.5721
# theta | semiCirc -> R² = -15.1685, R² diff = 0.0318
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=7257 salvo.
