# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = [
    "SuperZZ1",
    "SuperZZ2",
    "LSG-1",
    "LSG-2",
    "ZZx1-inv",
    "ZZx1",
    "ZZx2-inv2",
    "ZZx2",
    "ZZxReto",
    "ZZy1",
    "ZZy2",
    "semiCirc",
]

PREDICTORS = ["e_a_d", "e_a_e", "Se_a", "De_a"]   
TARGET_INT = ["theta"]  
TARGET = ["dtheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 12
TS = 0.07
PLOT = False
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for title in TITLES:
    df = pd.read_excel("./../../00-Data/SavgolDatasets.xlsx", sheet_name=title)
    Datasets.append(df)

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["Se_a"] = Dataset["e_a_d"] + Dataset["e_a_e"]
    Dataset["De_a"] = Dataset["e_a_d"] - Dataset["e_a_e"]

    Dataset = Dataset.dropna(subset=[f"d{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train = Train1

# Train2 = Datasets[1].copy()
# Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
# Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
# NormDatasets.append(Train2)

# # concatena
# Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(len(TITLES)-1):
    CurrentTestDataset = Datasets[i + 1].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = NormDatasets[1]

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (2209, 12, 4)
# Dimensão da saida: (2209, 1)
# Dimensão da entrada: (3054, 12, 4)
# Dimensão da saida: (3054, 1)

# %%
phi_d_train =  Train["phi_d"].values[:len(x_train)]
phi_e_train =  Train["phi_e"].values[:len(x_train)]
theta_train = Train["theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(phi_d_train)}")
print(f"Dimensão da entrada fisica: {np.shape(phi_e_train)}")
# Out:
# Dimensão da entrada: (2209, 12, 4)
# Dimensão da saida: (2209, 1)
# Dimensão da entrada fisica : (2209,)
# Dimensão da entrada fisica: (2209,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(phi_d, phi_e, theta):

    dtheta_cin = (R / (2 * L)) * (phi_d - phi_e)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["phi_d"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["phi_e"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(dq).T, np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, phi_d, phi_e, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(phi_d, phi_e, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss, data_loss, physics_loss

# %%
phi_d_train = tf.convert_to_tensor(phi_d_train, dtype=tf.float32)
phi_e_train = tf.convert_to_tensor(phi_e_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss, data_loss, physics_loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          phi_d_train, phi_e_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | data Loss {data_loss.numpy():.6f} |  physics Loss {physics_loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(len(y_pred)).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, '-', linewidth=1.5, label='Amostras Reais')
    ax.plot(time, y_pred, '--', linewidth=1.5, label='Valores preditos')
    ax.plot(time, y_cin, ':', linewidth=2, label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    from sklearn.metrics import r2_score, mean_squared_error

    n_targets = len(TARGET)
    n_datasets = len(Datasets)

    if PLOT:
        fig, axs = plt.subplots(
            n_datasets,
            2 * n_targets,
            figsize=(6 * 2 * n_targets, 4 * n_datasets)
        )
        axs = np.atleast_2d(axs)

    metrics = {name: {} for name in TARGET_INT}

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS]
        y = Datasets[i][TARGET_INT]
        dy_true = Datasets[i][TARGET].values

        x, y = CreateSequences(x, y, TIME_STEPS)

        # alinhar derivada
        dy_true = dy_true[TIME_STEPS:]

        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()
        dy_pred = OUT_SCALER.inverse_transform(pred)

        y_true = y.copy()
        y_pred = np.zeros_like(dy_pred)

        dy_cin, y_cin = GetCin(Datasets[i])
        y_cin = y_cin[:y_true.shape[0]]
        dy_cin = dy_cin[:dy_pred.shape[0]]

        init_vals = np.array([Datasets[i][name].iloc[0] for name in TARGET_INT])

        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(dy_pred[:, j] * TS)

        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = r2_score(dy_true[:, j], dy_pred[:, j])

            key_r2 = f"R2_{TITLES[i]}"
            key_mse = f"MSE_{TITLES[i]}"

            metrics[name].setdefault(key_r2, []).append(r2)
            metrics[name].setdefault(key_mse, []).append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, R² diff = {mse:.4f}")

            if PLOT:
                ax_y = axs[i, j]
                PlotOut(ax_y, TITLES[i], name,
                        y_true[:, j], y_pred[:, j], y_cin[:, j])

                ax_dy = axs[i, j + n_targets]
                PlotOut(ax_dy, TITLES[i], f"d{name}",
                        dy_true[:, j], dy_pred[:, j], dy_cin[:, j])

    if PLOT:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        entry = {}
        for title in TITLES:
            safe_title = title.replace("-", "_")  
            entry[f"R2_{safe_title}_{name}"] = to_scalar(metrics[name][f"R2_{title}"])
            entry[f"MSE_{safe_title}_{name}"] = to_scalar(metrics[name][f"MSE_{title}"])
        row.update(entry)
        df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    #os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    #weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    #model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}")

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import initializers
from itertools import product
import numpy as np
import tensorflow as tf

N_MODELS = 5

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[n] for n in range(89, 101)]


# FirstLayers = [
#     [27], [30], [32], [35], [36], [37], [40],
#     [42], [44], [46], [49], [50], [52], [75],
# ]

# architectures = [
#     [fl[0], sl]
#     for fl in FirstLayers
#     for sl in range(
#         max(1, int(0.3 * fl[0])),
#         int(0.7 * fl[0])
#     )
# ]

# 🔹 retomar a partir do último modelo salvo
# last_saved = [27, 12]

# if last_saved in architectures:
#     idx = architectures.index(last_saved)
#     architectures = architectures[idx + 1:]  # começa DEPOIS do último salvo
#     print(f"Retomando a partir de {last_saved} (índice {idx}). Restam {len(architectures)} arquiteturas.")
# else:
#     print(f"⚠️ {last_saved} não encontrado na lista — rodando tudo do zero.")

print(len(architectures))
print(architectures)

Ld_Lp = [[0.3, 0.7], [0.7, 0.3]]
r_values = [0.01, 0.9]

results = {}

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados-1l-v2.xlsx")
# Out:
# 12
# [[89], [90], [91], [92], [93], [94], [95], [96], [97], [98], [99], [100]]
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.2\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 1.069764 | data Loss 1.009787 |  physics Loss 1.095469 | Val Loss 1.098635
# Epoch 100 | Train Loss 0.431413 | data Loss 0.618535 |  physics Loss 0.351217 | Val Loss 0.826922
# Epoch 200 | Train Loss 0.379557 | data Loss 0.599662 |  physics Loss 0.285227 | Val Loss 0.854029
# Early stopping at epoch 208
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.3_Lp0.7_seed2389.keras
# theta | SuperZZ1 -> R² = 0.7165, R² diff = 0.4844
# theta | SuperZZ2 -> R² = -1.4725, R² diff = 0.4136
# theta | LSG-1 -> R² = -0.7830, R² diff = 0.4022
# theta | LSG-2 -> R² = 0.1733, R² diff = 0.4236
# theta | ZZx1-inv -> R² = 0.4103, R² diff = 0.5913
# theta | ZZx1 -> R² = -0.1623, R² diff = 0.3477
# theta | ZZx2-inv2 -> R² = -0.3168, R² diff = 0.3304
# theta | ZZx2 -> R² = -1.9826, R² diff = 0.2749
# theta | ZZxReto -> R² = -0.1296, R² diff = 0.3947
# theta | ZZy1 -> R² = -14.6037, R² diff = 0.1124
# theta | ZZy2 -> R² = 0.4169, R² diff = 0.4560
# theta | semiCirc -> R² = -7.6579, R² diff = 0.2532
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.01 seed=2389 salvo.
# Epoch 0 | Train Loss 1.128346 | data Loss 1.078145 |  physics Loss 1.149861 | Val Loss 1.183314
# Epoch 100 | Train Loss 0.403160 | data Loss 0.633329 |  physics Loss 0.304516 | Val Loss 0.752416
# Epoch 200 | Train Loss 0.372731 | data Loss 0.578780 |  physics Loss 0.284424 | Val Loss 0.777982
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.3_Lp0.7_seed1595.keras
# theta | SuperZZ1 -> R² = 0.8550, R² diff = 0.4935
# theta | SuperZZ2 -> R² = -0.9514, R² diff = 0.4082
# theta | LSG-1 -> R² = -1.2139, R² diff = 0.4446
# theta | LSG-2 -> R² = 0.2897, R² diff = 0.4545
# theta | ZZx1-inv -> R² = 0.2937, R² diff = 0.5784
# theta | ZZx1 -> R² = -0.0805, R² diff = 0.3529
# theta | ZZx2-inv2 -> R² = -0.2675, R² diff = 0.3194
# theta | ZZx2 -> R² = -0.9649, R² diff = 0.3158
# theta | ZZxReto -> R² = -0.8677, R² diff = 0.3706
# theta | ZZy1 -> R² = -34.9151, R² diff = -0.0992
# theta | ZZy2 -> R² = 0.5618, R² diff = 0.4162
# theta | semiCirc -> R² = -14.9743, R² diff = 0.0602
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 1.057422 | data Loss 1.004370 |  physics Loss 1.080159 | Val Loss 1.098303
# Epoch 100 | Train Loss 0.453857 | data Loss 0.628371 |  physics Loss 0.379066 | Val Loss 0.828102
# Epoch 200 | Train Loss 0.396885 | data Loss 0.616124 |  physics Loss 0.302926 | Val Loss 0.813235
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.3_Lp0.7_seed6927.keras
# theta | SuperZZ1 -> R² = 0.8484, R² diff = 0.5238
# theta | SuperZZ2 -> R² = -1.6675, R² diff = 0.4515
# theta | LSG-1 -> R² = -0.4030, R² diff = 0.4723
# theta | LSG-2 -> R² = 0.4113, R² diff = 0.4467
# theta | ZZx1-inv -> R² = 0.3853, R² diff = 0.6150
# theta | ZZx1 -> R² = 0.1014, R² diff = 0.4057
# theta | ZZx2-inv2 -> R² = -0.3803, R² diff = 0.3731
# theta | ZZx2 -> R² = -0.9954, R² diff = 0.3702
# theta | ZZxReto -> R² = -0.1081, R² diff = 0.4707
# theta | ZZy1 -> R² = -20.8147, R² diff = 0.1142
# theta | ZZy2 -> R² = 0.2128, R² diff = 0.4891
# theta | semiCirc -> R² = -13.4125, R² diff = 0.1470
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.01 seed=6927 salvo.
# Epoch 0 | Train Loss 1.148803 | data Loss 1.078053 |  physics Loss 1.179124 | Val Loss 1.183912
# Epoch 100 | Train Loss 0.408544 | data Loss 0.602075 |  physics Loss 0.325602 | Val Loss 0.804607
# Epoch 200 | Train Loss 0.365031 | data Loss 0.602999 |  physics Loss 0.263044 | Val Loss 0.794230
# Early stopping at epoch 210
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.3_Lp0.7_seed4518.keras
# theta | SuperZZ1 -> R² = 0.7944, R² diff = 0.4822
# theta | SuperZZ2 -> R² = -1.6245, R² diff = 0.4248
# theta | LSG-1 -> R² = -0.8938, R² diff = 0.3893
# theta | LSG-2 -> R² = -0.1098, R² diff = 0.4169
# theta | ZZx1-inv -> R² = 0.0701, R² diff = 0.5841
# theta | ZZx1 -> R² = -0.2942, R² diff = 0.3364
# theta | ZZx2-inv2 -> R² = -0.3922, R² diff = 0.3447
# theta | ZZx2 -> R² = -1.9404, R² diff = 0.2748
# theta | ZZxReto -> R² = -0.4174, R² diff = 0.3690
# theta | ZZy1 -> R² = -16.4497, R² diff = 0.0726
# theta | ZZy2 -> R² = 0.3978, R² diff = 0.4720
# theta | semiCirc -> R² = -7.2269, R² diff = 0.2628
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.01 seed=4518 salvo.
# Epoch 0 | Train Loss 1.104846 | data Loss 1.054971 |  physics Loss 1.126221 | Val Loss 1.136912
# Epoch 100 | Train Loss 0.467736 | data Loss 0.672377 |  physics Loss 0.380033 | Val Loss 0.796922
# Epoch 200 | Train Loss 0.366096 | data Loss 0.618128 |  physics Loss 0.258082 | Val Loss 0.846684
# Early stopping at epoch 211
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.3_Lp0.7_seed306.keras
# theta | SuperZZ1 -> R² = 0.5114, R² diff = 0.4761
# theta | SuperZZ2 -> R² = -0.4292, R² diff = 0.4006
# theta | LSG-1 -> R² = -2.0462, R² diff = 0.3663
# theta | LSG-2 -> R² = -0.4380, R² diff = 0.4433
# theta | ZZx1-inv -> R² = 0.2952, R² diff = 0.5623
# theta | ZZx1 -> R² = -0.5983, R² diff = 0.2705
# theta | ZZx2-inv2 -> R² = -0.0741, R² diff = 0.2754
# theta | ZZx2 -> R² = -4.1845, R² diff = 0.1307
# theta | ZZxReto -> R² = -0.6170, R² diff = 0.2888
# theta | ZZy1 -> R² = -21.3027, R² diff = -0.0335
# theta | ZZy2 -> R² = 0.8192, R² diff = 0.4310
# theta | semiCirc -> R² = -9.1133, R² diff = 0.2040
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.01 seed=306 salvo.
# Epoch 0 | Train Loss 0.969765 | data Loss 0.857677 |  physics Loss 1.017802 | Val Loss 0.915881
# Epoch 100 | Train Loss 0.428283 | data Loss 0.629881 |  physics Loss 0.341884 | Val Loss 0.807243
# Epoch 200 | Train Loss 0.396791 | data Loss 0.647845 |  physics Loss 0.289196 | Val Loss 0.818378
# Early stopping at epoch 216
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.3_Lp0.7_seed2389.keras
# theta | SuperZZ1 -> R² = 0.6413, R² diff = 0.5197
# theta | SuperZZ2 -> R² = -0.3962, R² diff = 0.4695
# theta | LSG-1 -> R² = -0.8303, R² diff = 0.4787
# theta | LSG-2 -> R² = 0.0773, R² diff = 0.4309
# theta | ZZx1-inv -> R² = 0.5697, R² diff = 0.6100
# theta | ZZx1 -> R² = 0.2243, R² diff = 0.3974
# theta | ZZx2-inv2 -> R² = 0.0416, R² diff = 0.3875
# theta | ZZx2 -> R² = -0.1824, R² diff = 0.4199
# theta | ZZxReto -> R² = 0.0806, R² diff = 0.5065
# theta | ZZy1 -> R² = -23.6882, R² diff = 0.0862
# theta | ZZy2 -> R² = 0.5863, R² diff = 0.4944
# theta | semiCirc -> R² = -19.3361, R² diff = 0.0099
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.9 seed=2389 salvo.
# Epoch 0 | Train Loss 1.098738 | data Loss 1.042134 |  physics Loss 1.122997 | Val Loss 1.149653
# Epoch 100 | Train Loss 0.414977 | data Loss 0.639518 |  physics Loss 0.318745 | Val Loss 0.829774
# Epoch 200 | Train Loss 0.372497 | data Loss 0.599849 |  physics Loss 0.275061 | Val Loss 0.851481
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.3_Lp0.7_seed1595.keras
# theta | SuperZZ1 -> R² = 0.4879, R² diff = 0.4786
# theta | SuperZZ2 -> R² = -0.2676, R² diff = 0.4266
# theta | LSG-1 -> R² = -0.6778, R² diff = 0.4279
# theta | LSG-2 -> R² = 0.1159, R² diff = 0.4049
# theta | ZZx1-inv -> R² = 0.5363, R² diff = 0.5795
# theta | ZZx1 -> R² = 0.0328, R² diff = 0.3362
# theta | ZZx2-inv2 -> R² = -0.0877, R² diff = 0.3331
# theta | ZZx2 -> R² = -0.2356, R² diff = 0.3699
# theta | ZZxReto -> R² = 0.0648, R² diff = 0.4398
# theta | ZZy1 -> R² = -15.6031, R² diff = 0.1369
# theta | ZZy2 -> R² = 0.6434, R² diff = 0.4588
# theta | semiCirc -> R² = -11.4711, R² diff = 0.1708
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 1.079662 | data Loss 1.033232 |  physics Loss 1.099560 | Val Loss 1.136541
# Epoch 100 | Train Loss 0.427576 | data Loss 0.639584 |  physics Loss 0.336716 | Val Loss 0.835118
# Epoch 200 | Train Loss 0.380918 | data Loss 0.616257 |  physics Loss 0.280058 | Val Loss 0.785435
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.3_Lp0.7_seed6927.keras
# theta | SuperZZ1 -> R² = 0.4144, R² diff = 0.4453
# theta | SuperZZ2 -> R² = -0.0593, R² diff = 0.3861
# theta | LSG-1 -> R² = -0.7220, R² diff = 0.3917
# theta | LSG-2 -> R² = 0.0983, R² diff = 0.3905
# theta | ZZx1-inv -> R² = 0.3369, R² diff = 0.5414
# theta | ZZx1 -> R² = -0.0794, R² diff = 0.2930
# theta | ZZx2-inv2 -> R² = -0.0985, R² diff = 0.2916
# theta | ZZx2 -> R² = -0.2010, R² diff = 0.3260
# theta | ZZxReto -> R² = -0.3733, R² diff = 0.3836
# theta | ZZy1 -> R² = -17.1826, R² diff = 0.0949
# theta | ZZy2 -> R² = 0.6905, R² diff = 0.4138
# theta | semiCirc -> R² = -9.0392, R² diff = 0.1978
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.9 seed=6927 salvo.
# Epoch 0 | Train Loss 1.022073 | data Loss 0.908040 |  physics Loss 1.070944 | Val Loss 0.947826
# Epoch 100 | Train Loss 0.416874 | data Loss 0.616313 |  physics Loss 0.331400 | Val Loss 0.823571
# Epoch 200 | Train Loss 0.364327 | data Loss 0.606331 |  physics Loss 0.260612 | Val Loss 0.825351
# Early stopping at epoch 216
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.3_Lp0.7_seed4518.keras
# theta | SuperZZ1 -> R² = 0.8375, R² diff = 0.4956
# theta | SuperZZ2 -> R² = -1.3449, R² diff = 0.4494
# theta | LSG-1 -> R² = -0.4200, R² diff = 0.4444
# theta | LSG-2 -> R² = 0.1654, R² diff = 0.4241
# theta | ZZx1-inv -> R² = -0.1774, R² diff = 0.5873
# theta | ZZx1 -> R² = -0.1562, R² diff = 0.3660
# theta | ZZx2-inv2 -> R² = -0.4100, R² diff = 0.3704
# theta | ZZx2 -> R² = -0.8666, R² diff = 0.3474
# theta | ZZxReto -> R² = -0.5491, R² diff = 0.4382
# theta | ZZy1 -> R² = -18.0795, R² diff = 0.1210
# theta | ZZy2 -> R² = 0.2656, R² diff = 0.4872
# theta | semiCirc -> R² = -9.7389, R² diff = 0.2235
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.9 seed=4518 salvo.
# Epoch 0 | Train Loss 1.091756 | data Loss 1.031041 |  physics Loss 1.117777 | Val Loss 1.108079
# Epoch 100 | Train Loss 0.438952 | data Loss 0.623733 |  physics Loss 0.359760 | Val Loss 0.810281
# Epoch 200 | Train Loss 0.392988 | data Loss 0.600578 |  physics Loss 0.304020 | Val Loss 0.796525
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.3_Lp0.7_seed306.keras
# theta | SuperZZ1 -> R² = 0.8368, R² diff = 0.5217
# theta | SuperZZ2 -> R² = -1.2617, R² diff = 0.4463
# theta | LSG-1 -> R² = -0.8475, R² diff = 0.4683
# theta | LSG-2 -> R² = 0.3570, R² diff = 0.4666
# theta | ZZx1-inv -> R² = 0.4125, R² diff = 0.6092
# theta | ZZx1 -> R² = -0.0839, R² diff = 0.3889
# theta | ZZx2-inv2 -> R² = -0.0567, R² diff = 0.3642
# theta | ZZx2 -> R² = -2.6394, R² diff = 0.2640
# theta | ZZxReto -> R² = -0.4386, R² diff = 0.4093
# theta | ZZy1 -> R² = -27.0857, R² diff = 0.0084
# theta | ZZy2 -> R² = 0.5382, R² diff = 0.4690
# theta | semiCirc -> R² = -13.4106, R² diff = 0.1241
# Modelo [89] | Ld=0.3 Lp=0.7 r=0.9 seed=306 salvo.
# Epoch 0 | Train Loss 1.054269 | data Loss 1.007486 |  physics Loss 1.163429 | Val Loss 1.068613
# Epoch 100 | Train Loss 0.456826 | data Loss 0.350859 |  physics Loss 0.704083 | Val Loss 0.602947
# Epoch 200 | Train Loss 0.429777 | data Loss 0.340252 |  physics Loss 0.638671 | Val Loss 0.806305
# Epoch 300 | Train Loss 0.416293 | data Loss 0.332666 |  physics Loss 0.611420 | Val Loss 0.650119
# Early stopping at epoch 318
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.7_Lp0.3_seed2389.keras
# theta | SuperZZ1 -> R² = 0.8025, R² diff = 0.6329
# theta | SuperZZ2 -> R² = 0.2063, R² diff = 0.5644
# theta | LSG-1 -> R² = -1.8110, R² diff = 0.4056
# theta | LSG-2 -> R² = -0.4638, R² diff = 0.4196
# theta | ZZx1-inv -> R² = 0.2522, R² diff = 0.5698
# theta | ZZx1 -> R² = -0.3809, R² diff = 0.3529
# theta | ZZx2-inv2 -> R² = -0.4951, R² diff = 0.3679
# theta | ZZx2 -> R² = -0.5654, R² diff = 0.4598
# theta | ZZxReto -> R² = -0.2543, R² diff = 0.3971
# theta | ZZy1 -> R² = -39.1993, R² diff = -0.2206
# theta | ZZy2 -> R² = 0.9584, R² diff = 0.5911
# theta | semiCirc -> R² = -8.8553, R² diff = 0.2468
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.01 seed=2389 salvo.
# Epoch 0 | Train Loss 1.203443 | data Loss 1.175953 |  physics Loss 1.267589 | Val Loss 1.258792
# Epoch 100 | Train Loss 0.445544 | data Loss 0.359431 |  physics Loss 0.646473 | Val Loss 0.616642
# Epoch 200 | Train Loss 0.381847 | data Loss 0.280404 |  physics Loss 0.618546 | Val Loss 0.641132
# Early stopping at epoch 289
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.7_Lp0.3_seed1595.keras
# theta | SuperZZ1 -> R² = 0.7396, R² diff = 0.6073
# theta | SuperZZ2 -> R² = 0.4262, R² diff = 0.5465
# theta | LSG-1 -> R² = -2.4412, R² diff = 0.3992
# theta | LSG-2 -> R² = -0.4824, R² diff = 0.4192
# theta | ZZx1-inv -> R² = 0.3511, R² diff = 0.5568
# theta | ZZx1 -> R² = -0.6651, R² diff = 0.3149
# theta | ZZx2-inv2 -> R² = -0.0934, R² diff = 0.3920
# theta | ZZx2 -> R² = -0.5241, R² diff = 0.4335
# theta | ZZxReto -> R² = -0.6445, R² diff = 0.3084
# theta | ZZy1 -> R² = -49.5853, R² diff = -0.3559
# theta | ZZy2 -> R² = 0.9477, R² diff = 0.5690
# theta | semiCirc -> R² = -12.1807, R² diff = 0.1187
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 1.044312 | data Loss 1.020413 |  physics Loss 1.100075 | Val Loss 1.134922
# Epoch 100 | Train Loss 0.463620 | data Loss 0.349440 |  physics Loss 0.730039 | Val Loss 0.597056
# Epoch 200 | Train Loss 0.407981 | data Loss 0.319233 |  physics Loss 0.615059 | Val Loss 0.718377
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.7_Lp0.3_seed6927.keras
# theta | SuperZZ1 -> R² = 0.3352, R² diff = 0.5738
# theta | SuperZZ2 -> R² = 0.6506, R² diff = 0.5485
# theta | LSG-1 -> R² = -3.7635, R² diff = 0.4347
# theta | LSG-2 -> R² = -0.6650, R² diff = 0.4402
# theta | ZZx1-inv -> R² = 0.6558, R² diff = 0.6165
# theta | ZZx1 -> R² = -0.6881, R² diff = 0.3512
# theta | ZZx2-inv2 -> R² = 0.3006, R² diff = 0.4095
# theta | ZZx2 -> R² = -1.0105, R² diff = 0.4127
# theta | ZZxReto -> R² = -0.3110, R² diff = 0.4066
# theta | ZZy1 -> R² = -38.9196, R² diff = -0.1661
# theta | ZZy2 -> R² = 0.8646, R² diff = 0.5821
# theta | semiCirc -> R² = -25.1218, R² diff = -0.1541
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.01 seed=6927 salvo.
# Epoch 0 | Train Loss 0.948620 | data Loss 0.881305 |  physics Loss 1.105688 | Val Loss 0.890126
# Epoch 100 | Train Loss 0.425744 | data Loss 0.337588 |  physics Loss 0.631441 | Val Loss 0.580889
# Epoch 200 | Train Loss 0.376805 | data Loss 0.286501 |  physics Loss 0.587516 | Val Loss 0.614497
# Epoch 300 | Train Loss 0.352801 | data Loss 0.247398 |  physics Loss 0.598742 | Val Loss 0.731524
# Early stopping at epoch 363
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.7_Lp0.3_seed4518.keras
# theta | SuperZZ1 -> R² = 0.4462, R² diff = 0.6078
# theta | SuperZZ2 -> R² = 0.5874, R² diff = 0.5747
# theta | LSG-1 -> R² = -3.7449, R² diff = 0.3235
# theta | LSG-2 -> R² = -2.4747, R² diff = 0.3835
# theta | ZZx1-inv -> R² = -0.0984, R² diff = 0.4712
# theta | ZZx1 -> R² = -1.4971, R² diff = 0.1526
# theta | ZZx2-inv2 -> R² = -1.0188, R² diff = 0.2265
# theta | ZZx2 -> R² = -0.7585, R² diff = 0.4191
# theta | ZZxReto -> R² = -0.8184, R² diff = 0.2632
# theta | ZZy1 -> R² = -19.3668, R² diff = -0.0175
# theta | ZZy2 -> R² = 0.1620, R² diff = 0.5619
# theta | semiCirc -> R² = -2.9241, R² diff = 0.3761
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.01 seed=4518 salvo.
# Epoch 0 | Train Loss 1.128963 | data Loss 1.118726 |  physics Loss 1.152850 | Val Loss 1.210837
# Epoch 100 | Train Loss 0.424597 | data Loss 0.349498 |  physics Loss 0.599830 | Val Loss 0.594594
# Epoch 200 | Train Loss 0.375004 | data Loss 0.265181 |  physics Loss 0.631260 | Val Loss 0.581538
# Epoch 300 | Train Loss 0.345450 | data Loss 0.240436 |  physics Loss 0.590481 | Val Loss 0.671902
# Early stopping at epoch 395
# Modelo salvo em:
# models/model_arch89_r0.01_Ld0.7_Lp0.3_seed306.keras
# theta | SuperZZ1 -> R² = 0.4056, R² diff = 0.7270
# theta | SuperZZ2 -> R² = 0.2961, R² diff = 0.5452
# theta | LSG-1 -> R² = -3.5558, R² diff = 0.5166
# theta | LSG-2 -> R² = -2.4369, R² diff = 0.4987
# theta | ZZx1-inv -> R² = 0.7537, R² diff = 0.6432
# theta | ZZx1 -> R² = -1.0686, R² diff = 0.4382
# theta | ZZx2-inv2 -> R² = -1.0024, R² diff = 0.2833
# theta | ZZx2 -> R² = 0.7903, R² diff = 0.4997
# theta | ZZxReto -> R² = -0.1732, R² diff = 0.5632
# theta | ZZy1 -> R² = -17.8307, R² diff = 0.2014
# theta | ZZy2 -> R² = 0.9268, R² diff = 0.6188
# theta | semiCirc -> R² = -11.2797, R² diff = 0.1686
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.01 seed=306 salvo.
# Epoch 0 | Train Loss 0.985923 | data Loss 0.939939 |  physics Loss 1.093221 | Val Loss 0.994366
# Epoch 100 | Train Loss 0.458348 | data Loss 0.370587 |  physics Loss 0.663123 | Val Loss 0.637023
# Epoch 200 | Train Loss 0.394877 | data Loss 0.309957 |  physics Loss 0.593025 | Val Loss 0.618533
# Early stopping at epoch 265
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.7_Lp0.3_seed2389.keras
# theta | SuperZZ1 -> R² = 0.7269, R² diff = 0.5861
# theta | SuperZZ2 -> R² = 0.3695, R² diff = 0.5408
# theta | LSG-1 -> R² = -2.8368, R² diff = 0.4194
# theta | LSG-2 -> R² = -0.3871, R² diff = 0.4276
# theta | ZZx1-inv -> R² = 0.3796, R² diff = 0.5895
# theta | ZZx1 -> R² = -0.5369, R² diff = 0.3573
# theta | ZZx2-inv2 -> R² = 0.1087, R² diff = 0.4105
# theta | ZZx2 -> R² = -0.2500, R² diff = 0.4448
# theta | ZZxReto -> R² = -0.4505, R² diff = 0.3796
# theta | ZZy1 -> R² = -49.1754, R² diff = -0.3130
# theta | ZZy2 -> R² = 0.9416, R² diff = 0.5801
# theta | semiCirc -> R² = -22.0790, R² diff = -0.0928
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.9 seed=2389 salvo.
# Epoch 0 | Train Loss 1.040778 | data Loss 1.007205 |  physics Loss 1.119118 | Val Loss 1.046709
# Epoch 100 | Train Loss 0.447430 | data Loss 0.359050 |  physics Loss 0.653648 | Val Loss 0.616782
# Epoch 200 | Train Loss 0.476551 | data Loss 0.392614 |  physics Loss 0.672403 | Val Loss 0.823923
# Epoch 300 | Train Loss 0.355022 | data Loss 0.248766 |  physics Loss 0.602955 | Val Loss 0.797813
# Early stopping at epoch 314
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.7_Lp0.3_seed1595.keras
# theta | SuperZZ1 -> R² = 0.7969, R² diff = 0.6411
# theta | SuperZZ2 -> R² = -0.1490, R² diff = 0.5469
# theta | LSG-1 -> R² = -2.0350, R² diff = 0.4113
# theta | LSG-2 -> R² = -0.4115, R² diff = 0.4338
# theta | ZZx1-inv -> R² = 0.2189, R² diff = 0.5783
# theta | ZZx1 -> R² = -0.4304, R² diff = 0.3272
# theta | ZZx2-inv2 -> R² = -1.5360, R² diff = 0.3121
# theta | ZZx2 -> R² = 0.0235, R² diff = 0.4730
# theta | ZZxReto -> R² = -0.4770, R² diff = 0.3689
# theta | ZZy1 -> R² = -44.3461, R² diff = -0.2639
# theta | ZZy2 -> R² = 0.9692, R² diff = 0.5866
# theta | semiCirc -> R² = -10.0998, R² diff = 0.2160
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 0.939596 | data Loss 0.901065 |  physics Loss 1.029501 | Val Loss 0.975442
# Epoch 100 | Train Loss 0.421904 | data Loss 0.326312 |  physics Loss 0.644952 | Val Loss 0.610811
# Epoch 200 | Train Loss 0.378130 | data Loss 0.282318 |  physics Loss 0.601693 | Val Loss 0.648550
# Early stopping at epoch 282
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.7_Lp0.3_seed6927.keras
# theta | SuperZZ1 -> R² = 0.8557, R² diff = 0.6482
# theta | SuperZZ2 -> R² = -0.6932, R² diff = 0.5440
# theta | LSG-1 -> R² = -2.4691, R² diff = 0.4320
# theta | LSG-2 -> R² = -0.1223, R² diff = 0.4488
# theta | ZZx1-inv -> R² = 0.5634, R² diff = 0.5962
# theta | ZZx1 -> R² = -0.9141, R² diff = 0.3834
# theta | ZZx2-inv2 -> R² = -1.0899, R² diff = 0.3528
# theta | ZZx2 -> R² = -0.2442, R² diff = 0.4861
# theta | ZZxReto -> R² = -0.3363, R² diff = 0.3988
# theta | ZZy1 -> R² = -34.4655, R² diff = -0.1446
# theta | ZZy2 -> R² = 0.9254, R² diff = 0.5973
# theta | semiCirc -> R² = -16.1525, R² diff = 0.0544
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.9 seed=6927 salvo.
# Epoch 0 | Train Loss 0.951131 | data Loss 0.897221 |  physics Loss 1.076921 | Val Loss 0.947267
# Epoch 100 | Train Loss 0.434769 | data Loss 0.350065 |  physics Loss 0.632413 | Val Loss 0.610449
# Epoch 200 | Train Loss 0.383172 | data Loss 0.287761 |  physics Loss 0.605796 | Val Loss 0.639791
# Epoch 300 | Train Loss 0.348799 | data Loss 0.246968 |  physics Loss 0.586404 | Val Loss 0.770549
# Early stopping at epoch 374
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.7_Lp0.3_seed4518.keras
# theta | SuperZZ1 -> R² = 0.6694, R² diff = 0.6453
# theta | SuperZZ2 -> R² = 0.3389, R² diff = 0.5470
# theta | LSG-1 -> R² = -2.8957, R² diff = 0.3949
# theta | LSG-2 -> R² = -1.1696, R² diff = 0.4484
# theta | ZZx1-inv -> R² = 0.2790, R² diff = 0.5386
# theta | ZZx1 -> R² = -1.0703, R² diff = 0.2479
# theta | ZZx2-inv2 -> R² = -1.3930, R² diff = 0.2091
# theta | ZZx2 -> R² = -0.3062, R² diff = 0.4621
# theta | ZZxReto -> R² = -0.3817, R² diff = 0.3550
# theta | ZZy1 -> R² = -19.6314, R² diff = 0.0350
# theta | ZZy2 -> R² = 0.5845, R² diff = 0.5989
# theta | semiCirc -> R² = -4.2448, R² diff = 0.4313
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.9 seed=4518 salvo.
# Epoch 0 | Train Loss 1.134080 | data Loss 1.116421 |  physics Loss 1.175282 | Val Loss 1.176033
# Epoch 100 | Train Loss 0.445342 | data Loss 0.343044 |  physics Loss 0.684040 | Val Loss 0.581765
# Epoch 200 | Train Loss 0.399805 | data Loss 0.318508 |  physics Loss 0.589497 | Val Loss 0.559844
# Epoch 300 | Train Loss 0.372997 | data Loss 0.282423 |  physics Loss 0.584337 | Val Loss 0.566849
# Early stopping at epoch 346
# Modelo salvo em:
# models/model_arch89_r0.9_Ld0.7_Lp0.3_seed306.keras
# theta | SuperZZ1 -> R² = 0.1365, R² diff = 0.6601
# theta | SuperZZ2 -> R² = 0.6516, R² diff = 0.6042
# theta | LSG-1 -> R² = -2.4795, R² diff = 0.4922
# theta | LSG-2 -> R² = -1.1466, R² diff = 0.4517
# theta | ZZx1-inv -> R² = 0.8433, R² diff = 0.6176
# theta | ZZx1 -> R² = -0.3461, R² diff = 0.3954
# theta | ZZx2-inv2 -> R² = -0.1214, R² diff = 0.3955
# theta | ZZx2 -> R² = 0.0766, R² diff = 0.5472
# theta | ZZxReto -> R² = 0.2869, R² diff = 0.5320
# theta | ZZy1 -> R² = -30.2528, R² diff = 0.0017
# theta | ZZy2 -> R² = 0.8662, R² diff = 0.6017
# theta | semiCirc -> R² = -17.2258, R² diff = 0.1129
# Modelo [89] | Ld=0.7 Lp=0.3 r=0.9 seed=306 salvo.
# Epoch 0 | Train Loss 1.039897 | data Loss 0.926330 |  physics Loss 1.088568 | Val Loss 1.003061
# Epoch 100 | Train Loss 0.430110 | data Loss 0.642682 |  physics Loss 0.339008 | Val Loss 0.847780
# Epoch 200 | Train Loss 0.373980 | data Loss 0.610223 |  physics Loss 0.272734 | Val Loss 0.817186
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.3_Lp0.7_seed2389.keras
# theta | SuperZZ1 -> R² = 0.5059, R² diff = 0.4978
# theta | SuperZZ2 -> R² = -0.6994, R² diff = 0.4492
# theta | LSG-1 -> R² = -0.4665, R² diff = 0.4468
# theta | LSG-2 -> R² = 0.1792, R² diff = 0.4119
# theta | ZZx1-inv -> R² = 0.8017, R² diff = 0.5966
# theta | ZZx1 -> R² = 0.0952, R² diff = 0.3860
# theta | ZZx2-inv2 -> R² = 0.0620, R² diff = 0.3704
# theta | ZZx2 -> R² = -1.1557, R² diff = 0.3619
# theta | ZZxReto -> R² = 0.3693, R² diff = 0.4712
# theta | ZZy1 -> R² = -14.3909, R² diff = 0.1662
# theta | ZZy2 -> R² = 0.4880, R² diff = 0.4802
# theta | semiCirc -> R² = -11.6679, R² diff = 0.1752
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.01 seed=2389 salvo.
# Epoch 0 | Train Loss 1.135538 | data Loss 1.072732 |  physics Loss 1.162455 | Val Loss 1.160825
# Epoch 100 | Train Loss 0.430956 | data Loss 0.621373 |  physics Loss 0.349349 | Val Loss 0.847668
# Epoch 200 | Train Loss 0.377081 | data Loss 0.638432 |  physics Loss 0.265074 | Val Loss 0.819654
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.3_Lp0.7_seed1595.keras
# theta | SuperZZ1 -> R² = 0.8029, R² diff = 0.4453
# theta | SuperZZ2 -> R² = -0.3912, R² diff = 0.3988
# theta | LSG-1 -> R² = -0.3185, R² diff = 0.4431
# theta | LSG-2 -> R² = 0.4757, R² diff = 0.4256
# theta | ZZx1-inv -> R² = 0.6726, R² diff = 0.4732
# theta | ZZx1 -> R² = 0.1404, R² diff = 0.3409
# theta | ZZx2-inv2 -> R² = 0.7188, R² diff = 0.3460
# theta | ZZx2 -> R² = -2.2714, R² diff = 0.2077
# theta | ZZxReto -> R² = -0.3173, R² diff = 0.3453
# theta | ZZy1 -> R² = -30.4062, R² diff = -0.0678
# theta | ZZy2 -> R² = 0.3693, R² diff = 0.3718
# theta | semiCirc -> R² = -12.2253, R² diff = 0.0903
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 1.078061 | data Loss 1.034028 |  physics Loss 1.096932 | Val Loss 1.134973
# Epoch 100 | Train Loss 0.434643 | data Loss 0.598678 |  physics Loss 0.364343 | Val Loss 0.811027
# Epoch 200 | Train Loss 0.402118 | data Loss 0.597481 |  physics Loss 0.318392 | Val Loss 0.792216
# Epoch 300 | Train Loss 0.378007 | data Loss 0.594829 |  physics Loss 0.285083 | Val Loss 0.761306
# Epoch 400 | Train Loss 0.366877 | data Loss 0.595373 |  physics Loss 0.268950 | Val Loss 0.767369
# Early stopping at epoch 472
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.3_Lp0.7_seed6927.keras
# theta | SuperZZ1 -> R² = 0.8630, R² diff = 0.4703
# theta | SuperZZ2 -> R² = -0.1248, R² diff = 0.4301
# theta | LSG-1 -> R² = -2.0703, R² diff = 0.3879
# theta | LSG-2 -> R² = -0.0108, R² diff = 0.4115
# theta | ZZx1-inv -> R² = 0.7713, R² diff = 0.3011
# theta | ZZx1 -> R² = -2.1443, R² diff = 0.2361
# theta | ZZx2-inv2 -> R² = -0.4342, R² diff = 0.3224
# theta | ZZx2 -> R² = 0.7443, R² diff = 0.4082
# theta | ZZxReto -> R² = -0.8971, R² diff = 0.1966
# theta | ZZy1 -> R² = -20.3935, R² diff = 0.0298
# theta | ZZy2 -> R² = 0.7753, R² diff = 0.4304
# theta | semiCirc -> R² = -14.2230, R² diff = 0.1358
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.01 seed=6927 salvo.
# Epoch 0 | Train Loss 1.055814 | data Loss 0.981280 |  physics Loss 1.087757 | Val Loss 1.082455
# Epoch 100 | Train Loss 0.415258 | data Loss 0.620679 |  physics Loss 0.327220 | Val Loss 0.833751
# Epoch 200 | Train Loss 0.375651 | data Loss 0.597708 |  physics Loss 0.280484 | Val Loss 0.806275
# Early stopping at epoch 208
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.3_Lp0.7_seed4518.keras
# theta | SuperZZ1 -> R² = 0.8501, R² diff = 0.4736
# theta | SuperZZ2 -> R² = -3.0024, R² diff = 0.3872
# theta | LSG-1 -> R² = -0.6417, R² diff = 0.4054
# theta | LSG-2 -> R² = 0.1684, R² diff = 0.4194
# theta | ZZx1-inv -> R² = 0.0737, R² diff = 0.5763
# theta | ZZx1 -> R² = -0.1956, R² diff = 0.3637
# theta | ZZx2-inv2 -> R² = -0.8216, R² diff = 0.3221
# theta | ZZx2 -> R² = -1.4618, R² diff = 0.2868
# theta | ZZxReto -> R² = -0.3630, R² diff = 0.3955
# theta | ZZy1 -> R² = -13.9345, R² diff = 0.1256
# theta | ZZy2 -> R² = -0.3062, R² diff = 0.4398
# theta | semiCirc -> R² = -6.7150, R² diff = 0.2707
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.01 seed=4518 salvo.
# Epoch 0 | Train Loss 1.094236 | data Loss 1.029363 |  physics Loss 1.122039 | Val Loss 1.104381
# Epoch 100 | Train Loss 0.423391 | data Loss 0.628419 |  physics Loss 0.335522 | Val Loss 0.833840
# Epoch 200 | Train Loss 0.377761 | data Loss 0.631326 |  physics Loss 0.269091 | Val Loss 0.849912
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.3_Lp0.7_seed306.keras
# theta | SuperZZ1 -> R² = 0.2970, R² diff = 0.4712
# theta | SuperZZ2 -> R² = -0.1885, R² diff = 0.4288
# theta | LSG-1 -> R² = -0.7123, R² diff = 0.4326
# theta | LSG-2 -> R² = 0.0717, R² diff = 0.4014
# theta | ZZx1-inv -> R² = 0.7823, R² diff = 0.5718
# theta | ZZx1 -> R² = -0.0298, R² diff = 0.3387
# theta | ZZx2-inv2 -> R² = 0.1100, R² diff = 0.3373
# theta | ZZx2 -> R² = -1.0221, R² diff = 0.3434
# theta | ZZxReto -> R² = 0.3071, R² diff = 0.4325
# theta | ZZy1 -> R² = -12.8864, R² diff = 0.1640
# theta | ZZy2 -> R² = 0.7146, R² diff = 0.4579
# theta | semiCirc -> R² = -10.4799, R² diff = 0.1974
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.01 seed=306 salvo.
# Epoch 0 | Train Loss 1.022254 | data Loss 0.935809 |  physics Loss 1.059302 | Val Loss 0.982113
# Epoch 100 | Train Loss 0.433924 | data Loss 0.630549 |  physics Loss 0.349656 | Val Loss 0.870122
# Epoch 200 | Train Loss 0.393109 | data Loss 0.626006 |  physics Loss 0.293296 | Val Loss 0.820747
# Early stopping at epoch 218
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.3_Lp0.7_seed2389.keras
# theta | SuperZZ1 -> R² = 0.6999, R² diff = 0.4676
# theta | SuperZZ2 -> R² = -0.6637, R² diff = 0.4145
# theta | LSG-1 -> R² = -0.5014, R² diff = 0.4202
# theta | LSG-2 -> R² = 0.1987, R² diff = 0.3991
# theta | ZZx1-inv -> R² = 0.0951, R² diff = 0.5747
# theta | ZZx1 -> R² = -0.0039, R² diff = 0.3279
# theta | ZZx2-inv2 -> R² = -0.5263, R² diff = 0.3184
# theta | ZZx2 -> R² = 0.1410, R² diff = 0.3705
# theta | ZZxReto -> R² = -0.2735, R² diff = 0.4403
# theta | ZZy1 -> R² = -16.2105, R² diff = 0.1311
# theta | ZZy2 -> R² = 0.4610, R² diff = 0.4496
# theta | semiCirc -> R² = -10.5021, R² diff = 0.1946
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.9 seed=2389 salvo.
# Epoch 0 | Train Loss 1.386930 | data Loss 1.308798 |  physics Loss 1.420415 | Val Loss 1.344501
# Epoch 100 | Train Loss 0.421479 | data Loss 0.646130 |  physics Loss 0.325199 | Val Loss 0.802515
# Epoch 200 | Train Loss 0.375987 | data Loss 0.626453 |  physics Loss 0.268644 | Val Loss 0.775937
# Early stopping at epoch 216
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.3_Lp0.7_seed1595.keras
# theta | SuperZZ1 -> R² = 0.7306, R² diff = 0.4823
# theta | SuperZZ2 -> R² = -1.5387, R² diff = 0.4090
# theta | LSG-1 -> R² = -0.9322, R² diff = 0.4095
# theta | LSG-2 -> R² = 0.1680, R² diff = 0.4349
# theta | ZZx1-inv -> R² = 0.4634, R² diff = 0.5849
# theta | ZZx1 -> R² = -0.2341, R² diff = 0.3411
# theta | ZZx2-inv2 -> R² = -0.3409, R² diff = 0.3152
# theta | ZZx2 -> R² = -3.1345, R² diff = 0.2076
# theta | ZZxReto -> R² = -0.2786, R² diff = 0.3623
# theta | ZZy1 -> R² = -18.1288, R² diff = 0.0597
# theta | ZZy2 -> R² = 0.5412, R² diff = 0.4465
# theta | semiCirc -> R² = -8.3903, R² diff = 0.2388
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 1.032163 | data Loss 0.940246 |  physics Loss 1.071556 | Val Loss 1.021975
# Epoch 100 | Train Loss 0.427608 | data Loss 0.628190 |  physics Loss 0.341644 | Val Loss 0.860594
# Epoch 200 | Train Loss 0.371543 | data Loss 0.612323 |  physics Loss 0.268351 | Val Loss 0.820741
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.3_Lp0.7_seed6927.keras
# theta | SuperZZ1 -> R² = 0.8492, R² diff = 0.5064
# theta | SuperZZ2 -> R² = -0.3169, R² diff = 0.4677
# theta | LSG-1 -> R² = -1.2425, R² diff = 0.4189
# theta | LSG-2 -> R² = -0.5113, R² diff = 0.4459
# theta | ZZx1-inv -> R² = -0.9463, R² diff = 0.5708
# theta | ZZx1 -> R² = -0.6729, R² diff = 0.3006
# theta | ZZx2-inv2 -> R² = -0.1426, R² diff = 0.3662
# theta | ZZx2 -> R² = -1.0060, R² diff = 0.3142
# theta | ZZxReto -> R² = -1.6385, R² diff = 0.3427
# theta | ZZy1 -> R² = -33.1893, R² diff = -0.0893
# theta | ZZy2 -> R² = 0.8166, R² diff = 0.4904
# theta | semiCirc -> R² = -13.0588, R² diff = 0.1032
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.9 seed=6927 salvo.
# Epoch 0 | Train Loss 1.043952 | data Loss 0.870027 |  physics Loss 1.118491 | Val Loss 0.887612
# Epoch 100 | Train Loss 0.422722 | data Loss 0.561121 |  physics Loss 0.363409 | Val Loss 0.791342
# Epoch 200 | Train Loss 0.373729 | data Loss 0.603904 |  physics Loss 0.275083 | Val Loss 0.782529
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.3_Lp0.7_seed4518.keras
# theta | SuperZZ1 -> R² = 0.5113, R² diff = 0.5178
# theta | SuperZZ2 -> R² = -0.2099, R² diff = 0.4568
# theta | LSG-1 -> R² = -1.0550, R² diff = 0.4455
# theta | LSG-2 -> R² = 0.0932, R² diff = 0.4440
# theta | ZZx1-inv -> R² = 0.7799, R² diff = 0.6283
# theta | ZZx1 -> R² = -0.0436, R² diff = 0.4002
# theta | ZZx2-inv2 -> R² = 0.3159, R² diff = 0.3805
# theta | ZZx2 -> R² = -1.4851, R² diff = 0.3317
# theta | ZZxReto -> R² = 0.0009, R² diff = 0.4417
# theta | ZZy1 -> R² = -23.2062, R² diff = 0.0450
# theta | ZZy2 -> R² = 0.6943, R² diff = 0.4828
# theta | semiCirc -> R² = -13.8834, R² diff = 0.1103
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.9 seed=4518 salvo.
# Epoch 0 | Train Loss 1.064545 | data Loss 1.008456 |  physics Loss 1.088583 | Val Loss 1.085245
# Epoch 100 | Train Loss 0.429865 | data Loss 0.616210 |  physics Loss 0.350003 | Val Loss 0.847875
# Epoch 200 | Train Loss 0.391133 | data Loss 0.556501 |  physics Loss 0.320260 | Val Loss 0.900456
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.3_Lp0.7_seed306.keras
# theta | SuperZZ1 -> R² = 0.8807, R² diff = 0.5201
# theta | SuperZZ2 -> R² = -1.2263, R² diff = 0.4569
# theta | LSG-1 -> R² = -0.5148, R² diff = 0.4659
# theta | LSG-2 -> R² = 0.3937, R² diff = 0.4520
# theta | ZZx1-inv -> R² = 0.2227, R² diff = 0.6012
# theta | ZZx1 -> R² = -0.0088, R² diff = 0.3998
# theta | ZZx2-inv2 -> R² = -0.0690, R² diff = 0.3906
# theta | ZZx2 -> R² = -0.9785, R² diff = 0.3600
# theta | ZZxReto -> R² = -0.5150, R² diff = 0.4275
# theta | ZZy1 -> R² = -26.3353, R² diff = 0.0256
# theta | ZZy2 -> R² = 0.3134, R² diff = 0.4872
# theta | semiCirc -> R² = -13.4494, R² diff = 0.1223
# Modelo [90] | Ld=0.3 Lp=0.7 r=0.9 seed=306 salvo.
# Epoch 0 | Train Loss 1.015037 | data Loss 0.987058 |  physics Loss 1.080319 | Val Loss 1.037603
# Epoch 100 | Train Loss 0.450549 | data Loss 0.353699 |  physics Loss 0.676532 | Val Loss 0.649928
# Epoch 200 | Train Loss 0.391278 | data Loss 0.299349 |  physics Loss 0.605780 | Val Loss 0.695072
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.7_Lp0.3_seed2389.keras
# theta | SuperZZ1 -> R² = 0.7845, R² diff = 0.6004
# theta | SuperZZ2 -> R² = -0.4741, R² diff = 0.5312
# theta | LSG-1 -> R² = -1.8448, R² diff = 0.4870
# theta | LSG-2 -> R² = 0.0222, R² diff = 0.4618
# theta | ZZx1-inv -> R² = 0.3608, R² diff = 0.6220
# theta | ZZx1 -> R² = 0.0718, R² diff = 0.4344
# theta | ZZx2-inv2 -> R² = -0.2318, R² diff = 0.4215
# theta | ZZx2 -> R² = 0.3142, R² diff = 0.4849
# theta | ZZxReto -> R² = -0.3860, R² diff = 0.4935
# theta | ZZy1 -> R² = -45.6781, R² diff = -0.1731
# theta | ZZy2 -> R² = 0.7623, R² diff = 0.5927
# theta | semiCirc -> R² = -29.6226, R² diff = -0.2320
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.01 seed=2389 salvo.
# Epoch 0 | Train Loss 1.120881 | data Loss 1.082720 |  physics Loss 1.209924 | Val Loss 1.114884
# Epoch 100 | Train Loss 0.448120 | data Loss 0.355517 |  physics Loss 0.664194 | Val Loss 0.572366
# Epoch 200 | Train Loss 0.395220 | data Loss 0.307750 |  physics Loss 0.599317 | Val Loss 0.658784
# Early stopping at epoch 263
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.7_Lp0.3_seed1595.keras
# theta | SuperZZ1 -> R² = 0.7143, R² diff = 0.5959
# theta | SuperZZ2 -> R² = 0.2280, R² diff = 0.5418
# theta | LSG-1 -> R² = -3.6385, R² diff = 0.4303
# theta | LSG-2 -> R² = -0.4216, R² diff = 0.4458
# theta | ZZx1-inv -> R² = 0.5044, R² diff = 0.5960
# theta | ZZx1 -> R² = -0.8651, R² diff = 0.3359
# theta | ZZx2-inv2 -> R² = -0.0097, R² diff = 0.4013
# theta | ZZx2 -> R² = -0.5945, R² diff = 0.4366
# theta | ZZxReto -> R² = -0.5415, R² diff = 0.3438
# theta | ZZy1 -> R² = -45.1454, R² diff = -0.2732
# theta | ZZy2 -> R² = 0.9324, R² diff = 0.5921
# theta | semiCirc -> R² = -23.3956, R² diff = -0.1179
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 1.001864 | data Loss 0.977935 |  physics Loss 1.057696 | Val Loss 1.077797
# Epoch 100 | Train Loss 0.390640 | data Loss 0.297752 |  physics Loss 0.607378 | Val Loss 0.636836
# Epoch 200 | Train Loss 0.348826 | data Loss 0.248249 |  physics Loss 0.583506 | Val Loss 0.685293
# Early stopping at epoch 266
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.7_Lp0.3_seed6927.keras
# theta | SuperZZ1 -> R² = 0.8412, R² diff = 0.6496
# theta | SuperZZ2 -> R² = -0.4115, R² diff = 0.5435
# theta | LSG-1 -> R² = -2.3208, R² diff = 0.4185
# theta | LSG-2 -> R² = -0.3142, R² diff = 0.4468
# theta | ZZx1-inv -> R² = 0.4149, R² diff = 0.5764
# theta | ZZx1 -> R² = -0.5927, R² diff = 0.3273
# theta | ZZx2-inv2 -> R² = -0.9437, R² diff = 0.3498
# theta | ZZx2 -> R² = -0.0208, R² diff = 0.5017
# theta | ZZxReto -> R² = -0.3881, R² diff = 0.3497
# theta | ZZy1 -> R² = -43.5489, R² diff = -0.2660
# theta | ZZy2 -> R² = 0.9586, R² diff = 0.5944
# theta | semiCirc -> R² = -10.9759, R² diff = 0.2132
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.01 seed=6927 salvo.
# Epoch 0 | Train Loss 1.102606 | data Loss 1.080669 |  physics Loss 1.153794 | Val Loss 1.118232
# Epoch 100 | Train Loss 0.438054 | data Loss 0.350899 |  physics Loss 0.641415 | Val Loss 0.629431
# Epoch 200 | Train Loss 0.371430 | data Loss 0.267299 |  physics Loss 0.614402 | Val Loss 0.650624
# Epoch 300 | Train Loss 0.345960 | data Loss 0.237812 |  physics Loss 0.598305 | Val Loss 0.748194
# Early stopping at epoch 306
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.7_Lp0.3_seed4518.keras
# theta | SuperZZ1 -> R² = 0.8318, R² diff = 0.6551
# theta | SuperZZ2 -> R² = -0.5512, R² diff = 0.5367
# theta | LSG-1 -> R² = -1.9683, R² diff = 0.4296
# theta | LSG-2 -> R² = -0.2108, R² diff = 0.4534
# theta | ZZx1-inv -> R² = 0.4153, R² diff = 0.5914
# theta | ZZx1 -> R² = -0.4646, R² diff = 0.3469
# theta | ZZx2-inv2 -> R² = -1.3487, R² diff = 0.3278
# theta | ZZx2 -> R² = 0.0434, R² diff = 0.4923
# theta | ZZxReto -> R² = -0.3172, R² diff = 0.3836
# theta | ZZy1 -> R² = -37.6141, R² diff = -0.1555
# theta | ZZy2 -> R² = 0.9415, R² diff = 0.5860
# theta | semiCirc -> R² = -11.5213, R² diff = 0.1613
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.01 seed=4518 salvo.
# Epoch 0 | Train Loss 0.974772 | data Loss 0.942514 |  physics Loss 1.050039 | Val Loss 0.996176
# Epoch 100 | Train Loss 0.440053 | data Loss 0.338819 |  physics Loss 0.676265 | Val Loss 0.633735
# Epoch 200 | Train Loss 0.397480 | data Loss 0.293045 |  physics Loss 0.641162 | Val Loss 0.669312
# Epoch 300 | Train Loss 0.383902 | data Loss 0.281407 |  physics Loss 0.623055 | Val Loss 0.632326
# Early stopping at epoch 371
# Modelo salvo em:
# models/model_arch90_r0.01_Ld0.7_Lp0.3_seed306.keras
# theta | SuperZZ1 -> R² = 0.8392, R² diff = 0.6769
# theta | SuperZZ2 -> R² = -0.7723, R² diff = 0.5424
# theta | LSG-1 -> R² = -1.0028, R² diff = 0.5258
# theta | LSG-2 -> R² = -0.0200, R² diff = 0.4821
# theta | ZZx1-inv -> R² = 0.2504, R² diff = 0.5932
# theta | ZZx1 -> R² = 0.2702, R² diff = 0.4118
# theta | ZZx2-inv2 -> R² = -2.4710, R² diff = 0.2346
# theta | ZZx2 -> R² = -0.1865, R² diff = 0.5026
# theta | ZZxReto -> R² = 0.3301, R² diff = 0.5873
# theta | ZZy1 -> R² = -21.5674, R² diff = 0.1174
# theta | ZZy2 -> R² = 0.9321, R² diff = 0.6107
# theta | semiCirc -> R² = -16.0451, R² diff = 0.1489
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.01 seed=306 salvo.
# Epoch 0 | Train Loss 1.299688 | data Loss 1.295975 |  physics Loss 1.308352 | Val Loss 1.457205
# Epoch 100 | Train Loss 0.434222 | data Loss 0.332958 |  physics Loss 0.670504 | Val Loss 0.556716
# Epoch 200 | Train Loss 0.392446 | data Loss 0.292293 |  physics Loss 0.626136 | Val Loss 0.704504
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.7_Lp0.3_seed2389.keras
# theta | SuperZZ1 -> R² = 0.8097, R² diff = 0.6180
# theta | SuperZZ2 -> R² = -0.1252, R² diff = 0.5540
# theta | LSG-1 -> R² = -1.4863, R² diff = 0.4620
# theta | LSG-2 -> R² = -0.0441, R² diff = 0.4511
# theta | ZZx1-inv -> R² = 0.5871, R² diff = 0.5893
# theta | ZZx1 -> R² = -0.1192, R² diff = 0.4128
# theta | ZZx2-inv2 -> R² = -0.0865, R² diff = 0.4153
# theta | ZZx2 -> R² = -0.5744, R² diff = 0.4695
# theta | ZZxReto -> R² = 0.0804, R² diff = 0.4968
# theta | ZZy1 -> R² = -40.1472, R² diff = -0.1560
# theta | ZZy2 -> R² = 0.9411, R² diff = 0.5729
# theta | semiCirc -> R² = -17.5532, R² diff = 0.0434
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.9 seed=2389 salvo.
# Epoch 0 | Train Loss 1.041146 | data Loss 1.017458 |  physics Loss 1.096417 | Val Loss 1.101540
# Epoch 100 | Train Loss 0.427080 | data Loss 0.346972 |  physics Loss 0.614000 | Val Loss 0.574733
# Epoch 200 | Train Loss 0.384509 | data Loss 0.297505 |  physics Loss 0.587519 | Val Loss 0.617473
# Epoch 300 | Train Loss 0.353765 | data Loss 0.250144 |  physics Loss 0.595547 | Val Loss 0.724982
# Early stopping at epoch 381
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.7_Lp0.3_seed1595.keras
# theta | SuperZZ1 -> R² = 0.7285, R² diff = 0.6825
# theta | SuperZZ2 -> R² = -0.5514, R² diff = 0.5704
# theta | LSG-1 -> R² = -2.1986, R² diff = 0.4773
# theta | LSG-2 -> R² = -0.5758, R² diff = 0.4959
# theta | ZZx1-inv -> R² = 0.7524, R² diff = 0.5833
# theta | ZZx1 -> R² = -0.8122, R² diff = 0.3244
# theta | ZZx2-inv2 -> R² = -1.2114, R² diff = 0.2976
# theta | ZZx2 -> R² = -0.5122, R² diff = 0.5168
# theta | ZZxReto -> R² = -0.1549, R² diff = 0.4544
# theta | ZZy1 -> R² = -15.1265, R² diff = 0.1637
# theta | ZZy2 -> R² = 0.9255, R² diff = 0.6228
# theta | semiCirc -> R² = -7.1993, R² diff = 0.4084
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 1.026616 | data Loss 0.988210 |  physics Loss 1.116230 | Val Loss 1.101409
# Epoch 100 | Train Loss 0.446476 | data Loss 0.360097 |  physics Loss 0.648027 | Val Loss 0.625055
# Epoch 200 | Train Loss 0.373437 | data Loss 0.286735 |  physics Loss 0.575741 | Val Loss 0.591122
# Early stopping at epoch 284
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.7_Lp0.3_seed6927.keras
# theta | SuperZZ1 -> R² = 0.7935, R² diff = 0.6172
# theta | SuperZZ2 -> R² = 0.4504, R² diff = 0.5654
# theta | LSG-1 -> R² = -2.1702, R² diff = 0.4085
# theta | LSG-2 -> R² = -0.6081, R² diff = 0.4170
# theta | ZZx1-inv -> R² = -0.0652, R² diff = 0.5675
# theta | ZZx1 -> R² = -0.4319, R² diff = 0.3165
# theta | ZZx2-inv2 -> R² = -0.3634, R² diff = 0.3943
# theta | ZZx2 -> R² = -0.0472, R² diff = 0.4502
# theta | ZZxReto -> R² = -0.7876, R² diff = 0.3461
# theta | ZZy1 -> R² = -49.9568, R² diff = -0.3594
# theta | ZZy2 -> R² = 0.9522, R² diff = 0.5763
# theta | semiCirc -> R² = -12.0304, R² diff = 0.1107
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.9 seed=6927 salvo.
# Epoch 0 | Train Loss 0.957732 | data Loss 0.917320 |  physics Loss 1.052028 | Val Loss 0.985148
# Epoch 100 | Train Loss 0.433578 | data Loss 0.351405 |  physics Loss 0.625315 | Val Loss 0.541538
# Epoch 200 | Train Loss 0.372560 | data Loss 0.281158 |  physics Loss 0.585832 | Val Loss 0.582197
# Epoch 300 | Train Loss 0.345743 | data Loss 0.238341 |  physics Loss 0.596349 | Val Loss 0.670367
# Early stopping at epoch 356
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.7_Lp0.3_seed4518.keras
# theta | SuperZZ1 -> R² = 0.6394, R² diff = 0.6746
# theta | SuperZZ2 -> R² = 0.1850, R² diff = 0.5825
# theta | LSG-1 -> R² = -2.3609, R² diff = 0.4787
# theta | LSG-2 -> R² = -0.3567, R² diff = 0.4781
# theta | ZZx1-inv -> R² = 0.3373, R² diff = 0.5713
# theta | ZZx1 -> R² = -0.5640, R² diff = 0.3227
# theta | ZZx2-inv2 -> R² = -1.2089, R² diff = 0.3372
# theta | ZZx2 -> R² = -0.1716, R² diff = 0.5151
# theta | ZZxReto -> R² = -0.0895, R² diff = 0.3798
# theta | ZZy1 -> R² = -30.2875, R² diff = -0.0138
# theta | ZZy2 -> R² = 0.9686, R² diff = 0.6475
# theta | semiCirc -> R² = -8.2143, R² diff = 0.3020
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.9 seed=4518 salvo.
# Epoch 0 | Train Loss 1.101229 | data Loss 1.074393 |  physics Loss 1.163845 | Val Loss 1.157695
# Epoch 100 | Train Loss 0.446824 | data Loss 0.373536 |  physics Loss 0.617829 | Val Loss 0.566323
# Epoch 200 | Train Loss 0.391218 | data Loss 0.303411 |  physics Loss 0.596101 | Val Loss 0.559593
# Epoch 300 | Train Loss 0.354040 | data Loss 0.256429 |  physics Loss 0.581797 | Val Loss 0.636143
# Early stopping at epoch 381
# Modelo salvo em:
# models/model_arch90_r0.9_Ld0.7_Lp0.3_seed306.keras
# theta | SuperZZ1 -> R² = 0.7480, R² diff = 0.6473
# theta | SuperZZ2 -> R² = -0.1148, R² diff = 0.5583
# theta | LSG-1 -> R² = -1.7427, R² diff = 0.4297
# theta | LSG-2 -> R² = -1.1668, R² diff = 0.4590
# theta | ZZx1-inv -> R² = -1.5156, R² diff = 0.5409
# theta | ZZx1 -> R² = -0.5257, R² diff = 0.3083
# theta | ZZx2-inv2 -> R² = -1.6275, R² diff = 0.3270
# theta | ZZx2 -> R² = 0.5604, R² diff = 0.4759
# theta | ZZxReto -> R² = -0.7737, R² diff = 0.3428
# theta | ZZy1 -> R² = -34.3742, R² diff = -0.1116
# theta | ZZy2 -> R² = 0.9312, R² diff = 0.5870
# theta | semiCirc -> R² = -3.2431, R² diff = 0.4066
# Modelo [90] | Ld=0.7 Lp=0.3 r=0.9 seed=306 salvo.
# Epoch 0 | Train Loss 1.073144 | data Loss 0.986320 |  physics Loss 1.110354 | Val Loss 1.063202
# Epoch 100 | Train Loss 0.448798 | data Loss 0.616853 |  physics Loss 0.376774 | Val Loss 0.865853
# Epoch 200 | Train Loss 0.395877 | data Loss 0.572566 |  physics Loss 0.320154 | Val Loss 0.760179
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch91_r0.01_Ld0.3_Lp0.7_seed2389.keras
# theta | SuperZZ1 -> R² = 0.5277, R² diff = 0.5118
# theta | SuperZZ2 -> R² = -0.2773, R² diff = 0.4366
# theta | LSG-1 -> R² = -1.3969, R² diff = 0.4389
# theta | LSG-2 -> R² = -0.0371, R² diff = 0.4353
# theta | ZZx1-inv -> R² = 0.6681, R² diff = 0.6223
# theta | ZZx1 -> R² = -0.0365, R² diff = 0.3711
# theta | ZZx2-inv2 -> R² = -0.3297, R² diff = 0.3111
# theta | ZZx2 -> R² = -0.6606, R² diff = 0.3682
# theta | ZZxReto -> R² = 0.0217, R² diff = 0.4504
# theta | ZZy1 -> R² = -22.6207, R² diff = 0.0573
# theta | ZZy2 -> R² = 0.7588, R² diff = 0.4698
# theta | semiCirc -> R² = -15.3042, R² diff = 0.0910
# Modelo [91] | Ld=0.3 Lp=0.7 r=0.01 seed=2389 salvo.
# Epoch 0 | Train Loss 1.181148 | data Loss 1.146143 |  physics Loss 1.196150 | Val Loss 1.218592
# Epoch 100 | Train Loss 0.424665 | data Loss 0.625845 |  physics Loss 0.338446 | Val Loss 0.831026
# Epoch 200 | Train Loss 0.374970 | data Loss 0.610275 |  physics Loss 0.274124 | Val Loss 0.818725
# Early stopping at epoch 211
# Modelo salvo em:
# models/model_arch91_r0.01_Ld0.3_Lp0.7_seed1595.keras
# theta | SuperZZ1 -> R² = 0.7063, R² diff = 0.4739
# theta | SuperZZ2 -> R² = -1.2800, R² diff = 0.3956
# theta | LSG-1 -> R² = -1.0529, R² diff = 0.3954
# theta | LSG-2 -> R² = -0.1461, R² diff = 0.4295
# theta | ZZx1-inv -> R² = 0.3239, R² diff = 0.5874
# theta | ZZx1 -> R² = -0.2857, R² diff = 0.3253
# theta | ZZx2-inv2 -> R² = -0.5084, R² diff = 0.2795
# theta | ZZx2 -> R² = -2.6039, R² diff = 0.2284
# theta | ZZxReto -> R² = -0.1467, R² diff = 0.3742
# theta | ZZy1 -> R² = -14.4573, R² diff = 0.0915
# theta | ZZy2 -> R² = 0.6332, R² diff = 0.4408
# theta | semiCirc -> R² = -7.9234, R² diff = 0.2451
# Modelo [91] | Ld=0.3 Lp=0.7 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 1.032603 | data Loss 0.978416 |  physics Loss 1.055826 | Val Loss 1.068331
# Epoch 100 | Train Loss 0.437694 | data Loss 0.629789 |  physics Loss 0.355367 | Val Loss 0.810370
# Epoch 200 | Train Loss 0.393358 | data Loss 0.588274 |  physics Loss 0.309822 | Val Loss 0.869700
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch91_r0.01_Ld0.3_Lp0.7_seed6927.keras
# theta | SuperZZ1 -> R² = 0.8565, R² diff = 0.5020
# theta | SuperZZ2 -> R² = -1.3301, R² diff = 0.4130
# theta | LSG-1 -> R² = -0.4651, R² diff = 0.4695
# theta | LSG-2 -> R² = 0.2399, R² diff = 0.4448
# theta | ZZx1-inv -> R² = 0.2621, R² diff = 0.5812
# theta | ZZx1 -> R² = 0.1076, R² diff = 0.3970
# theta | ZZx2-inv2 -> R² = -0.6502, R² diff = 0.3250
# theta | ZZx2 -> R² = 0.0407, R² diff = 0.3722
# theta | ZZxReto -> R² = -1.1510, R² diff = 0.4543
# theta | ZZy1 -> R² = -36.8989, R² diff = -0.0602
# theta | ZZy2 -> R² = 0.2322, R² diff = 0.4309
# theta | semiCirc -> R² = -16.5948, R² diff = 0.0356
# Modelo [91] | Ld=0.3 Lp=0.7 r=0.01 seed=6927 salvo.
# Epoch 0 | Train Loss 1.001520 | data Loss 0.904853 |  physics Loss 1.042949 | Val Loss 0.945501
# Epoch 100 | Train Loss 0.417598 | data Loss 0.627188 |  physics Loss 0.327774 | Val Loss 0.822543
# Epoch 200 | Train Loss 0.402058 | data Loss 0.594425 |  physics Loss 0.319615 | Val Loss 0.884710
# Early stopping at epoch 219
# Modelo salvo em:
# models/model_arch91_r0.01_Ld0.3_Lp0.7_seed4518.keras
# theta | SuperZZ1 -> R² = 0.6356, R² diff = 0.5073
# theta | SuperZZ2 -> R² = -0.3423, R² diff = 0.4529
# theta | LSG-1 -> R² = -1.0767, R² diff = 0.4542
# theta | LSG-2 -> R² = 0.0165, R² diff = 0.4217
# theta | ZZx1-inv -> R² = 0.4858, R² diff = 0.6044
# theta | ZZx1 -> R² = 0.0601, R² diff = 0.3659
# theta | ZZx2-inv2 -> R² = -0.1114, R² diff = 0.3632
# theta | ZZx2 -> R² = 0.1048, R² diff = 0.4132
# theta | ZZxReto -> R² = 0.0265, R² diff = 0.4660
# theta | ZZy1 -> R² = -22.2947, R² diff = 0.0795
# theta | ZZy2 -> R² = 0.6881, R² diff = 0.4905
# theta | semiCirc -> R² = -16.7206, R² diff = 0.0692
# Modelo [91] | Ld=0.3 Lp=0.7 r=0.01 seed=4518 salvo.
# Epoch 0 | Train Loss 0.969185 | data Loss 0.873161 |  physics Loss 1.010338 | Val Loss 0.894118
# Epoch 100 | Train Loss 0.421141 | data Loss 0.632779 |  physics Loss 0.330439 | Val Loss 0.857958
# Epoch 200 | Train Loss 0.375872 | data Loss 0.602660 |  physics Loss 0.278678 | Val Loss 0.789594
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch91_r0.01_Ld0.3_Lp0.7_seed306.keras
# theta | SuperZZ1 -> R² = 0.7603, R² diff = 0.4975
# theta | SuperZZ2 -> R² = -1.2653, R² diff = 0.4292
# theta | LSG-1 -> R² = -0.5351, R² diff = 0.4417
# theta | LSG-2 -> R² = 0.3272, R² diff = 0.4282
# theta | ZZx1-inv -> R² = 0.3935, R² diff = 0.6025
# theta | ZZx1 -> R² = 0.0302, R² diff = 0.3719
# theta | ZZx2-inv2 -> R² = -0.4424, R² diff = 0.3417
# theta | ZZx2 -> R² = -0.7213, R² diff = 0.3598
# theta | ZZxReto -> R² = -0.1079, R² diff = 0.4446
# theta | ZZy1 -> R² = -17.8309, R² diff = 0.1158
# theta | ZZy2 -> R² = 0.3469, R² diff = 0.4687
# theta | semiCirc -> R² = -11.5914, R² diff = 0.1763
# Modelo [91] | Ld=0.3 Lp=0.7 r=0.01 seed=306 salvo.
# Epoch 0 | Train Loss 0.990081 | data Loss 0.906193 |  physics Loss 1.026033 | Val Loss 0.992047
# ...
# Epoch 200 | Train Loss 0.370106 | data Loss 0.606146 |  physics Loss 0.268946 | Val Loss 0.854927
# Early stopping at epoch 217
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed2389.keras
# theta | SuperZZ1 -> R² = 0.3131, R² diff = 0.4728
# theta | SuperZZ2 -> R² = -0.0767, R² diff = 0.4203
# theta | LSG-1 -> R² = -0.5561, R² diff = 0.4341
# theta | LSG-2 -> R² = -0.0428, R² diff = 0.4053
# theta | ZZx1-inv -> R² = 0.8766, R² diff = 0.5647
# theta | ZZx1 -> R² = 0.0667, R² diff = 0.3742
# theta | ZZx2-inv2 -> R² = 0.3809, R² diff = 0.3531
# theta | ZZx2 -> R² = -0.8524, R² diff = 0.3361
# theta | ZZxReto -> R² = 0.3302, R² diff = 0.4455
# theta | ZZy1 -> R² = -16.1625, R² diff = 0.1280
# theta | ZZy2 -> R² = 0.5580, R² diff = 0.4362
# theta | semiCirc -> R² = -11.8227, R² diff = 0.1331
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=2389 salvo.
# Epoch 0 | Train Loss 1.053579 | data Loss 0.952987 |  physics Loss 1.096689 | Val Loss 0.984395
# Epoch 100 | Train Loss 0.407685 | data Loss 0.591921 |  physics Loss 0.328727 | Val Loss 0.828380
# Epoch 200 | Train Loss 0.372669 | data Loss 0.617406 |  physics Loss 0.267782 | Val Loss 0.776219
# Early stopping at epoch 219
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed1595.keras
# theta | SuperZZ1 -> R² = -0.0410, R² diff = 0.4638
# theta | SuperZZ2 -> R² = 0.1624, R² diff = 0.3953
# theta | LSG-1 -> R² = -1.3588, R² diff = 0.4052
# theta | LSG-2 -> R² = -0.5319, R² diff = 0.4012
# theta | ZZx1-inv -> R² = 0.8887, R² diff = 0.5755
# theta | ZZx1 -> R² = -0.1735, R² diff = 0.3245
# theta | ZZx2-inv2 -> R² = 0.1887, R² diff = 0.2967
# theta | ZZx2 -> R² = -0.5311, R² diff = 0.3336
# theta | ZZxReto -> R² = 0.2075, R² diff = 0.4168
# theta | ZZy1 -> R² = -16.4916, R² diff = 0.1047
# theta | ZZy2 -> R² = 0.8282, R² diff = 0.4212
# theta | semiCirc -> R² = -12.3012, R² diff = 0.1242
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 1.043876 | data Loss 0.977608 |  physics Loss 1.072277 | Val Loss 1.057778
# Epoch 100 | Train Loss 0.419369 | data Loss 0.629086 |  physics Loss 0.329491 | Val Loss 0.940031
# Epoch 200 | Train Loss 0.375074 | data Loss 0.610402 |  physics Loss 0.274219 | Val Loss 0.816676
# Early stopping at epoch 218
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed6927.keras
# theta | SuperZZ1 -> R² = 0.7723, R² diff = 0.4759
# theta | SuperZZ2 -> R² = -1.6507, R² diff = 0.4154
# theta | LSG-1 -> R² = -0.2898, R² diff = 0.4324
# theta | LSG-2 -> R² = 0.4545, R² diff = 0.4091
# theta | ZZx1-inv -> R² = 0.5980, R² diff = 0.5554
# theta | ZZx1 -> R² = 0.1487, R² diff = 0.3863
# theta | ZZx2-inv2 -> R² = 0.0004, R² diff = 0.3638
# theta | ZZx2 -> R² = -1.5175, R² diff = 0.3029
# theta | ZZxReto -> R² = 0.0196, R² diff = 0.4301
# theta | ZZy1 -> R² = -15.7509, R² diff = 0.1398
# theta | ZZy2 -> R² = -0.1278, R² diff = 0.4353
# theta | semiCirc -> R² = -8.5823, R² diff = 0.2158
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=6927 salvo.
# Epoch 0 | Train Loss 1.052590 | data Loss 0.955383 |  physics Loss 1.094251 | Val Loss 0.967424
# Epoch 100 | Train Loss 0.409698 | data Loss 0.599953 |  physics Loss 0.328160 | Val Loss 0.821650
# Epoch 200 | Train Loss 0.363026 | data Loss 0.606473 |  physics Loss 0.258692 | Val Loss 0.864876
# Early stopping at epoch 206
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed4518.keras
# theta | SuperZZ1 -> R² = 0.8192, R² diff = 0.5038
# theta | SuperZZ2 -> R² = -2.6498, R² diff = 0.4157
# theta | LSG-1 -> R² = -0.5424, R² diff = 0.4352
# theta | LSG-2 -> R² = 0.3513, R² diff = 0.4389
# theta | ZZx1-inv -> R² = 0.4419, R² diff = 0.6142
# theta | ZZx1 -> R² = -0.0682, R² diff = 0.3831
# theta | ZZx2-inv2 -> R² = -0.7393, R² diff = 0.3288
# theta | ZZx2 -> R² = -2.1721, R² diff = 0.2946
# theta | ZZxReto -> R² = -0.0889, R² diff = 0.4244
# theta | ZZy1 -> R² = -15.7532, R² diff = 0.1241
# theta | ZZy2 -> R² = 0.1062, R² diff = 0.4772
# theta | semiCirc -> R² = -9.6481, R² diff = 0.2298
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=4518 salvo.
# Epoch 0 | Train Loss 0.986864 | data Loss 0.913504 |  physics Loss 1.018304 | Val Loss 0.965880
# Epoch 100 | Train Loss 0.426219 | data Loss 0.628789 |  physics Loss 0.339403 | Val Loss 0.848422
# Epoch 200 | Train Loss 0.380839 | data Loss 0.610772 |  physics Loss 0.282296 | Val Loss 0.834123
# Early stopping at epoch 217
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.3_Lp0.7_seed306.keras
# theta | SuperZZ1 -> R² = -0.8810, R² diff = 0.4482
# theta | SuperZZ2 -> R² = 0.5012, R² diff = 0.3725
# theta | LSG-1 -> R² = -2.9442, R² diff = 0.3946
# theta | LSG-2 -> R² = -1.9722, R² diff = 0.4016
# theta | ZZx1-inv -> R² = 0.7847, R² diff = 0.5437
# theta | ZZx1 -> R² = -0.5166, R² diff = 0.3145
# theta | ZZx2-inv2 -> R² = 0.5959, R² diff = 0.2809
# theta | ZZx2 -> R² = -1.5657, R² diff = 0.2884
# theta | ZZxReto -> R² = -0.0540, R² diff = 0.3594
# theta | ZZy1 -> R² = -26.8791, R² diff = -0.0583
# theta | ZZy2 -> R² = 0.9097, R² diff = 0.3890
# theta | semiCirc -> R² = -16.8422, R² diff = -0.0036
# Modelo [100] | Ld=0.3 Lp=0.7 r=0.9 seed=306 salvo.
# Epoch 0 | Train Loss 1.091610 | data Loss 1.082342 |  physics Loss 1.113237 | Val Loss 1.187345
# Epoch 100 | Train Loss 0.423188 | data Loss 0.334384 |  physics Loss 0.630398 | Val Loss 0.583593
# Epoch 200 | Train Loss 0.368789 | data Loss 0.270576 |  physics Loss 0.597953 | Val Loss 0.664055
# Early stopping at epoch 263
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed2389.keras
# theta | SuperZZ1 -> R² = 0.7806, R² diff = 0.6170
# theta | SuperZZ2 -> R² = -0.2587, R² diff = 0.5429
# theta | LSG-1 -> R² = -2.4322, R² diff = 0.4586
# theta | LSG-2 -> R² = -0.2944, R² diff = 0.4350
# theta | ZZx1-inv -> R² = 0.7210, R² diff = 0.5808
# theta | ZZx1 -> R² = -0.6162, R² diff = 0.4029
# theta | ZZx2-inv2 -> R² = -0.3519, R² diff = 0.3960
# theta | ZZx2 -> R² = 0.0698, R² diff = 0.4733
# theta | ZZxReto -> R² = -0.0442, R² diff = 0.4369
# theta | ZZy1 -> R² = -42.9111, R² diff = -0.2181
# theta | ZZy2 -> R² = 0.9245, R² diff = 0.5765
# theta | semiCirc -> R² = -20.0521, R² diff = -0.0241
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=2389 salvo.
# Epoch 0 | Train Loss 0.965508 | data Loss 0.919765 |  physics Loss 1.072242 | Val Loss 0.990777
# Epoch 100 | Train Loss 0.412935 | data Loss 0.325803 |  physics Loss 0.616242 | Val Loss 0.607915
# Epoch 200 | Train Loss 0.362156 | data Loss 0.253858 |  physics Loss 0.614850 | Val Loss 0.607585
# Early stopping at epoch 266
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed1595.keras
# theta | SuperZZ1 -> R² = 0.7896, R² diff = 0.6320
# theta | SuperZZ2 -> R² = -0.4338, R² diff = 0.5341
# theta | LSG-1 -> R² = -1.9878, R² diff = 0.4767
# theta | LSG-2 -> R² = -0.1750, R² diff = 0.4582
# theta | ZZx1-inv -> R² = 0.6878, R² diff = 0.5854
# theta | ZZx1 -> R² = -0.1961, R² diff = 0.4148
# theta | ZZx2-inv2 -> R² = -0.5590, R² diff = 0.3742
# theta | ZZx2 -> R² = -0.1293, R² diff = 0.4688
# theta | ZZxReto -> R² = -0.0147, R² diff = 0.4562
# theta | ZZy1 -> R² = -43.3227, R² diff = -0.2047
# theta | ZZy2 -> R² = 0.8548, R² diff = 0.5706
# theta | semiCirc -> R² = -19.5201, R² diff = -0.0185
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 1.029280 | data Loss 1.008473 |  physics Loss 1.077830 | Val Loss 1.080259
# Epoch 100 | Train Loss 0.428227 | data Loss 0.348889 |  physics Loss 0.613349 | Val Loss 0.559367
# Epoch 200 | Train Loss 0.368830 | data Loss 0.273847 |  physics Loss 0.590459 | Val Loss 0.721106
# Epoch 300 | Train Loss 0.337448 | data Loss 0.226913 |  physics Loss 0.595364 | Val Loss 0.767044
# Early stopping at epoch 356
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed6927.keras
# theta | SuperZZ1 -> R² = 0.8492, R² diff = 0.6969
# theta | SuperZZ2 -> R² = -0.2056, R² diff = 0.5471
# theta | LSG-1 -> R² = -1.3255, R² diff = 0.5129
# theta | LSG-2 -> R² = 0.0400, R² diff = 0.5004
# theta | ZZx1-inv -> R² = 0.1849, R² diff = 0.6064
# theta | ZZx1 -> R² = -0.1108, R² diff = 0.3954
# theta | ZZx2-inv2 -> R² = -1.7909, R² diff = 0.2813
# theta | ZZx2 -> R² = 0.5009, R² diff = 0.5714
# theta | ZZxReto -> R² = 0.1681, R² diff = 0.4964
# theta | ZZy1 -> R² = -20.4657, R² diff = 0.1503
# theta | ZZy2 -> R² = 0.8550, R² diff = 0.5993
# theta | semiCirc -> R² = -8.4330, R² diff = 0.3069
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=6927 salvo.
# Epoch 0 | Train Loss 0.993741 | data Loss 0.953565 |  physics Loss 1.087485 | Val Loss 0.996199
# Epoch 100 | Train Loss 0.422280 | data Loss 0.351315 |  physics Loss 0.587866 | Val Loss 0.610096
# Epoch 200 | Train Loss 0.353179 | data Loss 0.261299 |  physics Loss 0.567567 | Val Loss 0.616818
# Early stopping at epoch 259
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed4518.keras
# theta | SuperZZ1 -> R² = 0.6242, R² diff = 0.6134
# theta | SuperZZ2 -> R² = 0.1905, R² diff = 0.5543
# theta | LSG-1 -> R² = -2.9710, R² diff = 0.4338
# theta | LSG-2 -> R² = -0.6904, R² diff = 0.4287
# theta | ZZx1-inv -> R² = 0.7976, R² diff = 0.5819
# theta | ZZx1 -> R² = -1.0344, R² diff = 0.3604
# theta | ZZx2-inv2 -> R² = -0.1943, R² diff = 0.3968
# theta | ZZx2 -> R² = 0.1380, R² diff = 0.4652
# theta | ZZxReto -> R² = -0.1871, R² diff = 0.4010
# theta | ZZy1 -> R² = -40.7801, R² diff = -0.1940
# theta | ZZy2 -> R² = 0.9588, R² diff = 0.5765
# theta | semiCirc -> R² = -18.4626, R² diff = 0.0038
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=4518 salvo.
# Epoch 0 | Train Loss 1.048186 | data Loss 1.001073 |  physics Loss 1.158116 | Val Loss 1.006372
# Epoch 100 | Train Loss 0.441673 | data Loss 0.355551 |  physics Loss 0.642623 | Val Loss 0.608289
# Epoch 200 | Train Loss 0.378220 | data Loss 0.279655 |  physics Loss 0.608204 | Val Loss 0.595582
# Early stopping at epoch 252
# Modelo salvo em:
# models/model_arch100_r0.01_Ld0.7_Lp0.3_seed306.keras
# theta | SuperZZ1 -> R² = 0.6402, R² diff = 0.5334
# theta | SuperZZ2 -> R² = 0.8663, R² diff = 0.5459
# theta | LSG-1 -> R² = -4.3216, R² diff = 0.3311
# theta | LSG-2 -> R² = -2.0977, R² diff = 0.3833
# theta | ZZx1-inv -> R² = -0.5106, R² diff = 0.5009
# theta | ZZx1 -> R² = -1.1140, R² diff = 0.1872
# theta | ZZx2-inv2 -> R² = 0.2956, R² diff = 0.3840
# theta | ZZx2 -> R² = -1.6900, R² diff = 0.3241
# theta | ZZxReto -> R² = -1.5499, R² diff = 0.1644
# theta | ZZy1 -> R² = -57.8720, R² diff = -0.5317
# theta | ZZy2 -> R² = 0.2204, R² diff = 0.5500
# theta | semiCirc -> R² = -16.6806, R² diff = -0.0509
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.01 seed=306 salvo.
# Epoch 0 | Train Loss 0.971012 | data Loss 0.935260 |  physics Loss 1.054433 | Val Loss 0.951825
# Epoch 100 | Train Loss 0.423061 | data Loss 0.341252 |  physics Loss 0.613949 | Val Loss 0.579858
# Epoch 200 | Train Loss 0.366598 | data Loss 0.276279 |  physics Loss 0.577342 | Val Loss 0.584863
# Epoch 300 | Train Loss 0.344565 | data Loss 0.241199 |  physics Loss 0.585752 | Val Loss 0.664092
# Early stopping at epoch 367
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed2389.keras
# theta | SuperZZ1 -> R² = 0.8124, R² diff = 0.6639
# theta | SuperZZ2 -> R² = 0.1700, R² diff = 0.6101
# theta | LSG-1 -> R² = -2.0645, R² diff = 0.4739
# theta | LSG-2 -> R² = -0.6703, R² diff = 0.4704
# theta | ZZx1-inv -> R² = -1.1522, R² diff = 0.5756
# theta | ZZx1 -> R² = -0.4342, R² diff = 0.3358
# theta | ZZx2-inv2 -> R² = -1.7653, R² diff = 0.3604
# theta | ZZx2 -> R² = -0.0486, R² diff = 0.4902
# theta | ZZxReto -> R² = -0.1418, R² diff = 0.4285
# theta | ZZy1 -> R² = -22.2457, R² diff = 0.0748
# theta | ZZy2 -> R² = 0.8841, R² diff = 0.6461
# theta | semiCirc -> R² = -6.4138, R² diff = 0.3034
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=2389 salvo.
# Epoch 0 | Train Loss 1.244823 | data Loss 1.228135 |  physics Loss 1.283759 | Val Loss 1.272681
# Epoch 100 | Train Loss 0.429470 | data Loss 0.347864 |  physics Loss 0.619886 | Val Loss 0.607198
# Epoch 200 | Train Loss 0.385203 | data Loss 0.292480 |  physics Loss 0.601555 | Val Loss 0.621933
# Epoch 300 | Train Loss 0.358575 | data Loss 0.257856 |  physics Loss 0.593588 | Val Loss 0.727030
# Epoch 400 | Train Loss 0.359722 | data Loss 0.260820 |  physics Loss 0.590495 | Val Loss 0.694710
# Epoch 500 | Train Loss 0.342436 | data Loss 0.236980 |  physics Loss 0.588500 | Val Loss 0.800874
# Early stopping at epoch 507
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed1595.keras
# theta | SuperZZ1 -> R² = 0.6428, R² diff = 0.5247
# theta | SuperZZ2 -> R² = 0.6493, R² diff = 0.5884
# theta | LSG-1 -> R² = -0.8137, R² diff = 0.5189
# theta | LSG-2 -> R² = -1.8894, R² diff = 0.4426
# theta | ZZx1-inv -> R² = -2.3921, R² diff = 0.3821
# theta | ZZx1 -> R² = -1.3779, R² diff = 0.2786
# theta | ZZx2-inv2 -> R² = -2.2554, R² diff = 0.1963
# theta | ZZx2 -> R² = -1.0067, R² diff = 0.3038
# theta | ZZxReto -> R² = -2.1333, R² diff = 0.4443
# theta | ZZy1 -> R² = -36.4767, R² diff = 0.0055
# theta | ZZy2 -> R² = 0.8308, R² diff = 0.5829
# theta | semiCirc -> R² = -9.7701, R² diff = 0.1840
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 0.873999 | data Loss 0.825911 |  physics Loss 0.986206 | Val Loss 0.871515
# Epoch 100 | Train Loss 0.425851 | data Loss 0.337478 |  physics Loss 0.632057 | Val Loss 0.570196
# Epoch 200 | Train Loss 0.370878 | data Loss 0.285393 |  physics Loss 0.570341 | Val Loss 0.649018
# Early stopping at epoch 280
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed6927.keras
# theta | SuperZZ1 -> R² = 0.7613, R² diff = 0.6178
# theta | SuperZZ2 -> R² = 0.4094, R² diff = 0.5633
# theta | LSG-1 -> R² = -2.6786, R² diff = 0.3635
# theta | LSG-2 -> R² = -0.8386, R² diff = 0.4133
# theta | ZZx1-inv -> R² = 0.2765, R² diff = 0.5419
# theta | ZZx1 -> R² = -0.9777, R² diff = 0.2759
# theta | ZZx2-inv2 -> R² = -0.2681, R² diff = 0.3811
# theta | ZZx2 -> R² = -0.4573, R² diff = 0.4507
# theta | ZZxReto -> R² = -0.5674, R² diff = 0.2861
# theta | ZZy1 -> R² = -40.2557, R² diff = -0.2609
# theta | ZZy2 -> R² = 0.8862, R² diff = 0.5814
# theta | semiCirc -> R² = -9.7267, R² diff = 0.2082
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=6927 salvo.
# Epoch 0 | Train Loss 0.946301 | data Loss 0.895106 |  physics Loss 1.065754 | Val Loss 0.920469
# Epoch 100 | Train Loss 0.429041 | data Loss 0.352854 |  physics Loss 0.606812 | Val Loss 0.548150
# Epoch 200 | Train Loss 0.377694 | data Loss 0.284393 |  physics Loss 0.595396 | Val Loss 0.615079
# Early stopping at epoch 275
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed4518.keras
# theta | SuperZZ1 -> R² = 0.8617, R² diff = 0.6300
# theta | SuperZZ2 -> R² = -0.8513, R² diff = 0.5438
# theta | LSG-1 -> R² = -1.7839, R² diff = 0.4897
# theta | LSG-2 -> R² = -0.0204, R² diff = 0.4522
# theta | ZZx1-inv -> R² = 0.5500, R² diff = 0.5810
# theta | ZZx1 -> R² = -0.2165, R² diff = 0.4199
# theta | ZZx2-inv2 -> R² = -0.8376, R² diff = 0.3906
# theta | ZZx2 -> R² = 0.4567, R² diff = 0.4978
# theta | ZZxReto -> R² = 0.1194, R² diff = 0.4691
# theta | ZZy1 -> R² = -36.3298, R² diff = -0.0878
# theta | ZZy2 -> R² = 0.7423, R² diff = 0.5729
# theta | semiCirc -> R² = -19.7521, R² diff = -0.0251
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=4518 salvo.
# Epoch 0 | Train Loss 1.011278 | data Loss 0.968510 |  physics Loss 1.111069 | Val Loss 0.981193
# Epoch 100 | Train Loss 0.462274 | data Loss 0.372316 |  physics Loss 0.672179 | Val Loss 0.558975
# Epoch 200 | Train Loss 0.400197 | data Loss 0.310250 |  physics Loss 0.610074 | Val Loss 0.570507
# Epoch 300 | Train Loss 0.372672 | data Loss 0.278547 |  physics Loss 0.592296 | Val Loss 0.645507
# Epoch 400 | Train Loss 0.355980 | data Loss 0.254966 |  physics Loss 0.591681 | Val Loss 0.622977
# Early stopping at epoch 452
# Modelo salvo em:
# models/model_arch100_r0.9_Ld0.7_Lp0.3_seed306.keras
# theta | SuperZZ1 -> R² = 0.6612, R² diff = 0.6766
# theta | SuperZZ2 -> R² = -0.3450, R² diff = 0.5716
# theta | LSG-1 -> R² = -1.6802, R² diff = 0.4849
# theta | LSG-2 -> R² = -0.4731, R² diff = 0.4861
# theta | ZZx1-inv -> R² = 0.5076, R² diff = 0.5668
# theta | ZZx1 -> R² = -0.4272, R² diff = 0.3326
# theta | ZZx2-inv2 -> R² = -1.5990, R² diff = 0.2926
# theta | ZZx2 -> R² = -0.5048, R² diff = 0.5197
# theta | ZZxReto -> R² = 0.2278, R² diff = 0.4854
# theta | ZZy1 -> R² = -16.4863, R² diff = 0.1839
# theta | ZZy2 -> R² = 0.9070, R² diff = 0.6359
# theta | semiCirc -> R² = -8.8832, R² diff = 0.3858
# Modelo [100] | Ld=0.7 Lp=0.3 r=0.9 seed=306 salvo.
